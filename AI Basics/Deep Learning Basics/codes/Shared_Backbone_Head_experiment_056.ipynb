# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms

import plotly.graph_objects as go

import random
import pandas as pd
import numpy as np

# !pip install torchinfo
from torchinfo import summary
# Out:
# Collecting torchinfo
#   Downloading torchinfo-1.8.0-py3-none-any.whl.metadata (21 kB)
# Downloading torchinfo-1.8.0-py3-none-any.whl (23 kB)
# Installing collected packages: torchinfo
# Successfully installed torchinfo-1.8.0

# %%
# 경고 미 표시

import warnings
warnings.filterwarnings('ignore')

# %%
# Random Seed 고정 (학습 반복 시행 시에도 동일한 결과가 나오도록)

seed = 20251003

random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)
torch.cuda.manual_seed_all(seed)

# %%
# 데이터셋 로딩

transform = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.5,), (0.5,))])

train_dataset = torchvision.datasets.MNIST(root='./data',
                                           train=True,
                                           transform=transform,
                                           download=True)

test_dataset = torchvision.datasets.MNIST(root='./data',
                                          train=False,
                                          transform=transform,
                                          download=True)
# Out:
# 100%|██████████| 9.91M/9.91M [00:00<00:00, 18.1MB/s]
# 100%|██████████| 28.9k/28.9k [00:00<00:00, 493kB/s]
# 100%|██████████| 1.65M/1.65M [00:00<00:00, 4.44MB/s]
# 100%|██████████| 4.54k/4.54k [00:00<00:00, 11.5MB/s]

# %% [markdown]
# **1. 데이터셋 분석**

# %%
# 데이터셋 로딩

from torch.utils.data import DataLoader

BATCH_SIZE = 32

train_loader = DataLoader(train_dataset,
                          batch_size=BATCH_SIZE,
                          shuffle=True)

test_loader = DataLoader(test_dataset,
                         batch_size=BATCH_SIZE,
                         shuffle=False)

# %%
# 클래스 불균형 분석

# 학습 데이터
train_labels = torch.tensor(train_dataset.targets)
train_class_counts = torch.bincount(train_labels)
print(f'train data : {train_class_counts}')

# 테스트 데이터
test_labels = torch.tensor(test_dataset.targets)
test_class_counts = torch.bincount(test_labels)
print(f'test  data : {test_class_counts}')

NUM_CLASSES = len(train_class_counts)
# Out:
# train data : tensor([5923, 6742, 5958, 6131, 5842, 5421, 5918, 6265, 5851, 5949])
# test  data : tensor([ 980, 1135, 1032, 1010,  982,  892,  958, 1028,  974, 1009])

# %%
# 클래스 불균형 분석 (percentage)

train_class_percentage = np.array(train_class_counts) * 100.0 / sum(train_class_counts)

train_y_distrib = pd.DataFrame({'class': list(range(NUM_CLASSES)),
                                'count': train_class_counts,
                                'percentage (%)': train_class_percentage})

train_y_distrib
# Out:
#    class  count  percentage (%)
# 0      0   5923        9.871667
# 1      1   6742       11.236667
# 2      2   5958        9.930000
# 3      3   6131       10.218333
# 4      4   5842        9.736667
# 5      5   5421        9.035000
# 6      6   5918        9.863333
# 7      7   6265       10.441667
# 8      8   5851        9.751667
# 9      9   5949        9.915000

# %%
test_class_percentage = np.array(test_class_counts) * 100.0 / sum(test_class_counts)

test_y_distrib = pd.DataFrame({'class': list(range(NUM_CLASSES)),
                               'count': test_class_counts,
                               'percentage (%)': test_class_percentage})

test_y_distrib
# Out:
#    class  count  percentage (%)
# 0      0    980            9.80
# 1      1   1135           11.35
# 2      2   1032           10.32
# 3      3   1010           10.10
# 4      4    982            9.82
# 5      5    892            8.92
# 6      6    958            9.58
# 7      7   1028           10.28
# 8      8    974            9.74
# 9      9   1009           10.09

# %% [markdown]
# **2. 0, 1, 2 숫자 데이터만 추출**

# %%
from torch.utils.data import Subset

# train dataset
train_targets = torch.tensor(train_dataset.targets)
train_mask = (train_targets == 0) | (train_targets == 5) | (train_targets == 6)
train_indices = torch.where(train_mask)[0]

train_subset = Subset(train_dataset, train_indices)

# test dataset
test_targets = torch.tensor(test_dataset.targets)
test_mask = (test_targets == 0) | (test_targets == 5) | (test_targets == 6)
test_indices = torch.where(test_mask)[0]

test_subset = Subset(test_dataset, test_indices)

# %%
# train, test Data Loader 갱신

train_subset_loader = DataLoader(train_subset,
                                 batch_size=BATCH_SIZE,
                                 shuffle=True)

test_subset_loader = DataLoader(test_subset,
                                batch_size=BATCH_SIZE,
                                shuffle=False)

# %%
# train, test Data Loader 의 class 가 0, 5, 6 뿐인지 확인

train_subset_labels = train_subset.dataset.targets[train_subset.indices]
train_subset_class_counts = torch.bincount(train_subset_labels)
print(f'train data (subset) [0,5,6] : {train_subset_class_counts}')

test_subset_labels = test_subset.dataset.targets[test_subset.indices]
test_subset_class_counts = torch.bincount(test_subset_labels)
print(f'test  data (subset) [0,5,6] : {test_subset_class_counts}')
# Out:
# train data (subset) [0,5,6] : tensor([5923,    0,    0,    0,    0, 5421, 5918])
# test  data (subset) [0,5,6] : tensor([980,   0,   0,   0,   0, 892, 958])

# %% [markdown]
# **3. CNN 모델 정의**

# %%
# 1. Non-Shared backbone & Shared head

class CNN_CASE_1(nn.Module):
    def __init__(self, backbone_1, backbone_2):
        super(CNN_CASE_1, self).__init__()

        self.backbone_1 = backbone_1
        self.backbone_2 = backbone_2
        self.final_linear = nn.Linear(2000, 3)
        self.final_softmax = nn.Softmax(dim=1)

    def forward(self, x):
        x1 = self.backbone_1(x)
        x2 = self.backbone_2(x)
        x = torch.concatenate([x1, x2], dim=1)

        x = self.final_linear(x)
        x = self.final_softmax(x)

        return x

# %%
# 2. Shared backbone & Shared head

class CNN_CASE_2(nn.Module):
    def __init__(self, backbone):
        super(CNN_CASE_2, self).__init__()

        self.backbone = backbone
        self.final_linear = nn.Linear(1000, 3)
        self.final_softmax = nn.Softmax(dim=1)

    def forward(self, x):
        x = self.backbone(x)
        x = self.final_linear(x)
        x = self.final_softmax(x)

        return x

# %%
# 3. Shared backbone & Non-Shared head

class CNN_CASE_3(nn.Module):
    def __init__(self, backbone):
        super(CNN_CASE_3, self).__init__()

        self.backbone = backbone
        self.final_linear_1 = nn.Linear(1000, 2)
        self.final_linear_2 = nn.Linear(1000, 2)
        self.final_softmax = nn.Softmax(dim=1)

    def forward(self, x):
        x = self.backbone(x)
        x1 = self.final_linear_1(x)
        x2 = self.final_linear_2(x)
        x1 = self.final_softmax(x1)
        x2 = self.final_softmax(x2)

        return x1, x2

# %%
# 4. Non-Shared backbone & Non-Shared head (4-1)

class CNN_CASE_4_1(nn.Module):
    def __init__(self, backbone_1, backbone_2):
        super(CNN_CASE_4_1, self).__init__()

        self.backbone_1 = backbone_1
        self.backbone_2 = backbone_2
        self.final_linear_1 = nn.Linear(2000, 2)
        self.final_linear_2 = nn.Linear(2000, 2)
        self.final_softmax = nn.Softmax(dim=1)

    def forward(self, x):
        x11 = self.backbone_1(x)
        x12 = self.backbone_2(x)
        x = torch.concatenate([x11, x12], dim=1)

        x21 = self.final_linear_1(x)
        x22 = self.final_linear_2(x)
        x21 = self.final_softmax(x21)
        x22 = self.final_softmax(x22)

        return x21, x22

# %%
# 5. Non-Shared backbone & Non-Shared head (4-2)

class CNN_CASE_4_2(nn.Module):
    def __init__(self, backbone_1, backbone_2):
        super(CNN_CASE_4_2, self).__init__()

        self.backbone_1 = backbone_1
        self.backbone_2 = backbone_2
        self.final_linear_1 = nn.Linear(1000, 2)
        self.final_linear_2 = nn.Linear(1000, 2)
        self.final_softmax = nn.Softmax(dim=1)

    def forward(self, x):
        x11 = self.backbone_1(x)
        x12 = self.backbone_2(x)
        x21 = self.final_linear_1(x11)
        x22 = self.final_linear_2(x12)
        x21 = self.final_softmax(x21)
        x22 = self.final_softmax(x22)

        return x21, x22

# %% [markdown]
# **4. backbone model 로딩**

# %%
import torchvision.models as models

def define_model(backbone_name, case_name, device):

    # model count
    if case_name in ['1', '4_1', '4_2']:
        model_count = 2
    else:
        model_count = 1

    # load pre-trained backbone model
    pretrained_models = []

    for _ in range(model_count):
        if backbone_name == 'resnet18':
            pretrained_model = models.resnet18(pretrained=True)

        elif backbone_name == 'resnet34':
            pretrained_model = models.resnet34(pretrained=True)

        else:  # resnet50
            pretrained_model = models.resnet50(pretrained=True)

        pretrained_model.conv1 = torch.nn.Conv2d(1, 64,
                                                 kernel_size=(7, 7),
                                                 stride=(2, 2),
                                                 padding=(3, 3),
                                                 bias=False)
        pretrained_models.append(pretrained_model)

    # define full model
    if case_name == '1':
        model = CNN_CASE_1(backbone_1=pretrained_models[0],
                           backbone_2=pretrained_models[1])

    elif case_name == '2':
        model = CNN_CASE_2(backbone=pretrained_models[0])

    elif case_name == '3':
        model = CNN_CASE_3(backbone=pretrained_models[0])

    elif case_name == '4_1':
        model = CNN_CASE_4_1(backbone_1=pretrained_models[0],
                             backbone_2=pretrained_models[1])

    elif case_name == '4_2':
        model = CNN_CASE_4_2(backbone_1=pretrained_models[0],
                             backbone_2=pretrained_models[1])

    # device & optimizer & scheduler setting
    model.to(device)
    model.optimizer = torch.optim.AdamW(model.parameters(), lr=0.0001)
    model.scheduler = torch.optim.lr_scheduler.ExponentialLR(optimizer=model.optimizer,
                                                             gamma=0.95)

    return model

# %% [markdown]
# **5. 모델 구조 출력**

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
input_size=(BATCH_SIZE, 1, 28, 28)

# %%
temp_backbone_name = 'resnet18'

# %%
# 1. Non-Shared backbone & Shared head

model_case_1 = define_model(temp_backbone_name, case_name='1', device=device)
print(summary(model=model_case_1, input_size=input_size))
# Out:
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100%|██████████| 44.7M/44.7M [00:00<00:00, 109MB/s]
# ===============================================================================================
# Layer (type:depth-idx)                        Output Shape              Param #
# ===============================================================================================
# CNN_CASE_1                                    [32, 3]                   --
# ├─ResNet: 1-1                                 [32, 1000]                --
# │    └─Conv2d: 2-1                            [32, 64, 14, 14]          3,136
# │    └─BatchNorm2d: 2-2                       [32, 64, 14, 14]          128
# │    └─ReLU: 2-3                              [32, 64, 14, 14]          --
# │    └─MaxPool2d: 2-4                         [32, 64, 7, 7]            --
# │    └─Sequential: 2-5                        [32, 64, 7, 7]            --
# │    │    └─BasicBlock: 3-1                   [32, 64, 7, 7]            73,984
# │    │    └─BasicBlock: 3-2                   [32, 64, 7, 7]            73,984
# │    └─Sequential: 2-6                        [32, 128, 4, 4]           --
# │    │    └─BasicBlock: 3-3                   [32, 128, 4, 4]           230,144
# │    │    └─BasicBlock: 3-4                   [32, 128, 4, 4]           295,424
# │    └─Sequential: 2-7                        [32, 256, 2, 2]           --
# │    │    └─BasicBlock: 3-5                   [32, 256, 2, 2]           919,040
# │    │    └─BasicBlock: 3-6                   [32, 256, 2, 2]           1,180,672
# │    └─Sequential: 2-8                        [32, 512, 1, 1]           --
# │    │    └─BasicBlock: 3-7                   [32, 512, 1, 1]           3,673,088
# │    │    └─BasicBlock: 3-8                   [32, 512, 1, 1]           4,720,640
# │    └─AdaptiveAvgPool2d: 2-9                 [32, 512, 1, 1]           --
# │    └─Linear: 2-10                           [32, 1000]                513,000
# ├─ResNet: 1-2                                 [32, 1000]                --
# │    └─Conv2d: 2-11                           [32, 64, 14, 14]          3,136
# │    └─BatchNorm2d: 2-12                      [32, 64, 14, 14]          128
# │    └─ReLU: 2-13                             [32, 64, 14, 14]          --
# │    └─MaxPool2d: 2-14                        [32, 64, 7, 7]            --
# │    └─Sequential: 2-15                       [32, 64, 7, 7]            --
# │    │    └─BasicBlock: 3-9                   [32, 64, 7, 7]            73,984
# │    │    └─BasicBlock: 3-10                  [32, 64, 7, 7]            73,984
# │    └─Sequential: 2-16                       [32, 128, 4, 4]           --
# │    │    └─BasicBlock: 3-11                  [32, 128, 4, 4]           230,144
# │    │    └─BasicBlock: 3-12                  [32, 128, 4, 4]           295,424
# │    └─Sequential: 2-17                       [32, 256, 2, 2]           --
# │    │    └─BasicBlock: 3-13                  [32, 256, 2, 2]           919,040
# │    │    └─BasicBlock: 3-14                  [32, 256, 2, 2]           1,180,672
# │    └─Sequential: 2-18                       [32, 512, 1, 1]           --
# │    │    └─BasicBlock: 3-15                  [32, 512, 1, 1]           3,673,088
# │    │    └─BasicBlock: 3-16                  [32, 512, 1, 1]           4,720,640
# │    └─AdaptiveAvgPool2d: 2-19                [32, 512, 1, 1]           --
# │    └─Linear: 2-20                           [32, 1000]                513,000
# ├─Linear: 1-3                                 [32, 3]                   6,003
# ├─Softmax: 1-4                                [32, 3]                   --
# ===============================================================================================
# Total params: 23,372,483
# Trainable params: 23,372,483
# Non-trainable params: 0
# Total mult-adds (Units.GIGABYTES): 2.15
# ===============================================================================================
# Input size (MB): 0.10
# Forward/backward pass size (MB): 44.55
# Params size (MB): 93.49
# Estimated Total Size (MB): 138.14
# ===============================================================================================

# %%
# 2. Shared backbone & Shared head

model_case_2 = define_model(temp_backbone_name, case_name='2', device=device)
print(summary(model=model_case_2, input_size=input_size))
# Out:
# ===============================================================================================
# Layer (type:depth-idx)                        Output Shape              Param #
# ===============================================================================================
# CNN_CASE_2                                    [32, 3]                   --
# ├─ResNet: 1-1                                 [32, 1000]                --
# │    └─Conv2d: 2-1                            [32, 64, 14, 14]          3,136
# │    └─BatchNorm2d: 2-2                       [32, 64, 14, 14]          128
# │    └─ReLU: 2-3                              [32, 64, 14, 14]          --
# │    └─MaxPool2d: 2-4                         [32, 64, 7, 7]            --
# │    └─Sequential: 2-5                        [32, 64, 7, 7]            --
# │    │    └─BasicBlock: 3-1                   [32, 64, 7, 7]            73,984
# │    │    └─BasicBlock: 3-2                   [32, 64, 7, 7]            73,984
# │    └─Sequential: 2-6                        [32, 128, 4, 4]           --
# │    │    └─BasicBlock: 3-3                   [32, 128, 4, 4]           230,144
# │    │    └─BasicBlock: 3-4                   [32, 128, 4, 4]           295,424
# │    └─Sequential: 2-7                        [32, 256, 2, 2]           --
# │    │    └─BasicBlock: 3-5                   [32, 256, 2, 2]           919,040
# │    │    └─BasicBlock: 3-6                   [32, 256, 2, 2]           1,180,672
# │    └─Sequential: 2-8                        [32, 512, 1, 1]           --
# │    │    └─BasicBlock: 3-7                   [32, 512, 1, 1]           3,673,088
# │    │    └─BasicBlock: 3-8                   [32, 512, 1, 1]           4,720,640
# │    └─AdaptiveAvgPool2d: 2-9                 [32, 512, 1, 1]           --
# │    └─Linear: 2-10                           [32, 1000]                513,000
# ├─Linear: 1-2                                 [32, 3]                   3,003
# ├─Softmax: 1-3                                [32, 3]                   --
# ===============================================================================================
# Total params: 11,686,243
# Trainable params: 11,686,243
# Non-trainable params: 0
# Total mult-adds (Units.GIGABYTES): 1.07
# ===============================================================================================
# Input size (MB): 0.10
# Forward/backward pass size (MB): 22.28
# Params size (MB): 46.74
# Estimated Total Size (MB): 69.12
# ===============================================================================================

# %%
# 3. Shared backbone & Non-Shared head

model_case_3 = define_model(temp_backbone_name, case_name='3', device=device)
print(summary(model=model_case_3, input_size=input_size))
# Out:
# ===============================================================================================
# Layer (type:depth-idx)                        Output Shape              Param #
# ===============================================================================================
# CNN_CASE_3                                    [32, 2]                   --
# ├─ResNet: 1-1                                 [32, 1000]                --
# │    └─Conv2d: 2-1                            [32, 64, 14, 14]          3,136
# │    └─BatchNorm2d: 2-2                       [32, 64, 14, 14]          128
# │    └─ReLU: 2-3                              [32, 64, 14, 14]          --
# │    └─MaxPool2d: 2-4                         [32, 64, 7, 7]            --
# │    └─Sequential: 2-5                        [32, 64, 7, 7]            --
# │    │    └─BasicBlock: 3-1                   [32, 64, 7, 7]            73,984
# │    │    └─BasicBlock: 3-2                   [32, 64, 7, 7]            73,984
# │    └─Sequential: 2-6                        [32, 128, 4, 4]           --
# │    │    └─BasicBlock: 3-3                   [32, 128, 4, 4]           230,144
# │    │    └─BasicBlock: 3-4                   [32, 128, 4, 4]           295,424
# │    └─Sequential: 2-7                        [32, 256, 2, 2]           --
# │    │    └─BasicBlock: 3-5                   [32, 256, 2, 2]           919,040
# │    │    └─BasicBlock: 3-6                   [32, 256, 2, 2]           1,180,672
# │    └─Sequential: 2-8                        [32, 512, 1, 1]           --
# │    │    └─BasicBlock: 3-7                   [32, 512, 1, 1]           3,673,088
# │    │    └─BasicBlock: 3-8                   [32, 512, 1, 1]           4,720,640
# │    └─AdaptiveAvgPool2d: 2-9                 [32, 512, 1, 1]           --
# │    └─Linear: 2-10                           [32, 1000]                513,000
# ├─Linear: 1-2                                 [32, 2]                   2,002
# ├─Linear: 1-3                                 [32, 2]                   2,002
# ├─Softmax: 1-4                                [32, 2]                   --
# ├─Softmax: 1-5                                [32, 2]                   --
# ===============================================================================================
# Total params: 11,687,244
# Trainable params: 11,687,244
# Non-trainable params: 0
# Total mult-adds (Units.GIGABYTES): 1.07
# ===============================================================================================
# Input size (MB): 0.10
# Forward/backward pass size (MB): 22.28
# Params size (MB): 46.75
# Estimated Total Size (MB): 69.13
# ===============================================================================================

# %%
# 4. Non-Shared backbone & Non-Shared head (4-1)

model_case_4_1 = define_model(temp_backbone_name, case_name='4_1', device=device)
print(summary(model=model_case_4_1, input_size=input_size))
# Out:
# ===============================================================================================
# Layer (type:depth-idx)                        Output Shape              Param #
# ===============================================================================================
# CNN_CASE_4_1                                  [32, 2]                   --
# ├─ResNet: 1-1                                 [32, 1000]                --
# │    └─Conv2d: 2-1                            [32, 64, 14, 14]          3,136
# │    └─BatchNorm2d: 2-2                       [32, 64, 14, 14]          128
# │    └─ReLU: 2-3                              [32, 64, 14, 14]          --
# │    └─MaxPool2d: 2-4                         [32, 64, 7, 7]            --
# │    └─Sequential: 2-5                        [32, 64, 7, 7]            --
# │    │    └─BasicBlock: 3-1                   [32, 64, 7, 7]            73,984
# │    │    └─BasicBlock: 3-2                   [32, 64, 7, 7]            73,984
# │    └─Sequential: 2-6                        [32, 128, 4, 4]           --
# │    │    └─BasicBlock: 3-3                   [32, 128, 4, 4]           230,144
# │    │    └─BasicBlock: 3-4                   [32, 128, 4, 4]           295,424
# │    └─Sequential: 2-7                        [32, 256, 2, 2]           --
# │    │    └─BasicBlock: 3-5                   [32, 256, 2, 2]           919,040
# │    │    └─BasicBlock: 3-6                   [32, 256, 2, 2]           1,180,672
# │    └─Sequential: 2-8                        [32, 512, 1, 1]           --
# │    │    └─BasicBlock: 3-7                   [32, 512, 1, 1]           3,673,088
# │    │    └─BasicBlock: 3-8                   [32, 512, 1, 1]           4,720,640
# │    └─AdaptiveAvgPool2d: 2-9                 [32, 512, 1, 1]           --
# │    └─Linear: 2-10                           [32, 1000]                513,000
# ├─ResNet: 1-2                                 [32, 1000]                --
# │    └─Conv2d: 2-11                           [32, 64, 14, 14]          3,136
# │    └─BatchNorm2d: 2-12                      [32, 64, 14, 14]          128
# │    └─ReLU: 2-13                             [32, 64, 14, 14]          --
# │    └─MaxPool2d: 2-14                        [32, 64, 7, 7]            --
# │    └─Sequential: 2-15                       [32, 64, 7, 7]            --
# │    │    └─BasicBlock: 3-9                   [32, 64, 7, 7]            73,984
# │    │    └─BasicBlock: 3-10                  [32, 64, 7, 7]            73,984
# │    └─Sequential: 2-16                       [32, 128, 4, 4]           --
# │    │    └─BasicBlock: 3-11                  [32, 128, 4, 4]           230,144
# │    │    └─BasicBlock: 3-12                  [32, 128, 4, 4]           295,424
# │    └─Sequential: 2-17                       [32, 256, 2, 2]           --
# │    │    └─BasicBlock: 3-13                  [32, 256, 2, 2]           919,040
# │    │    └─BasicBlock: 3-14                  [32, 256, 2, 2]           1,180,672
# │    └─Sequential: 2-18                       [32, 512, 1, 1]           --
# │    │    └─BasicBlock: 3-15                  [32, 512, 1, 1]           3,673,088
# │    │    └─BasicBlock: 3-16                  [32, 512, 1, 1]           4,720,640
# │    └─AdaptiveAvgPool2d: 2-19                [32, 512, 1, 1]           --
# │    └─Linear: 2-20                           [32, 1000]                513,000
# ├─Linear: 1-3                                 [32, 2]                   4,002
# ├─Linear: 1-4                                 [32, 2]                   4,002
# ├─Softmax: 1-5                                [32, 2]                   --
# ├─Softmax: 1-6                                [32, 2]                   --
# ===============================================================================================
# Total params: 23,374,484
# Trainable params: 23,374,484
# Non-trainable params: 0
# Total mult-adds (Units.GIGABYTES): 2.15
# ===============================================================================================
# Input size (MB): 0.10
# Forward/backward pass size (MB): 44.55
# Params size (MB): 93.50
# Estimated Total Size (MB): 138.15
# ===============================================================================================

# %%
# 5. Non-Shared backbone & Non-Shared head (4-2)

model_case_4_2 = define_model(temp_backbone_name, case_name='4_2', device=device)
print(summary(model=model_case_4_2, input_size=input_size))
# Out:
# ===============================================================================================
# Layer (type:depth-idx)                        Output Shape              Param #
# ===============================================================================================
# CNN_CASE_4_2                                  [32, 2]                   --
# ├─ResNet: 1-1                                 [32, 1000]                --
# │    └─Conv2d: 2-1                            [32, 64, 14, 14]          3,136
# │    └─BatchNorm2d: 2-2                       [32, 64, 14, 14]          128
# │    └─ReLU: 2-3                              [32, 64, 14, 14]          --
# │    └─MaxPool2d: 2-4                         [32, 64, 7, 7]            --
# │    └─Sequential: 2-5                        [32, 64, 7, 7]            --
# │    │    └─BasicBlock: 3-1                   [32, 64, 7, 7]            73,984
# │    │    └─BasicBlock: 3-2                   [32, 64, 7, 7]            73,984
# │    └─Sequential: 2-6                        [32, 128, 4, 4]           --
# │    │    └─BasicBlock: 3-3                   [32, 128, 4, 4]           230,144
# │    │    └─BasicBlock: 3-4                   [32, 128, 4, 4]           295,424
# │    └─Sequential: 2-7                        [32, 256, 2, 2]           --
# │    │    └─BasicBlock: 3-5                   [32, 256, 2, 2]           919,040
# │    │    └─BasicBlock: 3-6                   [32, 256, 2, 2]           1,180,672
# │    └─Sequential: 2-8                        [32, 512, 1, 1]           --
# │    │    └─BasicBlock: 3-7                   [32, 512, 1, 1]           3,673,088
# │    │    └─BasicBlock: 3-8                   [32, 512, 1, 1]           4,720,640
# │    └─AdaptiveAvgPool2d: 2-9                 [32, 512, 1, 1]           --
# │    └─Linear: 2-10                           [32, 1000]                513,000
# ├─ResNet: 1-2                                 [32, 1000]                --
# │    └─Conv2d: 2-11                           [32, 64, 14, 14]          3,136
# │    └─BatchNorm2d: 2-12                      [32, 64, 14, 14]          128
# │    └─ReLU: 2-13                             [32, 64, 14, 14]          --
# │    └─MaxPool2d: 2-14                        [32, 64, 7, 7]            --
# │    └─Sequential: 2-15                       [32, 64, 7, 7]            --
# │    │    └─BasicBlock: 3-9                   [32, 64, 7, 7]            73,984
# │    │    └─BasicBlock: 3-10                  [32, 64, 7, 7]            73,984
# │    └─Sequential: 2-16                       [32, 128, 4, 4]           --
# │    │    └─BasicBlock: 3-11                  [32, 128, 4, 4]           230,144
# │    │    └─BasicBlock: 3-12                  [32, 128, 4, 4]           295,424
# │    └─Sequential: 2-17                       [32, 256, 2, 2]           --
# │    │    └─BasicBlock: 3-13                  [32, 256, 2, 2]           919,040
# │    │    └─BasicBlock: 3-14                  [32, 256, 2, 2]           1,180,672
# │    └─Sequential: 2-18                       [32, 512, 1, 1]           --
# │    │    └─BasicBlock: 3-15                  [32, 512, 1, 1]           3,673,088
# │    │    └─BasicBlock: 3-16                  [32, 512, 1, 1]           4,720,640
# │    └─AdaptiveAvgPool2d: 2-19                [32, 512, 1, 1]           --
# │    └─Linear: 2-20                           [32, 1000]                513,000
# ├─Linear: 1-3                                 [32, 2]                   2,002
# ├─Linear: 1-4                                 [32, 2]                   2,002
# ├─Softmax: 1-5                                [32, 2]                   --
# ├─Softmax: 1-6                                [32, 2]                   --
# ===============================================================================================
# Total params: 23,370,484
# Trainable params: 23,370,484
# Non-trainable params: 0
# Total mult-adds (Units.GIGABYTES): 2.15
# ===============================================================================================
# Input size (MB): 0.10
# Forward/backward pass size (MB): 44.55
# Params size (MB): 93.48
# Estimated Total Size (MB): 138.14
# ===============================================================================================

# %% [markdown]
# **6. 데이터셋 분리**
#
# * Train Data -> Train Data + Valid Data

# %%
# dataset size

num_tv = sum(train_subset_class_counts)
num_valid = int(0.1 * num_tv)
num_train = num_tv - num_valid

# %%
# 데이터셋 분리

from torch.utils.data import random_split

train_dataset, valid_dataset = random_split(train_subset, [num_train, num_valid])

# %%
# {0,1,2} -> {0,5,6} Mapping 된 DataLoader 생성

from torch.utils.data import Dataset

class MappedDataset(Dataset):
    def __init__(self, dataset):
        self.dataset = dataset

    def __len__(self):
        return len(self.dataset)

    def __getitem__(self, idx):
        img, target = self.dataset[idx]
        target_mapping = {0: 0, 5: 1, 6: 2}
        target = target_mapping[target]

        return img, target

# %%
# DataLoader 생성

train_dataset_loader = DataLoader(MappedDataset(train_dataset),
                                  batch_size=BATCH_SIZE,
                                  shuffle=True)

valid_dataset_loader = DataLoader(MappedDataset(valid_dataset),
                                  batch_size=BATCH_SIZE,
                                  shuffle=False)

test_dataset_loader = DataLoader(MappedDataset(test_subset),
                                 batch_size=BATCH_SIZE,
                                 shuffle=False)

# %%
# {0,5} vs. {6} / {0,6} vs. {5} Split 된 DataLoader 생성

class DualOutputDataset(Dataset):
    def __init__(self, dataset):
        self.dataset = dataset

    def __len__(self):
        return len(self.dataset)

    def __getitem__(self, idx):
        img, target = self.dataset[idx]
        target1_mapping = {0: 0, 5: 0, 6: 1}
        target2_mapping = {0: 0, 5: 1, 6: 0}

        target1 = target1_mapping[target]
        target2 = target2_mapping[target]

        return img, [target1, target2]

# %%
# Dual Output Dataset 생성

train_01_02_dataset_loader = DataLoader(DualOutputDataset(train_dataset),
                                        batch_size=BATCH_SIZE,
                                        shuffle=True)

valid_01_02_dataset_loader = DataLoader(DualOutputDataset(valid_dataset),
                                        batch_size=BATCH_SIZE,
                                        shuffle=False)

test_01_02_dataset_loader = DataLoader(DualOutputDataset(test_subset),
                                       batch_size=BATCH_SIZE,
                                       shuffle=False)

# %% [markdown]
# **7. 모델 학습 함수 정의**

# %%
MAX_EPOCHS = 9999
EARLY_STOPPING_ROUNDS = 10  # Early Stopping Patience (epochs)

# %%
# dual labels -> PyTorch tensor

def convert_to_tensor(labels):
    labels[0] = list(labels[0])
    labels[1] = list(labels[1])
    labels_tensor = torch.tensor(labels)
    labels_tensor = labels_tensor.transpose(0, 1)

    return labels_tensor

# %%
# 모델 학습 실시

# args :
# - model           : 학습할 모델
# - train_loader    : Training Data Loader
# - train_loss_list : 각 epoch 에서의 train loss 기록
# - is_dual_head    : 신경망 출력값, 즉 MLP Head 가 2개인지의 여부

# returns :
# - train_loss : 모델의 Train Loss

def run_train(model, train_loader, train_loss_list, is_dual_head, verbose):
    model.train()
    train_loss = 0.0
    train_idx = 0

    for images, labels in train_loader:
        if is_dual_head:
            labels = convert_to_tensor(labels)
        images, labels = images.to(device), labels.to(device)

        # train 실시
        model.optimizer.zero_grad()
        outputs = model(images)

        if is_dual_head:
            loss1 = nn.CrossEntropyLoss()(outputs[0], labels[:, 0])
            loss2 = nn.CrossEntropyLoss()(outputs[1], labels[:, 1])
            loss = loss1 + loss2
        else:
            loss = nn.CrossEntropyLoss()(outputs, labels)

        loss.backward()
        model.optimizer.step()

        train_loss += loss.item()
        train_idx += 1

        if verbose:
            if train_idx % 20 == 0:
                print(f'idx: {train_idx}, loss for current idx: {loss.item():.6f}')

    train_loss_list.append(train_loss / len(train_loader))
    return train_loss_list[-1]

# %%
import time

# 모델 validation / test 실시

# args :
# - model                : validation/test 할 모델
# - valid_or_test_loader : validation/test Data Loader
# - is_dual_head         : 신경망 출력값, 즉 MLP Head 가 2개인지의 여부

# returns :
# - accuracy       : 모델의 validation/test 정확도
# - inference_time : inference 시간 (seconds)

def run_valid_or_test(model, valid_or_test_loader, is_dual_head):
    model.eval()
    correct, total = 0, 0
    inference_time_sum = 0.0
    valid_test_idx = 0

    with torch.no_grad():
        for images, labels in valid_or_test_loader:
            if is_dual_head:
                labels = convert_to_tensor(labels)
            images, labels = images.to(device), labels.to(device)

            start_at = time.time()
            outputs = model(images)
            inference_time_sum += time.time() - start_at

            # validation/test 실시 및 정확도 측정
            if is_dual_head:
                _, predicted_1 = torch.max(outputs[0], 1)
                _, predicted_2 = torch.max(outputs[1], 1)
                correct += ((predicted_1 == labels[:, 0]) & (predicted_2 == labels[:, 1])).sum().item()

            else:
                _, predicted = torch.max(outputs, 1)
                correct += (predicted == labels).sum().item()

            total += labels.size(0)
            valid_test_idx += 1

    accuracy = correct / total
    inference_time = inference_time_sum / valid_test_idx

    return accuracy, inference_time

# %%
# 모델 학습 및 validation 전체 프로세스

# args :
# - model         : 학습할 모델
# - train_loader  : Training Data Loader
# - valid_loader  : Valid Data Loader
# - test_loader   : Test Data Loader
# - backbone_name : Backbone 모델 이름 ('resnet18', 'resnet34' or 'resnet50')
# - case_name     : 모델 구조 case 이름 ('1', '2', '3', '4_1' or '4_2')
# - verbose       : 학습 중 프로세스 출력 여부

# returns :
# - final_acc      : 해당 하이퍼파라미터 조합에 대한 최종 Accuracy (valid_acc 이 가장 높았던 epoch 의 모델로 측정)
# - inference_time : inference 시간 (seconds)

def run_model_common(model, train_loader, valid_loader, test_loader,
                     backbone_name, case_name, verbose=False):

    train_loss_list = []       # train loss
    valid_acc_list = []        # valid accuracy
    max_valid_acc = 0.0        # max validation accuracy
    best_valid_acc_epoch = -1  # valid_acc 이 가장 높았던 epoch (여기서는 Loss 가 아닌 Accuracy 기준 Early Stopping)
    best_epoch_model = None    # valid_acc 이 가장 높았던 epoch 의 모델

    is_dual_head = case_name in ['3', '4_1', '4_2']

    # 1. 학습 실시
    for epoch in range(MAX_EPOCHS):

        # 1-1. train model
        train_loss = run_train(model,
                               train_loader,
                               train_loss_list,
                               is_dual_head,
                               verbose=(verbose and epoch == 0))

        # 1-2. validate model (with VALID SET)
        epoch_acc, _ = run_valid_or_test(model, valid_loader, is_dual_head)
        valid_acc_list.append(epoch_acc)

        # 1-3. Early Stopping 처리 (overfitting 방지)
        if epoch_acc > max_valid_acc:
            max_valid_acc = epoch_acc
            best_valid_acc_epoch = epoch

            best_epoch_model = define_model(backbone_name, case_name, device)
            best_epoch_model.load_state_dict(model.state_dict())

            if verbose:
                print('best model updated')

        if epoch - best_valid_acc_epoch >= EARLY_STOPPING_ROUNDS:
            break

        # 1-4. 결과 출력
        if verbose:
            print(f"Epoch {epoch+1}, Loss: {train_loss:.4f}, Accuracy: {epoch_acc:.4f}")

    # check best-epoch model correctly loaded
    checked_acc, _ = run_valid_or_test(best_epoch_model, valid_loader, is_dual_head)

    if verbose:
        print(f"Best Epoch: {best_valid_acc_epoch}, Best Valid Acc: {max_valid_acc}")
        print(f"Valid Acc (with Epoch valid set) on Loaded Best Model: {checked_acc}")

    assert abs(max_valid_acc - checked_acc) < 1e-6

    # 2. test best-epoch model (with TEST SET)
    final_acc, inference_time = run_valid_or_test(best_epoch_model, test_loader, is_dual_head)

    if verbose:
        print(f"Final Acc (with TEST set) on Loaded Best Model: {final_acc} (time: {inference_time})")

    return final_acc, inference_time

# %% [markdown]
# **8. 학습 실시**

# %%
print(device)
# Out:
# cuda

# %%
result_dict = {
    'backbone': [],
    'case': [],
    'accuracy': [],
    'inference_time': []
}

dataloader_by_case_name = {
    'dual_head': {
        'train': train_01_02_dataset_loader,
        'valid': valid_01_02_dataset_loader,
        'test': test_01_02_dataset_loader
    },
    'single_head': {
        'train': train_dataset_loader,
        'valid': valid_dataset_loader,
        'test': test_dataset_loader
    }
}

for case_name in ['1', '2', '3', '4_1', '4_2']:
    if case_name in ['3', '4_1', '4_2']:
        head_type = 'dual_head'
    else:
        head_type = 'single_head'

    for backbone_name in ['resnet18', 'resnet34', 'resnet50']:
        print(f'\n=== case={case_name}, backbone={backbone_name} ===')
        model = define_model(backbone_name, case_name, device=device)

        train_loader = dataloader_by_case_name[head_type]['train']
        valid_loader = dataloader_by_case_name[head_type]['valid']
        test_loader = dataloader_by_case_name[head_type]['test']

        final_acc, inference_time = run_model_common(model,
                                                     train_loader=train_loader,
                                                     valid_loader=valid_loader,
                                                     test_loader=test_loader,
                                                     backbone_name=backbone_name,
                                                     case_name=case_name,
                                                     verbose=True)

        result_dict['backbone'].append(backbone_name)
        result_dict['case'].append(case_name)
        result_dict['accuracy'].append(final_acc)
        result_dict['inference_time'].append(inference_time)
# Out:
# === case=1, backbone=resnet18 ===
# idx: 20, loss for current idx: 0.691994
# idx: 40, loss for current idx: 0.697704
# idx: 60, loss for current idx: 0.625606
# idx: 80, loss for current idx: 0.607090
# idx: 100, loss for current idx: 0.573112
# idx: 120, loss for current idx: 0.584160
# idx: 140, loss for current idx: 0.582782
# idx: 160, loss for current idx: 0.592025
# idx: 180, loss for current idx: 0.551550
# idx: 200, loss for current idx: 0.568720
# idx: 220, loss for current idx: 0.581916
# idx: 240, loss for current idx: 0.610129
# idx: 260, loss for current idx: 0.634942
# idx: 280, loss for current idx: 0.551463
# idx: 300, loss for current idx: 0.574960
# idx: 320, loss for current idx: 0.598945
# idx: 340, loss for current idx: 0.556584
# idx: 360, loss for current idx: 0.584673
# idx: 380, loss for current idx: 0.630444
# idx: 400, loss for current idx: 0.646151
# idx: 420, loss for current idx: 0.579609
# idx: 440, loss for current idx: 0.639449
# idx: 460, loss for current idx: 0.560195
# idx: 480, loss for current idx: 0.582573
# best model updated
# Epoch 1, Loss: 0.5980, Accuracy: 0.9855
# best model updated
# Epoch 2, Loss: 0.5744, Accuracy: 0.9902
# Epoch 3, Loss: 0.5671, Accuracy: 0.9884
# Epoch 4, Loss: 0.5672, Accuracy: 0.9855
# Epoch 5, Loss: 0.5622, Accuracy: 0.9867
# Epoch 6, Loss: 0.5639, Accuracy: 0.9884
# best model updated
# Epoch 7, Loss: 0.5601, Accuracy: 0.9930
# Epoch 8, Loss: 0.5598, Accuracy: 0.9913
# Epoch 9, Loss: 0.5609, Accuracy: 0.9849
# Epoch 10, Loss: 0.5609, Accuracy: 0.9925
# Epoch 11, Loss: 0.5645, Accuracy: 0.9907
# best model updated
# Epoch 12, Loss: 0.5603, Accuracy: 0.9954
# Epoch 13, Loss: 0.5614, Accuracy: 0.9925
# Epoch 14, Loss: 0.5640, Accuracy: 0.9913
# Epoch 15, Loss: 0.5642, Accuracy: 0.9907
# Epoch 16, Loss: 0.5620, Accuracy: 0.9925
# best model updated
# Epoch 17, Loss: 0.5599, Accuracy: 0.9959
# Epoch 18, Loss: 0.5591, Accuracy: 0.9942
# best model updated
# Epoch 19, Loss: 0.5623, Accuracy: 0.9965
# Epoch 20, Loss: 0.5581, Accuracy: 0.9942
# Epoch 21, Loss: 0.5603, Accuracy: 0.9948
# Epoch 22, Loss: 0.5654, Accuracy: 0.9878
# Epoch 23, Loss: 0.5688, Accuracy: 0.9699
# Epoch 24, Loss: 0.5716, Accuracy: 0.9844
# Epoch 25, Loss: 0.5625, Accuracy: 0.9907
# Epoch 26, Loss: 0.5600, Accuracy: 0.9930
# Epoch 27, Loss: 0.5608, Accuracy: 0.9936
# Epoch 28, Loss: 0.5576, Accuracy: 0.9954
# Best Epoch: 18, Best Valid Acc: 0.996523754345307
# Valid Acc (with Epoch valid set) on Loaded Best Model: 0.996523754345307
# Final Acc (with TEST set) on Loaded Best Model: 0.995053003533569 (time: 0.005235797903510962)
#
# === case=1, backbone=resnet34 ===
# Downloading: "https://download.pytorch.org/models/resnet34-b627a593.pth" to /root/.cache/torch/hub/checkpoints/resnet34-b627a593.pth
# 100%|██████████| 83.3M/83.3M [00:00<00:00, 191MB/s]
# idx: 20, loss for current idx: 0.608138
# idx: 40, loss for current idx: 0.684254
# idx: 60, loss for current idx: 0.586645
# idx: 80, loss for current idx: 0.615842
# idx: 100, loss for current idx: 0.623437
# idx: 120, loss for current idx: 0.620016
# idx: 140, loss for current idx: 0.584581
# idx: 160, loss for current idx: 0.581304
# idx: 180, loss for current idx: 0.620951
# idx: 200, loss for current idx: 0.609198
# idx: 220, loss for current idx: 0.551632
# idx: 240, loss for current idx: 0.596755
# idx: 260, loss for current idx: 0.583143
# idx: 280, loss for current idx: 0.600916
# idx: 300, loss for current idx: 0.606932
# idx: 320, loss for current idx: 0.551518
# idx: 340, loss for current idx: 0.582404
# idx: 360, loss for current idx: 0.558337
# idx: 380, loss for current idx: 0.694951
# idx: 400, loss for current idx: 0.562874
# idx: 420, loss for current idx: 0.571599
# idx: 440, loss for current idx: 0.590084
# idx: 460, loss for current idx: 0.551502
# idx: 480, loss for current idx: 0.587066
# best model updated
# Epoch 1, Loss: 0.6041, Accuracy: 0.9838
# best model updated
# Epoch 2, Loss: 0.5713, Accuracy: 0.9884
# Epoch 3, Loss: 0.5679, Accuracy: 0.9849
# best model updated
# Epoch 4, Loss: 0.5646, Accuracy: 0.9907
# best model updated
# Epoch 5, Loss: 0.5611, Accuracy: 0.9942
# Epoch 6, Loss: 0.5611, Accuracy: 0.9907
# Epoch 7, Loss: 0.5608, Accuracy: 0.9786
# Epoch 8, Loss: 0.5603, Accuracy: 0.9809
# Epoch 9, Loss: 0.5593, Accuracy: 0.9902
# Epoch 10, Loss: 0.5582, Accuracy: 0.9925
# Epoch 11, Loss: 0.5587, Accuracy: 0.9913
# Epoch 12, Loss: 0.5730, Accuracy: 0.9861
# Epoch 13, Loss: 0.5593, Accuracy: 0.9925
# Epoch 14, Loss: 0.5585, Accuracy: 0.9919
# Best Epoch: 4, Best Valid Acc: 0.9942062572421785
# Valid Acc (with Epoch valid set) on Loaded Best Model: 0.9942062572421785
# Final Acc (with TEST set) on Loaded Best Model: 0.9946996466431095 (time: 0.008719473742367177)
#
# === case=1, backbone=resnet50 ===
# Downloading: "https://download.pytorch.org/models/resnet50-0676ba61.pth" to /root/.cache/torch/hub/checkpoints/resnet50-0676ba61.pth
# 100%|██████████| 97.8M/97.8M [00:00<00:00, 140MB/s]
# idx: 20, loss for current idx: 0.859645
# idx: 40, loss for current idx: 0.586241
# idx: 60, loss for current idx: 0.616649
# idx: 80, loss for current idx: 0.583222
# idx: 100, loss for current idx: 0.679040
# idx: 120, loss for current idx: 0.662743
# idx: 140, loss for current idx: 0.672166
# idx: 160, loss for current idx: 0.600174
# idx: 180, loss for current idx: 0.551824
# idx: 200, loss for current idx: 0.603475
# idx: 220, loss for current idx: 0.559286
# idx: 240, loss for current idx: 0.552876
# idx: 260, loss for current idx: 0.551476
# idx: 280, loss for current idx: 0.583552
# idx: 300, loss for current idx: 0.557593
# idx: 320, loss for current idx: 0.572128
# idx: 340, loss for current idx: 0.559089
# idx: 360, loss for current idx: 0.610202
# idx: 380, loss for current idx: 0.551627
# idx: 400, loss for current idx: 0.665427
# idx: 420, loss for current idx: 0.551609
# idx: 440, loss for current idx: 0.594761
# idx: 460, loss for current idx: 0.552382
# idx: 480, loss for current idx: 0.551667
# best model updated
# Epoch 1, Loss: 0.6200, Accuracy: 0.9739
# best model updated
# Epoch 2, Loss: 0.5775, Accuracy: 0.9780
# Epoch 3, Loss: 0.5677, Accuracy: 0.9687
# best model updated
# Epoch 4, Loss: 0.5658, Accuracy: 0.9861
# best model updated
# Epoch 5, Loss: 0.5647, Accuracy: 0.9954
# Epoch 6, Loss: 0.5649, Accuracy: 0.9426
# Epoch 7, Loss: 0.5768, Accuracy: 0.9919
# Epoch 8, Loss: 0.5627, Accuracy: 0.9919
# Epoch 9, Loss: 0.5601, Accuracy: 0.9930
# Epoch 10, Loss: 0.5639, Accuracy: 0.9930
# Epoch 11, Loss: 0.5589, Accuracy: 0.9936
# Epoch 12, Loss: 0.5598, Accuracy: 0.9780
# Epoch 13, Loss: 0.5606, Accuracy: 0.9913
# Epoch 14, Loss: 0.5597, Accuracy: 0.9942
# Best Epoch: 4, Best Valid Acc: 0.9953650057937428
# Valid Acc (with Epoch valid set) on Loaded Best Model: 0.9953650057937428
# Final Acc (with TEST set) on Loaded Best Model: 0.9929328621908127 (time: 0.014324107866608695)
#
# === case=2, backbone=resnet18 ===
# idx: 20, loss for current idx: 0.701242
# idx: 40, loss for current idx: 0.648385
# idx: 60, loss for current idx: 0.599870
# idx: 80, loss for current idx: 0.597812
# idx: 100, loss for current idx: 0.578889
# idx: 120, loss for current idx: 0.628012
# idx: 140, loss for current idx: 0.597902
# idx: 160, loss for current idx: 0.589301
# idx: 180, loss for current idx: 0.562038
# idx: 200, loss for current idx: 0.568963
# idx: 220, loss for current idx: 0.567994
# idx: 240, loss for current idx: 0.584576
# idx: 260, loss for current idx: 0.585979
# idx: 280, loss for current idx: 0.576326
# idx: 300, loss for current idx: 0.551450
# idx: 320, loss for current idx: 0.556345
# idx: 340, loss for current idx: 0.584955
# idx: 360, loss for current idx: 0.552080
# idx: 380, loss for current idx: 0.554178
# idx: 400, loss for current idx: 0.552279
# idx: 420, loss for current idx: 0.613501
# idx: 440, loss for current idx: 0.565688
# idx: 460, loss for current idx: 0.551535
# idx: 480, loss for current idx: 0.577072
# best model updated
# Epoch 1, Loss: 0.6146, Accuracy: 0.9820
# best model updated
# Epoch 2, Loss: 0.5731, Accuracy: 0.9873
# Epoch 3, Loss: 0.5647, Accuracy: 0.9861
# best model updated
# Epoch 4, Loss: 0.5625, Accuracy: 0.9878
# best model updated
# Epoch 5, Loss: 0.5603, Accuracy: 0.9913
# Epoch 6, Loss: 0.5639, Accuracy: 0.9907
# Epoch 7, Loss: 0.5671, Accuracy: 0.9896
# Epoch 8, Loss: 0.5626, Accuracy: 0.9902
# best model updated
# Epoch 9, Loss: 0.5616, Accuracy: 0.9930
# Epoch 10, Loss: 0.5653, Accuracy: 0.9884
# best model updated
# Epoch 11, Loss: 0.5632, Accuracy: 0.9948
# Epoch 12, Loss: 0.5653, Accuracy: 0.9716
# Epoch 13, Loss: 0.5663, Accuracy: 0.9902
# Epoch 14, Loss: 0.5661, Accuracy: 0.9878
# Epoch 15, Loss: 0.5694, Accuracy: 0.9873
# Epoch 16, Loss: 0.5675, Accuracy: 0.9936
# Epoch 17, Loss: 0.5615, Accuracy: 0.9722
# Epoch 18, Loss: 0.5732, Accuracy: 0.9913
# Epoch 19, Loss: 0.5669, Accuracy: 0.9913
# Epoch 20, Loss: 0.5775, Accuracy: 0.9838
# Best Epoch: 10, Best Valid Acc: 0.9947856315179606
# Valid Acc (with Epoch valid set) on Loaded Best Model: 0.9947856315179606
# Final Acc (with TEST set) on Loaded Best Model: 0.9908127208480565 (time: 0.002621133675735988)
#
# === case=2, backbone=resnet34 ===
# idx: 20, loss for current idx: 0.776763
# idx: 40, loss for current idx: 0.625161
# idx: 60, loss for current idx: 0.614632
# idx: 80, loss for current idx: 0.582994
# idx: 100, loss for current idx: 0.614806
# idx: 120, loss for current idx: 0.560343
# idx: 140, loss for current idx: 0.565041
# idx: 160, loss for current idx: 0.617585
# idx: 180, loss for current idx: 0.564994
# idx: 200, loss for current idx: 0.577750
# idx: 220, loss for current idx: 0.583757
# idx: 240, loss for current idx: 0.585875
# idx: 260, loss for current idx: 0.552340
# idx: 280, loss for current idx: 0.603954
# idx: 300, loss for current idx: 0.684680
# idx: 320, loss for current idx: 0.580313
# idx: 340, loss for current idx: 0.590452
# idx: 360, loss for current idx: 0.637182
# idx: 380, loss for current idx: 0.552844
# idx: 400, loss for current idx: 0.559862
# idx: 420, loss for current idx: 0.582632
# idx: 440, loss for current idx: 0.579270
# idx: 460, loss for current idx: 0.562215
# idx: 480, loss for current idx: 0.583640
# best model updated
# Epoch 1, Loss: 0.6100, Accuracy: 0.9820
# Epoch 2, Loss: 0.5725, Accuracy: 0.9728
# best model updated
# Epoch 3, Loss: 0.5666, Accuracy: 0.9890
# best model updated
# Epoch 4, Loss: 0.5656, Accuracy: 0.9930
# Epoch 5, Loss: 0.5621, Accuracy: 0.9925
# Epoch 6, Loss: 0.5607, Accuracy: 0.9855
# Epoch 7, Loss: 0.5600, Accuracy: 0.9907
# Epoch 8, Loss: 0.5599, Accuracy: 0.9849
# Epoch 9, Loss: 0.5623, Accuracy: 0.9913
# Epoch 10, Loss: 0.5636, Accuracy: 0.9896
# Epoch 11, Loss: 0.5613, Accuracy: 0.9919
# Epoch 12, Loss: 0.5649, Accuracy: 0.9762
# Epoch 13, Loss: 0.5636, Accuracy: 0.9907
# Best Epoch: 3, Best Valid Acc: 0.9930475086906141
# Valid Acc (with Epoch valid set) on Loaded Best Model: 0.9930475086906141
# Final Acc (with TEST set) on Loaded Best Model: 0.9890459363957598 (time: 0.004543671447239565)
#
# === case=2, backbone=resnet50 ===
# idx: 20, loss for current idx: 0.702696
# idx: 40, loss for current idx: 0.740961
# idx: 60, loss for current idx: 0.664868
# idx: 80, loss for current idx: 0.609520
# idx: 100, loss for current idx: 0.645220
# idx: 120, loss for current idx: 0.606773
# idx: 140, loss for current idx: 0.553154
# idx: 160, loss for current idx: 0.618801
# idx: 180, loss for current idx: 0.614142
# idx: 200, loss for current idx: 0.605816
# idx: 220, loss for current idx: 0.599244
# idx: 240, loss for current idx: 0.599448
# idx: 260, loss for current idx: 0.567529
# idx: 280, loss for current idx: 0.604089
# idx: 300, loss for current idx: 0.621920
# idx: 320, loss for current idx: 0.654019
# idx: 340, loss for current idx: 0.575551
# idx: 360, loss for current idx: 0.617436
# idx: 380, loss for current idx: 0.589059
# idx: 400, loss for current idx: 0.618876
# idx: 420, loss for current idx: 0.579753
# idx: 440, loss for current idx: 0.582538
# idx: 460, loss for current idx: 0.576893
# idx: 480, loss for current idx: 0.603398
# best model updated
# Epoch 1, Loss: 0.6300, Accuracy: 0.9635
# best model updated
# Epoch 2, Loss: 0.5795, Accuracy: 0.9844
# best model updated
# Epoch 3, Loss: 0.5667, Accuracy: 0.9930
# best model updated
# Epoch 4, Loss: 0.5653, Accuracy: 0.9942
# Epoch 5, Loss: 0.5622, Accuracy: 0.9907
# Epoch 6, Loss: 0.5629, Accuracy: 0.9803
# Epoch 7, Loss: 0.5621, Accuracy: 0.9907
# Epoch 8, Loss: 0.5607, Accuracy: 0.9925
# Epoch 9, Loss: 0.5607, Accuracy: 0.9832
# Epoch 10, Loss: 0.5648, Accuracy: 0.9913
# Epoch 11, Loss: 0.5622, Accuracy: 0.9942
# Epoch 12, Loss: 0.5663, Accuracy: 0.9693
# Epoch 13, Loss: 0.5634, Accuracy: 0.9867
# Best Epoch: 3, Best Valid Acc: 0.9942062572421785
# Valid Acc (with Epoch valid set) on Loaded Best Model: 0.9942062572421785
# Final Acc (with TEST set) on Loaded Best Model: 0.9915194346289753 (time: 0.005857277452275994)
#
# === case=3, backbone=resnet18 ===
# idx: 20, loss for current idx: 0.907848
# idx: 40, loss for current idx: 0.836370
# idx: 60, loss for current idx: 0.792783
# idx: 80, loss for current idx: 0.639879
# idx: 100, loss for current idx: 0.663000
# idx: 120, loss for current idx: 0.655864
# idx: 140, loss for current idx: 0.677365
# idx: 160, loss for current idx: 0.675445
# idx: 180, loss for current idx: 0.669647
# idx: 200, loss for current idx: 0.683615
# idx: 220, loss for current idx: 0.685991
# idx: 240, loss for current idx: 0.692299
# idx: 260, loss for current idx: 0.666977
# idx: 280, loss for current idx: 0.710873
# idx: 300, loss for current idx: 0.626961
# idx: 320, loss for current idx: 0.633125
# idx: 340, loss for current idx: 0.660120
# idx: 360, loss for current idx: 0.632692
# idx: 380, loss for current idx: 0.635379
# idx: 400, loss for current idx: 0.669821
# idx: 420, loss for current idx: 0.700170
# idx: 440, loss for current idx: 0.657425
# idx: 460, loss for current idx: 0.716335
# idx: 480, loss for current idx: 0.632588
# best model updated
# Epoch 1, Loss: 0.6998, Accuracy: 0.9844
# best model updated
# Epoch 2, Loss: 0.6494, Accuracy: 0.9867
# best model updated
# Epoch 3, Loss: 0.6432, Accuracy: 0.9913
# Epoch 4, Loss: 0.6406, Accuracy: 0.9722
# Epoch 5, Loss: 0.6391, Accuracy: 0.9861
# best model updated
# Epoch 6, Loss: 0.6376, Accuracy: 0.9930
# Epoch 7, Loss: 0.6388, Accuracy: 0.9815
# Epoch 8, Loss: 0.6409, Accuracy: 0.9890
# Epoch 9, Loss: 0.6402, Accuracy: 0.9820
# Epoch 10, Loss: 0.6428, Accuracy: 0.9925
# Epoch 11, Loss: 0.6359, Accuracy: 0.9913
# Epoch 12, Loss: 0.6342, Accuracy: 0.9913
# Epoch 13, Loss: 0.6352, Accuracy: 0.9693
# Epoch 14, Loss: 0.6344, Accuracy: 0.9913
# Epoch 15, Loss: 0.6402, Accuracy: 0.9913
# best model updated
# Epoch 16, Loss: 0.6340, Accuracy: 0.9948
# Epoch 17, Loss: 0.6370, Accuracy: 0.9948
# Epoch 18, Loss: 0.6453, Accuracy: 0.9913
# Epoch 19, Loss: 0.6347, Accuracy: 0.9948
# Epoch 20, Loss: 0.6330, Accuracy: 0.9948
# Epoch 21, Loss: 0.6346, Accuracy: 0.9948
# Epoch 22, Loss: 0.6361, Accuracy: 0.9902
# Epoch 23, Loss: 0.6379, Accuracy: 0.9902
# Epoch 24, Loss: 0.6358, Accuracy: 0.9838
# Epoch 25, Loss: 0.6341, Accuracy: 0.9930
# Best Epoch: 15, Best Valid Acc: 0.9947856315179606
# Valid Acc (with Epoch valid set) on Loaded Best Model: 0.9947856315179606
# Final Acc (with TEST set) on Loaded Best Model: 0.9943462897526502 (time: 0.0030856802222434055)
#
# === case=3, backbone=resnet34 ===
# idx: 20, loss for current idx: 0.906507
# idx: 40, loss for current idx: 0.815677
# idx: 60, loss for current idx: 0.641631
# idx: 80, loss for current idx: 0.709147
# idx: 100, loss for current idx: 0.696732
# idx: 120, loss for current idx: 0.707338
# idx: 140, loss for current idx: 0.686725
# idx: 160, loss for current idx: 0.677913
# idx: 180, loss for current idx: 0.682122
# idx: 200, loss for current idx: 0.750224
# idx: 220, loss for current idx: 0.700723
# idx: 240, loss for current idx: 0.656216
# idx: 260, loss for current idx: 0.656587
# idx: 280, loss for current idx: 0.690650
# idx: 300, loss for current idx: 0.655688
# idx: 320, loss for current idx: 0.627189
# idx: 340, loss for current idx: 0.626927
# idx: 360, loss for current idx: 0.640402
# idx: 380, loss for current idx: 0.628767
# idx: 400, loss for current idx: 0.626587
# idx: 420, loss for current idx: 0.776063
# idx: 440, loss for current idx: 0.653046
# idx: 460, loss for current idx: 0.631891
# idx: 480, loss for current idx: 0.626622
# best model updated
# Epoch 1, Loss: 0.6972, Accuracy: 0.9849
# Epoch 2, Loss: 0.6583, Accuracy: 0.9774
# best model updated
# Epoch 3, Loss: 0.6457, Accuracy: 0.9907
# Epoch 4, Loss: 0.6398, Accuracy: 0.9832
# Epoch 5, Loss: 0.6416, Accuracy: 0.9896
# Epoch 6, Loss: 0.6395, Accuracy: 0.9907
# best model updated
# Epoch 7, Loss: 0.6406, Accuracy: 0.9948
# Epoch 8, Loss: 0.6386, Accuracy: 0.9936
# Epoch 9, Loss: 0.6398, Accuracy: 0.9902
# Epoch 10, Loss: 0.6405, Accuracy: 0.9936
# Epoch 11, Loss: 0.6350, Accuracy: 0.9942
# Epoch 12, Loss: 0.6365, Accuracy: 0.9948
# Epoch 13, Loss: 0.6373, Accuracy: 0.9930
# Epoch 14, Loss: 0.6443, Accuracy: 0.9936
# Epoch 15, Loss: 0.6339, Accuracy: 0.9820
# Epoch 16, Loss: 0.6399, Accuracy: 0.9878
# Best Epoch: 6, Best Valid Acc: 0.9947856315179606
# Valid Acc (with Epoch valid set) on Loaded Best Model: 0.9947856315179606
# Final Acc (with TEST set) on Loaded Best Model: 0.9943462897526502 (time: 0.006120261181606336)
#
# === case=3, backbone=resnet50 ===
# idx: 20, loss for current idx: 1.047053
# idx: 40, loss for current idx: 0.932752
# idx: 60, loss for current idx: 0.684124
# idx: 80, loss for current idx: 0.752576
# idx: 100, loss for current idx: 0.801786
# idx: 120, loss for current idx: 0.670156
# idx: 140, loss for current idx: 0.697292
# idx: 160, loss for current idx: 0.791520
# idx: 180, loss for current idx: 0.707999
# idx: 200, loss for current idx: 0.751841
# idx: 220, loss for current idx: 0.690076
# idx: 240, loss for current idx: 0.626735
# idx: 260, loss for current idx: 0.665787
# idx: 280, loss for current idx: 0.653987
# idx: 300, loss for current idx: 0.672451
# idx: 320, loss for current idx: 0.681644
# idx: 340, loss for current idx: 0.658772
# idx: 360, loss for current idx: 0.627820
# idx: 380, loss for current idx: 0.678228
# idx: 400, loss for current idx: 0.739845
# idx: 420, loss for current idx: 0.670902
# idx: 440, loss for current idx: 0.631130
# idx: 460, loss for current idx: 0.630726
# idx: 480, loss for current idx: 0.627804
# best model updated
# Epoch 1, Loss: 0.7347, Accuracy: 0.9815
# best model updated
# Epoch 2, Loss: 0.6549, Accuracy: 0.9884
# best model updated
# Epoch 3, Loss: 0.6458, Accuracy: 0.9890
# Epoch 4, Loss: 0.6449, Accuracy: 0.9815
# Epoch 5, Loss: 0.6447, Accuracy: 0.9855
# best model updated
# Epoch 6, Loss: 0.6399, Accuracy: 0.9902
# Epoch 7, Loss: 0.6394, Accuracy: 0.9884
# Epoch 8, Loss: 0.6369, Accuracy: 0.9878
# Epoch 9, Loss: 0.6482, Accuracy: 0.9774
# Epoch 10, Loss: 0.6463, Accuracy: 0.9844
# best model updated
# Epoch 11, Loss: 0.6444, Accuracy: 0.9907
# Epoch 12, Loss: 0.6413, Accuracy: 0.9884
# Epoch 13, Loss: 0.6506, Accuracy: 0.9803
# Epoch 14, Loss: 0.6435, Accuracy: 0.9878
# Epoch 15, Loss: 0.6414, Accuracy: 0.9902
# Epoch 16, Loss: 0.6455, Accuracy: 0.9890
# Epoch 17, Loss: 0.6377, Accuracy: 0.9878
# Epoch 18, Loss: 0.6386, Accuracy: 0.9884
# Epoch 19, Loss: 0.6388, Accuracy: 0.9890
# Epoch 20, Loss: 0.6405, Accuracy: 0.9896
# best model updated
# Epoch 21, Loss: 0.6365, Accuracy: 0.9936
# Epoch 22, Loss: 0.6376, Accuracy: 0.9902
# Epoch 23, Loss: 0.6442, Accuracy: 0.9896
# Epoch 24, Loss: 0.6411, Accuracy: 0.9780
# Epoch 25, Loss: 0.6391, Accuracy: 0.9902
# Epoch 26, Loss: 0.6385, Accuracy: 0.9890
# Epoch 27, Loss: 0.6384, Accuracy: 0.9902
# Epoch 28, Loss: 0.6536, Accuracy: 0.9844
# Epoch 29, Loss: 0.6498, Accuracy: 0.9902
# Epoch 30, Loss: 0.6409, Accuracy: 0.9907
# Best Epoch: 20, Best Valid Acc: 0.9936268829663963
# Valid Acc (with Epoch valid set) on Loaded Best Model: 0.9936268829663963
# Final Acc (with TEST set) on Loaded Best Model: 0.9939929328621908 (time: 0.006177937046865399)
#
# === case=4_1, backbone=resnet18 ===
# idx: 20, loss for current idx: 0.759148
# idx: 40, loss for current idx: 0.734338
# idx: 60, loss for current idx: 0.757408
# idx: 80, loss for current idx: 0.636465
# idx: 100, loss for current idx: 0.696598
# idx: 120, loss for current idx: 0.631366
# idx: 140, loss for current idx: 0.664193
# idx: 160, loss for current idx: 0.659117
# idx: 180, loss for current idx: 0.785425
# idx: 200, loss for current idx: 0.696819
# idx: 220, loss for current idx: 0.676850
# idx: 240, loss for current idx: 0.629225
# idx: 260, loss for current idx: 0.682442
# idx: 280, loss for current idx: 0.715983
# idx: 300, loss for current idx: 0.655195
# idx: 320, loss for current idx: 0.664386
# idx: 340, loss for current idx: 0.694352
# idx: 360, loss for current idx: 0.692092
# idx: 380, loss for current idx: 0.704116
# idx: 400, loss for current idx: 0.626685
# idx: 420, loss for current idx: 0.633901
# idx: 440, loss for current idx: 0.669187
# idx: 460, loss for current idx: 0.643187
# idx: 480, loss for current idx: 0.629459
# best model updated
# Epoch 1, Loss: 0.6958, Accuracy: 0.9826
# best model updated
# Epoch 2, Loss: 0.6520, Accuracy: 0.9902
# best model updated
# Epoch 3, Loss: 0.6443, Accuracy: 0.9942
# Epoch 4, Loss: 0.6421, Accuracy: 0.9878
# Epoch 5, Loss: 0.6417, Accuracy: 0.9902
# Epoch 6, Loss: 0.6358, Accuracy: 0.9896
# Epoch 7, Loss: 0.6377, Accuracy: 0.9873
# Epoch 8, Loss: 0.6374, Accuracy: 0.9913
# Epoch 9, Loss: 0.6362, Accuracy: 0.9902
# Epoch 10, Loss: 0.6388, Accuracy: 0.9925
# Epoch 11, Loss: 0.6402, Accuracy: 0.9936
# Epoch 12, Loss: 0.6441, Accuracy: 0.9884
# Best Epoch: 2, Best Valid Acc: 0.9942062572421785
# Valid Acc (with Epoch valid set) on Loaded Best Model: 0.9942062572421785
# Final Acc (with TEST set) on Loaded Best Model: 0.9925795053003533 (time: 0.005443342616049091)
#
# === case=4_1, backbone=resnet34 ===
# idx: 20, loss for current idx: 0.828910
# idx: 40, loss for current idx: 0.676343
# idx: 60, loss for current idx: 0.695854
# idx: 80, loss for current idx: 0.659884
# idx: 100, loss for current idx: 0.637998
# idx: 120, loss for current idx: 0.643912
# idx: 140, loss for current idx: 0.683268
# idx: 160, loss for current idx: 0.729805
# idx: 180, loss for current idx: 0.726096
# idx: 200, loss for current idx: 0.626891
# idx: 220, loss for current idx: 0.660951
# idx: 240, loss for current idx: 0.655924
# idx: 260, loss for current idx: 0.727509
# idx: 280, loss for current idx: 0.630316
# idx: 300, loss for current idx: 0.644855
# idx: 320, loss for current idx: 0.627955
# idx: 340, loss for current idx: 0.653109
# idx: 360, loss for current idx: 0.672349
# idx: 380, loss for current idx: 0.699981
# idx: 400, loss for current idx: 0.655627
# idx: 420, loss for current idx: 0.627536
# idx: 440, loss for current idx: 0.657791
# idx: 460, loss for current idx: 0.646102
# idx: 480, loss for current idx: 0.626591
# best model updated
# Epoch 1, Loss: 0.6907, Accuracy: 0.9647
# best model updated
# Epoch 2, Loss: 0.6548, Accuracy: 0.9873
# Epoch 3, Loss: 0.6444, Accuracy: 0.9861
# best model updated
# Epoch 4, Loss: 0.6435, Accuracy: 0.9907
# Epoch 5, Loss: 0.6468, Accuracy: 0.9861
# best model updated
# Epoch 6, Loss: 0.6374, Accuracy: 0.9930
# Epoch 7, Loss: 0.6365, Accuracy: 0.9826
# Epoch 8, Loss: 0.6353, Accuracy: 0.9919
# best model updated
# Epoch 9, Loss: 0.6377, Accuracy: 0.9954
# Epoch 10, Loss: 0.6381, Accuracy: 0.9733
# Epoch 11, Loss: 0.6403, Accuracy: 0.9873
# Epoch 12, Loss: 0.6398, Accuracy: 0.9797
# Epoch 13, Loss: 0.6441, Accuracy: 0.9890
# Epoch 14, Loss: 0.6363, Accuracy: 0.9861
# Epoch 15, Loss: 0.6351, Accuracy: 0.9878
# Epoch 16, Loss: 0.6379, Accuracy: 0.9936
# Epoch 17, Loss: 0.6343, Accuracy: 0.9936
# Epoch 18, Loss: 0.6383, Accuracy: 0.9936
# Best Epoch: 8, Best Valid Acc: 0.9953650057937428
# Valid Acc (with Epoch valid set) on Loaded Best Model: 0.9953650057937428
# Final Acc (with TEST set) on Loaded Best Model: 0.9908127208480565 (time: 0.00891223382414057)
#
# === case=4_1, backbone=resnet50 ===
# idx: 20, loss for current idx: 0.872847
# idx: 40, loss for current idx: 0.854191
# idx: 60, loss for current idx: 0.742808
# idx: 80, loss for current idx: 0.693454
# idx: 100, loss for current idx: 0.829430
# idx: 120, loss for current idx: 0.733608
# idx: 140, loss for current idx: 0.766880
# idx: 160, loss for current idx: 0.669337
# idx: 180, loss for current idx: 0.723293
# idx: 200, loss for current idx: 0.780412
# idx: 220, loss for current idx: 0.660619
# idx: 240, loss for current idx: 0.649998
# idx: 260, loss for current idx: 0.626563
# idx: 280, loss for current idx: 0.676154
# idx: 300, loss for current idx: 0.740024
# idx: 320, loss for current idx: 0.671910
# idx: 340, loss for current idx: 0.690640
# idx: 360, loss for current idx: 0.681151
# idx: 380, loss for current idx: 0.626940
# idx: 400, loss for current idx: 0.655405
# idx: 420, loss for current idx: 0.628261
# idx: 440, loss for current idx: 0.665579
# idx: 460, loss for current idx: 0.689144
# idx: 480, loss for current idx: 0.688464
# best model updated
# Epoch 1, Loss: 0.7076, Accuracy: 0.9728
# best model updated
# Epoch 2, Loss: 0.6593, Accuracy: 0.9815
# best model updated
# Epoch 3, Loss: 0.6481, Accuracy: 0.9884
# best model updated
# Epoch 4, Loss: 0.6439, Accuracy: 0.9936
# best model updated
# Epoch 5, Loss: 0.6391, Accuracy: 0.9948
# Epoch 6, Loss: 0.6392, Accuracy: 0.9884
# Epoch 7, Loss: 0.6388, Accuracy: 0.9902
# Epoch 8, Loss: 0.6360, Accuracy: 0.9936
# Epoch 9, Loss: 0.6330, Accuracy: 0.9936
# Epoch 10, Loss: 0.6330, Accuracy: 0.9896
# Epoch 11, Loss: 0.6442, Accuracy: 0.9861
# Epoch 12, Loss: 0.6410, Accuracy: 0.9797
# Epoch 13, Loss: 0.6389, Accuracy: 0.9890
# Epoch 14, Loss: 0.6386, Accuracy: 0.9902
# Best Epoch: 4, Best Valid Acc: 0.9947856315179606
# Valid Acc (with Epoch valid set) on Loaded Best Model: 0.9947856315179606
# Final Acc (with TEST set) on Loaded Best Model: 0.9908127208480565 (time: 0.011798242504677077)
#
# === case=4_2, backbone=resnet18 ===
# idx: 20, loss for current idx: 0.843242
# idx: 40, loss for current idx: 0.740236
# idx: 60, loss for current idx: 0.685362
# idx: 80, loss for current idx: 0.718073
# idx: 100, loss for current idx: 0.691480
# idx: 120, loss for current idx: 0.774040
# idx: 140, loss for current idx: 0.714732
# idx: 160, loss for current idx: 0.695151
# idx: 180, loss for current idx: 0.678218
# idx: 200, loss for current idx: 0.662729
# idx: 220, loss for current idx: 0.687995
# idx: 240, loss for current idx: 0.697625
# idx: 260, loss for current idx: 0.748198
# idx: 280, loss for current idx: 0.727919
# idx: 300, loss for current idx: 0.679980
# idx: 320, loss for current idx: 0.642172
# idx: 340, loss for current idx: 0.714722
# idx: 360, loss for current idx: 0.666113
# idx: 380, loss for current idx: 0.722725
# idx: 400, loss for current idx: 0.691875
# idx: 420, loss for current idx: 0.632130
# idx: 440, loss for current idx: 0.629453
# idx: 460, loss for current idx: 0.658698
# idx: 480, loss for current idx: 0.699463
# best model updated
# Epoch 1, Loss: 0.7096, Accuracy: 0.9762
# best model updated
# Epoch 2, Loss: 0.6564, Accuracy: 0.9786
# Epoch 3, Loss: 0.6521, Accuracy: 0.9722
# Epoch 4, Loss: 0.6487, Accuracy: 0.9728
# best model updated
# Epoch 5, Loss: 0.6442, Accuracy: 0.9902
# Epoch 6, Loss: 0.6426, Accuracy: 0.9797
# Epoch 7, Loss: 0.6456, Accuracy: 0.9873
# best model updated
# Epoch 8, Loss: 0.6478, Accuracy: 0.9930
# Epoch 9, Loss: 0.6406, Accuracy: 0.9919
# Epoch 10, Loss: 0.6384, Accuracy: 0.9890
# Epoch 11, Loss: 0.6371, Accuracy: 0.9867
# best model updated
# Epoch 12, Loss: 0.6375, Accuracy: 0.9948
# Epoch 13, Loss: 0.6346, Accuracy: 0.9913
# Epoch 14, Loss: 0.6342, Accuracy: 0.9815
# Epoch 15, Loss: 0.6338, Accuracy: 0.9902
# Epoch 16, Loss: 0.6345, Accuracy: 0.9762
# Epoch 17, Loss: 0.6435, Accuracy: 0.9838
# Epoch 18, Loss: 0.6447, Accuracy: 0.9867
# Epoch 19, Loss: 0.6416, Accuracy: 0.9902
# Epoch 20, Loss: 0.6366, Accuracy: 0.9936
# Epoch 21, Loss: 0.6364, Accuracy: 0.9919
# Best Epoch: 11, Best Valid Acc: 0.9947856315179606
# Valid Acc (with Epoch valid set) on Loaded Best Model: 0.9947856315179606
# Final Acc (with TEST set) on Loaded Best Model: 0.9915194346289753 (time: 0.007250483116407073)
#
# === case=4_2, backbone=resnet34 ===
# idx: 20, loss for current idx: 0.807752
# idx: 40, loss for current idx: 0.661652
# idx: 60, loss for current idx: 0.753335
# idx: 80, loss for current idx: 0.693072
# idx: 100, loss for current idx: 0.731576
# idx: 120, loss for current idx: 0.644214
# idx: 140, loss for current idx: 0.636164
# idx: 160, loss for current idx: 0.636245
# idx: 180, loss for current idx: 0.835356
# idx: 200, loss for current idx: 0.657831
# idx: 220, loss for current idx: 0.689215
# idx: 240, loss for current idx: 0.796564
# idx: 260, loss for current idx: 0.636449
# idx: 280, loss for current idx: 0.696152
# idx: 300, loss for current idx: 0.716252
# idx: 320, loss for current idx: 0.626932
# idx: 340, loss for current idx: 0.626598
# idx: 360, loss for current idx: 0.639173
# idx: 380, loss for current idx: 0.633679
# idx: 400, loss for current idx: 0.663655
# idx: 420, loss for current idx: 0.628247
# idx: 440, loss for current idx: 0.684045
# idx: 460, loss for current idx: 0.781964
# idx: 480, loss for current idx: 0.666162
# best model updated
# Epoch 1, Loss: 0.7080, Accuracy: 0.9531
# best model updated
# Epoch 2, Loss: 0.6595, Accuracy: 0.9844
# Epoch 3, Loss: 0.6533, Accuracy: 0.9751
# best model updated
# Epoch 4, Loss: 0.6465, Accuracy: 0.9861
# Epoch 5, Loss: 0.6474, Accuracy: 0.9832
# Epoch 6, Loss: 0.6434, Accuracy: 0.9844
# Epoch 7, Loss: 0.6457, Accuracy: 0.9826
# best model updated
# Epoch 8, Loss: 0.6525, Accuracy: 0.9867
# Epoch 9, Loss: 0.6649, Accuracy: 0.9618
# Epoch 10, Loss: 0.6464, Accuracy: 0.9861
# Epoch 11, Loss: 0.6419, Accuracy: 0.9849
# Epoch 12, Loss: 0.6467, Accuracy: 0.9745
# Epoch 13, Loss: 0.6455, Accuracy: 0.9826
# Epoch 14, Loss: 0.6426, Accuracy: 0.9786
# best model updated
# Epoch 15, Loss: 0.6447, Accuracy: 0.9919
# Epoch 16, Loss: 0.6372, Accuracy: 0.9878
# Epoch 17, Loss: 0.6377, Accuracy: 0.9907
# Epoch 18, Loss: 0.6395, Accuracy: 0.9919
# Epoch 19, Loss: 0.6412, Accuracy: 0.9902
# Epoch 20, Loss: 0.6425, Accuracy: 0.9919
# Epoch 21, Loss: 0.6405, Accuracy: 0.9664
# Epoch 22, Loss: 0.6449, Accuracy: 0.9873
# best model updated
# Epoch 23, Loss: 0.6388, Accuracy: 0.9936
# Epoch 24, Loss: 0.6395, Accuracy: 0.9890
# Epoch 25, Loss: 0.6373, Accuracy: 0.9890
# Epoch 26, Loss: 0.6430, Accuracy: 0.9791
# Epoch 27, Loss: 0.6399, Accuracy: 0.9936
# Epoch 28, Loss: 0.6454, Accuracy: 0.9896
# Epoch 29, Loss: 0.6392, Accuracy: 0.9907
# Epoch 30, Loss: 0.6420, Accuracy: 0.9774
# Epoch 31, Loss: 0.6386, Accuracy: 0.9907
# Epoch 32, Loss: 0.6395, Accuracy: 0.9890
# Best Epoch: 22, Best Valid Acc: 0.9936268829663963
# Valid Acc (with Epoch valid set) on Loaded Best Model: 0.9936268829663963
# Final Acc (with TEST set) on Loaded Best Model: 0.9925795053003533 (time: 0.008848388543289698)
#
# === case=4_2, backbone=resnet50 ===
# idx: 20, loss for current idx: 0.769767
# idx: 40, loss for current idx: 0.777950
# idx: 60, loss for current idx: 0.767348
# idx: 80, loss for current idx: 0.770090
# idx: 100, loss for current idx: 0.737537
# idx: 120, loss for current idx: 0.721160
# idx: 140, loss for current idx: 0.787854
# idx: 160, loss for current idx: 0.803470
# idx: 180, loss for current idx: 0.662292
# idx: 200, loss for current idx: 0.868657
# idx: 220, loss for current idx: 0.751521
# idx: 240, loss for current idx: 0.682548
# idx: 260, loss for current idx: 0.719403
# idx: 280, loss for current idx: 0.813354
# idx: 300, loss for current idx: 0.700261
# idx: 320, loss for current idx: 0.658033
# idx: 340, loss for current idx: 0.649622
# idx: 360, loss for current idx: 0.660134
# idx: 380, loss for current idx: 0.629526
# idx: 400, loss for current idx: 0.656340
# idx: 420, loss for current idx: 0.748453
# idx: 440, loss for current idx: 0.720128
# idx: 460, loss for current idx: 0.708157
# idx: 480, loss for current idx: 0.657789
# best model updated
# Epoch 1, Loss: 0.7359, Accuracy: 0.9351
# best model updated
# Epoch 2, Loss: 0.6703, Accuracy: 0.9838
# Epoch 3, Loss: 0.6504, Accuracy: 0.9751
# Epoch 4, Loss: 0.6467, Accuracy: 0.9815
# Epoch 5, Loss: 0.6468, Accuracy: 0.9815
# best model updated
# Epoch 6, Loss: 0.6451, Accuracy: 0.9855
# Epoch 7, Loss: 0.6462, Accuracy: 0.9635
# Epoch 8, Loss: 0.6427, Accuracy: 0.9838
# best model updated
# Epoch 9, Loss: 0.6546, Accuracy: 0.9861
# Epoch 10, Loss: 0.6512, Accuracy: 0.9838
# Epoch 11, Loss: 0.6557, Accuracy: 0.9757
# Epoch 12, Loss: 0.6566, Accuracy: 0.9774
# Epoch 13, Loss: 0.6558, Accuracy: 0.9838
# Epoch 14, Loss: 0.6443, Accuracy: 0.9820
# Epoch 15, Loss: 0.6628, Accuracy: 0.9797
# Epoch 16, Loss: 0.6521, Accuracy: 0.9809
# Epoch 17, Loss: 0.6470, Accuracy: 0.9809
# Epoch 18, Loss: 0.6595, Accuracy: 0.9739
# Best Epoch: 8, Best Valid Acc: 0.9860950173812283
# Valid Acc (with Epoch valid set) on Loaded Best Model: 0.9860950173812283
# Final Acc (with TEST set) on Loaded Best Model: 0.9823321554770318 (time: 0.011234312914730458)

# %%
result_df = pd.DataFrame(result_dict)
result_df
# Out:
#     backbone case  accuracy  inference_time
# 0   resnet18    1  0.995053        0.005236
# 1   resnet34    1  0.994700        0.008719
# 2   resnet50    1  0.992933        0.014324
# 3   resnet18    2  0.990813        0.002621
# 4   resnet34    2  0.989046        0.004544
# 5   resnet50    2  0.991519        0.005857
# 6   resnet18    3  0.994346        0.003086
# 7   resnet34    3  0.994346        0.006120
# 8   resnet50    3  0.993993        0.006178
# 9   resnet18  4_1  0.992580        0.005443
# 10  resnet34  4_1  0.990813        0.008912
# 11  resnet50  4_1  0.990813        0.011798
# 12  resnet18  4_2  0.991519        0.007250
# 13  resnet34  4_2  0.992580        0.008848
# 14  resnet50  4_2  0.982332        0.011234

# %%
result_df.to_csv('result_experiment_2.csv')
