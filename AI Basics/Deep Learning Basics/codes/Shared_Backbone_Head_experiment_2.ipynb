# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms

import plotly.graph_objects as go

import random
import pandas as pd
import numpy as np

# !pip install torchinfo
from torchinfo import summary
# Out:
# Collecting torchinfo
#   Downloading torchinfo-1.8.0-py3-none-any.whl.metadata (21 kB)
# Downloading torchinfo-1.8.0-py3-none-any.whl (23 kB)
# Installing collected packages: torchinfo
# Successfully installed torchinfo-1.8.0

# %%
# 경고 미 표시

import warnings
warnings.filterwarnings('ignore')

# %%
# Random Seed 고정 (학습 반복 시행 시에도 동일한 결과가 나오도록)

seed = 20250928

random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)
torch.cuda.manual_seed_all(seed)

# %%
# 데이터셋 로딩

transform = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.5,), (0.5,))])

train_dataset = torchvision.datasets.MNIST(root='./data',
                                           train=True,
                                           transform=transform,
                                           download=True)

test_dataset = torchvision.datasets.MNIST(root='./data',
                                          train=False,
                                          transform=transform,
                                          download=True)
# Out:
# 100%|██████████| 9.91M/9.91M [00:00<00:00, 17.9MB/s]
# 100%|██████████| 28.9k/28.9k [00:00<00:00, 492kB/s]
# 100%|██████████| 1.65M/1.65M [00:00<00:00, 4.46MB/s]
# 100%|██████████| 4.54k/4.54k [00:00<00:00, 13.2MB/s]

# %% [markdown]
# **1. 데이터셋 분석**

# %%
# 데이터셋 로딩

from torch.utils.data import DataLoader

BATCH_SIZE = 32

train_loader = DataLoader(train_dataset,
                          batch_size=BATCH_SIZE,
                          shuffle=True)

test_loader = DataLoader(test_dataset,
                         batch_size=BATCH_SIZE,
                         shuffle=False)

# %%
# 클래스 불균형 분석

# 학습 데이터
train_labels = torch.tensor(train_dataset.targets)
train_class_counts = torch.bincount(train_labels)
print(f'train data : {train_class_counts}')

# 테스트 데이터
test_labels = torch.tensor(test_dataset.targets)
test_class_counts = torch.bincount(test_labels)
print(f'test  data : {test_class_counts}')

NUM_CLASSES = len(train_class_counts)
# Out:
# train data : tensor([5923, 6742, 5958, 6131, 5842, 5421, 5918, 6265, 5851, 5949])
# test  data : tensor([ 980, 1135, 1032, 1010,  982,  892,  958, 1028,  974, 1009])

# %%
# 클래스 불균형 분석 (percentage)

train_class_percentage = np.array(train_class_counts) * 100.0 / sum(train_class_counts)

train_y_distrib = pd.DataFrame({'class': list(range(NUM_CLASSES)),
                                'count': train_class_counts,
                                'percentage (%)': train_class_percentage})

train_y_distrib
# Out:
#    class  count  percentage (%)
# 0      0   5923        9.871667
# 1      1   6742       11.236667
# 2      2   5958        9.930000
# 3      3   6131       10.218333
# 4      4   5842        9.736667
# 5      5   5421        9.035000
# 6      6   5918        9.863333
# 7      7   6265       10.441667
# 8      8   5851        9.751667
# 9      9   5949        9.915000

# %%
test_class_percentage = np.array(test_class_counts) * 100.0 / sum(test_class_counts)

test_y_distrib = pd.DataFrame({'class': list(range(NUM_CLASSES)),
                               'count': test_class_counts,
                               'percentage (%)': test_class_percentage})

test_y_distrib
# Out:
#    class  count  percentage (%)
# 0      0    980            9.80
# 1      1   1135           11.35
# 2      2   1032           10.32
# 3      3   1010           10.10
# 4      4    982            9.82
# 5      5    892            8.92
# 6      6    958            9.58
# 7      7   1028           10.28
# 8      8    974            9.74
# 9      9   1009           10.09

# %% [markdown]
# **2. 0, 1, 2 숫자 데이터만 추출**

# %%
from torch.utils.data import Subset

# train dataset
train_targets = torch.tensor(train_dataset.targets)
train_mask = (train_targets == 0) | (train_targets == 1) | (train_targets == 2)
train_indices = torch.where(train_mask)[0]

train_subset = Subset(train_dataset, train_indices)

# test dataset
test_targets = torch.tensor(test_dataset.targets)
test_mask = (test_targets == 0) | (test_targets == 1) | (test_targets == 2)
test_indices = torch.where(test_mask)[0]

test_subset = Subset(test_dataset, test_indices)

# %%
# train, test Data Loader 갱신

train_subset_loader = DataLoader(train_subset,
                                 batch_size=BATCH_SIZE,
                                 shuffle=True)

test_subset_loader = DataLoader(test_subset,
                                batch_size=BATCH_SIZE,
                                shuffle=False)

# %%
# train, test Data Loader 의 class 가 0, 1, 2 뿐인지 확인

train_subset_labels = train_subset.dataset.targets[train_subset.indices]
train_subset_class_counts = torch.bincount(train_subset_labels)
print(f'train data (subset) [0,1,2] : {train_subset_class_counts}')

test_subset_labels = test_subset.dataset.targets[test_subset.indices]
test_subset_class_counts = torch.bincount(test_subset_labels)
print(f'test  data (subset) [0,1,2] : {test_subset_class_counts}')
# Out:
# train data (subset) [0,1,2] : tensor([5923, 6742, 5958])
# test  data (subset) [0,1,2] : tensor([ 980, 1135, 1032])

# %% [markdown]
# **3. CNN 모델 정의**

# %%
# 1. Non-Shared backbone & Shared head

class CNN_CASE_1(nn.Module):
    def __init__(self, backbone_1, backbone_2):
        super(CNN_CASE_1, self).__init__()

        self.backbone_1 = backbone_1
        self.backbone_2 = backbone_2
        self.final_linear = nn.Linear(2000, 3)
        self.final_softmax = nn.Softmax(dim=1)

    def forward(self, x):
        x1 = self.backbone_1(x)
        x2 = self.backbone_2(x)
        x = torch.concatenate([x1, x2], dim=1)

        x = self.final_linear(x)
        x = self.final_softmax(x)

        return x

# %%
# 2. Shared backbone & Shared head

class CNN_CASE_2(nn.Module):
    def __init__(self, backbone):
        super(CNN_CASE_2, self).__init__()

        self.backbone = backbone
        self.final_linear = nn.Linear(1000, 3)
        self.final_softmax = nn.Softmax(dim=1)

    def forward(self, x):
        x = self.backbone(x)
        x = self.final_linear(x)
        x = self.final_softmax(x)

        return x

# %%
# 3. Shared backbone & Non-Shared head

class CNN_CASE_3(nn.Module):
    def __init__(self, backbone):
        super(CNN_CASE_3, self).__init__()

        self.backbone = backbone
        self.final_linear_1 = nn.Linear(1000, 2)
        self.final_linear_2 = nn.Linear(1000, 2)
        self.final_softmax = nn.Softmax(dim=1)

    def forward(self, x):
        x = self.backbone(x)
        x1 = self.final_linear_1(x)
        x2 = self.final_linear_2(x)
        x1 = self.final_softmax(x1)
        x2 = self.final_softmax(x2)

        return x1, x2

# %%
# 4. Non-Shared backbone & Non-Shared head (4-1)

class CNN_CASE_4_1(nn.Module):
    def __init__(self, backbone_1, backbone_2):
        super(CNN_CASE_4_1, self).__init__()

        self.backbone_1 = backbone_1
        self.backbone_2 = backbone_2
        self.final_linear_1 = nn.Linear(2000, 2)
        self.final_linear_2 = nn.Linear(2000, 2)
        self.final_softmax = nn.Softmax(dim=1)

    def forward(self, x):
        x11 = self.backbone_1(x)
        x12 = self.backbone_2(x)
        x = torch.concatenate([x11, x12], dim=1)

        x21 = self.final_linear_1(x)
        x22 = self.final_linear_2(x)
        x21 = self.final_softmax(x21)
        x22 = self.final_softmax(x22)

        return x21, x22

# %%
# 5. Non-Shared backbone & Non-Shared head (4-2)

class CNN_CASE_4_2(nn.Module):
    def __init__(self, backbone_1, backbone_2):
        super(CNN_CASE_4_2, self).__init__()

        self.backbone_1 = backbone_1
        self.backbone_2 = backbone_2
        self.final_linear_1 = nn.Linear(1000, 2)
        self.final_linear_2 = nn.Linear(1000, 2)
        self.final_softmax = nn.Softmax(dim=1)

    def forward(self, x):
        x11 = self.backbone_1(x)
        x12 = self.backbone_2(x)
        x21 = self.final_linear_1(x11)
        x22 = self.final_linear_2(x12)
        x21 = self.final_softmax(x21)
        x22 = self.final_softmax(x22)

        return x21, x22

# %% [markdown]
# **4. backbone model 로딩**

# %%
import torchvision.models as models

def define_model(backbone_name, case_name, device):

    # model count
    if case_name in ['1', '4_1', '4_2']:
        model_count = 2
    else:
        model_count = 1

    # load pre-trained backbone model
    pretrained_models = []

    for _ in range(model_count):
        if backbone_name == 'resnet18':
            pretrained_model = models.resnet18(pretrained=True)

        elif backbone_name == 'resnet34':
            pretrained_model = models.resnet34(pretrained=True)

        else:  # resnet50
            pretrained_model = models.resnet50(pretrained=True)

        pretrained_model.conv1 = torch.nn.Conv2d(1, 64,
                                                 kernel_size=(7, 7),
                                                 stride=(2, 2),
                                                 padding=(3, 3),
                                                 bias=False)
        pretrained_models.append(pretrained_model)

    # define full model
    if case_name == '1':
        model = CNN_CASE_1(backbone_1=pretrained_models[0],
                           backbone_2=pretrained_models[1])

    elif case_name == '2':
        model = CNN_CASE_2(backbone=pretrained_models[0])

    elif case_name == '3':
        model = CNN_CASE_3(backbone=pretrained_models[0])

    elif case_name == '4_1':
        model = CNN_CASE_4_1(backbone_1=pretrained_models[0],
                             backbone_2=pretrained_models[1])

    elif case_name == '4_2':
        model = CNN_CASE_4_2(backbone_1=pretrained_models[0],
                             backbone_2=pretrained_models[1])

    # device & optimizer & scheduler setting
    model.to(device)
    model.optimizer = torch.optim.AdamW(model.parameters(), lr=0.0001)
    model.scheduler = torch.optim.lr_scheduler.ExponentialLR(optimizer=model.optimizer,
                                                             gamma=0.95)

    return model

# %% [markdown]
# **5. 모델 구조 출력**

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
input_size=(BATCH_SIZE, 1, 28, 28)

# %%
temp_backbone_name = 'resnet18'

# %%
# 1. Non-Shared backbone & Shared head

model_case_1 = define_model(temp_backbone_name, case_name='1', device=device)
print(summary(model=model_case_1, input_size=input_size))
# Out:
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100%|██████████| 44.7M/44.7M [00:00<00:00, 184MB/s]
# ===============================================================================================
# Layer (type:depth-idx)                        Output Shape              Param #
# ===============================================================================================
# CNN_CASE_1                                    [32, 3]                   --
# ├─ResNet: 1-1                                 [32, 1000]                --
# │    └─Conv2d: 2-1                            [32, 64, 14, 14]          3,136
# │    └─BatchNorm2d: 2-2                       [32, 64, 14, 14]          128
# │    └─ReLU: 2-3                              [32, 64, 14, 14]          --
# │    └─MaxPool2d: 2-4                         [32, 64, 7, 7]            --
# │    └─Sequential: 2-5                        [32, 64, 7, 7]            --
# │    │    └─BasicBlock: 3-1                   [32, 64, 7, 7]            73,984
# │    │    └─BasicBlock: 3-2                   [32, 64, 7, 7]            73,984
# │    └─Sequential: 2-6                        [32, 128, 4, 4]           --
# │    │    └─BasicBlock: 3-3                   [32, 128, 4, 4]           230,144
# │    │    └─BasicBlock: 3-4                   [32, 128, 4, 4]           295,424
# │    └─Sequential: 2-7                        [32, 256, 2, 2]           --
# │    │    └─BasicBlock: 3-5                   [32, 256, 2, 2]           919,040
# │    │    └─BasicBlock: 3-6                   [32, 256, 2, 2]           1,180,672
# │    └─Sequential: 2-8                        [32, 512, 1, 1]           --
# │    │    └─BasicBlock: 3-7                   [32, 512, 1, 1]           3,673,088
# │    │    └─BasicBlock: 3-8                   [32, 512, 1, 1]           4,720,640
# │    └─AdaptiveAvgPool2d: 2-9                 [32, 512, 1, 1]           --
# │    └─Linear: 2-10                           [32, 1000]                513,000
# ├─ResNet: 1-2                                 [32, 1000]                --
# │    └─Conv2d: 2-11                           [32, 64, 14, 14]          3,136
# │    └─BatchNorm2d: 2-12                      [32, 64, 14, 14]          128
# │    └─ReLU: 2-13                             [32, 64, 14, 14]          --
# │    └─MaxPool2d: 2-14                        [32, 64, 7, 7]            --
# │    └─Sequential: 2-15                       [32, 64, 7, 7]            --
# │    │    └─BasicBlock: 3-9                   [32, 64, 7, 7]            73,984
# │    │    └─BasicBlock: 3-10                  [32, 64, 7, 7]            73,984
# │    └─Sequential: 2-16                       [32, 128, 4, 4]           --
# │    │    └─BasicBlock: 3-11                  [32, 128, 4, 4]           230,144
# │    │    └─BasicBlock: 3-12                  [32, 128, 4, 4]           295,424
# │    └─Sequential: 2-17                       [32, 256, 2, 2]           --
# │    │    └─BasicBlock: 3-13                  [32, 256, 2, 2]           919,040
# │    │    └─BasicBlock: 3-14                  [32, 256, 2, 2]           1,180,672
# │    └─Sequential: 2-18                       [32, 512, 1, 1]           --
# │    │    └─BasicBlock: 3-15                  [32, 512, 1, 1]           3,673,088
# │    │    └─BasicBlock: 3-16                  [32, 512, 1, 1]           4,720,640
# │    └─AdaptiveAvgPool2d: 2-19                [32, 512, 1, 1]           --
# │    └─Linear: 2-20                           [32, 1000]                513,000
# ├─Linear: 1-3                                 [32, 3]                   6,003
# ├─Softmax: 1-4                                [32, 3]                   --
# ===============================================================================================
# Total params: 23,372,483
# Trainable params: 23,372,483
# Non-trainable params: 0
# Total mult-adds (Units.GIGABYTES): 2.15
# ===============================================================================================
# Input size (MB): 0.10
# Forward/backward pass size (MB): 44.55
# Params size (MB): 93.49
# Estimated Total Size (MB): 138.14
# ===============================================================================================

# %%
# 2. Shared backbone & Shared head

model_case_2 = define_model(temp_backbone_name, case_name='2', device=device)
print(summary(model=model_case_2, input_size=input_size))
# Out:
# ===============================================================================================
# Layer (type:depth-idx)                        Output Shape              Param #
# ===============================================================================================
# CNN_CASE_2                                    [32, 3]                   --
# ├─ResNet: 1-1                                 [32, 1000]                --
# │    └─Conv2d: 2-1                            [32, 64, 14, 14]          3,136
# │    └─BatchNorm2d: 2-2                       [32, 64, 14, 14]          128
# │    └─ReLU: 2-3                              [32, 64, 14, 14]          --
# │    └─MaxPool2d: 2-4                         [32, 64, 7, 7]            --
# │    └─Sequential: 2-5                        [32, 64, 7, 7]            --
# │    │    └─BasicBlock: 3-1                   [32, 64, 7, 7]            73,984
# │    │    └─BasicBlock: 3-2                   [32, 64, 7, 7]            73,984
# │    └─Sequential: 2-6                        [32, 128, 4, 4]           --
# │    │    └─BasicBlock: 3-3                   [32, 128, 4, 4]           230,144
# │    │    └─BasicBlock: 3-4                   [32, 128, 4, 4]           295,424
# │    └─Sequential: 2-7                        [32, 256, 2, 2]           --
# │    │    └─BasicBlock: 3-5                   [32, 256, 2, 2]           919,040
# │    │    └─BasicBlock: 3-6                   [32, 256, 2, 2]           1,180,672
# │    └─Sequential: 2-8                        [32, 512, 1, 1]           --
# │    │    └─BasicBlock: 3-7                   [32, 512, 1, 1]           3,673,088
# │    │    └─BasicBlock: 3-8                   [32, 512, 1, 1]           4,720,640
# │    └─AdaptiveAvgPool2d: 2-9                 [32, 512, 1, 1]           --
# │    └─Linear: 2-10                           [32, 1000]                513,000
# ├─Linear: 1-2                                 [32, 3]                   3,003
# ├─Softmax: 1-3                                [32, 3]                   --
# ===============================================================================================
# Total params: 11,686,243
# Trainable params: 11,686,243
# Non-trainable params: 0
# Total mult-adds (Units.GIGABYTES): 1.07
# ===============================================================================================
# Input size (MB): 0.10
# Forward/backward pass size (MB): 22.28
# Params size (MB): 46.74
# Estimated Total Size (MB): 69.12
# ===============================================================================================

# %%
# 3. Shared backbone & Non-Shared head

model_case_3 = define_model(temp_backbone_name, case_name='3', device=device)
print(summary(model=model_case_3, input_size=input_size))
# Out:
# ===============================================================================================
# Layer (type:depth-idx)                        Output Shape              Param #
# ===============================================================================================
# CNN_CASE_3                                    [32, 2]                   --
# ├─ResNet: 1-1                                 [32, 1000]                --
# │    └─Conv2d: 2-1                            [32, 64, 14, 14]          3,136
# │    └─BatchNorm2d: 2-2                       [32, 64, 14, 14]          128
# │    └─ReLU: 2-3                              [32, 64, 14, 14]          --
# │    └─MaxPool2d: 2-4                         [32, 64, 7, 7]            --
# │    └─Sequential: 2-5                        [32, 64, 7, 7]            --
# │    │    └─BasicBlock: 3-1                   [32, 64, 7, 7]            73,984
# │    │    └─BasicBlock: 3-2                   [32, 64, 7, 7]            73,984
# │    └─Sequential: 2-6                        [32, 128, 4, 4]           --
# │    │    └─BasicBlock: 3-3                   [32, 128, 4, 4]           230,144
# │    │    └─BasicBlock: 3-4                   [32, 128, 4, 4]           295,424
# │    └─Sequential: 2-7                        [32, 256, 2, 2]           --
# │    │    └─BasicBlock: 3-5                   [32, 256, 2, 2]           919,040
# │    │    └─BasicBlock: 3-6                   [32, 256, 2, 2]           1,180,672
# │    └─Sequential: 2-8                        [32, 512, 1, 1]           --
# │    │    └─BasicBlock: 3-7                   [32, 512, 1, 1]           3,673,088
# │    │    └─BasicBlock: 3-8                   [32, 512, 1, 1]           4,720,640
# │    └─AdaptiveAvgPool2d: 2-9                 [32, 512, 1, 1]           --
# │    └─Linear: 2-10                           [32, 1000]                513,000
# ├─Linear: 1-2                                 [32, 2]                   2,002
# ├─Linear: 1-3                                 [32, 2]                   2,002
# ├─Softmax: 1-4                                [32, 2]                   --
# ├─Softmax: 1-5                                [32, 2]                   --
# ===============================================================================================
# Total params: 11,687,244
# Trainable params: 11,687,244
# Non-trainable params: 0
# Total mult-adds (Units.GIGABYTES): 1.07
# ===============================================================================================
# Input size (MB): 0.10
# Forward/backward pass size (MB): 22.28
# Params size (MB): 46.75
# Estimated Total Size (MB): 69.13
# ===============================================================================================

# %%
# 4. Non-Shared backbone & Non-Shared head (4-1)

model_case_4_1 = define_model(temp_backbone_name, case_name='4_1', device=device)
print(summary(model=model_case_4_1, input_size=input_size))
# Out:
# ===============================================================================================
# Layer (type:depth-idx)                        Output Shape              Param #
# ===============================================================================================
# CNN_CASE_4_1                                  [32, 2]                   --
# ├─ResNet: 1-1                                 [32, 1000]                --
# │    └─Conv2d: 2-1                            [32, 64, 14, 14]          3,136
# │    └─BatchNorm2d: 2-2                       [32, 64, 14, 14]          128
# │    └─ReLU: 2-3                              [32, 64, 14, 14]          --
# │    └─MaxPool2d: 2-4                         [32, 64, 7, 7]            --
# │    └─Sequential: 2-5                        [32, 64, 7, 7]            --
# │    │    └─BasicBlock: 3-1                   [32, 64, 7, 7]            73,984
# │    │    └─BasicBlock: 3-2                   [32, 64, 7, 7]            73,984
# │    └─Sequential: 2-6                        [32, 128, 4, 4]           --
# │    │    └─BasicBlock: 3-3                   [32, 128, 4, 4]           230,144
# │    │    └─BasicBlock: 3-4                   [32, 128, 4, 4]           295,424
# │    └─Sequential: 2-7                        [32, 256, 2, 2]           --
# │    │    └─BasicBlock: 3-5                   [32, 256, 2, 2]           919,040
# │    │    └─BasicBlock: 3-6                   [32, 256, 2, 2]           1,180,672
# │    └─Sequential: 2-8                        [32, 512, 1, 1]           --
# │    │    └─BasicBlock: 3-7                   [32, 512, 1, 1]           3,673,088
# │    │    └─BasicBlock: 3-8                   [32, 512, 1, 1]           4,720,640
# │    └─AdaptiveAvgPool2d: 2-9                 [32, 512, 1, 1]           --
# │    └─Linear: 2-10                           [32, 1000]                513,000
# ├─ResNet: 1-2                                 [32, 1000]                --
# │    └─Conv2d: 2-11                           [32, 64, 14, 14]          3,136
# │    └─BatchNorm2d: 2-12                      [32, 64, 14, 14]          128
# │    └─ReLU: 2-13                             [32, 64, 14, 14]          --
# │    └─MaxPool2d: 2-14                        [32, 64, 7, 7]            --
# │    └─Sequential: 2-15                       [32, 64, 7, 7]            --
# │    │    └─BasicBlock: 3-9                   [32, 64, 7, 7]            73,984
# │    │    └─BasicBlock: 3-10                  [32, 64, 7, 7]            73,984
# │    └─Sequential: 2-16                       [32, 128, 4, 4]           --
# │    │    └─BasicBlock: 3-11                  [32, 128, 4, 4]           230,144
# │    │    └─BasicBlock: 3-12                  [32, 128, 4, 4]           295,424
# │    └─Sequential: 2-17                       [32, 256, 2, 2]           --
# │    │    └─BasicBlock: 3-13                  [32, 256, 2, 2]           919,040
# │    │    └─BasicBlock: 3-14                  [32, 256, 2, 2]           1,180,672
# │    └─Sequential: 2-18                       [32, 512, 1, 1]           --
# │    │    └─BasicBlock: 3-15                  [32, 512, 1, 1]           3,673,088
# │    │    └─BasicBlock: 3-16                  [32, 512, 1, 1]           4,720,640
# │    └─AdaptiveAvgPool2d: 2-19                [32, 512, 1, 1]           --
# │    └─Linear: 2-20                           [32, 1000]                513,000
# ├─Linear: 1-3                                 [32, 2]                   4,002
# ├─Linear: 1-4                                 [32, 2]                   4,002
# ├─Softmax: 1-5                                [32, 2]                   --
# ├─Softmax: 1-6                                [32, 2]                   --
# ===============================================================================================
# Total params: 23,374,484
# Trainable params: 23,374,484
# Non-trainable params: 0
# Total mult-adds (Units.GIGABYTES): 2.15
# ===============================================================================================
# Input size (MB): 0.10
# Forward/backward pass size (MB): 44.55
# Params size (MB): 93.50
# Estimated Total Size (MB): 138.15
# ===============================================================================================

# %%
# 5. Non-Shared backbone & Non-Shared head (4-2)

model_case_4_2 = define_model(temp_backbone_name, case_name='4_2', device=device)
print(summary(model=model_case_4_2, input_size=input_size))
# Out:
# ===============================================================================================
# Layer (type:depth-idx)                        Output Shape              Param #
# ===============================================================================================
# CNN_CASE_4_2                                  [32, 2]                   --
# ├─ResNet: 1-1                                 [32, 1000]                --
# │    └─Conv2d: 2-1                            [32, 64, 14, 14]          3,136
# │    └─BatchNorm2d: 2-2                       [32, 64, 14, 14]          128
# │    └─ReLU: 2-3                              [32, 64, 14, 14]          --
# │    └─MaxPool2d: 2-4                         [32, 64, 7, 7]            --
# │    └─Sequential: 2-5                        [32, 64, 7, 7]            --
# │    │    └─BasicBlock: 3-1                   [32, 64, 7, 7]            73,984
# │    │    └─BasicBlock: 3-2                   [32, 64, 7, 7]            73,984
# │    └─Sequential: 2-6                        [32, 128, 4, 4]           --
# │    │    └─BasicBlock: 3-3                   [32, 128, 4, 4]           230,144
# │    │    └─BasicBlock: 3-4                   [32, 128, 4, 4]           295,424
# │    └─Sequential: 2-7                        [32, 256, 2, 2]           --
# │    │    └─BasicBlock: 3-5                   [32, 256, 2, 2]           919,040
# │    │    └─BasicBlock: 3-6                   [32, 256, 2, 2]           1,180,672
# │    └─Sequential: 2-8                        [32, 512, 1, 1]           --
# │    │    └─BasicBlock: 3-7                   [32, 512, 1, 1]           3,673,088
# │    │    └─BasicBlock: 3-8                   [32, 512, 1, 1]           4,720,640
# │    └─AdaptiveAvgPool2d: 2-9                 [32, 512, 1, 1]           --
# │    └─Linear: 2-10                           [32, 1000]                513,000
# ├─ResNet: 1-2                                 [32, 1000]                --
# │    └─Conv2d: 2-11                           [32, 64, 14, 14]          3,136
# │    └─BatchNorm2d: 2-12                      [32, 64, 14, 14]          128
# │    └─ReLU: 2-13                             [32, 64, 14, 14]          --
# │    └─MaxPool2d: 2-14                        [32, 64, 7, 7]            --
# │    └─Sequential: 2-15                       [32, 64, 7, 7]            --
# │    │    └─BasicBlock: 3-9                   [32, 64, 7, 7]            73,984
# │    │    └─BasicBlock: 3-10                  [32, 64, 7, 7]            73,984
# │    └─Sequential: 2-16                       [32, 128, 4, 4]           --
# │    │    └─BasicBlock: 3-11                  [32, 128, 4, 4]           230,144
# │    │    └─BasicBlock: 3-12                  [32, 128, 4, 4]           295,424
# │    └─Sequential: 2-17                       [32, 256, 2, 2]           --
# │    │    └─BasicBlock: 3-13                  [32, 256, 2, 2]           919,040
# │    │    └─BasicBlock: 3-14                  [32, 256, 2, 2]           1,180,672
# │    └─Sequential: 2-18                       [32, 512, 1, 1]           --
# │    │    └─BasicBlock: 3-15                  [32, 512, 1, 1]           3,673,088
# │    │    └─BasicBlock: 3-16                  [32, 512, 1, 1]           4,720,640
# │    └─AdaptiveAvgPool2d: 2-19                [32, 512, 1, 1]           --
# │    └─Linear: 2-20                           [32, 1000]                513,000
# ├─Linear: 1-3                                 [32, 2]                   2,002
# ├─Linear: 1-4                                 [32, 2]                   2,002
# ├─Softmax: 1-5                                [32, 2]                   --
# ├─Softmax: 1-6                                [32, 2]                   --
# ===============================================================================================
# Total params: 23,370,484
# Trainable params: 23,370,484
# Non-trainable params: 0
# Total mult-adds (Units.GIGABYTES): 2.15
# ===============================================================================================
# Input size (MB): 0.10
# Forward/backward pass size (MB): 44.55
# Params size (MB): 93.48
# Estimated Total Size (MB): 138.14
# ===============================================================================================

# %% [markdown]
# **6. 데이터셋 분리**
#
# * Train Data -> Train Data + Valid Data

# %%
# dataset size

num_tv = sum(train_subset_class_counts)
num_valid = int(0.1 * num_tv)
num_train = num_tv - num_valid

# %%
# 데이터셋 분리

from torch.utils.data import random_split

train_dataset, valid_dataset = random_split(train_subset, [num_train, num_valid])

# %%
# DataLoader 생성

train_dataset_loader = DataLoader(train_dataset,
                                  batch_size=BATCH_SIZE,
                                  shuffle=True)

valid_dataset_loader = DataLoader(valid_dataset,
                                  batch_size=BATCH_SIZE,
                                  shuffle=False)

test_dataset_loader = test_subset_loader

# %%
# {0,1} vs. {2} / {0,2} vs. {1} Split 된 DataLoader 생성

from torch.utils.data import Dataset

class DualOutputDataset(Dataset):
    def __init__(self, dataset):
        self.dataset = dataset

    def __len__(self):
        return len(self.dataset)

    def __getitem__(self, idx):
        img, target = self.dataset[idx]
        target1_mapping = {0: 0, 1: 0, 2: 1}
        target2_mapping = {0: 0, 1: 1, 2: 0}

        target1 = target1_mapping[target]
        target2 = target2_mapping[target]

        return img, [target1, target2]

# %%
# Dual Output Dataset 생성

train_01_02_dataset_loader = DataLoader(DualOutputDataset(train_dataset),
                                        batch_size=BATCH_SIZE,
                                        shuffle=True)

valid_01_02_dataset_loader = DataLoader(DualOutputDataset(valid_dataset),
                                        batch_size=BATCH_SIZE,
                                        shuffle=False)

test_01_02_dataset_loader = DataLoader(DualOutputDataset(test_subset),
                                       batch_size=BATCH_SIZE,
                                       shuffle=False)

# %% [markdown]
# **7. 모델 학습 함수 정의**

# %%
MAX_EPOCHS = 9999
EARLY_STOPPING_ROUNDS = 10  # Early Stopping Patience (epochs)

# %%
# dual labels -> PyTorch tensor

def convert_to_tensor(labels):
    labels[0] = list(labels[0])
    labels[1] = list(labels[1])
    labels_tensor = torch.tensor(labels)
    labels_tensor = labels_tensor.transpose(0, 1)

    return labels_tensor

# %%
# 모델 학습 실시

# args :
# - model           : 학습할 모델
# - train_loader    : Training Data Loader
# - train_loss_list : 각 epoch 에서의 train loss 기록
# - is_dual_head    : 신경망 출력값, 즉 MLP Head 가 2개인지의 여부

# returns :
# - train_loss : 모델의 Train Loss

def run_train(model, train_loader, train_loss_list, is_dual_head, verbose):
    model.train()
    train_loss = 0.0
    train_idx = 0

    for images, labels in train_loader:
        if is_dual_head:
            labels = convert_to_tensor(labels)
        images, labels = images.to(device), labels.to(device)

        # train 실시
        model.optimizer.zero_grad()
        outputs = model(images)

        if is_dual_head:
            loss1 = nn.CrossEntropyLoss()(outputs[0], labels[:, 0])
            loss2 = nn.CrossEntropyLoss()(outputs[1], labels[:, 1])
            loss = loss1 + loss2
        else:
            loss = nn.CrossEntropyLoss()(outputs, labels)

        loss.backward()
        model.optimizer.step()

        train_loss += loss.item()
        train_idx += 1

        if verbose:
            if train_idx % 20 == 0:
                print(f'idx: {train_idx}, loss for current idx: {loss.item():.6f}')

    train_loss_list.append(train_loss / len(train_loader))
    return train_loss_list[-1]

# %%
import time

# 모델 validation / test 실시

# args :
# - model                : validation/test 할 모델
# - valid_or_test_loader : validation/test Data Loader
# - is_dual_head         : 신경망 출력값, 즉 MLP Head 가 2개인지의 여부

# returns :
# - accuracy       : 모델의 validation/test 정확도
# - inference_time : inference 시간 (seconds)

def run_valid_or_test(model, valid_or_test_loader, is_dual_head):
    model.eval()
    correct, total = 0, 0
    inference_time_sum = 0.0
    valid_test_idx = 0

    with torch.no_grad():
        for images, labels in valid_or_test_loader:
            if is_dual_head:
                labels = convert_to_tensor(labels)
            images, labels = images.to(device), labels.to(device)

            start_at = time.time()
            outputs = model(images)
            inference_time_sum += time.time() - start_at

            # validation/test 실시 및 정확도 측정
            if is_dual_head:
                _, predicted_1 = torch.max(outputs[0], 1)
                _, predicted_2 = torch.max(outputs[1], 1)
                correct += ((predicted_1 == labels[:, 0]) & (predicted_2 == labels[:, 1])).sum().item()

            else:
                _, predicted = torch.max(outputs, 1)
                correct += (predicted == labels).sum().item()

            total += labels.size(0)
            valid_test_idx += 1

    accuracy = correct / total
    inference_time = inference_time_sum / valid_test_idx

    return accuracy, inference_time

# %%
# 모델 학습 및 validation 전체 프로세스

# args :
# - model         : 학습할 모델
# - train_loader  : Training Data Loader
# - valid_loader  : Valid Data Loader
# - test_loader   : Test Data Loader
# - backbone_name : Backbone 모델 이름 ('resnet18', 'resnet34' or 'resnet50')
# - case_name     : 모델 구조 case 이름 ('1', '2', '3', '4_1' or '4_2')
# - verbose       : 학습 중 프로세스 출력 여부

# returns :
# - final_acc      : 해당 하이퍼파라미터 조합에 대한 최종 Accuracy (valid_acc 이 가장 높았던 epoch 의 모델로 측정)
# - inference_time : inference 시간 (seconds)

def run_model_common(model, train_loader, valid_loader, test_loader,
                     backbone_name, case_name, verbose=False):

    train_loss_list = []       # train loss
    valid_acc_list = []        # valid accuracy
    max_valid_acc = 0.0        # max validation accuracy
    best_valid_acc_epoch = -1  # valid_acc 이 가장 높았던 epoch (여기서는 Loss 가 아닌 Accuracy 기준 Early Stopping)
    best_epoch_model = None    # valid_acc 이 가장 높았던 epoch 의 모델

    is_dual_head = case_name in ['3', '4_1', '4_2']

    # 1. 학습 실시
    for epoch in range(MAX_EPOCHS):

        # 1-1. train model
        train_loss = run_train(model,
                               train_loader,
                               train_loss_list,
                               is_dual_head,
                               verbose=(verbose and epoch == 0))

        # 1-2. validate model (with VALID SET)
        epoch_acc, _ = run_valid_or_test(model, valid_loader, is_dual_head)
        valid_acc_list.append(epoch_acc)

        # 1-3. Early Stopping 처리 (overfitting 방지)
        if epoch_acc > max_valid_acc:
            max_valid_acc = epoch_acc
            best_valid_acc_epoch = epoch

            best_epoch_model = define_model(backbone_name, case_name, device)
            best_epoch_model.load_state_dict(model.state_dict())

            if verbose:
                print('best model updated')

        if epoch - best_valid_acc_epoch >= EARLY_STOPPING_ROUNDS:
            break

        # 1-4. 결과 출력
        if verbose:
            print(f"Epoch {epoch+1}, Loss: {train_loss:.4f}, Accuracy: {epoch_acc:.4f}")

    # check best-epoch model correctly loaded
    checked_acc, _ = run_valid_or_test(best_epoch_model, valid_loader, is_dual_head)

    if verbose:
        print(f"Best Epoch: {best_valid_acc_epoch}, Best Valid Acc: {max_valid_acc}")
        print(f"Valid Acc (with Epoch valid set) on Loaded Best Model: {checked_acc}")

    assert abs(max_valid_acc - checked_acc) < 1e-6

    # 2. test best-epoch model (with TEST SET)
    final_acc, inference_time = run_valid_or_test(best_epoch_model, test_loader, is_dual_head)

    if verbose:
        print(f"Final Acc (with TEST set) on Loaded Best Model: {final_acc} (time: {inference_time})")

    return final_acc, inference_time

# %% [markdown]
# **8. 학습 실시**

# %%
print(device)
# Out:
# cuda

# %%
result_dict = {
    'backbone': [],
    'case': [],
    'accuracy': [],
    'inference_time': []
}

dataloader_by_case_name = {
    'dual_head': {
        'train': train_01_02_dataset_loader,
        'valid': valid_01_02_dataset_loader,
        'test': test_01_02_dataset_loader
    },
    'single_head': {
        'train': train_dataset_loader,
        'valid': valid_dataset_loader,
        'test': test_dataset_loader
    }
}

for case_name in ['1', '2', '3', '4_1', '4_2']:
    if case_name in ['3', '4_1', '4_2']:
        head_type = 'dual_head'
    else:
        head_type = 'single_head'

    for backbone_name in ['resnet18', 'resnet34', 'resnet50']:
        print(f'\n=== case={case_name}, backbone={backbone_name} ===')
        model = define_model(backbone_name, case_name, device=device)

        train_loader = dataloader_by_case_name[head_type]['train']
        valid_loader = dataloader_by_case_name[head_type]['valid']
        test_loader = dataloader_by_case_name[head_type]['test']

        final_acc, inference_time = run_model_common(model,
                                                     train_loader=train_loader,
                                                     valid_loader=valid_loader,
                                                     test_loader=test_loader,
                                                     backbone_name=backbone_name,
                                                     case_name=case_name,
                                                     verbose=True)

        result_dict['backbone'].append(backbone_name)
        result_dict['case'].append(case_name)
        result_dict['accuracy'].append(final_acc)
        result_dict['inference_time'].append(inference_time)
# Out:
# === case=1, backbone=resnet18 ===
# idx: 20, loss for current idx: 0.652169
# idx: 40, loss for current idx: 0.625817
# idx: 60, loss for current idx: 0.589158
# idx: 80, loss for current idx: 0.623886
# idx: 100, loss for current idx: 0.582934
# idx: 120, loss for current idx: 0.552996
# idx: 140, loss for current idx: 0.584564
# idx: 160, loss for current idx: 0.631220
# idx: 180, loss for current idx: 0.615693
# idx: 200, loss for current idx: 0.559502
# idx: 220, loss for current idx: 0.579927
# idx: 240, loss for current idx: 0.622593
# idx: 260, loss for current idx: 0.551451
# idx: 280, loss for current idx: 0.594152
# idx: 300, loss for current idx: 0.582573
# idx: 320, loss for current idx: 0.583475
# idx: 340, loss for current idx: 0.560263
# idx: 360, loss for current idx: 0.552870
# idx: 380, loss for current idx: 0.606358
# idx: 400, loss for current idx: 0.601199
# idx: 420, loss for current idx: 0.583384
# idx: 440, loss for current idx: 0.551893
# idx: 460, loss for current idx: 0.664162
# idx: 480, loss for current idx: 0.561748
# idx: 500, loss for current idx: 0.582127
# idx: 520, loss for current idx: 0.614159
# best model updated
# Epoch 1, Loss: 0.5875, Accuracy: 0.9828
# best model updated
# Epoch 2, Loss: 0.5667, Accuracy: 0.9866
# best model updated
# Epoch 3, Loss: 0.5654, Accuracy: 0.9893
# best model updated
# Epoch 4, Loss: 0.5648, Accuracy: 0.9925
# Epoch 5, Loss: 0.5600, Accuracy: 0.9914
# Epoch 6, Loss: 0.5592, Accuracy: 0.9893
# best model updated
# Epoch 7, Loss: 0.5612, Accuracy: 0.9930
# Epoch 8, Loss: 0.5643, Accuracy: 0.9887
# Epoch 9, Loss: 0.5600, Accuracy: 0.9919
# Epoch 10, Loss: 0.5601, Accuracy: 0.9914
# best model updated
# Epoch 11, Loss: 0.5583, Accuracy: 0.9957
# Epoch 12, Loss: 0.5596, Accuracy: 0.9893
# Epoch 13, Loss: 0.5597, Accuracy: 0.9893
# Epoch 14, Loss: 0.5569, Accuracy: 0.9936
# Epoch 15, Loss: 0.5572, Accuracy: 0.9936
# Epoch 16, Loss: 0.5609, Accuracy: 0.9925
# Epoch 17, Loss: 0.5576, Accuracy: 0.9925
# best model updated
# Epoch 18, Loss: 0.5563, Accuracy: 0.9962
# Epoch 19, Loss: 0.5563, Accuracy: 0.9962
# Epoch 20, Loss: 0.5585, Accuracy: 0.9914
# best model updated
# Epoch 21, Loss: 0.5608, Accuracy: 0.9968
# Epoch 22, Loss: 0.5572, Accuracy: 0.9903
# Epoch 23, Loss: 0.5629, Accuracy: 0.9715
# best model updated
# Epoch 24, Loss: 0.5581, Accuracy: 0.9973
# Epoch 25, Loss: 0.5561, Accuracy: 0.9930
# Epoch 26, Loss: 0.5560, Accuracy: 0.9957
# Epoch 27, Loss: 0.5549, Accuracy: 0.9946
# Epoch 28, Loss: 0.5565, Accuracy: 0.9925
# Epoch 29, Loss: 0.5579, Accuracy: 0.9946
# Epoch 30, Loss: 0.5594, Accuracy: 0.9629
# Epoch 31, Loss: 0.5600, Accuracy: 0.9962
# Epoch 32, Loss: 0.5623, Accuracy: 0.9968
# Epoch 33, Loss: 0.5565, Accuracy: 0.9957
# best model updated
# Epoch 34, Loss: 0.5557, Accuracy: 0.9984
# Epoch 35, Loss: 0.5560, Accuracy: 0.9844
# Epoch 36, Loss: 0.5576, Accuracy: 0.9941
# Epoch 37, Loss: 0.5553, Accuracy: 0.9962
# Epoch 38, Loss: 0.5581, Accuracy: 0.9957
# Epoch 39, Loss: 0.5579, Accuracy: 0.9952
# Epoch 40, Loss: 0.5568, Accuracy: 0.9919
# Epoch 41, Loss: 0.5561, Accuracy: 0.9962
# Epoch 42, Loss: 0.5545, Accuracy: 0.9957
# Epoch 43, Loss: 0.5577, Accuracy: 0.9313
# Best Epoch: 33, Best Valid Acc: 0.9983888292158969
# Valid Acc (with Epoch valid set) on Loaded Best Model: 0.9983888292158969
# Final Acc (with TEST set) on Loaded Best Model: 0.996186844613918 (time: 0.005822420120239258)
#
# === case=1, backbone=resnet34 ===
# Downloading: "https://download.pytorch.org/models/resnet34-b627a593.pth" to /root/.cache/torch/hub/checkpoints/resnet34-b627a593.pth
# 100%|██████████| 83.3M/83.3M [00:00<00:00, 214MB/s]
# idx: 20, loss for current idx: 0.587465
# idx: 40, loss for current idx: 0.626155
# idx: 60, loss for current idx: 0.584852
# idx: 80, loss for current idx: 0.551605
# idx: 100, loss for current idx: 0.645708
# idx: 120, loss for current idx: 0.552630
# idx: 140, loss for current idx: 0.603647
# idx: 160, loss for current idx: 0.556875
# idx: 180, loss for current idx: 0.576863
# idx: 200, loss for current idx: 0.553561
# idx: 220, loss for current idx: 0.551501
# idx: 240, loss for current idx: 0.551484
# idx: 260, loss for current idx: 0.583562
# idx: 280, loss for current idx: 0.562133
# idx: 300, loss for current idx: 0.602320
# idx: 320, loss for current idx: 0.551562
# idx: 340, loss for current idx: 0.590386
# idx: 360, loss for current idx: 0.583114
# idx: 380, loss for current idx: 0.582696
# idx: 400, loss for current idx: 0.551453
# idx: 420, loss for current idx: 0.582675
# idx: 440, loss for current idx: 0.582165
# idx: 460, loss for current idx: 0.563896
# idx: 480, loss for current idx: 0.614332
# idx: 500, loss for current idx: 0.583535
# idx: 520, loss for current idx: 0.552062
# best model updated
# Epoch 1, Loss: 0.5860, Accuracy: 0.9882
# Epoch 2, Loss: 0.5670, Accuracy: 0.9860
# best model updated
# Epoch 3, Loss: 0.5645, Accuracy: 0.9893
# best model updated
# Epoch 4, Loss: 0.5608, Accuracy: 0.9925
# Epoch 5, Loss: 0.5614, Accuracy: 0.9850
# best model updated
# Epoch 6, Loss: 0.5605, Accuracy: 0.9957
# Epoch 7, Loss: 0.5583, Accuracy: 0.9952
# Epoch 8, Loss: 0.5641, Accuracy: 0.9742
# Epoch 9, Loss: 0.5631, Accuracy: 0.9952
# Epoch 10, Loss: 0.5685, Accuracy: 0.9941
# Epoch 11, Loss: 0.5576, Accuracy: 0.9919
# Epoch 12, Loss: 0.5582, Accuracy: 0.9946
# Epoch 13, Loss: 0.5585, Accuracy: 0.9930
# Epoch 14, Loss: 0.5579, Accuracy: 0.9936
# Epoch 15, Loss: 0.5574, Accuracy: 0.9936
# Best Epoch: 5, Best Valid Acc: 0.9957035445757251
# Valid Acc (with Epoch valid set) on Loaded Best Model: 0.9957035445757251
# Final Acc (with TEST set) on Loaded Best Model: 0.996186844613918 (time: 0.010676186494152955)
#
# === case=1, backbone=resnet50 ===
# Downloading: "https://download.pytorch.org/models/resnet50-0676ba61.pth" to /root/.cache/torch/hub/checkpoints/resnet50-0676ba61.pth
# 100%|██████████| 97.8M/97.8M [00:00<00:00, 211MB/s]
# idx: 20, loss for current idx: 0.603330
# idx: 40, loss for current idx: 0.606472
# idx: 60, loss for current idx: 0.583623
# idx: 80, loss for current idx: 0.703788
# idx: 100, loss for current idx: 0.631665
# idx: 120, loss for current idx: 0.582892
# idx: 140, loss for current idx: 0.555212
# idx: 160, loss for current idx: 0.553789
# idx: 180, loss for current idx: 0.647272
# idx: 200, loss for current idx: 0.683172
# idx: 220, loss for current idx: 0.616076
# idx: 240, loss for current idx: 0.577055
# idx: 260, loss for current idx: 0.551671
# idx: 280, loss for current idx: 0.554823
# idx: 300, loss for current idx: 0.552120
# idx: 320, loss for current idx: 0.615155
# idx: 340, loss for current idx: 0.619932
# idx: 360, loss for current idx: 0.614134
# idx: 380, loss for current idx: 0.551453
# idx: 400, loss for current idx: 0.583558
# idx: 420, loss for current idx: 0.613951
# idx: 440, loss for current idx: 0.615127
# idx: 460, loss for current idx: 0.582701
# idx: 480, loss for current idx: 0.551533
# idx: 500, loss for current idx: 0.613938
# idx: 520, loss for current idx: 0.582675
# best model updated
# Epoch 1, Loss: 0.5962, Accuracy: 0.9796
# best model updated
# Epoch 2, Loss: 0.5717, Accuracy: 0.9834
# best model updated
# Epoch 3, Loss: 0.5651, Accuracy: 0.9876
# best model updated
# Epoch 4, Loss: 0.5621, Accuracy: 0.9898
# Epoch 5, Loss: 0.5597, Accuracy: 0.9898
# best model updated
# Epoch 6, Loss: 0.5612, Accuracy: 0.9936
# Epoch 7, Loss: 0.5631, Accuracy: 0.9898
# Epoch 8, Loss: 0.5576, Accuracy: 0.9930
# best model updated
# Epoch 9, Loss: 0.5627, Accuracy: 0.9941
# Epoch 10, Loss: 0.5609, Accuracy: 0.9914
# Epoch 11, Loss: 0.5592, Accuracy: 0.9941
# Epoch 12, Loss: 0.5606, Accuracy: 0.9893
# Epoch 13, Loss: 0.5574, Accuracy: 0.9914
# Epoch 14, Loss: 0.5587, Accuracy: 0.9903
# Epoch 15, Loss: 0.5566, Accuracy: 0.9903
# Epoch 16, Loss: 0.5560, Accuracy: 0.9909
# Epoch 17, Loss: 0.5574, Accuracy: 0.9925
# Epoch 18, Loss: 0.5663, Accuracy: 0.9941
# best model updated
# Epoch 19, Loss: 0.5560, Accuracy: 0.9946
# best model updated
# Epoch 20, Loss: 0.5579, Accuracy: 0.9962
# Epoch 21, Loss: 0.5608, Accuracy: 0.9919
# Epoch 22, Loss: 0.5616, Accuracy: 0.9919
# Epoch 23, Loss: 0.5607, Accuracy: 0.9876
# Epoch 24, Loss: 0.5581, Accuracy: 0.9925
# Epoch 25, Loss: 0.5586, Accuracy: 0.9898
# Epoch 26, Loss: 0.5576, Accuracy: 0.9936
# Epoch 27, Loss: 0.5586, Accuracy: 0.9941
# Epoch 28, Loss: 0.5574, Accuracy: 0.9946
# Epoch 29, Loss: 0.5568, Accuracy: 0.9930
# Best Epoch: 19, Best Valid Acc: 0.9962406015037594
# Valid Acc (with Epoch valid set) on Loaded Best Model: 0.9962406015037594
# Final Acc (with TEST set) on Loaded Best Model: 0.9977756593581188 (time: 0.014768704019411646)
#
# === case=2, backbone=resnet18 ===
# idx: 20, loss for current idx: 0.727986
# idx: 40, loss for current idx: 0.663715
# idx: 60, loss for current idx: 0.554545
# idx: 80, loss for current idx: 0.685945
# idx: 100, loss for current idx: 0.611169
# idx: 120, loss for current idx: 0.552983
# idx: 140, loss for current idx: 0.615569
# idx: 160, loss for current idx: 0.664006
# idx: 180, loss for current idx: 0.551788
# idx: 200, loss for current idx: 0.613111
# idx: 220, loss for current idx: 0.551515
# idx: 240, loss for current idx: 0.560347
# idx: 260, loss for current idx: 0.584227
# idx: 280, loss for current idx: 0.557856
# idx: 300, loss for current idx: 0.571987
# idx: 320, loss for current idx: 0.582360
# idx: 340, loss for current idx: 0.553506
# idx: 360, loss for current idx: 0.551472
# idx: 380, loss for current idx: 0.553785
# idx: 400, loss for current idx: 0.551705
# idx: 420, loss for current idx: 0.551448
# idx: 440, loss for current idx: 0.551473
# idx: 460, loss for current idx: 0.551447
# idx: 480, loss for current idx: 0.551453
# idx: 500, loss for current idx: 0.551479
# idx: 520, loss for current idx: 0.587017
# best model updated
# Epoch 1, Loss: 0.5923, Accuracy: 0.9882
# Epoch 2, Loss: 0.5649, Accuracy: 0.9876
# best model updated
# Epoch 3, Loss: 0.5638, Accuracy: 0.9936
# Epoch 4, Loss: 0.5622, Accuracy: 0.9925
# Epoch 5, Loss: 0.5608, Accuracy: 0.9844
# Epoch 6, Loss: 0.5642, Accuracy: 0.9876
# Epoch 7, Loss: 0.5619, Accuracy: 0.9919
# best model updated
# Epoch 8, Loss: 0.5604, Accuracy: 0.9941
# best model updated
# Epoch 9, Loss: 0.5572, Accuracy: 0.9952
# Epoch 10, Loss: 0.5635, Accuracy: 0.9812
# Epoch 11, Loss: 0.5629, Accuracy: 0.9909
# Epoch 12, Loss: 0.5629, Accuracy: 0.9801
# Epoch 13, Loss: 0.5641, Accuracy: 0.9936
# Epoch 14, Loss: 0.5608, Accuracy: 0.9925
# Epoch 15, Loss: 0.5609, Accuracy: 0.9925
# Epoch 16, Loss: 0.5642, Accuracy: 0.9925
# Epoch 17, Loss: 0.5602, Accuracy: 0.9941
# Epoch 18, Loss: 0.5611, Accuracy: 0.9850
# best model updated
# Epoch 19, Loss: 0.5581, Accuracy: 0.9962
# Epoch 20, Loss: 0.5606, Accuracy: 0.9925
# Epoch 21, Loss: 0.5621, Accuracy: 0.9946
# Epoch 22, Loss: 0.5624, Accuracy: 0.9946
# Epoch 23, Loss: 0.5636, Accuracy: 0.9882
# Epoch 24, Loss: 0.5611, Accuracy: 0.9936
# Epoch 25, Loss: 0.5640, Accuracy: 0.9946
# Epoch 26, Loss: 0.5627, Accuracy: 0.9871
# Epoch 27, Loss: 0.5589, Accuracy: 0.9946
# Epoch 28, Loss: 0.5615, Accuracy: 0.9828
# Best Epoch: 18, Best Valid Acc: 0.9962406015037594
# Valid Acc (with Epoch valid set) on Loaded Best Model: 0.9962406015037594
# Final Acc (with TEST set) on Loaded Best Model: 0.9933269780743565 (time: 0.002481559310296569)
#
# === case=2, backbone=resnet34 ===
# idx: 20, loss for current idx: 0.603517
# idx: 40, loss for current idx: 0.583439
# idx: 60, loss for current idx: 0.582701
# idx: 80, loss for current idx: 0.584279
# idx: 100, loss for current idx: 0.552137
# idx: 120, loss for current idx: 0.553630
# idx: 140, loss for current idx: 0.555447
# idx: 160, loss for current idx: 0.552138
# idx: 180, loss for current idx: 0.556176
# idx: 200, loss for current idx: 0.582587
# idx: 220, loss for current idx: 0.583658
# idx: 240, loss for current idx: 0.584900
# idx: 260, loss for current idx: 0.551771
# idx: 280, loss for current idx: 0.570663
# idx: 300, loss for current idx: 0.597553
# idx: 320, loss for current idx: 0.556104
# idx: 340, loss for current idx: 0.552542
# idx: 360, loss for current idx: 0.573219
# idx: 380, loss for current idx: 0.622168
# idx: 400, loss for current idx: 0.551480
# idx: 420, loss for current idx: 0.551723
# idx: 440, loss for current idx: 0.586819
# idx: 460, loss for current idx: 0.603796
# idx: 480, loss for current idx: 0.613907
# idx: 500, loss for current idx: 0.577905
# idx: 520, loss for current idx: 0.582697
# best model updated
# Epoch 1, Loss: 0.5907, Accuracy: 0.9823
# best model updated
# Epoch 2, Loss: 0.5679, Accuracy: 0.9898
# best model updated
# Epoch 3, Loss: 0.5629, Accuracy: 0.9919
# Epoch 4, Loss: 0.5599, Accuracy: 0.9785
# Epoch 5, Loss: 0.5619, Accuracy: 0.9919
# Epoch 6, Loss: 0.5598, Accuracy: 0.9919
# best model updated
# Epoch 7, Loss: 0.5625, Accuracy: 0.9925
# Epoch 8, Loss: 0.5605, Accuracy: 0.9834
# best model updated
# Epoch 9, Loss: 0.5625, Accuracy: 0.9946
# Epoch 10, Loss: 0.5594, Accuracy: 0.9936
# Epoch 11, Loss: 0.5585, Accuracy: 0.9909
# best model updated
# Epoch 12, Loss: 0.5619, Accuracy: 0.9952
# Epoch 13, Loss: 0.5572, Accuracy: 0.9946
# best model updated
# Epoch 14, Loss: 0.5578, Accuracy: 0.9957
# Epoch 15, Loss: 0.5610, Accuracy: 0.9930
# Epoch 16, Loss: 0.5582, Accuracy: 0.9941
# Epoch 17, Loss: 0.5628, Accuracy: 0.9957
# Epoch 18, Loss: 0.5570, Accuracy: 0.9941
# Epoch 19, Loss: 0.5566, Accuracy: 0.9946
# Epoch 20, Loss: 0.5582, Accuracy: 0.9957
# Epoch 21, Loss: 0.5566, Accuracy: 0.9812
# best model updated
# Epoch 22, Loss: 0.5559, Accuracy: 0.9962
# Epoch 23, Loss: 0.5567, Accuracy: 0.9876
# Epoch 24, Loss: 0.5564, Accuracy: 0.9962
# Epoch 25, Loss: 0.5555, Accuracy: 0.9936
# best model updated
# Epoch 26, Loss: 0.5545, Accuracy: 0.9973
# Epoch 27, Loss: 0.5538, Accuracy: 0.9968
# Epoch 28, Loss: 0.5541, Accuracy: 0.9962
# Epoch 29, Loss: 0.5564, Accuracy: 0.9957
# Epoch 30, Loss: 0.5559, Accuracy: 0.9957
# best model updated
# Epoch 31, Loss: 0.5545, Accuracy: 0.9979
# Epoch 32, Loss: 0.5552, Accuracy: 0.9973
# Epoch 33, Loss: 0.5629, Accuracy: 0.9941
# Epoch 34, Loss: 0.5630, Accuracy: 0.9919
# Epoch 35, Loss: 0.5569, Accuracy: 0.9962
# Epoch 36, Loss: 0.5573, Accuracy: 0.9957
# Epoch 37, Loss: 0.5563, Accuracy: 0.9957
# Epoch 38, Loss: 0.5557, Accuracy: 0.9968
# Epoch 39, Loss: 0.5719, Accuracy: 0.9855
# Epoch 40, Loss: 0.5603, Accuracy: 0.9898
# Best Epoch: 30, Best Valid Acc: 0.9978517722878625
# Valid Acc (with Epoch valid set) on Loaded Best Model: 0.9978517722878625
# Final Acc (with TEST set) on Loaded Best Model: 0.9968223705115984 (time: 0.004243263090499724)
#
# === case=2, backbone=resnet50 ===
# idx: 20, loss for current idx: 0.702038
# idx: 40, loss for current idx: 0.641217
# idx: 60, loss for current idx: 0.642982
# idx: 80, loss for current idx: 0.580240
# idx: 100, loss for current idx: 0.599878
# idx: 120, loss for current idx: 0.569807
# idx: 140, loss for current idx: 0.648322
# idx: 160, loss for current idx: 0.705565
# idx: 180, loss for current idx: 0.598279
# idx: 200, loss for current idx: 0.609334
# idx: 220, loss for current idx: 0.607036
# idx: 240, loss for current idx: 0.564940
# idx: 260, loss for current idx: 0.639240
# idx: 280, loss for current idx: 0.582868
# idx: 300, loss for current idx: 0.613904
# idx: 320, loss for current idx: 0.552108
# idx: 340, loss for current idx: 0.576618
# idx: 360, loss for current idx: 0.597435
# idx: 380, loss for current idx: 0.551456
# idx: 400, loss for current idx: 0.579012
# idx: 420, loss for current idx: 0.552229
# idx: 440, loss for current idx: 0.551456
# idx: 460, loss for current idx: 0.571473
# idx: 480, loss for current idx: 0.559713
# idx: 500, loss for current idx: 0.551540
# idx: 520, loss for current idx: 0.591119
# best model updated
# Epoch 1, Loss: 0.6001, Accuracy: 0.9876
# best model updated
# Epoch 2, Loss: 0.5697, Accuracy: 0.9925
# Epoch 3, Loss: 0.5645, Accuracy: 0.9893
# Epoch 4, Loss: 0.5619, Accuracy: 0.9903
# Epoch 5, Loss: 0.5600, Accuracy: 0.9893
# best model updated
# Epoch 6, Loss: 0.5593, Accuracy: 0.9952
# Epoch 7, Loss: 0.5603, Accuracy: 0.9941
# Epoch 8, Loss: 0.5594, Accuracy: 0.9936
# Epoch 9, Loss: 0.5574, Accuracy: 0.9952
# Epoch 10, Loss: 0.5597, Accuracy: 0.9930
# Epoch 11, Loss: 0.5568, Accuracy: 0.9936
# Epoch 12, Loss: 0.5619, Accuracy: 0.9930
# Epoch 13, Loss: 0.5630, Accuracy: 0.9753
# Epoch 14, Loss: 0.5614, Accuracy: 0.9834
# Epoch 15, Loss: 0.5599, Accuracy: 0.9946
# Best Epoch: 5, Best Valid Acc: 0.9951664876476907
# Valid Acc (with Epoch valid set) on Loaded Best Model: 0.9951664876476907
# Final Acc (with TEST set) on Loaded Best Model: 0.994280266920877 (time: 0.0053129412911155005)
#
# === case=3, backbone=resnet18 ===
# idx: 20, loss for current idx: 0.763496
# idx: 40, loss for current idx: 0.760613
# idx: 60, loss for current idx: 0.700106
# idx: 80, loss for current idx: 0.646744
# idx: 100, loss for current idx: 0.742329
# idx: 120, loss for current idx: 0.682159
# idx: 140, loss for current idx: 0.722747
# idx: 160, loss for current idx: 0.736937
# idx: 180, loss for current idx: 0.658226
# idx: 200, loss for current idx: 0.637066
# idx: 220, loss for current idx: 0.689209
# idx: 240, loss for current idx: 0.632225
# idx: 260, loss for current idx: 0.640820
# idx: 280, loss for current idx: 0.689394
# idx: 300, loss for current idx: 0.691985
# idx: 320, loss for current idx: 0.727656
# idx: 340, loss for current idx: 0.626578
# idx: 360, loss for current idx: 0.685136
# idx: 380, loss for current idx: 0.626882
# idx: 400, loss for current idx: 0.634314
# idx: 420, loss for current idx: 0.636182
# idx: 440, loss for current idx: 0.626769
# idx: 460, loss for current idx: 0.649603
# idx: 480, loss for current idx: 0.657905
# idx: 500, loss for current idx: 0.626598
# idx: 520, loss for current idx: 0.626553
# best model updated
# Epoch 1, Loss: 0.6747, Accuracy: 0.9876
# Epoch 2, Loss: 0.6473, Accuracy: 0.9844
# best model updated
# Epoch 3, Loss: 0.6427, Accuracy: 0.9898
# best model updated
# Epoch 4, Loss: 0.6395, Accuracy: 0.9909
# Epoch 5, Loss: 0.6391, Accuracy: 0.9882
# best model updated
# Epoch 6, Loss: 0.6398, Accuracy: 0.9941
# best model updated
# Epoch 7, Loss: 0.6375, Accuracy: 0.9952
# best model updated
# Epoch 8, Loss: 0.6375, Accuracy: 0.9962
# Epoch 9, Loss: 0.6359, Accuracy: 0.9925
# Epoch 10, Loss: 0.6328, Accuracy: 0.9962
# Epoch 11, Loss: 0.6358, Accuracy: 0.9952
# Epoch 12, Loss: 0.6336, Accuracy: 0.9952
# Epoch 13, Loss: 0.6353, Accuracy: 0.9962
# Epoch 14, Loss: 0.6320, Accuracy: 0.9699
# Epoch 15, Loss: 0.6362, Accuracy: 0.9946
# Epoch 16, Loss: 0.6367, Accuracy: 0.9882
# Epoch 17, Loss: 0.6361, Accuracy: 0.9876
# Best Epoch: 7, Best Valid Acc: 0.9962406015037594
# Valid Acc (with Epoch valid set) on Loaded Best Model: 0.9962406015037594
# Final Acc (with TEST set) on Loaded Best Model: 0.994280266920877 (time: 0.002885344052555585)
#
# === case=3, backbone=resnet34 ===
# idx: 20, loss for current idx: 0.662450
# idx: 40, loss for current idx: 0.690145
# idx: 60, loss for current idx: 0.683255
# idx: 80, loss for current idx: 0.720213
# idx: 100, loss for current idx: 0.629017
# idx: 120, loss for current idx: 0.672629
# idx: 140, loss for current idx: 0.628370
# idx: 160, loss for current idx: 0.637555
# idx: 180, loss for current idx: 0.658672
# idx: 200, loss for current idx: 0.626818
# idx: 220, loss for current idx: 0.673972
# idx: 240, loss for current idx: 0.633296
# idx: 260, loss for current idx: 0.626716
# idx: 280, loss for current idx: 0.673985
# idx: 300, loss for current idx: 0.652492
# idx: 320, loss for current idx: 0.626549
# idx: 340, loss for current idx: 0.720277
# idx: 360, loss for current idx: 0.626653
# idx: 380, loss for current idx: 0.772372
# idx: 400, loss for current idx: 0.626676
# idx: 420, loss for current idx: 0.671319
# idx: 440, loss for current idx: 0.626660
# idx: 460, loss for current idx: 0.690065
# idx: 480, loss for current idx: 0.673770
# idx: 500, loss for current idx: 0.657836
# idx: 520, loss for current idx: 0.658870
# best model updated
# Epoch 1, Loss: 0.6724, Accuracy: 0.9860
# best model updated
# Epoch 2, Loss: 0.6456, Accuracy: 0.9887
# Epoch 3, Loss: 0.6469, Accuracy: 0.9860
# Epoch 4, Loss: 0.6416, Accuracy: 0.9855
# Epoch 5, Loss: 0.6405, Accuracy: 0.9721
# best model updated
# Epoch 6, Loss: 0.6412, Accuracy: 0.9930
# Epoch 7, Loss: 0.6350, Accuracy: 0.9898
# best model updated
# Epoch 8, Loss: 0.6351, Accuracy: 0.9936
# best model updated
# Epoch 9, Loss: 0.6357, Accuracy: 0.9957
# best model updated
# Epoch 10, Loss: 0.6355, Accuracy: 0.9962
# Epoch 11, Loss: 0.6369, Accuracy: 0.9930
# Epoch 12, Loss: 0.6382, Accuracy: 0.9903
# Epoch 13, Loss: 0.6361, Accuracy: 0.9882
# Epoch 14, Loss: 0.6391, Accuracy: 0.9823
# Epoch 15, Loss: 0.6368, Accuracy: 0.9930
# Epoch 16, Loss: 0.6390, Accuracy: 0.9909
# Epoch 17, Loss: 0.6371, Accuracy: 0.9952
# Epoch 18, Loss: 0.6331, Accuracy: 0.9936
# Epoch 19, Loss: 0.6348, Accuracy: 0.9925
# Best Epoch: 9, Best Valid Acc: 0.9962406015037594
# Valid Acc (with Epoch valid set) on Loaded Best Model: 0.9962406015037594
# Final Acc (with TEST set) on Loaded Best Model: 0.996186844613918 (time: 0.004151859668770221)
#
# === case=3, backbone=resnet50 ===
# idx: 20, loss for current idx: 0.789810
# idx: 40, loss for current idx: 0.718670
# idx: 60, loss for current idx: 0.664577
# idx: 80, loss for current idx: 0.762139
# idx: 100, loss for current idx: 0.753958
# idx: 120, loss for current idx: 0.662077
# idx: 140, loss for current idx: 0.629287
# idx: 160, loss for current idx: 0.722525
# idx: 180, loss for current idx: 0.699872
# idx: 200, loss for current idx: 0.627488
# idx: 220, loss for current idx: 0.662640
# idx: 240, loss for current idx: 0.679277
# idx: 260, loss for current idx: 0.657938
# idx: 280, loss for current idx: 0.719835
# idx: 300, loss for current idx: 0.689041
# idx: 320, loss for current idx: 0.629210
# idx: 340, loss for current idx: 0.689145
# idx: 360, loss for current idx: 0.653937
# idx: 380, loss for current idx: 0.626830
# idx: 400, loss for current idx: 0.626551
# idx: 420, loss for current idx: 0.688698
# idx: 440, loss for current idx: 0.626697
# idx: 460, loss for current idx: 0.693863
# idx: 480, loss for current idx: 0.633499
# idx: 500, loss for current idx: 0.627128
# idx: 520, loss for current idx: 0.626529
# best model updated
# Epoch 1, Loss: 0.6805, Accuracy: 0.9823
# best model updated
# Epoch 2, Loss: 0.6488, Accuracy: 0.9850
# best model updated
# Epoch 3, Loss: 0.6406, Accuracy: 0.9936
# Epoch 4, Loss: 0.6396, Accuracy: 0.9925
# Epoch 5, Loss: 0.6388, Accuracy: 0.9936
# Epoch 6, Loss: 0.6374, Accuracy: 0.9925
# best model updated
# Epoch 7, Loss: 0.6353, Accuracy: 0.9952
# Epoch 8, Loss: 0.6353, Accuracy: 0.9930
# Epoch 9, Loss: 0.6384, Accuracy: 0.9876
# Epoch 10, Loss: 0.6403, Accuracy: 0.9893
# Epoch 11, Loss: 0.6377, Accuracy: 0.9946
# Epoch 12, Loss: 0.6339, Accuracy: 0.9936
# best model updated
# Epoch 13, Loss: 0.6357, Accuracy: 0.9968
# Epoch 14, Loss: 0.6309, Accuracy: 0.9962
# Epoch 15, Loss: 0.6366, Accuracy: 0.9871
# Epoch 16, Loss: 0.6479, Accuracy: 0.9850
# Epoch 17, Loss: 0.6371, Accuracy: 0.9941
# Epoch 18, Loss: 0.6323, Accuracy: 0.9952
# Epoch 19, Loss: 0.6364, Accuracy: 0.9925
# Epoch 20, Loss: 0.6343, Accuracy: 0.9968
# Epoch 21, Loss: 0.6364, Accuracy: 0.9946
# Epoch 22, Loss: 0.6346, Accuracy: 0.9898
# Best Epoch: 12, Best Valid Acc: 0.9967776584317938
# Valid Acc (with Epoch valid set) on Loaded Best Model: 0.9967776584317938
# Final Acc (with TEST set) on Loaded Best Model: 0.9971401334604385 (time: 0.005479408032966383)
#
# === case=4_1, backbone=resnet18 ===
# idx: 20, loss for current idx: 0.674463
# idx: 40, loss for current idx: 0.722178
# idx: 60, loss for current idx: 0.628834
# idx: 80, loss for current idx: 0.681128
# idx: 100, loss for current idx: 0.714044
# idx: 120, loss for current idx: 0.651363
# idx: 140, loss for current idx: 0.665493
# idx: 160, loss for current idx: 0.665417
# idx: 180, loss for current idx: 0.661807
# idx: 200, loss for current idx: 0.665864
# idx: 220, loss for current idx: 0.627205
# idx: 240, loss for current idx: 0.626638
# idx: 260, loss for current idx: 0.627056
# idx: 280, loss for current idx: 0.626615
# idx: 300, loss for current idx: 0.652561
# idx: 320, loss for current idx: 0.626704
# idx: 340, loss for current idx: 0.627098
# idx: 360, loss for current idx: 0.654774
# idx: 380, loss for current idx: 0.639580
# idx: 400, loss for current idx: 0.689025
# idx: 420, loss for current idx: 0.626649
# idx: 440, loss for current idx: 0.627963
# idx: 460, loss for current idx: 0.657781
# idx: 480, loss for current idx: 0.631319
# idx: 500, loss for current idx: 0.642230
# idx: 520, loss for current idx: 0.630362
# best model updated
# Epoch 1, Loss: 0.6718, Accuracy: 0.9898
# Epoch 2, Loss: 0.6460, Accuracy: 0.9893
# Epoch 3, Loss: 0.6377, Accuracy: 0.9866
# best model updated
# Epoch 4, Loss: 0.6397, Accuracy: 0.9903
# best model updated
# Epoch 5, Loss: 0.6409, Accuracy: 0.9919
# best model updated
# Epoch 6, Loss: 0.6342, Accuracy: 0.9957
# Epoch 7, Loss: 0.6359, Accuracy: 0.9898
# Epoch 8, Loss: 0.6387, Accuracy: 0.9909
# best model updated
# Epoch 9, Loss: 0.6389, Accuracy: 0.9962
# Epoch 10, Loss: 0.6343, Accuracy: 0.9952
# Epoch 11, Loss: 0.6358, Accuracy: 0.9936
# Epoch 12, Loss: 0.6430, Accuracy: 0.9909
# Epoch 13, Loss: 0.6363, Accuracy: 0.9936
# Epoch 14, Loss: 0.6335, Accuracy: 0.9957
# Epoch 15, Loss: 0.6378, Accuracy: 0.9914
# Epoch 16, Loss: 0.6387, Accuracy: 0.9936
# Epoch 17, Loss: 0.6358, Accuracy: 0.9952
# Epoch 18, Loss: 0.6410, Accuracy: 0.9957
# Best Epoch: 8, Best Valid Acc: 0.9962406015037594
# Valid Acc (with Epoch valid set) on Loaded Best Model: 0.9962406015037594
# Final Acc (with TEST set) on Loaded Best Model: 0.9968223705115984 (time: 0.004788102525653261)
#
# === case=4_1, backbone=resnet34 ===
# idx: 20, loss for current idx: 0.712639
# idx: 40, loss for current idx: 0.783538
# idx: 60, loss for current idx: 0.632367
# idx: 80, loss for current idx: 0.799019
# idx: 100, loss for current idx: 0.796723
# idx: 120, loss for current idx: 0.627053
# idx: 140, loss for current idx: 0.688723
# idx: 160, loss for current idx: 0.628932
# idx: 180, loss for current idx: 0.753146
# idx: 200, loss for current idx: 0.632236
# idx: 220, loss for current idx: 0.631064
# idx: 240, loss for current idx: 0.626861
# idx: 260, loss for current idx: 0.723654
# idx: 280, loss for current idx: 0.645661
# idx: 300, loss for current idx: 0.626559
# idx: 320, loss for current idx: 0.626696
# idx: 340, loss for current idx: 0.627726
# idx: 360, loss for current idx: 0.627058
# idx: 380, loss for current idx: 0.653704
# idx: 400, loss for current idx: 0.641579
# idx: 420, loss for current idx: 0.626648
# idx: 440, loss for current idx: 0.653875
# idx: 460, loss for current idx: 0.657805
# idx: 480, loss for current idx: 0.626572
# idx: 500, loss for current idx: 0.682408
# idx: 520, loss for current idx: 0.630123
# best model updated
# Epoch 1, Loss: 0.6727, Accuracy: 0.9860
# best model updated
# Epoch 2, Loss: 0.6430, Accuracy: 0.9914
# best model updated
# Epoch 3, Loss: 0.6377, Accuracy: 0.9925
# Epoch 4, Loss: 0.6409, Accuracy: 0.9860
# best model updated
# Epoch 5, Loss: 0.6361, Accuracy: 0.9946
# Epoch 6, Loss: 0.6346, Accuracy: 0.9903
# Epoch 7, Loss: 0.6358, Accuracy: 0.9887
# best model updated
# Epoch 8, Loss: 0.6337, Accuracy: 0.9957
# Epoch 9, Loss: 0.6412, Accuracy: 0.9925
# Epoch 10, Loss: 0.6356, Accuracy: 0.9941
# best model updated
# Epoch 11, Loss: 0.6305, Accuracy: 0.9962
# Epoch 12, Loss: 0.6330, Accuracy: 0.9952
# Epoch 13, Loss: 0.6320, Accuracy: 0.9952
# Epoch 14, Loss: 0.6318, Accuracy: 0.9919
# Epoch 15, Loss: 0.6325, Accuracy: 0.9785
# Epoch 16, Loss: 0.6385, Accuracy: 0.9893
# Epoch 17, Loss: 0.6358, Accuracy: 0.9914
# best model updated
# Epoch 18, Loss: 0.6360, Accuracy: 0.9968
# Epoch 19, Loss: 0.6327, Accuracy: 0.9828
# Epoch 20, Loss: 0.6332, Accuracy: 0.9839
# Epoch 21, Loss: 0.6322, Accuracy: 0.9909
# Epoch 22, Loss: 0.6364, Accuracy: 0.9936
# Epoch 23, Loss: 0.6315, Accuracy: 0.9952
# Epoch 24, Loss: 0.6324, Accuracy: 0.9925
# Epoch 25, Loss: 0.6326, Accuracy: 0.9957
# Epoch 26, Loss: 0.6312, Accuracy: 0.9952
# Epoch 27, Loss: 0.6314, Accuracy: 0.9941
# best model updated
# Epoch 28, Loss: 0.6290, Accuracy: 0.9973
# Epoch 29, Loss: 0.6292, Accuracy: 0.9957
# Epoch 30, Loss: 0.6304, Accuracy: 0.9925
# Epoch 31, Loss: 0.6343, Accuracy: 0.9898
# Epoch 32, Loss: 0.6389, Accuracy: 0.9936
# Epoch 33, Loss: 0.6370, Accuracy: 0.9930
# Epoch 34, Loss: 0.6475, Accuracy: 0.9882
# Epoch 35, Loss: 0.6322, Accuracy: 0.9941
# Epoch 36, Loss: 0.6314, Accuracy: 0.9936
# Epoch 37, Loss: 0.6321, Accuracy: 0.9925
# Best Epoch: 27, Best Valid Acc: 0.9973147153598282
# Valid Acc (with Epoch valid set) on Loaded Best Model: 0.9973147153598282
# Final Acc (with TEST set) on Loaded Best Model: 0.9984111852557992 (time: 0.008076501615119703)
#
# === case=4_1, backbone=resnet50 ===
# idx: 20, loss for current idx: 0.720309
# idx: 40, loss for current idx: 0.683504
# idx: 60, loss for current idx: 0.780919
# idx: 80, loss for current idx: 0.695556
# idx: 100, loss for current idx: 0.655381
# idx: 120, loss for current idx: 0.779811
# idx: 140, loss for current idx: 0.748815
# idx: 160, loss for current idx: 0.657699
# idx: 180, loss for current idx: 0.627183
# idx: 200, loss for current idx: 0.655299
# idx: 220, loss for current idx: 0.627432
# idx: 240, loss for current idx: 0.688094
# idx: 260, loss for current idx: 0.626527
# idx: 280, loss for current idx: 0.687861
# idx: 300, loss for current idx: 0.627187
# idx: 320, loss for current idx: 0.687560
# idx: 340, loss for current idx: 0.626536
# idx: 360, loss for current idx: 0.626538
# idx: 380, loss for current idx: 0.626533
# idx: 400, loss for current idx: 0.694399
# idx: 420, loss for current idx: 0.627315
# idx: 440, loss for current idx: 0.626557
# idx: 460, loss for current idx: 0.638469
# idx: 480, loss for current idx: 0.650487
# idx: 500, loss for current idx: 0.626599
# idx: 520, loss for current idx: 0.719744
# best model updated
# Epoch 1, Loss: 0.6777, Accuracy: 0.9791
# best model updated
# Epoch 2, Loss: 0.6511, Accuracy: 0.9930
# Epoch 3, Loss: 0.6463, Accuracy: 0.9893
# best model updated
# Epoch 4, Loss: 0.6382, Accuracy: 0.9941
# Epoch 5, Loss: 0.6408, Accuracy: 0.9925
# Epoch 6, Loss: 0.6389, Accuracy: 0.9919
# Epoch 7, Loss: 0.6462, Accuracy: 0.9903
# Epoch 8, Loss: 0.6452, Accuracy: 0.9909
# Epoch 9, Loss: 0.6445, Accuracy: 0.9388
# Epoch 10, Loss: 0.6456, Accuracy: 0.9925
# best model updated
# Epoch 11, Loss: 0.6407, Accuracy: 0.9946
# Epoch 12, Loss: 0.6420, Accuracy: 0.9919
# Epoch 13, Loss: 0.6396, Accuracy: 0.9919
# Epoch 14, Loss: 0.6412, Accuracy: 0.9844
# best model updated
# Epoch 15, Loss: 0.6403, Accuracy: 0.9952
# Epoch 16, Loss: 0.6376, Accuracy: 0.9936
# Epoch 17, Loss: 0.6337, Accuracy: 0.9715
# Epoch 18, Loss: 0.6440, Accuracy: 0.9919
# Epoch 19, Loss: 0.6366, Accuracy: 0.9909
# Epoch 20, Loss: 0.6425, Accuracy: 0.9909
# Epoch 21, Loss: 0.6363, Accuracy: 0.9919
# Epoch 22, Loss: 0.6353, Accuracy: 0.9919
# Epoch 23, Loss: 0.6377, Accuracy: 0.9925
# Epoch 24, Loss: 0.6387, Accuracy: 0.9876
# Best Epoch: 14, Best Valid Acc: 0.9951664876476907
# Valid Acc (with Epoch valid set) on Loaded Best Model: 0.9951664876476907
# Final Acc (with TEST set) on Loaded Best Model: 0.9977756593581188 (time: 0.010910111244278724)
#
# === case=4_2, backbone=resnet18 ===
# idx: 20, loss for current idx: 0.658840
# idx: 40, loss for current idx: 0.767734
# idx: 60, loss for current idx: 0.627151
# idx: 80, loss for current idx: 0.628673
# idx: 100, loss for current idx: 0.666124
# idx: 120, loss for current idx: 0.629433
# idx: 140, loss for current idx: 0.687928
# idx: 160, loss for current idx: 0.689369
# idx: 180, loss for current idx: 0.626916
# idx: 200, loss for current idx: 0.628268
# idx: 220, loss for current idx: 0.708270
# idx: 240, loss for current idx: 0.666999
# idx: 260, loss for current idx: 0.668252
# idx: 280, loss for current idx: 0.720090
# idx: 300, loss for current idx: 0.632915
# idx: 320, loss for current idx: 0.628963
# idx: 340, loss for current idx: 0.681210
# idx: 360, loss for current idx: 0.627018
# idx: 380, loss for current idx: 0.679079
# idx: 400, loss for current idx: 0.626660
# idx: 420, loss for current idx: 0.661149
# idx: 440, loss for current idx: 0.626548
# idx: 460, loss for current idx: 0.658015
# idx: 480, loss for current idx: 0.716511
# idx: 500, loss for current idx: 0.645655
# idx: 520, loss for current idx: 0.626556
# best model updated
# Epoch 1, Loss: 0.6715, Accuracy: 0.9823
# best model updated
# Epoch 2, Loss: 0.6476, Accuracy: 0.9919
# Epoch 3, Loss: 0.6478, Accuracy: 0.9769
# Epoch 4, Loss: 0.6430, Accuracy: 0.9855
# Epoch 5, Loss: 0.6414, Accuracy: 0.9909
# Epoch 6, Loss: 0.6364, Accuracy: 0.9828
# Epoch 7, Loss: 0.6404, Accuracy: 0.9834
# Epoch 8, Loss: 0.6425, Accuracy: 0.9914
# Epoch 9, Loss: 0.6382, Accuracy: 0.9871
# best model updated
# Epoch 10, Loss: 0.6379, Accuracy: 0.9946
# Epoch 11, Loss: 0.6341, Accuracy: 0.9914
# Epoch 12, Loss: 0.6394, Accuracy: 0.9866
# Epoch 13, Loss: 0.6374, Accuracy: 0.9903
# Epoch 14, Loss: 0.6419, Accuracy: 0.9855
# Epoch 15, Loss: 0.6422, Accuracy: 0.9876
# Epoch 16, Loss: 0.6369, Accuracy: 0.9930
# Epoch 17, Loss: 0.6358, Accuracy: 0.9930
# Epoch 18, Loss: 0.6362, Accuracy: 0.9903
# Epoch 19, Loss: 0.6425, Accuracy: 0.9876
# Best Epoch: 9, Best Valid Acc: 0.9946294307196563
# Valid Acc (with Epoch valid set) on Loaded Best Model: 0.9946294307196563
# Final Acc (with TEST set) on Loaded Best Model: 0.9949157928185574 (time: 0.004581711509011008)
#
# === case=4_2, backbone=resnet34 ===
# idx: 20, loss for current idx: 0.779058
# idx: 40, loss for current idx: 0.663889
# idx: 60, loss for current idx: 0.706284
# idx: 80, loss for current idx: 0.657578
# idx: 100, loss for current idx: 0.724760
# idx: 120, loss for current idx: 0.638395
# idx: 140, loss for current idx: 0.626781
# idx: 160, loss for current idx: 0.627115
# idx: 180, loss for current idx: 0.663119
# idx: 200, loss for current idx: 0.657622
# idx: 220, loss for current idx: 0.686450
# idx: 240, loss for current idx: 0.644739
# idx: 260, loss for current idx: 0.626545
# idx: 280, loss for current idx: 0.659008
# idx: 300, loss for current idx: 0.663436
# idx: 320, loss for current idx: 0.658785
# idx: 340, loss for current idx: 0.626564
# idx: 360, loss for current idx: 0.647217
# idx: 380, loss for current idx: 0.626571
# idx: 400, loss for current idx: 0.657319
# idx: 420, loss for current idx: 0.626668
# idx: 440, loss for current idx: 0.626575
# idx: 460, loss for current idx: 0.653177
# idx: 480, loss for current idx: 0.657809
# idx: 500, loss for current idx: 0.647579
# idx: 520, loss for current idx: 0.657789
# best model updated
# Epoch 1, Loss: 0.6724, Accuracy: 0.9791
# best model updated
# Epoch 2, Loss: 0.6515, Accuracy: 0.9860
# Epoch 3, Loss: 0.6437, Accuracy: 0.9855
# best model updated
# Epoch 4, Loss: 0.6489, Accuracy: 0.9898
# best model updated
# Epoch 5, Loss: 0.6442, Accuracy: 0.9919
# best model updated
# Epoch 6, Loss: 0.6383, Accuracy: 0.9930
# Epoch 7, Loss: 0.6381, Accuracy: 0.9866
# Epoch 8, Loss: 0.6396, Accuracy: 0.9828
# Epoch 9, Loss: 0.6410, Accuracy: 0.9919
# Epoch 10, Loss: 0.6426, Accuracy: 0.9882
# Epoch 11, Loss: 0.6402, Accuracy: 0.9925
# Epoch 12, Loss: 0.6389, Accuracy: 0.9914
# Epoch 13, Loss: 0.6433, Accuracy: 0.9876
# Epoch 14, Loss: 0.6384, Accuracy: 0.9925
# best model updated
# Epoch 15, Loss: 0.6397, Accuracy: 0.9936
# Epoch 16, Loss: 0.6439, Accuracy: 0.9882
# Epoch 17, Loss: 0.6433, Accuracy: 0.9914
# Epoch 18, Loss: 0.6353, Accuracy: 0.9871
# Epoch 19, Loss: 0.6400, Accuracy: 0.9871
# Epoch 20, Loss: 0.6473, Accuracy: 0.9909
# Epoch 21, Loss: 0.6383, Accuracy: 0.9914
# Epoch 22, Loss: 0.6388, Accuracy: 0.9807
# Epoch 23, Loss: 0.6390, Accuracy: 0.9898
# Epoch 24, Loss: 0.6364, Accuracy: 0.9909
# Best Epoch: 14, Best Valid Acc: 0.9935553168635876
# Valid Acc (with Epoch valid set) on Loaded Best Model: 0.9935553168635876
# Final Acc (with TEST set) on Loaded Best Model: 0.9945980298697172 (time: 0.008165385988023546)
#
# === case=4_2, backbone=resnet50 ===
# idx: 20, loss for current idx: 0.780573
# idx: 40, loss for current idx: 0.692392
# idx: 60, loss for current idx: 0.639479
# idx: 80, loss for current idx: 0.635575
# idx: 100, loss for current idx: 0.710622
# idx: 120, loss for current idx: 0.656053
# idx: 140, loss for current idx: 0.659353
# idx: 160, loss for current idx: 0.636349
# idx: 180, loss for current idx: 0.644957
# idx: 200, loss for current idx: 0.629670
# idx: 220, loss for current idx: 0.743740
# idx: 240, loss for current idx: 0.696299
# idx: 260, loss for current idx: 0.750414
# idx: 280, loss for current idx: 0.646022
# idx: 300, loss for current idx: 0.659279
# idx: 320, loss for current idx: 0.725282
# idx: 340, loss for current idx: 0.657797
# idx: 360, loss for current idx: 0.732773
# idx: 380, loss for current idx: 0.626662
# idx: 400, loss for current idx: 0.626653
# idx: 420, loss for current idx: 0.627218
# idx: 440, loss for current idx: 0.751580
# idx: 460, loss for current idx: 0.656798
# idx: 480, loss for current idx: 0.627141
# idx: 500, loss for current idx: 0.627040
# idx: 520, loss for current idx: 0.720089
# best model updated
# Epoch 1, Loss: 0.6863, Accuracy: 0.9764
# best model updated
# Epoch 2, Loss: 0.6558, Accuracy: 0.9876
# Epoch 3, Loss: 0.6490, Accuracy: 0.9871
# Epoch 4, Loss: 0.6430, Accuracy: 0.9860
# best model updated
# Epoch 5, Loss: 0.6399, Accuracy: 0.9887
# Epoch 6, Loss: 0.6397, Accuracy: 0.9850
# Epoch 7, Loss: 0.6425, Accuracy: 0.9860
# best model updated
# Epoch 8, Loss: 0.6357, Accuracy: 0.9898
# Epoch 9, Loss: 0.6359, Accuracy: 0.9893
# Epoch 10, Loss: 0.6386, Accuracy: 0.9844
# best model updated
# Epoch 11, Loss: 0.6389, Accuracy: 0.9919
# Epoch 12, Loss: 0.6387, Accuracy: 0.9844
# Epoch 13, Loss: 0.6355, Accuracy: 0.9919
# Epoch 14, Loss: 0.6383, Accuracy: 0.9893
# Epoch 15, Loss: 0.6444, Accuracy: 0.9871
# Epoch 16, Loss: 0.6403, Accuracy: 0.9893
# Epoch 17, Loss: 0.6389, Accuracy: 0.9909
# Epoch 18, Loss: 0.6481, Accuracy: 0.9860
# Epoch 19, Loss: 0.6408, Accuracy: 0.9903
# Epoch 20, Loss: 0.6483, Accuracy: 0.9608
# Best Epoch: 10, Best Valid Acc: 0.9919441460794844
# Valid Acc (with Epoch valid set) on Loaded Best Model: 0.9919441460794844
# Final Acc (with TEST set) on Loaded Best Model: 0.994280266920877 (time: 0.010856185296569208)

# %%
result_df = pd.DataFrame(result_dict)
result_df
# Out:
#     backbone case  accuracy  inference_time
# 0   resnet18    1  0.996187        0.005822
# 1   resnet34    1  0.996187        0.010676
# 2   resnet50    1  0.997776        0.014769
# 3   resnet18    2  0.993327        0.002482
# 4   resnet34    2  0.996822        0.004243
# 5   resnet50    2  0.994280        0.005313
# 6   resnet18    3  0.994280        0.002885
# 7   resnet34    3  0.996187        0.004152
# 8   resnet50    3  0.997140        0.005479
# 9   resnet18  4_1  0.996822        0.004788
# 10  resnet34  4_1  0.998411        0.008077
# 11  resnet50  4_1  0.997776        0.010910
# 12  resnet18  4_2  0.994916        0.004582
# 13  resnet34  4_2  0.994598        0.008165
# 14  resnet50  4_2  0.994280        0.010856

# %%
result_df.to_csv('result_experiment_2.csv')
