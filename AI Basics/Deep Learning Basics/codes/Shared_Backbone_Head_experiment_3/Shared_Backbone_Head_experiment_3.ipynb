# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms

import plotly.graph_objects as go

import random
import pandas as pd
import numpy as np

# !pip install torchinfo
from torchinfo import summary
# Out:
# Requirement already satisfied: torchinfo in /usr/local/lib/python3.12/dist-packages (1.8.0)

# %%
# 경고 미 표시

import warnings
warnings.filterwarnings('ignore')

# %%
# Random Seed 고정 (학습 반복 시행 시에도 동일한 결과가 나오도록)

seed = 20251004

random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)
torch.cuda.manual_seed_all(seed)

# %%
# 데이터셋 로딩

transform = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.5,), (0.5,))])

train_dataset = torchvision.datasets.MNIST(root='./data',
                                           train=True,
                                           transform=transform,
                                           download=True)

test_dataset = torchvision.datasets.MNIST(root='./data',
                                          train=False,
                                          transform=transform,
                                          download=True)

# %% [markdown]
# **1. 데이터셋 분석**

# %%
# 데이터셋 로딩

from torch.utils.data import DataLoader

BATCH_SIZE = 32

train_loader = DataLoader(train_dataset,
                          batch_size=BATCH_SIZE,
                          shuffle=True)

test_loader = DataLoader(test_dataset,
                         batch_size=BATCH_SIZE,
                         shuffle=False)

# %%
# 클래스 불균형 분석

# 학습 데이터
train_labels = torch.tensor(train_dataset.targets)
train_class_counts = torch.bincount(train_labels)
print(f'train data : {train_class_counts}')

# 테스트 데이터
test_labels = torch.tensor(test_dataset.targets)
test_class_counts = torch.bincount(test_labels)
print(f'test  data : {test_class_counts}')

NUM_CLASSES = len(train_class_counts)
# Out:
# train data : tensor([5923, 6742, 5958, 6131, 5842, 5421, 5918, 6265, 5851, 5949])
# test  data : tensor([ 980, 1135, 1032, 1010,  982,  892,  958, 1028,  974, 1009])

# %%
# 클래스 불균형 분석 (percentage)

train_class_percentage = np.array(train_class_counts) * 100.0 / sum(train_class_counts)

train_y_distrib = pd.DataFrame({'class': list(range(NUM_CLASSES)),
                                'count': train_class_counts,
                                'percentage (%)': train_class_percentage})

train_y_distrib
# Out:
#    class  count  percentage (%)
# 0      0   5923        9.871667
# 1      1   6742       11.236667
# 2      2   5958        9.930000
# 3      3   6131       10.218333
# 4      4   5842        9.736667
# 5      5   5421        9.035000
# 6      6   5918        9.863333
# 7      7   6265       10.441667
# 8      8   5851        9.751667
# 9      9   5949        9.915000

# %%
test_class_percentage = np.array(test_class_counts) * 100.0 / sum(test_class_counts)

test_y_distrib = pd.DataFrame({'class': list(range(NUM_CLASSES)),
                               'count': test_class_counts,
                               'percentage (%)': test_class_percentage})

test_y_distrib
# Out:
#    class  count  percentage (%)
# 0      0    980            9.80
# 1      1   1135           11.35
# 2      2   1032           10.32
# 3      3   1010           10.10
# 4      4    982            9.82
# 5      5    892            8.92
# 6      6    958            9.58
# 7      7   1028           10.28
# 8      8    974            9.74
# 9      9   1009           10.09

# %% [markdown]
# **2. 6, 8, 9 숫자 데이터만 추출**

# %%
from torch.utils.data import Subset

TRAIN_N = 400

# train dataset
train_targets = torch.tensor(train_dataset.targets)[:TRAIN_N]
train_mask = (train_targets == 6) | (train_targets == 8) | (train_targets == 9)
train_indices = torch.where(train_mask)[0]

train_subset = Subset(train_dataset, train_indices)

# test dataset
test_targets = torch.tensor(test_dataset.targets)
test_mask = (test_targets == 6) | (test_targets == 8) | (test_targets == 9)
test_indices = torch.where(test_mask)[0]

test_subset = Subset(test_dataset, test_indices)

# %%
# train, test Data Loader 갱신

train_subset_loader = DataLoader(train_subset,
                                 batch_size=BATCH_SIZE,
                                 shuffle=True)

test_subset_loader = DataLoader(test_subset,
                                batch_size=BATCH_SIZE,
                                shuffle=False)

# %%
# train, test Data Loader 의 class 가 6, 8, 9 뿐인지 확인

train_subset_labels = train_subset.dataset.targets[train_subset.indices]
train_subset_class_counts = torch.bincount(train_subset_labels)
print(f'train data (subset) [6,8,9] : {train_subset_class_counts}')

test_subset_labels = test_subset.dataset.targets[test_subset.indices]
test_subset_class_counts = torch.bincount(test_subset_labels)
print(f'test  data (subset) [6,8,9] : {test_subset_class_counts}')
# Out:
# train data (subset) [6,8,9] : tensor([ 0,  0,  0,  0,  0,  0, 36,  0, 30, 44])
# test  data (subset) [6,8,9] : tensor([   0,    0,    0,    0,    0,    0,  958,    0,  974, 1009])

# %% [markdown]
# **3. CNN 모델 정의**

# %%
# 1. Non-Shared backbone & Shared head

class CNN_CASE_1(nn.Module):
    def __init__(self, backbone_1, backbone_2):
        super(CNN_CASE_1, self).__init__()

        self.backbone_1 = backbone_1
        self.backbone_2 = backbone_2
        self.final_linear = nn.Linear(2000, 3)
        self.final_softmax = nn.Softmax(dim=1)

    def forward(self, x):
        x1 = self.backbone_1(x)
        x2 = self.backbone_2(x)
        x = torch.concatenate([x1, x2], dim=1)

        x = self.final_linear(x)
        x = self.final_softmax(x)

        return x

# %%
# 2. Shared backbone & Shared head

class CNN_CASE_2(nn.Module):
    def __init__(self, backbone):
        super(CNN_CASE_2, self).__init__()

        self.backbone = backbone
        self.final_linear = nn.Linear(1000, 3)
        self.final_softmax = nn.Softmax(dim=1)

    def forward(self, x):
        x = self.backbone(x)
        x = self.final_linear(x)
        x = self.final_softmax(x)

        return x

# %%
# 3. Shared backbone & Non-Shared head

class CNN_CASE_3(nn.Module):
    def __init__(self, backbone):
        super(CNN_CASE_3, self).__init__()

        self.backbone = backbone
        self.final_linear_1 = nn.Linear(1000, 2)
        self.final_linear_2 = nn.Linear(1000, 2)
        self.final_softmax = nn.Softmax(dim=1)

    def forward(self, x):
        x = self.backbone(x)
        x1 = self.final_linear_1(x)
        x2 = self.final_linear_2(x)
        x1 = self.final_softmax(x1)
        x2 = self.final_softmax(x2)

        return x1, x2

# %%
# 4. Non-Shared backbone & Non-Shared head (4-1)

class CNN_CASE_4_1(nn.Module):
    def __init__(self, backbone_1, backbone_2):
        super(CNN_CASE_4_1, self).__init__()

        self.backbone_1 = backbone_1
        self.backbone_2 = backbone_2
        self.final_linear_1 = nn.Linear(2000, 2)
        self.final_linear_2 = nn.Linear(2000, 2)
        self.final_softmax = nn.Softmax(dim=1)

    def forward(self, x):
        x11 = self.backbone_1(x)
        x12 = self.backbone_2(x)
        x = torch.concatenate([x11, x12], dim=1)

        x21 = self.final_linear_1(x)
        x22 = self.final_linear_2(x)
        x21 = self.final_softmax(x21)
        x22 = self.final_softmax(x22)

        return x21, x22

# %%
# 5. Non-Shared backbone & Non-Shared head (4-2)

class CNN_CASE_4_2(nn.Module):
    def __init__(self, backbone_1, backbone_2):
        super(CNN_CASE_4_2, self).__init__()

        self.backbone_1 = backbone_1
        self.backbone_2 = backbone_2
        self.final_linear_1 = nn.Linear(1000, 2)
        self.final_linear_2 = nn.Linear(1000, 2)
        self.final_softmax = nn.Softmax(dim=1)

    def forward(self, x):
        x11 = self.backbone_1(x)
        x12 = self.backbone_2(x)
        x21 = self.final_linear_1(x11)
        x22 = self.final_linear_2(x12)
        x21 = self.final_softmax(x21)
        x22 = self.final_softmax(x22)

        return x21, x22

# %% [markdown]
# **4. backbone model 로딩**

# %%
import torchvision.models as models

def define_model(backbone_name, case_name, device):

    # model count
    if case_name in ['1', '4_1', '4_2']:
        model_count = 2
    else:
        model_count = 1

    # load pre-trained backbone model
    pretrained_models = []

    for _ in range(model_count):
        if backbone_name == 'resnet18':
            pretrained_model = models.resnet18(pretrained=True)

        elif backbone_name == 'resnet34':
            pretrained_model = models.resnet34(pretrained=True)

        else:  # resnet50
            pretrained_model = models.resnet50(pretrained=True)

        pretrained_model.conv1 = torch.nn.Conv2d(1, 64,
                                                 kernel_size=(7, 7),
                                                 stride=(2, 2),
                                                 padding=(3, 3),
                                                 bias=False)
        pretrained_models.append(pretrained_model)

    # define full model
    if case_name == '1':
        model = CNN_CASE_1(backbone_1=pretrained_models[0],
                           backbone_2=pretrained_models[1])

    elif case_name == '2':
        model = CNN_CASE_2(backbone=pretrained_models[0])

    elif case_name == '3':
        model = CNN_CASE_3(backbone=pretrained_models[0])

    elif case_name == '4_1':
        model = CNN_CASE_4_1(backbone_1=pretrained_models[0],
                             backbone_2=pretrained_models[1])

    elif case_name == '4_2':
        model = CNN_CASE_4_2(backbone_1=pretrained_models[0],
                             backbone_2=pretrained_models[1])

    # device & optimizer & scheduler setting
    model.to(device)
    model.optimizer = torch.optim.AdamW(model.parameters(), lr=0.0001)
    model.scheduler = torch.optim.lr_scheduler.ExponentialLR(optimizer=model.optimizer,
                                                             gamma=0.95)

    return model

# %% [markdown]
# **5. 모델 구조 출력**

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
input_size=(BATCH_SIZE, 1, 28, 28)

# %%
temp_backbone_name = 'resnet18'

# %%
# 1. Non-Shared backbone & Shared head

model_case_1 = define_model(temp_backbone_name, case_name='1', device=device)
print(summary(model=model_case_1, input_size=input_size))
# Out:
# ===============================================================================================
# Layer (type:depth-idx)                        Output Shape              Param #
# ===============================================================================================
# CNN_CASE_1                                    [32, 3]                   --
# ├─ResNet: 1-1                                 [32, 1000]                --
# │    └─Conv2d: 2-1                            [32, 64, 14, 14]          3,136
# │    └─BatchNorm2d: 2-2                       [32, 64, 14, 14]          128
# │    └─ReLU: 2-3                              [32, 64, 14, 14]          --
# │    └─MaxPool2d: 2-4                         [32, 64, 7, 7]            --
# │    └─Sequential: 2-5                        [32, 64, 7, 7]            --
# │    │    └─BasicBlock: 3-1                   [32, 64, 7, 7]            73,984
# │    │    └─BasicBlock: 3-2                   [32, 64, 7, 7]            73,984
# │    └─Sequential: 2-6                        [32, 128, 4, 4]           --
# │    │    └─BasicBlock: 3-3                   [32, 128, 4, 4]           230,144
# │    │    └─BasicBlock: 3-4                   [32, 128, 4, 4]           295,424
# │    └─Sequential: 2-7                        [32, 256, 2, 2]           --
# │    │    └─BasicBlock: 3-5                   [32, 256, 2, 2]           919,040
# │    │    └─BasicBlock: 3-6                   [32, 256, 2, 2]           1,180,672
# │    └─Sequential: 2-8                        [32, 512, 1, 1]           --
# │    │    └─BasicBlock: 3-7                   [32, 512, 1, 1]           3,673,088
# │    │    └─BasicBlock: 3-8                   [32, 512, 1, 1]           4,720,640
# │    └─AdaptiveAvgPool2d: 2-9                 [32, 512, 1, 1]           --
# │    └─Linear: 2-10                           [32, 1000]                513,000
# ├─ResNet: 1-2                                 [32, 1000]                --
# │    └─Conv2d: 2-11                           [32, 64, 14, 14]          3,136
# │    └─BatchNorm2d: 2-12                      [32, 64, 14, 14]          128
# │    └─ReLU: 2-13                             [32, 64, 14, 14]          --
# │    └─MaxPool2d: 2-14                        [32, 64, 7, 7]            --
# │    └─Sequential: 2-15                       [32, 64, 7, 7]            --
# │    │    └─BasicBlock: 3-9                   [32, 64, 7, 7]            73,984
# │    │    └─BasicBlock: 3-10                  [32, 64, 7, 7]            73,984
# │    └─Sequential: 2-16                       [32, 128, 4, 4]           --
# │    │    └─BasicBlock: 3-11                  [32, 128, 4, 4]           230,144
# │    │    └─BasicBlock: 3-12                  [32, 128, 4, 4]           295,424
# │    └─Sequential: 2-17                       [32, 256, 2, 2]           --
# │    │    └─BasicBlock: 3-13                  [32, 256, 2, 2]           919,040
# │    │    └─BasicBlock: 3-14                  [32, 256, 2, 2]           1,180,672
# │    └─Sequential: 2-18                       [32, 512, 1, 1]           --
# │    │    └─BasicBlock: 3-15                  [32, 512, 1, 1]           3,673,088
# │    │    └─BasicBlock: 3-16                  [32, 512, 1, 1]           4,720,640
# │    └─AdaptiveAvgPool2d: 2-19                [32, 512, 1, 1]           --
# │    └─Linear: 2-20                           [32, 1000]                513,000
# ├─Linear: 1-3                                 [32, 3]                   6,003
# ├─Softmax: 1-4                                [32, 3]                   --
# ===============================================================================================
# Total params: 23,372,483
# Trainable params: 23,372,483
# Non-trainable params: 0
# Total mult-adds (Units.GIGABYTES): 2.15
# ===============================================================================================
# Input size (MB): 0.10
# Forward/backward pass size (MB): 44.55
# Params size (MB): 93.49
# Estimated Total Size (MB): 138.14
# ===============================================================================================

# %%
# 2. Shared backbone & Shared head

model_case_2 = define_model(temp_backbone_name, case_name='2', device=device)
print(summary(model=model_case_2, input_size=input_size))
# Out:
# ===============================================================================================
# Layer (type:depth-idx)                        Output Shape              Param #
# ===============================================================================================
# CNN_CASE_2                                    [32, 3]                   --
# ├─ResNet: 1-1                                 [32, 1000]                --
# │    └─Conv2d: 2-1                            [32, 64, 14, 14]          3,136
# │    └─BatchNorm2d: 2-2                       [32, 64, 14, 14]          128
# │    └─ReLU: 2-3                              [32, 64, 14, 14]          --
# │    └─MaxPool2d: 2-4                         [32, 64, 7, 7]            --
# │    └─Sequential: 2-5                        [32, 64, 7, 7]            --
# │    │    └─BasicBlock: 3-1                   [32, 64, 7, 7]            73,984
# │    │    └─BasicBlock: 3-2                   [32, 64, 7, 7]            73,984
# │    └─Sequential: 2-6                        [32, 128, 4, 4]           --
# │    │    └─BasicBlock: 3-3                   [32, 128, 4, 4]           230,144
# │    │    └─BasicBlock: 3-4                   [32, 128, 4, 4]           295,424
# │    └─Sequential: 2-7                        [32, 256, 2, 2]           --
# │    │    └─BasicBlock: 3-5                   [32, 256, 2, 2]           919,040
# │    │    └─BasicBlock: 3-6                   [32, 256, 2, 2]           1,180,672
# │    └─Sequential: 2-8                        [32, 512, 1, 1]           --
# │    │    └─BasicBlock: 3-7                   [32, 512, 1, 1]           3,673,088
# │    │    └─BasicBlock: 3-8                   [32, 512, 1, 1]           4,720,640
# │    └─AdaptiveAvgPool2d: 2-9                 [32, 512, 1, 1]           --
# │    └─Linear: 2-10                           [32, 1000]                513,000
# ├─Linear: 1-2                                 [32, 3]                   3,003
# ├─Softmax: 1-3                                [32, 3]                   --
# ===============================================================================================
# Total params: 11,686,243
# Trainable params: 11,686,243
# Non-trainable params: 0
# Total mult-adds (Units.GIGABYTES): 1.07
# ===============================================================================================
# Input size (MB): 0.10
# Forward/backward pass size (MB): 22.28
# Params size (MB): 46.74
# Estimated Total Size (MB): 69.12
# ===============================================================================================

# %%
# 3. Shared backbone & Non-Shared head

model_case_3 = define_model(temp_backbone_name, case_name='3', device=device)
print(summary(model=model_case_3, input_size=input_size))
# Out:
# ===============================================================================================
# Layer (type:depth-idx)                        Output Shape              Param #
# ===============================================================================================
# CNN_CASE_3                                    [32, 2]                   --
# ├─ResNet: 1-1                                 [32, 1000]                --
# │    └─Conv2d: 2-1                            [32, 64, 14, 14]          3,136
# │    └─BatchNorm2d: 2-2                       [32, 64, 14, 14]          128
# │    └─ReLU: 2-3                              [32, 64, 14, 14]          --
# │    └─MaxPool2d: 2-4                         [32, 64, 7, 7]            --
# │    └─Sequential: 2-5                        [32, 64, 7, 7]            --
# │    │    └─BasicBlock: 3-1                   [32, 64, 7, 7]            73,984
# │    │    └─BasicBlock: 3-2                   [32, 64, 7, 7]            73,984
# │    └─Sequential: 2-6                        [32, 128, 4, 4]           --
# │    │    └─BasicBlock: 3-3                   [32, 128, 4, 4]           230,144
# │    │    └─BasicBlock: 3-4                   [32, 128, 4, 4]           295,424
# │    └─Sequential: 2-7                        [32, 256, 2, 2]           --
# │    │    └─BasicBlock: 3-5                   [32, 256, 2, 2]           919,040
# │    │    └─BasicBlock: 3-6                   [32, 256, 2, 2]           1,180,672
# │    └─Sequential: 2-8                        [32, 512, 1, 1]           --
# │    │    └─BasicBlock: 3-7                   [32, 512, 1, 1]           3,673,088
# │    │    └─BasicBlock: 3-8                   [32, 512, 1, 1]           4,720,640
# │    └─AdaptiveAvgPool2d: 2-9                 [32, 512, 1, 1]           --
# │    └─Linear: 2-10                           [32, 1000]                513,000
# ├─Linear: 1-2                                 [32, 2]                   2,002
# ├─Linear: 1-3                                 [32, 2]                   2,002
# ├─Softmax: 1-4                                [32, 2]                   --
# ├─Softmax: 1-5                                [32, 2]                   --
# ===============================================================================================
# Total params: 11,687,244
# Trainable params: 11,687,244
# Non-trainable params: 0
# Total mult-adds (Units.GIGABYTES): 1.07
# ===============================================================================================
# Input size (MB): 0.10
# Forward/backward pass size (MB): 22.28
# Params size (MB): 46.75
# Estimated Total Size (MB): 69.13
# ===============================================================================================

# %%
# 4. Non-Shared backbone & Non-Shared head (4-1)

model_case_4_1 = define_model(temp_backbone_name, case_name='4_1', device=device)
print(summary(model=model_case_4_1, input_size=input_size))
# Out:
# ===============================================================================================
# Layer (type:depth-idx)                        Output Shape              Param #
# ===============================================================================================
# CNN_CASE_4_1                                  [32, 2]                   --
# ├─ResNet: 1-1                                 [32, 1000]                --
# │    └─Conv2d: 2-1                            [32, 64, 14, 14]          3,136
# │    └─BatchNorm2d: 2-2                       [32, 64, 14, 14]          128
# │    └─ReLU: 2-3                              [32, 64, 14, 14]          --
# │    └─MaxPool2d: 2-4                         [32, 64, 7, 7]            --
# │    └─Sequential: 2-5                        [32, 64, 7, 7]            --
# │    │    └─BasicBlock: 3-1                   [32, 64, 7, 7]            73,984
# │    │    └─BasicBlock: 3-2                   [32, 64, 7, 7]            73,984
# │    └─Sequential: 2-6                        [32, 128, 4, 4]           --
# │    │    └─BasicBlock: 3-3                   [32, 128, 4, 4]           230,144
# │    │    └─BasicBlock: 3-4                   [32, 128, 4, 4]           295,424
# │    └─Sequential: 2-7                        [32, 256, 2, 2]           --
# │    │    └─BasicBlock: 3-5                   [32, 256, 2, 2]           919,040
# │    │    └─BasicBlock: 3-6                   [32, 256, 2, 2]           1,180,672
# │    └─Sequential: 2-8                        [32, 512, 1, 1]           --
# │    │    └─BasicBlock: 3-7                   [32, 512, 1, 1]           3,673,088
# │    │    └─BasicBlock: 3-8                   [32, 512, 1, 1]           4,720,640
# │    └─AdaptiveAvgPool2d: 2-9                 [32, 512, 1, 1]           --
# │    └─Linear: 2-10                           [32, 1000]                513,000
# ├─ResNet: 1-2                                 [32, 1000]                --
# │    └─Conv2d: 2-11                           [32, 64, 14, 14]          3,136
# │    └─BatchNorm2d: 2-12                      [32, 64, 14, 14]          128
# │    └─ReLU: 2-13                             [32, 64, 14, 14]          --
# │    └─MaxPool2d: 2-14                        [32, 64, 7, 7]            --
# │    └─Sequential: 2-15                       [32, 64, 7, 7]            --
# │    │    └─BasicBlock: 3-9                   [32, 64, 7, 7]            73,984
# │    │    └─BasicBlock: 3-10                  [32, 64, 7, 7]            73,984
# │    └─Sequential: 2-16                       [32, 128, 4, 4]           --
# │    │    └─BasicBlock: 3-11                  [32, 128, 4, 4]           230,144
# │    │    └─BasicBlock: 3-12                  [32, 128, 4, 4]           295,424
# │    └─Sequential: 2-17                       [32, 256, 2, 2]           --
# │    │    └─BasicBlock: 3-13                  [32, 256, 2, 2]           919,040
# │    │    └─BasicBlock: 3-14                  [32, 256, 2, 2]           1,180,672
# │    └─Sequential: 2-18                       [32, 512, 1, 1]           --
# │    │    └─BasicBlock: 3-15                  [32, 512, 1, 1]           3,673,088
# │    │    └─BasicBlock: 3-16                  [32, 512, 1, 1]           4,720,640
# │    └─AdaptiveAvgPool2d: 2-19                [32, 512, 1, 1]           --
# │    └─Linear: 2-20                           [32, 1000]                513,000
# ├─Linear: 1-3                                 [32, 2]                   4,002
# ├─Linear: 1-4                                 [32, 2]                   4,002
# ├─Softmax: 1-5                                [32, 2]                   --
# ├─Softmax: 1-6                                [32, 2]                   --
# ===============================================================================================
# Total params: 23,374,484
# Trainable params: 23,374,484
# Non-trainable params: 0
# Total mult-adds (Units.GIGABYTES): 2.15
# ===============================================================================================
# Input size (MB): 0.10
# Forward/backward pass size (MB): 44.55
# Params size (MB): 93.50
# Estimated Total Size (MB): 138.15
# ===============================================================================================

# %%
# 5. Non-Shared backbone & Non-Shared head (4-2)

model_case_4_2 = define_model(temp_backbone_name, case_name='4_2', device=device)
print(summary(model=model_case_4_2, input_size=input_size))
# Out:
# ===============================================================================================
# Layer (type:depth-idx)                        Output Shape              Param #
# ===============================================================================================
# CNN_CASE_4_2                                  [32, 2]                   --
# ├─ResNet: 1-1                                 [32, 1000]                --
# │    └─Conv2d: 2-1                            [32, 64, 14, 14]          3,136
# │    └─BatchNorm2d: 2-2                       [32, 64, 14, 14]          128
# │    └─ReLU: 2-3                              [32, 64, 14, 14]          --
# │    └─MaxPool2d: 2-4                         [32, 64, 7, 7]            --
# │    └─Sequential: 2-5                        [32, 64, 7, 7]            --
# │    │    └─BasicBlock: 3-1                   [32, 64, 7, 7]            73,984
# │    │    └─BasicBlock: 3-2                   [32, 64, 7, 7]            73,984
# │    └─Sequential: 2-6                        [32, 128, 4, 4]           --
# │    │    └─BasicBlock: 3-3                   [32, 128, 4, 4]           230,144
# │    │    └─BasicBlock: 3-4                   [32, 128, 4, 4]           295,424
# │    └─Sequential: 2-7                        [32, 256, 2, 2]           --
# │    │    └─BasicBlock: 3-5                   [32, 256, 2, 2]           919,040
# │    │    └─BasicBlock: 3-6                   [32, 256, 2, 2]           1,180,672
# │    └─Sequential: 2-8                        [32, 512, 1, 1]           --
# │    │    └─BasicBlock: 3-7                   [32, 512, 1, 1]           3,673,088
# │    │    └─BasicBlock: 3-8                   [32, 512, 1, 1]           4,720,640
# │    └─AdaptiveAvgPool2d: 2-9                 [32, 512, 1, 1]           --
# │    └─Linear: 2-10                           [32, 1000]                513,000
# ├─ResNet: 1-2                                 [32, 1000]                --
# │    └─Conv2d: 2-11                           [32, 64, 14, 14]          3,136
# │    └─BatchNorm2d: 2-12                      [32, 64, 14, 14]          128
# │    └─ReLU: 2-13                             [32, 64, 14, 14]          --
# │    └─MaxPool2d: 2-14                        [32, 64, 7, 7]            --
# │    └─Sequential: 2-15                       [32, 64, 7, 7]            --
# │    │    └─BasicBlock: 3-9                   [32, 64, 7, 7]            73,984
# │    │    └─BasicBlock: 3-10                  [32, 64, 7, 7]            73,984
# │    └─Sequential: 2-16                       [32, 128, 4, 4]           --
# │    │    └─BasicBlock: 3-11                  [32, 128, 4, 4]           230,144
# │    │    └─BasicBlock: 3-12                  [32, 128, 4, 4]           295,424
# │    └─Sequential: 2-17                       [32, 256, 2, 2]           --
# │    │    └─BasicBlock: 3-13                  [32, 256, 2, 2]           919,040
# │    │    └─BasicBlock: 3-14                  [32, 256, 2, 2]           1,180,672
# │    └─Sequential: 2-18                       [32, 512, 1, 1]           --
# │    │    └─BasicBlock: 3-15                  [32, 512, 1, 1]           3,673,088
# │    │    └─BasicBlock: 3-16                  [32, 512, 1, 1]           4,720,640
# │    └─AdaptiveAvgPool2d: 2-19                [32, 512, 1, 1]           --
# │    └─Linear: 2-20                           [32, 1000]                513,000
# ├─Linear: 1-3                                 [32, 2]                   2,002
# ├─Linear: 1-4                                 [32, 2]                   2,002
# ├─Softmax: 1-5                                [32, 2]                   --
# ├─Softmax: 1-6                                [32, 2]                   --
# ===============================================================================================
# Total params: 23,370,484
# Trainable params: 23,370,484
# Non-trainable params: 0
# Total mult-adds (Units.GIGABYTES): 2.15
# ===============================================================================================
# Input size (MB): 0.10
# Forward/backward pass size (MB): 44.55
# Params size (MB): 93.48
# Estimated Total Size (MB): 138.14
# ===============================================================================================

# %% [markdown]
# **6. 데이터셋 분리**
#
# * Train Data -> Train Data + Valid Data

# %%
# dataset size

num_tv = sum(train_subset_class_counts)
num_valid = int(0.1 * num_tv)
num_train = num_tv - num_valid

# %%
# 데이터셋 분리

from torch.utils.data import random_split

train_dataset, valid_dataset = random_split(train_subset, [num_train, num_valid])

# %%
# {0,1,2} -> {6,8,9} Mapping 된 DataLoader 생성

from torch.utils.data import Dataset

class MappedDataset(Dataset):
    def __init__(self, dataset):
        self.dataset = dataset

    def __len__(self):
        return len(self.dataset)

    def __getitem__(self, idx):
        img, target = self.dataset[idx]
        target_mapping = {6: 0, 8: 1, 9: 2}
        target = target_mapping[target]

        return img, target

# %%
# DataLoader 생성

train_dataset_loader = DataLoader(MappedDataset(train_dataset),
                                  batch_size=BATCH_SIZE,
                                  shuffle=True)

valid_dataset_loader = DataLoader(MappedDataset(valid_dataset),
                                  batch_size=BATCH_SIZE,
                                  shuffle=False)

test_dataset_loader = DataLoader(MappedDataset(test_subset),
                                 batch_size=BATCH_SIZE,
                                 shuffle=False)

# %%
# {6,8} vs. {9} / {6,9} vs. {8} Split 된 DataLoader 생성

class DualOutputDataset(Dataset):
    def __init__(self, dataset):
        self.dataset = dataset

    def __len__(self):
        return len(self.dataset)

    def __getitem__(self, idx):
        img, target = self.dataset[idx]
        target1_mapping = {6: 0, 8: 0, 9: 1}
        target2_mapping = {6: 0, 8: 1, 9: 0}

        target1 = target1_mapping[target]
        target2 = target2_mapping[target]

        return img, [target1, target2]

# %%
# Dual Output Dataset 생성

train_01_02_dataset_loader = DataLoader(DualOutputDataset(train_dataset),
                                        batch_size=BATCH_SIZE,
                                        shuffle=True)

valid_01_02_dataset_loader = DataLoader(DualOutputDataset(valid_dataset),
                                        batch_size=BATCH_SIZE,
                                        shuffle=False)

test_01_02_dataset_loader = DataLoader(DualOutputDataset(test_subset),
                                       batch_size=BATCH_SIZE,
                                       shuffle=False)

# %% [markdown]
# **7. 모델 학습 함수 정의**

# %%
MAX_EPOCHS = 9999
EARLY_STOPPING_ROUNDS = 20  # Early Stopping Patience (epochs)

# %%
# dual labels -> PyTorch tensor

def convert_to_tensor(labels):
    labels[0] = list(labels[0])
    labels[1] = list(labels[1])
    labels_tensor = torch.tensor(labels)
    labels_tensor = labels_tensor.transpose(0, 1)

    return labels_tensor

# %%
# 모델 학습 실시

# args :
# - model           : 학습할 모델
# - train_loader    : Training Data Loader
# - train_loss_list : 각 epoch 에서의 train loss 기록
# - is_dual_head    : 신경망 출력값, 즉 MLP Head 가 2개인지의 여부

# returns :
# - train_loss : 모델의 Train Loss

def run_train(model, train_loader, train_loss_list, is_dual_head, verbose):
    model.train()
    train_loss = 0.0
    total_data = 0
    train_idx = 0

    for images, labels in train_loader:
        if is_dual_head:
            labels = convert_to_tensor(labels)
        images, labels = images.to(device), labels.to(device)

        # train 실시
        model.optimizer.zero_grad()
        outputs = model(images)

        if is_dual_head:
            loss1 = nn.CrossEntropyLoss(reduction='sum')(outputs[0], labels[:, 0])
            loss2 = nn.CrossEntropyLoss(reduction='sum')(outputs[1], labels[:, 1])
            loss = loss1 + loss2
        else:
            loss = nn.CrossEntropyLoss(reduction='sum')(outputs, labels)

        loss.backward()
        model.optimizer.step()

        train_loss += loss.item()
        total_data += labels.size(0)
        train_idx += 1

        if verbose:
            if train_idx % 20 == 0:
                print(f'idx: {train_idx}, loss for current batch: {loss.item() / labels.size(0):.6f}')

    train_loss_list.append(train_loss / total_data)
    return train_loss_list[-1]

# %%
import time

# 모델 validation / test 실시

# args :
# - model                : validation/test 할 모델
# - valid_or_test_loader : validation/test Data Loader
# - is_dual_head         : 신경망 출력값, 즉 MLP Head 가 2개인지의 여부

# returns :
# - accuracy       : 모델의 validation/test 정확도
# - inference_time : inference 시간 (seconds)

def run_valid_or_test(model, valid_or_test_loader, is_dual_head):
    model.eval()
    correct, total_data, valid_loss = 0, 0, 0.0
    inference_time_sum = 0.0
    valid_test_idx = 0

    with torch.no_grad():
        for images, labels in valid_or_test_loader:
            if is_dual_head:
                labels = convert_to_tensor(labels)
            images, labels = images.to(device), labels.to(device)

            start_at = time.time()
            outputs = model(images)
            inference_time_sum += time.time() - start_at

            # validation/test 실시 및 Loss 계산 & 정확도 측정
            if is_dual_head:
                _, predicted_1 = torch.max(outputs[0], 1)
                _, predicted_2 = torch.max(outputs[1], 1)
                correct += ((predicted_1 == labels[:, 0]) & (predicted_2 == labels[:, 1])).sum().item()

                loss1 = nn.CrossEntropyLoss(reduction='sum')(outputs[0], labels[:, 0])
                loss2 = nn.CrossEntropyLoss(reduction='sum')(outputs[1], labels[:, 1])
                loss = loss1 + loss2

            else:
                _, predicted = torch.max(outputs, 1)
                correct += (predicted == labels).sum().item()
                loss = nn.CrossEntropyLoss(reduction='sum')(outputs, labels)

            valid_loss += loss.item()
            total_data += labels.size(0)
            valid_test_idx += 1

    accuracy = correct / total_data
    inference_time = inference_time_sum / valid_test_idx
    loss = valid_loss / total_data

    return accuracy, loss, inference_time

# %%
# 모델 학습 및 validation 전체 프로세스

# args :
# - model         : 학습할 모델
# - train_loader  : Training Data Loader
# - valid_loader  : Valid Data Loader
# - test_loader   : Test Data Loader
# - backbone_name : Backbone 모델 이름 ('resnet18', 'resnet34' or 'resnet50')
# - case_name     : 모델 구조 case 이름 ('1', '2', '3', '4_1' or '4_2')
# - verbose       : 학습 중 프로세스 출력 여부

# returns :
# - final_acc      : 최종 Accuracy
# - inference_time : inference 시간 (seconds)

def run_model_common(model, train_loader, valid_loader, test_loader,
                     backbone_name, case_name, verbose=False):

    train_loss_list = []        # train loss
    min_valid_loss = 999.9      # min validation loss
    best_valid_loss_epoch = -1  # valid_loss 가 가장 낮았던 epoch
    best_epoch_model = None     # valid_loss 가 가장 낮았던 epoch 의 모델

    is_dual_head = case_name in ['3', '4_1', '4_2']

    # 1. 학습 실시
    for epoch in range(MAX_EPOCHS):

        # 1-1. train model
        train_loss = run_train(model,
                               train_loader,
                               train_loss_list,
                               is_dual_head,
                               verbose=(verbose and epoch == 0))

        # 1-2. validate model (with VALID SET)
        valid_acc, valid_loss, _ = run_valid_or_test(model, valid_loader, is_dual_head)

        # 1-3. Early Stopping 처리 (overfitting 방지)
        if valid_loss < min_valid_loss - 1e-6:
            min_valid_loss = valid_loss
            best_valid_loss_epoch = epoch

            best_epoch_model = define_model(backbone_name, case_name, device)
            best_epoch_model.load_state_dict(model.state_dict())

            if verbose:
                print('best model updated')

        if epoch - best_valid_loss_epoch >= EARLY_STOPPING_ROUNDS:
            break

        # 1-4. 결과 출력
        if verbose:
            print(f"Epoch {epoch+1}, Loss: train={train_loss:.4f} valid={valid_loss:.4f}, Acc: valid={valid_acc:.4f}")

    # check best-epoch model correctly loaded
    _, checked_loss, _ = run_valid_or_test(best_epoch_model, valid_loader, is_dual_head)

    if verbose:
        print(f"Best Epoch: {best_valid_loss_epoch}, Best Valid Loss: {min_valid_loss}")
        print(f"Valid Loss (with Epoch valid set) on Loaded Best Model: {checked_loss}")

    assert abs(min_valid_loss - checked_loss) < 1e-6

    # 2. test best-epoch model (with TEST SET)
    final_acc, _, inference_time = run_valid_or_test(best_epoch_model, test_loader, is_dual_head)

    if verbose:
        print(f"Final Acc (with TEST set) on Loaded Best Model: {final_acc} (time: {inference_time})")

    return final_acc, inference_time

# %% [markdown]
# **8. 학습 실시**

# %%
print(device)
# Out:
# cuda

# %%
result_dict = {
    'backbone': [],
    'case': [],
    'accuracy': [],
    'inference_time': []
}

dataloader_by_case_name = {
    'dual_head': {
        'train': train_01_02_dataset_loader,
        'valid': valid_01_02_dataset_loader,
        'test': test_01_02_dataset_loader
    },
    'single_head': {
        'train': train_dataset_loader,
        'valid': valid_dataset_loader,
        'test': test_dataset_loader
    }
}

for case_name in ['1', '2', '3', '4_1', '4_2']:
    if case_name in ['3', '4_1', '4_2']:
        head_type = 'dual_head'
    else:
        head_type = 'single_head'

    for backbone_name in ['resnet18', 'resnet34', 'resnet50']:
        print(f'\n=== case={case_name}, backbone={backbone_name} ===')
        model = define_model(backbone_name, case_name, device=device)

        train_loader = dataloader_by_case_name[head_type]['train']
        valid_loader = dataloader_by_case_name[head_type]['valid']
        test_loader = dataloader_by_case_name[head_type]['test']

        final_acc, inference_time = run_model_common(model,
                                                     train_loader=train_loader,
                                                     valid_loader=valid_loader,
                                                     test_loader=test_loader,
                                                     backbone_name=backbone_name,
                                                     case_name=case_name,
                                                     verbose=True)

        result_dict['backbone'].append(backbone_name)
        result_dict['case'].append(case_name)
        result_dict['accuracy'].append(final_acc)
        result_dict['inference_time'].append(inference_time)
# Out:
# === case=1, backbone=resnet18 ===
# best model updated
# Epoch 1, Loss: train=1.0559 valid=1.0599, Acc: valid=0.5455
# best model updated
# Epoch 2, Loss: train=0.7353 valid=1.0407, Acc: valid=0.4545
# Epoch 3, Loss: train=0.6472 valid=1.0518, Acc: valid=0.4545
# Epoch 4, Loss: train=0.5782 valid=1.0562, Acc: valid=0.5455
# Epoch 5, Loss: train=0.5631 valid=1.0445, Acc: valid=0.5455
# best model updated
# Epoch 6, Loss: train=0.5669 valid=1.0121, Acc: valid=0.5455
# best model updated
# Epoch 7, Loss: train=0.5632 valid=0.9463, Acc: valid=0.6364
# best model updated
# Epoch 8, Loss: train=0.5765 valid=0.7875, Acc: valid=0.7273
# best model updated
# Epoch 9, Loss: train=0.5636 valid=0.7027, Acc: valid=0.8182
# best model updated
# Epoch 10, Loss: train=0.5648 valid=0.5951, Acc: valid=1.0000
# best model updated
# Epoch 11, Loss: train=0.5755 valid=0.5674, Acc: valid=1.0000
# Epoch 12, Loss: train=0.5613 valid=0.5968, Acc: valid=1.0000
# Epoch 13, Loss: train=0.5549 valid=0.5756, Acc: valid=1.0000
# Epoch 14, Loss: train=0.5882 valid=0.5833, Acc: valid=1.0000
# best model updated
# Epoch 15, Loss: train=0.5542 valid=0.5607, Acc: valid=1.0000
# Epoch 16, Loss: train=0.5581 valid=0.6241, Acc: valid=0.9091
# Epoch 17, Loss: train=0.5578 valid=0.6326, Acc: valid=0.9091
# Epoch 18, Loss: train=0.5649 valid=0.6375, Acc: valid=0.9091
# Epoch 19, Loss: train=0.5734 valid=0.6360, Acc: valid=0.9091
# Epoch 20, Loss: train=0.5622 valid=0.6389, Acc: valid=0.9091
# Epoch 21, Loss: train=0.5715 valid=0.6356, Acc: valid=0.9091
# Epoch 22, Loss: train=0.5692 valid=0.6438, Acc: valid=0.9091
# Epoch 23, Loss: train=0.5577 valid=0.6513, Acc: valid=0.9091
# Epoch 24, Loss: train=0.5581 valid=0.6665, Acc: valid=0.9091
# Epoch 25, Loss: train=0.5571 valid=0.6444, Acc: valid=0.9091
# Epoch 26, Loss: train=0.5591 valid=0.6389, Acc: valid=0.9091
# Epoch 27, Loss: train=0.5597 valid=0.6411, Acc: valid=0.9091
# Epoch 28, Loss: train=0.5531 valid=0.6410, Acc: valid=0.9091
# Epoch 29, Loss: train=0.5726 valid=0.6391, Acc: valid=0.9091
# Epoch 30, Loss: train=0.5539 valid=0.6429, Acc: valid=0.9091
# Epoch 31, Loss: train=0.5628 valid=0.6399, Acc: valid=0.9091
# Epoch 32, Loss: train=0.5616 valid=0.6435, Acc: valid=0.9091
# Epoch 33, Loss: train=0.5618 valid=0.6445, Acc: valid=0.9091
# Epoch 34, Loss: train=0.5531 valid=0.6506, Acc: valid=0.9091
# Best Epoch: 14, Best Valid Loss: 0.5606564608487216
# Valid Loss (with Epoch valid set) on Loaded Best Model: 0.5606564608487216
# Final Acc (with TEST set) on Loaded Best Model: 0.81468888133288 (time: 0.007934285246807596)
#
# === case=1, backbone=resnet34 ===
# best model updated
# Epoch 1, Loss: train=1.0615 valid=1.1059, Acc: valid=0.3636
# Epoch 2, Loss: train=0.7934 valid=1.1622, Acc: valid=0.3636
# Epoch 3, Loss: train=0.6941 valid=1.3639, Acc: valid=0.1818
# Epoch 4, Loss: train=0.6550 valid=1.3251, Acc: valid=0.1818
# Epoch 5, Loss: train=0.6035 valid=1.2608, Acc: valid=0.1818
# best model updated
# Epoch 6, Loss: train=0.5854 valid=1.1016, Acc: valid=0.3636
# Epoch 7, Loss: train=0.5693 valid=1.1087, Acc: valid=0.3636
# best model updated
# Epoch 8, Loss: train=0.5604 valid=0.9578, Acc: valid=0.5455
# best model updated
# Epoch 9, Loss: train=0.5620 valid=0.7904, Acc: valid=0.8182
# best model updated
# Epoch 10, Loss: train=0.5680 valid=0.6782, Acc: valid=0.9091
# best model updated
# Epoch 11, Loss: train=0.5721 valid=0.6484, Acc: valid=1.0000
# Epoch 12, Loss: train=0.5673 valid=0.6526, Acc: valid=0.9091
# Epoch 13, Loss: train=0.5852 valid=0.6799, Acc: valid=0.9091
# Epoch 14, Loss: train=0.5670 valid=0.6771, Acc: valid=0.9091
# Epoch 15, Loss: train=0.5547 valid=0.7318, Acc: valid=0.7273
# Epoch 16, Loss: train=0.5561 valid=0.7148, Acc: valid=0.8182
# Epoch 17, Loss: train=0.5654 valid=0.6936, Acc: valid=0.8182
# Epoch 18, Loss: train=0.5571 valid=0.6710, Acc: valid=0.9091
# best model updated
# Epoch 19, Loss: train=0.5628 valid=0.6484, Acc: valid=0.9091
# best model updated
# Epoch 20, Loss: train=0.5856 valid=0.6369, Acc: valid=0.9091
# best model updated
# Epoch 21, Loss: train=0.5608 valid=0.6192, Acc: valid=0.9091
# Epoch 22, Loss: train=0.5569 valid=0.6670, Acc: valid=0.8182
# Epoch 23, Loss: train=0.5784 valid=0.6401, Acc: valid=0.9091
# Epoch 24, Loss: train=0.5656 valid=0.6212, Acc: valid=0.9091
# Epoch 25, Loss: train=0.5562 valid=0.6803, Acc: valid=0.8182
# Epoch 26, Loss: train=0.5826 valid=0.6846, Acc: valid=0.8182
# Epoch 27, Loss: train=0.5577 valid=0.6719, Acc: valid=0.9091
# Epoch 28, Loss: train=0.5616 valid=0.6934, Acc: valid=0.8182
# Epoch 29, Loss: train=0.5825 valid=0.7157, Acc: valid=0.8182
# Epoch 30, Loss: train=0.5614 valid=0.7247, Acc: valid=0.8182
# Epoch 31, Loss: train=0.5542 valid=0.7157, Acc: valid=0.8182
# Epoch 32, Loss: train=0.5768 valid=0.6424, Acc: valid=0.9091
# Epoch 33, Loss: train=0.5609 valid=0.6648, Acc: valid=0.9091
# best model updated
# Epoch 34, Loss: train=0.5731 valid=0.6045, Acc: valid=1.0000
# Epoch 35, Loss: train=0.5642 valid=0.6534, Acc: valid=0.9091
# Epoch 36, Loss: train=0.5535 valid=0.6739, Acc: valid=0.8182
# Epoch 37, Loss: train=0.5619 valid=0.6115, Acc: valid=0.9091
# Epoch 38, Loss: train=0.5551 valid=0.6045, Acc: valid=0.9091
# best model updated
# Epoch 39, Loss: train=0.5746 valid=0.5893, Acc: valid=0.9091
# best model updated
# Epoch 40, Loss: train=0.5610 valid=0.5561, Acc: valid=1.0000
# Epoch 41, Loss: train=0.5617 valid=0.5616, Acc: valid=1.0000
# Epoch 42, Loss: train=0.5792 valid=0.5620, Acc: valid=1.0000
# best model updated
# Epoch 43, Loss: train=0.5625 valid=0.5544, Acc: valid=1.0000
# Epoch 44, Loss: train=0.5570 valid=0.5551, Acc: valid=1.0000
# Epoch 45, Loss: train=0.5608 valid=0.5608, Acc: valid=1.0000
# best model updated
# Epoch 46, Loss: train=0.5733 valid=0.5523, Acc: valid=1.0000
# Epoch 47, Loss: train=0.5620 valid=0.5548, Acc: valid=1.0000
# best model updated
# Epoch 48, Loss: train=0.5798 valid=0.5520, Acc: valid=1.0000
# Epoch 49, Loss: train=0.5685 valid=0.5524, Acc: valid=1.0000
# Epoch 50, Loss: train=0.5616 valid=0.5590, Acc: valid=1.0000
# Epoch 51, Loss: train=0.5858 valid=0.5545, Acc: valid=1.0000
# best model updated
# Epoch 52, Loss: train=0.5552 valid=0.5515, Acc: valid=1.0000
# Epoch 53, Loss: train=0.5620 valid=0.5516, Acc: valid=1.0000
# Epoch 54, Loss: train=0.5745 valid=0.5523, Acc: valid=1.0000
# Epoch 55, Loss: train=0.5526 valid=0.5518, Acc: valid=1.0000
# best model updated
# Epoch 56, Loss: train=0.5583 valid=0.5515, Acc: valid=1.0000
# Epoch 57, Loss: train=0.5602 valid=0.5515, Acc: valid=1.0000
# Epoch 58, Loss: train=0.5658 valid=0.5521, Acc: valid=1.0000
# Epoch 59, Loss: train=0.5715 valid=0.5572, Acc: valid=1.0000
# Epoch 60, Loss: train=0.5615 valid=0.5582, Acc: valid=1.0000
# Epoch 61, Loss: train=0.5575 valid=0.5540, Acc: valid=1.0000
# Epoch 62, Loss: train=0.5640 valid=0.5523, Acc: valid=1.0000
# Epoch 63, Loss: train=0.5670 valid=0.5516, Acc: valid=1.0000
# Epoch 64, Loss: train=0.5518 valid=0.5517, Acc: valid=1.0000
# Epoch 65, Loss: train=0.5617 valid=0.5561, Acc: valid=1.0000
# Epoch 66, Loss: train=0.5703 valid=0.5706, Acc: valid=1.0000
# Epoch 67, Loss: train=0.5675 valid=0.6484, Acc: valid=0.8182
# Epoch 68, Loss: train=0.5517 valid=0.6917, Acc: valid=0.8182
# Epoch 69, Loss: train=0.5822 valid=0.5662, Acc: valid=1.0000
# Epoch 70, Loss: train=0.5738 valid=0.5551, Acc: valid=1.0000
# Epoch 71, Loss: train=0.5670 valid=0.5608, Acc: valid=1.0000
# Epoch 72, Loss: train=0.5915 valid=0.6379, Acc: valid=0.9091
# Epoch 73, Loss: train=0.5560 valid=0.6398, Acc: valid=0.9091
# Epoch 74, Loss: train=0.5592 valid=0.6401, Acc: valid=0.9091
# Epoch 75, Loss: train=0.5775 valid=0.6413, Acc: valid=0.9091
# Best Epoch: 55, Best Valid Loss: 0.5514772588556464
# Valid Loss (with Epoch valid set) on Loaded Best Model: 0.5514772588556464
# Final Acc (with TEST set) on Loaded Best Model: 0.8167290037402244 (time: 0.0084601614786231)
#
# === case=1, backbone=resnet50 ===
# best model updated
# Epoch 1, Loss: train=1.1376 valid=1.0992, Acc: valid=0.3636
# Epoch 2, Loss: train=0.8573 valid=1.1156, Acc: valid=0.4545
# Epoch 3, Loss: train=0.6910 valid=1.3139, Acc: valid=0.1818
# Epoch 4, Loss: train=0.6342 valid=1.2582, Acc: valid=0.1818
# Epoch 5, Loss: train=0.6450 valid=1.2865, Acc: valid=0.1818
# Epoch 6, Loss: train=0.5874 valid=1.2951, Acc: valid=0.1818
# Epoch 7, Loss: train=0.5642 valid=1.2427, Acc: valid=0.2727
# Epoch 8, Loss: train=0.5926 valid=1.2607, Acc: valid=0.1818
# Epoch 9, Loss: train=0.5714 valid=1.1230, Acc: valid=0.4545
# best model updated
# Epoch 10, Loss: train=0.5958 valid=1.0986, Acc: valid=0.4545
# best model updated
# Epoch 11, Loss: train=0.5869 valid=0.9379, Acc: valid=0.6364
# best model updated
# Epoch 12, Loss: train=0.5705 valid=0.7719, Acc: valid=0.8182
# best model updated
# Epoch 13, Loss: train=0.5757 valid=0.7421, Acc: valid=0.8182
# best model updated
# Epoch 14, Loss: train=0.5766 valid=0.7017, Acc: valid=0.8182
# best model updated
# Epoch 15, Loss: train=0.5661 valid=0.6879, Acc: valid=0.9091
# best model updated
# Epoch 16, Loss: train=0.6020 valid=0.6585, Acc: valid=0.9091
# Epoch 17, Loss: train=0.5824 valid=0.7204, Acc: valid=0.8182
# Epoch 18, Loss: train=0.5729 valid=0.7378, Acc: valid=0.8182
# Epoch 19, Loss: train=0.5783 valid=0.6666, Acc: valid=0.9091
# best model updated
# Epoch 20, Loss: train=0.5884 valid=0.6273, Acc: valid=0.9091
# best model updated
# Epoch 21, Loss: train=0.5805 valid=0.6116, Acc: valid=0.9091
# Epoch 22, Loss: train=0.5635 valid=0.6162, Acc: valid=0.9091
# Epoch 23, Loss: train=0.5652 valid=0.6361, Acc: valid=0.9091
# Epoch 24, Loss: train=0.5753 valid=0.6447, Acc: valid=0.9091
# Epoch 25, Loss: train=0.5586 valid=0.6462, Acc: valid=0.9091
# Epoch 26, Loss: train=0.5645 valid=0.6390, Acc: valid=0.9091
# Epoch 27, Loss: train=0.5623 valid=0.6145, Acc: valid=0.9091
# Epoch 28, Loss: train=0.5630 valid=0.6709, Acc: valid=0.8182
# Epoch 29, Loss: train=0.5757 valid=0.6136, Acc: valid=0.9091
# best model updated
# Epoch 30, Loss: train=0.5745 valid=0.6005, Acc: valid=0.9091
# Epoch 31, Loss: train=0.5551 valid=0.6086, Acc: valid=0.9091
# best model updated
# Epoch 32, Loss: train=0.5723 valid=0.5550, Acc: valid=1.0000
# Epoch 33, Loss: train=0.5560 valid=0.5572, Acc: valid=1.0000
# Epoch 34, Loss: train=0.5811 valid=0.6450, Acc: valid=0.9091
# best model updated
# Epoch 35, Loss: train=0.5882 valid=0.5522, Acc: valid=1.0000
# Epoch 36, Loss: train=0.5541 valid=0.6340, Acc: valid=0.9091
# Epoch 37, Loss: train=0.5529 valid=0.6423, Acc: valid=0.9091
# Epoch 38, Loss: train=0.5626 valid=0.6415, Acc: valid=0.9091
# Epoch 39, Loss: train=0.5571 valid=0.6424, Acc: valid=0.9091
# Epoch 40, Loss: train=0.5563 valid=0.6424, Acc: valid=0.9091
# Epoch 41, Loss: train=0.5900 valid=0.6402, Acc: valid=0.9091
# Epoch 42, Loss: train=0.5690 valid=0.6422, Acc: valid=0.9091
# Epoch 43, Loss: train=0.5730 valid=0.6372, Acc: valid=0.9091
# Epoch 44, Loss: train=0.5663 valid=0.6527, Acc: valid=0.9091
# Epoch 45, Loss: train=0.5617 valid=0.6413, Acc: valid=0.9091
# Epoch 46, Loss: train=0.5779 valid=0.6405, Acc: valid=0.9091
# Epoch 47, Loss: train=0.5851 valid=0.6427, Acc: valid=0.9091
# Epoch 48, Loss: train=0.5754 valid=0.6435, Acc: valid=0.9091
# Epoch 49, Loss: train=0.5574 valid=0.5852, Acc: valid=1.0000
# Epoch 50, Loss: train=0.5983 valid=0.5975, Acc: valid=1.0000
# Epoch 51, Loss: train=0.5802 valid=0.5574, Acc: valid=1.0000
# best model updated
# Epoch 52, Loss: train=0.5671 valid=0.5515, Acc: valid=1.0000
# Epoch 53, Loss: train=0.5614 valid=0.5516, Acc: valid=1.0000
# Epoch 54, Loss: train=0.5731 valid=0.5524, Acc: valid=1.0000
# Epoch 55, Loss: train=0.5564 valid=0.5516, Acc: valid=1.0000
# best model updated
# Epoch 56, Loss: train=0.5654 valid=0.5515, Acc: valid=1.0000
# Epoch 57, Loss: train=0.5776 valid=0.5515, Acc: valid=1.0000
# Epoch 58, Loss: train=0.5726 valid=0.5557, Acc: valid=1.0000
# Epoch 59, Loss: train=0.5736 valid=0.5515, Acc: valid=1.0000
# Epoch 60, Loss: train=0.5534 valid=0.5568, Acc: valid=1.0000
# Epoch 61, Loss: train=0.5721 valid=0.5519, Acc: valid=1.0000
# Epoch 62, Loss: train=0.5622 valid=0.5537, Acc: valid=1.0000
# Epoch 63, Loss: train=0.5791 valid=0.5515, Acc: valid=1.0000
# best model updated
# Epoch 64, Loss: train=0.5725 valid=0.5514, Acc: valid=1.0000
# Epoch 65, Loss: train=0.5517 valid=0.5515, Acc: valid=1.0000
# best model updated
# Epoch 66, Loss: train=0.5673 valid=0.5514, Acc: valid=1.0000
# Epoch 67, Loss: train=0.5570 valid=0.5582, Acc: valid=1.0000
# Epoch 68, Loss: train=0.5714 valid=0.5904, Acc: valid=0.9091
# Epoch 69, Loss: train=0.5652 valid=0.6122, Acc: valid=0.9091
# Epoch 70, Loss: train=0.5516 valid=0.6050, Acc: valid=0.9091
# Epoch 71, Loss: train=0.5622 valid=0.5904, Acc: valid=0.9091
# Epoch 72, Loss: train=0.5606 valid=0.6400, Acc: valid=0.9091
# Epoch 73, Loss: train=0.5610 valid=0.6386, Acc: valid=0.9091
# Epoch 74, Loss: train=0.5620 valid=0.5515, Acc: valid=1.0000
# Epoch 75, Loss: train=0.5630 valid=0.5530, Acc: valid=1.0000
# Epoch 76, Loss: train=0.5601 valid=0.5713, Acc: valid=1.0000
# Epoch 77, Loss: train=0.5515 valid=0.5516, Acc: valid=1.0000
# Epoch 78, Loss: train=0.5516 valid=0.5516, Acc: valid=1.0000
# Epoch 79, Loss: train=0.5704 valid=0.5515, Acc: valid=1.0000
# Epoch 80, Loss: train=0.5518 valid=0.5518, Acc: valid=1.0000
# Epoch 81, Loss: train=0.5516 valid=0.5521, Acc: valid=1.0000
# Epoch 82, Loss: train=0.5607 valid=0.5521, Acc: valid=1.0000
# Epoch 83, Loss: train=0.5516 valid=0.5589, Acc: valid=1.0000
# Epoch 84, Loss: train=0.5550 valid=0.5630, Acc: valid=1.0000
# Epoch 85, Loss: train=0.5619 valid=0.5519, Acc: valid=1.0000
# Best Epoch: 65, Best Valid Loss: 0.5514468279751864
# Valid Loss (with Epoch valid set) on Loaded Best Model: 0.5514468279751864
# Final Acc (with TEST set) on Loaded Best Model: 0.8806528391703502 (time: 0.010915942814039148)
#
# === case=2, backbone=resnet18 ===
# best model updated
# Epoch 1, Loss: train=1.0684 valid=1.1419, Acc: valid=0.1818
# Epoch 2, Loss: train=0.7738 valid=1.1469, Acc: valid=0.1818
# best model updated
# Epoch 3, Loss: train=0.6524 valid=1.1338, Acc: valid=0.1818
# best model updated
# Epoch 4, Loss: train=0.6058 valid=1.0981, Acc: valid=0.3636
# Epoch 5, Loss: train=0.5778 valid=1.1245, Acc: valid=0.2727
# Epoch 6, Loss: train=0.5727 valid=1.1027, Acc: valid=0.3636
# best model updated
# Epoch 7, Loss: train=0.5614 valid=1.0789, Acc: valid=0.3636
# best model updated
# Epoch 8, Loss: train=0.5657 valid=1.0432, Acc: valid=0.4545
# best model updated
# Epoch 9, Loss: train=0.5628 valid=0.9082, Acc: valid=0.6364
# best model updated
# Epoch 10, Loss: train=0.5665 valid=0.7271, Acc: valid=0.9091
# best model updated
# Epoch 11, Loss: train=0.5653 valid=0.6539, Acc: valid=0.9091
# best model updated
# Epoch 12, Loss: train=0.5638 valid=0.6415, Acc: valid=0.9091
# Epoch 13, Loss: train=0.5718 valid=0.6568, Acc: valid=0.8182
# Epoch 14, Loss: train=0.5640 valid=0.6673, Acc: valid=0.8182
# Epoch 15, Loss: train=0.5645 valid=0.6516, Acc: valid=1.0000
# Epoch 16, Loss: train=0.5545 valid=0.6942, Acc: valid=0.8182
# best model updated
# Epoch 17, Loss: train=0.5697 valid=0.6329, Acc: valid=0.9091
# Epoch 18, Loss: train=0.5660 valid=0.6465, Acc: valid=0.9091
# Epoch 19, Loss: train=0.5615 valid=0.6367, Acc: valid=0.9091
# best model updated
# Epoch 20, Loss: train=0.5661 valid=0.6321, Acc: valid=0.9091
# Epoch 21, Loss: train=0.5674 valid=0.6494, Acc: valid=0.9091
# best model updated
# Epoch 22, Loss: train=0.5641 valid=0.6004, Acc: valid=1.0000
# best model updated
# Epoch 23, Loss: train=0.5584 valid=0.5853, Acc: valid=1.0000
# Epoch 24, Loss: train=0.5628 valid=0.5897, Acc: valid=1.0000
# Epoch 25, Loss: train=0.5630 valid=0.6198, Acc: valid=0.9091
# Epoch 26, Loss: train=0.5731 valid=0.6367, Acc: valid=0.9091
# best model updated
# Epoch 27, Loss: train=0.5615 valid=0.5597, Acc: valid=1.0000
# best model updated
# Epoch 28, Loss: train=0.5625 valid=0.5578, Acc: valid=1.0000
# Epoch 29, Loss: train=0.5519 valid=0.5590, Acc: valid=1.0000
# Epoch 30, Loss: train=0.5639 valid=0.5908, Acc: valid=1.0000
# Epoch 31, Loss: train=0.5623 valid=0.5680, Acc: valid=1.0000
# Epoch 32, Loss: train=0.5748 valid=0.5891, Acc: valid=0.9091
# Epoch 33, Loss: train=0.5622 valid=0.6229, Acc: valid=0.9091
# best model updated
# Epoch 34, Loss: train=0.5586 valid=0.5577, Acc: valid=1.0000
# Epoch 35, Loss: train=0.5582 valid=0.6210, Acc: valid=0.9091
# Epoch 36, Loss: train=0.5821 valid=0.6354, Acc: valid=0.9091
# Epoch 37, Loss: train=0.5796 valid=0.6974, Acc: valid=0.8182
# Epoch 38, Loss: train=0.5624 valid=0.7214, Acc: valid=0.8182
# Epoch 39, Loss: train=0.5530 valid=0.7191, Acc: valid=0.8182
# Epoch 40, Loss: train=0.5658 valid=0.7202, Acc: valid=0.8182
# Epoch 41, Loss: train=0.5706 valid=0.7200, Acc: valid=0.8182
# Epoch 42, Loss: train=0.5593 valid=0.7166, Acc: valid=0.8182
# Epoch 43, Loss: train=0.5578 valid=0.7075, Acc: valid=0.8182
# Epoch 44, Loss: train=0.5635 valid=0.6686, Acc: valid=0.9091
# Epoch 45, Loss: train=0.5614 valid=0.6145, Acc: valid=0.9091
# Epoch 46, Loss: train=0.5593 valid=0.6139, Acc: valid=1.0000
# Epoch 47, Loss: train=0.5708 valid=0.6576, Acc: valid=0.9091
# Epoch 48, Loss: train=0.5723 valid=0.6003, Acc: valid=0.9091
# Epoch 49, Loss: train=0.5663 valid=0.6190, Acc: valid=0.9091
# Epoch 50, Loss: train=0.5672 valid=0.6097, Acc: valid=0.9091
# Epoch 51, Loss: train=0.5555 valid=0.5840, Acc: valid=1.0000
# Epoch 52, Loss: train=0.5640 valid=0.5622, Acc: valid=1.0000
# Epoch 53, Loss: train=0.5623 valid=0.5803, Acc: valid=1.0000
# Best Epoch: 33, Best Valid Loss: 0.5577034516768022
# Valid Loss (with Epoch valid set) on Loaded Best Model: 0.5577034516768022
# Final Acc (with TEST set) on Loaded Best Model: 0.8201292077524651 (time: 0.0024957397709722104)
#
# === case=2, backbone=resnet34 ===
# best model updated
# Epoch 1, Loss: train=1.0787 valid=1.0950, Acc: valid=0.4545
# Epoch 2, Loss: train=0.7971 valid=1.3239, Acc: valid=0.1818
# Epoch 3, Loss: train=0.6784 valid=1.3646, Acc: valid=0.1818
# Epoch 4, Loss: train=0.6392 valid=1.3511, Acc: valid=0.1818
# Epoch 5, Loss: train=0.6241 valid=1.3397, Acc: valid=0.1818
# Epoch 6, Loss: train=0.5914 valid=1.2900, Acc: valid=0.1818
# Epoch 7, Loss: train=0.5764 valid=1.1438, Acc: valid=0.3636
# best model updated
# Epoch 8, Loss: train=0.5733 valid=1.0714, Acc: valid=0.3636
# best model updated
# Epoch 9, Loss: train=0.5566 valid=0.8498, Acc: valid=0.8182
# best model updated
# Epoch 10, Loss: train=0.5557 valid=0.7268, Acc: valid=0.9091
# best model updated
# Epoch 11, Loss: train=0.5560 valid=0.6451, Acc: valid=0.9091
# best model updated
# Epoch 12, Loss: train=0.5778 valid=0.6235, Acc: valid=0.9091
# best model updated
# Epoch 13, Loss: train=0.5632 valid=0.6039, Acc: valid=1.0000
# Epoch 14, Loss: train=0.5567 valid=0.6140, Acc: valid=1.0000
# Epoch 15, Loss: train=0.5620 valid=0.6445, Acc: valid=0.9091
# Epoch 16, Loss: train=0.5703 valid=0.6589, Acc: valid=0.9091
# Epoch 17, Loss: train=0.5617 valid=0.6295, Acc: valid=0.9091
# Epoch 18, Loss: train=0.5738 valid=0.6433, Acc: valid=0.8182
# Epoch 19, Loss: train=0.5563 valid=0.6212, Acc: valid=0.9091
# best model updated
# Epoch 20, Loss: train=0.5540 valid=0.5959, Acc: valid=1.0000
# best model updated
# Epoch 21, Loss: train=0.5555 valid=0.5775, Acc: valid=1.0000
# best model updated
# Epoch 22, Loss: train=0.5696 valid=0.5716, Acc: valid=1.0000
# best model updated
# Epoch 23, Loss: train=0.5524 valid=0.5693, Acc: valid=1.0000
# Epoch 24, Loss: train=0.5688 valid=0.5809, Acc: valid=1.0000
# best model updated
# Epoch 25, Loss: train=0.5627 valid=0.5638, Acc: valid=1.0000
# best model updated
# Epoch 26, Loss: train=0.5531 valid=0.5540, Acc: valid=1.0000
# best model updated
# Epoch 27, Loss: train=0.5629 valid=0.5519, Acc: valid=1.0000
# Epoch 28, Loss: train=0.5527 valid=0.5540, Acc: valid=1.0000
# Epoch 29, Loss: train=0.5696 valid=0.6140, Acc: valid=0.9091
# Epoch 30, Loss: train=0.5604 valid=0.6287, Acc: valid=0.9091
# Epoch 31, Loss: train=0.5566 valid=0.6147, Acc: valid=0.9091
# Epoch 32, Loss: train=0.5545 valid=0.5605, Acc: valid=1.0000
# Epoch 33, Loss: train=0.5709 valid=0.6198, Acc: valid=0.9091
# Epoch 34, Loss: train=0.5744 valid=0.6419, Acc: valid=0.9091
# Epoch 35, Loss: train=0.5650 valid=0.5560, Acc: valid=1.0000
# Epoch 36, Loss: train=0.5678 valid=0.5548, Acc: valid=1.0000
# Epoch 37, Loss: train=0.5552 valid=0.5529, Acc: valid=1.0000
# Epoch 38, Loss: train=0.5625 valid=0.5583, Acc: valid=1.0000
# Epoch 39, Loss: train=0.5706 valid=0.5520, Acc: valid=1.0000
# Epoch 40, Loss: train=0.5531 valid=0.5520, Acc: valid=1.0000
# best model updated
# Epoch 41, Loss: train=0.5758 valid=0.5517, Acc: valid=1.0000
# Epoch 42, Loss: train=0.5716 valid=0.5544, Acc: valid=1.0000
# Epoch 43, Loss: train=0.5629 valid=0.5558, Acc: valid=1.0000
# Epoch 44, Loss: train=0.5618 valid=0.5579, Acc: valid=1.0000
# Epoch 45, Loss: train=0.5821 valid=0.5560, Acc: valid=1.0000
# Epoch 46, Loss: train=0.5659 valid=0.5527, Acc: valid=1.0000
# best model updated
# Epoch 47, Loss: train=0.5551 valid=0.5517, Acc: valid=1.0000
# Epoch 48, Loss: train=0.5770 valid=0.5519, Acc: valid=1.0000
# Epoch 49, Loss: train=0.5885 valid=0.5518, Acc: valid=1.0000
# Epoch 50, Loss: train=0.5742 valid=0.5519, Acc: valid=1.0000
# Epoch 51, Loss: train=0.5880 valid=0.5517, Acc: valid=1.0000
# Epoch 52, Loss: train=0.5564 valid=0.5532, Acc: valid=1.0000
# Epoch 53, Loss: train=0.5637 valid=0.5698, Acc: valid=1.0000
# Epoch 54, Loss: train=0.5536 valid=0.5681, Acc: valid=1.0000
# Epoch 55, Loss: train=0.5551 valid=0.5954, Acc: valid=0.9091
# Epoch 56, Loss: train=0.5522 valid=0.6228, Acc: valid=0.9091
# Epoch 57, Loss: train=0.5597 valid=0.5798, Acc: valid=1.0000
# Epoch 58, Loss: train=0.5718 valid=0.5595, Acc: valid=1.0000
# Epoch 59, Loss: train=0.5573 valid=0.5914, Acc: valid=0.9091
# Epoch 60, Loss: train=0.5516 valid=0.6232, Acc: valid=0.9091
# Epoch 61, Loss: train=0.5645 valid=0.6098, Acc: valid=0.9091
# Epoch 62, Loss: train=0.5663 valid=0.6124, Acc: valid=0.9091
# Epoch 63, Loss: train=0.5608 valid=0.5770, Acc: valid=1.0000
# Epoch 64, Loss: train=0.5844 valid=0.5543, Acc: valid=1.0000
# Epoch 65, Loss: train=0.5728 valid=0.5561, Acc: valid=1.0000
# Epoch 66, Loss: train=0.5588 valid=0.5727, Acc: valid=1.0000
# Best Epoch: 46, Best Valid Loss: 0.5516575033014471
# Valid Loss (with Epoch valid set) on Loaded Best Model: 0.5516575033014471
# Final Acc (with TEST set) on Loaded Best Model: 0.7786467188031282 (time: 0.004177477048790973)
#
# === case=2, backbone=resnet50 ===
# best model updated
# Epoch 1, Loss: train=1.1294 valid=1.0818, Acc: valid=0.4545
# best model updated
# Epoch 2, Loss: train=0.8894 valid=1.0807, Acc: valid=0.4545
# Epoch 3, Loss: train=0.8021 valid=1.0839, Acc: valid=0.4545
# best model updated
# Epoch 4, Loss: train=0.7340 valid=1.0764, Acc: valid=0.4545
# Epoch 5, Loss: train=0.6732 valid=1.0883, Acc: valid=0.4545
# best model updated
# Epoch 6, Loss: train=0.6319 valid=1.0126, Acc: valid=0.4545
# best model updated
# Epoch 7, Loss: train=0.6227 valid=0.9053, Acc: valid=0.6364
# best model updated
# Epoch 8, Loss: train=0.5976 valid=0.8045, Acc: valid=0.6364
# Epoch 9, Loss: train=0.5746 valid=0.8335, Acc: valid=0.6364
# best model updated
# Epoch 10, Loss: train=0.5877 valid=0.7935, Acc: valid=0.7273
# best model updated
# Epoch 11, Loss: train=0.5755 valid=0.7867, Acc: valid=0.7273
# best model updated
# Epoch 12, Loss: train=0.5698 valid=0.7755, Acc: valid=0.8182
# best model updated
# Epoch 13, Loss: train=0.5756 valid=0.7091, Acc: valid=0.8182
# best model updated
# Epoch 14, Loss: train=0.5639 valid=0.6663, Acc: valid=0.9091
# Epoch 15, Loss: train=0.6080 valid=0.7335, Acc: valid=0.8182
# Epoch 16, Loss: train=0.5935 valid=0.7888, Acc: valid=0.7273
# Epoch 17, Loss: train=0.5914 valid=0.7865, Acc: valid=0.7273
# Epoch 18, Loss: train=0.5753 valid=0.7352, Acc: valid=0.8182
# Epoch 19, Loss: train=0.5633 valid=0.7645, Acc: valid=0.8182
# Epoch 20, Loss: train=0.5999 valid=0.7535, Acc: valid=0.8182
# Epoch 21, Loss: train=0.6161 valid=0.7346, Acc: valid=0.8182
# Epoch 22, Loss: train=0.5812 valid=0.7255, Acc: valid=0.8182
# Epoch 23, Loss: train=0.5670 valid=0.8078, Acc: valid=0.7273
# Epoch 24, Loss: train=0.6550 valid=0.7810, Acc: valid=0.7273
# Epoch 25, Loss: train=0.6183 valid=0.7445, Acc: valid=0.8182
# best model updated
# Epoch 26, Loss: train=0.6023 valid=0.6494, Acc: valid=0.9091
# Epoch 27, Loss: train=0.6063 valid=0.7195, Acc: valid=0.8182
# best model updated
# Epoch 28, Loss: train=0.5916 valid=0.6261, Acc: valid=0.9091
# Epoch 29, Loss: train=0.6212 valid=0.6373, Acc: valid=0.9091
# Epoch 30, Loss: train=0.5810 valid=0.6578, Acc: valid=0.9091
# Epoch 31, Loss: train=0.6001 valid=0.6784, Acc: valid=0.9091
# Epoch 32, Loss: train=0.5781 valid=0.7449, Acc: valid=0.8182
# Epoch 33, Loss: train=0.5835 valid=0.6806, Acc: valid=0.8182
# Epoch 34, Loss: train=0.5742 valid=0.6881, Acc: valid=0.8182
# Epoch 35, Loss: train=0.5725 valid=0.6950, Acc: valid=0.8182
# Epoch 36, Loss: train=0.5724 valid=0.6578, Acc: valid=0.9091
# Epoch 37, Loss: train=0.5722 valid=0.6452, Acc: valid=0.9091
# best model updated
# Epoch 38, Loss: train=0.5803 valid=0.6190, Acc: valid=0.9091
# Epoch 39, Loss: train=0.5669 valid=0.6244, Acc: valid=0.9091
# best model updated
# Epoch 40, Loss: train=0.5853 valid=0.5969, Acc: valid=0.9091
# best model updated
# Epoch 41, Loss: train=0.5807 valid=0.5803, Acc: valid=1.0000
# Epoch 42, Loss: train=0.5902 valid=0.7204, Acc: valid=0.8182
# Epoch 43, Loss: train=0.5804 valid=0.7600, Acc: valid=0.8182
# Epoch 44, Loss: train=0.5851 valid=0.6179, Acc: valid=0.9091
# best model updated
# Epoch 45, Loss: train=0.5705 valid=0.5754, Acc: valid=1.0000
# best model updated
# Epoch 46, Loss: train=0.5971 valid=0.5693, Acc: valid=1.0000
# Epoch 47, Loss: train=0.6004 valid=0.5697, Acc: valid=1.0000
# best model updated
# Epoch 48, Loss: train=0.5939 valid=0.5591, Acc: valid=1.0000
# Epoch 49, Loss: train=0.5788 valid=0.5618, Acc: valid=1.0000
# Epoch 50, Loss: train=0.5875 valid=0.5624, Acc: valid=1.0000
# Epoch 51, Loss: train=0.5755 valid=0.5742, Acc: valid=1.0000
# Epoch 52, Loss: train=0.5883 valid=0.5629, Acc: valid=1.0000
# Epoch 53, Loss: train=0.5811 valid=0.5927, Acc: valid=0.9091
# Epoch 54, Loss: train=0.5737 valid=0.6281, Acc: valid=0.9091
# Epoch 55, Loss: train=0.5927 valid=0.6280, Acc: valid=0.9091
# Epoch 56, Loss: train=0.5605 valid=0.6457, Acc: valid=0.9091
# Epoch 57, Loss: train=0.5534 valid=0.6446, Acc: valid=0.9091
# Epoch 58, Loss: train=0.5633 valid=0.6079, Acc: valid=0.9091
# Epoch 59, Loss: train=0.5857 valid=0.5894, Acc: valid=1.0000
# Epoch 60, Loss: train=0.5764 valid=0.6404, Acc: valid=0.9091
# Epoch 61, Loss: train=0.5784 valid=0.6468, Acc: valid=0.9091
# Epoch 62, Loss: train=0.5812 valid=0.6423, Acc: valid=0.9091
# Epoch 63, Loss: train=0.5617 valid=0.6430, Acc: valid=0.9091
# Epoch 64, Loss: train=0.5789 valid=0.6380, Acc: valid=0.9091
# Epoch 65, Loss: train=0.5537 valid=0.7141, Acc: valid=0.8182
# Epoch 66, Loss: train=0.5548 valid=0.6808, Acc: valid=0.9091
# Epoch 67, Loss: train=0.5725 valid=0.6794, Acc: valid=0.8182
# Best Epoch: 47, Best Valid Loss: 0.5591309287331321
# Valid Loss (with Epoch valid set) on Loaded Best Model: 0.5591309287331321
# Final Acc (with TEST set) on Loaded Best Model: 0.7912274736484189 (time: 0.005506245986275051)
#
# === case=3, backbone=resnet18 ===
# best model updated
# Epoch 1, Loss: train=1.3505 valid=1.3204, Acc: valid=0.4545
# best model updated
# Epoch 2, Loss: train=0.9968 valid=1.2847, Acc: valid=0.3636
# best model updated
# Epoch 3, Loss: train=0.8310 valid=1.2790, Acc: valid=0.3636
# best model updated
# Epoch 4, Loss: train=0.7298 valid=1.2694, Acc: valid=0.3636
# Epoch 5, Loss: train=0.6964 valid=1.2748, Acc: valid=0.3636
# best model updated
# Epoch 6, Loss: train=0.6592 valid=1.2589, Acc: valid=0.3636
# best model updated
# Epoch 7, Loss: train=0.6796 valid=1.1774, Acc: valid=0.3636
# best model updated
# Epoch 8, Loss: train=0.6570 valid=1.0929, Acc: valid=0.5455
# best model updated
# Epoch 9, Loss: train=0.6763 valid=1.0725, Acc: valid=0.5455
# best model updated
# Epoch 10, Loss: train=0.6798 valid=0.9894, Acc: valid=0.7273
# best model updated
# Epoch 11, Loss: train=0.6853 valid=0.9264, Acc: valid=0.7273
# best model updated
# Epoch 12, Loss: train=0.6664 valid=0.7893, Acc: valid=0.8182
# best model updated
# Epoch 13, Loss: train=0.6529 valid=0.7491, Acc: valid=0.9091
# best model updated
# Epoch 14, Loss: train=0.6602 valid=0.7190, Acc: valid=1.0000
# Epoch 15, Loss: train=0.6545 valid=0.7322, Acc: valid=0.9091
# best model updated
# Epoch 16, Loss: train=0.6409 valid=0.6817, Acc: valid=1.0000
# Epoch 17, Loss: train=0.6545 valid=0.7046, Acc: valid=1.0000
# Epoch 18, Loss: train=0.6386 valid=0.7430, Acc: valid=0.9091
# Epoch 19, Loss: train=0.6451 valid=0.7097, Acc: valid=1.0000
# Epoch 20, Loss: train=0.6342 valid=0.7019, Acc: valid=1.0000
# Epoch 21, Loss: train=0.6443 valid=0.6925, Acc: valid=1.0000
# Epoch 22, Loss: train=0.6338 valid=0.7251, Acc: valid=0.9091
# best model updated
# Epoch 23, Loss: train=0.6312 valid=0.6568, Acc: valid=1.0000
# best model updated
# Epoch 24, Loss: train=0.6315 valid=0.6517, Acc: valid=1.0000
# Epoch 25, Loss: train=0.6364 valid=0.6749, Acc: valid=1.0000
# Epoch 26, Loss: train=0.6349 valid=0.7063, Acc: valid=1.0000
# best model updated
# Epoch 27, Loss: train=0.6309 valid=0.6430, Acc: valid=1.0000
# Epoch 28, Loss: train=0.6351 valid=0.6571, Acc: valid=1.0000
# Epoch 29, Loss: train=0.6288 valid=0.6910, Acc: valid=1.0000
# Epoch 30, Loss: train=0.6364 valid=0.6961, Acc: valid=1.0000
# best model updated
# Epoch 31, Loss: train=0.6296 valid=0.6352, Acc: valid=1.0000
# best model updated
# Epoch 32, Loss: train=0.6774 valid=0.6330, Acc: valid=1.0000
# best model updated
# Epoch 33, Loss: train=0.6297 valid=0.6312, Acc: valid=1.0000
# Epoch 34, Loss: train=0.6289 valid=0.6377, Acc: valid=1.0000
# Epoch 35, Loss: train=0.6490 valid=0.6331, Acc: valid=1.0000
# best model updated
# Epoch 36, Loss: train=0.6437 valid=0.6310, Acc: valid=1.0000
# Epoch 37, Loss: train=0.6385 valid=0.6344, Acc: valid=1.0000
# Epoch 38, Loss: train=0.6476 valid=0.6310, Acc: valid=1.0000
# Epoch 39, Loss: train=0.6274 valid=0.6320, Acc: valid=1.0000
# Epoch 40, Loss: train=0.6377 valid=0.6340, Acc: valid=1.0000
# Epoch 41, Loss: train=0.6409 valid=0.6339, Acc: valid=1.0000
# Epoch 42, Loss: train=0.6577 valid=0.6440, Acc: valid=1.0000
# Epoch 43, Loss: train=0.6524 valid=0.6383, Acc: valid=1.0000
# Epoch 44, Loss: train=0.6387 valid=0.6462, Acc: valid=1.0000
# Epoch 45, Loss: train=0.6287 valid=0.6501, Acc: valid=1.0000
# Epoch 46, Loss: train=0.6429 valid=0.6732, Acc: valid=1.0000
# Epoch 47, Loss: train=0.6271 valid=0.6691, Acc: valid=0.9091
# Epoch 48, Loss: train=0.6399 valid=0.6413, Acc: valid=1.0000
# Epoch 49, Loss: train=0.6455 valid=0.6679, Acc: valid=0.9091
# Epoch 50, Loss: train=0.6309 valid=0.6586, Acc: valid=1.0000
# Epoch 51, Loss: train=0.6443 valid=0.6690, Acc: valid=1.0000
# Epoch 52, Loss: train=0.6304 valid=0.6514, Acc: valid=1.0000
# Epoch 53, Loss: train=0.6430 valid=0.6468, Acc: valid=1.0000
# Epoch 54, Loss: train=0.6645 valid=0.6412, Acc: valid=1.0000
# Epoch 55, Loss: train=0.6292 valid=0.6407, Acc: valid=1.0000
# Best Epoch: 35, Best Valid Loss: 0.6310188987038352
# Valid Loss (with Epoch valid set) on Loaded Best Model: 0.6310188987038352
# Final Acc (with TEST set) on Loaded Best Model: 0.7327439646378783 (time: 0.002491344576296599)
#
# === case=3, backbone=resnet34 ===
# best model updated
# Epoch 1, Loss: train=1.3275 valid=1.2691, Acc: valid=0.3636
# Epoch 2, Loss: train=1.0059 valid=1.3000, Acc: valid=0.3636
# Epoch 3, Loss: train=0.8396 valid=1.4995, Acc: valid=0.3636
# Epoch 4, Loss: train=0.7121 valid=1.6013, Acc: valid=0.3636
# Epoch 5, Loss: train=0.6802 valid=1.5417, Acc: valid=0.3636
# Epoch 6, Loss: train=0.6760 valid=1.3742, Acc: valid=0.3636
# Epoch 7, Loss: train=0.6807 valid=1.3058, Acc: valid=0.2727
# best model updated
# Epoch 8, Loss: train=0.6653 valid=1.1316, Acc: valid=0.3636
# best model updated
# Epoch 9, Loss: train=0.6739 valid=1.1159, Acc: valid=0.4545
# Epoch 10, Loss: train=0.6700 valid=1.1717, Acc: valid=0.4545
# Epoch 11, Loss: train=0.6432 valid=1.1276, Acc: valid=0.6364
# best model updated
# Epoch 12, Loss: train=0.6708 valid=0.8360, Acc: valid=0.9091
# best model updated
# Epoch 13, Loss: train=0.6575 valid=0.7091, Acc: valid=0.9091
# Epoch 14, Loss: train=0.6484 valid=0.7561, Acc: valid=0.8182
# best model updated
# Epoch 15, Loss: train=0.6504 valid=0.6527, Acc: valid=1.0000
# Epoch 16, Loss: train=0.6572 valid=0.6573, Acc: valid=1.0000
# Epoch 17, Loss: train=0.6386 valid=0.6815, Acc: valid=1.0000
# Epoch 18, Loss: train=0.6442 valid=0.6934, Acc: valid=0.9091
# Epoch 19, Loss: train=0.6597 valid=0.6794, Acc: valid=1.0000
# Epoch 20, Loss: train=0.6534 valid=0.6651, Acc: valid=1.0000
# best model updated
# Epoch 21, Loss: train=0.6385 valid=0.6466, Acc: valid=1.0000
# Epoch 22, Loss: train=0.6486 valid=0.6714, Acc: valid=1.0000
# Epoch 23, Loss: train=0.6494 valid=0.7171, Acc: valid=0.9091
# Epoch 24, Loss: train=0.6383 valid=0.7233, Acc: valid=0.9091
# Epoch 25, Loss: train=0.6514 valid=0.7578, Acc: valid=0.8182
# Epoch 26, Loss: train=0.6391 valid=0.8619, Acc: valid=0.8182
# Epoch 27, Loss: train=0.6366 valid=0.8617, Acc: valid=0.8182
# Epoch 28, Loss: train=0.6384 valid=0.7324, Acc: valid=0.9091
# best model updated
# Epoch 29, Loss: train=0.6410 valid=0.6315, Acc: valid=1.0000
# Epoch 30, Loss: train=0.6696 valid=0.6358, Acc: valid=1.0000
# Epoch 31, Loss: train=0.6361 valid=0.6358, Acc: valid=1.0000
# best model updated
# Epoch 32, Loss: train=0.6565 valid=0.6295, Acc: valid=1.0000
# Epoch 33, Loss: train=0.6374 valid=0.6326, Acc: valid=1.0000
# Epoch 34, Loss: train=0.6303 valid=0.6361, Acc: valid=1.0000
# Epoch 35, Loss: train=0.6376 valid=0.7101, Acc: valid=0.9091
# Epoch 36, Loss: train=0.6288 valid=0.6881, Acc: valid=0.9091
# Epoch 37, Loss: train=0.6458 valid=0.6900, Acc: valid=0.9091
# Epoch 38, Loss: train=0.6554 valid=0.6318, Acc: valid=1.0000
# Epoch 39, Loss: train=0.6403 valid=0.6476, Acc: valid=1.0000
# Epoch 40, Loss: train=0.6280 valid=0.6354, Acc: valid=1.0000
# Epoch 41, Loss: train=0.6596 valid=0.7659, Acc: valid=0.9091
# best model updated
# Epoch 42, Loss: train=0.6544 valid=0.6268, Acc: valid=1.0000
# Epoch 43, Loss: train=0.6365 valid=0.6268, Acc: valid=1.0000
# best model updated
# Epoch 44, Loss: train=0.6329 valid=0.6267, Acc: valid=1.0000
# Epoch 45, Loss: train=0.6375 valid=0.6273, Acc: valid=1.0000
# Epoch 46, Loss: train=0.6316 valid=0.6277, Acc: valid=1.0000
# Epoch 47, Loss: train=0.6281 valid=0.6270, Acc: valid=1.0000
# Epoch 48, Loss: train=0.6270 valid=0.6272, Acc: valid=1.0000
# Epoch 49, Loss: train=0.6461 valid=0.6275, Acc: valid=1.0000
# Epoch 50, Loss: train=0.6269 valid=0.6270, Acc: valid=1.0000
# Epoch 51, Loss: train=0.6372 valid=0.6293, Acc: valid=1.0000
# Epoch 52, Loss: train=0.6480 valid=0.6463, Acc: valid=1.0000
# Epoch 53, Loss: train=0.6451 valid=0.6269, Acc: valid=1.0000
# best model updated
# Epoch 54, Loss: train=0.6372 valid=0.6266, Acc: valid=1.0000
# Epoch 55, Loss: train=0.6292 valid=0.6271, Acc: valid=1.0000
# Epoch 56, Loss: train=0.6464 valid=0.6269, Acc: valid=1.0000
# best model updated
# Epoch 57, Loss: train=0.6271 valid=0.6266, Acc: valid=1.0000
# best model updated
# Epoch 58, Loss: train=0.6472 valid=0.6266, Acc: valid=1.0000
# Epoch 59, Loss: train=0.6272 valid=0.6266, Acc: valid=1.0000
# Epoch 60, Loss: train=0.6444 valid=0.6270, Acc: valid=1.0000
# Epoch 61, Loss: train=0.6319 valid=0.6660, Acc: valid=0.9091
# Epoch 62, Loss: train=0.6413 valid=0.6510, Acc: valid=1.0000
# Epoch 63, Loss: train=0.6269 valid=0.6282, Acc: valid=1.0000
# Epoch 64, Loss: train=0.6297 valid=0.6326, Acc: valid=1.0000
# Epoch 65, Loss: train=0.6385 valid=0.6433, Acc: valid=1.0000
# Epoch 66, Loss: train=0.6600 valid=0.6302, Acc: valid=1.0000
# Epoch 67, Loss: train=0.6396 valid=0.6307, Acc: valid=1.0000
# Epoch 68, Loss: train=0.6374 valid=0.6274, Acc: valid=1.0000
# Epoch 69, Loss: train=0.6396 valid=0.6290, Acc: valid=1.0000
# Epoch 70, Loss: train=0.6533 valid=0.6346, Acc: valid=1.0000
# Epoch 71, Loss: train=0.6564 valid=0.6464, Acc: valid=1.0000
# Epoch 72, Loss: train=0.6378 valid=0.6400, Acc: valid=1.0000
# Epoch 73, Loss: train=0.6492 valid=0.6463, Acc: valid=1.0000
# Epoch 74, Loss: train=0.6319 valid=0.6283, Acc: valid=1.0000
# Epoch 75, Loss: train=0.6360 valid=0.6267, Acc: valid=1.0000
# Epoch 76, Loss: train=0.6431 valid=0.6309, Acc: valid=1.0000
# Epoch 77, Loss: train=0.6477 valid=0.6473, Acc: valid=1.0000
# Best Epoch: 57, Best Valid Loss: 0.6265646327625621
# Valid Loss (with Epoch valid set) on Loaded Best Model: 0.6265646327625621
# Final Acc (with TEST set) on Loaded Best Model: 0.8031281876912615 (time: 0.00537918702415798)
#
# === case=3, backbone=resnet50 ===
# best model updated
# Epoch 1, Loss: train=1.4456 valid=1.1097, Acc: valid=0.3636
# Epoch 2, Loss: train=1.1127 valid=1.2847, Acc: valid=0.2727
# Epoch 3, Loss: train=0.9545 valid=1.3655, Acc: valid=0.0909
# Epoch 4, Loss: train=0.8961 valid=1.3307, Acc: valid=0.4545
# Epoch 5, Loss: train=0.7864 valid=1.3357, Acc: valid=0.4545
# Epoch 6, Loss: train=0.7446 valid=1.3314, Acc: valid=0.4545
# Epoch 7, Loss: train=0.7698 valid=1.2617, Acc: valid=0.4545
# best model updated
# Epoch 8, Loss: train=0.7354 valid=1.1020, Acc: valid=0.4545
# best model updated
# Epoch 9, Loss: train=0.6887 valid=1.0483, Acc: valid=0.6364
# best model updated
# Epoch 10, Loss: train=0.7029 valid=0.9969, Acc: valid=0.6364
# Epoch 11, Loss: train=0.6971 valid=1.0028, Acc: valid=0.5455
# Epoch 12, Loss: train=0.7198 valid=1.0665, Acc: valid=0.5455
# Epoch 13, Loss: train=0.6479 valid=1.0854, Acc: valid=0.6364
# Epoch 14, Loss: train=0.6505 valid=1.0134, Acc: valid=0.7273
# best model updated
# Epoch 15, Loss: train=0.6388 valid=0.8865, Acc: valid=0.8182
# Epoch 16, Loss: train=0.6521 valid=0.9325, Acc: valid=0.7273
# Epoch 17, Loss: train=0.6584 valid=0.9500, Acc: valid=0.7273
# Epoch 18, Loss: train=0.6409 valid=0.8905, Acc: valid=0.8182
# Epoch 19, Loss: train=0.6689 valid=0.9213, Acc: valid=0.8182
# best model updated
# Epoch 20, Loss: train=0.6758 valid=0.8846, Acc: valid=0.8182
# best model updated
# Epoch 21, Loss: train=0.6548 valid=0.8750, Acc: valid=0.8182
# Epoch 22, Loss: train=0.6966 valid=0.8792, Acc: valid=0.8182
# best model updated
# Epoch 23, Loss: train=0.6295 valid=0.8306, Acc: valid=0.8182
# Epoch 24, Loss: train=0.6456 valid=0.8433, Acc: valid=0.8182
# best model updated
# Epoch 25, Loss: train=0.6563 valid=0.8249, Acc: valid=0.9091
# best model updated
# Epoch 26, Loss: train=0.6601 valid=0.8188, Acc: valid=0.9091
# best model updated
# Epoch 27, Loss: train=0.6741 valid=0.8144, Acc: valid=0.8182
# Epoch 28, Loss: train=0.6630 valid=0.8926, Acc: valid=0.7273
# best model updated
# Epoch 29, Loss: train=0.7163 valid=0.7758, Acc: valid=0.9091
# Epoch 30, Loss: train=0.7017 valid=0.8074, Acc: valid=0.8182
# Epoch 31, Loss: train=0.6498 valid=0.8302, Acc: valid=0.8182
# Epoch 32, Loss: train=0.6723 valid=0.9370, Acc: valid=0.7273
# Epoch 33, Loss: train=0.6548 valid=1.0707, Acc: valid=0.6364
# Epoch 34, Loss: train=0.7014 valid=0.9273, Acc: valid=0.8182
# Epoch 35, Loss: train=0.6774 valid=0.9509, Acc: valid=0.7273
# best model updated
# Epoch 36, Loss: train=0.6682 valid=0.7582, Acc: valid=0.8182
# best model updated
# Epoch 37, Loss: train=0.6517 valid=0.6861, Acc: valid=0.9091
# best model updated
# Epoch 38, Loss: train=0.7062 valid=0.6851, Acc: valid=0.9091
# Epoch 39, Loss: train=0.6630 valid=0.7070, Acc: valid=1.0000
# Epoch 40, Loss: train=0.6551 valid=0.7436, Acc: valid=0.9091
# Epoch 41, Loss: train=0.6490 valid=0.8601, Acc: valid=0.7273
# Epoch 42, Loss: train=0.6409 valid=0.7354, Acc: valid=0.9091
# Epoch 43, Loss: train=0.6549 valid=0.7201, Acc: valid=0.9091
# Epoch 44, Loss: train=0.6581 valid=0.7185, Acc: valid=0.9091
# Epoch 45, Loss: train=0.6460 valid=0.7714, Acc: valid=0.8182
# Epoch 46, Loss: train=0.6399 valid=0.9430, Acc: valid=0.7273
# Epoch 47, Loss: train=0.6449 valid=0.8176, Acc: valid=0.8182
# Epoch 48, Loss: train=0.6612 valid=0.8078, Acc: valid=0.8182
# Epoch 49, Loss: train=0.6716 valid=0.8077, Acc: valid=0.8182
# Epoch 50, Loss: train=0.6357 valid=0.8061, Acc: valid=0.8182
# Epoch 51, Loss: train=0.7024 valid=0.8353, Acc: valid=0.8182
# Epoch 52, Loss: train=0.6275 valid=0.6969, Acc: valid=0.9091
# Epoch 53, Loss: train=0.6289 valid=0.7561, Acc: valid=0.8182
# Epoch 54, Loss: train=0.6509 valid=0.7546, Acc: valid=0.8182
# Epoch 55, Loss: train=0.6325 valid=0.7522, Acc: valid=0.8182
# Epoch 56, Loss: train=0.6283 valid=0.6882, Acc: valid=1.0000
# best model updated
# Epoch 57, Loss: train=0.6549 valid=0.6547, Acc: valid=1.0000
# best model updated
# Epoch 58, Loss: train=0.6665 valid=0.6423, Acc: valid=1.0000
# Epoch 59, Loss: train=0.6283 valid=0.6518, Acc: valid=1.0000
# Epoch 60, Loss: train=0.6453 valid=0.6969, Acc: valid=0.9091
# Epoch 61, Loss: train=0.6367 valid=0.6772, Acc: valid=0.9091
# Epoch 62, Loss: train=0.6660 valid=0.6437, Acc: valid=1.0000
# best model updated
# Epoch 63, Loss: train=0.6472 valid=0.6394, Acc: valid=1.0000
# best model updated
# Epoch 64, Loss: train=0.6517 valid=0.6305, Acc: valid=1.0000
# best model updated
# Epoch 65, Loss: train=0.6280 valid=0.6298, Acc: valid=1.0000
# Epoch 66, Loss: train=0.6381 valid=0.6394, Acc: valid=1.0000
# best model updated
# Epoch 67, Loss: train=0.6567 valid=0.6273, Acc: valid=1.0000
# Epoch 68, Loss: train=0.6641 valid=0.6488, Acc: valid=1.0000
# Epoch 69, Loss: train=0.6529 valid=0.6824, Acc: valid=0.9091
# Epoch 70, Loss: train=0.6561 valid=0.6770, Acc: valid=0.9091
# Epoch 71, Loss: train=0.6394 valid=0.7560, Acc: valid=0.8182
# Epoch 72, Loss: train=0.6486 valid=0.7828, Acc: valid=0.7273
# Epoch 73, Loss: train=0.6283 valid=0.7819, Acc: valid=0.8182
# Epoch 74, Loss: train=0.6493 valid=0.8540, Acc: valid=0.7273
# Epoch 75, Loss: train=0.6495 valid=0.7599, Acc: valid=0.9091
# Epoch 76, Loss: train=0.6472 valid=0.7764, Acc: valid=0.8182
# Epoch 77, Loss: train=0.6380 valid=0.6440, Acc: valid=1.0000
# Epoch 78, Loss: train=0.6267 valid=0.6518, Acc: valid=1.0000
# Epoch 79, Loss: train=0.6560 valid=0.6442, Acc: valid=1.0000
# Epoch 80, Loss: train=0.6270 valid=0.7043, Acc: valid=0.9091
# Epoch 81, Loss: train=0.6763 valid=0.7169, Acc: valid=0.9091
# Epoch 82, Loss: train=0.6268 valid=0.6560, Acc: valid=1.0000
# Epoch 83, Loss: train=0.6460 valid=0.6632, Acc: valid=0.9091
# Epoch 84, Loss: train=0.6453 valid=0.6951, Acc: valid=0.9091
# Epoch 85, Loss: train=0.6460 valid=0.7277, Acc: valid=0.9091
# Epoch 86, Loss: train=0.6475 valid=0.7047, Acc: valid=0.9091
# Best Epoch: 66, Best Valid Loss: 0.6272703084078702
# Valid Loss (with Epoch valid set) on Loaded Best Model: 0.6272703084078702
# Final Acc (with TEST set) on Loaded Best Model: 0.8395103706222373 (time: 0.007448885751807172)
#
# === case=4_1, backbone=resnet18 ===
# best model updated
# Epoch 1, Loss: train=1.4860 valid=1.3984, Acc: valid=0.1818
# best model updated
# Epoch 2, Loss: train=0.9173 valid=1.3071, Acc: valid=0.2727
# best model updated
# Epoch 3, Loss: train=0.7362 valid=1.2373, Acc: valid=0.4545
# best model updated
# Epoch 4, Loss: train=0.6923 valid=1.0859, Acc: valid=0.7273
# best model updated
# Epoch 5, Loss: train=0.6565 valid=0.9965, Acc: valid=0.7273
# Epoch 6, Loss: train=0.6444 valid=1.0096, Acc: valid=0.7273
# best model updated
# Epoch 7, Loss: train=0.6560 valid=0.9564, Acc: valid=0.8182
# best model updated
# Epoch 8, Loss: train=0.6438 valid=0.7111, Acc: valid=1.0000
# Epoch 9, Loss: train=0.6424 valid=0.7353, Acc: valid=0.9091
# Epoch 10, Loss: train=0.6461 valid=0.7588, Acc: valid=0.9091
# best model updated
# Epoch 11, Loss: train=0.6417 valid=0.6481, Acc: valid=1.0000
# best model updated
# Epoch 12, Loss: train=0.6610 valid=0.6420, Acc: valid=1.0000
# best model updated
# Epoch 13, Loss: train=0.6506 valid=0.6341, Acc: valid=1.0000
# Epoch 14, Loss: train=0.6622 valid=0.6582, Acc: valid=1.0000
# Epoch 15, Loss: train=0.6313 valid=0.6595, Acc: valid=1.0000
# Epoch 16, Loss: train=0.6316 valid=0.6561, Acc: valid=1.0000
# Epoch 17, Loss: train=0.6335 valid=0.6421, Acc: valid=1.0000
# Epoch 18, Loss: train=0.6402 valid=0.6592, Acc: valid=1.0000
# Epoch 19, Loss: train=0.6356 valid=0.6502, Acc: valid=1.0000
# Epoch 20, Loss: train=0.6336 valid=0.6404, Acc: valid=1.0000
# best model updated
# Epoch 21, Loss: train=0.6344 valid=0.6314, Acc: valid=1.0000
# Epoch 22, Loss: train=0.6328 valid=0.6470, Acc: valid=1.0000
# Epoch 23, Loss: train=0.6593 valid=0.6604, Acc: valid=1.0000
# Epoch 24, Loss: train=0.6280 valid=0.7019, Acc: valid=0.9091
# Epoch 25, Loss: train=0.6498 valid=0.6552, Acc: valid=1.0000
# Epoch 26, Loss: train=0.6320 valid=0.6648, Acc: valid=1.0000
# Epoch 27, Loss: train=0.6344 valid=0.6635, Acc: valid=1.0000
# Epoch 28, Loss: train=0.6390 valid=0.6507, Acc: valid=1.0000
# Epoch 29, Loss: train=0.6550 valid=0.6492, Acc: valid=1.0000
# Epoch 30, Loss: train=0.6593 valid=0.6383, Acc: valid=1.0000
# Epoch 31, Loss: train=0.6285 valid=0.6570, Acc: valid=1.0000
# Epoch 32, Loss: train=0.6400 valid=0.6526, Acc: valid=1.0000
# best model updated
# Epoch 33, Loss: train=0.6442 valid=0.6288, Acc: valid=1.0000
# Epoch 34, Loss: train=0.6277 valid=0.6355, Acc: valid=1.0000
# Epoch 35, Loss: train=0.6318 valid=0.6412, Acc: valid=1.0000
# Epoch 36, Loss: train=0.6293 valid=0.6631, Acc: valid=0.9091
# Epoch 37, Loss: train=0.6285 valid=0.6483, Acc: valid=1.0000
# Epoch 38, Loss: train=0.6372 valid=0.6309, Acc: valid=1.0000
# Epoch 39, Loss: train=0.6588 valid=0.6329, Acc: valid=1.0000
# Epoch 40, Loss: train=0.6275 valid=0.7010, Acc: valid=0.9091
# Epoch 41, Loss: train=0.6604 valid=0.7221, Acc: valid=0.9091
# Epoch 42, Loss: train=0.6326 valid=0.7253, Acc: valid=0.9091
# Epoch 43, Loss: train=0.6456 valid=0.7379, Acc: valid=0.9091
# Epoch 44, Loss: train=0.6506 valid=0.7902, Acc: valid=0.8182
# Epoch 45, Loss: train=0.6285 valid=0.7956, Acc: valid=0.8182
# Epoch 46, Loss: train=0.6422 valid=0.7949, Acc: valid=0.8182
# Epoch 47, Loss: train=0.6922 valid=0.7811, Acc: valid=0.8182
# Epoch 48, Loss: train=0.6403 valid=0.7237, Acc: valid=0.9091
# Epoch 49, Loss: train=0.6561 valid=0.7587, Acc: valid=0.8182
# Epoch 50, Loss: train=0.6277 valid=0.7430, Acc: valid=0.9091
# Epoch 51, Loss: train=0.6579 valid=0.7095, Acc: valid=0.9091
# Epoch 52, Loss: train=0.6405 valid=0.7024, Acc: valid=0.9091
# Best Epoch: 32, Best Valid Loss: 0.6288440010764382
# Valid Loss (with Epoch valid set) on Loaded Best Model: 0.6288440010764382
# Final Acc (with TEST set) on Loaded Best Model: 0.7922475348520911 (time: 0.004799855792004129)
#
# === case=4_1, backbone=resnet34 ===
# best model updated
# Epoch 1, Loss: train=1.4525 valid=1.5590, Acc: valid=0.0909
# best model updated
# Epoch 2, Loss: train=0.9763 valid=1.4981, Acc: valid=0.1818
# best model updated
# Epoch 3, Loss: train=0.7532 valid=1.3397, Acc: valid=0.1818
# best model updated
# Epoch 4, Loss: train=0.7214 valid=1.1999, Acc: valid=0.4545
# Epoch 5, Loss: train=0.6981 valid=1.2148, Acc: valid=0.3636
# best model updated
# Epoch 6, Loss: train=0.6617 valid=1.1947, Acc: valid=0.3636
# best model updated
# Epoch 7, Loss: train=0.6591 valid=1.1864, Acc: valid=0.4545
# best model updated
# Epoch 8, Loss: train=0.6855 valid=1.0026, Acc: valid=0.6364
# best model updated
# Epoch 9, Loss: train=0.6614 valid=0.9741, Acc: valid=0.6364
# Epoch 10, Loss: train=0.6718 valid=1.0248, Acc: valid=0.5455
# Epoch 11, Loss: train=0.6547 valid=0.9779, Acc: valid=0.7273
# best model updated
# Epoch 12, Loss: train=0.6529 valid=0.7695, Acc: valid=0.8182
# best model updated
# Epoch 13, Loss: train=0.6504 valid=0.7622, Acc: valid=0.9091
# best model updated
# Epoch 14, Loss: train=0.6549 valid=0.7119, Acc: valid=0.9091
# best model updated
# Epoch 15, Loss: train=0.6569 valid=0.6854, Acc: valid=1.0000
# best model updated
# Epoch 16, Loss: train=0.6475 valid=0.6679, Acc: valid=1.0000
# best model updated
# Epoch 17, Loss: train=0.6384 valid=0.6499, Acc: valid=1.0000
# Epoch 18, Loss: train=0.6474 valid=0.7634, Acc: valid=0.8182
# Epoch 19, Loss: train=0.6478 valid=0.6987, Acc: valid=0.9091
# Epoch 20, Loss: train=0.6300 valid=0.6590, Acc: valid=1.0000
# Epoch 21, Loss: train=0.6351 valid=0.7051, Acc: valid=0.9091
# Epoch 22, Loss: train=0.6332 valid=0.7467, Acc: valid=0.9091
# Epoch 23, Loss: train=0.6562 valid=0.7721, Acc: valid=0.9091
# Epoch 24, Loss: train=0.6673 valid=0.6746, Acc: valid=1.0000
# Epoch 25, Loss: train=0.6561 valid=0.7038, Acc: valid=1.0000
# Epoch 26, Loss: train=0.6360 valid=0.7846, Acc: valid=0.7273
# Epoch 27, Loss: train=0.6745 valid=0.8882, Acc: valid=0.8182
# Epoch 28, Loss: train=0.6402 valid=0.7728, Acc: valid=0.8182
# Epoch 29, Loss: train=0.6448 valid=0.7308, Acc: valid=0.9091
# Epoch 30, Loss: train=0.6420 valid=0.8012, Acc: valid=0.9091
# Epoch 31, Loss: train=0.6405 valid=0.8069, Acc: valid=0.9091
# Epoch 32, Loss: train=0.6408 valid=0.8076, Acc: valid=0.9091
# Epoch 33, Loss: train=0.6750 valid=0.7994, Acc: valid=0.9091
# Epoch 34, Loss: train=0.6507 valid=0.7013, Acc: valid=0.9091
# Epoch 35, Loss: train=0.6483 valid=0.8066, Acc: valid=0.9091
# Epoch 36, Loss: train=0.6537 valid=0.8076, Acc: valid=0.9091
# Best Epoch: 16, Best Valid Loss: 0.6499481201171875
# Valid Loss (with Epoch valid set) on Loaded Best Model: 0.6499481201171875
# Final Acc (with TEST set) on Loaded Best Model: 0.7262835770146209 (time: 0.010300545588783596)
#
# === case=4_1, backbone=resnet50 ===
# best model updated
# ...
# best model updated
# Epoch 14, Loss: train=0.6470 valid=0.6875, Acc: valid=1.0000
# best model updated
# Epoch 15, Loss: train=0.6353 valid=0.6612, Acc: valid=1.0000
# best model updated
# Epoch 16, Loss: train=0.6385 valid=0.6441, Acc: valid=1.0000
# best model updated
# Epoch 17, Loss: train=0.6614 valid=0.6427, Acc: valid=1.0000
# best model updated
# Epoch 18, Loss: train=0.6460 valid=0.6386, Acc: valid=1.0000
# best model updated
# Epoch 19, Loss: train=0.6421 valid=0.6337, Acc: valid=1.0000
# Epoch 20, Loss: train=0.6534 valid=0.6351, Acc: valid=1.0000
# Epoch 21, Loss: train=0.6512 valid=0.6493, Acc: valid=1.0000
# best model updated
# Epoch 22, Loss: train=0.6367 valid=0.6307, Acc: valid=1.0000
# Epoch 23, Loss: train=0.6612 valid=0.6376, Acc: valid=1.0000
# Epoch 24, Loss: train=0.6367 valid=0.6437, Acc: valid=1.0000
# best model updated
# Epoch 25, Loss: train=0.6684 valid=0.6301, Acc: valid=1.0000
# Epoch 26, Loss: train=0.6417 valid=0.6334, Acc: valid=1.0000
# Epoch 27, Loss: train=0.6490 valid=0.6430, Acc: valid=1.0000
# Epoch 28, Loss: train=0.6317 valid=0.6526, Acc: valid=1.0000
# Epoch 29, Loss: train=0.6570 valid=0.6470, Acc: valid=1.0000
# Epoch 30, Loss: train=0.6348 valid=0.6394, Acc: valid=1.0000
# Epoch 31, Loss: train=0.6400 valid=0.6375, Acc: valid=1.0000
# Epoch 32, Loss: train=0.6372 valid=0.6531, Acc: valid=1.0000
# Epoch 33, Loss: train=0.6644 valid=0.6501, Acc: valid=1.0000
# Epoch 34, Loss: train=0.6450 valid=0.6873, Acc: valid=1.0000
# Epoch 35, Loss: train=0.6500 valid=0.6903, Acc: valid=0.9091
# Epoch 36, Loss: train=0.6641 valid=0.6649, Acc: valid=1.0000
# Epoch 37, Loss: train=0.6553 valid=0.6872, Acc: valid=1.0000
# Epoch 38, Loss: train=0.6492 valid=0.6822, Acc: valid=0.9091
# Epoch 39, Loss: train=0.6628 valid=0.6829, Acc: valid=0.9091
# Epoch 40, Loss: train=0.6411 valid=0.6301, Acc: valid=1.0000
# Epoch 41, Loss: train=0.6333 valid=0.6431, Acc: valid=1.0000
# Epoch 42, Loss: train=0.6658 valid=0.6649, Acc: valid=1.0000
# Epoch 43, Loss: train=0.6372 valid=0.7015, Acc: valid=0.9091
# Epoch 44, Loss: train=0.6828 valid=0.6987, Acc: valid=0.9091
# Best Epoch: 24, Best Valid Loss: 0.6300534335049716
# Valid Loss (with Epoch valid set) on Loaded Best Model: 0.6300534335049716
# Final Acc (with TEST set) on Loaded Best Model: 0.8170690241414484 (time: 0.011004183603369671)
#
# === case=4_2, backbone=resnet18 ===
# best model updated
# Epoch 1, Loss: train=1.3718 valid=1.2182, Acc: valid=0.3636
# best model updated
# Epoch 2, Loss: train=0.9260 valid=1.1628, Acc: valid=0.3636
# best model updated
# Epoch 3, Loss: train=0.7837 valid=1.1438, Acc: valid=0.3636
# Epoch 4, Loss: train=0.7224 valid=1.1477, Acc: valid=0.3636
# best model updated
# Epoch 5, Loss: train=0.6654 valid=1.1286, Acc: valid=0.4545
# best model updated
# Epoch 6, Loss: train=0.6397 valid=1.1169, Acc: valid=0.6364
# best model updated
# Epoch 7, Loss: train=0.6473 valid=1.0902, Acc: valid=0.5455
# best model updated
# Epoch 8, Loss: train=0.6412 valid=1.0514, Acc: valid=0.5455
# best model updated
# Epoch 9, Loss: train=0.6436 valid=0.8700, Acc: valid=0.7273
# best model updated
# Epoch 10, Loss: train=0.6744 valid=0.7185, Acc: valid=0.9091
# Epoch 11, Loss: train=0.6292 valid=0.7725, Acc: valid=0.8182
# Epoch 12, Loss: train=0.6469 valid=0.7626, Acc: valid=0.9091
# Epoch 13, Loss: train=0.6672 valid=0.7575, Acc: valid=0.9091
# Epoch 14, Loss: train=0.6449 valid=0.7824, Acc: valid=0.9091
# Epoch 15, Loss: train=0.6570 valid=0.7863, Acc: valid=0.8182
# Epoch 16, Loss: train=0.6345 valid=0.7617, Acc: valid=0.9091
# Epoch 17, Loss: train=0.6316 valid=0.7873, Acc: valid=0.9091
# Epoch 18, Loss: train=0.6447 valid=0.7861, Acc: valid=0.9091
# Epoch 19, Loss: train=0.6347 valid=0.8296, Acc: valid=0.8182
# Epoch 20, Loss: train=0.6398 valid=0.8169, Acc: valid=0.8182
# Epoch 21, Loss: train=0.6482 valid=0.8316, Acc: valid=0.7273
# Epoch 22, Loss: train=0.6329 valid=0.7926, Acc: valid=0.8182
# best model updated
# Epoch 23, Loss: train=0.6478 valid=0.6899, Acc: valid=1.0000
# Epoch 24, Loss: train=0.6599 valid=0.7430, Acc: valid=0.9091
# Epoch 25, Loss: train=0.6380 valid=0.7996, Acc: valid=0.8182
# Epoch 26, Loss: train=0.6291 valid=0.8232, Acc: valid=0.8182
# Epoch 27, Loss: train=0.6485 valid=0.7836, Acc: valid=0.9091
# Epoch 28, Loss: train=0.6472 valid=0.7413, Acc: valid=0.9091
# Epoch 29, Loss: train=0.6367 valid=0.7134, Acc: valid=1.0000
# best model updated
# Epoch 30, Loss: train=0.6595 valid=0.6647, Acc: valid=1.0000
# best model updated
# Epoch 31, Loss: train=0.6639 valid=0.6448, Acc: valid=1.0000
# Epoch 32, Loss: train=0.6322 valid=0.7404, Acc: valid=0.9091
# Epoch 33, Loss: train=0.6355 valid=0.7323, Acc: valid=0.9091
# Epoch 34, Loss: train=0.6530 valid=0.7290, Acc: valid=0.9091
# Epoch 35, Loss: train=0.6358 valid=0.7244, Acc: valid=0.9091
# Epoch 36, Loss: train=0.6544 valid=0.6474, Acc: valid=1.0000
# Epoch 37, Loss: train=0.6415 valid=0.6958, Acc: valid=0.9091
# Epoch 38, Loss: train=0.6391 valid=0.6829, Acc: valid=0.9091
# best model updated
# Epoch 39, Loss: train=0.6342 valid=0.6318, Acc: valid=1.0000
# Epoch 40, Loss: train=0.6648 valid=0.6389, Acc: valid=1.0000
# Epoch 41, Loss: train=0.6293 valid=0.6563, Acc: valid=1.0000
# Epoch 42, Loss: train=0.6338 valid=0.6378, Acc: valid=1.0000
# Epoch 43, Loss: train=0.6579 valid=0.6835, Acc: valid=0.9091
# Epoch 44, Loss: train=0.6278 valid=0.6626, Acc: valid=0.9091
# Epoch 45, Loss: train=0.6471 valid=0.6395, Acc: valid=1.0000
# best model updated
# Epoch 46, Loss: train=0.6649 valid=0.6273, Acc: valid=1.0000
# Epoch 47, Loss: train=0.6370 valid=0.6274, Acc: valid=1.0000
# Epoch 48, Loss: train=0.6670 valid=0.6278, Acc: valid=1.0000
# best model updated
# Epoch 49, Loss: train=0.6313 valid=0.6269, Acc: valid=1.0000
# Epoch 50, Loss: train=0.6281 valid=0.6270, Acc: valid=1.0000
# Epoch 51, Loss: train=0.6294 valid=0.6272, Acc: valid=1.0000
# Epoch 52, Loss: train=0.6285 valid=0.6278, Acc: valid=1.0000
# Epoch 53, Loss: train=0.6294 valid=0.6273, Acc: valid=1.0000
# Epoch 54, Loss: train=0.6281 valid=0.6274, Acc: valid=1.0000
# Epoch 55, Loss: train=0.6434 valid=0.6273, Acc: valid=1.0000
# Epoch 56, Loss: train=0.6385 valid=0.6273, Acc: valid=1.0000
# Epoch 57, Loss: train=0.6267 valid=0.6302, Acc: valid=1.0000
# Epoch 58, Loss: train=0.6297 valid=0.6288, Acc: valid=1.0000
# Epoch 59, Loss: train=0.6468 valid=0.6270, Acc: valid=1.0000
# Epoch 60, Loss: train=0.6274 valid=0.6270, Acc: valid=1.0000
# best model updated
# Epoch 61, Loss: train=0.6390 valid=0.6268, Acc: valid=1.0000
# best model updated
# Epoch 62, Loss: train=0.6369 valid=0.6268, Acc: valid=1.0000
# Epoch 63, Loss: train=0.6276 valid=0.6272, Acc: valid=1.0000
# Epoch 64, Loss: train=0.6296 valid=0.6269, Acc: valid=1.0000
# Epoch 65, Loss: train=0.6465 valid=0.6270, Acc: valid=1.0000
# best model updated
# Epoch 66, Loss: train=0.6468 valid=0.6266, Acc: valid=1.0000
# Epoch 67, Loss: train=0.6372 valid=0.6267, Acc: valid=1.0000
# Epoch 68, Loss: train=0.6344 valid=0.6271, Acc: valid=1.0000
# Epoch 69, Loss: train=0.6268 valid=0.6277, Acc: valid=1.0000
# Epoch 70, Loss: train=0.6458 valid=0.6291, Acc: valid=1.0000
# Epoch 71, Loss: train=0.6505 valid=0.6267, Acc: valid=1.0000
# Epoch 72, Loss: train=0.6523 valid=0.6275, Acc: valid=1.0000
# Epoch 73, Loss: train=0.6387 valid=0.6271, Acc: valid=1.0000
# Epoch 74, Loss: train=0.6370 valid=0.6401, Acc: valid=1.0000
# Epoch 75, Loss: train=0.6271 valid=0.6767, Acc: valid=0.9091
# Epoch 76, Loss: train=0.6451 valid=0.6282, Acc: valid=1.0000
# Epoch 77, Loss: train=0.6290 valid=0.6458, Acc: valid=1.0000
# Epoch 78, Loss: train=0.6475 valid=0.6269, Acc: valid=1.0000
# best model updated
# Epoch 79, Loss: train=0.6470 valid=0.6266, Acc: valid=1.0000
# Epoch 80, Loss: train=0.6267 valid=0.6267, Acc: valid=1.0000
# Epoch 81, Loss: train=0.6546 valid=0.6268, Acc: valid=1.0000
# Epoch 82, Loss: train=0.6469 valid=0.6271, Acc: valid=1.0000
# Epoch 83, Loss: train=0.6466 valid=0.6269, Acc: valid=1.0000
# Epoch 84, Loss: train=0.6288 valid=0.6271, Acc: valid=1.0000
# Epoch 85, Loss: train=0.6294 valid=0.6298, Acc: valid=1.0000
# Epoch 86, Loss: train=0.6373 valid=0.6290, Acc: valid=1.0000
# Epoch 87, Loss: train=0.6279 valid=0.6296, Acc: valid=1.0000
# Epoch 88, Loss: train=0.6274 valid=0.6274, Acc: valid=1.0000
# Epoch 89, Loss: train=0.6332 valid=0.6270, Acc: valid=1.0000
# Epoch 90, Loss: train=0.6380 valid=0.6266, Acc: valid=1.0000
# Epoch 91, Loss: train=0.6271 valid=0.6267, Acc: valid=1.0000
# Epoch 92, Loss: train=0.6391 valid=0.6267, Acc: valid=1.0000
# Epoch 93, Loss: train=0.6270 valid=0.6266, Acc: valid=1.0000
# Epoch 94, Loss: train=0.6267 valid=0.6267, Acc: valid=1.0000
# Epoch 95, Loss: train=0.6408 valid=0.6267, Acc: valid=1.0000
# Epoch 96, Loss: train=0.6308 valid=0.6269, Acc: valid=1.0000
# Epoch 97, Loss: train=0.6399 valid=0.6276, Acc: valid=1.0000
# Epoch 98, Loss: train=0.6461 valid=0.6306, Acc: valid=1.0000
# Best Epoch: 78, Best Valid Loss: 0.6265932429920543
# Valid Loss (with Epoch valid set) on Loaded Best Model: 0.6265932429920543
# Final Acc (with TEST set) on Loaded Best Model: 0.7966678000680041 (time: 0.004812577496404233)
#
# === case=4_2, backbone=resnet34 ===
# best model updated
# Epoch 1, Loss: train=1.3376 valid=1.2615, Acc: valid=0.3636
# best model updated
# Epoch 2, Loss: train=0.8563 valid=1.2515, Acc: valid=0.3636
# best model updated
# Epoch 3, Loss: train=0.7691 valid=1.2363, Acc: valid=0.3636
# best model updated
# Epoch 4, Loss: train=0.7237 valid=1.1986, Acc: valid=0.3636
# Epoch 5, Loss: train=0.6899 valid=1.2772, Acc: valid=0.5455
# Epoch 6, Loss: train=0.7064 valid=1.3849, Acc: valid=0.4545
# Epoch 7, Loss: train=0.6941 valid=1.3130, Acc: valid=0.4545
# Epoch 8, Loss: train=0.7154 valid=1.2296, Acc: valid=0.4545
# best model updated
# Epoch 9, Loss: train=0.6848 valid=1.0776, Acc: valid=0.5455
# best model updated
# Epoch 10, Loss: train=0.6903 valid=1.0112, Acc: valid=0.7273
# best model updated
# Epoch 11, Loss: train=0.6605 valid=0.8005, Acc: valid=0.8182
# best model updated
# Epoch 12, Loss: train=0.6729 valid=0.6773, Acc: valid=1.0000
# Epoch 13, Loss: train=0.6640 valid=0.6810, Acc: valid=0.9091
# best model updated
# Epoch 14, Loss: train=0.6588 valid=0.6608, Acc: valid=1.0000
# Epoch 15, Loss: train=0.6492 valid=0.6938, Acc: valid=1.0000
# best model updated
# Epoch 16, Loss: train=0.6775 valid=0.6547, Acc: valid=1.0000
# best model updated
# Epoch 17, Loss: train=0.6995 valid=0.6326, Acc: valid=1.0000
# best model updated
# Epoch 18, Loss: train=0.6649 valid=0.6299, Acc: valid=1.0000
# Epoch 19, Loss: train=0.6571 valid=0.6328, Acc: valid=1.0000
# best model updated
# Epoch 20, Loss: train=0.6656 valid=0.6290, Acc: valid=1.0000
# Epoch 21, Loss: train=0.6401 valid=0.6303, Acc: valid=1.0000
# Epoch 22, Loss: train=0.6681 valid=0.6298, Acc: valid=1.0000
# best model updated
# Epoch 23, Loss: train=0.6613 valid=0.6286, Acc: valid=1.0000
# best model updated
# Epoch 24, Loss: train=0.6810 valid=0.6270, Acc: valid=1.0000
# Epoch 25, Loss: train=0.6789 valid=0.6281, Acc: valid=1.0000
# Epoch 26, Loss: train=0.6578 valid=0.6287, Acc: valid=1.0000
# Epoch 27, Loss: train=0.6732 valid=0.6404, Acc: valid=1.0000
# Epoch 28, Loss: train=0.6987 valid=0.6297, Acc: valid=1.0000
# Epoch 29, Loss: train=0.6449 valid=0.6287, Acc: valid=1.0000
# Epoch 30, Loss: train=0.6652 valid=0.6332, Acc: valid=1.0000
# Epoch 31, Loss: train=0.6819 valid=0.6710, Acc: valid=0.9091
# Epoch 32, Loss: train=0.6430 valid=0.6707, Acc: valid=1.0000
# Epoch 33, Loss: train=0.6615 valid=0.7575, Acc: valid=0.8182
# Epoch 34, Loss: train=0.6750 valid=0.6473, Acc: valid=1.0000
# Epoch 35, Loss: train=0.6553 valid=0.6437, Acc: valid=1.0000
# Epoch 36, Loss: train=0.6828 valid=0.6341, Acc: valid=1.0000
# Epoch 37, Loss: train=0.6628 valid=0.6278, Acc: valid=1.0000
# Epoch 38, Loss: train=0.6514 valid=0.6290, Acc: valid=1.0000
# Epoch 39, Loss: train=0.6613 valid=0.6455, Acc: valid=1.0000
# Epoch 40, Loss: train=0.6402 valid=0.6444, Acc: valid=1.0000
# Epoch 41, Loss: train=0.6287 valid=0.6377, Acc: valid=1.0000
# Epoch 42, Loss: train=0.6477 valid=0.6274, Acc: valid=1.0000
# Epoch 43, Loss: train=0.6743 valid=0.6276, Acc: valid=1.0000
# Best Epoch: 23, Best Valid Loss: 0.6270432905717329
# Valid Loss (with Epoch valid set) on Loaded Best Model: 0.6270432905717329
# Final Acc (with TEST set) on Loaded Best Model: 0.7779666780006801 (time: 0.008395550043686577)
#
# === case=4_2, backbone=resnet50 ===
# best model updated
# Epoch 1, Loss: train=1.3430 valid=1.3095, Acc: valid=0.4545
# best model updated
# Epoch 2, Loss: train=1.0112 valid=1.2366, Acc: valid=0.4545
# best model updated
# Epoch 3, Loss: train=0.9084 valid=1.0288, Acc: valid=0.7273
# Epoch 4, Loss: train=0.8328 valid=1.0648, Acc: valid=0.6364
# Epoch 5, Loss: train=0.7169 valid=1.1545, Acc: valid=0.6364
# Epoch 6, Loss: train=0.6864 valid=1.0922, Acc: valid=0.7273
# Epoch 7, Loss: train=0.7255 valid=1.2798, Acc: valid=0.2727
# Epoch 8, Loss: train=0.7425 valid=1.1337, Acc: valid=0.3636
# best model updated
# Epoch 9, Loss: train=0.6776 valid=0.9838, Acc: valid=0.8182
# best model updated
# Epoch 10, Loss: train=0.7201 valid=0.7956, Acc: valid=0.9091
# best model updated
# Epoch 11, Loss: train=0.6783 valid=0.7929, Acc: valid=0.8182
# Epoch 12, Loss: train=0.6665 valid=0.8511, Acc: valid=0.8182
# best model updated
# Epoch 13, Loss: train=0.6572 valid=0.6769, Acc: valid=1.0000
# best model updated
# Epoch 14, Loss: train=0.6480 valid=0.6338, Acc: valid=1.0000
# Epoch 15, Loss: train=0.6616 valid=0.6340, Acc: valid=1.0000
# Epoch 16, Loss: train=0.6446 valid=0.7382, Acc: valid=0.9091
# Epoch 17, Loss: train=0.6661 valid=0.7444, Acc: valid=0.9091
# Epoch 18, Loss: train=0.6641 valid=0.7913, Acc: valid=0.8182
# Epoch 19, Loss: train=0.6552 valid=0.7695, Acc: valid=0.8182
# Epoch 20, Loss: train=0.6622 valid=0.6994, Acc: valid=0.9091
# Epoch 21, Loss: train=0.6525 valid=0.8022, Acc: valid=0.8182
# Epoch 22, Loss: train=0.6520 valid=0.7300, Acc: valid=0.9091
# Epoch 23, Loss: train=0.6672 valid=0.7423, Acc: valid=0.9091
# Epoch 24, Loss: train=0.6445 valid=0.7857, Acc: valid=0.8182
# Epoch 25, Loss: train=0.6660 valid=0.7792, Acc: valid=0.8182
# Epoch 26, Loss: train=0.6378 valid=0.7637, Acc: valid=0.8182
# Epoch 27, Loss: train=0.6615 valid=0.7168, Acc: valid=0.9091
# Epoch 28, Loss: train=0.6302 valid=0.7811, Acc: valid=0.8182
# Epoch 29, Loss: train=0.6692 valid=0.7070, Acc: valid=0.9091
# Epoch 30, Loss: train=0.6557 valid=0.6885, Acc: valid=0.9091
# Epoch 31, Loss: train=0.6651 valid=0.6378, Acc: valid=1.0000
# Epoch 32, Loss: train=0.6513 valid=0.6597, Acc: valid=1.0000
# Epoch 33, Loss: train=0.6477 valid=0.6666, Acc: valid=1.0000
# best model updated
# Epoch 34, Loss: train=0.6487 valid=0.6311, Acc: valid=1.0000
# Epoch 35, Loss: train=0.6521 valid=0.6437, Acc: valid=1.0000
# Epoch 36, Loss: train=0.6504 valid=0.6442, Acc: valid=1.0000
# Epoch 37, Loss: train=0.6614 valid=0.6325, Acc: valid=1.0000
# Epoch 38, Loss: train=0.6387 valid=0.6349, Acc: valid=1.0000
# best model updated
# Epoch 39, Loss: train=0.6635 valid=0.6269, Acc: valid=1.0000
# Epoch 40, Loss: train=0.6408 valid=0.6295, Acc: valid=1.0000
# Epoch 41, Loss: train=0.6276 valid=0.6373, Acc: valid=1.0000
# Epoch 42, Loss: train=0.6553 valid=0.6329, Acc: valid=1.0000
# Epoch 43, Loss: train=0.6490 valid=0.8736, Acc: valid=0.7273
# Epoch 44, Loss: train=0.6531 valid=0.8891, Acc: valid=0.7273
# Epoch 45, Loss: train=0.6413 valid=0.7959, Acc: valid=0.7273
# Epoch 46, Loss: train=0.6508 valid=0.6945, Acc: valid=0.9091
# Epoch 47, Loss: train=0.6528 valid=0.6294, Acc: valid=1.0000
# Epoch 48, Loss: train=0.6279 valid=0.6622, Acc: valid=0.9091
# Epoch 49, Loss: train=0.6426 valid=0.6575, Acc: valid=1.0000
# Epoch 50, Loss: train=0.6410 valid=0.6308, Acc: valid=1.0000
# Epoch 51, Loss: train=0.6303 valid=0.6880, Acc: valid=0.9091
# Epoch 52, Loss: train=0.6526 valid=0.7008, Acc: valid=0.9091
# Epoch 53, Loss: train=0.6459 valid=0.7143, Acc: valid=0.9091
# Epoch 54, Loss: train=0.6584 valid=0.7273, Acc: valid=0.9091
# Epoch 55, Loss: train=0.6364 valid=0.7180, Acc: valid=0.9091
# Epoch 56, Loss: train=0.6430 valid=0.7167, Acc: valid=0.9091
# Epoch 57, Loss: train=0.6285 valid=0.7160, Acc: valid=0.9091
# Epoch 58, Loss: train=0.6457 valid=0.7304, Acc: valid=0.9091
# Best Epoch: 38, Best Valid Loss: 0.6268957744945179
# Valid Loss (with Epoch valid set) on Loaded Best Model: 0.6268957744945179
# Final Acc (with TEST set) on Loaded Best Model: 0.7844270656239375 (time: 0.013216008310732634)

# %%
result_df = pd.DataFrame(result_dict)
result_df
# Out:
#     backbone case  accuracy  inference_time
# 0   resnet18    1  0.814689        0.007934
# 1   resnet34    1  0.816729        0.008460
# 2   resnet50    1  0.880653        0.010916
# 3   resnet18    2  0.820129        0.002496
# 4   resnet34    2  0.778647        0.004177
# 5   resnet50    2  0.791227        0.005506
# 6   resnet18    3  0.732744        0.002491
# 7   resnet34    3  0.803128        0.005379
# 8   resnet50    3  0.839510        0.007449
# 9   resnet18  4_1  0.792248        0.004800
# 10  resnet34  4_1  0.726284        0.010301
# 11  resnet50  4_1  0.817069        0.011004
# 12  resnet18  4_2  0.796668        0.004813
# 13  resnet34  4_2  0.777967        0.008396
# 14  resnet50  4_2  0.784427        0.013216

# %%
result_df.to_csv(f'result_experiment_3_{TRAIN_N}.csv')
