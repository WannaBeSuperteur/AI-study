# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms

import plotly.graph_objects as go

import random
import pandas as pd
import numpy as np

# !pip install torchinfo
from torchinfo import summary
# Out:
# Collecting torchinfo
#   Downloading torchinfo-1.8.0-py3-none-any.whl.metadata (21 kB)
# Downloading torchinfo-1.8.0-py3-none-any.whl (23 kB)
# Installing collected packages: torchinfo
# Successfully installed torchinfo-1.8.0

# %%
# 경고 미 표시

import warnings
warnings.filterwarnings('ignore')

# %%
# Random Seed 고정 (학습 반복 시행 시에도 동일한 결과가 나오도록)

seed = 20251003

random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)
torch.cuda.manual_seed_all(seed)

# %%
# 데이터셋 로딩

transform = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.5,), (0.5,))])

train_dataset = torchvision.datasets.MNIST(root='./data',
                                           train=True,
                                           transform=transform,
                                           download=True)

test_dataset = torchvision.datasets.MNIST(root='./data',
                                          train=False,
                                          transform=transform,
                                          download=True)
# Out:
# 100%|██████████| 9.91M/9.91M [00:00<00:00, 38.6MB/s]
# 100%|██████████| 28.9k/28.9k [00:00<00:00, 1.66MB/s]
# 100%|██████████| 1.65M/1.65M [00:00<00:00, 14.4MB/s]
# 100%|██████████| 4.54k/4.54k [00:00<00:00, 13.3MB/s]

# %% [markdown]
# **1. 데이터셋 분석**

# %%
# 데이터셋 로딩

from torch.utils.data import DataLoader

BATCH_SIZE = 32

train_loader = DataLoader(train_dataset,
                          batch_size=BATCH_SIZE,
                          shuffle=True)

test_loader = DataLoader(test_dataset,
                         batch_size=BATCH_SIZE,
                         shuffle=False)

# %%
# 클래스 불균형 분석

# 학습 데이터
train_labels = torch.tensor(train_dataset.targets)
train_class_counts = torch.bincount(train_labels)
print(f'train data : {train_class_counts}')

# 테스트 데이터
test_labels = torch.tensor(test_dataset.targets)
test_class_counts = torch.bincount(test_labels)
print(f'test  data : {test_class_counts}')

NUM_CLASSES = len(train_class_counts)
# Out:
# train data : tensor([5923, 6742, 5958, 6131, 5842, 5421, 5918, 6265, 5851, 5949])
# test  data : tensor([ 980, 1135, 1032, 1010,  982,  892,  958, 1028,  974, 1009])

# %%
# 클래스 불균형 분석 (percentage)

train_class_percentage = np.array(train_class_counts) * 100.0 / sum(train_class_counts)

train_y_distrib = pd.DataFrame({'class': list(range(NUM_CLASSES)),
                                'count': train_class_counts,
                                'percentage (%)': train_class_percentage})

train_y_distrib
# Out:
#    class  count  percentage (%)
# 0      0   5923        9.871667
# 1      1   6742       11.236667
# 2      2   5958        9.930000
# 3      3   6131       10.218333
# 4      4   5842        9.736667
# 5      5   5421        9.035000
# 6      6   5918        9.863333
# 7      7   6265       10.441667
# 8      8   5851        9.751667
# 9      9   5949        9.915000

# %%
test_class_percentage = np.array(test_class_counts) * 100.0 / sum(test_class_counts)

test_y_distrib = pd.DataFrame({'class': list(range(NUM_CLASSES)),
                               'count': test_class_counts,
                               'percentage (%)': test_class_percentage})

test_y_distrib
# Out:
#    class  count  percentage (%)
# 0      0    980            9.80
# 1      1   1135           11.35
# 2      2   1032           10.32
# 3      3   1010           10.10
# 4      4    982            9.82
# 5      5    892            8.92
# 6      6    958            9.58
# 7      7   1028           10.28
# 8      8    974            9.74
# 9      9   1009           10.09

# %% [markdown]
# **2. 1, 7, 9 숫자 데이터만 추출**

# %%
from torch.utils.data import Subset

# train dataset
train_targets = torch.tensor(train_dataset.targets)
train_mask = (train_targets == 1) | (train_targets == 7) | (train_targets == 9)
train_indices = torch.where(train_mask)[0]

train_subset = Subset(train_dataset, train_indices)

# test dataset
test_targets = torch.tensor(test_dataset.targets)
test_mask = (test_targets == 1) | (test_targets == 7) | (test_targets == 9)
test_indices = torch.where(test_mask)[0]

test_subset = Subset(test_dataset, test_indices)

# %%
# train, test Data Loader 갱신

train_subset_loader = DataLoader(train_subset,
                                 batch_size=BATCH_SIZE,
                                 shuffle=True)

test_subset_loader = DataLoader(test_subset,
                                batch_size=BATCH_SIZE,
                                shuffle=False)

# %%
# train, test Data Loader 의 class 가 1, 7, 9 뿐인지 확인

train_subset_labels = train_subset.dataset.targets[train_subset.indices]
train_subset_class_counts = torch.bincount(train_subset_labels)
print(f'train data (subset) [1,7,9] : {train_subset_class_counts}')

test_subset_labels = test_subset.dataset.targets[test_subset.indices]
test_subset_class_counts = torch.bincount(test_subset_labels)
print(f'test  data (subset) [1,7,9] : {test_subset_class_counts}')
# Out:
# train data (subset) [1,7,9] : tensor([   0, 6742,    0,    0,    0,    0,    0, 6265,    0, 5949])
# test  data (subset) [1,7,9] : tensor([   0, 1135,    0,    0,    0,    0,    0, 1028,    0, 1009])

# %% [markdown]
# **3. CNN 모델 정의**

# %%
# 1. Non-Shared backbone & Shared head

class CNN_CASE_1(nn.Module):
    def __init__(self, backbone_1, backbone_2):
        super(CNN_CASE_1, self).__init__()

        self.backbone_1 = backbone_1
        self.backbone_2 = backbone_2
        self.final_linear = nn.Linear(2000, 3)
        self.final_softmax = nn.Softmax(dim=1)

    def forward(self, x):
        x1 = self.backbone_1(x)
        x2 = self.backbone_2(x)
        x = torch.concatenate([x1, x2], dim=1)

        x = self.final_linear(x)
        x = self.final_softmax(x)

        return x

# %%
# 2. Shared backbone & Shared head

class CNN_CASE_2(nn.Module):
    def __init__(self, backbone):
        super(CNN_CASE_2, self).__init__()

        self.backbone = backbone
        self.final_linear = nn.Linear(1000, 3)
        self.final_softmax = nn.Softmax(dim=1)

    def forward(self, x):
        x = self.backbone(x)
        x = self.final_linear(x)
        x = self.final_softmax(x)

        return x

# %%
# 3. Shared backbone & Non-Shared head

class CNN_CASE_3(nn.Module):
    def __init__(self, backbone):
        super(CNN_CASE_3, self).__init__()

        self.backbone = backbone
        self.final_linear_1 = nn.Linear(1000, 2)
        self.final_linear_2 = nn.Linear(1000, 2)
        self.final_softmax = nn.Softmax(dim=1)

    def forward(self, x):
        x = self.backbone(x)
        x1 = self.final_linear_1(x)
        x2 = self.final_linear_2(x)
        x1 = self.final_softmax(x1)
        x2 = self.final_softmax(x2)

        return x1, x2

# %%
# 4. Non-Shared backbone & Non-Shared head (4-1)

class CNN_CASE_4_1(nn.Module):
    def __init__(self, backbone_1, backbone_2):
        super(CNN_CASE_4_1, self).__init__()

        self.backbone_1 = backbone_1
        self.backbone_2 = backbone_2
        self.final_linear_1 = nn.Linear(2000, 2)
        self.final_linear_2 = nn.Linear(2000, 2)
        self.final_softmax = nn.Softmax(dim=1)

    def forward(self, x):
        x11 = self.backbone_1(x)
        x12 = self.backbone_2(x)
        x = torch.concatenate([x11, x12], dim=1)

        x21 = self.final_linear_1(x)
        x22 = self.final_linear_2(x)
        x21 = self.final_softmax(x21)
        x22 = self.final_softmax(x22)

        return x21, x22

# %%
# 5. Non-Shared backbone & Non-Shared head (4-2)

class CNN_CASE_4_2(nn.Module):
    def __init__(self, backbone_1, backbone_2):
        super(CNN_CASE_4_2, self).__init__()

        self.backbone_1 = backbone_1
        self.backbone_2 = backbone_2
        self.final_linear_1 = nn.Linear(1000, 2)
        self.final_linear_2 = nn.Linear(1000, 2)
        self.final_softmax = nn.Softmax(dim=1)

    def forward(self, x):
        x11 = self.backbone_1(x)
        x12 = self.backbone_2(x)
        x21 = self.final_linear_1(x11)
        x22 = self.final_linear_2(x12)
        x21 = self.final_softmax(x21)
        x22 = self.final_softmax(x22)

        return x21, x22

# %% [markdown]
# **4. backbone model 로딩**

# %%
import torchvision.models as models

def define_model(backbone_name, case_name, device):

    # model count
    if case_name in ['1', '4_1', '4_2']:
        model_count = 2
    else:
        model_count = 1

    # load pre-trained backbone model
    pretrained_models = []

    for _ in range(model_count):
        if backbone_name == 'resnet18':
            pretrained_model = models.resnet18(pretrained=True)

        elif backbone_name == 'resnet34':
            pretrained_model = models.resnet34(pretrained=True)

        else:  # resnet50
            pretrained_model = models.resnet50(pretrained=True)

        pretrained_model.conv1 = torch.nn.Conv2d(1, 64,
                                                 kernel_size=(7, 7),
                                                 stride=(2, 2),
                                                 padding=(3, 3),
                                                 bias=False)
        pretrained_models.append(pretrained_model)

    # define full model
    if case_name == '1':
        model = CNN_CASE_1(backbone_1=pretrained_models[0],
                           backbone_2=pretrained_models[1])

    elif case_name == '2':
        model = CNN_CASE_2(backbone=pretrained_models[0])

    elif case_name == '3':
        model = CNN_CASE_3(backbone=pretrained_models[0])

    elif case_name == '4_1':
        model = CNN_CASE_4_1(backbone_1=pretrained_models[0],
                             backbone_2=pretrained_models[1])

    elif case_name == '4_2':
        model = CNN_CASE_4_2(backbone_1=pretrained_models[0],
                             backbone_2=pretrained_models[1])

    # device & optimizer & scheduler setting
    model.to(device)
    model.optimizer = torch.optim.AdamW(model.parameters(), lr=0.0001)
    model.scheduler = torch.optim.lr_scheduler.ExponentialLR(optimizer=model.optimizer,
                                                             gamma=0.95)

    return model

# %% [markdown]
# **5. 모델 구조 출력**

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
input_size=(BATCH_SIZE, 1, 28, 28)

# %%
temp_backbone_name = 'resnet18'

# %%
# 1. Non-Shared backbone & Shared head

model_case_1 = define_model(temp_backbone_name, case_name='1', device=device)
print(summary(model=model_case_1, input_size=input_size))
# Out:
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100%|██████████| 44.7M/44.7M [00:00<00:00, 113MB/s]
# ===============================================================================================
# Layer (type:depth-idx)                        Output Shape              Param #
# ===============================================================================================
# CNN_CASE_1                                    [32, 3]                   --
# ├─ResNet: 1-1                                 [32, 1000]                --
# │    └─Conv2d: 2-1                            [32, 64, 14, 14]          3,136
# │    └─BatchNorm2d: 2-2                       [32, 64, 14, 14]          128
# │    └─ReLU: 2-3                              [32, 64, 14, 14]          --
# │    └─MaxPool2d: 2-4                         [32, 64, 7, 7]            --
# │    └─Sequential: 2-5                        [32, 64, 7, 7]            --
# │    │    └─BasicBlock: 3-1                   [32, 64, 7, 7]            73,984
# │    │    └─BasicBlock: 3-2                   [32, 64, 7, 7]            73,984
# │    └─Sequential: 2-6                        [32, 128, 4, 4]           --
# │    │    └─BasicBlock: 3-3                   [32, 128, 4, 4]           230,144
# │    │    └─BasicBlock: 3-4                   [32, 128, 4, 4]           295,424
# │    └─Sequential: 2-7                        [32, 256, 2, 2]           --
# │    │    └─BasicBlock: 3-5                   [32, 256, 2, 2]           919,040
# │    │    └─BasicBlock: 3-6                   [32, 256, 2, 2]           1,180,672
# │    └─Sequential: 2-8                        [32, 512, 1, 1]           --
# │    │    └─BasicBlock: 3-7                   [32, 512, 1, 1]           3,673,088
# │    │    └─BasicBlock: 3-8                   [32, 512, 1, 1]           4,720,640
# │    └─AdaptiveAvgPool2d: 2-9                 [32, 512, 1, 1]           --
# │    └─Linear: 2-10                           [32, 1000]                513,000
# ├─ResNet: 1-2                                 [32, 1000]                --
# │    └─Conv2d: 2-11                           [32, 64, 14, 14]          3,136
# │    └─BatchNorm2d: 2-12                      [32, 64, 14, 14]          128
# │    └─ReLU: 2-13                             [32, 64, 14, 14]          --
# │    └─MaxPool2d: 2-14                        [32, 64, 7, 7]            --
# │    └─Sequential: 2-15                       [32, 64, 7, 7]            --
# │    │    └─BasicBlock: 3-9                   [32, 64, 7, 7]            73,984
# │    │    └─BasicBlock: 3-10                  [32, 64, 7, 7]            73,984
# │    └─Sequential: 2-16                       [32, 128, 4, 4]           --
# │    │    └─BasicBlock: 3-11                  [32, 128, 4, 4]           230,144
# │    │    └─BasicBlock: 3-12                  [32, 128, 4, 4]           295,424
# │    └─Sequential: 2-17                       [32, 256, 2, 2]           --
# │    │    └─BasicBlock: 3-13                  [32, 256, 2, 2]           919,040
# │    │    └─BasicBlock: 3-14                  [32, 256, 2, 2]           1,180,672
# │    └─Sequential: 2-18                       [32, 512, 1, 1]           --
# │    │    └─BasicBlock: 3-15                  [32, 512, 1, 1]           3,673,088
# │    │    └─BasicBlock: 3-16                  [32, 512, 1, 1]           4,720,640
# │    └─AdaptiveAvgPool2d: 2-19                [32, 512, 1, 1]           --
# │    └─Linear: 2-20                           [32, 1000]                513,000
# ├─Linear: 1-3                                 [32, 3]                   6,003
# ├─Softmax: 1-4                                [32, 3]                   --
# ===============================================================================================
# Total params: 23,372,483
# Trainable params: 23,372,483
# Non-trainable params: 0
# Total mult-adds (Units.GIGABYTES): 2.15
# ===============================================================================================
# Input size (MB): 0.10
# Forward/backward pass size (MB): 44.55
# Params size (MB): 93.49
# Estimated Total Size (MB): 138.14
# ===============================================================================================

# %%
# 2. Shared backbone & Shared head

model_case_2 = define_model(temp_backbone_name, case_name='2', device=device)
print(summary(model=model_case_2, input_size=input_size))
# Out:
# ===============================================================================================
# Layer (type:depth-idx)                        Output Shape              Param #
# ===============================================================================================
# CNN_CASE_2                                    [32, 3]                   --
# ├─ResNet: 1-1                                 [32, 1000]                --
# │    └─Conv2d: 2-1                            [32, 64, 14, 14]          3,136
# │    └─BatchNorm2d: 2-2                       [32, 64, 14, 14]          128
# │    └─ReLU: 2-3                              [32, 64, 14, 14]          --
# │    └─MaxPool2d: 2-4                         [32, 64, 7, 7]            --
# │    └─Sequential: 2-5                        [32, 64, 7, 7]            --
# │    │    └─BasicBlock: 3-1                   [32, 64, 7, 7]            73,984
# │    │    └─BasicBlock: 3-2                   [32, 64, 7, 7]            73,984
# │    └─Sequential: 2-6                        [32, 128, 4, 4]           --
# │    │    └─BasicBlock: 3-3                   [32, 128, 4, 4]           230,144
# │    │    └─BasicBlock: 3-4                   [32, 128, 4, 4]           295,424
# │    └─Sequential: 2-7                        [32, 256, 2, 2]           --
# │    │    └─BasicBlock: 3-5                   [32, 256, 2, 2]           919,040
# │    │    └─BasicBlock: 3-6                   [32, 256, 2, 2]           1,180,672
# │    └─Sequential: 2-8                        [32, 512, 1, 1]           --
# │    │    └─BasicBlock: 3-7                   [32, 512, 1, 1]           3,673,088
# │    │    └─BasicBlock: 3-8                   [32, 512, 1, 1]           4,720,640
# │    └─AdaptiveAvgPool2d: 2-9                 [32, 512, 1, 1]           --
# │    └─Linear: 2-10                           [32, 1000]                513,000
# ├─Linear: 1-2                                 [32, 3]                   3,003
# ├─Softmax: 1-3                                [32, 3]                   --
# ===============================================================================================
# Total params: 11,686,243
# Trainable params: 11,686,243
# Non-trainable params: 0
# Total mult-adds (Units.GIGABYTES): 1.07
# ===============================================================================================
# Input size (MB): 0.10
# Forward/backward pass size (MB): 22.28
# Params size (MB): 46.74
# Estimated Total Size (MB): 69.12
# ===============================================================================================

# %%
# 3. Shared backbone & Non-Shared head

model_case_3 = define_model(temp_backbone_name, case_name='3', device=device)
print(summary(model=model_case_3, input_size=input_size))
# Out:
# ===============================================================================================
# Layer (type:depth-idx)                        Output Shape              Param #
# ===============================================================================================
# CNN_CASE_3                                    [32, 2]                   --
# ├─ResNet: 1-1                                 [32, 1000]                --
# │    └─Conv2d: 2-1                            [32, 64, 14, 14]          3,136
# │    └─BatchNorm2d: 2-2                       [32, 64, 14, 14]          128
# │    └─ReLU: 2-3                              [32, 64, 14, 14]          --
# │    └─MaxPool2d: 2-4                         [32, 64, 7, 7]            --
# │    └─Sequential: 2-5                        [32, 64, 7, 7]            --
# │    │    └─BasicBlock: 3-1                   [32, 64, 7, 7]            73,984
# │    │    └─BasicBlock: 3-2                   [32, 64, 7, 7]            73,984
# │    └─Sequential: 2-6                        [32, 128, 4, 4]           --
# │    │    └─BasicBlock: 3-3                   [32, 128, 4, 4]           230,144
# │    │    └─BasicBlock: 3-4                   [32, 128, 4, 4]           295,424
# │    └─Sequential: 2-7                        [32, 256, 2, 2]           --
# │    │    └─BasicBlock: 3-5                   [32, 256, 2, 2]           919,040
# │    │    └─BasicBlock: 3-6                   [32, 256, 2, 2]           1,180,672
# │    └─Sequential: 2-8                        [32, 512, 1, 1]           --
# │    │    └─BasicBlock: 3-7                   [32, 512, 1, 1]           3,673,088
# │    │    └─BasicBlock: 3-8                   [32, 512, 1, 1]           4,720,640
# │    └─AdaptiveAvgPool2d: 2-9                 [32, 512, 1, 1]           --
# │    └─Linear: 2-10                           [32, 1000]                513,000
# ├─Linear: 1-2                                 [32, 2]                   2,002
# ├─Linear: 1-3                                 [32, 2]                   2,002
# ├─Softmax: 1-4                                [32, 2]                   --
# ├─Softmax: 1-5                                [32, 2]                   --
# ===============================================================================================
# Total params: 11,687,244
# Trainable params: 11,687,244
# Non-trainable params: 0
# Total mult-adds (Units.GIGABYTES): 1.07
# ===============================================================================================
# Input size (MB): 0.10
# Forward/backward pass size (MB): 22.28
# Params size (MB): 46.75
# Estimated Total Size (MB): 69.13
# ===============================================================================================

# %%
# 4. Non-Shared backbone & Non-Shared head (4-1)

model_case_4_1 = define_model(temp_backbone_name, case_name='4_1', device=device)
print(summary(model=model_case_4_1, input_size=input_size))
# Out:
# ===============================================================================================
# Layer (type:depth-idx)                        Output Shape              Param #
# ===============================================================================================
# CNN_CASE_4_1                                  [32, 2]                   --
# ├─ResNet: 1-1                                 [32, 1000]                --
# │    └─Conv2d: 2-1                            [32, 64, 14, 14]          3,136
# │    └─BatchNorm2d: 2-2                       [32, 64, 14, 14]          128
# │    └─ReLU: 2-3                              [32, 64, 14, 14]          --
# │    └─MaxPool2d: 2-4                         [32, 64, 7, 7]            --
# │    └─Sequential: 2-5                        [32, 64, 7, 7]            --
# │    │    └─BasicBlock: 3-1                   [32, 64, 7, 7]            73,984
# │    │    └─BasicBlock: 3-2                   [32, 64, 7, 7]            73,984
# │    └─Sequential: 2-6                        [32, 128, 4, 4]           --
# │    │    └─BasicBlock: 3-3                   [32, 128, 4, 4]           230,144
# │    │    └─BasicBlock: 3-4                   [32, 128, 4, 4]           295,424
# │    └─Sequential: 2-7                        [32, 256, 2, 2]           --
# │    │    └─BasicBlock: 3-5                   [32, 256, 2, 2]           919,040
# │    │    └─BasicBlock: 3-6                   [32, 256, 2, 2]           1,180,672
# │    └─Sequential: 2-8                        [32, 512, 1, 1]           --
# │    │    └─BasicBlock: 3-7                   [32, 512, 1, 1]           3,673,088
# │    │    └─BasicBlock: 3-8                   [32, 512, 1, 1]           4,720,640
# │    └─AdaptiveAvgPool2d: 2-9                 [32, 512, 1, 1]           --
# │    └─Linear: 2-10                           [32, 1000]                513,000
# ├─ResNet: 1-2                                 [32, 1000]                --
# │    └─Conv2d: 2-11                           [32, 64, 14, 14]          3,136
# │    └─BatchNorm2d: 2-12                      [32, 64, 14, 14]          128
# │    └─ReLU: 2-13                             [32, 64, 14, 14]          --
# │    └─MaxPool2d: 2-14                        [32, 64, 7, 7]            --
# │    └─Sequential: 2-15                       [32, 64, 7, 7]            --
# │    │    └─BasicBlock: 3-9                   [32, 64, 7, 7]            73,984
# │    │    └─BasicBlock: 3-10                  [32, 64, 7, 7]            73,984
# │    └─Sequential: 2-16                       [32, 128, 4, 4]           --
# │    │    └─BasicBlock: 3-11                  [32, 128, 4, 4]           230,144
# │    │    └─BasicBlock: 3-12                  [32, 128, 4, 4]           295,424
# │    └─Sequential: 2-17                       [32, 256, 2, 2]           --
# │    │    └─BasicBlock: 3-13                  [32, 256, 2, 2]           919,040
# │    │    └─BasicBlock: 3-14                  [32, 256, 2, 2]           1,180,672
# │    └─Sequential: 2-18                       [32, 512, 1, 1]           --
# │    │    └─BasicBlock: 3-15                  [32, 512, 1, 1]           3,673,088
# │    │    └─BasicBlock: 3-16                  [32, 512, 1, 1]           4,720,640
# │    └─AdaptiveAvgPool2d: 2-19                [32, 512, 1, 1]           --
# │    └─Linear: 2-20                           [32, 1000]                513,000
# ├─Linear: 1-3                                 [32, 2]                   4,002
# ├─Linear: 1-4                                 [32, 2]                   4,002
# ├─Softmax: 1-5                                [32, 2]                   --
# ├─Softmax: 1-6                                [32, 2]                   --
# ===============================================================================================
# Total params: 23,374,484
# Trainable params: 23,374,484
# Non-trainable params: 0
# Total mult-adds (Units.GIGABYTES): 2.15
# ===============================================================================================
# Input size (MB): 0.10
# Forward/backward pass size (MB): 44.55
# Params size (MB): 93.50
# Estimated Total Size (MB): 138.15
# ===============================================================================================

# %%
# 5. Non-Shared backbone & Non-Shared head (4-2)

model_case_4_2 = define_model(temp_backbone_name, case_name='4_2', device=device)
print(summary(model=model_case_4_2, input_size=input_size))
# Out:
# ===============================================================================================
# Layer (type:depth-idx)                        Output Shape              Param #
# ===============================================================================================
# CNN_CASE_4_2                                  [32, 2]                   --
# ├─ResNet: 1-1                                 [32, 1000]                --
# │    └─Conv2d: 2-1                            [32, 64, 14, 14]          3,136
# │    └─BatchNorm2d: 2-2                       [32, 64, 14, 14]          128
# │    └─ReLU: 2-3                              [32, 64, 14, 14]          --
# │    └─MaxPool2d: 2-4                         [32, 64, 7, 7]            --
# │    └─Sequential: 2-5                        [32, 64, 7, 7]            --
# │    │    └─BasicBlock: 3-1                   [32, 64, 7, 7]            73,984
# │    │    └─BasicBlock: 3-2                   [32, 64, 7, 7]            73,984
# │    └─Sequential: 2-6                        [32, 128, 4, 4]           --
# │    │    └─BasicBlock: 3-3                   [32, 128, 4, 4]           230,144
# │    │    └─BasicBlock: 3-4                   [32, 128, 4, 4]           295,424
# │    └─Sequential: 2-7                        [32, 256, 2, 2]           --
# │    │    └─BasicBlock: 3-5                   [32, 256, 2, 2]           919,040
# │    │    └─BasicBlock: 3-6                   [32, 256, 2, 2]           1,180,672
# │    └─Sequential: 2-8                        [32, 512, 1, 1]           --
# │    │    └─BasicBlock: 3-7                   [32, 512, 1, 1]           3,673,088
# │    │    └─BasicBlock: 3-8                   [32, 512, 1, 1]           4,720,640
# │    └─AdaptiveAvgPool2d: 2-9                 [32, 512, 1, 1]           --
# │    └─Linear: 2-10                           [32, 1000]                513,000
# ├─ResNet: 1-2                                 [32, 1000]                --
# │    └─Conv2d: 2-11                           [32, 64, 14, 14]          3,136
# │    └─BatchNorm2d: 2-12                      [32, 64, 14, 14]          128
# │    └─ReLU: 2-13                             [32, 64, 14, 14]          --
# │    └─MaxPool2d: 2-14                        [32, 64, 7, 7]            --
# │    └─Sequential: 2-15                       [32, 64, 7, 7]            --
# │    │    └─BasicBlock: 3-9                   [32, 64, 7, 7]            73,984
# │    │    └─BasicBlock: 3-10                  [32, 64, 7, 7]            73,984
# │    └─Sequential: 2-16                       [32, 128, 4, 4]           --
# │    │    └─BasicBlock: 3-11                  [32, 128, 4, 4]           230,144
# │    │    └─BasicBlock: 3-12                  [32, 128, 4, 4]           295,424
# │    └─Sequential: 2-17                       [32, 256, 2, 2]           --
# │    │    └─BasicBlock: 3-13                  [32, 256, 2, 2]           919,040
# │    │    └─BasicBlock: 3-14                  [32, 256, 2, 2]           1,180,672
# │    └─Sequential: 2-18                       [32, 512, 1, 1]           --
# │    │    └─BasicBlock: 3-15                  [32, 512, 1, 1]           3,673,088
# │    │    └─BasicBlock: 3-16                  [32, 512, 1, 1]           4,720,640
# │    └─AdaptiveAvgPool2d: 2-19                [32, 512, 1, 1]           --
# │    └─Linear: 2-20                           [32, 1000]                513,000
# ├─Linear: 1-3                                 [32, 2]                   2,002
# ├─Linear: 1-4                                 [32, 2]                   2,002
# ├─Softmax: 1-5                                [32, 2]                   --
# ├─Softmax: 1-6                                [32, 2]                   --
# ===============================================================================================
# Total params: 23,370,484
# Trainable params: 23,370,484
# Non-trainable params: 0
# Total mult-adds (Units.GIGABYTES): 2.15
# ===============================================================================================
# Input size (MB): 0.10
# Forward/backward pass size (MB): 44.55
# Params size (MB): 93.48
# Estimated Total Size (MB): 138.14
# ===============================================================================================

# %% [markdown]
# **6. 데이터셋 분리**
#
# * Train Data -> Train Data + Valid Data

# %%
# dataset size

num_tv = sum(train_subset_class_counts)
num_valid = int(0.1 * num_tv)
num_train = num_tv - num_valid

# %%
# 데이터셋 분리

from torch.utils.data import random_split

train_dataset, valid_dataset = random_split(train_subset, [num_train, num_valid])

# %%
# {0,1,2} -> {1,7,9} Mapping 된 DataLoader 생성

from torch.utils.data import Dataset

class MappedDataset(Dataset):
    def __init__(self, dataset):
        self.dataset = dataset

    def __len__(self):
        return len(self.dataset)

    def __getitem__(self, idx):
        img, target = self.dataset[idx]
        target_mapping = {1: 0, 7: 1, 9: 2}
        target = target_mapping[target]

        return img, target

# %%
# DataLoader 생성

train_dataset_loader = DataLoader(MappedDataset(train_dataset),
                                  batch_size=BATCH_SIZE,
                                  shuffle=True)

valid_dataset_loader = DataLoader(MappedDataset(valid_dataset),
                                  batch_size=BATCH_SIZE,
                                  shuffle=False)

test_dataset_loader = DataLoader(MappedDataset(test_subset),
                                 batch_size=BATCH_SIZE,
                                 shuffle=False)

# %%
# {1,7} vs. {9} / {1,9} vs. {7} Split 된 DataLoader 생성

class DualOutputDataset(Dataset):
    def __init__(self, dataset):
        self.dataset = dataset

    def __len__(self):
        return len(self.dataset)

    def __getitem__(self, idx):
        img, target = self.dataset[idx]
        target1_mapping = {1: 0, 7: 0, 9: 1}
        target2_mapping = {1: 0, 7: 1, 9: 0}

        target1 = target1_mapping[target]
        target2 = target2_mapping[target]

        return img, [target1, target2]

# %%
# Dual Output Dataset 생성

train_01_02_dataset_loader = DataLoader(DualOutputDataset(train_dataset),
                                        batch_size=BATCH_SIZE,
                                        shuffle=True)

valid_01_02_dataset_loader = DataLoader(DualOutputDataset(valid_dataset),
                                        batch_size=BATCH_SIZE,
                                        shuffle=False)

test_01_02_dataset_loader = DataLoader(DualOutputDataset(test_subset),
                                       batch_size=BATCH_SIZE,
                                       shuffle=False)

# %% [markdown]
# **7. 모델 학습 함수 정의**

# %%
MAX_EPOCHS = 9999
EARLY_STOPPING_ROUNDS = 10  # Early Stopping Patience (epochs)

# %%
# dual labels -> PyTorch tensor

def convert_to_tensor(labels):
    labels[0] = list(labels[0])
    labels[1] = list(labels[1])
    labels_tensor = torch.tensor(labels)
    labels_tensor = labels_tensor.transpose(0, 1)

    return labels_tensor

# %%
# 모델 학습 실시

# args :
# - model           : 학습할 모델
# - train_loader    : Training Data Loader
# - train_loss_list : 각 epoch 에서의 train loss 기록
# - is_dual_head    : 신경망 출력값, 즉 MLP Head 가 2개인지의 여부

# returns :
# - train_loss : 모델의 Train Loss

def run_train(model, train_loader, train_loss_list, is_dual_head, verbose):
    model.train()
    train_loss = 0.0
    train_idx = 0

    for images, labels in train_loader:
        if is_dual_head:
            labels = convert_to_tensor(labels)
        images, labels = images.to(device), labels.to(device)

        # train 실시
        model.optimizer.zero_grad()
        outputs = model(images)

        if is_dual_head:
            loss1 = nn.CrossEntropyLoss()(outputs[0], labels[:, 0])
            loss2 = nn.CrossEntropyLoss()(outputs[1], labels[:, 1])
            loss = loss1 + loss2
        else:
            loss = nn.CrossEntropyLoss()(outputs, labels)

        loss.backward()
        model.optimizer.step()

        train_loss += loss.item()
        train_idx += 1

        if verbose:
            if train_idx % 20 == 0:
                print(f'idx: {train_idx}, loss for current idx: {loss.item():.6f}')

    train_loss_list.append(train_loss / len(train_loader))
    return train_loss_list[-1]

# %%
import time

# 모델 validation / test 실시

# args :
# - model                : validation/test 할 모델
# - valid_or_test_loader : validation/test Data Loader
# - is_dual_head         : 신경망 출력값, 즉 MLP Head 가 2개인지의 여부

# returns :
# - accuracy       : 모델의 validation/test 정확도
# - inference_time : inference 시간 (seconds)

def run_valid_or_test(model, valid_or_test_loader, is_dual_head):
    model.eval()
    correct, total = 0, 0
    inference_time_sum = 0.0
    valid_test_idx = 0

    with torch.no_grad():
        for images, labels in valid_or_test_loader:
            if is_dual_head:
                labels = convert_to_tensor(labels)
            images, labels = images.to(device), labels.to(device)

            start_at = time.time()
            outputs = model(images)
            inference_time_sum += time.time() - start_at

            # validation/test 실시 및 정확도 측정
            if is_dual_head:
                _, predicted_1 = torch.max(outputs[0], 1)
                _, predicted_2 = torch.max(outputs[1], 1)
                correct += ((predicted_1 == labels[:, 0]) & (predicted_2 == labels[:, 1])).sum().item()

            else:
                _, predicted = torch.max(outputs, 1)
                correct += (predicted == labels).sum().item()

            total += labels.size(0)
            valid_test_idx += 1

    accuracy = correct / total
    inference_time = inference_time_sum / valid_test_idx

    return accuracy, inference_time

# %%
# 모델 학습 및 validation 전체 프로세스

# args :
# - model         : 학습할 모델
# - train_loader  : Training Data Loader
# - valid_loader  : Valid Data Loader
# - test_loader   : Test Data Loader
# - backbone_name : Backbone 모델 이름 ('resnet18', 'resnet34' or 'resnet50')
# - case_name     : 모델 구조 case 이름 ('1', '2', '3', '4_1' or '4_2')
# - verbose       : 학습 중 프로세스 출력 여부

# returns :
# - final_acc      : 해당 하이퍼파라미터 조합에 대한 최종 Accuracy (valid_acc 이 가장 높았던 epoch 의 모델로 측정)
# - inference_time : inference 시간 (seconds)

def run_model_common(model, train_loader, valid_loader, test_loader,
                     backbone_name, case_name, verbose=False):

    train_loss_list = []       # train loss
    valid_acc_list = []        # valid accuracy
    max_valid_acc = 0.0        # max validation accuracy
    best_valid_acc_epoch = -1  # valid_acc 이 가장 높았던 epoch (여기서는 Loss 가 아닌 Accuracy 기준 Early Stopping)
    best_epoch_model = None    # valid_acc 이 가장 높았던 epoch 의 모델

    is_dual_head = case_name in ['3', '4_1', '4_2']

    # 1. 학습 실시
    for epoch in range(MAX_EPOCHS):

        # 1-1. train model
        train_loss = run_train(model,
                               train_loader,
                               train_loss_list,
                               is_dual_head,
                               verbose=(verbose and epoch == 0))

        # 1-2. validate model (with VALID SET)
        epoch_acc, _ = run_valid_or_test(model, valid_loader, is_dual_head)
        valid_acc_list.append(epoch_acc)

        # 1-3. Early Stopping 처리 (overfitting 방지)
        if epoch_acc > max_valid_acc:
            max_valid_acc = epoch_acc
            best_valid_acc_epoch = epoch

            best_epoch_model = define_model(backbone_name, case_name, device)
            best_epoch_model.load_state_dict(model.state_dict())

            if verbose:
                print('best model updated')

        if epoch - best_valid_acc_epoch >= EARLY_STOPPING_ROUNDS:
            break

        # 1-4. 결과 출력
        if verbose:
            print(f"Epoch {epoch+1}, Loss: {train_loss:.4f}, Accuracy: {epoch_acc:.4f}")

    # check best-epoch model correctly loaded
    checked_acc, _ = run_valid_or_test(best_epoch_model, valid_loader, is_dual_head)

    if verbose:
        print(f"Best Epoch: {best_valid_acc_epoch}, Best Valid Acc: {max_valid_acc}")
        print(f"Valid Acc (with Epoch valid set) on Loaded Best Model: {checked_acc}")

    assert abs(max_valid_acc - checked_acc) < 1e-6

    # 2. test best-epoch model (with TEST SET)
    final_acc, inference_time = run_valid_or_test(best_epoch_model, test_loader, is_dual_head)

    if verbose:
        print(f"Final Acc (with TEST set) on Loaded Best Model: {final_acc} (time: {inference_time})")

    return final_acc, inference_time

# %% [markdown]
# **8. 학습 실시**

# %%
print(device)
# Out:
# cuda

# %%
result_dict = {
    'backbone': [],
    'case': [],
    'accuracy': [],
    'inference_time': []
}

dataloader_by_case_name = {
    'dual_head': {
        'train': train_01_02_dataset_loader,
        'valid': valid_01_02_dataset_loader,
        'test': test_01_02_dataset_loader
    },
    'single_head': {
        'train': train_dataset_loader,
        'valid': valid_dataset_loader,
        'test': test_dataset_loader
    }
}

for case_name in ['1', '2', '3', '4_1', '4_2']:
    if case_name in ['3', '4_1', '4_2']:
        head_type = 'dual_head'
    else:
        head_type = 'single_head'

    for backbone_name in ['resnet18', 'resnet34', 'resnet50']:
        print(f'\n=== case={case_name}, backbone={backbone_name} ===')
        model = define_model(backbone_name, case_name, device=device)

        train_loader = dataloader_by_case_name[head_type]['train']
        valid_loader = dataloader_by_case_name[head_type]['valid']
        test_loader = dataloader_by_case_name[head_type]['test']

        final_acc, inference_time = run_model_common(model,
                                                     train_loader=train_loader,
                                                     valid_loader=valid_loader,
                                                     test_loader=test_loader,
                                                     backbone_name=backbone_name,
                                                     case_name=case_name,
                                                     verbose=True)

        result_dict['backbone'].append(backbone_name)
        result_dict['case'].append(case_name)
        result_dict['accuracy'].append(final_acc)
        result_dict['inference_time'].append(inference_time)
# Out:
# === case=1, backbone=resnet18 ===
# idx: 20, loss for current idx: 0.709649
# idx: 40, loss for current idx: 0.683735
# idx: 60, loss for current idx: 0.655797
# idx: 80, loss for current idx: 0.580977
# idx: 100, loss for current idx: 0.579376
# idx: 120, loss for current idx: 0.644863
# idx: 140, loss for current idx: 0.615864
# idx: 160, loss for current idx: 0.676720
# idx: 180, loss for current idx: 0.633137
# idx: 200, loss for current idx: 0.629233
# idx: 220, loss for current idx: 0.562981
# idx: 240, loss for current idx: 0.551501
# idx: 260, loss for current idx: 0.551481
# idx: 280, loss for current idx: 0.551470
# idx: 300, loss for current idx: 0.582251
# idx: 320, loss for current idx: 0.581918
# idx: 340, loss for current idx: 0.626650
# idx: 360, loss for current idx: 0.612713
# idx: 380, loss for current idx: 0.551622
# idx: 400, loss for current idx: 0.637668
# idx: 420, loss for current idx: 0.575965
# idx: 440, loss for current idx: 0.551744
# idx: 460, loss for current idx: 0.645198
# idx: 480, loss for current idx: 0.583440
# idx: 500, loss for current idx: 0.587529
# idx: 520, loss for current idx: 0.551445
# best model updated
# Epoch 1, Loss: 0.6042, Accuracy: 0.9736
# best model updated
# Epoch 2, Loss: 0.5807, Accuracy: 0.9815
# Epoch 3, Loss: 0.5749, Accuracy: 0.9784
# best model updated
# Epoch 4, Loss: 0.5665, Accuracy: 0.9852
# best model updated
# Epoch 5, Loss: 0.5640, Accuracy: 0.9889
# Epoch 6, Loss: 0.5638, Accuracy: 0.9858
# Epoch 7, Loss: 0.5630, Accuracy: 0.9831
# Epoch 8, Loss: 0.5657, Accuracy: 0.9773
# best model updated
# Epoch 9, Loss: 0.5634, Accuracy: 0.9926
# Epoch 10, Loss: 0.5671, Accuracy: 0.9810
# Epoch 11, Loss: 0.5645, Accuracy: 0.9905
# Epoch 12, Loss: 0.5606, Accuracy: 0.9858
# Epoch 13, Loss: 0.5647, Accuracy: 0.9916
# Epoch 14, Loss: 0.5736, Accuracy: 0.9794
# Epoch 15, Loss: 0.5676, Accuracy: 0.9916
# Epoch 16, Loss: 0.5618, Accuracy: 0.9831
# Epoch 17, Loss: 0.5653, Accuracy: 0.9879
# Epoch 18, Loss: 0.5615, Accuracy: 0.9900
# Best Epoch: 8, Best Valid Acc: 0.9926121372031662
# Valid Acc (with Epoch valid set) on Loaded Best Model: 0.9926121372031662
# Final Acc (with TEST set) on Loaded Best Model: 0.9908575031525851 (time: 0.005272750854492188)
#
# === case=1, backbone=resnet34 ===
# Downloading: "https://download.pytorch.org/models/resnet34-b627a593.pth" to /root/.cache/torch/hub/checkpoints/resnet34-b627a593.pth
# 100%|██████████| 83.3M/83.3M [00:00<00:00, 178MB/s]
# idx: 20, loss for current idx: 0.636999
# idx: 40, loss for current idx: 0.651166
# idx: 60, loss for current idx: 0.644292
# idx: 80, loss for current idx: 0.571429
# idx: 100, loss for current idx: 0.583560
# idx: 120, loss for current idx: 0.624203
# idx: 140, loss for current idx: 0.578620
# idx: 160, loss for current idx: 0.583203
# idx: 180, loss for current idx: 0.579308
# idx: 200, loss for current idx: 0.670044
# idx: 220, loss for current idx: 0.635276
# idx: 240, loss for current idx: 0.587485
# idx: 260, loss for current idx: 0.585025
# idx: 280, loss for current idx: 0.561412
# idx: 300, loss for current idx: 0.582272
# idx: 320, loss for current idx: 0.611119
# idx: 340, loss for current idx: 0.592693
# idx: 360, loss for current idx: 0.554193
# idx: 380, loss for current idx: 0.614022
# idx: 400, loss for current idx: 0.648181
# idx: 420, loss for current idx: 0.551753
# idx: 440, loss for current idx: 0.582705
# idx: 460, loss for current idx: 0.583032
# idx: 480, loss for current idx: 0.628486
# idx: 500, loss for current idx: 0.551549
# idx: 520, loss for current idx: 0.583112
# best model updated
# Epoch 1, Loss: 0.6020, Accuracy: 0.9652
# best model updated
# Epoch 2, Loss: 0.5834, Accuracy: 0.9805
# best model updated
# Epoch 3, Loss: 0.5669, Accuracy: 0.9810
# best model updated
# Epoch 4, Loss: 0.5756, Accuracy: 0.9842
# best model updated
# Epoch 5, Loss: 0.5644, Accuracy: 0.9894
# best model updated
# Epoch 6, Loss: 0.5631, Accuracy: 0.9916
# Epoch 7, Loss: 0.5625, Accuracy: 0.9900
# Epoch 8, Loss: 0.5646, Accuracy: 0.9900
# best model updated
# Epoch 9, Loss: 0.5662, Accuracy: 0.9931
# Epoch 10, Loss: 0.5651, Accuracy: 0.9905
# Epoch 11, Loss: 0.5608, Accuracy: 0.9921
# best model updated
# Epoch 12, Loss: 0.5617, Accuracy: 0.9942
# Epoch 13, Loss: 0.5701, Accuracy: 0.9863
# Epoch 14, Loss: 0.5703, Accuracy: 0.9641
# Epoch 15, Loss: 0.5764, Accuracy: 0.9863
# Epoch 16, Loss: 0.5631, Accuracy: 0.9921
# Epoch 17, Loss: 0.5638, Accuracy: 0.9926
# Epoch 18, Loss: 0.5615, Accuracy: 0.9900
# Epoch 19, Loss: 0.5629, Accuracy: 0.9937
# best model updated
# Epoch 20, Loss: 0.5629, Accuracy: 0.9947
# Epoch 21, Loss: 0.5645, Accuracy: 0.9699
# Epoch 22, Loss: 0.5859, Accuracy: 0.9530
# Epoch 23, Loss: 0.5715, Accuracy: 0.9916
# best model updated
# Epoch 24, Loss: 0.5634, Accuracy: 0.9953
# Epoch 25, Loss: 0.5642, Accuracy: 0.9931
# Epoch 26, Loss: 0.5608, Accuracy: 0.9847
# Epoch 27, Loss: 0.5614, Accuracy: 0.9926
# Epoch 28, Loss: 0.5822, Accuracy: 0.9847
# Epoch 29, Loss: 0.5640, Accuracy: 0.9905
# Epoch 30, Loss: 0.5620, Accuracy: 0.9916
# Epoch 31, Loss: 0.5672, Accuracy: 0.9916
# Epoch 32, Loss: 0.5601, Accuracy: 0.9905
# Epoch 33, Loss: 0.5621, Accuracy: 0.9863
# Best Epoch: 23, Best Valid Acc: 0.9952506596306069
# Valid Acc (with Epoch valid set) on Loaded Best Model: 0.9952506596306069
# Final Acc (with TEST set) on Loaded Best Model: 0.9959016393442623 (time: 0.008936421871185303)
#
# === case=1, backbone=resnet50 ===
# Downloading: "https://download.pytorch.org/models/resnet50-0676ba61.pth" to /root/.cache/torch/hub/checkpoints/resnet50-0676ba61.pth
# 100%|██████████| 97.8M/97.8M [00:00<00:00, 168MB/s]
# idx: 20, loss for current idx: 0.672161
# idx: 40, loss for current idx: 0.709058
# idx: 60, loss for current idx: 0.628357
# idx: 80, loss for current idx: 0.699933
# idx: 100, loss for current idx: 0.573921
# idx: 120, loss for current idx: 0.600026
# idx: 140, loss for current idx: 0.592592
# idx: 160, loss for current idx: 0.669680
# idx: 180, loss for current idx: 0.564579
# idx: 200, loss for current idx: 0.644392
# idx: 220, loss for current idx: 0.676676
# idx: 240, loss for current idx: 0.561523
# idx: 260, loss for current idx: 0.630410
# idx: 280, loss for current idx: 0.645037
# idx: 300, loss for current idx: 0.582783
# idx: 320, loss for current idx: 0.572731
# idx: 340, loss for current idx: 0.580038
# idx: 360, loss for current idx: 0.609635
# idx: 380, loss for current idx: 0.611568
# idx: 400, loss for current idx: 0.689822
# idx: 420, loss for current idx: 0.582743
# idx: 440, loss for current idx: 0.718257
# idx: 460, loss for current idx: 0.796166
# idx: 480, loss for current idx: 0.551457
# idx: 500, loss for current idx: 0.603350
# idx: 520, loss for current idx: 0.570446
# best model updated
# Epoch 1, Loss: 0.6159, Accuracy: 0.9662
# best model updated
# Epoch 2, Loss: 0.5813, Accuracy: 0.9868
# Epoch 3, Loss: 0.5795, Accuracy: 0.9826
# Epoch 4, Loss: 0.5682, Accuracy: 0.9847
# Epoch 5, Loss: 0.5690, Accuracy: 0.9799
# best model updated
# Epoch 6, Loss: 0.5653, Accuracy: 0.9900
# best model updated
# Epoch 7, Loss: 0.5631, Accuracy: 0.9916
# Epoch 8, Loss: 0.5597, Accuracy: 0.9889
# Epoch 9, Loss: 0.5661, Accuracy: 0.9910
# Epoch 10, Loss: 0.5632, Accuracy: 0.9884
# Epoch 11, Loss: 0.5630, Accuracy: 0.9894
# Epoch 12, Loss: 0.5602, Accuracy: 0.9894
# Epoch 13, Loss: 0.5604, Accuracy: 0.9905
# Epoch 14, Loss: 0.5600, Accuracy: 0.9847
# best model updated
# Epoch 15, Loss: 0.5572, Accuracy: 0.9953
# Epoch 16, Loss: 0.5584, Accuracy: 0.9926
# Epoch 17, Loss: 0.5635, Accuracy: 0.9926
# Epoch 18, Loss: 0.5601, Accuracy: 0.9921
# Epoch 19, Loss: 0.5601, Accuracy: 0.9953
# Epoch 20, Loss: 0.5590, Accuracy: 0.9937
# Epoch 21, Loss: 0.5616, Accuracy: 0.9894
# Epoch 22, Loss: 0.5572, Accuracy: 0.9916
# Epoch 23, Loss: 0.5575, Accuracy: 0.9894
# Epoch 24, Loss: 0.5597, Accuracy: 0.9937
# Best Epoch: 14, Best Valid Acc: 0.9952506596306069
# Valid Acc (with Epoch valid set) on Loaded Best Model: 0.9952506596306069
# Final Acc (with TEST set) on Loaded Best Model: 0.9943253467843631 (time: 0.012169497013092041)
#
# === case=2, backbone=resnet18 ===
# idx: 20, loss for current idx: 0.694297
# idx: 40, loss for current idx: 0.635974
# idx: 60, loss for current idx: 0.592142
# idx: 80, loss for current idx: 0.615242
# idx: 100, loss for current idx: 0.564799
# idx: 120, loss for current idx: 0.618219
# idx: 140, loss for current idx: 0.583415
# idx: 160, loss for current idx: 0.591839
# idx: 180, loss for current idx: 0.552582
# idx: 200, loss for current idx: 0.552329
# idx: 220, loss for current idx: 0.582720
# idx: 240, loss for current idx: 0.586885
# idx: 260, loss for current idx: 0.587244
# idx: 280, loss for current idx: 0.568418
# idx: 300, loss for current idx: 0.553982
# idx: 320, loss for current idx: 0.551615
# idx: 340, loss for current idx: 0.552695
# idx: 360, loss for current idx: 0.551451
# idx: 380, loss for current idx: 0.622800
# idx: 400, loss for current idx: 0.563197
# idx: 420, loss for current idx: 0.560639
# idx: 440, loss for current idx: 0.582398
# idx: 460, loss for current idx: 0.577836
# idx: 480, loss for current idx: 0.582972
# idx: 500, loss for current idx: 0.583379
# idx: 520, loss for current idx: 0.552305
# best model updated
# Epoch 1, Loss: 0.6045, Accuracy: 0.9784
# best model updated
# Epoch 2, Loss: 0.5734, Accuracy: 0.9836
# best model updated
# Epoch 3, Loss: 0.5700, Accuracy: 0.9884
# Epoch 4, Loss: 0.5654, Accuracy: 0.9858
# Epoch 5, Loss: 0.5663, Accuracy: 0.9852
# Epoch 6, Loss: 0.5643, Accuracy: 0.9884
# Epoch 7, Loss: 0.5642, Accuracy: 0.9852
# best model updated
# Epoch 8, Loss: 0.5616, Accuracy: 0.9921
# Epoch 9, Loss: 0.5619, Accuracy: 0.9900
# Epoch 10, Loss: 0.5619, Accuracy: 0.9921
# Epoch 11, Loss: 0.5602, Accuracy: 0.9842
# Epoch 12, Loss: 0.5613, Accuracy: 0.9858
# Epoch 13, Loss: 0.5652, Accuracy: 0.9900
# Epoch 14, Loss: 0.5630, Accuracy: 0.9858
# Epoch 15, Loss: 0.5617, Accuracy: 0.9868
# Epoch 16, Loss: 0.5621, Accuracy: 0.9916
# Epoch 17, Loss: 0.5644, Accuracy: 0.9910
# Best Epoch: 7, Best Valid Acc: 0.9920844327176781
# Valid Acc (with Epoch valid set) on Loaded Best Model: 0.9920844327176781
# Final Acc (with TEST set) on Loaded Best Model: 0.9908575031525851 (time: 0.003449852466583252)
#
# === case=2, backbone=resnet34 ===
# idx: 20, loss for current idx: 0.642356
# idx: 40, loss for current idx: 0.672891
# idx: 60, loss for current idx: 0.614028
# idx: 80, loss for current idx: 0.581768
# idx: 100, loss for current idx: 0.609722
# idx: 120, loss for current idx: 0.584603
# idx: 140, loss for current idx: 0.594270
# idx: 160, loss for current idx: 0.583674
# idx: 180, loss for current idx: 0.672411
# idx: 200, loss for current idx: 0.558900
# idx: 220, loss for current idx: 0.629268
# idx: 240, loss for current idx: 0.551616
# idx: 260, loss for current idx: 0.604911
# idx: 280, loss for current idx: 0.590190
# idx: 300, loss for current idx: 0.552459
# idx: 320, loss for current idx: 0.560971
# idx: 340, loss for current idx: 0.587116
# idx: 360, loss for current idx: 0.551535
# idx: 380, loss for current idx: 0.551546
# idx: 400, loss for current idx: 0.551538
# idx: 420, loss for current idx: 0.551465
# idx: 440, loss for current idx: 0.611200
# idx: 460, loss for current idx: 0.585449
# idx: 480, loss for current idx: 0.611873
# idx: 500, loss for current idx: 0.594164
# idx: 520, loss for current idx: 0.612164
# best model updated
# Epoch 1, Loss: 0.6058, Accuracy: 0.9736
# best model updated
# Epoch 2, Loss: 0.5713, Accuracy: 0.9821
# Epoch 3, Loss: 0.5677, Accuracy: 0.9789
# Epoch 4, Loss: 0.5662, Accuracy: 0.9625
# best model updated
# Epoch 5, Loss: 0.5628, Accuracy: 0.9926
# Epoch 6, Loss: 0.5632, Accuracy: 0.9884
# Epoch 7, Loss: 0.5605, Accuracy: 0.9921
# Epoch 8, Loss: 0.5617, Accuracy: 0.9757
# Epoch 9, Loss: 0.5595, Accuracy: 0.9836
# Epoch 10, Loss: 0.5626, Accuracy: 0.9763
# Epoch 11, Loss: 0.5650, Accuracy: 0.9715
# Epoch 12, Loss: 0.5623, Accuracy: 0.9884
# best model updated
# Epoch 13, Loss: 0.5613, Accuracy: 0.9947
# Epoch 14, Loss: 0.5642, Accuracy: 0.9905
# Epoch 15, Loss: 0.5622, Accuracy: 0.9910
# Epoch 16, Loss: 0.5588, Accuracy: 0.9894
# Epoch 17, Loss: 0.5628, Accuracy: 0.9884
# best model updated
# Epoch 18, Loss: 0.5582, Accuracy: 0.9953
# Epoch 19, Loss: 0.5576, Accuracy: 0.9926
# Epoch 20, Loss: 0.5602, Accuracy: 0.9953
# Epoch 21, Loss: 0.5591, Accuracy: 0.9926
# Epoch 22, Loss: 0.5612, Accuracy: 0.9942
# Epoch 23, Loss: 0.5580, Accuracy: 0.9953
# Epoch 24, Loss: 0.5576, Accuracy: 0.9905
# Epoch 25, Loss: 0.5586, Accuracy: 0.9931
# Epoch 26, Loss: 0.5641, Accuracy: 0.9942
# Epoch 27, Loss: 0.5607, Accuracy: 0.9926
# Best Epoch: 17, Best Valid Acc: 0.9952506596306069
# Valid Acc (with Epoch valid set) on Loaded Best Model: 0.9952506596306069
# Final Acc (with TEST set) on Loaded Best Model: 0.9930643127364439 (time: 0.004477314949035645)
#
# === case=2, backbone=resnet50 ===
# idx: 20, loss for current idx: 0.624897
# idx: 40, loss for current idx: 0.649046
# idx: 60, loss for current idx: 0.680694
# idx: 80, loss for current idx: 0.637927
# idx: 100, loss for current idx: 0.618148
# idx: 120, loss for current idx: 0.612904
# idx: 140, loss for current idx: 0.670168
# idx: 160, loss for current idx: 0.633880
# idx: 180, loss for current idx: 0.595396
# idx: 200, loss for current idx: 0.643706
# idx: 220, loss for current idx: 0.596590
# idx: 240, loss for current idx: 0.714585
# idx: 260, loss for current idx: 0.557959
# idx: 280, loss for current idx: 0.582719
# idx: 300, loss for current idx: 0.618236
# idx: 320, loss for current idx: 0.582463
# idx: 340, loss for current idx: 0.613937
# idx: 360, loss for current idx: 0.582760
# idx: 380, loss for current idx: 0.587618
# idx: 400, loss for current idx: 0.582750
# idx: 420, loss for current idx: 0.612613
# idx: 440, loss for current idx: 0.645174
# idx: 460, loss for current idx: 0.587672
# idx: 480, loss for current idx: 0.551946
# idx: 500, loss for current idx: 0.614602
# idx: 520, loss for current idx: 0.551509
# best model updated
# Epoch 1, Loss: 0.6196, Accuracy: 0.9747
# Epoch 2, Loss: 0.5740, Accuracy: 0.9736
# best model updated
# Epoch 3, Loss: 0.5682, Accuracy: 0.9847
# Epoch 4, Loss: 0.5652, Accuracy: 0.9826
# Epoch 5, Loss: 0.5651, Accuracy: 0.9826
# Epoch 6, Loss: 0.5652, Accuracy: 0.9815
# best model updated
# Epoch 7, Loss: 0.5632, Accuracy: 0.9852
# Epoch 8, Loss: 0.5697, Accuracy: 0.9768
# best model updated
# Epoch 9, Loss: 0.5631, Accuracy: 0.9873
# Epoch 10, Loss: 0.5632, Accuracy: 0.9852
# Epoch 11, Loss: 0.5645, Accuracy: 0.9847
# Epoch 12, Loss: 0.5656, Accuracy: 0.9799
# Epoch 13, Loss: 0.5660, Accuracy: 0.9784
# best model updated
# Epoch 14, Loss: 0.5655, Accuracy: 0.9889
# Epoch 15, Loss: 0.5650, Accuracy: 0.9673
# Epoch 16, Loss: 0.5686, Accuracy: 0.9805
# Epoch 17, Loss: 0.5646, Accuracy: 0.9831
# Epoch 18, Loss: 0.5618, Accuracy: 0.9863
# best model updated
# Epoch 19, Loss: 0.5620, Accuracy: 0.9910
# Epoch 20, Loss: 0.5602, Accuracy: 0.9852
# Epoch 21, Loss: 0.5616, Accuracy: 0.9889
# Epoch 22, Loss: 0.5759, Accuracy: 0.9863
# Epoch 23, Loss: 0.5630, Accuracy: 0.9678
# Epoch 24, Loss: 0.5702, Accuracy: 0.9847
# Epoch 25, Loss: 0.5611, Accuracy: 0.9894
# best model updated
# Epoch 26, Loss: 0.5597, Accuracy: 0.9921
# Epoch 27, Loss: 0.5652, Accuracy: 0.9894
# Epoch 28, Loss: 0.5642, Accuracy: 0.9905
# Epoch 29, Loss: 0.5650, Accuracy: 0.9894
# best model updated
# Epoch 30, Loss: 0.5619, Accuracy: 0.9931
# Epoch 31, Loss: 0.5612, Accuracy: 0.9905
# Epoch 32, Loss: 0.5581, Accuracy: 0.9900
# Epoch 33, Loss: 0.5598, Accuracy: 0.9910
# Epoch 34, Loss: 0.5576, Accuracy: 0.9926
# Epoch 35, Loss: 0.5587, Accuracy: 0.9894
# best model updated
# Epoch 36, Loss: 0.5595, Accuracy: 0.9937
# Epoch 37, Loss: 0.5595, Accuracy: 0.9889
# Epoch 38, Loss: 0.5668, Accuracy: 0.9689
# Epoch 39, Loss: 0.5655, Accuracy: 0.9868
# Epoch 40, Loss: 0.5622, Accuracy: 0.9868
# Epoch 41, Loss: 0.5599, Accuracy: 0.9921
# Epoch 42, Loss: 0.5618, Accuracy: 0.9720
# Epoch 43, Loss: 0.5638, Accuracy: 0.9805
# Epoch 44, Loss: 0.5621, Accuracy: 0.9879
# Epoch 45, Loss: 0.5619, Accuracy: 0.9905
# Best Epoch: 35, Best Valid Acc: 0.9936675461741424
# Valid Acc (with Epoch valid set) on Loaded Best Model: 0.9936675461741424
# Final Acc (with TEST set) on Loaded Best Model: 0.9924337957124842 (time: 0.006056830883026123)
#
# === case=3, backbone=resnet18 ===
# idx: 20, loss for current idx: 0.929262
# idx: 40, loss for current idx: 0.681693
# idx: 60, loss for current idx: 0.644377
# idx: 80, loss for current idx: 0.824734
# idx: 100, loss for current idx: 0.773770
# idx: 120, loss for current idx: 0.721782
# idx: 140, loss for current idx: 0.704532
# idx: 160, loss for current idx: 0.702773
# idx: 180, loss for current idx: 0.652956
# idx: 200, loss for current idx: 0.632536
# idx: 220, loss for current idx: 0.673631
# idx: 240, loss for current idx: 0.796496
# idx: 260, loss for current idx: 0.787226
# idx: 280, loss for current idx: 0.639314
# idx: 300, loss for current idx: 0.750668
# idx: 320, loss for current idx: 0.626588
# idx: 340, loss for current idx: 0.722204
# idx: 360, loss for current idx: 0.651366
# idx: 380, loss for current idx: 0.708427
# idx: 400, loss for current idx: 0.712240
# idx: 420, loss for current idx: 0.797485
# idx: 440, loss for current idx: 0.737301
# idx: 460, loss for current idx: 0.650325
# idx: 480, loss for current idx: 0.627324
# idx: 500, loss for current idx: 0.639799
# idx: 520, loss for current idx: 0.678095
# best model updated
# Epoch 1, Loss: 0.7156, Accuracy: 0.9789
# best model updated
# Epoch 2, Loss: 0.6523, Accuracy: 0.9810
# best model updated
# Epoch 3, Loss: 0.6452, Accuracy: 0.9842
# Epoch 4, Loss: 0.6497, Accuracy: 0.9821
# Epoch 5, Loss: 0.6451, Accuracy: 0.9736
# Epoch 6, Loss: 0.6428, Accuracy: 0.9842
# best model updated
# Epoch 7, Loss: 0.6421, Accuracy: 0.9905
# best model updated
# Epoch 8, Loss: 0.6422, Accuracy: 0.9910
# Epoch 9, Loss: 0.6382, Accuracy: 0.9879
# Epoch 10, Loss: 0.6486, Accuracy: 0.9858
# best model updated
# Epoch 11, Loss: 0.6425, Accuracy: 0.9926
# best model updated
# Epoch 12, Loss: 0.6342, Accuracy: 0.9931
# Epoch 13, Loss: 0.6425, Accuracy: 0.9916
# Epoch 14, Loss: 0.6405, Accuracy: 0.9842
# Epoch 15, Loss: 0.6430, Accuracy: 0.9757
# best model updated
# Epoch 16, Loss: 0.6390, Accuracy: 0.9942
# Epoch 17, Loss: 0.6360, Accuracy: 0.9921
# Epoch 18, Loss: 0.6367, Accuracy: 0.9916
# Epoch 19, Loss: 0.6367, Accuracy: 0.9916
# Epoch 20, Loss: 0.6369, Accuracy: 0.9926
# Epoch 21, Loss: 0.6386, Accuracy: 0.9900
# Epoch 22, Loss: 0.6398, Accuracy: 0.9942
# best model updated
# Epoch 23, Loss: 0.6379, Accuracy: 0.9947
# Epoch 24, Loss: 0.6366, Accuracy: 0.9942
# Epoch 25, Loss: 0.6389, Accuracy: 0.9910
# Epoch 26, Loss: 0.6497, Accuracy: 0.9916
# Epoch 27, Loss: 0.6384, Accuracy: 0.9905
# Epoch 28, Loss: 0.6531, Accuracy: 0.9894
# Epoch 29, Loss: 0.6371, Accuracy: 0.9873
# Epoch 30, Loss: 0.6463, Accuracy: 0.9900
# Epoch 31, Loss: 0.6445, Accuracy: 0.9916
# Epoch 32, Loss: 0.6491, Accuracy: 0.9926
# Best Epoch: 22, Best Valid Acc: 0.9947229551451188
# Valid Acc (with Epoch valid set) on Loaded Best Model: 0.9947229551451188
# Final Acc (with TEST set) on Loaded Best Model: 0.9940100882723834 (time: 0.002619771957397461)
#
# === case=3, backbone=resnet34 ===
# idx: 20, loss for current idx: 1.038319
# idx: 40, loss for current idx: 0.803577
# idx: 60, loss for current idx: 0.827113
# idx: 80, loss for current idx: 0.738768
# idx: 100, loss for current idx: 0.775847
# idx: 120, loss for current idx: 0.673532
# idx: 140, loss for current idx: 0.745276
# idx: 160, loss for current idx: 0.659254
# idx: 180, loss for current idx: 0.672126
# idx: 200, loss for current idx: 0.720371
# idx: 220, loss for current idx: 0.628686
# idx: 240, loss for current idx: 0.753900
# idx: 260, loss for current idx: 0.658888
# idx: 280, loss for current idx: 0.782091
# idx: 300, loss for current idx: 0.635890
# idx: 320, loss for current idx: 0.636799
# idx: 340, loss for current idx: 0.689086
# idx: 360, loss for current idx: 0.626675
# idx: 380, loss for current idx: 0.637089
# idx: 400, loss for current idx: 0.749244
# idx: 420, loss for current idx: 0.750881
# idx: 440, loss for current idx: 0.627219
# idx: 460, loss for current idx: 0.633714
# idx: 480, loss for current idx: 0.627029
# idx: 500, loss for current idx: 0.720627
# idx: 520, loss for current idx: 0.626544
# best model updated
# Epoch 1, Loss: 0.7086, Accuracy: 0.9805
# Epoch 2, Loss: 0.6523, Accuracy: 0.9794
# Epoch 3, Loss: 0.6508, Accuracy: 0.9741
# Epoch 4, Loss: 0.6470, Accuracy: 0.9799
# best model updated
# Epoch 5, Loss: 0.6385, Accuracy: 0.9916
# Epoch 6, Loss: 0.6365, Accuracy: 0.9873
# Epoch 7, Loss: 0.6399, Accuracy: 0.9910
# Epoch 8, Loss: 0.6432, Accuracy: 0.9810
# Epoch 9, Loss: 0.6373, Accuracy: 0.9879
# best model updated
# Epoch 10, Loss: 0.6430, Accuracy: 0.9921
# best model updated
# Epoch 11, Loss: 0.6368, Accuracy: 0.9937
# Epoch 12, Loss: 0.6410, Accuracy: 0.9604
# Epoch 13, Loss: 0.6392, Accuracy: 0.9921
# Epoch 14, Loss: 0.6345, Accuracy: 0.9921
# Epoch 15, Loss: 0.6359, Accuracy: 0.9910
# Epoch 16, Loss: 0.6367, Accuracy: 0.9931
# Epoch 17, Loss: 0.6364, Accuracy: 0.9910
# best model updated
# Epoch 18, Loss: 0.6356, Accuracy: 0.9947
# best model updated
# Epoch 19, Loss: 0.6322, Accuracy: 0.9963
# Epoch 20, Loss: 0.6355, Accuracy: 0.9916
# Epoch 21, Loss: 0.6377, Accuracy: 0.9963
# Epoch 22, Loss: 0.6342, Accuracy: 0.9958
# Epoch 23, Loss: 0.6344, Accuracy: 0.9953
# Epoch 24, Loss: 0.6348, Accuracy: 0.9916
# Epoch 25, Loss: 0.6325, Accuracy: 0.9942
# Epoch 26, Loss: 0.6319, Accuracy: 0.9953
# Epoch 27, Loss: 0.6322, Accuracy: 0.9926
# Epoch 28, Loss: 0.6342, Accuracy: 0.9947
# Best Epoch: 18, Best Valid Acc: 0.9963060686015831
# Valid Acc (with Epoch valid set) on Loaded Best Model: 0.9963060686015831
# Final Acc (with TEST set) on Loaded Best Model: 0.9949558638083228 (time: 0.00480212926864624)
#
# === case=3, backbone=resnet50 ===
# idx: 20, loss for current idx: 0.972530
# idx: 40, loss for current idx: 0.873630
# idx: 60, loss for current idx: 0.711530
# idx: 80, loss for current idx: 0.729871
# idx: 100, loss for current idx: 0.660054
# idx: 120, loss for current idx: 0.702419
# idx: 140, loss for current idx: 0.666853
# idx: 160, loss for current idx: 0.640684
# idx: 180, loss for current idx: 0.648932
# idx: 200, loss for current idx: 0.722360
# idx: 220, loss for current idx: 0.683931
# idx: 240, loss for current idx: 0.650132
# idx: 260, loss for current idx: 0.833506
# idx: 280, loss for current idx: 0.669411
# idx: 300, loss for current idx: 0.711813
# idx: 320, loss for current idx: 0.708237
# idx: 340, loss for current idx: 0.643134
# idx: 360, loss for current idx: 0.629625
# idx: 380, loss for current idx: 0.722799
# idx: 400, loss for current idx: 0.752927
# idx: 420, loss for current idx: 0.766352
# idx: 440, loss for current idx: 0.647605
# idx: 460, loss for current idx: 0.696418
# idx: 480, loss for current idx: 0.634692
# idx: 500, loss for current idx: 0.626670
# idx: 520, loss for current idx: 0.688771
# best model updated
# Epoch 1, Loss: 0.7333, Accuracy: 0.9604
# best model updated
# Epoch 2, Loss: 0.6702, Accuracy: 0.9773
# best model updated
# Epoch 3, Loss: 0.6526, Accuracy: 0.9799
# best model updated
# Epoch 4, Loss: 0.6496, Accuracy: 0.9852
# best model updated
# Epoch 5, Loss: 0.6465, Accuracy: 0.9879
# Epoch 6, Loss: 0.6459, Accuracy: 0.9815
# Epoch 7, Loss: 0.6417, Accuracy: 0.9773
# best model updated
# Epoch 8, Loss: 0.6539, Accuracy: 0.9910
# Epoch 9, Loss: 0.6388, Accuracy: 0.9836
# best model updated
# Epoch 10, Loss: 0.6384, Accuracy: 0.9926
# Epoch 11, Loss: 0.6376, Accuracy: 0.9900
# Epoch 12, Loss: 0.6412, Accuracy: 0.9884
# Epoch 13, Loss: 0.6389, Accuracy: 0.9926
# best model updated
# Epoch 14, Loss: 0.6397, Accuracy: 0.9937
# Epoch 15, Loss: 0.6493, Accuracy: 0.9810
# Epoch 16, Loss: 0.6494, Accuracy: 0.9752
# Epoch 17, Loss: 0.6534, Accuracy: 0.9805
# Epoch 18, Loss: 0.6419, Accuracy: 0.9858
# Epoch 19, Loss: 0.6416, Accuracy: 0.9715
# Epoch 20, Loss: 0.6497, Accuracy: 0.9884
# Epoch 21, Loss: 0.6494, Accuracy: 0.9852
# Epoch 22, Loss: 0.6551, Accuracy: 0.9916
# Epoch 23, Loss: 0.6376, Accuracy: 0.9863
# Best Epoch: 13, Best Valid Acc: 0.9936675461741424
# Valid Acc (with Epoch valid set) on Loaded Best Model: 0.9936675461741424
# Final Acc (with TEST set) on Loaded Best Model: 0.9899117276166457 (time: 0.0073756051063537595)
#
# === case=4_1, backbone=resnet18 ===
# idx: 20, loss for current idx: 0.855034
# idx: 40, loss for current idx: 0.924593
# idx: 60, loss for current idx: 0.723789
# idx: 80, loss for current idx: 0.843475
# idx: 100, loss for current idx: 0.635576
# idx: 120, loss for current idx: 0.747720
# idx: 140, loss for current idx: 0.669246
# idx: 160, loss for current idx: 0.683052
# idx: 180, loss for current idx: 0.697088
# idx: 200, loss for current idx: 0.689038
# idx: 220, loss for current idx: 0.722377
# idx: 240, loss for current idx: 0.657865
# idx: 260, loss for current idx: 0.641340
# idx: 280, loss for current idx: 0.634523
# idx: 300, loss for current idx: 0.626551
# idx: 320, loss for current idx: 0.728208
# idx: 340, loss for current idx: 0.626641
# idx: 360, loss for current idx: 0.626763
# idx: 380, loss for current idx: 0.684434
# idx: 400, loss for current idx: 0.685345
# idx: 420, loss for current idx: 0.680269
# idx: 440, loss for current idx: 0.686333
# idx: 460, loss for current idx: 0.636349
# idx: 480, loss for current idx: 0.633838
# idx: 500, loss for current idx: 0.660557
# idx: 520, loss for current idx: 0.703709
# best model updated
# Epoch 1, Loss: 0.6991, Accuracy: 0.9821
# best model updated
# Epoch 2, Loss: 0.6538, Accuracy: 0.9858
# best model updated
# Epoch 3, Loss: 0.6456, Accuracy: 0.9879
# Epoch 4, Loss: 0.6468, Accuracy: 0.9868
# Epoch 5, Loss: 0.6404, Accuracy: 0.9799
# Epoch 6, Loss: 0.6410, Accuracy: 0.9879
# best model updated
# Epoch 7, Loss: 0.6409, Accuracy: 0.9926
# best model updated
# Epoch 8, Loss: 0.6392, Accuracy: 0.9942
# Epoch 9, Loss: 0.6410, Accuracy: 0.9873
# Epoch 10, Loss: 0.6384, Accuracy: 0.9821
# Epoch 11, Loss: 0.6391, Accuracy: 0.9879
# Epoch 12, Loss: 0.6392, Accuracy: 0.9889
# Epoch 13, Loss: 0.6405, Accuracy: 0.9873
# Epoch 14, Loss: 0.6376, Accuracy: 0.9926
# Epoch 15, Loss: 0.6353, Accuracy: 0.9873
# Epoch 16, Loss: 0.6353, Accuracy: 0.9942
# Epoch 17, Loss: 0.6352, Accuracy: 0.9916
# Best Epoch: 7, Best Valid Acc: 0.9941952506596307
# Valid Acc (with Epoch valid set) on Loaded Best Model: 0.9941952506596307
# Final Acc (with TEST set) on Loaded Best Model: 0.9924337957124842 (time: 0.005329279899597168)
#
# === case=4_1, backbone=resnet34 ===
# idx: 20, loss for current idx: 0.951737
# idx: 40, loss for current idx: 0.746193
# idx: 60, loss for current idx: 0.845025
# idx: 80, loss for current idx: 0.729429
# idx: 100, loss for current idx: 0.730861
# idx: 120, loss for current idx: 0.687546
# idx: 140, loss for current idx: 0.636651
# idx: 160, loss for current idx: 0.741445
# idx: 180, loss for current idx: 0.694921
# idx: 200, loss for current idx: 0.759386
# idx: 220, loss for current idx: 0.630642
# idx: 240, loss for current idx: 0.716462
# idx: 260, loss for current idx: 0.695616
# idx: 280, loss for current idx: 0.679065
# idx: 300, loss for current idx: 0.627714
# idx: 320, loss for current idx: 0.680951
# idx: 340, loss for current idx: 0.626644
# idx: 360, loss for current idx: 0.683821
# idx: 380, loss for current idx: 0.691788
# idx: 400, loss for current idx: 0.761527
# idx: 420, loss for current idx: 0.627318
# idx: 440, loss for current idx: 0.626886
# idx: 460, loss for current idx: 0.630294
# idx: 480, loss for current idx: 0.655272
# idx: 500, loss for current idx: 0.644957
# idx: 520, loss for current idx: 0.629361
# best model updated
# Epoch 1, Loss: 0.7023, Accuracy: 0.9504
# best model updated
# Epoch 2, Loss: 0.6537, Accuracy: 0.9852
# Epoch 3, Loss: 0.6474, Accuracy: 0.9747
# Epoch 4, Loss: 0.6417, Accuracy: 0.9831
# Epoch 5, Loss: 0.6435, Accuracy: 0.9852
# best model updated
# Epoch 6, Loss: 0.6420, Accuracy: 0.9916
# Epoch 7, Loss: 0.6430, Accuracy: 0.9900
# Epoch 8, Loss: 0.6489, Accuracy: 0.9784
# Epoch 9, Loss: 0.6447, Accuracy: 0.9852
# best model updated
# Epoch 10, Loss: 0.6396, Accuracy: 0.9947
# Epoch 11, Loss: 0.6407, Accuracy: 0.9847
# Epoch 12, Loss: 0.6471, Accuracy: 0.9836
# Epoch 13, Loss: 0.6399, Accuracy: 0.9905
# Epoch 14, Loss: 0.6393, Accuracy: 0.9926
# Epoch 15, Loss: 0.6426, Accuracy: 0.9926
# Epoch 16, Loss: 0.6378, Accuracy: 0.9799
# Epoch 17, Loss: 0.6353, Accuracy: 0.9921
# Epoch 18, Loss: 0.6377, Accuracy: 0.9900
# Epoch 19, Loss: 0.6354, Accuracy: 0.9942
# Best Epoch: 9, Best Valid Acc: 0.9947229551451188
# Valid Acc (with Epoch valid set) on Loaded Best Model: 0.9947229551451188
# Final Acc (with TEST set) on Loaded Best Model: 0.9936948297604036 (time: 0.008833158016204833)
#
# === case=4_1, backbone=resnet50 ===
# idx: 20, loss for current idx: 0.979637
# idx: 40, loss for current idx: 0.773382
# idx: 60, loss for current idx: 0.736849
# idx: 80, loss for current idx: 0.820941
# idx: 100, loss for current idx: 0.696688
# idx: 120, loss for current idx: 0.731005
# idx: 140, loss for current idx: 0.653906
# idx: 160, loss for current idx: 0.706579
# idx: 180, loss for current idx: 0.636030
# idx: 200, loss for current idx: 0.755757
# idx: 220, loss for current idx: 0.807205
# idx: 240, loss for current idx: 0.657376
# idx: 260, loss for current idx: 0.720289
# idx: 280, loss for current idx: 0.726777
# idx: 300, loss for current idx: 0.693515
# idx: 320, loss for current idx: 0.686109
# idx: 340, loss for current idx: 0.649254
# idx: 360, loss for current idx: 0.682559
# idx: 380, loss for current idx: 0.719211
# idx: 400, loss for current idx: 0.721451
# idx: 420, loss for current idx: 0.660411
# idx: 440, loss for current idx: 0.691312
# idx: 460, loss for current idx: 0.767844
# idx: 480, loss for current idx: 0.627493
# idx: 500, loss for current idx: 0.630081
# idx: 520, loss for current idx: 0.662912
# best model updated
# Epoch 1, Loss: 0.7338, Accuracy: 0.9773
# best model updated
# Epoch 2, Loss: 0.6648, Accuracy: 0.9863
# best model updated
# Epoch 3, Loss: 0.6507, Accuracy: 0.9900
# Epoch 4, Loss: 0.6483, Accuracy: 0.9900
# Epoch 5, Loss: 0.6456, Accuracy: 0.9821
# best model updated
# Epoch 6, Loss: 0.6405, Accuracy: 0.9921
# best model updated
# Epoch 7, Loss: 0.6379, Accuracy: 0.9931
# Epoch 8, Loss: 0.6410, Accuracy: 0.9815
# Epoch 9, Loss: 0.6381, Accuracy: 0.9931
# Epoch 10, Loss: 0.6365, Accuracy: 0.9916
# Epoch 11, Loss: 0.6399, Accuracy: 0.9900
# Epoch 12, Loss: 0.6415, Accuracy: 0.9852
# Epoch 13, Loss: 0.6457, Accuracy: 0.9921
# Epoch 14, Loss: 0.6433, Accuracy: 0.9858
# Epoch 15, Loss: 0.6503, Accuracy: 0.9831
# Epoch 16, Loss: 0.6465, Accuracy: 0.9789
# Best Epoch: 6, Best Valid Acc: 0.9931398416886543
# Valid Acc (with Epoch valid set) on Loaded Best Model: 0.9931398416886543
# Final Acc (with TEST set) on Loaded Best Model: 0.9905422446406053 (time: 0.011397769451141357)
#
# === case=4_2, backbone=resnet18 ===
# idx: 20, loss for current idx: 0.856284
# idx: 40, loss for current idx: 0.805846
# idx: 60, loss for current idx: 0.830110
# idx: 80, loss for current idx: 0.881896
# idx: 100, loss for current idx: 0.781852
# idx: 120, loss for current idx: 0.736810
# idx: 140, loss for current idx: 0.678651
# idx: 160, loss for current idx: 0.660026
# idx: 180, loss for current idx: 0.626687
# idx: 200, loss for current idx: 0.689505
# idx: 220, loss for current idx: 0.674136
# idx: 240, loss for current idx: 0.627694
# idx: 260, loss for current idx: 0.627082
# idx: 280, loss for current idx: 0.629629
# idx: 300, loss for current idx: 0.647262
# idx: 320, loss for current idx: 0.670539
# idx: 340, loss for current idx: 0.790855
# idx: 360, loss for current idx: 0.666086
# idx: 380, loss for current idx: 0.662940
# idx: 400, loss for current idx: 0.649070
# idx: 420, loss for current idx: 0.696098
# idx: 440, loss for current idx: 0.666245
# idx: 460, loss for current idx: 0.670171
# idx: 480, loss for current idx: 0.736068
# idx: 500, loss for current idx: 0.783870
# idx: 520, loss for current idx: 0.626558
# best model updated
# Epoch 1, Loss: 0.7120, Accuracy: 0.9683
# best model updated
# Epoch 2, Loss: 0.6610, Accuracy: 0.9763
# Epoch 3, Loss: 0.6497, Accuracy: 0.9673
# best model updated
# Epoch 4, Loss: 0.6466, Accuracy: 0.9894
# Epoch 5, Loss: 0.6503, Accuracy: 0.9778
# Epoch 6, Loss: 0.6511, Accuracy: 0.9831
# Epoch 7, Loss: 0.6449, Accuracy: 0.9662
# Epoch 8, Loss: 0.6456, Accuracy: 0.9789
# best model updated
# Epoch 9, Loss: 0.6408, Accuracy: 0.9916
# Epoch 10, Loss: 0.6363, Accuracy: 0.9916
# Epoch 11, Loss: 0.6420, Accuracy: 0.9842
# Epoch 12, Loss: 0.6397, Accuracy: 0.9900
# Epoch 13, Loss: 0.6369, Accuracy: 0.9889
# Epoch 14, Loss: 0.6371, Accuracy: 0.9900
# Epoch 15, Loss: 0.6392, Accuracy: 0.9868
# Epoch 16, Loss: 0.6408, Accuracy: 0.9847
# best model updated
# Epoch 17, Loss: 0.6391, Accuracy: 0.9931
# Epoch 18, Loss: 0.6367, Accuracy: 0.9889
# Epoch 19, Loss: 0.6424, Accuracy: 0.9916
# Epoch 20, Loss: 0.6491, Accuracy: 0.9757
# best model updated
# Epoch 21, Loss: 0.6428, Accuracy: 0.9937
# best model updated
# Epoch 22, Loss: 0.6348, Accuracy: 0.9958
# Epoch 23, Loss: 0.6350, Accuracy: 0.9894
# Epoch 24, Loss: 0.6368, Accuracy: 0.9942
# Epoch 25, Loss: 0.6363, Accuracy: 0.9905
# Epoch 26, Loss: 0.6390, Accuracy: 0.9889
# Epoch 27, Loss: 0.6369, Accuracy: 0.9905
# Epoch 28, Loss: 0.6398, Accuracy: 0.9858
# Epoch 29, Loss: 0.6387, Accuracy: 0.9821
# Epoch 30, Loss: 0.6389, Accuracy: 0.9921
# Epoch 31, Loss: 0.6390, Accuracy: 0.9842
# Best Epoch: 21, Best Valid Acc: 0.995778364116095
# Valid Acc (with Epoch valid set) on Loaded Best Model: 0.995778364116095
# Final Acc (with TEST set) on Loaded Best Model: 0.992749054224464 (time: 0.00510504961013794)
#
# === case=4_2, backbone=resnet34 ===
# idx: 20, loss for current idx: 0.825181
# idx: 40, loss for current idx: 0.791971
# idx: 60, loss for current idx: 0.888814
# idx: 80, loss for current idx: 0.695675
# idx: 100, loss for current idx: 0.807570
# idx: 120, loss for current idx: 0.736573
# idx: 140, loss for current idx: 0.791539
# idx: 160, loss for current idx: 0.659833
# idx: 180, loss for current idx: 0.701714
# idx: 200, loss for current idx: 0.693073
# idx: 220, loss for current idx: 0.741908
# idx: 240, loss for current idx: 0.704457
# idx: 260, loss for current idx: 0.655074
# idx: 280, loss for current idx: 0.661332
# idx: 300, loss for current idx: 0.686135
# idx: 320, loss for current idx: 0.644344
# idx: 340, loss for current idx: 0.681030
# idx: 360, loss for current idx: 0.766263
# idx: 380, loss for current idx: 0.759097
# idx: 400, loss for current idx: 0.733972
# idx: 420, loss for current idx: 0.657470
# idx: 440, loss for current idx: 0.629061
# idx: 460, loss for current idx: 0.646560
# idx: 480, loss for current idx: 0.626533
# idx: 500, loss for current idx: 0.680936
# idx: 520, loss for current idx: 0.640909
# best model updated
# Epoch 1, Loss: 0.7277, Accuracy: 0.9599
# best model updated
# Epoch 2, Loss: 0.6651, Accuracy: 0.9699
# best model updated
# Epoch 3, Loss: 0.6552, Accuracy: 0.9826
# Epoch 4, Loss: 0.6509, Accuracy: 0.9799
# best model updated
# Epoch 5, Loss: 0.6506, Accuracy: 0.9847
# Epoch 6, Loss: 0.6519, Accuracy: 0.9757
# Epoch 7, Loss: 0.6447, Accuracy: 0.9842
# best model updated
# Epoch 8, Loss: 0.6461, Accuracy: 0.9868
# Epoch 9, Loss: 0.6441, Accuracy: 0.9858
# Epoch 10, Loss: 0.6465, Accuracy: 0.9699
# Epoch 11, Loss: 0.6433, Accuracy: 0.9831
# Epoch 12, Loss: 0.6519, Accuracy: 0.9625
# Epoch 13, Loss: 0.6520, Accuracy: 0.9821
# Epoch 14, Loss: 0.6465, Accuracy: 0.9842
# best model updated
# Epoch 15, Loss: 0.6449, Accuracy: 0.9884
# best model updated
# Epoch 16, Loss: 0.6425, Accuracy: 0.9894
# Epoch 17, Loss: 0.6506, Accuracy: 0.9615
# Epoch 18, Loss: 0.6520, Accuracy: 0.9821
# Epoch 19, Loss: 0.6505, Accuracy: 0.9815
# Epoch 20, Loss: 0.6465, Accuracy: 0.9842
# Epoch 21, Loss: 0.6477, Accuracy: 0.9842
# Epoch 22, Loss: 0.6449, Accuracy: 0.9847
# Epoch 23, Loss: 0.6460, Accuracy: 0.9794
# Epoch 24, Loss: 0.6436, Accuracy: 0.9873
# Epoch 25, Loss: 0.6453, Accuracy: 0.9863
# Best Epoch: 15, Best Valid Acc: 0.9894459102902374
# Valid Acc (with Epoch valid set) on Loaded Best Model: 0.9894459102902374
# Final Acc (with TEST set) on Loaded Best Model: 0.9883354350567465 (time: 0.009233522415161132)
#
# === case=4_2, backbone=resnet50 ===
# idx: 20, loss for current idx: 0.844875
# idx: 40, loss for current idx: 0.810473
# idx: 60, loss for current idx: 0.771010
# idx: 80, loss for current idx: 0.822342
# idx: 100, loss for current idx: 0.761175
# idx: 120, loss for current idx: 0.728997
# idx: 140, loss for current idx: 0.784309
# idx: 160, loss for current idx: 0.751663
# idx: 180, loss for current idx: 0.666719
# idx: 200, loss for current idx: 0.657870
# idx: 220, loss for current idx: 0.727111
# idx: 240, loss for current idx: 0.887826
# idx: 260, loss for current idx: 0.670999
# idx: 280, loss for current idx: 0.746478
# idx: 300, loss for current idx: 0.689401
# idx: 320, loss for current idx: 0.719445
# idx: 340, loss for current idx: 0.737251
# idx: 360, loss for current idx: 0.717137
# idx: 380, loss for current idx: 0.754022
# idx: 400, loss for current idx: 0.678526
# idx: 420, loss for current idx: 0.700621
# idx: 440, loss for current idx: 0.657779
# idx: 460, loss for current idx: 0.772075
# idx: 480, loss for current idx: 0.741401
# idx: 500, loss for current idx: 0.657825
# idx: 520, loss for current idx: 0.691792
# best model updated
# Epoch 1, Loss: 0.7389, Accuracy: 0.9631
# best model updated
# Epoch 2, Loss: 0.6638, Accuracy: 0.9683
# best model updated
# Epoch 3, Loss: 0.6544, Accuracy: 0.9768
# best model updated
# Epoch 4, Loss: 0.6544, Accuracy: 0.9773
# best model updated
# Epoch 5, Loss: 0.6436, Accuracy: 0.9784
# best model updated
# Epoch 6, Loss: 0.6468, Accuracy: 0.9815
# Epoch 7, Loss: 0.6518, Accuracy: 0.9731
# best model updated
# Epoch 8, Loss: 0.6487, Accuracy: 0.9826
# best model updated
# Epoch 9, Loss: 0.6476, Accuracy: 0.9836
# best model updated
# Epoch 10, Loss: 0.6473, Accuracy: 0.9852
# Epoch 11, Loss: 0.6498, Accuracy: 0.9852
# Epoch 12, Loss: 0.6494, Accuracy: 0.9815
# Epoch 13, Loss: 0.6584, Accuracy: 0.9520
# Epoch 14, Loss: 0.6645, Accuracy: 0.8971
# Epoch 15, Loss: 0.6719, Accuracy: 0.9741
# Epoch 16, Loss: 0.6594, Accuracy: 0.9821
# Epoch 17, Loss: 0.6480, Accuracy: 0.9836
# Epoch 18, Loss: 0.6661, Accuracy: 0.9836
# best model updated
# Epoch 19, Loss: 0.6496, Accuracy: 0.9868
# best model updated
# Epoch 20, Loss: 0.6389, Accuracy: 0.9894
# Epoch 21, Loss: 0.6378, Accuracy: 0.9889
# Epoch 22, Loss: 0.6463, Accuracy: 0.9826
# Epoch 23, Loss: 0.6485, Accuracy: 0.9789
# Epoch 24, Loss: 0.6453, Accuracy: 0.9778
# Epoch 25, Loss: 0.6439, Accuracy: 0.9868
# Epoch 26, Loss: 0.6415, Accuracy: 0.9879
# Epoch 27, Loss: 0.6433, Accuracy: 0.9852
# Epoch 28, Loss: 0.6452, Accuracy: 0.9768
# Epoch 29, Loss: 0.6607, Accuracy: 0.9768
# Best Epoch: 19, Best Valid Acc: 0.9894459102902374
# Valid Acc (with Epoch valid set) on Loaded Best Model: 0.9894459102902374
# Final Acc (with TEST set) on Loaded Best Model: 0.9886506935687264 (time: 0.01693567752838135)

# %%
result_df = pd.DataFrame(result_dict)
result_df
# Out:
#     backbone case  accuracy  inference_time
# 0   resnet18    1  0.990858        0.005273
# 1   resnet34    1  0.995902        0.008936
# 2   resnet50    1  0.994325        0.012169
# 3   resnet18    2  0.990858        0.003450
# 4   resnet34    2  0.993064        0.004477
# 5   resnet50    2  0.992434        0.006057
# 6   resnet18    3  0.994010        0.002620
# 7   resnet34    3  0.994956        0.004802
# 8   resnet50    3  0.989912        0.007376
# 9   resnet18  4_1  0.992434        0.005329
# 10  resnet34  4_1  0.993695        0.008833
# 11  resnet50  4_1  0.990542        0.011398
# 12  resnet18  4_2  0.992749        0.005105
# 13  resnet34  4_2  0.988335        0.009234
# 14  resnet50  4_2  0.988651        0.016936

# %%
result_df.to_csv('result_experiment_2.csv')
