# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms

import plotly.graph_objects as go

import random
import pandas as pd
import numpy as np

# !pip install torchinfo
from torchinfo import summary
# Out:
# Collecting torchinfo
#   Downloading torchinfo-1.8.0-py3-none-any.whl.metadata (21 kB)
# Downloading torchinfo-1.8.0-py3-none-any.whl (23 kB)
# Installing collected packages: torchinfo
# Successfully installed torchinfo-1.8.0

# %%
# 경고 미 표시

import warnings
warnings.filterwarnings('ignore')

# %%
# Random Seed 고정 (학습 반복 시행 시에도 동일한 결과가 나오도록)

seed = 20250928

random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)
torch.cuda.manual_seed_all(seed)

# %%
# 데이터셋 로딩

transform = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.5,), (0.5,))])

train_dataset = torchvision.datasets.MNIST(root='./data',
                                           train=True,
                                           transform=transform,
                                           download=True)

test_dataset = torchvision.datasets.MNIST(root='./data',
                                          train=False,
                                          transform=transform,
                                          download=True)
# Out:
# 100%|██████████| 9.91M/9.91M [00:00<00:00, 12.9MB/s]
# 100%|██████████| 28.9k/28.9k [00:00<00:00, 348kB/s]
# 100%|██████████| 1.65M/1.65M [00:00<00:00, 3.16MB/s]
# 100%|██████████| 4.54k/4.54k [00:00<00:00, 13.2MB/s]

# %% [markdown]
# **1. 데이터셋 분석**

# %%
# 데이터셋 로딩

from torch.utils.data import DataLoader

BATCH_SIZE = 32

train_loader = DataLoader(train_dataset,
                          batch_size=BATCH_SIZE,
                          shuffle=True)

test_loader = DataLoader(test_dataset,
                         batch_size=BATCH_SIZE,
                         shuffle=False)

# %%
# 클래스 불균형 분석

# 학습 데이터
train_labels = torch.tensor(train_dataset.targets)
train_class_counts = torch.bincount(train_labels)
print(f'train data : {train_class_counts}')

# 테스트 데이터
test_labels = torch.tensor(test_dataset.targets)
test_class_counts = torch.bincount(test_labels)
print(f'test  data : {test_class_counts}')

NUM_CLASSES = len(train_class_counts)
# Out:
# train data : tensor([5923, 6742, 5958, 6131, 5842, 5421, 5918, 6265, 5851, 5949])
# test  data : tensor([ 980, 1135, 1032, 1010,  982,  892,  958, 1028,  974, 1009])

# %%
# 클래스 불균형 분석 (percentage)

train_class_percentage = np.array(train_class_counts) * 100.0 / sum(train_class_counts)

train_y_distrib = pd.DataFrame({'class': list(range(NUM_CLASSES)),
                                'count': train_class_counts,
                                'percentage (%)': train_class_percentage})

train_y_distrib
# Out:
#    class  count  percentage (%)
# 0      0   5923        9.871667
# 1      1   6742       11.236667
# 2      2   5958        9.930000
# 3      3   6131       10.218333
# 4      4   5842        9.736667
# 5      5   5421        9.035000
# 6      6   5918        9.863333
# 7      7   6265       10.441667
# 8      8   5851        9.751667
# 9      9   5949        9.915000

# %%
test_class_percentage = np.array(test_class_counts) * 100.0 / sum(test_class_counts)

test_y_distrib = pd.DataFrame({'class': list(range(NUM_CLASSES)),
                               'count': test_class_counts,
                               'percentage (%)': test_class_percentage})

test_y_distrib
# Out:
#    class  count  percentage (%)
# 0      0    980            9.80
# 1      1   1135           11.35
# 2      2   1032           10.32
# 3      3   1010           10.10
# 4      4    982            9.82
# 5      5    892            8.92
# 6      6    958            9.58
# 7      7   1028           10.28
# 8      8    974            9.74
# 9      9   1009           10.09

# %% [markdown]
# **2. 0, 1, 2 숫자 데이터만 추출**

# %%
from torch.utils.data import Subset

# train dataset
train_targets = torch.tensor(train_dataset.targets)
train_mask = (train_targets == 0) | (train_targets == 1) | (train_targets == 2)
train_indices = torch.where(train_mask)[0]

train_subset = Subset(train_dataset, train_indices)

# test dataset
test_targets = torch.tensor(test_dataset.targets)
test_mask = (test_targets == 0) | (test_targets == 1) | (test_targets == 2)
test_indices = torch.where(test_mask)[0]

test_subset = Subset(test_dataset, test_indices)

# %%
# train, test Data Loader 갱신

train_subset_loader = DataLoader(train_subset,
                                 batch_size=BATCH_SIZE,
                                 shuffle=True)

test_subset_loader = DataLoader(test_subset,
                                batch_size=BATCH_SIZE,
                                shuffle=False)

# %%
# train, test Data Loader 의 class 가 0, 1, 2 뿐인지 확인

train_subset_labels = train_subset.dataset.targets[train_subset.indices]
train_subset_class_counts = torch.bincount(train_subset_labels)
print(f'train data (subset) [0,1,2] : {train_subset_class_counts}')

test_subset_labels = test_subset.dataset.targets[test_subset.indices]
test_subset_class_counts = torch.bincount(test_subset_labels)
print(f'test  data (subset) [0,1,2] : {test_subset_class_counts}')
# Out:
# train data (subset) [0,1,2] : tensor([5923, 6742, 5958])
# test  data (subset) [0,1,2] : tensor([ 980, 1135, 1032])

# %% [markdown]
# **3. CNN 모델 정의**

# %%
# 1. Non-Shared backbone & Shared head

class CNN_CASE_1(nn.Module):
    def __init__(self, backbone_1, backbone_2):
        super(CNN_CASE_1, self).__init__()

        self.backbone_1 = backbone_1
        self.backbone_2 = backbone_2
        self.final_linear = nn.Linear(2000, 3)
        self.final_softmax = nn.Softmax(dim=1)

    def forward(self, x):
        x1 = self.backbone_1(x)
        x2 = self.backbone_2(x)
        x = torch.concatenate([x1, x2], dim=1)

        x = self.final_linear(x)
        x = self.final_softmax(x)

        return x

# %%
# 2. Shared backbone & Shared head

class CNN_CASE_2(nn.Module):
    def __init__(self, backbone):
        super(CNN_CASE_2, self).__init__()

        self.backbone = backbone
        self.final_linear = nn.Linear(1000, 3)
        self.final_softmax = nn.Softmax(dim=1)

    def forward(self, x):
        x = self.backbone(x)
        x = self.final_linear(x)
        x = self.final_softmax(x)

        return x

# %%
# 3. Shared backbone & Non-Shared head

class CNN_CASE_3(nn.Module):
    def __init__(self, backbone):
        super(CNN_CASE_3, self).__init__()

        self.backbone = backbone
        self.final_linear_1 = nn.Linear(1000, 2)
        self.final_linear_2 = nn.Linear(1000, 2)
        self.final_softmax = nn.Softmax(dim=1)

    def forward(self, x):
        x = self.backbone(x)
        x1 = self.final_linear_1(x)
        x2 = self.final_linear_2(x)
        x1 = self.final_softmax(x1)
        x2 = self.final_softmax(x2)

        return x1, x2

# %%
# 4. Non-Shared backbone & Non-Shared head (4-1)

class CNN_CASE_4_1(nn.Module):
    def __init__(self, backbone_1, backbone_2):
        super(CNN_CASE_4_1, self).__init__()

        self.backbone_1 = backbone_1
        self.backbone_2 = backbone_2
        self.final_linear_1 = nn.Linear(2000, 2)
        self.final_linear_2 = nn.Linear(2000, 2)
        self.final_softmax = nn.Softmax(dim=1)

    def forward(self, x):
        x11 = self.backbone_1(x)
        x12 = self.backbone_2(x)
        x = torch.concatenate([x11, x12], dim=1)

        x21 = self.final_linear_1(x)
        x22 = self.final_linear_2(x)
        x21 = self.final_softmax(x21)
        x22 = self.final_softmax(x22)

        return x21, x22

# %%
# 5. Non-Shared backbone & Non-Shared head (4-2)

class CNN_CASE_4_2(nn.Module):
    def __init__(self, backbone_1, backbone_2):
        super(CNN_CASE_4_2, self).__init__()

        self.backbone_1 = backbone_1
        self.backbone_2 = backbone_2
        self.final_linear_1 = nn.Linear(1000, 2)
        self.final_linear_2 = nn.Linear(1000, 2)
        self.final_softmax = nn.Softmax(dim=1)

    def forward(self, x):
        x11 = self.backbone_1(x)
        x12 = self.backbone_2(x)
        x21 = self.final_linear_1(x11)
        x22 = self.final_linear_2(x12)
        x21 = self.final_softmax(x21)
        x22 = self.final_softmax(x22)

        return x21, x22

# %% [markdown]
# **4. backbone model 로딩**

# %%
import torchvision.models as models

def define_model(backbone_name, case_name, device):

    # model count
    if case_name in ['1', '4_1', '4_2']:
        model_count = 2
    else:
        model_count = 1

    # load pre-trained backbone model
    pretrained_models = []

    for _ in range(model_count):
        if backbone_name == 'resnet18':
            pretrained_model = models.resnet18(pretrained=True)

        elif backbone_name == 'resnet34':
            pretrained_model = models.resnet34(pretrained=True)

        else:  # resnet50
            pretrained_model = models.resnet50(pretrained=True)

        pretrained_model.conv1 = torch.nn.Conv2d(1, 64,
                                                 kernel_size=(7, 7),
                                                 stride=(2, 2),
                                                 padding=(3, 3),
                                                 bias=False)
        pretrained_models.append(pretrained_model)

    # define full model
    if case_name == '1':
        model = CNN_CASE_1(backbone_1=pretrained_models[0],
                           backbone_2=pretrained_models[1])

    elif case_name == '2':
        model = CNN_CASE_2(backbone=pretrained_models[0])

    elif case_name == '3':
        model = CNN_CASE_3(backbone=pretrained_models[0])

    elif case_name == '4_1':
        model = CNN_CASE_4_1(backbone_1=pretrained_models[0],
                             backbone_2=pretrained_models[1])

    elif case_name == '4_2':
        model = CNN_CASE_4_2(backbone_1=pretrained_models[0],
                             backbone_2=pretrained_models[1])

    # device & optimizer & scheduler setting
    model.to(device)
    model.optimizer = torch.optim.AdamW(model.parameters(), lr=0.0001)
    model.scheduler = torch.optim.lr_scheduler.ExponentialLR(optimizer=model.optimizer,
                                                             gamma=0.95)

    return model

# %% [markdown]
# **5. 모델 구조 출력**

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
input_size=(BATCH_SIZE, 1, 28, 28)

# %%
temp_backbone_name = 'resnet18'

# %%
# 1. Non-Shared backbone & Shared head

model_case_1 = define_model(temp_backbone_name, case_name='1', device=device)
print(summary(model=model_case_1, input_size=input_size))
# Out:
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100%|██████████| 44.7M/44.7M [00:00<00:00, 175MB/s]
# ===============================================================================================
# Layer (type:depth-idx)                        Output Shape              Param #
# ===============================================================================================
# CNN_CASE_1                                    [32, 3]                   --
# ├─ResNet: 1-1                                 [32, 1000]                --
# │    └─Conv2d: 2-1                            [32, 64, 14, 14]          3,136
# │    └─BatchNorm2d: 2-2                       [32, 64, 14, 14]          128
# │    └─ReLU: 2-3                              [32, 64, 14, 14]          --
# │    └─MaxPool2d: 2-4                         [32, 64, 7, 7]            --
# │    └─Sequential: 2-5                        [32, 64, 7, 7]            --
# │    │    └─BasicBlock: 3-1                   [32, 64, 7, 7]            73,984
# │    │    └─BasicBlock: 3-2                   [32, 64, 7, 7]            73,984
# │    └─Sequential: 2-6                        [32, 128, 4, 4]           --
# │    │    └─BasicBlock: 3-3                   [32, 128, 4, 4]           230,144
# │    │    └─BasicBlock: 3-4                   [32, 128, 4, 4]           295,424
# │    └─Sequential: 2-7                        [32, 256, 2, 2]           --
# │    │    └─BasicBlock: 3-5                   [32, 256, 2, 2]           919,040
# │    │    └─BasicBlock: 3-6                   [32, 256, 2, 2]           1,180,672
# │    └─Sequential: 2-8                        [32, 512, 1, 1]           --
# │    │    └─BasicBlock: 3-7                   [32, 512, 1, 1]           3,673,088
# │    │    └─BasicBlock: 3-8                   [32, 512, 1, 1]           4,720,640
# │    └─AdaptiveAvgPool2d: 2-9                 [32, 512, 1, 1]           --
# │    └─Linear: 2-10                           [32, 1000]                513,000
# ├─ResNet: 1-2                                 [32, 1000]                --
# │    └─Conv2d: 2-11                           [32, 64, 14, 14]          3,136
# │    └─BatchNorm2d: 2-12                      [32, 64, 14, 14]          128
# │    └─ReLU: 2-13                             [32, 64, 14, 14]          --
# │    └─MaxPool2d: 2-14                        [32, 64, 7, 7]            --
# │    └─Sequential: 2-15                       [32, 64, 7, 7]            --
# │    │    └─BasicBlock: 3-9                   [32, 64, 7, 7]            73,984
# │    │    └─BasicBlock: 3-10                  [32, 64, 7, 7]            73,984
# │    └─Sequential: 2-16                       [32, 128, 4, 4]           --
# │    │    └─BasicBlock: 3-11                  [32, 128, 4, 4]           230,144
# │    │    └─BasicBlock: 3-12                  [32, 128, 4, 4]           295,424
# │    └─Sequential: 2-17                       [32, 256, 2, 2]           --
# │    │    └─BasicBlock: 3-13                  [32, 256, 2, 2]           919,040
# │    │    └─BasicBlock: 3-14                  [32, 256, 2, 2]           1,180,672
# │    └─Sequential: 2-18                       [32, 512, 1, 1]           --
# │    │    └─BasicBlock: 3-15                  [32, 512, 1, 1]           3,673,088
# │    │    └─BasicBlock: 3-16                  [32, 512, 1, 1]           4,720,640
# │    └─AdaptiveAvgPool2d: 2-19                [32, 512, 1, 1]           --
# │    └─Linear: 2-20                           [32, 1000]                513,000
# ├─Linear: 1-3                                 [32, 3]                   6,003
# ├─Softmax: 1-4                                [32, 3]                   --
# ===============================================================================================
# Total params: 23,372,483
# Trainable params: 23,372,483
# Non-trainable params: 0
# Total mult-adds (Units.GIGABYTES): 2.15
# ===============================================================================================
# Input size (MB): 0.10
# Forward/backward pass size (MB): 44.55
# Params size (MB): 93.49
# Estimated Total Size (MB): 138.14
# ===============================================================================================

# %%
# 2. Shared backbone & Shared head

model_case_2 = define_model(temp_backbone_name, case_name='2', device=device)
print(summary(model=model_case_2, input_size=input_size))
# Out:
# ===============================================================================================
# Layer (type:depth-idx)                        Output Shape              Param #
# ===============================================================================================
# CNN_CASE_2                                    [32, 3]                   --
# ├─ResNet: 1-1                                 [32, 1000]                --
# │    └─Conv2d: 2-1                            [32, 64, 14, 14]          3,136
# │    └─BatchNorm2d: 2-2                       [32, 64, 14, 14]          128
# │    └─ReLU: 2-3                              [32, 64, 14, 14]          --
# │    └─MaxPool2d: 2-4                         [32, 64, 7, 7]            --
# │    └─Sequential: 2-5                        [32, 64, 7, 7]            --
# │    │    └─BasicBlock: 3-1                   [32, 64, 7, 7]            73,984
# │    │    └─BasicBlock: 3-2                   [32, 64, 7, 7]            73,984
# │    └─Sequential: 2-6                        [32, 128, 4, 4]           --
# │    │    └─BasicBlock: 3-3                   [32, 128, 4, 4]           230,144
# │    │    └─BasicBlock: 3-4                   [32, 128, 4, 4]           295,424
# │    └─Sequential: 2-7                        [32, 256, 2, 2]           --
# │    │    └─BasicBlock: 3-5                   [32, 256, 2, 2]           919,040
# │    │    └─BasicBlock: 3-6                   [32, 256, 2, 2]           1,180,672
# │    └─Sequential: 2-8                        [32, 512, 1, 1]           --
# │    │    └─BasicBlock: 3-7                   [32, 512, 1, 1]           3,673,088
# │    │    └─BasicBlock: 3-8                   [32, 512, 1, 1]           4,720,640
# │    └─AdaptiveAvgPool2d: 2-9                 [32, 512, 1, 1]           --
# │    └─Linear: 2-10                           [32, 1000]                513,000
# ├─Linear: 1-2                                 [32, 3]                   3,003
# ├─Softmax: 1-3                                [32, 3]                   --
# ===============================================================================================
# Total params: 11,686,243
# Trainable params: 11,686,243
# Non-trainable params: 0
# Total mult-adds (Units.GIGABYTES): 1.07
# ===============================================================================================
# Input size (MB): 0.10
# Forward/backward pass size (MB): 22.28
# Params size (MB): 46.74
# Estimated Total Size (MB): 69.12
# ===============================================================================================

# %%
# 3. Shared backbone & Non-Shared head

model_case_3 = define_model(temp_backbone_name, case_name='3', device=device)
print(summary(model=model_case_3, input_size=input_size))
# Out:
# ===============================================================================================
# Layer (type:depth-idx)                        Output Shape              Param #
# ===============================================================================================
# CNN_CASE_3                                    [32, 2]                   --
# ├─ResNet: 1-1                                 [32, 1000]                --
# │    └─Conv2d: 2-1                            [32, 64, 14, 14]          3,136
# │    └─BatchNorm2d: 2-2                       [32, 64, 14, 14]          128
# │    └─ReLU: 2-3                              [32, 64, 14, 14]          --
# │    └─MaxPool2d: 2-4                         [32, 64, 7, 7]            --
# │    └─Sequential: 2-5                        [32, 64, 7, 7]            --
# │    │    └─BasicBlock: 3-1                   [32, 64, 7, 7]            73,984
# │    │    └─BasicBlock: 3-2                   [32, 64, 7, 7]            73,984
# │    └─Sequential: 2-6                        [32, 128, 4, 4]           --
# │    │    └─BasicBlock: 3-3                   [32, 128, 4, 4]           230,144
# │    │    └─BasicBlock: 3-4                   [32, 128, 4, 4]           295,424
# │    └─Sequential: 2-7                        [32, 256, 2, 2]           --
# │    │    └─BasicBlock: 3-5                   [32, 256, 2, 2]           919,040
# │    │    └─BasicBlock: 3-6                   [32, 256, 2, 2]           1,180,672
# │    └─Sequential: 2-8                        [32, 512, 1, 1]           --
# │    │    └─BasicBlock: 3-7                   [32, 512, 1, 1]           3,673,088
# │    │    └─BasicBlock: 3-8                   [32, 512, 1, 1]           4,720,640
# │    └─AdaptiveAvgPool2d: 2-9                 [32, 512, 1, 1]           --
# │    └─Linear: 2-10                           [32, 1000]                513,000
# ├─Linear: 1-2                                 [32, 2]                   2,002
# ├─Linear: 1-3                                 [32, 2]                   2,002
# ├─Softmax: 1-4                                [32, 2]                   --
# ├─Softmax: 1-5                                [32, 2]                   --
# ===============================================================================================
# Total params: 11,687,244
# Trainable params: 11,687,244
# Non-trainable params: 0
# Total mult-adds (Units.GIGABYTES): 1.07
# ===============================================================================================
# Input size (MB): 0.10
# Forward/backward pass size (MB): 22.28
# Params size (MB): 46.75
# Estimated Total Size (MB): 69.13
# ===============================================================================================

# %%
# 4. Non-Shared backbone & Non-Shared head (4-1)

model_case_4_1 = define_model(temp_backbone_name, case_name='4_1', device=device)
print(summary(model=model_case_4_1, input_size=input_size))
# Out:
# ===============================================================================================
# Layer (type:depth-idx)                        Output Shape              Param #
# ===============================================================================================
# CNN_CASE_4_1                                  [32, 2]                   --
# ├─ResNet: 1-1                                 [32, 1000]                --
# │    └─Conv2d: 2-1                            [32, 64, 14, 14]          3,136
# │    └─BatchNorm2d: 2-2                       [32, 64, 14, 14]          128
# │    └─ReLU: 2-3                              [32, 64, 14, 14]          --
# │    └─MaxPool2d: 2-4                         [32, 64, 7, 7]            --
# │    └─Sequential: 2-5                        [32, 64, 7, 7]            --
# │    │    └─BasicBlock: 3-1                   [32, 64, 7, 7]            73,984
# │    │    └─BasicBlock: 3-2                   [32, 64, 7, 7]            73,984
# │    └─Sequential: 2-6                        [32, 128, 4, 4]           --
# │    │    └─BasicBlock: 3-3                   [32, 128, 4, 4]           230,144
# │    │    └─BasicBlock: 3-4                   [32, 128, 4, 4]           295,424
# │    └─Sequential: 2-7                        [32, 256, 2, 2]           --
# │    │    └─BasicBlock: 3-5                   [32, 256, 2, 2]           919,040
# │    │    └─BasicBlock: 3-6                   [32, 256, 2, 2]           1,180,672
# │    └─Sequential: 2-8                        [32, 512, 1, 1]           --
# │    │    └─BasicBlock: 3-7                   [32, 512, 1, 1]           3,673,088
# │    │    └─BasicBlock: 3-8                   [32, 512, 1, 1]           4,720,640
# │    └─AdaptiveAvgPool2d: 2-9                 [32, 512, 1, 1]           --
# │    └─Linear: 2-10                           [32, 1000]                513,000
# ├─ResNet: 1-2                                 [32, 1000]                --
# │    └─Conv2d: 2-11                           [32, 64, 14, 14]          3,136
# │    └─BatchNorm2d: 2-12                      [32, 64, 14, 14]          128
# │    └─ReLU: 2-13                             [32, 64, 14, 14]          --
# │    └─MaxPool2d: 2-14                        [32, 64, 7, 7]            --
# │    └─Sequential: 2-15                       [32, 64, 7, 7]            --
# │    │    └─BasicBlock: 3-9                   [32, 64, 7, 7]            73,984
# │    │    └─BasicBlock: 3-10                  [32, 64, 7, 7]            73,984
# │    └─Sequential: 2-16                       [32, 128, 4, 4]           --
# │    │    └─BasicBlock: 3-11                  [32, 128, 4, 4]           230,144
# │    │    └─BasicBlock: 3-12                  [32, 128, 4, 4]           295,424
# │    └─Sequential: 2-17                       [32, 256, 2, 2]           --
# │    │    └─BasicBlock: 3-13                  [32, 256, 2, 2]           919,040
# │    │    └─BasicBlock: 3-14                  [32, 256, 2, 2]           1,180,672
# │    └─Sequential: 2-18                       [32, 512, 1, 1]           --
# │    │    └─BasicBlock: 3-15                  [32, 512, 1, 1]           3,673,088
# │    │    └─BasicBlock: 3-16                  [32, 512, 1, 1]           4,720,640
# │    └─AdaptiveAvgPool2d: 2-19                [32, 512, 1, 1]           --
# │    └─Linear: 2-20                           [32, 1000]                513,000
# ├─Linear: 1-3                                 [32, 2]                   4,002
# ├─Linear: 1-4                                 [32, 2]                   4,002
# ├─Softmax: 1-5                                [32, 2]                   --
# ├─Softmax: 1-6                                [32, 2]                   --
# ===============================================================================================
# Total params: 23,374,484
# Trainable params: 23,374,484
# Non-trainable params: 0
# Total mult-adds (Units.GIGABYTES): 2.15
# ===============================================================================================
# Input size (MB): 0.10
# Forward/backward pass size (MB): 44.55
# Params size (MB): 93.50
# Estimated Total Size (MB): 138.15
# ===============================================================================================

# %%
# 5. Non-Shared backbone & Non-Shared head (4-2)

model_case_4_2 = define_model(temp_backbone_name, case_name='4_2', device=device)
print(summary(model=model_case_4_2, input_size=input_size))
# Out:
# ===============================================================================================
# Layer (type:depth-idx)                        Output Shape              Param #
# ===============================================================================================
# CNN_CASE_4_2                                  [32, 2]                   --
# ├─ResNet: 1-1                                 [32, 1000]                --
# │    └─Conv2d: 2-1                            [32, 64, 14, 14]          3,136
# │    └─BatchNorm2d: 2-2                       [32, 64, 14, 14]          128
# │    └─ReLU: 2-3                              [32, 64, 14, 14]          --
# │    └─MaxPool2d: 2-4                         [32, 64, 7, 7]            --
# │    └─Sequential: 2-5                        [32, 64, 7, 7]            --
# │    │    └─BasicBlock: 3-1                   [32, 64, 7, 7]            73,984
# │    │    └─BasicBlock: 3-2                   [32, 64, 7, 7]            73,984
# │    └─Sequential: 2-6                        [32, 128, 4, 4]           --
# │    │    └─BasicBlock: 3-3                   [32, 128, 4, 4]           230,144
# │    │    └─BasicBlock: 3-4                   [32, 128, 4, 4]           295,424
# │    └─Sequential: 2-7                        [32, 256, 2, 2]           --
# │    │    └─BasicBlock: 3-5                   [32, 256, 2, 2]           919,040
# │    │    └─BasicBlock: 3-6                   [32, 256, 2, 2]           1,180,672
# │    └─Sequential: 2-8                        [32, 512, 1, 1]           --
# │    │    └─BasicBlock: 3-7                   [32, 512, 1, 1]           3,673,088
# │    │    └─BasicBlock: 3-8                   [32, 512, 1, 1]           4,720,640
# │    └─AdaptiveAvgPool2d: 2-9                 [32, 512, 1, 1]           --
# │    └─Linear: 2-10                           [32, 1000]                513,000
# ├─ResNet: 1-2                                 [32, 1000]                --
# │    └─Conv2d: 2-11                           [32, 64, 14, 14]          3,136
# │    └─BatchNorm2d: 2-12                      [32, 64, 14, 14]          128
# │    └─ReLU: 2-13                             [32, 64, 14, 14]          --
# │    └─MaxPool2d: 2-14                        [32, 64, 7, 7]            --
# │    └─Sequential: 2-15                       [32, 64, 7, 7]            --
# │    │    └─BasicBlock: 3-9                   [32, 64, 7, 7]            73,984
# │    │    └─BasicBlock: 3-10                  [32, 64, 7, 7]            73,984
# │    └─Sequential: 2-16                       [32, 128, 4, 4]           --
# │    │    └─BasicBlock: 3-11                  [32, 128, 4, 4]           230,144
# │    │    └─BasicBlock: 3-12                  [32, 128, 4, 4]           295,424
# │    └─Sequential: 2-17                       [32, 256, 2, 2]           --
# │    │    └─BasicBlock: 3-13                  [32, 256, 2, 2]           919,040
# │    │    └─BasicBlock: 3-14                  [32, 256, 2, 2]           1,180,672
# │    └─Sequential: 2-18                       [32, 512, 1, 1]           --
# │    │    └─BasicBlock: 3-15                  [32, 512, 1, 1]           3,673,088
# │    │    └─BasicBlock: 3-16                  [32, 512, 1, 1]           4,720,640
# │    └─AdaptiveAvgPool2d: 2-19                [32, 512, 1, 1]           --
# │    └─Linear: 2-20                           [32, 1000]                513,000
# ├─Linear: 1-3                                 [32, 2]                   2,002
# ├─Linear: 1-4                                 [32, 2]                   2,002
# ├─Softmax: 1-5                                [32, 2]                   --
# ├─Softmax: 1-6                                [32, 2]                   --
# ===============================================================================================
# Total params: 23,370,484
# Trainable params: 23,370,484
# Non-trainable params: 0
# Total mult-adds (Units.GIGABYTES): 2.15
# ===============================================================================================
# Input size (MB): 0.10
# Forward/backward pass size (MB): 44.55
# Params size (MB): 93.48
# Estimated Total Size (MB): 138.14
# ===============================================================================================

# %% [markdown]
# **6. 데이터셋 분리**
#
# * Train Data -> Train Data + Valid Data

# %%
# dataset size

num_tv = sum(train_subset_class_counts)
num_valid = int(0.1 * num_tv)
num_train = num_tv - num_valid

# %%
# 데이터셋 분리

from torch.utils.data import random_split

train_dataset, valid_dataset = random_split(train_subset, [num_train, num_valid])

# %%
# DataLoader 생성

train_dataset_loader = DataLoader(train_dataset,
                                  batch_size=BATCH_SIZE,
                                  shuffle=True)

valid_dataset_loader = DataLoader(valid_dataset,
                                  batch_size=BATCH_SIZE,
                                  shuffle=False)

test_dataset_loader = test_subset_loader

# %%
# {0,1} vs. {2} / {0,2} vs. {1} Split 된 DataLoader 생성

from torch.utils.data import Dataset

class DualOutputDataset(Dataset):
    def __init__(self, dataset):
        self.dataset = dataset

    def __len__(self):
        return len(self.dataset)

    def __getitem__(self, idx):
        img, target = self.dataset[idx]
        target1_mapping = {0: 0, 1: 0, 2: 1}
        target2_mapping = {0: 0, 1: 1, 2: 0}

        target1 = target1_mapping[target]
        target2 = target2_mapping[target]

        return img, [target1, target2]

# %%
# Dual Output Dataset 생성

train_01_02_dataset_loader = DataLoader(DualOutputDataset(train_dataset),
                                        batch_size=BATCH_SIZE,
                                        shuffle=True)

valid_01_02_dataset_loader = DataLoader(DualOutputDataset(valid_dataset),
                                        batch_size=BATCH_SIZE,
                                        shuffle=False)

test_01_02_dataset_loader = DataLoader(DualOutputDataset(test_subset),
                                       batch_size=BATCH_SIZE,
                                       shuffle=False)

# %% [markdown]
# **7. 모델 학습 함수 정의**

# %%
MAX_EPOCHS = 9999
EARLY_STOPPING_ROUNDS = 10  # Early Stopping Patience (epochs)

# %%
# dual labels -> PyTorch tensor

def convert_to_tensor(labels):
    labels[0] = list(labels[0])
    labels[1] = list(labels[1])
    labels_tensor = torch.tensor(labels)
    labels_tensor = labels_tensor.transpose(0, 1)

    return labels_tensor

# %%
# 모델 학습 실시

# args :
# - model           : 학습할 모델
# - train_loader    : Training Data Loader
# - train_loss_list : 각 epoch 에서의 train loss 기록
# - is_dual_head    : 신경망 출력값, 즉 MLP Head 가 2개인지의 여부

# returns :
# - train_loss : 모델의 Train Loss

def run_train(model, train_loader, train_loss_list, is_dual_head, verbose):
    model.train()
    train_loss = 0.0
    train_idx = 0

    for images, labels in train_loader:
        if is_dual_head:
            labels = convert_to_tensor(labels)
        images, labels = images.to(device), labels.to(device)

        # train 실시
        model.optimizer.zero_grad()
        outputs = model(images)

        if is_dual_head:
            loss1 = nn.CrossEntropyLoss()(outputs[0], labels[:, 0])
            loss2 = nn.CrossEntropyLoss()(outputs[1], labels[:, 1])
            loss = loss1 + loss2
        else:
            loss = nn.CrossEntropyLoss()(outputs, labels)

        loss.backward()
        model.optimizer.step()

        train_loss += loss.item()
        train_idx += 1

        if verbose:
            if train_idx % 20 == 0:
                print(f'idx: {train_idx}, loss for current idx: {loss.item():.6f}')

    train_loss_list.append(train_loss / len(train_loader))
    return train_loss_list[-1]

# %%
import time

# 모델 validation / test 실시

# args :
# - model                : validation/test 할 모델
# - valid_or_test_loader : validation/test Data Loader
# - is_dual_head         : 신경망 출력값, 즉 MLP Head 가 2개인지의 여부

# returns :
# - accuracy       : 모델의 validation/test 정확도
# - inference_time : inference 시간 (seconds)

def run_valid_or_test(model, valid_or_test_loader, is_dual_head):
    model.eval()
    correct, total = 0, 0
    inference_time_sum = 0.0
    valid_test_idx = 0

    with torch.no_grad():
        for images, labels in valid_or_test_loader:
            if is_dual_head:
                labels = convert_to_tensor(labels)
            images, labels = images.to(device), labels.to(device)

            start_at = time.time()
            outputs = model(images)
            inference_time_sum += time.time() - start_at

            # validation/test 실시 및 정확도 측정
            if is_dual_head:
                _, predicted_1 = torch.max(outputs[0], 1)
                _, predicted_2 = torch.max(outputs[1], 1)
                correct += (predicted_1 == labels[:, 0]).sum().item()
                correct += (predicted_2 == labels[:, 1]).sum().item()
                total += 2 * labels.size(0)

            else:
                _, predicted = torch.max(outputs, 1)
                correct += (predicted == labels).sum().item()
                total += labels.size(0)

            valid_test_idx += 1

    accuracy = correct / total
    inference_time = inference_time_sum / valid_test_idx

    return accuracy, inference_time

# %%
# 모델 학습 및 validation 전체 프로세스

# args :
# - model         : 학습할 모델
# - train_loader  : Training Data Loader
# - valid_loader  : Valid Data Loader
# - test_loader   : Test Data Loader
# - backbone_name : Backbone 모델 이름 ('resnet18', 'resnet34' or 'resnet50')
# - case_name     : 모델 구조 case 이름 ('1', '2', '3', '4_1' or '4_2')
# - verbose       : 학습 중 프로세스 출력 여부

# returns :
# - final_acc      : 해당 하이퍼파라미터 조합에 대한 최종 Accuracy (valid_acc 이 가장 높았던 epoch 의 모델로 측정)
# - inference_time : inference 시간 (seconds)

def run_model_common(model, train_loader, valid_loader, test_loader,
                     backbone_name, case_name, verbose=False):

    train_loss_list = []       # train loss
    valid_acc_list = []        # valid accuracy
    max_valid_acc = 0.0        # max validation accuracy
    best_valid_acc_epoch = -1  # valid_acc 이 가장 높았던 epoch (여기서는 Loss 가 아닌 Accuracy 기준 Early Stopping)
    best_epoch_model = None    # valid_acc 이 가장 높았던 epoch 의 모델

    is_dual_head = case_name in ['3', '4_1', '4_2']

    # 1. 학습 실시
    for epoch in range(MAX_EPOCHS):

        # 1-1. train model
        train_loss = run_train(model,
                               train_loader,
                               train_loss_list,
                               is_dual_head,
                               verbose=(verbose and epoch == 0))

        # 1-2. validate model (with VALID SET)
        epoch_acc, _ = run_valid_or_test(model, valid_loader, is_dual_head)
        valid_acc_list.append(epoch_acc)

        # 1-3. Early Stopping 처리 (overfitting 방지)
        if epoch_acc > max_valid_acc:
            max_valid_acc = epoch_acc
            best_valid_acc_epoch = epoch

            best_epoch_model = define_model(backbone_name, case_name, device)
            best_epoch_model.load_state_dict(model.state_dict())

            if verbose:
                print('best model updated')

        if epoch - best_valid_acc_epoch >= EARLY_STOPPING_ROUNDS:
            break

        # 1-4. 결과 출력
        if verbose:
            print(f"Epoch {epoch+1}, Loss: {train_loss:.4f}, Accuracy: {epoch_acc:.4f}")

    # check best-epoch model correctly loaded
    checked_acc, _ = run_valid_or_test(best_epoch_model, valid_loader, is_dual_head)

    if verbose:
        print(f"Best Epoch: {best_valid_acc_epoch}, Best Valid Acc: {max_valid_acc}")
        print(f"Valid Acc (with Epoch valid set) on Loaded Best Model: {checked_acc}")

    assert abs(max_valid_acc - checked_acc) < 1e-6

    # 2. test best-epoch model (with TEST SET)
    final_acc, inference_time = run_valid_or_test(best_epoch_model, test_loader, is_dual_head)

    if verbose:
        print(f"Final Acc (with TEST set) on Loaded Best Model: {final_acc} (time: {inference_time})")

    return final_acc, inference_time

# %% [markdown]
# **8. 학습 실시**

# %%
print(device)
# Out:
# cuda

# %%
result_dict = {
    'backbone': [],
    'case': [],
    'accuracy': [],
    'inference_time': []
}

dataloader_by_case_name = {
    'dual_head': {
        'train': train_01_02_dataset_loader,
        'valid': valid_01_02_dataset_loader,
        'test': test_01_02_dataset_loader
    },
    'single_head': {
        'train': train_dataset_loader,
        'valid': valid_dataset_loader,
        'test': test_dataset_loader
    }
}

for case_name in ['1', '2', '3', '4_1', '4_2']:
    if case_name in ['3', '4_1', '4_2']:
        head_type = 'dual_head'
    else:
        head_type = 'single_head'

    for backbone_name in ['resnet18', 'resnet34', 'resnet50']:
        print(f'\n=== case={case_name}, backbone={backbone_name} ===')
        model = define_model(backbone_name, case_name, device=device)

        train_loader = dataloader_by_case_name[head_type]['train']
        valid_loader = dataloader_by_case_name[head_type]['valid']
        test_loader = dataloader_by_case_name[head_type]['test']

        final_acc, inference_time = run_model_common(model,
                                                     train_loader=train_loader,
                                                     valid_loader=valid_loader,
                                                     test_loader=test_loader,
                                                     backbone_name=backbone_name,
                                                     case_name=case_name,
                                                     verbose=True)

        result_dict['backbone'].append(backbone_name)
        result_dict['case'].append(case_name)
        result_dict['accuracy'].append(final_acc)
        result_dict['inference_time'].append(inference_time)
# Out:
# === case=1, backbone=resnet18 ===
# idx: 20, loss for current idx: 0.653857
# idx: 40, loss for current idx: 0.659568
# idx: 60, loss for current idx: 0.587841
# idx: 80, loss for current idx: 0.660984
# idx: 100, loss for current idx: 0.588861
# idx: 120, loss for current idx: 0.572445
# idx: 140, loss for current idx: 0.583521
# idx: 160, loss for current idx: 0.614681
# idx: 180, loss for current idx: 0.644210
# idx: 200, loss for current idx: 0.558130
# idx: 220, loss for current idx: 0.552170
# idx: 240, loss for current idx: 0.557243
# idx: 260, loss for current idx: 0.560693
# idx: 280, loss for current idx: 0.553174
# idx: 300, loss for current idx: 0.582704
# idx: 320, loss for current idx: 0.551543
# idx: 340, loss for current idx: 0.551462
# idx: 360, loss for current idx: 0.558965
# idx: 380, loss for current idx: 0.613948
# idx: 400, loss for current idx: 0.605213
# idx: 420, loss for current idx: 0.583203
# idx: 440, loss for current idx: 0.573533
# idx: 460, loss for current idx: 0.595053
# idx: 480, loss for current idx: 0.551838
# idx: 500, loss for current idx: 0.551462
# idx: 520, loss for current idx: 0.596140
# best model updated
# Epoch 1, Loss: 0.5873, Accuracy: 0.9882
# Epoch 2, Loss: 0.5654, Accuracy: 0.9876
# best model updated
# Epoch 3, Loss: 0.5657, Accuracy: 0.9930
# Epoch 4, Loss: 0.5612, Accuracy: 0.9903
# Epoch 5, Loss: 0.5641, Accuracy: 0.9817
# best model updated
# Epoch 6, Loss: 0.5606, Accuracy: 0.9957
# Epoch 7, Loss: 0.5583, Accuracy: 0.9941
# Epoch 8, Loss: 0.5590, Accuracy: 0.9946
# Epoch 9, Loss: 0.5603, Accuracy: 0.9866
# Epoch 10, Loss: 0.5591, Accuracy: 0.9930
# Epoch 11, Loss: 0.5586, Accuracy: 0.9876
# Epoch 12, Loss: 0.5598, Accuracy: 0.9903
# Epoch 13, Loss: 0.5605, Accuracy: 0.9919
# Epoch 14, Loss: 0.5596, Accuracy: 0.9898
# Epoch 15, Loss: 0.5609, Accuracy: 0.9876
# Best Epoch: 5, Best Valid Acc: 0.9957035445757251
# Valid Acc (with Epoch valid set) on Loaded Best Model: 0.9957035445757251
# Final Acc (with TEST set) on Loaded Best Model: 0.994280266920877 (time: 0.004741437507398201)
#
# === case=1, backbone=resnet34 ===
# Downloading: "https://download.pytorch.org/models/resnet34-b627a593.pth" to /root/.cache/torch/hub/checkpoints/resnet34-b627a593.pth
# 100%|██████████| 83.3M/83.3M [00:00<00:00, 149MB/s]
# idx: 20, loss for current idx: 0.663815
# idx: 40, loss for current idx: 0.605467
# idx: 60, loss for current idx: 0.582338
# idx: 80, loss for current idx: 0.712944
# idx: 100, loss for current idx: 0.581446
# idx: 120, loss for current idx: 0.642506
# idx: 140, loss for current idx: 0.583268
# idx: 160, loss for current idx: 0.551688
# idx: 180, loss for current idx: 0.660429
# idx: 200, loss for current idx: 0.551535
# idx: 220, loss for current idx: 0.564917
# idx: 240, loss for current idx: 0.582620
# idx: 260, loss for current idx: 0.551447
# idx: 280, loss for current idx: 0.614220
# idx: 300, loss for current idx: 0.554843
# idx: 320, loss for current idx: 0.614485
# idx: 340, loss for current idx: 0.581543
# idx: 360, loss for current idx: 0.583015
# idx: 380, loss for current idx: 0.615847
# idx: 400, loss for current idx: 0.572798
# idx: 420, loss for current idx: 0.570583
# idx: 440, loss for current idx: 0.560436
# idx: 460, loss for current idx: 0.551472
# idx: 480, loss for current idx: 0.569519
# idx: 500, loss for current idx: 0.551542
# idx: 520, loss for current idx: 0.588483
# best model updated
# Epoch 1, Loss: 0.5883, Accuracy: 0.9855
# best model updated
# Epoch 2, Loss: 0.5692, Accuracy: 0.9919
# Epoch 3, Loss: 0.5642, Accuracy: 0.9812
# Epoch 4, Loss: 0.5627, Accuracy: 0.9876
# best model updated
# Epoch 5, Loss: 0.5609, Accuracy: 0.9936
# best model updated
# Epoch 6, Loss: 0.5590, Accuracy: 0.9957
# Epoch 7, Loss: 0.5600, Accuracy: 0.9941
# Epoch 8, Loss: 0.5628, Accuracy: 0.9898
# Epoch 9, Loss: 0.5579, Accuracy: 0.9952
# Epoch 10, Loss: 0.5567, Accuracy: 0.9936
# Epoch 11, Loss: 0.5603, Accuracy: 0.9914
# Epoch 12, Loss: 0.5596, Accuracy: 0.9941
# Epoch 13, Loss: 0.5613, Accuracy: 0.9919
# Epoch 14, Loss: 0.5595, Accuracy: 0.9952
# Epoch 15, Loss: 0.5629, Accuracy: 0.9721
# Best Epoch: 5, Best Valid Acc: 0.9957035445757251
# Valid Acc (with Epoch valid set) on Loaded Best Model: 0.9957035445757251
# Final Acc (with TEST set) on Loaded Best Model: 0.9958690816650778 (time: 0.008253933203340781)
#
# === case=1, backbone=resnet50 ===
# Downloading: "https://download.pytorch.org/models/resnet50-0676ba61.pth" to /root/.cache/torch/hub/checkpoints/resnet50-0676ba61.pth
# 100%|██████████| 97.8M/97.8M [00:00<00:00, 224MB/s]
# idx: 20, loss for current idx: 0.658905
# idx: 40, loss for current idx: 0.661390
# idx: 60, loss for current idx: 0.582829
# idx: 80, loss for current idx: 0.590982
# idx: 100, loss for current idx: 0.613509
# idx: 120, loss for current idx: 0.555851
# idx: 140, loss for current idx: 0.634061
# idx: 160, loss for current idx: 0.551539
# idx: 180, loss for current idx: 0.556512
# idx: 200, loss for current idx: 0.581384
# idx: 220, loss for current idx: 0.582796
# idx: 240, loss for current idx: 0.575954
# idx: 260, loss for current idx: 0.610009
# idx: 280, loss for current idx: 0.582698
# idx: 300, loss for current idx: 0.562583
# idx: 320, loss for current idx: 0.553603
# idx: 340, loss for current idx: 0.614894
# idx: 360, loss for current idx: 0.613877
# idx: 380, loss for current idx: 0.582488
# idx: 400, loss for current idx: 0.582705
# idx: 420, loss for current idx: 0.555099
# idx: 440, loss for current idx: 0.582762
# idx: 460, loss for current idx: 0.583794
# idx: 480, loss for current idx: 0.551483
# idx: 500, loss for current idx: 0.551556
# idx: 520, loss for current idx: 0.583206
# best model updated
# Epoch 1, Loss: 0.5927, Accuracy: 0.9839
# best model updated
# Epoch 2, Loss: 0.5715, Accuracy: 0.9882
# best model updated
# Epoch 3, Loss: 0.5645, Accuracy: 0.9887
# best model updated
# Epoch 4, Loss: 0.5618, Accuracy: 0.9941
# Epoch 5, Loss: 0.5608, Accuracy: 0.9844
# Epoch 6, Loss: 0.5624, Accuracy: 0.9914
# Epoch 7, Loss: 0.5590, Accuracy: 0.9930
# Epoch 8, Loss: 0.5606, Accuracy: 0.9925
# Epoch 9, Loss: 0.5576, Accuracy: 0.9936
# Epoch 10, Loss: 0.5565, Accuracy: 0.9936
# Epoch 11, Loss: 0.5623, Accuracy: 0.9586
# best model updated
# Epoch 12, Loss: 0.5642, Accuracy: 0.9946
# Epoch 13, Loss: 0.5590, Accuracy: 0.9936
# best model updated
# Epoch 14, Loss: 0.5575, Accuracy: 0.9952
# Epoch 15, Loss: 0.5567, Accuracy: 0.9898
# Epoch 16, Loss: 0.5601, Accuracy: 0.9952
# Epoch 17, Loss: 0.5630, Accuracy: 0.9576
# Epoch 18, Loss: 0.5609, Accuracy: 0.9893
# best model updated
# Epoch 19, Loss: 0.5566, Accuracy: 0.9962
# Epoch 20, Loss: 0.5562, Accuracy: 0.9925
# Epoch 21, Loss: 0.5588, Accuracy: 0.9914
# Epoch 22, Loss: 0.5582, Accuracy: 0.9941
# Epoch 23, Loss: 0.5563, Accuracy: 0.9936
# Epoch 24, Loss: 0.5548, Accuracy: 0.9930
# Epoch 25, Loss: 0.5554, Accuracy: 0.9941
# Epoch 26, Loss: 0.5553, Accuracy: 0.9946
# Epoch 27, Loss: 0.5567, Accuracy: 0.9930
# Epoch 28, Loss: 0.5547, Accuracy: 0.9941
# Best Epoch: 18, Best Valid Acc: 0.9962406015037594
# Valid Acc (with Epoch valid set) on Loaded Best Model: 0.9962406015037594
# Final Acc (with TEST set) on Loaded Best Model: 0.996186844613918 (time: 0.011401988039113055)
#
# === case=2, backbone=resnet18 ===
# idx: 20, loss for current idx: 0.692600
# idx: 40, loss for current idx: 0.645480
# idx: 60, loss for current idx: 0.634364
# idx: 80, loss for current idx: 0.618291
# idx: 100, loss for current idx: 0.586108
# idx: 120, loss for current idx: 0.587080
# idx: 140, loss for current idx: 0.586683
# idx: 160, loss for current idx: 0.551824
# idx: 180, loss for current idx: 0.552396
# idx: 200, loss for current idx: 0.582792
# idx: 220, loss for current idx: 0.588834
# idx: 240, loss for current idx: 0.582734
# idx: 260, loss for current idx: 0.582260
# idx: 280, loss for current idx: 0.556001
# idx: 300, loss for current idx: 0.551490
# idx: 320, loss for current idx: 0.582699
# idx: 340, loss for current idx: 0.604757
# idx: 360, loss for current idx: 0.578328
# idx: 380, loss for current idx: 0.551882
# idx: 400, loss for current idx: 0.613883
# idx: 420, loss for current idx: 0.582845
# idx: 440, loss for current idx: 0.553069
# idx: 460, loss for current idx: 0.552671
# idx: 480, loss for current idx: 0.551458
# idx: 500, loss for current idx: 0.590319
# idx: 520, loss for current idx: 0.598985
# best model updated
# Epoch 1, Loss: 0.5967, Accuracy: 0.9898
# Epoch 2, Loss: 0.5683, Accuracy: 0.9807
# best model updated
# Epoch 3, Loss: 0.5632, Accuracy: 0.9957
# Epoch 4, Loss: 0.5635, Accuracy: 0.9860
# Epoch 5, Loss: 0.5609, Accuracy: 0.9946
# Epoch 6, Loss: 0.5613, Accuracy: 0.9930
# Epoch 7, Loss: 0.5607, Accuracy: 0.9914
# Epoch 8, Loss: 0.5580, Accuracy: 0.9871
# Epoch 9, Loss: 0.5626, Accuracy: 0.9914
# Epoch 10, Loss: 0.5627, Accuracy: 0.9914
# Epoch 11, Loss: 0.5604, Accuracy: 0.9876
# Epoch 12, Loss: 0.5613, Accuracy: 0.9936
# Best Epoch: 2, Best Valid Acc: 0.9957035445757251
# Valid Acc (with Epoch valid set) on Loaded Best Model: 0.9957035445757251
# Final Acc (with TEST set) on Loaded Best Model: 0.9939625039720369 (time: 0.0024690700299812088)
#
# === case=2, backbone=resnet34 ===
# idx: 20, loss for current idx: 0.661698
# idx: 40, loss for current idx: 0.564175
# idx: 60, loss for current idx: 0.551893
# idx: 80, loss for current idx: 0.614105
# idx: 100, loss for current idx: 0.571412
# idx: 120, loss for current idx: 0.551512
# idx: 140, loss for current idx: 0.566825
# idx: 160, loss for current idx: 0.581389
# idx: 180, loss for current idx: 0.630527
# idx: 200, loss for current idx: 0.585023
# idx: 220, loss for current idx: 0.556952
# idx: 240, loss for current idx: 0.551497
# idx: 260, loss for current idx: 0.634282
# idx: 280, loss for current idx: 0.551550
# idx: 300, loss for current idx: 0.562097
# idx: 320, loss for current idx: 0.580896
# idx: 340, loss for current idx: 0.582871
# idx: 360, loss for current idx: 0.582856
# idx: 380, loss for current idx: 0.567817
# idx: 400, loss for current idx: 0.551492
# idx: 420, loss for current idx: 0.551762
# idx: 440, loss for current idx: 0.582628
# idx: 460, loss for current idx: 0.552210
# idx: 480, loss for current idx: 0.622936
# idx: 500, loss for current idx: 0.568345
# idx: 520, loss for current idx: 0.567510
# best model updated
# Epoch 1, Loss: 0.5889, Accuracy: 0.9887
# Epoch 2, Loss: 0.5633, Accuracy: 0.9817
# Epoch 3, Loss: 0.5649, Accuracy: 0.9855
# Epoch 4, Loss: 0.5666, Accuracy: 0.9866
# best model updated
# Epoch 5, Loss: 0.5597, Accuracy: 0.9914
# Epoch 6, Loss: 0.5610, Accuracy: 0.9887
# Epoch 7, Loss: 0.5615, Accuracy: 0.9882
# best model updated
# Epoch 8, Loss: 0.5589, Accuracy: 0.9936
# Epoch 9, Loss: 0.5604, Accuracy: 0.9936
# Epoch 10, Loss: 0.5605, Accuracy: 0.9876
# best model updated
# Epoch 11, Loss: 0.5598, Accuracy: 0.9946
# Epoch 12, Loss: 0.5587, Accuracy: 0.9930
# Epoch 13, Loss: 0.5633, Accuracy: 0.9871
# Epoch 14, Loss: 0.5630, Accuracy: 0.9919
# Epoch 15, Loss: 0.5595, Accuracy: 0.9903
# Epoch 16, Loss: 0.5577, Accuracy: 0.9930
# Epoch 17, Loss: 0.5551, Accuracy: 0.9925
# Epoch 18, Loss: 0.5579, Accuracy: 0.9882
# Epoch 19, Loss: 0.5588, Accuracy: 0.9898
# Epoch 20, Loss: 0.5607, Accuracy: 0.9930
# Best Epoch: 10, Best Valid Acc: 0.9946294307196563
# Valid Acc (with Epoch valid set) on Loaded Best Model: 0.9946294307196563
# Final Acc (with TEST set) on Loaded Best Model: 0.9949157928185574 (time: 0.004268034540041528)
#
# === case=2, backbone=resnet50 ===
# idx: 20, loss for current idx: 0.605852
# idx: 40, loss for current idx: 0.608301
# idx: 60, loss for current idx: 0.604733
# idx: 80, loss for current idx: 0.566265
# idx: 100, loss for current idx: 0.665155
# idx: 120, loss for current idx: 0.551497
# idx: 140, loss for current idx: 0.591093
# idx: 160, loss for current idx: 0.551571
# idx: 180, loss for current idx: 0.552753
# idx: 200, loss for current idx: 0.581727
# idx: 220, loss for current idx: 0.557663
# idx: 240, loss for current idx: 0.632187
# idx: 260, loss for current idx: 0.557278
# idx: 280, loss for current idx: 0.556484
# idx: 300, loss for current idx: 0.582710
# idx: 320, loss for current idx: 0.552529
# idx: 340, loss for current idx: 0.552333
# idx: 360, loss for current idx: 0.551528
# idx: 380, loss for current idx: 0.614357
# idx: 400, loss for current idx: 0.613891
# idx: 420, loss for current idx: 0.582405
# idx: 440, loss for current idx: 0.553553
# idx: 460, loss for current idx: 0.551890
# idx: 480, loss for current idx: 0.562535
# idx: 500, loss for current idx: 0.551449
# idx: 520, loss for current idx: 0.551565
# best model updated
# Epoch 1, Loss: 0.5896, Accuracy: 0.9850
# best model updated
# Epoch 2, Loss: 0.5685, Accuracy: 0.9860
# best model updated
# Epoch 3, Loss: 0.5620, Accuracy: 0.9936
# Epoch 4, Loss: 0.5598, Accuracy: 0.9882
# Epoch 5, Loss: 0.5597, Accuracy: 0.9866
# best model updated
# Epoch 6, Loss: 0.5593, Accuracy: 0.9957
# Epoch 7, Loss: 0.5570, Accuracy: 0.9914
# Epoch 8, Loss: 0.5678, Accuracy: 0.9882
# Epoch 9, Loss: 0.5632, Accuracy: 0.9855
# Epoch 10, Loss: 0.5602, Accuracy: 0.9914
# Epoch 11, Loss: 0.5624, Accuracy: 0.9791
# Epoch 12, Loss: 0.5672, Accuracy: 0.9919
# Epoch 13, Loss: 0.5619, Accuracy: 0.9930
# Epoch 14, Loss: 0.5588, Accuracy: 0.9930
# Epoch 15, Loss: 0.5598, Accuracy: 0.9946
# Best Epoch: 5, Best Valid Acc: 0.9957035445757251
# Valid Acc (with Epoch valid set) on Loaded Best Model: 0.9957035445757251
# Final Acc (with TEST set) on Loaded Best Model: 0.9939625039720369 (time: 0.005453562495684383)
#
# === case=3, backbone=resnet18 ===
# idx: 20, loss for current idx: 0.798262
# idx: 40, loss for current idx: 0.736396
# idx: 60, loss for current idx: 0.759184
# idx: 80, loss for current idx: 0.635155
# idx: 100, loss for current idx: 0.649239
# idx: 120, loss for current idx: 0.664631
# idx: 140, loss for current idx: 0.670447
# idx: 160, loss for current idx: 0.722304
# idx: 180, loss for current idx: 0.718008
# idx: 200, loss for current idx: 0.646054
# idx: 220, loss for current idx: 0.626538
# idx: 240, loss for current idx: 0.645209
# idx: 260, loss for current idx: 0.650317
# idx: 280, loss for current idx: 0.658154
# idx: 300, loss for current idx: 0.679267
# idx: 320, loss for current idx: 0.665611
# idx: 340, loss for current idx: 0.692692
# idx: 360, loss for current idx: 0.626603
# idx: 380, loss for current idx: 0.678491
# idx: 400, loss for current idx: 0.631402
# idx: 420, loss for current idx: 0.705228
# idx: 440, loss for current idx: 0.658580
# idx: 460, loss for current idx: 0.658240
# idx: 480, loss for current idx: 0.643958
# idx: 500, loss for current idx: 0.720611
# idx: 520, loss for current idx: 0.706535
# best model updated
# Epoch 1, Loss: 0.6699, Accuracy: 0.9911
# best model updated
# Epoch 2, Loss: 0.6402, Accuracy: 0.9952
# best model updated
# Epoch 3, Loss: 0.6376, Accuracy: 0.9960
# Epoch 4, Loss: 0.6358, Accuracy: 0.9952
# Epoch 5, Loss: 0.6356, Accuracy: 0.9933
# best model updated
# Epoch 6, Loss: 0.6401, Accuracy: 0.9965
# Epoch 7, Loss: 0.6344, Accuracy: 0.9927
# Epoch 8, Loss: 0.6372, Accuracy: 0.9930
# Epoch 9, Loss: 0.6349, Accuracy: 0.9927
# Epoch 10, Loss: 0.6353, Accuracy: 0.9946
# Epoch 11, Loss: 0.6352, Accuracy: 0.9962
# Epoch 12, Loss: 0.6347, Accuracy: 0.9933
# Epoch 13, Loss: 0.6347, Accuracy: 0.9941
# Epoch 14, Loss: 0.6397, Accuracy: 0.9919
# Epoch 15, Loss: 0.6341, Accuracy: 0.9960
# Best Epoch: 5, Best Valid Acc: 0.9965091299677766
# Valid Acc (with Epoch valid set) on Loaded Best Model: 0.9965091299677766
# Final Acc (with TEST set) on Loaded Best Model: 0.9965046075627582 (time: 0.0024690483555649266)
#
# === case=3, backbone=resnet34 ===
# idx: 20, loss for current idx: 0.793410
# idx: 40, loss for current idx: 0.675126
# idx: 60, loss for current idx: 0.699499
# idx: 80, loss for current idx: 0.641536
# idx: 100, loss for current idx: 0.742842
# idx: 120, loss for current idx: 0.675655
# idx: 140, loss for current idx: 0.629733
# idx: 160, loss for current idx: 0.739265
# idx: 180, loss for current idx: 0.628244
# idx: 200, loss for current idx: 0.689319
# idx: 220, loss for current idx: 0.626580
# idx: 240, loss for current idx: 0.689227
# idx: 260, loss for current idx: 0.652303
# idx: 280, loss for current idx: 0.660898
# idx: 300, loss for current idx: 0.689930
# idx: 320, loss for current idx: 0.726848
# idx: 340, loss for current idx: 0.741111
# idx: 360, loss for current idx: 0.627732
# idx: 380, loss for current idx: 0.627057
# idx: 400, loss for current idx: 0.654671
# idx: 420, loss for current idx: 0.627516
# idx: 440, loss for current idx: 0.630497
# idx: 460, loss for current idx: 0.631235
# idx: 480, loss for current idx: 0.720978
# idx: 500, loss for current idx: 0.626566
# idx: 520, loss for current idx: 0.658257
# best model updated
# Epoch 1, Loss: 0.6770, Accuracy: 0.9930
# best model updated
# Epoch 2, Loss: 0.6425, Accuracy: 0.9936
# Epoch 3, Loss: 0.6377, Accuracy: 0.9925
# Epoch 4, Loss: 0.6387, Accuracy: 0.9895
# best model updated
# Epoch 5, Loss: 0.6398, Accuracy: 0.9957
# Epoch 6, Loss: 0.6411, Accuracy: 0.9842
# Epoch 7, Loss: 0.6408, Accuracy: 0.9903
# best model updated
# Epoch 8, Loss: 0.6366, Accuracy: 0.9962
# best model updated
# Epoch 9, Loss: 0.6319, Accuracy: 0.9973
# Epoch 10, Loss: 0.6380, Accuracy: 0.9938
# Epoch 11, Loss: 0.6370, Accuracy: 0.9906
# Epoch 12, Loss: 0.6358, Accuracy: 0.9933
# Epoch 13, Loss: 0.6357, Accuracy: 0.9960
# Epoch 14, Loss: 0.6322, Accuracy: 0.9949
# Epoch 15, Loss: 0.6409, Accuracy: 0.9949
# best model updated
# Epoch 16, Loss: 0.6328, Accuracy: 0.9979
# Epoch 17, Loss: 0.6304, Accuracy: 0.9976
# Epoch 18, Loss: 0.6400, Accuracy: 0.9941
# Epoch 19, Loss: 0.6343, Accuracy: 0.9973
# Epoch 20, Loss: 0.6317, Accuracy: 0.9965
# Epoch 21, Loss: 0.6328, Accuracy: 0.9874
# Epoch 22, Loss: 0.6315, Accuracy: 0.9968
# Epoch 23, Loss: 0.6314, Accuracy: 0.9970
# Epoch 24, Loss: 0.6313, Accuracy: 0.9952
# Epoch 25, Loss: 0.6333, Accuracy: 0.9979
# Best Epoch: 15, Best Valid Acc: 0.9978517722878625
# Valid Acc (with Epoch valid set) on Loaded Best Model: 0.9978517722878625
# Final Acc (with TEST set) on Loaded Best Model: 0.9958690816650778 (time: 0.004139038047405204)
#
# === case=3, backbone=resnet50 ===
# idx: 20, loss for current idx: 0.841973
# idx: 40, loss for current idx: 0.718562
# idx: 60, loss for current idx: 0.689538
# idx: 80, loss for current idx: 0.672131
# idx: 100, loss for current idx: 0.678298
# idx: 120, loss for current idx: 0.776908
# idx: 140, loss for current idx: 0.633081
# idx: 160, loss for current idx: 0.632027
# idx: 180, loss for current idx: 0.710927
# idx: 200, loss for current idx: 0.657402
# idx: 220, loss for current idx: 0.778828
# idx: 240, loss for current idx: 0.657925
# idx: 260, loss for current idx: 0.657346
# idx: 280, loss for current idx: 0.626815
# idx: 300, loss for current idx: 0.627056
# idx: 320, loss for current idx: 0.648165
# idx: 340, loss for current idx: 0.626807
# idx: 360, loss for current idx: 0.688718
# idx: 380, loss for current idx: 0.763897
# idx: 400, loss for current idx: 0.626675
# idx: 420, loss for current idx: 0.716806
# idx: 440, loss for current idx: 0.660140
# idx: 460, loss for current idx: 0.689156
# idx: 480, loss for current idx: 0.627774
# idx: 500, loss for current idx: 0.689797
# idx: 520, loss for current idx: 0.696945
# best model updated
# Epoch 1, Loss: 0.6936, Accuracy: 0.9879
# best model updated
# Epoch 2, Loss: 0.6492, Accuracy: 0.9922
# best model updated
# Epoch 3, Loss: 0.6429, Accuracy: 0.9927
# best model updated
# Epoch 4, Loss: 0.6420, Accuracy: 0.9938
# Epoch 5, Loss: 0.6375, Accuracy: 0.9909
# Epoch 6, Loss: 0.6386, Accuracy: 0.9871
# best model updated
# Epoch 7, Loss: 0.6411, Accuracy: 0.9957
# Epoch 8, Loss: 0.6358, Accuracy: 0.9919
# best model updated
# Epoch 9, Loss: 0.6377, Accuracy: 0.9976
# Epoch 10, Loss: 0.6366, Accuracy: 0.9785
# Epoch 11, Loss: 0.6374, Accuracy: 0.9949
# Epoch 12, Loss: 0.6389, Accuracy: 0.9938
# Epoch 13, Loss: 0.6372, Accuracy: 0.9936
# Epoch 14, Loss: 0.6369, Accuracy: 0.9962
# Epoch 15, Loss: 0.6440, Accuracy: 0.9914
# Epoch 16, Loss: 0.6378, Accuracy: 0.9911
# Epoch 17, Loss: 0.6414, Accuracy: 0.9952
# Epoch 18, Loss: 0.6412, Accuracy: 0.9952
# Best Epoch: 8, Best Valid Acc: 0.9975832438238453
# Valid Acc (with Epoch valid set) on Loaded Best Model: 0.9975832438238453
# Final Acc (with TEST set) on Loaded Best Model: 0.9957102001906578 (time: 0.005534369536120482)
#
# === case=4_1, backbone=resnet18 ===
# idx: 20, loss for current idx: 0.791493
# idx: 40, loss for current idx: 0.727543
# idx: 60, loss for current idx: 0.631518
# idx: 80, loss for current idx: 0.627256
# idx: 100, loss for current idx: 0.653325
# idx: 120, loss for current idx: 0.656307
# idx: 140, loss for current idx: 0.719794
# idx: 160, loss for current idx: 0.655524
# idx: 180, loss for current idx: 0.659198
# idx: 200, loss for current idx: 0.628108
# idx: 220, loss for current idx: 0.655399
# idx: 240, loss for current idx: 0.643616
# idx: 260, loss for current idx: 0.643655
# idx: 280, loss for current idx: 0.701940
# idx: 300, loss for current idx: 0.697135
# idx: 320, loss for current idx: 0.628936
# idx: 340, loss for current idx: 0.659005
# idx: 360, loss for current idx: 0.626603
# idx: 380, loss for current idx: 0.632518
# idx: 400, loss for current idx: 0.708620
# idx: 420, loss for current idx: 0.689333
# idx: 440, loss for current idx: 0.627252
# idx: 460, loss for current idx: 0.628453
# idx: 480, loss for current idx: 0.633283
# idx: 500, loss for current idx: 0.656533
# idx: 520, loss for current idx: 0.657782
# best model updated
# Epoch 1, Loss: 0.6732, Accuracy: 0.9893
# Epoch 2, Loss: 0.6438, Accuracy: 0.9890
# best model updated
# Epoch 3, Loss: 0.6407, Accuracy: 0.9930
# Epoch 4, Loss: 0.6401, Accuracy: 0.9927
# best model updated
# Epoch 5, Loss: 0.6389, Accuracy: 0.9957
# Epoch 6, Loss: 0.6342, Accuracy: 0.9957
# Epoch 7, Loss: 0.6435, Accuracy: 0.9946
# Epoch 8, Loss: 0.6418, Accuracy: 0.9944
# Epoch 9, Loss: 0.6363, Accuracy: 0.9957
# best model updated
# Epoch 10, Loss: 0.6344, Accuracy: 0.9968
# best model updated
# Epoch 11, Loss: 0.6327, Accuracy: 0.9976
# Epoch 12, Loss: 0.6363, Accuracy: 0.9930
# Epoch 13, Loss: 0.6386, Accuracy: 0.9954
# Epoch 14, Loss: 0.6399, Accuracy: 0.9815
# Epoch 15, Loss: 0.6388, Accuracy: 0.9922
# Epoch 16, Loss: 0.6386, Accuracy: 0.9952
# Epoch 17, Loss: 0.6341, Accuracy: 0.9957
# Epoch 18, Loss: 0.6337, Accuracy: 0.9962
# Epoch 19, Loss: 0.6329, Accuracy: 0.9941
# Epoch 20, Loss: 0.6400, Accuracy: 0.9874
# Best Epoch: 10, Best Valid Acc: 0.9975832438238453
# Valid Acc (with Epoch valid set) on Loaded Best Model: 0.9975832438238453
# Final Acc (with TEST set) on Loaded Best Model: 0.996345726088338 (time: 0.004770999002938319)
#
# === case=4_1, backbone=resnet34 ===
# idx: 20, loss for current idx: 0.645599
# idx: 40, loss for current idx: 0.663647
# idx: 60, loss for current idx: 0.705637
# idx: 80, loss for current idx: 0.777634
# idx: 100, loss for current idx: 0.791238
# idx: 120, loss for current idx: 0.626714
# idx: 140, loss for current idx: 0.689952
# idx: 160, loss for current idx: 0.660495
# idx: 180, loss for current idx: 0.627158
# idx: 200, loss for current idx: 0.628045
# idx: 220, loss for current idx: 0.665938
# idx: 240, loss for current idx: 0.633714
# idx: 260, loss for current idx: 0.701532
# idx: 280, loss for current idx: 0.751474
# idx: 300, loss for current idx: 0.627687
# idx: 320, loss for current idx: 0.626565
# idx: 340, loss for current idx: 0.626815
# idx: 360, loss for current idx: 0.628919
# idx: 380, loss for current idx: 0.668795
# idx: 400, loss for current idx: 0.631557
# idx: 420, loss for current idx: 0.627982
# idx: 440, loss for current idx: 0.633632
# idx: 460, loss for current idx: 0.626582
# idx: 480, loss for current idx: 0.626839
# idx: 500, loss for current idx: 0.657845
# idx: 520, loss for current idx: 0.701193
# best model updated
# Epoch 1, Loss: 0.6715, Accuracy: 0.9890
# best model updated
# Epoch 2, Loss: 0.6432, Accuracy: 0.9914
# best model updated
# Epoch 3, Loss: 0.6426, Accuracy: 0.9949
# Epoch 4, Loss: 0.6380, Accuracy: 0.9707
# best model updated
# Epoch 5, Loss: 0.6429, Accuracy: 0.9960
# Epoch 6, Loss: 0.6338, Accuracy: 0.9952
# Epoch 7, Loss: 0.6337, Accuracy: 0.9930
# Epoch 8, Loss: 0.6379, Accuracy: 0.9941
# Epoch 9, Loss: 0.6368, Accuracy: 0.9930
# Epoch 10, Loss: 0.6315, Accuracy: 0.9930
# Epoch 11, Loss: 0.6335, Accuracy: 0.9960
# Epoch 12, Loss: 0.6346, Accuracy: 0.9944
# Epoch 13, Loss: 0.6403, Accuracy: 0.9957
# best model updated
# Epoch 14, Loss: 0.6335, Accuracy: 0.9965
# best model updated
# Epoch 15, Loss: 0.6352, Accuracy: 0.9970
# Epoch 16, Loss: 0.6339, Accuracy: 0.9970
# Epoch 17, Loss: 0.6371, Accuracy: 0.9946
# Epoch 18, Loss: 0.6346, Accuracy: 0.9941
# Epoch 19, Loss: 0.6361, Accuracy: 0.9970
# best model updated
# Epoch 20, Loss: 0.6310, Accuracy: 0.9973
# best model updated
# Epoch 21, Loss: 0.6330, Accuracy: 0.9979
# Epoch 22, Loss: 0.6352, Accuracy: 0.9962
# Epoch 23, Loss: 0.6325, Accuracy: 0.9962
# Epoch 24, Loss: 0.6319, Accuracy: 0.9976
# Epoch 25, Loss: 0.6359, Accuracy: 0.9973
# best model updated
# Epoch 26, Loss: 0.6313, Accuracy: 0.9981
# Epoch 27, Loss: 0.6305, Accuracy: 0.9973
# Epoch 28, Loss: 0.6330, Accuracy: 0.9965
# Epoch 29, Loss: 0.6293, Accuracy: 0.9960
# Epoch 30, Loss: 0.6319, Accuracy: 0.9979
# best model updated
# Epoch 31, Loss: 0.6313, Accuracy: 0.9987
# Epoch 32, Loss: 0.6308, Accuracy: 0.9973
# Epoch 33, Loss: 0.6294, Accuracy: 0.9957
# Epoch 34, Loss: 0.6309, Accuracy: 0.9970
# Epoch 35, Loss: 0.6296, Accuracy: 0.9979
# Epoch 36, Loss: 0.6338, Accuracy: 0.9952
# Epoch 37, Loss: 0.6295, Accuracy: 0.9984
# Epoch 38, Loss: 0.6322, Accuracy: 0.9979
# Epoch 39, Loss: 0.6324, Accuracy: 0.9968
# Epoch 40, Loss: 0.6296, Accuracy: 0.9957
# Best Epoch: 30, Best Valid Acc: 0.998657357679914
# Valid Acc (with Epoch valid set) on Loaded Best Model: 0.998657357679914
# Final Acc (with TEST set) on Loaded Best Model: 0.9990467111534795 (time: 0.008164675548823193)
#
# === case=4_1, backbone=resnet50 ===
# idx: 20, loss for current idx: 0.806524
# idx: 40, loss for current idx: 0.711480
# idx: 60, loss for current idx: 0.872585
# idx: 80, loss for current idx: 0.658062
# idx: 100, loss for current idx: 0.755859
# idx: 120, loss for current idx: 0.706766
# idx: 140, loss for current idx: 0.632963
# idx: 160, loss for current idx: 0.627013
# idx: 180, loss for current idx: 0.630804
# idx: 200, loss for current idx: 0.658686
# idx: 220, loss for current idx: 0.696783
# idx: 240, loss for current idx: 0.637107
# idx: 260, loss for current idx: 0.675900
# idx: 280, loss for current idx: 0.739520
# idx: 300, loss for current idx: 0.627453
# idx: 320, loss for current idx: 0.677310
# idx: 340, loss for current idx: 0.629416
# idx: 360, loss for current idx: 0.650519
# idx: 380, loss for current idx: 0.635935
# idx: 400, loss for current idx: 0.628820
# idx: 420, loss for current idx: 0.675218
# idx: 440, loss for current idx: 0.626700
# idx: 460, loss for current idx: 0.627134
# idx: 480, loss for current idx: 0.626780
# idx: 500, loss for current idx: 0.638178
# idx: 520, loss for current idx: 0.626657
# best model updated
# Epoch 1, Loss: 0.6761, Accuracy: 0.9906
# best model updated
# Epoch 2, Loss: 0.6454, Accuracy: 0.9930
# best model updated
# Epoch 3, Loss: 0.6420, Accuracy: 0.9946
# Epoch 4, Loss: 0.6352, Accuracy: 0.9890
# best model updated
# Epoch 5, Loss: 0.6349, Accuracy: 0.9957
# best model updated
# Epoch 6, Loss: 0.6343, Accuracy: 0.9960
# best model updated
# Epoch 7, Loss: 0.6347, Accuracy: 0.9962
# Epoch 8, Loss: 0.6370, Accuracy: 0.9949
# Epoch 9, Loss: 0.6346, Accuracy: 0.9944
# Epoch 10, Loss: 0.6343, Accuracy: 0.9936
# best model updated
# Epoch 11, Loss: 0.6331, Accuracy: 0.9976
# Epoch 12, Loss: 0.6417, Accuracy: 0.9930
# Epoch 13, Loss: 0.6387, Accuracy: 0.9976
# best model updated
# Epoch 14, Loss: 0.6338, Accuracy: 0.9979
# Epoch 15, Loss: 0.6330, Accuracy: 0.9979
# Epoch 16, Loss: 0.6317, Accuracy: 0.9957
# Epoch 17, Loss: 0.6414, Accuracy: 0.9957
# Epoch 18, Loss: 0.6332, Accuracy: 0.9976
# Epoch 19, Loss: 0.6346, Accuracy: 0.9946
# Epoch 20, Loss: 0.6353, Accuracy: 0.9922
# Epoch 21, Loss: 0.6332, Accuracy: 0.9973
# Epoch 22, Loss: 0.6344, Accuracy: 0.9979
# Epoch 23, Loss: 0.6374, Accuracy: 0.9893
# Best Epoch: 13, Best Valid Acc: 0.9978517722878625
# Valid Acc (with Epoch valid set) on Loaded Best Model: 0.9978517722878625
# Final Acc (with TEST set) on Loaded Best Model: 0.9974578964092787 (time: 0.011122657795145053)
#
# === case=4_2, backbone=resnet18 ===
# idx: 20, loss for current idx: 0.823181
# idx: 40, loss for current idx: 0.750878
# idx: 60, loss for current idx: 0.693863
# idx: 80, loss for current idx: 0.662041
# idx: 100, loss for current idx: 0.668336
# idx: 120, loss for current idx: 0.627991
# idx: 140, loss for current idx: 0.721090
# idx: 160, loss for current idx: 0.653685
# idx: 180, loss for current idx: 0.690359
# idx: 200, loss for current idx: 0.667245
# idx: 220, loss for current idx: 0.638369
# idx: 240, loss for current idx: 0.636264
# idx: 260, loss for current idx: 0.676650
# idx: 280, loss for current idx: 0.626870
# idx: 300, loss for current idx: 0.730735
# idx: 320, loss for current idx: 0.666018
# idx: 340, loss for current idx: 0.626534
# idx: 360, loss for current idx: 0.627057
# idx: 380, loss for current idx: 0.633718
# idx: 400, loss for current idx: 0.626533
# idx: 420, loss for current idx: 0.685761
# idx: 440, loss for current idx: 0.674828
# idx: 460, loss for current idx: 0.626529
# idx: 480, loss for current idx: 0.630798
# idx: 500, loss for current idx: 0.626542
# idx: 520, loss for current idx: 0.671926
# best model updated
# Epoch 1, Loss: 0.6765, Accuracy: 0.9863
# best model updated
# Epoch 2, Loss: 0.6489, Accuracy: 0.9898
# best model updated
# Epoch 3, Loss: 0.6427, Accuracy: 0.9952
# Epoch 4, Loss: 0.6449, Accuracy: 0.9933
# Epoch 5, Loss: 0.6415, Accuracy: 0.9903
# Epoch 6, Loss: 0.6407, Accuracy: 0.9952
# Epoch 7, Loss: 0.6414, Accuracy: 0.9895
# Epoch 8, Loss: 0.6409, Accuracy: 0.9952
# Epoch 9, Loss: 0.6372, Accuracy: 0.9914
# best model updated
# Epoch 10, Loss: 0.6386, Accuracy: 0.9954
# Epoch 11, Loss: 0.6378, Accuracy: 0.9930
# Epoch 12, Loss: 0.6482, Accuracy: 0.9919
# Epoch 13, Loss: 0.6365, Accuracy: 0.9949
# Epoch 14, Loss: 0.6411, Accuracy: 0.9941
# Epoch 15, Loss: 0.6363, Accuracy: 0.9941
# Epoch 16, Loss: 0.6413, Accuracy: 0.9925
# Epoch 17, Loss: 0.6432, Accuracy: 0.9933
# Epoch 18, Loss: 0.6403, Accuracy: 0.9922
# Epoch 19, Loss: 0.6405, Accuracy: 0.9944
# Best Epoch: 9, Best Valid Acc: 0.9954350161117078
# Valid Acc (with Epoch valid set) on Loaded Best Model: 0.9954350161117078
# Final Acc (with TEST set) on Loaded Best Model: 0.9969812519860184 (time: 0.005976672124381017)
#
# === case=4_2, backbone=resnet34 ===
# idx: 20, loss for current idx: 0.839095
# idx: 40, loss for current idx: 0.718866
# idx: 60, loss for current idx: 0.674903
# idx: 80, loss for current idx: 0.714726
# idx: 100, loss for current idx: 0.627621
# idx: 120, loss for current idx: 0.654921
# idx: 140, loss for current idx: 0.688949
# idx: 160, loss for current idx: 0.629772
# idx: 180, loss for current idx: 0.722017
# idx: 200, loss for current idx: 0.627003
# idx: 220, loss for current idx: 0.632498
# idx: 240, loss for current idx: 0.658135
# idx: 260, loss for current idx: 0.689733
# idx: 280, loss for current idx: 0.626540
# idx: 300, loss for current idx: 0.743196
# idx: 320, loss for current idx: 0.654854
# idx: 340, loss for current idx: 0.684195
# idx: 360, loss for current idx: 0.670343
# idx: 380, loss for current idx: 0.631595
# idx: 400, loss for current idx: 0.627348
# idx: 420, loss for current idx: 0.626842
# idx: 440, loss for current idx: 0.667197
# idx: 460, loss for current idx: 0.626669
# idx: 480, loss for current idx: 0.658217
# idx: 500, loss for current idx: 0.681861
# idx: 520, loss for current idx: 0.626560
# best model updated
# Epoch 1, Loss: 0.6738, Accuracy: 0.9847
# best model updated
# Epoch 2, Loss: 0.6537, Accuracy: 0.9871
# best model updated
# Epoch 3, Loss: 0.6449, Accuracy: 0.9917
# best model updated
# Epoch 4, Loss: 0.6441, Accuracy: 0.9925
# best model updated
# Epoch 5, Loss: 0.6414, Accuracy: 0.9936
# Epoch 6, Loss: 0.6427, Accuracy: 0.9863
# best model updated
# Epoch 7, Loss: 0.6415, Accuracy: 0.9944
# Epoch 8, Loss: 0.6431, Accuracy: 0.9885
# Epoch 9, Loss: 0.6389, Accuracy: 0.9925
# best model updated
# Epoch 10, Loss: 0.6404, Accuracy: 0.9946
# best model updated
# Epoch 11, Loss: 0.6378, Accuracy: 0.9970
# Epoch 12, Loss: 0.6342, Accuracy: 0.9949
# Epoch 13, Loss: 0.6361, Accuracy: 0.9925
# Epoch 14, Loss: 0.6357, Accuracy: 0.9949
# Epoch 15, Loss: 0.6375, Accuracy: 0.9777
# Epoch 16, Loss: 0.6384, Accuracy: 0.9933
# Epoch 17, Loss: 0.6346, Accuracy: 0.9941
# Epoch 18, Loss: 0.6338, Accuracy: 0.9957
# Epoch 19, Loss: 0.6349, Accuracy: 0.9970
# Epoch 20, Loss: 0.6349, Accuracy: 0.9949
# Best Epoch: 10, Best Valid Acc: 0.9970461868958109
# Valid Acc (with Epoch valid set) on Loaded Best Model: 0.9970461868958109
# Final Acc (with TEST set) on Loaded Best Model: 0.9966634890371783 (time: 0.008909569846259223)
#
# === case=4_2, backbone=resnet50 ===
# idx: 20, loss for current idx: 0.922841
# idx: 40, loss for current idx: 0.722961
# idx: 60, loss for current idx: 0.720091
# idx: 80, loss for current idx: 0.871026
# idx: 100, loss for current idx: 0.804716
# idx: 120, loss for current idx: 0.665810
# idx: 140, loss for current idx: 0.716159
# idx: 160, loss for current idx: 0.658514
# idx: 180, loss for current idx: 0.671225
# idx: 200, loss for current idx: 0.694818
# idx: 220, loss for current idx: 0.657886
# idx: 240, loss for current idx: 0.690816
# idx: 260, loss for current idx: 0.689018
# idx: 280, loss for current idx: 0.659836
# idx: 300, loss for current idx: 0.626527
# idx: 320, loss for current idx: 0.629620
# idx: 340, loss for current idx: 0.626529
# idx: 360, loss for current idx: 0.714899
# idx: 380, loss for current idx: 0.757086
# idx: 400, loss for current idx: 0.659619
# idx: 420, loss for current idx: 0.633783
# idx: 440, loss for current idx: 0.626562
# idx: 460, loss for current idx: 0.657655
# idx: 480, loss for current idx: 0.657660
# idx: 500, loss for current idx: 0.689031
# idx: 520, loss for current idx: 0.689262
# best model updated
# Epoch 1, Loss: 0.6928, Accuracy: 0.9866
# best model updated
# Epoch 2, Loss: 0.6547, Accuracy: 0.9882
# best model updated
# Epoch 3, Loss: 0.6437, Accuracy: 0.9933
# best model updated
# Epoch 4, Loss: 0.6464, Accuracy: 0.9936
# Epoch 5, Loss: 0.6454, Accuracy: 0.9882
# Epoch 6, Loss: 0.6468, Accuracy: 0.9852
# Epoch 7, Loss: 0.6441, Accuracy: 0.9903
# best model updated
# Epoch 8, Loss: 0.6437, Accuracy: 0.9952
# best model updated
# Epoch 9, Loss: 0.6401, Accuracy: 0.9954
# Epoch 10, Loss: 0.6402, Accuracy: 0.9936
# Epoch 11, Loss: 0.6446, Accuracy: 0.9949
# Epoch 12, Loss: 0.6453, Accuracy: 0.9938
# Epoch 13, Loss: 0.6421, Accuracy: 0.9917
# Epoch 14, Loss: 0.6425, Accuracy: 0.9917
# Epoch 15, Loss: 0.6409, Accuracy: 0.9933
# Epoch 16, Loss: 0.6485, Accuracy: 0.9860
# Epoch 17, Loss: 0.6539, Accuracy: 0.9927
# Epoch 18, Loss: 0.6493, Accuracy: 0.9839
# Best Epoch: 8, Best Valid Acc: 0.9954350161117078
# Valid Acc (with Epoch valid set) on Loaded Best Model: 0.9954350161117078
# Final Acc (with TEST set) on Loaded Best Model: 0.9950746742929775 (time: 0.011504122705170603)

# %%
result_df = pd.DataFrame(result_dict)
result_df
# Out:
#     backbone case  accuracy  inference_time
# 0   resnet18    1  0.994280        0.004741
# 1   resnet34    1  0.995869        0.008254
# 2   resnet50    1  0.996187        0.011402
# 3   resnet18    2  0.993963        0.002469
# 4   resnet34    2  0.994916        0.004268
# 5   resnet50    2  0.993963        0.005454
# 6   resnet18    3  0.996505        0.002469
# 7   resnet34    3  0.995869        0.004139
# 8   resnet50    3  0.995710        0.005534
# 9   resnet18  4_1  0.996346        0.004771
# 10  resnet34  4_1  0.999047        0.008165
# 11  resnet50  4_1  0.997458        0.011123
# 12  resnet18  4_2  0.996981        0.005977
# 13  resnet34  4_2  0.996663        0.008910
# 14  resnet50  4_2  0.995075        0.011504

# %%
result_df.to_csv('result_experiment_1.csv')
