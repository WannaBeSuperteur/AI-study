# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms

import plotly.graph_objects as go

import random
import pandas as pd
import numpy as np

# !pip install torchinfo
from torchinfo import summary
# Out:
# Collecting torchinfo
#   Downloading torchinfo-1.8.0-py3-none-any.whl.metadata (21 kB)
# Downloading torchinfo-1.8.0-py3-none-any.whl (23 kB)
# Installing collected packages: torchinfo
# Successfully installed torchinfo-1.8.0

# %%
# 경고 미 표시

import warnings
warnings.filterwarnings('ignore')

# %%
# Random Seed 고정 (학습 반복 시행 시에도 동일한 결과가 나오도록)

seed = 20251003

random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)
torch.cuda.manual_seed_all(seed)

# %%
# 데이터셋 로딩

transform = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.5,), (0.5,))])

train_dataset = torchvision.datasets.MNIST(root='./data',
                                           train=True,
                                           transform=transform,
                                           download=True)

test_dataset = torchvision.datasets.MNIST(root='./data',
                                          train=False,
                                          transform=transform,
                                          download=True)
# Out:
# 100%|██████████| 9.91M/9.91M [00:00<00:00, 65.7MB/s]
# 100%|██████████| 28.9k/28.9k [00:00<00:00, 1.54MB/s]
# 100%|██████████| 1.65M/1.65M [00:00<00:00, 14.9MB/s]
# 100%|██████████| 4.54k/4.54k [00:00<00:00, 8.62MB/s]

# %% [markdown]
# **1. 데이터셋 분석**

# %%
# 데이터셋 로딩

from torch.utils.data import DataLoader

BATCH_SIZE = 32

train_loader = DataLoader(train_dataset,
                          batch_size=BATCH_SIZE,
                          shuffle=True)

test_loader = DataLoader(test_dataset,
                         batch_size=BATCH_SIZE,
                         shuffle=False)

# %%
# 클래스 불균형 분석

# 학습 데이터
train_labels = torch.tensor(train_dataset.targets)
train_class_counts = torch.bincount(train_labels)
print(f'train data : {train_class_counts}')

# 테스트 데이터
test_labels = torch.tensor(test_dataset.targets)
test_class_counts = torch.bincount(test_labels)
print(f'test  data : {test_class_counts}')

NUM_CLASSES = len(train_class_counts)
# Out:
# train data : tensor([5923, 6742, 5958, 6131, 5842, 5421, 5918, 6265, 5851, 5949])
# test  data : tensor([ 980, 1135, 1032, 1010,  982,  892,  958, 1028,  974, 1009])

# %%
# 클래스 불균형 분석 (percentage)

train_class_percentage = np.array(train_class_counts) * 100.0 / sum(train_class_counts)

train_y_distrib = pd.DataFrame({'class': list(range(NUM_CLASSES)),
                                'count': train_class_counts,
                                'percentage (%)': train_class_percentage})

train_y_distrib
# Out:
#    class  count  percentage (%)
# 0      0   5923        9.871667
# 1      1   6742       11.236667
# 2      2   5958        9.930000
# 3      3   6131       10.218333
# 4      4   5842        9.736667
# 5      5   5421        9.035000
# 6      6   5918        9.863333
# 7      7   6265       10.441667
# 8      8   5851        9.751667
# 9      9   5949        9.915000

# %%
test_class_percentage = np.array(test_class_counts) * 100.0 / sum(test_class_counts)

test_y_distrib = pd.DataFrame({'class': list(range(NUM_CLASSES)),
                               'count': test_class_counts,
                               'percentage (%)': test_class_percentage})

test_y_distrib
# Out:
#    class  count  percentage (%)
# 0      0    980            9.80
# 1      1   1135           11.35
# 2      2   1032           10.32
# 3      3   1010           10.10
# 4      4    982            9.82
# 5      5    892            8.92
# 6      6    958            9.58
# 7      7   1028           10.28
# 8      8    974            9.74
# 9      9   1009           10.09

# %% [markdown]
# **2. 0, 3, 8 숫자 데이터만 추출**

# %%
from torch.utils.data import Subset

# train dataset
train_targets = torch.tensor(train_dataset.targets)
train_mask = (train_targets == 0) | (train_targets == 3) | (train_targets == 8)
train_indices = torch.where(train_mask)[0]

train_subset = Subset(train_dataset, train_indices)

# test dataset
test_targets = torch.tensor(test_dataset.targets)
test_mask = (test_targets == 0) | (test_targets == 3) | (test_targets == 8)
test_indices = torch.where(test_mask)[0]

test_subset = Subset(test_dataset, test_indices)

# %%
# train, test Data Loader 갱신

train_subset_loader = DataLoader(train_subset,
                                 batch_size=BATCH_SIZE,
                                 shuffle=True)

test_subset_loader = DataLoader(test_subset,
                                batch_size=BATCH_SIZE,
                                shuffle=False)

# %%
# train, test Data Loader 의 class 가 0, 3, 8 뿐인지 확인

train_subset_labels = train_subset.dataset.targets[train_subset.indices]
train_subset_class_counts = torch.bincount(train_subset_labels)
print(f'train data (subset) [0,3,8] : {train_subset_class_counts}')

test_subset_labels = test_subset.dataset.targets[test_subset.indices]
test_subset_class_counts = torch.bincount(test_subset_labels)
print(f'test  data (subset) [0,3,8] : {test_subset_class_counts}')
# Out:
# train data (subset) [0,3,8] : tensor([5923,    0,    0, 6131,    0,    0,    0,    0, 5851])
# test  data (subset) [0,3,8] : tensor([ 980,    0,    0, 1010,    0,    0,    0,    0,  974])

# %% [markdown]
# **3. CNN 모델 정의**

# %%
# 1. Non-Shared backbone & Shared head

class CNN_CASE_1(nn.Module):
    def __init__(self, backbone_1, backbone_2):
        super(CNN_CASE_1, self).__init__()

        self.backbone_1 = backbone_1
        self.backbone_2 = backbone_2
        self.final_linear = nn.Linear(2000, 3)
        self.final_softmax = nn.Softmax(dim=1)

    def forward(self, x):
        x1 = self.backbone_1(x)
        x2 = self.backbone_2(x)
        x = torch.concatenate([x1, x2], dim=1)

        x = self.final_linear(x)
        x = self.final_softmax(x)

        return x

# %%
# 2. Shared backbone & Shared head

class CNN_CASE_2(nn.Module):
    def __init__(self, backbone):
        super(CNN_CASE_2, self).__init__()

        self.backbone = backbone
        self.final_linear = nn.Linear(1000, 3)
        self.final_softmax = nn.Softmax(dim=1)

    def forward(self, x):
        x = self.backbone(x)
        x = self.final_linear(x)
        x = self.final_softmax(x)

        return x

# %%
# 3. Shared backbone & Non-Shared head

class CNN_CASE_3(nn.Module):
    def __init__(self, backbone):
        super(CNN_CASE_3, self).__init__()

        self.backbone = backbone
        self.final_linear_1 = nn.Linear(1000, 2)
        self.final_linear_2 = nn.Linear(1000, 2)
        self.final_softmax = nn.Softmax(dim=1)

    def forward(self, x):
        x = self.backbone(x)
        x1 = self.final_linear_1(x)
        x2 = self.final_linear_2(x)
        x1 = self.final_softmax(x1)
        x2 = self.final_softmax(x2)

        return x1, x2

# %%
# 4. Non-Shared backbone & Non-Shared head (4-1)

class CNN_CASE_4_1(nn.Module):
    def __init__(self, backbone_1, backbone_2):
        super(CNN_CASE_4_1, self).__init__()

        self.backbone_1 = backbone_1
        self.backbone_2 = backbone_2
        self.final_linear_1 = nn.Linear(2000, 2)
        self.final_linear_2 = nn.Linear(2000, 2)
        self.final_softmax = nn.Softmax(dim=1)

    def forward(self, x):
        x11 = self.backbone_1(x)
        x12 = self.backbone_2(x)
        x = torch.concatenate([x11, x12], dim=1)

        x21 = self.final_linear_1(x)
        x22 = self.final_linear_2(x)
        x21 = self.final_softmax(x21)
        x22 = self.final_softmax(x22)

        return x21, x22

# %%
# 5. Non-Shared backbone & Non-Shared head (4-2)

class CNN_CASE_4_2(nn.Module):
    def __init__(self, backbone_1, backbone_2):
        super(CNN_CASE_4_2, self).__init__()

        self.backbone_1 = backbone_1
        self.backbone_2 = backbone_2
        self.final_linear_1 = nn.Linear(1000, 2)
        self.final_linear_2 = nn.Linear(1000, 2)
        self.final_softmax = nn.Softmax(dim=1)

    def forward(self, x):
        x11 = self.backbone_1(x)
        x12 = self.backbone_2(x)
        x21 = self.final_linear_1(x11)
        x22 = self.final_linear_2(x12)
        x21 = self.final_softmax(x21)
        x22 = self.final_softmax(x22)

        return x21, x22

# %% [markdown]
# **4. backbone model 로딩**

# %%
import torchvision.models as models

def define_model(backbone_name, case_name, device):

    # model count
    if case_name in ['1', '4_1', '4_2']:
        model_count = 2
    else:
        model_count = 1

    # load pre-trained backbone model
    pretrained_models = []

    for _ in range(model_count):
        if backbone_name == 'resnet18':
            pretrained_model = models.resnet18(pretrained=True)

        elif backbone_name == 'resnet34':
            pretrained_model = models.resnet34(pretrained=True)

        else:  # resnet50
            pretrained_model = models.resnet50(pretrained=True)

        pretrained_model.conv1 = torch.nn.Conv2d(1, 64,
                                                 kernel_size=(7, 7),
                                                 stride=(2, 2),
                                                 padding=(3, 3),
                                                 bias=False)
        pretrained_models.append(pretrained_model)

    # define full model
    if case_name == '1':
        model = CNN_CASE_1(backbone_1=pretrained_models[0],
                           backbone_2=pretrained_models[1])

    elif case_name == '2':
        model = CNN_CASE_2(backbone=pretrained_models[0])

    elif case_name == '3':
        model = CNN_CASE_3(backbone=pretrained_models[0])

    elif case_name == '4_1':
        model = CNN_CASE_4_1(backbone_1=pretrained_models[0],
                             backbone_2=pretrained_models[1])

    elif case_name == '4_2':
        model = CNN_CASE_4_2(backbone_1=pretrained_models[0],
                             backbone_2=pretrained_models[1])

    # device & optimizer & scheduler setting
    model.to(device)
    model.optimizer = torch.optim.AdamW(model.parameters(), lr=0.0001)
    model.scheduler = torch.optim.lr_scheduler.ExponentialLR(optimizer=model.optimizer,
                                                             gamma=0.95)

    return model

# %% [markdown]
# **5. 모델 구조 출력**

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
input_size=(BATCH_SIZE, 1, 28, 28)

# %%
temp_backbone_name = 'resnet18'

# %%
# 1. Non-Shared backbone & Shared head

model_case_1 = define_model(temp_backbone_name, case_name='1', device=device)
print(summary(model=model_case_1, input_size=input_size))
# Out:
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100%|██████████| 44.7M/44.7M [00:00<00:00, 129MB/s]
# ===============================================================================================
# Layer (type:depth-idx)                        Output Shape              Param #
# ===============================================================================================
# CNN_CASE_1                                    [32, 3]                   --
# ├─ResNet: 1-1                                 [32, 1000]                --
# │    └─Conv2d: 2-1                            [32, 64, 14, 14]          3,136
# │    └─BatchNorm2d: 2-2                       [32, 64, 14, 14]          128
# │    └─ReLU: 2-3                              [32, 64, 14, 14]          --
# │    └─MaxPool2d: 2-4                         [32, 64, 7, 7]            --
# │    └─Sequential: 2-5                        [32, 64, 7, 7]            --
# │    │    └─BasicBlock: 3-1                   [32, 64, 7, 7]            73,984
# │    │    └─BasicBlock: 3-2                   [32, 64, 7, 7]            73,984
# │    └─Sequential: 2-6                        [32, 128, 4, 4]           --
# │    │    └─BasicBlock: 3-3                   [32, 128, 4, 4]           230,144
# │    │    └─BasicBlock: 3-4                   [32, 128, 4, 4]           295,424
# │    └─Sequential: 2-7                        [32, 256, 2, 2]           --
# │    │    └─BasicBlock: 3-5                   [32, 256, 2, 2]           919,040
# │    │    └─BasicBlock: 3-6                   [32, 256, 2, 2]           1,180,672
# │    └─Sequential: 2-8                        [32, 512, 1, 1]           --
# │    │    └─BasicBlock: 3-7                   [32, 512, 1, 1]           3,673,088
# │    │    └─BasicBlock: 3-8                   [32, 512, 1, 1]           4,720,640
# │    └─AdaptiveAvgPool2d: 2-9                 [32, 512, 1, 1]           --
# │    └─Linear: 2-10                           [32, 1000]                513,000
# ├─ResNet: 1-2                                 [32, 1000]                --
# │    └─Conv2d: 2-11                           [32, 64, 14, 14]          3,136
# │    └─BatchNorm2d: 2-12                      [32, 64, 14, 14]          128
# │    └─ReLU: 2-13                             [32, 64, 14, 14]          --
# │    └─MaxPool2d: 2-14                        [32, 64, 7, 7]            --
# │    └─Sequential: 2-15                       [32, 64, 7, 7]            --
# │    │    └─BasicBlock: 3-9                   [32, 64, 7, 7]            73,984
# │    │    └─BasicBlock: 3-10                  [32, 64, 7, 7]            73,984
# │    └─Sequential: 2-16                       [32, 128, 4, 4]           --
# │    │    └─BasicBlock: 3-11                  [32, 128, 4, 4]           230,144
# │    │    └─BasicBlock: 3-12                  [32, 128, 4, 4]           295,424
# │    └─Sequential: 2-17                       [32, 256, 2, 2]           --
# │    │    └─BasicBlock: 3-13                  [32, 256, 2, 2]           919,040
# │    │    └─BasicBlock: 3-14                  [32, 256, 2, 2]           1,180,672
# │    └─Sequential: 2-18                       [32, 512, 1, 1]           --
# │    │    └─BasicBlock: 3-15                  [32, 512, 1, 1]           3,673,088
# │    │    └─BasicBlock: 3-16                  [32, 512, 1, 1]           4,720,640
# │    └─AdaptiveAvgPool2d: 2-19                [32, 512, 1, 1]           --
# │    └─Linear: 2-20                           [32, 1000]                513,000
# ├─Linear: 1-3                                 [32, 3]                   6,003
# ├─Softmax: 1-4                                [32, 3]                   --
# ===============================================================================================
# Total params: 23,372,483
# Trainable params: 23,372,483
# Non-trainable params: 0
# Total mult-adds (Units.GIGABYTES): 2.15
# ===============================================================================================
# Input size (MB): 0.10
# Forward/backward pass size (MB): 44.55
# Params size (MB): 93.49
# Estimated Total Size (MB): 138.14
# ===============================================================================================

# %%
# 2. Shared backbone & Shared head

model_case_2 = define_model(temp_backbone_name, case_name='2', device=device)
print(summary(model=model_case_2, input_size=input_size))
# Out:
# ===============================================================================================
# Layer (type:depth-idx)                        Output Shape              Param #
# ===============================================================================================
# CNN_CASE_2                                    [32, 3]                   --
# ├─ResNet: 1-1                                 [32, 1000]                --
# │    └─Conv2d: 2-1                            [32, 64, 14, 14]          3,136
# │    └─BatchNorm2d: 2-2                       [32, 64, 14, 14]          128
# │    └─ReLU: 2-3                              [32, 64, 14, 14]          --
# │    └─MaxPool2d: 2-4                         [32, 64, 7, 7]            --
# │    └─Sequential: 2-5                        [32, 64, 7, 7]            --
# │    │    └─BasicBlock: 3-1                   [32, 64, 7, 7]            73,984
# │    │    └─BasicBlock: 3-2                   [32, 64, 7, 7]            73,984
# │    └─Sequential: 2-6                        [32, 128, 4, 4]           --
# │    │    └─BasicBlock: 3-3                   [32, 128, 4, 4]           230,144
# │    │    └─BasicBlock: 3-4                   [32, 128, 4, 4]           295,424
# │    └─Sequential: 2-7                        [32, 256, 2, 2]           --
# │    │    └─BasicBlock: 3-5                   [32, 256, 2, 2]           919,040
# │    │    └─BasicBlock: 3-6                   [32, 256, 2, 2]           1,180,672
# │    └─Sequential: 2-8                        [32, 512, 1, 1]           --
# │    │    └─BasicBlock: 3-7                   [32, 512, 1, 1]           3,673,088
# │    │    └─BasicBlock: 3-8                   [32, 512, 1, 1]           4,720,640
# │    └─AdaptiveAvgPool2d: 2-9                 [32, 512, 1, 1]           --
# │    └─Linear: 2-10                           [32, 1000]                513,000
# ├─Linear: 1-2                                 [32, 3]                   3,003
# ├─Softmax: 1-3                                [32, 3]                   --
# ===============================================================================================
# Total params: 11,686,243
# Trainable params: 11,686,243
# Non-trainable params: 0
# Total mult-adds (Units.GIGABYTES): 1.07
# ===============================================================================================
# Input size (MB): 0.10
# Forward/backward pass size (MB): 22.28
# Params size (MB): 46.74
# Estimated Total Size (MB): 69.12
# ===============================================================================================

# %%
# 3. Shared backbone & Non-Shared head

model_case_3 = define_model(temp_backbone_name, case_name='3', device=device)
print(summary(model=model_case_3, input_size=input_size))
# Out:
# ===============================================================================================
# Layer (type:depth-idx)                        Output Shape              Param #
# ===============================================================================================
# CNN_CASE_3                                    [32, 2]                   --
# ├─ResNet: 1-1                                 [32, 1000]                --
# │    └─Conv2d: 2-1                            [32, 64, 14, 14]          3,136
# │    └─BatchNorm2d: 2-2                       [32, 64, 14, 14]          128
# │    └─ReLU: 2-3                              [32, 64, 14, 14]          --
# │    └─MaxPool2d: 2-4                         [32, 64, 7, 7]            --
# │    └─Sequential: 2-5                        [32, 64, 7, 7]            --
# │    │    └─BasicBlock: 3-1                   [32, 64, 7, 7]            73,984
# │    │    └─BasicBlock: 3-2                   [32, 64, 7, 7]            73,984
# │    └─Sequential: 2-6                        [32, 128, 4, 4]           --
# │    │    └─BasicBlock: 3-3                   [32, 128, 4, 4]           230,144
# │    │    └─BasicBlock: 3-4                   [32, 128, 4, 4]           295,424
# │    └─Sequential: 2-7                        [32, 256, 2, 2]           --
# │    │    └─BasicBlock: 3-5                   [32, 256, 2, 2]           919,040
# │    │    └─BasicBlock: 3-6                   [32, 256, 2, 2]           1,180,672
# │    └─Sequential: 2-8                        [32, 512, 1, 1]           --
# │    │    └─BasicBlock: 3-7                   [32, 512, 1, 1]           3,673,088
# │    │    └─BasicBlock: 3-8                   [32, 512, 1, 1]           4,720,640
# │    └─AdaptiveAvgPool2d: 2-9                 [32, 512, 1, 1]           --
# │    └─Linear: 2-10                           [32, 1000]                513,000
# ├─Linear: 1-2                                 [32, 2]                   2,002
# ├─Linear: 1-3                                 [32, 2]                   2,002
# ├─Softmax: 1-4                                [32, 2]                   --
# ├─Softmax: 1-5                                [32, 2]                   --
# ===============================================================================================
# Total params: 11,687,244
# Trainable params: 11,687,244
# Non-trainable params: 0
# Total mult-adds (Units.GIGABYTES): 1.07
# ===============================================================================================
# Input size (MB): 0.10
# Forward/backward pass size (MB): 22.28
# Params size (MB): 46.75
# Estimated Total Size (MB): 69.13
# ===============================================================================================

# %%
# 4. Non-Shared backbone & Non-Shared head (4-1)

model_case_4_1 = define_model(temp_backbone_name, case_name='4_1', device=device)
print(summary(model=model_case_4_1, input_size=input_size))
# Out:
# ===============================================================================================
# Layer (type:depth-idx)                        Output Shape              Param #
# ===============================================================================================
# CNN_CASE_4_1                                  [32, 2]                   --
# ├─ResNet: 1-1                                 [32, 1000]                --
# │    └─Conv2d: 2-1                            [32, 64, 14, 14]          3,136
# │    └─BatchNorm2d: 2-2                       [32, 64, 14, 14]          128
# │    └─ReLU: 2-3                              [32, 64, 14, 14]          --
# │    └─MaxPool2d: 2-4                         [32, 64, 7, 7]            --
# │    └─Sequential: 2-5                        [32, 64, 7, 7]            --
# │    │    └─BasicBlock: 3-1                   [32, 64, 7, 7]            73,984
# │    │    └─BasicBlock: 3-2                   [32, 64, 7, 7]            73,984
# │    └─Sequential: 2-6                        [32, 128, 4, 4]           --
# │    │    └─BasicBlock: 3-3                   [32, 128, 4, 4]           230,144
# │    │    └─BasicBlock: 3-4                   [32, 128, 4, 4]           295,424
# │    └─Sequential: 2-7                        [32, 256, 2, 2]           --
# │    │    └─BasicBlock: 3-5                   [32, 256, 2, 2]           919,040
# │    │    └─BasicBlock: 3-6                   [32, 256, 2, 2]           1,180,672
# │    └─Sequential: 2-8                        [32, 512, 1, 1]           --
# │    │    └─BasicBlock: 3-7                   [32, 512, 1, 1]           3,673,088
# │    │    └─BasicBlock: 3-8                   [32, 512, 1, 1]           4,720,640
# │    └─AdaptiveAvgPool2d: 2-9                 [32, 512, 1, 1]           --
# │    └─Linear: 2-10                           [32, 1000]                513,000
# ├─ResNet: 1-2                                 [32, 1000]                --
# │    └─Conv2d: 2-11                           [32, 64, 14, 14]          3,136
# │    └─BatchNorm2d: 2-12                      [32, 64, 14, 14]          128
# │    └─ReLU: 2-13                             [32, 64, 14, 14]          --
# │    └─MaxPool2d: 2-14                        [32, 64, 7, 7]            --
# │    └─Sequential: 2-15                       [32, 64, 7, 7]            --
# │    │    └─BasicBlock: 3-9                   [32, 64, 7, 7]            73,984
# │    │    └─BasicBlock: 3-10                  [32, 64, 7, 7]            73,984
# │    └─Sequential: 2-16                       [32, 128, 4, 4]           --
# │    │    └─BasicBlock: 3-11                  [32, 128, 4, 4]           230,144
# │    │    └─BasicBlock: 3-12                  [32, 128, 4, 4]           295,424
# │    └─Sequential: 2-17                       [32, 256, 2, 2]           --
# │    │    └─BasicBlock: 3-13                  [32, 256, 2, 2]           919,040
# │    │    └─BasicBlock: 3-14                  [32, 256, 2, 2]           1,180,672
# │    └─Sequential: 2-18                       [32, 512, 1, 1]           --
# │    │    └─BasicBlock: 3-15                  [32, 512, 1, 1]           3,673,088
# │    │    └─BasicBlock: 3-16                  [32, 512, 1, 1]           4,720,640
# │    └─AdaptiveAvgPool2d: 2-19                [32, 512, 1, 1]           --
# │    └─Linear: 2-20                           [32, 1000]                513,000
# ├─Linear: 1-3                                 [32, 2]                   4,002
# ├─Linear: 1-4                                 [32, 2]                   4,002
# ├─Softmax: 1-5                                [32, 2]                   --
# ├─Softmax: 1-6                                [32, 2]                   --
# ===============================================================================================
# Total params: 23,374,484
# Trainable params: 23,374,484
# Non-trainable params: 0
# Total mult-adds (Units.GIGABYTES): 2.15
# ===============================================================================================
# Input size (MB): 0.10
# Forward/backward pass size (MB): 44.55
# Params size (MB): 93.50
# Estimated Total Size (MB): 138.15
# ===============================================================================================

# %%
# 5. Non-Shared backbone & Non-Shared head (4-2)

model_case_4_2 = define_model(temp_backbone_name, case_name='4_2', device=device)
print(summary(model=model_case_4_2, input_size=input_size))
# Out:
# ===============================================================================================
# Layer (type:depth-idx)                        Output Shape              Param #
# ===============================================================================================
# CNN_CASE_4_2                                  [32, 2]                   --
# ├─ResNet: 1-1                                 [32, 1000]                --
# │    └─Conv2d: 2-1                            [32, 64, 14, 14]          3,136
# │    └─BatchNorm2d: 2-2                       [32, 64, 14, 14]          128
# │    └─ReLU: 2-3                              [32, 64, 14, 14]          --
# │    └─MaxPool2d: 2-4                         [32, 64, 7, 7]            --
# │    └─Sequential: 2-5                        [32, 64, 7, 7]            --
# │    │    └─BasicBlock: 3-1                   [32, 64, 7, 7]            73,984
# │    │    └─BasicBlock: 3-2                   [32, 64, 7, 7]            73,984
# │    └─Sequential: 2-6                        [32, 128, 4, 4]           --
# │    │    └─BasicBlock: 3-3                   [32, 128, 4, 4]           230,144
# │    │    └─BasicBlock: 3-4                   [32, 128, 4, 4]           295,424
# │    └─Sequential: 2-7                        [32, 256, 2, 2]           --
# │    │    └─BasicBlock: 3-5                   [32, 256, 2, 2]           919,040
# │    │    └─BasicBlock: 3-6                   [32, 256, 2, 2]           1,180,672
# │    └─Sequential: 2-8                        [32, 512, 1, 1]           --
# │    │    └─BasicBlock: 3-7                   [32, 512, 1, 1]           3,673,088
# │    │    └─BasicBlock: 3-8                   [32, 512, 1, 1]           4,720,640
# │    └─AdaptiveAvgPool2d: 2-9                 [32, 512, 1, 1]           --
# │    └─Linear: 2-10                           [32, 1000]                513,000
# ├─ResNet: 1-2                                 [32, 1000]                --
# │    └─Conv2d: 2-11                           [32, 64, 14, 14]          3,136
# │    └─BatchNorm2d: 2-12                      [32, 64, 14, 14]          128
# │    └─ReLU: 2-13                             [32, 64, 14, 14]          --
# │    └─MaxPool2d: 2-14                        [32, 64, 7, 7]            --
# │    └─Sequential: 2-15                       [32, 64, 7, 7]            --
# │    │    └─BasicBlock: 3-9                   [32, 64, 7, 7]            73,984
# │    │    └─BasicBlock: 3-10                  [32, 64, 7, 7]            73,984
# │    └─Sequential: 2-16                       [32, 128, 4, 4]           --
# │    │    └─BasicBlock: 3-11                  [32, 128, 4, 4]           230,144
# │    │    └─BasicBlock: 3-12                  [32, 128, 4, 4]           295,424
# │    └─Sequential: 2-17                       [32, 256, 2, 2]           --
# │    │    └─BasicBlock: 3-13                  [32, 256, 2, 2]           919,040
# │    │    └─BasicBlock: 3-14                  [32, 256, 2, 2]           1,180,672
# │    └─Sequential: 2-18                       [32, 512, 1, 1]           --
# │    │    └─BasicBlock: 3-15                  [32, 512, 1, 1]           3,673,088
# │    │    └─BasicBlock: 3-16                  [32, 512, 1, 1]           4,720,640
# │    └─AdaptiveAvgPool2d: 2-19                [32, 512, 1, 1]           --
# │    └─Linear: 2-20                           [32, 1000]                513,000
# ├─Linear: 1-3                                 [32, 2]                   2,002
# ├─Linear: 1-4                                 [32, 2]                   2,002
# ├─Softmax: 1-5                                [32, 2]                   --
# ├─Softmax: 1-6                                [32, 2]                   --
# ===============================================================================================
# Total params: 23,370,484
# Trainable params: 23,370,484
# Non-trainable params: 0
# Total mult-adds (Units.GIGABYTES): 2.15
# ===============================================================================================
# Input size (MB): 0.10
# Forward/backward pass size (MB): 44.55
# Params size (MB): 93.48
# Estimated Total Size (MB): 138.14
# ===============================================================================================

# %% [markdown]
# **6. 데이터셋 분리**
#
# * Train Data -> Train Data + Valid Data

# %%
# dataset size

num_tv = sum(train_subset_class_counts)
num_valid = int(0.1 * num_tv)
num_train = num_tv - num_valid

# %%
# 데이터셋 분리

from torch.utils.data import random_split

train_dataset, valid_dataset = random_split(train_subset, [num_train, num_valid])

# %%
# {0,1,2} -> {0,3,8} Mapping 된 DataLoader 생성

from torch.utils.data import Dataset

class MappedDataset(Dataset):
    def __init__(self, dataset):
        self.dataset = dataset

    def __len__(self):
        return len(self.dataset)

    def __getitem__(self, idx):
        img, target = self.dataset[idx]
        target_mapping = {0: 0, 3: 1, 8: 2}
        target = target_mapping[target]

        return img, target

# %%
# DataLoader 생성

train_dataset_loader = DataLoader(MappedDataset(train_dataset),
                                  batch_size=BATCH_SIZE,
                                  shuffle=True)

valid_dataset_loader = DataLoader(MappedDataset(valid_dataset),
                                  batch_size=BATCH_SIZE,
                                  shuffle=False)

test_dataset_loader = DataLoader(MappedDataset(test_subset),
                                 batch_size=BATCH_SIZE,
                                 shuffle=False)

# %%
# {0,3} vs. {8} / {0,8} vs. {3} Split 된 DataLoader 생성

class DualOutputDataset(Dataset):
    def __init__(self, dataset):
        self.dataset = dataset

    def __len__(self):
        return len(self.dataset)

    def __getitem__(self, idx):
        img, target = self.dataset[idx]
        target1_mapping = {0: 0, 3: 0, 8: 1}
        target2_mapping = {0: 0, 3: 1, 8: 0}

        target1 = target1_mapping[target]
        target2 = target2_mapping[target]

        return img, [target1, target2]

# %%
# Dual Output Dataset 생성

train_01_02_dataset_loader = DataLoader(DualOutputDataset(train_dataset),
                                        batch_size=BATCH_SIZE,
                                        shuffle=True)

valid_01_02_dataset_loader = DataLoader(DualOutputDataset(valid_dataset),
                                        batch_size=BATCH_SIZE,
                                        shuffle=False)

test_01_02_dataset_loader = DataLoader(DualOutputDataset(test_subset),
                                       batch_size=BATCH_SIZE,
                                       shuffle=False)

# %% [markdown]
# **7. 모델 학습 함수 정의**

# %%
MAX_EPOCHS = 9999
EARLY_STOPPING_ROUNDS = 10  # Early Stopping Patience (epochs)

# %%
# dual labels -> PyTorch tensor

def convert_to_tensor(labels):
    labels[0] = list(labels[0])
    labels[1] = list(labels[1])
    labels_tensor = torch.tensor(labels)
    labels_tensor = labels_tensor.transpose(0, 1)

    return labels_tensor

# %%
# 모델 학습 실시

# args :
# - model           : 학습할 모델
# - train_loader    : Training Data Loader
# - train_loss_list : 각 epoch 에서의 train loss 기록
# - is_dual_head    : 신경망 출력값, 즉 MLP Head 가 2개인지의 여부

# returns :
# - train_loss : 모델의 Train Loss

def run_train(model, train_loader, train_loss_list, is_dual_head, verbose):
    model.train()
    train_loss = 0.0
    train_idx = 0

    for images, labels in train_loader:
        if is_dual_head:
            labels = convert_to_tensor(labels)
        images, labels = images.to(device), labels.to(device)

        # train 실시
        model.optimizer.zero_grad()
        outputs = model(images)

        if is_dual_head:
            loss1 = nn.CrossEntropyLoss()(outputs[0], labels[:, 0])
            loss2 = nn.CrossEntropyLoss()(outputs[1], labels[:, 1])
            loss = loss1 + loss2
        else:
            loss = nn.CrossEntropyLoss()(outputs, labels)

        loss.backward()
        model.optimizer.step()

        train_loss += loss.item()
        train_idx += 1

        if verbose:
            if train_idx % 20 == 0:
                print(f'idx: {train_idx}, loss for current idx: {loss.item():.6f}')

    train_loss_list.append(train_loss / len(train_loader))
    return train_loss_list[-1]

# %%
import time

# 모델 validation / test 실시

# args :
# - model                : validation/test 할 모델
# - valid_or_test_loader : validation/test Data Loader
# - is_dual_head         : 신경망 출력값, 즉 MLP Head 가 2개인지의 여부

# returns :
# - accuracy       : 모델의 validation/test 정확도
# - inference_time : inference 시간 (seconds)

def run_valid_or_test(model, valid_or_test_loader, is_dual_head):
    model.eval()
    correct, total = 0, 0
    inference_time_sum = 0.0
    valid_test_idx = 0

    with torch.no_grad():
        for images, labels in valid_or_test_loader:
            if is_dual_head:
                labels = convert_to_tensor(labels)
            images, labels = images.to(device), labels.to(device)

            start_at = time.time()
            outputs = model(images)
            inference_time_sum += time.time() - start_at

            # validation/test 실시 및 정확도 측정
            if is_dual_head:
                _, predicted_1 = torch.max(outputs[0], 1)
                _, predicted_2 = torch.max(outputs[1], 1)
                correct += ((predicted_1 == labels[:, 0]) & (predicted_2 == labels[:, 1])).sum().item()

            else:
                _, predicted = torch.max(outputs, 1)
                correct += (predicted == labels).sum().item()

            total += labels.size(0)
            valid_test_idx += 1

    accuracy = correct / total
    inference_time = inference_time_sum / valid_test_idx

    return accuracy, inference_time

# %%
# 모델 학습 및 validation 전체 프로세스

# args :
# - model         : 학습할 모델
# - train_loader  : Training Data Loader
# - valid_loader  : Valid Data Loader
# - test_loader   : Test Data Loader
# - backbone_name : Backbone 모델 이름 ('resnet18', 'resnet34' or 'resnet50')
# - case_name     : 모델 구조 case 이름 ('1', '2', '3', '4_1' or '4_2')
# - verbose       : 학습 중 프로세스 출력 여부

# returns :
# - final_acc      : 해당 하이퍼파라미터 조합에 대한 최종 Accuracy (valid_acc 이 가장 높았던 epoch 의 모델로 측정)
# - inference_time : inference 시간 (seconds)

def run_model_common(model, train_loader, valid_loader, test_loader,
                     backbone_name, case_name, verbose=False):

    train_loss_list = []       # train loss
    valid_acc_list = []        # valid accuracy
    max_valid_acc = 0.0        # max validation accuracy
    best_valid_acc_epoch = -1  # valid_acc 이 가장 높았던 epoch (여기서는 Loss 가 아닌 Accuracy 기준 Early Stopping)
    best_epoch_model = None    # valid_acc 이 가장 높았던 epoch 의 모델

    is_dual_head = case_name in ['3', '4_1', '4_2']

    # 1. 학습 실시
    for epoch in range(MAX_EPOCHS):

        # 1-1. train model
        train_loss = run_train(model,
                               train_loader,
                               train_loss_list,
                               is_dual_head,
                               verbose=(verbose and epoch == 0))

        # 1-2. validate model (with VALID SET)
        epoch_acc, _ = run_valid_or_test(model, valid_loader, is_dual_head)
        valid_acc_list.append(epoch_acc)

        # 1-3. Early Stopping 처리 (overfitting 방지)
        if epoch_acc > max_valid_acc:
            max_valid_acc = epoch_acc
            best_valid_acc_epoch = epoch

            best_epoch_model = define_model(backbone_name, case_name, device)
            best_epoch_model.load_state_dict(model.state_dict())

            if verbose:
                print('best model updated')

        if epoch - best_valid_acc_epoch >= EARLY_STOPPING_ROUNDS:
            break

        # 1-4. 결과 출력
        if verbose:
            print(f"Epoch {epoch+1}, Loss: {train_loss:.4f}, Accuracy: {epoch_acc:.4f}")

    # check best-epoch model correctly loaded
    checked_acc, _ = run_valid_or_test(best_epoch_model, valid_loader, is_dual_head)

    if verbose:
        print(f"Best Epoch: {best_valid_acc_epoch}, Best Valid Acc: {max_valid_acc}")
        print(f"Valid Acc (with Epoch valid set) on Loaded Best Model: {checked_acc}")

    assert abs(max_valid_acc - checked_acc) < 1e-6

    # 2. test best-epoch model (with TEST SET)
    final_acc, inference_time = run_valid_or_test(best_epoch_model, test_loader, is_dual_head)

    if verbose:
        print(f"Final Acc (with TEST set) on Loaded Best Model: {final_acc} (time: {inference_time})")

    return final_acc, inference_time

# %% [markdown]
# **8. 학습 실시**

# %%
print(device)
# Out:
# cuda

# %%
result_dict = {
    'backbone': [],
    'case': [],
    'accuracy': [],
    'inference_time': []
}

dataloader_by_case_name = {
    'dual_head': {
        'train': train_01_02_dataset_loader,
        'valid': valid_01_02_dataset_loader,
        'test': test_01_02_dataset_loader
    },
    'single_head': {
        'train': train_dataset_loader,
        'valid': valid_dataset_loader,
        'test': test_dataset_loader
    }
}

for case_name in ['1', '2', '3', '4_1', '4_2']:
    if case_name in ['3', '4_1', '4_2']:
        head_type = 'dual_head'
    else:
        head_type = 'single_head'

    for backbone_name in ['resnet18', 'resnet34', 'resnet50']:
        print(f'\n=== case={case_name}, backbone={backbone_name} ===')
        model = define_model(backbone_name, case_name, device=device)

        train_loader = dataloader_by_case_name[head_type]['train']
        valid_loader = dataloader_by_case_name[head_type]['valid']
        test_loader = dataloader_by_case_name[head_type]['test']

        final_acc, inference_time = run_model_common(model,
                                                     train_loader=train_loader,
                                                     valid_loader=valid_loader,
                                                     test_loader=test_loader,
                                                     backbone_name=backbone_name,
                                                     case_name=case_name,
                                                     verbose=True)

        result_dict['backbone'].append(backbone_name)
        result_dict['case'].append(case_name)
        result_dict['accuracy'].append(final_acc)
        result_dict['inference_time'].append(inference_time)
# Out:
# === case=1, backbone=resnet18 ===
# idx: 20, loss for current idx: 0.744580
# idx: 40, loss for current idx: 0.596468
# idx: 60, loss for current idx: 0.616834
# idx: 80, loss for current idx: 0.589270
# idx: 100, loss for current idx: 0.559304
# idx: 120, loss for current idx: 0.618129
# idx: 140, loss for current idx: 0.581857
# idx: 160, loss for current idx: 0.585129
# idx: 180, loss for current idx: 0.553517
# idx: 200, loss for current idx: 0.577554
# idx: 220, loss for current idx: 0.658458
# idx: 240, loss for current idx: 0.588318
# idx: 260, loss for current idx: 0.567388
# idx: 280, loss for current idx: 0.592293
# idx: 300, loss for current idx: 0.553608
# idx: 320, loss for current idx: 0.596631
# idx: 340, loss for current idx: 0.551694
# idx: 360, loss for current idx: 0.594992
# idx: 380, loss for current idx: 0.573671
# idx: 400, loss for current idx: 0.631738
# idx: 420, loss for current idx: 0.553669
# idx: 440, loss for current idx: 0.588446
# idx: 460, loss for current idx: 0.552554
# idx: 480, loss for current idx: 0.655260
# idx: 500, loss for current idx: 0.607147
# best model updated
# Epoch 1, Loss: 0.6164, Accuracy: 0.9810
# best model updated
# Epoch 2, Loss: 0.5761, Accuracy: 0.9877
# Epoch 3, Loss: 0.5672, Accuracy: 0.9866
# Epoch 4, Loss: 0.5655, Accuracy: 0.9860
# Epoch 5, Loss: 0.5662, Accuracy: 0.9849
# Epoch 6, Loss: 0.5625, Accuracy: 0.9832
# best model updated
# Epoch 7, Loss: 0.5624, Accuracy: 0.9950
# Epoch 8, Loss: 0.5603, Accuracy: 0.9933
# Epoch 9, Loss: 0.5609, Accuracy: 0.9888
# Epoch 10, Loss: 0.5610, Accuracy: 0.9860
# Epoch 11, Loss: 0.5611, Accuracy: 0.9894
# Epoch 12, Loss: 0.5626, Accuracy: 0.9939
# Epoch 13, Loss: 0.5628, Accuracy: 0.9894
# Epoch 14, Loss: 0.5738, Accuracy: 0.9246
# Epoch 15, Loss: 0.5667, Accuracy: 0.9927
# Epoch 16, Loss: 0.5623, Accuracy: 0.9905
# Best Epoch: 6, Best Valid Acc: 0.9949720670391061
# Valid Acc (with Epoch valid set) on Loaded Best Model: 0.9949720670391061
# Final Acc (with TEST set) on Loaded Best Model: 0.9946018893387314 (time: 0.0047817948043987315)
#
# === case=1, backbone=resnet34 ===
# Downloading: "https://download.pytorch.org/models/resnet34-b627a593.pth" to /root/.cache/torch/hub/checkpoints/resnet34-b627a593.pth
# 100%|██████████| 83.3M/83.3M [00:00<00:00, 193MB/s]
# idx: 20, loss for current idx: 0.651090
# idx: 40, loss for current idx: 0.687301
# idx: 60, loss for current idx: 0.629467
# idx: 80, loss for current idx: 0.661950
# idx: 100, loss for current idx: 0.633864
# idx: 120, loss for current idx: 0.586457
# idx: 140, loss for current idx: 0.609921
# idx: 160, loss for current idx: 0.620668
# idx: 180, loss for current idx: 0.638501
# idx: 200, loss for current idx: 0.583284
# idx: 220, loss for current idx: 0.593105
# idx: 240, loss for current idx: 0.697983
# idx: 260, loss for current idx: 0.609189
# idx: 280, loss for current idx: 0.584055
# idx: 300, loss for current idx: 0.583040
# idx: 320, loss for current idx: 0.616273
# idx: 340, loss for current idx: 0.613708
# idx: 360, loss for current idx: 0.596287
# idx: 380, loss for current idx: 0.614363
# idx: 400, loss for current idx: 0.580048
# idx: 420, loss for current idx: 0.551555
# idx: 440, loss for current idx: 0.560754
# idx: 460, loss for current idx: 0.626799
# idx: 480, loss for current idx: 0.578607
# idx: 500, loss for current idx: 0.568428
# best model updated
# Epoch 1, Loss: 0.6127, Accuracy: 0.9804
# best model updated
# Epoch 2, Loss: 0.5766, Accuracy: 0.9894
# Epoch 3, Loss: 0.5695, Accuracy: 0.9855
# best model updated
# Epoch 4, Loss: 0.5645, Accuracy: 0.9922
# Epoch 5, Loss: 0.5676, Accuracy: 0.9771
# Epoch 6, Loss: 0.5673, Accuracy: 0.9827
# Epoch 7, Loss: 0.5631, Accuracy: 0.9911
# Epoch 8, Loss: 0.5715, Accuracy: 0.9654
# Epoch 9, Loss: 0.5677, Accuracy: 0.9922
# Epoch 10, Loss: 0.5620, Accuracy: 0.9894
# Epoch 11, Loss: 0.5717, Accuracy: 0.9804
# best model updated
# Epoch 12, Loss: 0.5660, Accuracy: 0.9944
# Epoch 13, Loss: 0.5639, Accuracy: 0.9916
# Epoch 14, Loss: 0.5641, Accuracy: 0.9832
# Epoch 15, Loss: 0.5588, Accuracy: 0.9927
# Epoch 16, Loss: 0.5636, Accuracy: 0.9922
# Epoch 17, Loss: 0.5611, Accuracy: 0.9922
# Epoch 18, Loss: 0.5633, Accuracy: 0.9704
# Epoch 19, Loss: 0.5652, Accuracy: 0.9899
# Epoch 20, Loss: 0.5688, Accuracy: 0.9894
# Epoch 21, Loss: 0.5730, Accuracy: 0.9659
# Best Epoch: 11, Best Valid Acc: 0.994413407821229
# Valid Acc (with Epoch valid set) on Loaded Best Model: 0.994413407821229
# Final Acc (with TEST set) on Loaded Best Model: 0.9935897435897436 (time: 0.010597818641252416)
#
# === case=1, backbone=resnet50 ===
# Downloading: "https://download.pytorch.org/models/resnet50-0676ba61.pth" to /root/.cache/torch/hub/checkpoints/resnet50-0676ba61.pth
# 100%|██████████| 97.8M/97.8M [00:00<00:00, 195MB/s]
# idx: 20, loss for current idx: 0.765833
# idx: 40, loss for current idx: 0.713934
# idx: 60, loss for current idx: 0.786545
# idx: 80, loss for current idx: 0.714292
# idx: 100, loss for current idx: 0.615504
# idx: 120, loss for current idx: 0.644406
# idx: 140, loss for current idx: 0.597870
# idx: 160, loss for current idx: 0.639823
# idx: 180, loss for current idx: 0.602238
# idx: 200, loss for current idx: 0.612866
# idx: 220, loss for current idx: 0.661309
# idx: 240, loss for current idx: 0.591121
# idx: 260, loss for current idx: 0.639747
# idx: 280, loss for current idx: 0.591613
# idx: 300, loss for current idx: 0.597998
# idx: 320, loss for current idx: 0.635947
# idx: 340, loss for current idx: 0.583655
# idx: 360, loss for current idx: 0.668444
# idx: 380, loss for current idx: 0.617755
# idx: 400, loss for current idx: 0.702301
# idx: 420, loss for current idx: 0.551445
# idx: 440, loss for current idx: 0.553230
# idx: 460, loss for current idx: 0.590794
# idx: 480, loss for current idx: 0.651021
# idx: 500, loss for current idx: 0.676457
# best model updated
# Epoch 1, Loss: 0.6404, Accuracy: 0.9536
# best model updated
# Epoch 2, Loss: 0.5860, Accuracy: 0.9855
# best model updated
# Epoch 3, Loss: 0.5699, Accuracy: 0.9877
# Epoch 4, Loss: 0.5692, Accuracy: 0.9855
# best model updated
# Epoch 5, Loss: 0.5624, Accuracy: 0.9899
# best model updated
# Epoch 6, Loss: 0.5618, Accuracy: 0.9905
# Epoch 7, Loss: 0.5596, Accuracy: 0.9872
# Epoch 8, Loss: 0.5604, Accuracy: 0.9894
# Epoch 9, Loss: 0.5609, Accuracy: 0.9844
# Epoch 10, Loss: 0.5610, Accuracy: 0.9855
# best model updated
# Epoch 11, Loss: 0.5607, Accuracy: 0.9922
# Epoch 12, Loss: 0.5576, Accuracy: 0.9911
# best model updated
# Epoch 13, Loss: 0.5592, Accuracy: 0.9955
# Epoch 14, Loss: 0.5604, Accuracy: 0.9894
# Epoch 15, Loss: 0.5611, Accuracy: 0.9939
# Epoch 16, Loss: 0.5577, Accuracy: 0.9855
# Epoch 17, Loss: 0.5605, Accuracy: 0.9927
# Epoch 18, Loss: 0.5619, Accuracy: 0.9933
# Epoch 19, Loss: 0.5596, Accuracy: 0.9939
# best model updated
# Epoch 20, Loss: 0.5577, Accuracy: 0.9983
# Epoch 21, Loss: 0.5566, Accuracy: 0.9966
# Epoch 22, Loss: 0.5559, Accuracy: 0.9933
# Epoch 23, Loss: 0.5548, Accuracy: 0.9950
# Epoch 24, Loss: 0.5561, Accuracy: 0.9927
# Epoch 25, Loss: 0.5599, Accuracy: 0.9849
# Epoch 26, Loss: 0.5582, Accuracy: 0.9961
# Epoch 27, Loss: 0.5557, Accuracy: 0.9933
# Epoch 28, Loss: 0.5580, Accuracy: 0.9939
# Epoch 29, Loss: 0.5568, Accuracy: 0.9950
# Best Epoch: 19, Best Valid Acc: 0.9983240223463687
# Valid Acc (with Epoch valid set) on Loaded Best Model: 0.9983240223463687
# Final Acc (with TEST set) on Loaded Best Model: 0.9959514170040485 (time: 0.0109125183474633)
#
# === case=2, backbone=resnet18 ===
# idx: 20, loss for current idx: 0.920040
# idx: 40, loss for current idx: 0.685453
# idx: 60, loss for current idx: 0.695466
# idx: 80, loss for current idx: 0.620850
# idx: 100, loss for current idx: 0.617822
# idx: 120, loss for current idx: 0.611994
# idx: 140, loss for current idx: 0.582990
# idx: 160, loss for current idx: 0.578072
# idx: 180, loss for current idx: 0.582926
# idx: 200, loss for current idx: 0.652144
# idx: 220, loss for current idx: 0.659153
# idx: 240, loss for current idx: 0.605087
# idx: 260, loss for current idx: 0.586507
# idx: 280, loss for current idx: 0.552330
# idx: 300, loss for current idx: 0.553569
# idx: 320, loss for current idx: 0.652492
# idx: 340, loss for current idx: 0.621778
# idx: 360, loss for current idx: 0.660221
# idx: 380, loss for current idx: 0.590698
# idx: 400, loss for current idx: 0.617117
# idx: 420, loss for current idx: 0.551451
# idx: 440, loss for current idx: 0.593723
# idx: 460, loss for current idx: 0.639571
# idx: 480, loss for current idx: 0.553451
# idx: 500, loss for current idx: 0.556901
# best model updated
# Epoch 1, Loss: 0.6274, Accuracy: 0.9771
# best model updated
# Epoch 2, Loss: 0.5732, Accuracy: 0.9844
# Epoch 3, Loss: 0.5731, Accuracy: 0.9804
# best model updated
# Epoch 4, Loss: 0.5653, Accuracy: 0.9955
# Epoch 5, Loss: 0.5618, Accuracy: 0.9911
# Epoch 6, Loss: 0.5627, Accuracy: 0.9911
# Epoch 7, Loss: 0.5614, Accuracy: 0.9888
# Epoch 8, Loss: 0.5669, Accuracy: 0.9838
# Epoch 9, Loss: 0.5667, Accuracy: 0.9894
# Epoch 10, Loss: 0.5599, Accuracy: 0.9894
# Epoch 11, Loss: 0.5689, Accuracy: 0.9821
# Epoch 12, Loss: 0.5613, Accuracy: 0.9911
# best model updated
# Epoch 13, Loss: 0.5595, Accuracy: 0.9961
# Epoch 14, Loss: 0.5587, Accuracy: 0.9922
# Epoch 15, Loss: 0.5598, Accuracy: 0.9950
# Epoch 16, Loss: 0.5606, Accuracy: 0.9883
# Epoch 17, Loss: 0.5610, Accuracy: 0.9955
# Epoch 18, Loss: 0.5619, Accuracy: 0.9950
# Epoch 19, Loss: 0.5613, Accuracy: 0.9939
# Epoch 20, Loss: 0.5570, Accuracy: 0.9944
# Epoch 21, Loss: 0.5588, Accuracy: 0.9950
# Epoch 22, Loss: 0.5591, Accuracy: 0.9927
# Best Epoch: 12, Best Valid Acc: 0.9960893854748604
# Valid Acc (with Epoch valid set) on Loaded Best Model: 0.9960893854748604
# Final Acc (with TEST set) on Loaded Best Model: 0.9935897435897436 (time: 0.0024909280961559663)
#
# === case=2, backbone=resnet34 ===
# idx: 20, loss for current idx: 0.665214
# idx: 40, loss for current idx: 0.727285
# idx: 60, loss for current idx: 0.638247
# idx: 80, loss for current idx: 0.588892
# idx: 100, loss for current idx: 0.639487
# idx: 120, loss for current idx: 0.568240
# idx: 140, loss for current idx: 0.586506
# idx: 160, loss for current idx: 0.554895
# idx: 180, loss for current idx: 0.600716
# idx: 200, loss for current idx: 0.559566
# idx: 220, loss for current idx: 0.585289
# idx: 240, loss for current idx: 0.581161
# idx: 260, loss for current idx: 0.610882
# idx: 280, loss for current idx: 0.604115
# idx: 300, loss for current idx: 0.610968
# idx: 320, loss for current idx: 0.584968
# idx: 340, loss for current idx: 0.596819
# idx: 360, loss for current idx: 0.612960
# idx: 380, loss for current idx: 0.551514
# idx: 400, loss for current idx: 0.554897
# idx: 420, loss for current idx: 0.551543
# idx: 440, loss for current idx: 0.611397
# idx: 460, loss for current idx: 0.676742
# idx: 480, loss for current idx: 0.571484
# idx: 500, loss for current idx: 0.582700
# best model updated
# Epoch 1, Loss: 0.6174, Accuracy: 0.9749
# best model updated
# Epoch 2, Loss: 0.5796, Accuracy: 0.9860
# Epoch 3, Loss: 0.5667, Accuracy: 0.9598
# best model updated
# Epoch 4, Loss: 0.5667, Accuracy: 0.9922
# Epoch 5, Loss: 0.5650, Accuracy: 0.9838
# Epoch 6, Loss: 0.5646, Accuracy: 0.9877
# Epoch 7, Loss: 0.5664, Accuracy: 0.9877
# best model updated
# Epoch 8, Loss: 0.5634, Accuracy: 0.9939
# Epoch 9, Loss: 0.5602, Accuracy: 0.9933
# Epoch 10, Loss: 0.5605, Accuracy: 0.9911
# Epoch 11, Loss: 0.5634, Accuracy: 0.9911
# best model updated
# Epoch 12, Loss: 0.5588, Accuracy: 0.9950
# Epoch 13, Loss: 0.5609, Accuracy: 0.9944
# Epoch 14, Loss: 0.5590, Accuracy: 0.9950
# Epoch 15, Loss: 0.5581, Accuracy: 0.9939
# best model updated
# Epoch 16, Loss: 0.5606, Accuracy: 0.9961
# Epoch 17, Loss: 0.5662, Accuracy: 0.9737
# Epoch 18, Loss: 0.5625, Accuracy: 0.9939
# Epoch 19, Loss: 0.5590, Accuracy: 0.9955
# Epoch 20, Loss: 0.5565, Accuracy: 0.9927
# best model updated
# Epoch 21, Loss: 0.5580, Accuracy: 0.9966
# Epoch 22, Loss: 0.5593, Accuracy: 0.9777
# Epoch 23, Loss: 0.5591, Accuracy: 0.9916
# best model updated
# Epoch 24, Loss: 0.5566, Accuracy: 0.9978
# Epoch 25, Loss: 0.5608, Accuracy: 0.9966
# Epoch 26, Loss: 0.5580, Accuracy: 0.9961
# Epoch 27, Loss: 0.5559, Accuracy: 0.9939
# Epoch 28, Loss: 0.5571, Accuracy: 0.9950
# Epoch 29, Loss: 0.5596, Accuracy: 0.9821
# Epoch 30, Loss: 0.5586, Accuracy: 0.9872
# Epoch 31, Loss: 0.5567, Accuracy: 0.9961
# Epoch 32, Loss: 0.5625, Accuracy: 0.9927
# Epoch 33, Loss: 0.5593, Accuracy: 0.9950
# Best Epoch: 23, Best Valid Acc: 0.9977653631284916
# Valid Acc (with Epoch valid set) on Loaded Best Model: 0.9977653631284916
# Final Acc (with TEST set) on Loaded Best Model: 0.9962887989203779 (time: 0.004127135840795373)
#
# === case=2, backbone=resnet50 ===
# idx: 20, loss for current idx: 0.851655
# idx: 40, loss for current idx: 0.732318
# idx: 60, loss for current idx: 0.692569
# idx: 80, loss for current idx: 0.623224
# idx: 100, loss for current idx: 0.621424
# idx: 120, loss for current idx: 0.657470
# idx: 140, loss for current idx: 0.599783
# idx: 160, loss for current idx: 0.653430
# idx: 180, loss for current idx: 0.717146
# idx: 200, loss for current idx: 0.588406
# idx: 220, loss for current idx: 0.691819
# idx: 240, loss for current idx: 0.622701
# idx: 260, loss for current idx: 0.601793
# idx: 280, loss for current idx: 0.623868
# idx: 300, loss for current idx: 0.643262
# idx: 320, loss for current idx: 0.614571
# idx: 340, loss for current idx: 0.635807
# idx: 360, loss for current idx: 0.584539
# idx: 380, loss for current idx: 0.583202
# idx: 400, loss for current idx: 0.584847
# idx: 420, loss for current idx: 0.571490
# idx: 440, loss for current idx: 0.632253
# idx: 460, loss for current idx: 0.673823
# idx: 480, loss for current idx: 0.583031
# idx: 500, loss for current idx: 0.614750
# best model updated
# Epoch 1, Loss: 0.6407, Accuracy: 0.9793
# best model updated
# Epoch 2, Loss: 0.5828, Accuracy: 0.9860
# best model updated
# Epoch 3, Loss: 0.5693, Accuracy: 0.9888
# Epoch 4, Loss: 0.5677, Accuracy: 0.9693
# best model updated
# Epoch 5, Loss: 0.5640, Accuracy: 0.9916
# best model updated
# Epoch 6, Loss: 0.5653, Accuracy: 0.9922
# Epoch 7, Loss: 0.5612, Accuracy: 0.9905
# Epoch 8, Loss: 0.5669, Accuracy: 0.9877
# Epoch 9, Loss: 0.5614, Accuracy: 0.9860
# best model updated
# Epoch 10, Loss: 0.5622, Accuracy: 0.9944
# Epoch 11, Loss: 0.5600, Accuracy: 0.9916
# Epoch 12, Loss: 0.5640, Accuracy: 0.9832
# Epoch 13, Loss: 0.5634, Accuracy: 0.9793
# Epoch 14, Loss: 0.5657, Accuracy: 0.9888
# Epoch 15, Loss: 0.5688, Accuracy: 0.9866
# Epoch 16, Loss: 0.5628, Accuracy: 0.9927
# Epoch 17, Loss: 0.5581, Accuracy: 0.9944
# Epoch 18, Loss: 0.5614, Accuracy: 0.9894
# Epoch 19, Loss: 0.5636, Accuracy: 0.9922
# Best Epoch: 9, Best Valid Acc: 0.994413407821229
# Valid Acc (with Epoch valid set) on Loaded Best Model: 0.994413407821229
# Final Acc (with TEST set) on Loaded Best Model: 0.9922402159244265 (time: 0.005393023131996072)
#
# === case=3, backbone=resnet18 ===
# idx: 20, loss for current idx: 0.939067
# idx: 40, loss for current idx: 0.896294
# idx: 60, loss for current idx: 0.795489
# idx: 80, loss for current idx: 0.758664
# idx: 100, loss for current idx: 0.634048
# idx: 120, loss for current idx: 0.720671
# idx: 140, loss for current idx: 0.635194
# idx: 160, loss for current idx: 0.699334
# idx: 180, loss for current idx: 0.738878
# idx: 200, loss for current idx: 0.688304
# idx: 220, loss for current idx: 0.645131
# idx: 240, loss for current idx: 0.685315
# idx: 260, loss for current idx: 0.709259
# idx: 280, loss for current idx: 0.636318
# idx: 300, loss for current idx: 0.654186
# idx: 320, loss for current idx: 0.677473
# idx: 340, loss for current idx: 0.730579
# idx: 360, loss for current idx: 0.671961
# idx: 380, loss for current idx: 0.683039
# idx: 400, loss for current idx: 0.659865
# idx: 420, loss for current idx: 0.681069
# idx: 440, loss for current idx: 0.816253
# idx: 460, loss for current idx: 0.656098
# idx: 480, loss for current idx: 0.718464
# idx: 500, loss for current idx: 0.629378
# best model updated
# Epoch 1, Loss: 0.7336, Accuracy: 0.9709
# best model updated
# Epoch 2, Loss: 0.6620, Accuracy: 0.9855
# Epoch 3, Loss: 0.6475, Accuracy: 0.9793
# best model updated
# Epoch 4, Loss: 0.6419, Accuracy: 0.9894
# best model updated
# Epoch 5, Loss: 0.6442, Accuracy: 0.9899
# Epoch 6, Loss: 0.6445, Accuracy: 0.9883
# best model updated
# Epoch 7, Loss: 0.6394, Accuracy: 0.9922
# Epoch 8, Loss: 0.6430, Accuracy: 0.9899
# Epoch 9, Loss: 0.6433, Accuracy: 0.9905
# Epoch 10, Loss: 0.6431, Accuracy: 0.9894
# best model updated
# Epoch 11, Loss: 0.6439, Accuracy: 0.9939
# Epoch 12, Loss: 0.6421, Accuracy: 0.9782
# Epoch 13, Loss: 0.6485, Accuracy: 0.9927
# Epoch 14, Loss: 0.6382, Accuracy: 0.9888
# Epoch 15, Loss: 0.6372, Accuracy: 0.9927
# Epoch 16, Loss: 0.6442, Accuracy: 0.9922
# Epoch 17, Loss: 0.6556, Accuracy: 0.9844
# Epoch 18, Loss: 0.6447, Accuracy: 0.9933
# best model updated
# Epoch 19, Loss: 0.6420, Accuracy: 0.9961
# Epoch 20, Loss: 0.6388, Accuracy: 0.9866
# Epoch 21, Loss: 0.6352, Accuracy: 0.9955
# Epoch 22, Loss: 0.6403, Accuracy: 0.9888
# Epoch 23, Loss: 0.6424, Accuracy: 0.9955
# Epoch 24, Loss: 0.6417, Accuracy: 0.9939
# Epoch 25, Loss: 0.6555, Accuracy: 0.9922
# Epoch 26, Loss: 0.6460, Accuracy: 0.9933
# Epoch 27, Loss: 0.6470, Accuracy: 0.9933
# Epoch 28, Loss: 0.6363, Accuracy: 0.9944
# Best Epoch: 18, Best Valid Acc: 0.9960893854748604
# Valid Acc (with Epoch valid set) on Loaded Best Model: 0.9960893854748604
# Final Acc (with TEST set) on Loaded Best Model: 0.9962887989203779 (time: 0.00243736082507718)
#
# === case=3, backbone=resnet34 ===
# idx: 20, loss for current idx: 0.942984
# idx: 40, loss for current idx: 0.850267
# idx: 60, loss for current idx: 0.709566
# idx: 80, loss for current idx: 0.836484
# idx: 100, loss for current idx: 0.793889
# idx: 120, loss for current idx: 0.863370
# idx: 140, loss for current idx: 0.714527
# idx: 160, loss for current idx: 0.702640
# idx: 180, loss for current idx: 0.634695
# idx: 200, loss for current idx: 0.703352
# idx: 220, loss for current idx: 0.796145
# idx: 240, loss for current idx: 0.779533
# idx: 260, loss for current idx: 0.658128
# idx: 280, loss for current idx: 0.806703
# idx: 300, loss for current idx: 0.792030
# idx: 320, loss for current idx: 0.703178
# idx: 340, loss for current idx: 0.639045
# idx: 360, loss for current idx: 0.631917
# idx: 380, loss for current idx: 0.658385
# idx: 400, loss for current idx: 0.626559
# idx: 420, loss for current idx: 0.688875
# idx: 440, loss for current idx: 0.688880
# idx: 460, loss for current idx: 0.660688
# idx: 480, loss for current idx: 0.667811
# idx: 500, loss for current idx: 0.656237
# best model updated
# Epoch 1, Loss: 0.7287, Accuracy: 0.9860
# Epoch 2, Loss: 0.6669, Accuracy: 0.9637
# best model updated
# Epoch 3, Loss: 0.6485, Accuracy: 0.9905
# Epoch 4, Loss: 0.6443, Accuracy: 0.9872
# best model updated
# Epoch 5, Loss: 0.6441, Accuracy: 0.9922
# best model updated
# Epoch 6, Loss: 0.6432, Accuracy: 0.9927
# best model updated
# Epoch 7, Loss: 0.6430, Accuracy: 0.9961
# Epoch 8, Loss: 0.6431, Accuracy: 0.9933
# Epoch 9, Loss: 0.6416, Accuracy: 0.9760
# Epoch 10, Loss: 0.6470, Accuracy: 0.9939
# Epoch 11, Loss: 0.6425, Accuracy: 0.9922
# Epoch 12, Loss: 0.6360, Accuracy: 0.9950
# Epoch 13, Loss: 0.6414, Accuracy: 0.9933
# Epoch 14, Loss: 0.6322, Accuracy: 0.9944
# Epoch 15, Loss: 0.6368, Accuracy: 0.9905
# Epoch 16, Loss: 0.6376, Accuracy: 0.9944
# Best Epoch: 6, Best Valid Acc: 0.9960893854748604
# Valid Acc (with Epoch valid set) on Loaded Best Model: 0.9960893854748604
# Final Acc (with TEST set) on Loaded Best Model: 0.9935897435897436 (time: 0.004142663812124601)
#
# === case=3, backbone=resnet50 ===
# idx: 20, loss for current idx: 1.080478
# idx: 40, loss for current idx: 1.113662
# idx: 60, loss for current idx: 0.708206
# idx: 80, loss for current idx: 0.668860
# idx: 100, loss for current idx: 0.791638
# idx: 120, loss for current idx: 0.789423
# idx: 140, loss for current idx: 0.787689
# idx: 160, loss for current idx: 0.677462
# idx: 180, loss for current idx: 0.737650
# idx: 200, loss for current idx: 0.691923
# idx: 220, loss for current idx: 0.695125
# idx: 240, loss for current idx: 0.667850
# idx: 260, loss for current idx: 0.793263
# idx: 280, loss for current idx: 0.728899
# idx: 300, loss for current idx: 0.694350
# idx: 320, loss for current idx: 0.726204
# idx: 340, loss for current idx: 0.752204
# idx: 360, loss for current idx: 0.810494
# idx: 380, loss for current idx: 0.720564
# idx: 400, loss for current idx: 0.751199
# idx: 420, loss for current idx: 0.775736
# idx: 440, loss for current idx: 0.686632
# idx: 460, loss for current idx: 0.657788
# idx: 480, loss for current idx: 0.692333
# idx: 500, loss for current idx: 0.688976
# best model updated
# Epoch 1, Loss: 0.7738, Accuracy: 0.9592
# best model updated
# Epoch 2, Loss: 0.6779, Accuracy: 0.9737
# best model updated
# Epoch 3, Loss: 0.6495, Accuracy: 0.9905
# Epoch 4, Loss: 0.6500, Accuracy: 0.9899
# best model updated
# Epoch 5, Loss: 0.6481, Accuracy: 0.9955
# Epoch 6, Loss: 0.6413, Accuracy: 0.9788
# Epoch 7, Loss: 0.6363, Accuracy: 0.9922
# Epoch 8, Loss: 0.6390, Accuracy: 0.9939
# Epoch 9, Loss: 0.6414, Accuracy: 0.9771
# Epoch 10, Loss: 0.6449, Accuracy: 0.9944
# Epoch 11, Loss: 0.6397, Accuracy: 0.9905
# Epoch 12, Loss: 0.6409, Accuracy: 0.9860
# Epoch 13, Loss: 0.6684, Accuracy: 0.9872
# Epoch 14, Loss: 0.6389, Accuracy: 0.9911
# Best Epoch: 4, Best Valid Acc: 0.9955307262569832
# Valid Acc (with Epoch valid set) on Loaded Best Model: 0.9955307262569832
# Final Acc (with TEST set) on Loaded Best Model: 0.9912280701754386 (time: 0.005534318185621692)
#
# === case=4_1, backbone=resnet18 ===
# idx: 20, loss for current idx: 0.883030
# idx: 40, loss for current idx: 0.888878
# idx: 60, loss for current idx: 0.923273
# idx: 80, loss for current idx: 0.817005
# idx: 100, loss for current idx: 0.741025
# idx: 120, loss for current idx: 0.754026
# idx: 140, loss for current idx: 0.662058
# idx: 160, loss for current idx: 0.706146
# idx: 180, loss for current idx: 0.739690
# idx: 200, loss for current idx: 0.688621
# idx: 220, loss for current idx: 0.749979
# idx: 240, loss for current idx: 0.784739
# idx: 260, loss for current idx: 0.693256
# idx: 280, loss for current idx: 0.627866
# idx: 300, loss for current idx: 0.658595
# idx: 320, loss for current idx: 0.730593
# idx: 340, loss for current idx: 0.628168
# idx: 360, loss for current idx: 0.656267
# idx: 380, loss for current idx: 0.659761
# idx: 400, loss for current idx: 0.837185
# idx: 420, loss for current idx: 0.665730
# idx: 440, loss for current idx: 0.636883
# idx: 460, loss for current idx: 0.678996
# idx: 480, loss for current idx: 0.626557
# idx: 500, loss for current idx: 0.658546
# best model updated
# Epoch 1, Loss: 0.7145, Accuracy: 0.9799
# best model updated
# Epoch 2, Loss: 0.6552, Accuracy: 0.9810
# best model updated
# Epoch 3, Loss: 0.6477, Accuracy: 0.9894
# best model updated
# Epoch 4, Loss: 0.6434, Accuracy: 0.9899
# best model updated
# Epoch 5, Loss: 0.6409, Accuracy: 0.9927
# Epoch 6, Loss: 0.6407, Accuracy: 0.9888
# Epoch 7, Loss: 0.6400, Accuracy: 0.9860
# Epoch 8, Loss: 0.6382, Accuracy: 0.9872
# best model updated
# Epoch 9, Loss: 0.6372, Accuracy: 0.9955
# Epoch 10, Loss: 0.6347, Accuracy: 0.9883
# Epoch 11, Loss: 0.6438, Accuracy: 0.9899
# Epoch 12, Loss: 0.6467, Accuracy: 0.9899
# Epoch 13, Loss: 0.6394, Accuracy: 0.9821
# Epoch 14, Loss: 0.6349, Accuracy: 0.9894
# Epoch 15, Loss: 0.6459, Accuracy: 0.9922
# Epoch 16, Loss: 0.6372, Accuracy: 0.9911
# Epoch 17, Loss: 0.6390, Accuracy: 0.9894
# Epoch 18, Loss: 0.6358, Accuracy: 0.9855
# Best Epoch: 8, Best Valid Acc: 0.9955307262569832
# Valid Acc (with Epoch valid set) on Loaded Best Model: 0.9955307262569832
# Final Acc (with TEST set) on Loaded Best Model: 0.9969635627530364 (time: 0.004742750557520057)
#
# === case=4_1, backbone=resnet34 ===
# idx: 20, loss for current idx: 0.811062
# idx: 40, loss for current idx: 0.806123
# idx: 60, loss for current idx: 0.686727
# idx: 80, loss for current idx: 0.749112
# idx: 100, loss for current idx: 0.723273
# idx: 120, loss for current idx: 0.720738
# idx: 140, loss for current idx: 0.867351
# idx: 160, loss for current idx: 0.698812
# idx: 180, loss for current idx: 0.668577
# idx: 200, loss for current idx: 0.708218
# idx: 220, loss for current idx: 0.693332
# idx: 240, loss for current idx: 0.801781
# idx: 260, loss for current idx: 0.744969
# idx: 280, loss for current idx: 0.652146
# idx: 300, loss for current idx: 0.655710
# idx: 320, loss for current idx: 0.689643
# idx: 340, loss for current idx: 0.741853
# idx: 360, loss for current idx: 0.737929
# idx: 380, loss for current idx: 0.626740
# idx: 400, loss for current idx: 0.626732
# idx: 420, loss for current idx: 0.719886
# idx: 440, loss for current idx: 0.703819
# idx: 460, loss for current idx: 0.813729
# idx: 480, loss for current idx: 0.634454
# idx: 500, loss for current idx: 0.701218
# best model updated
# Epoch 1, Loss: 0.7312, Accuracy: 0.9765
# best model updated
# Epoch 2, Loss: 0.6661, Accuracy: 0.9849
# best model updated
# Epoch 3, Loss: 0.6536, Accuracy: 0.9872
# best model updated
# Epoch 4, Loss: 0.6478, Accuracy: 0.9950
# Epoch 5, Loss: 0.6402, Accuracy: 0.9905
# Epoch 6, Loss: 0.6374, Accuracy: 0.9911
# Epoch 7, Loss: 0.6415, Accuracy: 0.9927
# Epoch 8, Loss: 0.6456, Accuracy: 0.9799
# Epoch 9, Loss: 0.6514, Accuracy: 0.9827
# Epoch 10, Loss: 0.6428, Accuracy: 0.9821
# Epoch 11, Loss: 0.6417, Accuracy: 0.9927
# Epoch 12, Loss: 0.6526, Accuracy: 0.9743
# Epoch 13, Loss: 0.6456, Accuracy: 0.9927
# Best Epoch: 3, Best Valid Acc: 0.9949720670391061
# Valid Acc (with Epoch valid set) on Loaded Best Model: 0.9949720670391061
# Final Acc (with TEST set) on Loaded Best Model: 0.9925775978407557 (time: 0.008111128243066932)
#
# === case=4_1, backbone=resnet50 ===
# idx: 20, loss for current idx: 1.111274
# idx: 40, loss for current idx: 0.941145
# idx: 60, loss for current idx: 0.727740
# idx: 80, loss for current idx: 0.858613
# idx: 100, loss for current idx: 0.815986
# idx: 120, loss for current idx: 0.780639
# idx: 140, loss for current idx: 0.739534
# idx: 160, loss for current idx: 0.701817
# idx: 180, loss for current idx: 0.775028
# idx: 200, loss for current idx: 0.773813
# idx: 220, loss for current idx: 0.667191
# idx: 240, loss for current idx: 0.751101
# idx: 260, loss for current idx: 0.704443
# idx: 280, loss for current idx: 0.836197
# idx: 300, loss for current idx: 0.753835
# idx: 320, loss for current idx: 0.745707
# idx: 340, loss for current idx: 0.779779
# idx: 360, loss for current idx: 0.703465
# idx: 380, loss for current idx: 0.644461
# idx: 400, loss for current idx: 0.659031
# idx: 420, loss for current idx: 0.646875
# idx: 440, loss for current idx: 0.809151
# idx: 460, loss for current idx: 0.695166
# idx: 480, loss for current idx: 0.682831
# idx: 500, loss for current idx: 0.860501
# best model updated
# Epoch 1, Loss: 0.7514, Accuracy: 0.9737
# best model updated
# Epoch 2, Loss: 0.6658, Accuracy: 0.9877
# Epoch 3, Loss: 0.6518, Accuracy: 0.9849
# best model updated
# Epoch 4, Loss: 0.6527, Accuracy: 0.9894
# Epoch 5, Loss: 0.6440, Accuracy: 0.9866
# best model updated
# Epoch 6, Loss: 0.6407, Accuracy: 0.9927
# Epoch 7, Loss: 0.6407, Accuracy: 0.9905
# Epoch 8, Loss: 0.6450, Accuracy: 0.9838
# best model updated
# Epoch 9, Loss: 0.6386, Accuracy: 0.9961
# Epoch 10, Loss: 0.6380, Accuracy: 0.9872
# Epoch 11, Loss: 0.6406, Accuracy: 0.9860
# Epoch 12, Loss: 0.6389, Accuracy: 0.9955
# Epoch 13, Loss: 0.6406, Accuracy: 0.9894
# Epoch 14, Loss: 0.6414, Accuracy: 0.9877
# Epoch 15, Loss: 0.6385, Accuracy: 0.9922
# Epoch 16, Loss: 0.6520, Accuracy: 0.9855
# Epoch 17, Loss: 0.6368, Accuracy: 0.9927
# Epoch 18, Loss: 0.6395, Accuracy: 0.9911
# Best Epoch: 8, Best Valid Acc: 0.9960893854748604
# Valid Acc (with Epoch valid set) on Loaded Best Model: 0.9960893854748604
# Final Acc (with TEST set) on Loaded Best Model: 0.9962887989203779 (time: 0.010881498295773742)
#
# === case=4_2, backbone=resnet18 ===
# idx: 20, loss for current idx: 0.946016
# idx: 40, loss for current idx: 0.891825
# idx: 60, loss for current idx: 0.713481
# idx: 80, loss for current idx: 0.882962
# idx: 100, loss for current idx: 0.714050
# idx: 120, loss for current idx: 0.730395
# idx: 140, loss for current idx: 0.722479
# idx: 160, loss for current idx: 0.641694
# idx: 180, loss for current idx: 0.766607
# idx: 200, loss for current idx: 0.700323
# idx: 220, loss for current idx: 0.705557
# idx: 240, loss for current idx: 0.720872
# idx: 260, loss for current idx: 0.685634
# idx: 280, loss for current idx: 0.659708
# idx: 300, loss for current idx: 0.629448
# idx: 320, loss for current idx: 0.711688
# idx: 340, loss for current idx: 0.659508
# idx: 360, loss for current idx: 0.663555
# idx: 380, loss for current idx: 0.658990
# idx: 400, loss for current idx: 0.684119
# idx: 420, loss for current idx: 0.659473
# idx: 440, loss for current idx: 0.761437
# idx: 460, loss for current idx: 0.701317
# idx: 480, loss for current idx: 0.657937
# idx: 500, loss for current idx: 0.726944
# best model updated
# Epoch 1, Loss: 0.7347, Accuracy: 0.9631
# best model updated
# Epoch 2, Loss: 0.6647, Accuracy: 0.9754
# best model updated
# Epoch 3, Loss: 0.6554, Accuracy: 0.9765
# Epoch 4, Loss: 0.6531, Accuracy: 0.9754
# best model updated
# Epoch 5, Loss: 0.6482, Accuracy: 0.9788
# Epoch 6, Loss: 0.6484, Accuracy: 0.9693
# Epoch 7, Loss: 0.6420, Accuracy: 0.9676
# best model updated
# Epoch 8, Loss: 0.6437, Accuracy: 0.9883
# Epoch 9, Loss: 0.6388, Accuracy: 0.9821
# best model updated
# Epoch 10, Loss: 0.6422, Accuracy: 0.9888
# Epoch 11, Loss: 0.6410, Accuracy: 0.9877
# Epoch 12, Loss: 0.6427, Accuracy: 0.9782
# best model updated
# Epoch 13, Loss: 0.6380, Accuracy: 0.9916
# Epoch 14, Loss: 0.6353, Accuracy: 0.9916
# best model updated
# Epoch 15, Loss: 0.6343, Accuracy: 0.9922
# Epoch 16, Loss: 0.6364, Accuracy: 0.9888
# Epoch 17, Loss: 0.6370, Accuracy: 0.9883
# Epoch 18, Loss: 0.6357, Accuracy: 0.9916
# Epoch 19, Loss: 0.6382, Accuracy: 0.9860
# Epoch 20, Loss: 0.6421, Accuracy: 0.9905
# Epoch 21, Loss: 0.6378, Accuracy: 0.9905
# best model updated
# Epoch 22, Loss: 0.6331, Accuracy: 0.9933
# Epoch 23, Loss: 0.6326, Accuracy: 0.9911
# Epoch 24, Loss: 0.6339, Accuracy: 0.9883
# Epoch 25, Loss: 0.6391, Accuracy: 0.9877
# Epoch 26, Loss: 0.6329, Accuracy: 0.9844
# Epoch 27, Loss: 0.6337, Accuracy: 0.9899
# Epoch 28, Loss: 0.6330, Accuracy: 0.9916
# best model updated
# Epoch 29, Loss: 0.6322, Accuracy: 0.9939
# Epoch 30, Loss: 0.6333, Accuracy: 0.9899
# Epoch 31, Loss: 0.6450, Accuracy: 0.9827
# Epoch 32, Loss: 0.6461, Accuracy: 0.9927
# Epoch 33, Loss: 0.6325, Accuracy: 0.9939
# best model updated
# Epoch 34, Loss: 0.6322, Accuracy: 0.9950
# Epoch 35, Loss: 0.6314, Accuracy: 0.9916
# Epoch 36, Loss: 0.6346, Accuracy: 0.9866
# Epoch 37, Loss: 0.6339, Accuracy: 0.9922
# best model updated
# Epoch 38, Loss: 0.6326, Accuracy: 0.9961
# Epoch 39, Loss: 0.6316, Accuracy: 0.9939
# Epoch 40, Loss: 0.6351, Accuracy: 0.9944
# Epoch 41, Loss: 0.6307, Accuracy: 0.9905
# Epoch 42, Loss: 0.6317, Accuracy: 0.9939
# Epoch 43, Loss: 0.6324, Accuracy: 0.9927
# Epoch 44, Loss: 0.6332, Accuracy: 0.9922
# Epoch 45, Loss: 0.6338, Accuracy: 0.9911
# Epoch 46, Loss: 0.6349, Accuracy: 0.9933
# Epoch 47, Loss: 0.6325, Accuracy: 0.9944
# Best Epoch: 37, Best Valid Acc: 0.9960893854748604
# Valid Acc (with Epoch valid set) on Loaded Best Model: 0.9960893854748604
# Final Acc (with TEST set) on Loaded Best Model: 0.9956140350877193 (time: 0.004611325520341114)
#
# === case=4_2, backbone=resnet34 ===
# idx: 20, loss for current idx: 0.888032
# idx: 40, loss for current idx: 0.780522
# idx: 60, loss for current idx: 0.991279
# idx: 80, loss for current idx: 0.803228
# idx: 100, loss for current idx: 0.866092
# idx: 120, loss for current idx: 0.760149
# idx: 140, loss for current idx: 0.663671
# idx: 160, loss for current idx: 0.943135
# idx: 180, loss for current idx: 0.700660
# idx: 200, loss for current idx: 0.781784
# idx: 220, loss for current idx: 0.634498
# idx: 240, loss for current idx: 0.663107
# idx: 260, loss for current idx: 0.760932
# idx: 280, loss for current idx: 0.724431
# idx: 300, loss for current idx: 0.694718
# idx: 320, loss for current idx: 0.712591
# idx: 340, loss for current idx: 0.721528
# idx: 360, loss for current idx: 0.647818
# idx: 380, loss for current idx: 0.751599
# idx: 400, loss for current idx: 0.651400
# idx: 420, loss for current idx: 0.629131
# idx: 440, loss for current idx: 0.720480
# idx: 460, loss for current idx: 0.627366
# idx: 480, loss for current idx: 0.682535
# idx: 500, loss for current idx: 0.694788
# best model updated
# Epoch 1, Loss: 0.7425, Accuracy: 0.9536
# best model updated
# Epoch 2, Loss: 0.6646, Accuracy: 0.9698
# best model updated
# Epoch 3, Loss: 0.6556, Accuracy: 0.9732
# best model updated
# Epoch 4, Loss: 0.6530, Accuracy: 0.9872
# Epoch 5, Loss: 0.6560, Accuracy: 0.9832
# Epoch 6, Loss: 0.6457, Accuracy: 0.9726
# Epoch 7, Loss: 0.6448, Accuracy: 0.9749
# Epoch 8, Loss: 0.6455, Accuracy: 0.9810
# Epoch 9, Loss: 0.6467, Accuracy: 0.9872
# best model updated
# Epoch 10, Loss: 0.6523, Accuracy: 0.9888
# best model updated
# Epoch 11, Loss: 0.6398, Accuracy: 0.9905
# best model updated
# Epoch 12, Loss: 0.6384, Accuracy: 0.9922
# Epoch 13, Loss: 0.6399, Accuracy: 0.9905
# Epoch 14, Loss: 0.6440, Accuracy: 0.9793
# Epoch 15, Loss: 0.6513, Accuracy: 0.9637
# Epoch 16, Loss: 0.6421, Accuracy: 0.9860
# Epoch 17, Loss: 0.6391, Accuracy: 0.9844
# Epoch 18, Loss: 0.6401, Accuracy: 0.9860
# Epoch 19, Loss: 0.6382, Accuracy: 0.9894
# Epoch 20, Loss: 0.6363, Accuracy: 0.9877
# Epoch 21, Loss: 0.6391, Accuracy: 0.9804
# Best Epoch: 11, Best Valid Acc: 0.9921787709497206
# Valid Acc (with Epoch valid set) on Loaded Best Model: 0.9921787709497206
# Final Acc (with TEST set) on Loaded Best Model: 0.9912280701754386 (time: 0.008352256590320219)
#
# === case=4_2, backbone=resnet50 ===
# idx: 20, loss for current idx: 0.871474
# idx: 40, loss for current idx: 0.873526
# idx: 60, loss for current idx: 0.911501
# idx: 80, loss for current idx: 0.816459
# idx: 100, loss for current idx: 0.758914
# idx: 120, loss for current idx: 0.756382
# idx: 140, loss for current idx: 0.627119
# idx: 160, loss for current idx: 0.648004
# idx: 180, loss for current idx: 0.720027
# idx: 200, loss for current idx: 0.672645
# idx: 220, loss for current idx: 0.834767
# idx: 240, loss for current idx: 0.710220
# idx: 260, loss for current idx: 0.710719
# idx: 280, loss for current idx: 0.753002
# idx: 300, loss for current idx: 0.657877
# idx: 320, loss for current idx: 0.662258
# idx: 340, loss for current idx: 0.651427
# idx: 360, loss for current idx: 0.667069
# idx: 380, loss for current idx: 0.673228
# idx: 400, loss for current idx: 0.691251
# idx: 420, loss for current idx: 0.733660
# idx: 440, loss for current idx: 0.659410
# idx: 460, loss for current idx: 0.626736
# idx: 480, loss for current idx: 0.705706
# idx: 500, loss for current idx: 0.647779
# best model updated
# Epoch 1, Loss: 0.7554, Accuracy: 0.9503
# best model updated
# Epoch 2, Loss: 0.6700, Accuracy: 0.9788
# best model updated
# Epoch 3, Loss: 0.6535, Accuracy: 0.9821
# Epoch 4, Loss: 0.6466, Accuracy: 0.9704
# best model updated
# Epoch 5, Loss: 0.6469, Accuracy: 0.9872
# Epoch 6, Loss: 0.6479, Accuracy: 0.9866
# best model updated
# Epoch 7, Loss: 0.6413, Accuracy: 0.9877
# Epoch 8, Loss: 0.6451, Accuracy: 0.9737
# Epoch 9, Loss: 0.6532, Accuracy: 0.9726
# Epoch 10, Loss: 0.6494, Accuracy: 0.9827
# Epoch 11, Loss: 0.6398, Accuracy: 0.9866
# Epoch 12, Loss: 0.6397, Accuracy: 0.9877
# Epoch 13, Loss: 0.6463, Accuracy: 0.9827
# Epoch 14, Loss: 0.6518, Accuracy: 0.9799
# Epoch 15, Loss: 0.6450, Accuracy: 0.9760
# Epoch 16, Loss: 0.6554, Accuracy: 0.9793
# Best Epoch: 6, Best Valid Acc: 0.9877094972067039
# Valid Acc (with Epoch valid set) on Loaded Best Model: 0.9877094972067039
# Final Acc (with TEST set) on Loaded Best Model: 0.9871794871794872 (time: 0.010986325561359365)

# %%
result_df = pd.DataFrame(result_dict)
result_df
# Out:
#     backbone case  accuracy  inference_time
# 0   resnet18    1  0.994602        0.004782
# 1   resnet34    1  0.993590        0.010598
# 2   resnet50    1  0.995951        0.010913
# 3   resnet18    2  0.993590        0.002491
# 4   resnet34    2  0.996289        0.004127
# 5   resnet50    2  0.992240        0.005393
# 6   resnet18    3  0.996289        0.002437
# 7   resnet34    3  0.993590        0.004143
# 8   resnet50    3  0.991228        0.005534
# 9   resnet18  4_1  0.996964        0.004743
# 10  resnet34  4_1  0.992578        0.008111
# 11  resnet50  4_1  0.996289        0.010881
# 12  resnet18  4_2  0.995614        0.004611
# 13  resnet34  4_2  0.991228        0.008352
# 14  resnet50  4_2  0.987179        0.010986

# %%
result_df.to_csv('result_experiment_2.csv')
