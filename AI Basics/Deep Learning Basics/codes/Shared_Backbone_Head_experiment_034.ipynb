# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms

import plotly.graph_objects as go

import random
import pandas as pd
import numpy as np

# !pip install torchinfo
from torchinfo import summary
# Out:
# Collecting torchinfo
#   Downloading torchinfo-1.8.0-py3-none-any.whl.metadata (21 kB)
# Downloading torchinfo-1.8.0-py3-none-any.whl (23 kB)
# Installing collected packages: torchinfo
# Successfully installed torchinfo-1.8.0

# %%
# 경고 미 표시

import warnings
warnings.filterwarnings('ignore')

# %%
# Random Seed 고정 (학습 반복 시행 시에도 동일한 결과가 나오도록)

seed = 20251002

random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)
torch.cuda.manual_seed_all(seed)

# %%
# 데이터셋 로딩

transform = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.5,), (0.5,))])

train_dataset = torchvision.datasets.MNIST(root='./data',
                                           train=True,
                                           transform=transform,
                                           download=True)

test_dataset = torchvision.datasets.MNIST(root='./data',
                                          train=False,
                                          transform=transform,
                                          download=True)
# Out:
# 100%|██████████| 9.91M/9.91M [00:00<00:00, 20.3MB/s]
# 100%|██████████| 28.9k/28.9k [00:00<00:00, 534kB/s]
# 100%|██████████| 1.65M/1.65M [00:00<00:00, 4.63MB/s]
# 100%|██████████| 4.54k/4.54k [00:00<00:00, 14.2MB/s]

# %% [markdown]
# **1. 데이터셋 분석**

# %%
# 데이터셋 로딩

from torch.utils.data import DataLoader

BATCH_SIZE = 32

train_loader = DataLoader(train_dataset,
                          batch_size=BATCH_SIZE,
                          shuffle=True)

test_loader = DataLoader(test_dataset,
                         batch_size=BATCH_SIZE,
                         shuffle=False)

# %%
# 클래스 불균형 분석

# 학습 데이터
train_labels = torch.tensor(train_dataset.targets)
train_class_counts = torch.bincount(train_labels)
print(f'train data : {train_class_counts}')

# 테스트 데이터
test_labels = torch.tensor(test_dataset.targets)
test_class_counts = torch.bincount(test_labels)
print(f'test  data : {test_class_counts}')

NUM_CLASSES = len(train_class_counts)
# Out:
# train data : tensor([5923, 6742, 5958, 6131, 5842, 5421, 5918, 6265, 5851, 5949])
# test  data : tensor([ 980, 1135, 1032, 1010,  982,  892,  958, 1028,  974, 1009])

# %%
# 클래스 불균형 분석 (percentage)

train_class_percentage = np.array(train_class_counts) * 100.0 / sum(train_class_counts)

train_y_distrib = pd.DataFrame({'class': list(range(NUM_CLASSES)),
                                'count': train_class_counts,
                                'percentage (%)': train_class_percentage})

train_y_distrib
# Out:
#    class  count  percentage (%)
# 0      0   5923        9.871667
# 1      1   6742       11.236667
# 2      2   5958        9.930000
# 3      3   6131       10.218333
# 4      4   5842        9.736667
# 5      5   5421        9.035000
# 6      6   5918        9.863333
# 7      7   6265       10.441667
# 8      8   5851        9.751667
# 9      9   5949        9.915000

# %%
test_class_percentage = np.array(test_class_counts) * 100.0 / sum(test_class_counts)

test_y_distrib = pd.DataFrame({'class': list(range(NUM_CLASSES)),
                               'count': test_class_counts,
                               'percentage (%)': test_class_percentage})

test_y_distrib
# Out:
#    class  count  percentage (%)
# 0      0    980            9.80
# 1      1   1135           11.35
# 2      2   1032           10.32
# 3      3   1010           10.10
# 4      4    982            9.82
# 5      5    892            8.92
# 6      6    958            9.58
# 7      7   1028           10.28
# 8      8    974            9.74
# 9      9   1009           10.09

# %% [markdown]
# **2. 0, 1, 2 숫자 데이터만 추출**

# %%
from torch.utils.data import Subset

# train dataset
train_targets = torch.tensor(train_dataset.targets)
train_mask = (train_targets == 0) | (train_targets == 3) | (train_targets == 4)
train_indices = torch.where(train_mask)[0]

train_subset = Subset(train_dataset, train_indices)

# test dataset
test_targets = torch.tensor(test_dataset.targets)
test_mask = (test_targets == 0) | (test_targets == 3) | (test_targets == 4)
test_indices = torch.where(test_mask)[0]

test_subset = Subset(test_dataset, test_indices)

# %%
# train, test Data Loader 갱신

train_subset_loader = DataLoader(train_subset,
                                 batch_size=BATCH_SIZE,
                                 shuffle=True)

test_subset_loader = DataLoader(test_subset,
                                batch_size=BATCH_SIZE,
                                shuffle=False)

# %%
# train, test Data Loader 의 class 가 0, 3, 4 뿐인지 확인

train_subset_labels = train_subset.dataset.targets[train_subset.indices]
train_subset_class_counts = torch.bincount(train_subset_labels)
print(f'train data (subset) [0,3,4] : {train_subset_class_counts}')

test_subset_labels = test_subset.dataset.targets[test_subset.indices]
test_subset_class_counts = torch.bincount(test_subset_labels)
print(f'test  data (subset) [0,3,4] : {test_subset_class_counts}')
# Out:
# train data (subset) [0,3,4] : tensor([5923,    0,    0, 6131, 5842])
# test  data (subset) [0,3,4] : tensor([ 980,    0,    0, 1010,  982])

# %% [markdown]
# **3. CNN 모델 정의**

# %%
# 1. Non-Shared backbone & Shared head

class CNN_CASE_1(nn.Module):
    def __init__(self, backbone_1, backbone_2):
        super(CNN_CASE_1, self).__init__()

        self.backbone_1 = backbone_1
        self.backbone_2 = backbone_2
        self.final_linear = nn.Linear(2000, 3)
        self.final_softmax = nn.Softmax(dim=1)

    def forward(self, x):
        x1 = self.backbone_1(x)
        x2 = self.backbone_2(x)
        x = torch.concatenate([x1, x2], dim=1)

        x = self.final_linear(x)
        x = self.final_softmax(x)

        return x

# %%
# 2. Shared backbone & Shared head

class CNN_CASE_2(nn.Module):
    def __init__(self, backbone):
        super(CNN_CASE_2, self).__init__()

        self.backbone = backbone
        self.final_linear = nn.Linear(1000, 3)
        self.final_softmax = nn.Softmax(dim=1)

    def forward(self, x):
        x = self.backbone(x)
        x = self.final_linear(x)
        x = self.final_softmax(x)

        return x

# %%
# 3. Shared backbone & Non-Shared head

class CNN_CASE_3(nn.Module):
    def __init__(self, backbone):
        super(CNN_CASE_3, self).__init__()

        self.backbone = backbone
        self.final_linear_1 = nn.Linear(1000, 2)
        self.final_linear_2 = nn.Linear(1000, 2)
        self.final_softmax = nn.Softmax(dim=1)

    def forward(self, x):
        x = self.backbone(x)
        x1 = self.final_linear_1(x)
        x2 = self.final_linear_2(x)
        x1 = self.final_softmax(x1)
        x2 = self.final_softmax(x2)

        return x1, x2

# %%
# 4. Non-Shared backbone & Non-Shared head (4-1)

class CNN_CASE_4_1(nn.Module):
    def __init__(self, backbone_1, backbone_2):
        super(CNN_CASE_4_1, self).__init__()

        self.backbone_1 = backbone_1
        self.backbone_2 = backbone_2
        self.final_linear_1 = nn.Linear(2000, 2)
        self.final_linear_2 = nn.Linear(2000, 2)
        self.final_softmax = nn.Softmax(dim=1)

    def forward(self, x):
        x11 = self.backbone_1(x)
        x12 = self.backbone_2(x)
        x = torch.concatenate([x11, x12], dim=1)

        x21 = self.final_linear_1(x)
        x22 = self.final_linear_2(x)
        x21 = self.final_softmax(x21)
        x22 = self.final_softmax(x22)

        return x21, x22

# %%
# 5. Non-Shared backbone & Non-Shared head (4-2)

class CNN_CASE_4_2(nn.Module):
    def __init__(self, backbone_1, backbone_2):
        super(CNN_CASE_4_2, self).__init__()

        self.backbone_1 = backbone_1
        self.backbone_2 = backbone_2
        self.final_linear_1 = nn.Linear(1000, 2)
        self.final_linear_2 = nn.Linear(1000, 2)
        self.final_softmax = nn.Softmax(dim=1)

    def forward(self, x):
        x11 = self.backbone_1(x)
        x12 = self.backbone_2(x)
        x21 = self.final_linear_1(x11)
        x22 = self.final_linear_2(x12)
        x21 = self.final_softmax(x21)
        x22 = self.final_softmax(x22)

        return x21, x22

# %% [markdown]
# **4. backbone model 로딩**

# %%
import torchvision.models as models

def define_model(backbone_name, case_name, device):

    # model count
    if case_name in ['1', '4_1', '4_2']:
        model_count = 2
    else:
        model_count = 1

    # load pre-trained backbone model
    pretrained_models = []

    for _ in range(model_count):
        if backbone_name == 'resnet18':
            pretrained_model = models.resnet18(pretrained=True)

        elif backbone_name == 'resnet34':
            pretrained_model = models.resnet34(pretrained=True)

        else:  # resnet50
            pretrained_model = models.resnet50(pretrained=True)

        pretrained_model.conv1 = torch.nn.Conv2d(1, 64,
                                                 kernel_size=(7, 7),
                                                 stride=(2, 2),
                                                 padding=(3, 3),
                                                 bias=False)
        pretrained_models.append(pretrained_model)

    # define full model
    if case_name == '1':
        model = CNN_CASE_1(backbone_1=pretrained_models[0],
                           backbone_2=pretrained_models[1])

    elif case_name == '2':
        model = CNN_CASE_2(backbone=pretrained_models[0])

    elif case_name == '3':
        model = CNN_CASE_3(backbone=pretrained_models[0])

    elif case_name == '4_1':
        model = CNN_CASE_4_1(backbone_1=pretrained_models[0],
                             backbone_2=pretrained_models[1])

    elif case_name == '4_2':
        model = CNN_CASE_4_2(backbone_1=pretrained_models[0],
                             backbone_2=pretrained_models[1])

    # device & optimizer & scheduler setting
    model.to(device)
    model.optimizer = torch.optim.AdamW(model.parameters(), lr=0.0001)
    model.scheduler = torch.optim.lr_scheduler.ExponentialLR(optimizer=model.optimizer,
                                                             gamma=0.95)

    return model

# %% [markdown]
# **5. 모델 구조 출력**

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
input_size=(BATCH_SIZE, 1, 28, 28)

# %%
temp_backbone_name = 'resnet18'

# %%
# 1. Non-Shared backbone & Shared head

model_case_1 = define_model(temp_backbone_name, case_name='1', device=device)
print(summary(model=model_case_1, input_size=input_size))
# Out:
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100%|██████████| 44.7M/44.7M [00:00<00:00, 120MB/s]
# ===============================================================================================
# Layer (type:depth-idx)                        Output Shape              Param #
# ===============================================================================================
# CNN_CASE_1                                    [32, 3]                   --
# ├─ResNet: 1-1                                 [32, 1000]                --
# │    └─Conv2d: 2-1                            [32, 64, 14, 14]          3,136
# │    └─BatchNorm2d: 2-2                       [32, 64, 14, 14]          128
# │    └─ReLU: 2-3                              [32, 64, 14, 14]          --
# │    └─MaxPool2d: 2-4                         [32, 64, 7, 7]            --
# │    └─Sequential: 2-5                        [32, 64, 7, 7]            --
# │    │    └─BasicBlock: 3-1                   [32, 64, 7, 7]            73,984
# │    │    └─BasicBlock: 3-2                   [32, 64, 7, 7]            73,984
# │    └─Sequential: 2-6                        [32, 128, 4, 4]           --
# │    │    └─BasicBlock: 3-3                   [32, 128, 4, 4]           230,144
# │    │    └─BasicBlock: 3-4                   [32, 128, 4, 4]           295,424
# │    └─Sequential: 2-7                        [32, 256, 2, 2]           --
# │    │    └─BasicBlock: 3-5                   [32, 256, 2, 2]           919,040
# │    │    └─BasicBlock: 3-6                   [32, 256, 2, 2]           1,180,672
# │    └─Sequential: 2-8                        [32, 512, 1, 1]           --
# │    │    └─BasicBlock: 3-7                   [32, 512, 1, 1]           3,673,088
# │    │    └─BasicBlock: 3-8                   [32, 512, 1, 1]           4,720,640
# │    └─AdaptiveAvgPool2d: 2-9                 [32, 512, 1, 1]           --
# │    └─Linear: 2-10                           [32, 1000]                513,000
# ├─ResNet: 1-2                                 [32, 1000]                --
# │    └─Conv2d: 2-11                           [32, 64, 14, 14]          3,136
# │    └─BatchNorm2d: 2-12                      [32, 64, 14, 14]          128
# │    └─ReLU: 2-13                             [32, 64, 14, 14]          --
# │    └─MaxPool2d: 2-14                        [32, 64, 7, 7]            --
# │    └─Sequential: 2-15                       [32, 64, 7, 7]            --
# │    │    └─BasicBlock: 3-9                   [32, 64, 7, 7]            73,984
# │    │    └─BasicBlock: 3-10                  [32, 64, 7, 7]            73,984
# │    └─Sequential: 2-16                       [32, 128, 4, 4]           --
# │    │    └─BasicBlock: 3-11                  [32, 128, 4, 4]           230,144
# │    │    └─BasicBlock: 3-12                  [32, 128, 4, 4]           295,424
# │    └─Sequential: 2-17                       [32, 256, 2, 2]           --
# │    │    └─BasicBlock: 3-13                  [32, 256, 2, 2]           919,040
# │    │    └─BasicBlock: 3-14                  [32, 256, 2, 2]           1,180,672
# │    └─Sequential: 2-18                       [32, 512, 1, 1]           --
# │    │    └─BasicBlock: 3-15                  [32, 512, 1, 1]           3,673,088
# │    │    └─BasicBlock: 3-16                  [32, 512, 1, 1]           4,720,640
# │    └─AdaptiveAvgPool2d: 2-19                [32, 512, 1, 1]           --
# │    └─Linear: 2-20                           [32, 1000]                513,000
# ├─Linear: 1-3                                 [32, 3]                   6,003
# ├─Softmax: 1-4                                [32, 3]                   --
# ===============================================================================================
# Total params: 23,372,483
# Trainable params: 23,372,483
# Non-trainable params: 0
# Total mult-adds (Units.GIGABYTES): 2.15
# ===============================================================================================
# Input size (MB): 0.10
# Forward/backward pass size (MB): 44.55
# Params size (MB): 93.49
# Estimated Total Size (MB): 138.14
# ===============================================================================================

# %%
# 2. Shared backbone & Shared head

model_case_2 = define_model(temp_backbone_name, case_name='2', device=device)
print(summary(model=model_case_2, input_size=input_size))
# Out:
# ===============================================================================================
# Layer (type:depth-idx)                        Output Shape              Param #
# ===============================================================================================
# CNN_CASE_2                                    [32, 3]                   --
# ├─ResNet: 1-1                                 [32, 1000]                --
# │    └─Conv2d: 2-1                            [32, 64, 14, 14]          3,136
# │    └─BatchNorm2d: 2-2                       [32, 64, 14, 14]          128
# │    └─ReLU: 2-3                              [32, 64, 14, 14]          --
# │    └─MaxPool2d: 2-4                         [32, 64, 7, 7]            --
# │    └─Sequential: 2-5                        [32, 64, 7, 7]            --
# │    │    └─BasicBlock: 3-1                   [32, 64, 7, 7]            73,984
# │    │    └─BasicBlock: 3-2                   [32, 64, 7, 7]            73,984
# │    └─Sequential: 2-6                        [32, 128, 4, 4]           --
# │    │    └─BasicBlock: 3-3                   [32, 128, 4, 4]           230,144
# │    │    └─BasicBlock: 3-4                   [32, 128, 4, 4]           295,424
# │    └─Sequential: 2-7                        [32, 256, 2, 2]           --
# │    │    └─BasicBlock: 3-5                   [32, 256, 2, 2]           919,040
# │    │    └─BasicBlock: 3-6                   [32, 256, 2, 2]           1,180,672
# │    └─Sequential: 2-8                        [32, 512, 1, 1]           --
# │    │    └─BasicBlock: 3-7                   [32, 512, 1, 1]           3,673,088
# │    │    └─BasicBlock: 3-8                   [32, 512, 1, 1]           4,720,640
# │    └─AdaptiveAvgPool2d: 2-9                 [32, 512, 1, 1]           --
# │    └─Linear: 2-10                           [32, 1000]                513,000
# ├─Linear: 1-2                                 [32, 3]                   3,003
# ├─Softmax: 1-3                                [32, 3]                   --
# ===============================================================================================
# Total params: 11,686,243
# Trainable params: 11,686,243
# Non-trainable params: 0
# Total mult-adds (Units.GIGABYTES): 1.07
# ===============================================================================================
# Input size (MB): 0.10
# Forward/backward pass size (MB): 22.28
# Params size (MB): 46.74
# Estimated Total Size (MB): 69.12
# ===============================================================================================

# %%
# 3. Shared backbone & Non-Shared head

model_case_3 = define_model(temp_backbone_name, case_name='3', device=device)
print(summary(model=model_case_3, input_size=input_size))
# Out:
# ===============================================================================================
# Layer (type:depth-idx)                        Output Shape              Param #
# ===============================================================================================
# CNN_CASE_3                                    [32, 2]                   --
# ├─ResNet: 1-1                                 [32, 1000]                --
# │    └─Conv2d: 2-1                            [32, 64, 14, 14]          3,136
# │    └─BatchNorm2d: 2-2                       [32, 64, 14, 14]          128
# │    └─ReLU: 2-3                              [32, 64, 14, 14]          --
# │    └─MaxPool2d: 2-4                         [32, 64, 7, 7]            --
# │    └─Sequential: 2-5                        [32, 64, 7, 7]            --
# │    │    └─BasicBlock: 3-1                   [32, 64, 7, 7]            73,984
# │    │    └─BasicBlock: 3-2                   [32, 64, 7, 7]            73,984
# │    └─Sequential: 2-6                        [32, 128, 4, 4]           --
# │    │    └─BasicBlock: 3-3                   [32, 128, 4, 4]           230,144
# │    │    └─BasicBlock: 3-4                   [32, 128, 4, 4]           295,424
# │    └─Sequential: 2-7                        [32, 256, 2, 2]           --
# │    │    └─BasicBlock: 3-5                   [32, 256, 2, 2]           919,040
# │    │    └─BasicBlock: 3-6                   [32, 256, 2, 2]           1,180,672
# │    └─Sequential: 2-8                        [32, 512, 1, 1]           --
# │    │    └─BasicBlock: 3-7                   [32, 512, 1, 1]           3,673,088
# │    │    └─BasicBlock: 3-8                   [32, 512, 1, 1]           4,720,640
# │    └─AdaptiveAvgPool2d: 2-9                 [32, 512, 1, 1]           --
# │    └─Linear: 2-10                           [32, 1000]                513,000
# ├─Linear: 1-2                                 [32, 2]                   2,002
# ├─Linear: 1-3                                 [32, 2]                   2,002
# ├─Softmax: 1-4                                [32, 2]                   --
# ├─Softmax: 1-5                                [32, 2]                   --
# ===============================================================================================
# Total params: 11,687,244
# Trainable params: 11,687,244
# Non-trainable params: 0
# Total mult-adds (Units.GIGABYTES): 1.07
# ===============================================================================================
# Input size (MB): 0.10
# Forward/backward pass size (MB): 22.28
# Params size (MB): 46.75
# Estimated Total Size (MB): 69.13
# ===============================================================================================

# %%
# 4. Non-Shared backbone & Non-Shared head (4-1)

model_case_4_1 = define_model(temp_backbone_name, case_name='4_1', device=device)
print(summary(model=model_case_4_1, input_size=input_size))
# Out:
# ===============================================================================================
# Layer (type:depth-idx)                        Output Shape              Param #
# ===============================================================================================
# CNN_CASE_4_1                                  [32, 2]                   --
# ├─ResNet: 1-1                                 [32, 1000]                --
# │    └─Conv2d: 2-1                            [32, 64, 14, 14]          3,136
# │    └─BatchNorm2d: 2-2                       [32, 64, 14, 14]          128
# │    └─ReLU: 2-3                              [32, 64, 14, 14]          --
# │    └─MaxPool2d: 2-4                         [32, 64, 7, 7]            --
# │    └─Sequential: 2-5                        [32, 64, 7, 7]            --
# │    │    └─BasicBlock: 3-1                   [32, 64, 7, 7]            73,984
# │    │    └─BasicBlock: 3-2                   [32, 64, 7, 7]            73,984
# │    └─Sequential: 2-6                        [32, 128, 4, 4]           --
# │    │    └─BasicBlock: 3-3                   [32, 128, 4, 4]           230,144
# │    │    └─BasicBlock: 3-4                   [32, 128, 4, 4]           295,424
# │    └─Sequential: 2-7                        [32, 256, 2, 2]           --
# │    │    └─BasicBlock: 3-5                   [32, 256, 2, 2]           919,040
# │    │    └─BasicBlock: 3-6                   [32, 256, 2, 2]           1,180,672
# │    └─Sequential: 2-8                        [32, 512, 1, 1]           --
# │    │    └─BasicBlock: 3-7                   [32, 512, 1, 1]           3,673,088
# │    │    └─BasicBlock: 3-8                   [32, 512, 1, 1]           4,720,640
# │    └─AdaptiveAvgPool2d: 2-9                 [32, 512, 1, 1]           --
# │    └─Linear: 2-10                           [32, 1000]                513,000
# ├─ResNet: 1-2                                 [32, 1000]                --
# │    └─Conv2d: 2-11                           [32, 64, 14, 14]          3,136
# │    └─BatchNorm2d: 2-12                      [32, 64, 14, 14]          128
# │    └─ReLU: 2-13                             [32, 64, 14, 14]          --
# │    └─MaxPool2d: 2-14                        [32, 64, 7, 7]            --
# │    └─Sequential: 2-15                       [32, 64, 7, 7]            --
# │    │    └─BasicBlock: 3-9                   [32, 64, 7, 7]            73,984
# │    │    └─BasicBlock: 3-10                  [32, 64, 7, 7]            73,984
# │    └─Sequential: 2-16                       [32, 128, 4, 4]           --
# │    │    └─BasicBlock: 3-11                  [32, 128, 4, 4]           230,144
# │    │    └─BasicBlock: 3-12                  [32, 128, 4, 4]           295,424
# │    └─Sequential: 2-17                       [32, 256, 2, 2]           --
# │    │    └─BasicBlock: 3-13                  [32, 256, 2, 2]           919,040
# │    │    └─BasicBlock: 3-14                  [32, 256, 2, 2]           1,180,672
# │    └─Sequential: 2-18                       [32, 512, 1, 1]           --
# │    │    └─BasicBlock: 3-15                  [32, 512, 1, 1]           3,673,088
# │    │    └─BasicBlock: 3-16                  [32, 512, 1, 1]           4,720,640
# │    └─AdaptiveAvgPool2d: 2-19                [32, 512, 1, 1]           --
# │    └─Linear: 2-20                           [32, 1000]                513,000
# ├─Linear: 1-3                                 [32, 2]                   4,002
# ├─Linear: 1-4                                 [32, 2]                   4,002
# ├─Softmax: 1-5                                [32, 2]                   --
# ├─Softmax: 1-6                                [32, 2]                   --
# ===============================================================================================
# Total params: 23,374,484
# Trainable params: 23,374,484
# Non-trainable params: 0
# Total mult-adds (Units.GIGABYTES): 2.15
# ===============================================================================================
# Input size (MB): 0.10
# Forward/backward pass size (MB): 44.55
# Params size (MB): 93.50
# Estimated Total Size (MB): 138.15
# ===============================================================================================

# %%
# 5. Non-Shared backbone & Non-Shared head (4-2)

model_case_4_2 = define_model(temp_backbone_name, case_name='4_2', device=device)
print(summary(model=model_case_4_2, input_size=input_size))
# Out:
# ===============================================================================================
# Layer (type:depth-idx)                        Output Shape              Param #
# ===============================================================================================
# CNN_CASE_4_2                                  [32, 2]                   --
# ├─ResNet: 1-1                                 [32, 1000]                --
# │    └─Conv2d: 2-1                            [32, 64, 14, 14]          3,136
# │    └─BatchNorm2d: 2-2                       [32, 64, 14, 14]          128
# │    └─ReLU: 2-3                              [32, 64, 14, 14]          --
# │    └─MaxPool2d: 2-4                         [32, 64, 7, 7]            --
# │    └─Sequential: 2-5                        [32, 64, 7, 7]            --
# │    │    └─BasicBlock: 3-1                   [32, 64, 7, 7]            73,984
# │    │    └─BasicBlock: 3-2                   [32, 64, 7, 7]            73,984
# │    └─Sequential: 2-6                        [32, 128, 4, 4]           --
# │    │    └─BasicBlock: 3-3                   [32, 128, 4, 4]           230,144
# │    │    └─BasicBlock: 3-4                   [32, 128, 4, 4]           295,424
# │    └─Sequential: 2-7                        [32, 256, 2, 2]           --
# │    │    └─BasicBlock: 3-5                   [32, 256, 2, 2]           919,040
# │    │    └─BasicBlock: 3-6                   [32, 256, 2, 2]           1,180,672
# │    └─Sequential: 2-8                        [32, 512, 1, 1]           --
# │    │    └─BasicBlock: 3-7                   [32, 512, 1, 1]           3,673,088
# │    │    └─BasicBlock: 3-8                   [32, 512, 1, 1]           4,720,640
# │    └─AdaptiveAvgPool2d: 2-9                 [32, 512, 1, 1]           --
# │    └─Linear: 2-10                           [32, 1000]                513,000
# ├─ResNet: 1-2                                 [32, 1000]                --
# │    └─Conv2d: 2-11                           [32, 64, 14, 14]          3,136
# │    └─BatchNorm2d: 2-12                      [32, 64, 14, 14]          128
# │    └─ReLU: 2-13                             [32, 64, 14, 14]          --
# │    └─MaxPool2d: 2-14                        [32, 64, 7, 7]            --
# │    └─Sequential: 2-15                       [32, 64, 7, 7]            --
# │    │    └─BasicBlock: 3-9                   [32, 64, 7, 7]            73,984
# │    │    └─BasicBlock: 3-10                  [32, 64, 7, 7]            73,984
# │    └─Sequential: 2-16                       [32, 128, 4, 4]           --
# │    │    └─BasicBlock: 3-11                  [32, 128, 4, 4]           230,144
# │    │    └─BasicBlock: 3-12                  [32, 128, 4, 4]           295,424
# │    └─Sequential: 2-17                       [32, 256, 2, 2]           --
# │    │    └─BasicBlock: 3-13                  [32, 256, 2, 2]           919,040
# │    │    └─BasicBlock: 3-14                  [32, 256, 2, 2]           1,180,672
# │    └─Sequential: 2-18                       [32, 512, 1, 1]           --
# │    │    └─BasicBlock: 3-15                  [32, 512, 1, 1]           3,673,088
# │    │    └─BasicBlock: 3-16                  [32, 512, 1, 1]           4,720,640
# │    └─AdaptiveAvgPool2d: 2-19                [32, 512, 1, 1]           --
# │    └─Linear: 2-20                           [32, 1000]                513,000
# ├─Linear: 1-3                                 [32, 2]                   2,002
# ├─Linear: 1-4                                 [32, 2]                   2,002
# ├─Softmax: 1-5                                [32, 2]                   --
# ├─Softmax: 1-6                                [32, 2]                   --
# ===============================================================================================
# Total params: 23,370,484
# Trainable params: 23,370,484
# Non-trainable params: 0
# Total mult-adds (Units.GIGABYTES): 2.15
# ===============================================================================================
# Input size (MB): 0.10
# Forward/backward pass size (MB): 44.55
# Params size (MB): 93.48
# Estimated Total Size (MB): 138.14
# ===============================================================================================

# %% [markdown]
# **6. 데이터셋 분리**
#
# * Train Data -> Train Data + Valid Data

# %%
# dataset size

num_tv = sum(train_subset_class_counts)
num_valid = int(0.1 * num_tv)
num_train = num_tv - num_valid

# %%
# 데이터셋 분리

from torch.utils.data import random_split

train_dataset, valid_dataset = random_split(train_subset, [num_train, num_valid])

# %%
# {0,1,2} -> {0,3,4} Mapping 된 DataLoader 생성

from torch.utils.data import Dataset

class MappedDataset(Dataset):
    def __init__(self, dataset):
        self.dataset = dataset

    def __len__(self):
        return len(self.dataset)

    def __getitem__(self, idx):
        img, target = self.dataset[idx]
        target_mapping = {0: 0, 3: 1, 4: 2}
        target = target_mapping[target]

        return img, target

# %%
# DataLoader 생성

train_dataset_loader = DataLoader(MappedDataset(train_dataset),
                                  batch_size=BATCH_SIZE,
                                  shuffle=True)

valid_dataset_loader = DataLoader(MappedDataset(valid_dataset),
                                  batch_size=BATCH_SIZE,
                                  shuffle=False)

test_dataset_loader = DataLoader(MappedDataset(test_subset),
                                 batch_size=BATCH_SIZE,
                                 shuffle=False)

# %%
# {0,3} vs. {4} / {0,4} vs. {3} Split 된 DataLoader 생성

class DualOutputDataset(Dataset):
    def __init__(self, dataset):
        self.dataset = dataset

    def __len__(self):
        return len(self.dataset)

    def __getitem__(self, idx):
        img, target = self.dataset[idx]
        target1_mapping = {0: 0, 3: 0, 4: 1}
        target2_mapping = {0: 0, 3: 1, 4: 0}

        target1 = target1_mapping[target]
        target2 = target2_mapping[target]

        return img, [target1, target2]

# %%
# Dual Output Dataset 생성

train_01_02_dataset_loader = DataLoader(DualOutputDataset(train_dataset),
                                        batch_size=BATCH_SIZE,
                                        shuffle=True)

valid_01_02_dataset_loader = DataLoader(DualOutputDataset(valid_dataset),
                                        batch_size=BATCH_SIZE,
                                        shuffle=False)

test_01_02_dataset_loader = DataLoader(DualOutputDataset(test_subset),
                                       batch_size=BATCH_SIZE,
                                       shuffle=False)

# %% [markdown]
# **7. 모델 학습 함수 정의**

# %%
MAX_EPOCHS = 9999
EARLY_STOPPING_ROUNDS = 10  # Early Stopping Patience (epochs)

# %%
# dual labels -> PyTorch tensor

def convert_to_tensor(labels):
    labels[0] = list(labels[0])
    labels[1] = list(labels[1])
    labels_tensor = torch.tensor(labels)
    labels_tensor = labels_tensor.transpose(0, 1)

    return labels_tensor

# %%
# 모델 학습 실시

# args :
# - model           : 학습할 모델
# - train_loader    : Training Data Loader
# - train_loss_list : 각 epoch 에서의 train loss 기록
# - is_dual_head    : 신경망 출력값, 즉 MLP Head 가 2개인지의 여부

# returns :
# - train_loss : 모델의 Train Loss

def run_train(model, train_loader, train_loss_list, is_dual_head, verbose):
    model.train()
    train_loss = 0.0
    train_idx = 0

    for images, labels in train_loader:
        if is_dual_head:
            labels = convert_to_tensor(labels)
        images, labels = images.to(device), labels.to(device)

        # train 실시
        model.optimizer.zero_grad()
        outputs = model(images)

        if is_dual_head:
            loss1 = nn.CrossEntropyLoss()(outputs[0], labels[:, 0])
            loss2 = nn.CrossEntropyLoss()(outputs[1], labels[:, 1])
            loss = loss1 + loss2
        else:
            loss = nn.CrossEntropyLoss()(outputs, labels)

        loss.backward()
        model.optimizer.step()

        train_loss += loss.item()
        train_idx += 1

        if verbose:
            if train_idx % 20 == 0:
                print(f'idx: {train_idx}, loss for current idx: {loss.item():.6f}')

    train_loss_list.append(train_loss / len(train_loader))
    return train_loss_list[-1]

# %%
import time

# 모델 validation / test 실시

# args :
# - model                : validation/test 할 모델
# - valid_or_test_loader : validation/test Data Loader
# - is_dual_head         : 신경망 출력값, 즉 MLP Head 가 2개인지의 여부

# returns :
# - accuracy       : 모델의 validation/test 정확도
# - inference_time : inference 시간 (seconds)

def run_valid_or_test(model, valid_or_test_loader, is_dual_head):
    model.eval()
    correct, total = 0, 0
    inference_time_sum = 0.0
    valid_test_idx = 0

    with torch.no_grad():
        for images, labels in valid_or_test_loader:
            if is_dual_head:
                labels = convert_to_tensor(labels)
            images, labels = images.to(device), labels.to(device)

            start_at = time.time()
            outputs = model(images)
            inference_time_sum += time.time() - start_at

            # validation/test 실시 및 정확도 측정
            if is_dual_head:
                _, predicted_1 = torch.max(outputs[0], 1)
                _, predicted_2 = torch.max(outputs[1], 1)
                correct += ((predicted_1 == labels[:, 0]) & (predicted_2 == labels[:, 1])).sum().item()

            else:
                _, predicted = torch.max(outputs, 1)
                correct += (predicted == labels).sum().item()

            total += labels.size(0)
            valid_test_idx += 1

    accuracy = correct / total
    inference_time = inference_time_sum / valid_test_idx

    return accuracy, inference_time

# %%
# 모델 학습 및 validation 전체 프로세스

# args :
# - model         : 학습할 모델
# - train_loader  : Training Data Loader
# - valid_loader  : Valid Data Loader
# - test_loader   : Test Data Loader
# - backbone_name : Backbone 모델 이름 ('resnet18', 'resnet34' or 'resnet50')
# - case_name     : 모델 구조 case 이름 ('1', '2', '3', '4_1' or '4_2')
# - verbose       : 학습 중 프로세스 출력 여부

# returns :
# - final_acc      : 해당 하이퍼파라미터 조합에 대한 최종 Accuracy (valid_acc 이 가장 높았던 epoch 의 모델로 측정)
# - inference_time : inference 시간 (seconds)

def run_model_common(model, train_loader, valid_loader, test_loader,
                     backbone_name, case_name, verbose=False):

    train_loss_list = []       # train loss
    valid_acc_list = []        # valid accuracy
    max_valid_acc = 0.0        # max validation accuracy
    best_valid_acc_epoch = -1  # valid_acc 이 가장 높았던 epoch (여기서는 Loss 가 아닌 Accuracy 기준 Early Stopping)
    best_epoch_model = None    # valid_acc 이 가장 높았던 epoch 의 모델

    is_dual_head = case_name in ['3', '4_1', '4_2']

    # 1. 학습 실시
    for epoch in range(MAX_EPOCHS):

        # 1-1. train model
        train_loss = run_train(model,
                               train_loader,
                               train_loss_list,
                               is_dual_head,
                               verbose=(verbose and epoch == 0))

        # 1-2. validate model (with VALID SET)
        epoch_acc, _ = run_valid_or_test(model, valid_loader, is_dual_head)
        valid_acc_list.append(epoch_acc)

        # 1-3. Early Stopping 처리 (overfitting 방지)
        if epoch_acc > max_valid_acc:
            max_valid_acc = epoch_acc
            best_valid_acc_epoch = epoch

            best_epoch_model = define_model(backbone_name, case_name, device)
            best_epoch_model.load_state_dict(model.state_dict())

            if verbose:
                print('best model updated')

        if epoch - best_valid_acc_epoch >= EARLY_STOPPING_ROUNDS:
            break

        # 1-4. 결과 출력
        if verbose:
            print(f"Epoch {epoch+1}, Loss: {train_loss:.4f}, Accuracy: {epoch_acc:.4f}")

    # check best-epoch model correctly loaded
    checked_acc, _ = run_valid_or_test(best_epoch_model, valid_loader, is_dual_head)

    if verbose:
        print(f"Best Epoch: {best_valid_acc_epoch}, Best Valid Acc: {max_valid_acc}")
        print(f"Valid Acc (with Epoch valid set) on Loaded Best Model: {checked_acc}")

    assert abs(max_valid_acc - checked_acc) < 1e-6

    # 2. test best-epoch model (with TEST SET)
    final_acc, inference_time = run_valid_or_test(best_epoch_model, test_loader, is_dual_head)

    if verbose:
        print(f"Final Acc (with TEST set) on Loaded Best Model: {final_acc} (time: {inference_time})")

    return final_acc, inference_time

# %% [markdown]
# **8. 학습 실시**

# %%
print(device)
# Out:
# cuda

# %%
result_dict = {
    'backbone': [],
    'case': [],
    'accuracy': [],
    'inference_time': []
}

dataloader_by_case_name = {
    'dual_head': {
        'train': train_01_02_dataset_loader,
        'valid': valid_01_02_dataset_loader,
        'test': test_01_02_dataset_loader
    },
    'single_head': {
        'train': train_dataset_loader,
        'valid': valid_dataset_loader,
        'test': test_dataset_loader
    }
}

for case_name in ['1', '2', '3', '4_1', '4_2']:
    if case_name in ['3', '4_1', '4_2']:
        head_type = 'dual_head'
    else:
        head_type = 'single_head'

    for backbone_name in ['resnet18', 'resnet34', 'resnet50']:
        print(f'\n=== case={case_name}, backbone={backbone_name} ===')
        model = define_model(backbone_name, case_name, device=device)

        train_loader = dataloader_by_case_name[head_type]['train']
        valid_loader = dataloader_by_case_name[head_type]['valid']
        test_loader = dataloader_by_case_name[head_type]['test']

        final_acc, inference_time = run_model_common(model,
                                                     train_loader=train_loader,
                                                     valid_loader=valid_loader,
                                                     test_loader=test_loader,
                                                     backbone_name=backbone_name,
                                                     case_name=case_name,
                                                     verbose=True)

        result_dict['backbone'].append(backbone_name)
        result_dict['case'].append(case_name)
        result_dict['accuracy'].append(final_acc)
        result_dict['inference_time'].append(inference_time)
# Out:
# === case=1, backbone=resnet18 ===
# idx: 20, loss for current idx: 0.625366
# idx: 40, loss for current idx: 0.558255
# idx: 60, loss for current idx: 0.554028
# idx: 80, loss for current idx: 0.592228
# idx: 100, loss for current idx: 0.573471
# idx: 120, loss for current idx: 0.579993
# idx: 140, loss for current idx: 0.609902
# idx: 160, loss for current idx: 0.551636
# idx: 180, loss for current idx: 0.559562
# idx: 200, loss for current idx: 0.580937
# idx: 220, loss for current idx: 0.679008
# idx: 240, loss for current idx: 0.552843
# idx: 260, loss for current idx: 0.573088
# idx: 280, loss for current idx: 0.551708
# idx: 300, loss for current idx: 0.555480
# idx: 320, loss for current idx: 0.557005
# idx: 340, loss for current idx: 0.581074
# idx: 360, loss for current idx: 0.552137
# idx: 380, loss for current idx: 0.565600
# idx: 400, loss for current idx: 0.552268
# idx: 420, loss for current idx: 0.552285
# idx: 440, loss for current idx: 0.551805
# idx: 460, loss for current idx: 0.551445
# idx: 480, loss for current idx: 0.551485
# idx: 500, loss for current idx: 0.581117
# best model updated
# Epoch 1, Loss: 0.5793, Accuracy: 0.9871
# best model updated
# Epoch 2, Loss: 0.5635, Accuracy: 0.9950
# best model updated
# Epoch 3, Loss: 0.5585, Accuracy: 0.9955
# Epoch 4, Loss: 0.5572, Accuracy: 0.9950
# best model updated
# Epoch 5, Loss: 0.5569, Accuracy: 0.9972
# Epoch 6, Loss: 0.5619, Accuracy: 0.9939
# Epoch 7, Loss: 0.5598, Accuracy: 0.9939
# Epoch 8, Loss: 0.5571, Accuracy: 0.9939
# Epoch 9, Loss: 0.5543, Accuracy: 0.9972
# best model updated
# Epoch 10, Loss: 0.5573, Accuracy: 0.9978
# Epoch 11, Loss: 0.5616, Accuracy: 0.9911
# Epoch 12, Loss: 0.5571, Accuracy: 0.9927
# Epoch 13, Loss: 0.5564, Accuracy: 0.9955
# Epoch 14, Loss: 0.5564, Accuracy: 0.9883
# Epoch 15, Loss: 0.5561, Accuracy: 0.9899
# Epoch 16, Loss: 0.5550, Accuracy: 0.9972
# Epoch 17, Loss: 0.5541, Accuracy: 0.9966
# Epoch 18, Loss: 0.5569, Accuracy: 0.9966
# Epoch 19, Loss: 0.5573, Accuracy: 0.9972
# Best Epoch: 9, Best Valid Acc: 0.9977641140301845
# Valid Acc (with Epoch valid set) on Loaded Best Model: 0.9977641140301845
# Final Acc (with TEST set) on Loaded Best Model: 0.9983176312247645 (time: 0.00477185300601426)
#
# === case=1, backbone=resnet34 ===
# Downloading: "https://download.pytorch.org/models/resnet34-b627a593.pth" to /root/.cache/torch/hub/checkpoints/resnet34-b627a593.pth
# 100%|██████████| 83.3M/83.3M [00:00<00:00, 205MB/s]
# idx: 20, loss for current idx: 0.614686
# idx: 40, loss for current idx: 0.556165
# idx: 60, loss for current idx: 0.566507
# idx: 80, loss for current idx: 0.558017
# idx: 100, loss for current idx: 0.585180
# idx: 120, loss for current idx: 0.582562
# idx: 140, loss for current idx: 0.580840
# idx: 160, loss for current idx: 0.597089
# idx: 180, loss for current idx: 0.564582
# idx: 200, loss for current idx: 0.570905
# idx: 220, loss for current idx: 0.583385
# idx: 240, loss for current idx: 0.642519
# idx: 260, loss for current idx: 0.585393
# idx: 280, loss for current idx: 0.551446
# idx: 300, loss for current idx: 0.551472
# idx: 320, loss for current idx: 0.585439
# idx: 340, loss for current idx: 0.560284
# idx: 360, loss for current idx: 0.552986
# idx: 380, loss for current idx: 0.582750
# idx: 400, loss for current idx: 0.551928
# idx: 420, loss for current idx: 0.551462
# idx: 440, loss for current idx: 0.560968
# idx: 460, loss for current idx: 0.559651
# idx: 480, loss for current idx: 0.551448
# idx: 500, loss for current idx: 0.551452
# best model updated
# Epoch 1, Loss: 0.5836, Accuracy: 0.9955
# Epoch 2, Loss: 0.5607, Accuracy: 0.9911
# Epoch 3, Loss: 0.5616, Accuracy: 0.9939
# Epoch 4, Loss: 0.5581, Accuracy: 0.9922
# Epoch 5, Loss: 0.5601, Accuracy: 0.9939
# best model updated
# Epoch 6, Loss: 0.5567, Accuracy: 0.9966
# Epoch 7, Loss: 0.5567, Accuracy: 0.9961
# best model updated
# Epoch 8, Loss: 0.5556, Accuracy: 0.9989
# Epoch 9, Loss: 0.5554, Accuracy: 0.9939
# Epoch 10, Loss: 0.5549, Accuracy: 0.9989
# Epoch 11, Loss: 0.5545, Accuracy: 0.9983
# Epoch 12, Loss: 0.5550, Accuracy: 0.9955
# Epoch 13, Loss: 0.5557, Accuracy: 0.9972
# Epoch 14, Loss: 0.5580, Accuracy: 0.9955
# Epoch 15, Loss: 0.5659, Accuracy: 0.9966
# Epoch 16, Loss: 0.5613, Accuracy: 0.9978
# Epoch 17, Loss: 0.5575, Accuracy: 0.9978
# Best Epoch: 7, Best Valid Acc: 0.9988820570150923
# Valid Acc (with Epoch valid set) on Loaded Best Model: 0.9988820570150923
# Final Acc (with TEST set) on Loaded Best Model: 0.9983176312247645 (time: 0.008406680117371262)
#
# === case=1, backbone=resnet50 ===
# Downloading: "https://download.pytorch.org/models/resnet50-0676ba61.pth" to /root/.cache/torch/hub/checkpoints/resnet50-0676ba61.pth
# 100%|██████████| 97.8M/97.8M [00:00<00:00, 211MB/s]
# idx: 20, loss for current idx: 0.665168
# idx: 40, loss for current idx: 0.656883
# idx: 60, loss for current idx: 0.589032
# idx: 80, loss for current idx: 0.618805
# idx: 100, loss for current idx: 0.589720
# idx: 120, loss for current idx: 0.569913
# idx: 140, loss for current idx: 0.606303
# idx: 160, loss for current idx: 0.578358
# idx: 180, loss for current idx: 0.571824
# idx: 200, loss for current idx: 0.551454
# idx: 220, loss for current idx: 0.551445
# idx: 240, loss for current idx: 0.610461
# idx: 260, loss for current idx: 0.553687
# idx: 280, loss for current idx: 0.551464
# idx: 300, loss for current idx: 0.551446
# idx: 320, loss for current idx: 0.674033
# idx: 340, loss for current idx: 0.553151
# idx: 360, loss for current idx: 0.564422
# idx: 380, loss for current idx: 0.589125
# idx: 400, loss for current idx: 0.560729
# idx: 420, loss for current idx: 0.584210
# idx: 440, loss for current idx: 0.554242
# idx: 460, loss for current idx: 0.552262
# idx: 480, loss for current idx: 0.551942
# idx: 500, loss for current idx: 0.581136
# best model updated
# Epoch 1, Loss: 0.5989, Accuracy: 0.9883
# best model updated
# Epoch 2, Loss: 0.5671, Accuracy: 0.9950
# Epoch 3, Loss: 0.5607, Accuracy: 0.9911
# Epoch 4, Loss: 0.5639, Accuracy: 0.9905
# Epoch 5, Loss: 0.5605, Accuracy: 0.9933
# Epoch 6, Loss: 0.5565, Accuracy: 0.9950
# Epoch 7, Loss: 0.5568, Accuracy: 0.9922
# Epoch 8, Loss: 0.5559, Accuracy: 0.9894
# best model updated
# Epoch 9, Loss: 0.5594, Accuracy: 0.9966
# Epoch 10, Loss: 0.5561, Accuracy: 0.9905
# Epoch 11, Loss: 0.5579, Accuracy: 0.9955
# best model updated
# Epoch 12, Loss: 0.5551, Accuracy: 0.9972
# best model updated
# Epoch 13, Loss: 0.5554, Accuracy: 0.9983
# Epoch 14, Loss: 0.5613, Accuracy: 0.9950
# Epoch 15, Loss: 0.5558, Accuracy: 0.9972
# Epoch 16, Loss: 0.5580, Accuracy: 0.9961
# Epoch 17, Loss: 0.5558, Accuracy: 0.9888
# Epoch 18, Loss: 0.5572, Accuracy: 0.9944
# Epoch 19, Loss: 0.5541, Accuracy: 0.9966
# Epoch 20, Loss: 0.5603, Accuracy: 0.9955
# Epoch 21, Loss: 0.5555, Accuracy: 0.9972
# Epoch 22, Loss: 0.5565, Accuracy: 0.9961
# Best Epoch: 12, Best Valid Acc: 0.9983230855226384
# Valid Acc (with Epoch valid set) on Loaded Best Model: 0.9983230855226384
# Final Acc (with TEST set) on Loaded Best Model: 0.9976446837146703 (time: 0.011895805276850219)
#
# === case=2, backbone=resnet18 ===
# idx: 20, loss for current idx: 0.685558
# idx: 40, loss for current idx: 0.705950
# idx: 60, loss for current idx: 0.578559
# idx: 80, loss for current idx: 0.647482
# idx: 100, loss for current idx: 0.593475
# idx: 120, loss for current idx: 0.637323
# idx: 140, loss for current idx: 0.585086
# idx: 160, loss for current idx: 0.626475
# idx: 180, loss for current idx: 0.583663
# idx: 200, loss for current idx: 0.551878
# idx: 220, loss for current idx: 0.565896
# idx: 240, loss for current idx: 0.575508
# idx: 260, loss for current idx: 0.617072
# idx: 280, loss for current idx: 0.553231
# idx: 300, loss for current idx: 0.602317
# idx: 320, loss for current idx: 0.615033
# idx: 340, loss for current idx: 0.601122
# idx: 360, loss for current idx: 0.556875
# idx: 380, loss for current idx: 0.613863
# idx: 400, loss for current idx: 0.551473
# idx: 420, loss for current idx: 0.551470
# idx: 440, loss for current idx: 0.551480
# idx: 460, loss for current idx: 0.577038
# idx: 480, loss for current idx: 0.565402
# idx: 500, loss for current idx: 0.551452
# best model updated
# Epoch 1, Loss: 0.5908, Accuracy: 0.9894
# best model updated
# Epoch 2, Loss: 0.5622, Accuracy: 0.9911
# best model updated
# Epoch 3, Loss: 0.5612, Accuracy: 0.9961
# Epoch 4, Loss: 0.5569, Accuracy: 0.9939
# Epoch 5, Loss: 0.5619, Accuracy: 0.9916
# Epoch 6, Loss: 0.5568, Accuracy: 0.9944
# Epoch 7, Loss: 0.5567, Accuracy: 0.9911
# Epoch 8, Loss: 0.5571, Accuracy: 0.9950
# Epoch 9, Loss: 0.5565, Accuracy: 0.9916
# Epoch 10, Loss: 0.5610, Accuracy: 0.9933
# Epoch 11, Loss: 0.5580, Accuracy: 0.9955
# Epoch 12, Loss: 0.5573, Accuracy: 0.9849
# Best Epoch: 2, Best Valid Acc: 0.9960871995528228
# Valid Acc (with Epoch valid set) on Loaded Best Model: 0.9960871995528228
# Final Acc (with TEST set) on Loaded Best Model: 0.9959623149394348 (time: 0.0031506553772957095)
#
# === case=2, backbone=resnet34 ===
# idx: 20, loss for current idx: 0.704577
# idx: 40, loss for current idx: 0.617113
# idx: 60, loss for current idx: 0.563324
# idx: 80, loss for current idx: 0.585004
# idx: 100, loss for current idx: 0.633034
# idx: 120, loss for current idx: 0.556173
# idx: 140, loss for current idx: 0.582620
# idx: 160, loss for current idx: 0.581722
# idx: 180, loss for current idx: 0.551566
# idx: 200, loss for current idx: 0.555119
# idx: 220, loss for current idx: 0.599566
# idx: 240, loss for current idx: 0.557313
# idx: 260, loss for current idx: 0.569548
# idx: 280, loss for current idx: 0.553031
# idx: 300, loss for current idx: 0.581082
# idx: 320, loss for current idx: 0.557781
# idx: 340, loss for current idx: 0.614322
# idx: 360, loss for current idx: 0.557608
# idx: 380, loss for current idx: 0.586521
# idx: 400, loss for current idx: 0.551473
# idx: 420, loss for current idx: 0.551475
# idx: 440, loss for current idx: 0.674807
# idx: 460, loss for current idx: 0.553688
# idx: 480, loss for current idx: 0.551942
# idx: 500, loss for current idx: 0.551504
# best model updated
# Epoch 1, Loss: 0.5913, Accuracy: 0.9866
# best model updated
# Epoch 2, Loss: 0.5624, Accuracy: 0.9911
# best model updated
# Epoch 3, Loss: 0.5609, Accuracy: 0.9927
# Epoch 4, Loss: 0.5598, Accuracy: 0.9922
# best model updated
# Epoch 5, Loss: 0.5590, Accuracy: 0.9955
# Epoch 6, Loss: 0.5589, Accuracy: 0.9944
# Epoch 7, Loss: 0.5569, Accuracy: 0.9955
# Epoch 8, Loss: 0.5580, Accuracy: 0.9927
# Epoch 9, Loss: 0.5557, Accuracy: 0.9922
# best model updated
# Epoch 10, Loss: 0.5581, Accuracy: 0.9978
# Epoch 11, Loss: 0.5572, Accuracy: 0.9955
# Epoch 12, Loss: 0.5563, Accuracy: 0.9966
# Epoch 13, Loss: 0.5573, Accuracy: 0.9911
# Epoch 14, Loss: 0.5708, Accuracy: 0.9922
# Epoch 15, Loss: 0.5708, Accuracy: 0.9860
# Epoch 16, Loss: 0.5595, Accuracy: 0.9927
# Epoch 17, Loss: 0.5590, Accuracy: 0.9961
# Epoch 18, Loss: 0.5629, Accuracy: 0.9905
# Epoch 19, Loss: 0.5613, Accuracy: 0.9933
# Best Epoch: 9, Best Valid Acc: 0.9977641140301845
# Valid Acc (with Epoch valid set) on Loaded Best Model: 0.9977641140301845
# Final Acc (with TEST set) on Loaded Best Model: 0.996971736204576 (time: 0.004227948445145802)
#
# === case=2, backbone=resnet50 ===
# idx: 20, loss for current idx: 0.738151
# idx: 40, loss for current idx: 0.686558
# idx: 60, loss for current idx: 0.658809
# idx: 80, loss for current idx: 0.555137
# idx: 100, loss for current idx: 0.665379
# idx: 120, loss for current idx: 0.553352
# idx: 140, loss for current idx: 0.603764
# idx: 160, loss for current idx: 0.598042
# idx: 180, loss for current idx: 0.559822
# idx: 200, loss for current idx: 0.617944
# idx: 220, loss for current idx: 0.680400
# idx: 240, loss for current idx: 0.602835
# idx: 260, loss for current idx: 0.660129
# idx: 280, loss for current idx: 0.646860
# idx: 300, loss for current idx: 0.591671
# idx: 320, loss for current idx: 0.552478
# idx: 340, loss for current idx: 0.560120
# idx: 360, loss for current idx: 0.625239
# idx: 380, loss for current idx: 0.613494
# idx: 400, loss for current idx: 0.611152
# idx: 420, loss for current idx: 0.552633
# idx: 440, loss for current idx: 0.564890
# idx: 460, loss for current idx: 0.552909
# idx: 480, loss for current idx: 0.584444
# idx: 500, loss for current idx: 0.611620
# best model updated
# Epoch 1, Loss: 0.6168, Accuracy: 0.9911
# best model updated
# Epoch 2, Loss: 0.5646, Accuracy: 0.9961
# Epoch 3, Loss: 0.5585, Accuracy: 0.9950
# Epoch 4, Loss: 0.5584, Accuracy: 0.9955
# best model updated
# Epoch 5, Loss: 0.5568, Accuracy: 0.9966
# Epoch 6, Loss: 0.5573, Accuracy: 0.9961
# Epoch 7, Loss: 0.5570, Accuracy: 0.9911
# Epoch 8, Loss: 0.5559, Accuracy: 0.9955
# best model updated
# Epoch 9, Loss: 0.5559, Accuracy: 0.9994
# Epoch 10, Loss: 0.5601, Accuracy: 0.9748
# Epoch 11, Loss: 0.5564, Accuracy: 0.9966
# Epoch 12, Loss: 0.5575, Accuracy: 0.9911
# Epoch 13, Loss: 0.5610, Accuracy: 0.9944
# Epoch 14, Loss: 0.5599, Accuracy: 0.9804
# Epoch 15, Loss: 0.5568, Accuracy: 0.9983
# Epoch 16, Loss: 0.5542, Accuracy: 0.9966
# Epoch 17, Loss: 0.5550, Accuracy: 0.9983
# Epoch 18, Loss: 0.5587, Accuracy: 0.9983
# Best Epoch: 8, Best Valid Acc: 0.9994410285075461
# Valid Acc (with Epoch valid set) on Loaded Best Model: 0.9994410285075461
# Final Acc (with TEST set) on Loaded Best Model: 0.9976446837146703 (time: 0.006893350232032037)
#
# === case=3, backbone=resnet18 ===
# idx: 20, loss for current idx: 0.772193
# idx: 40, loss for current idx: 0.679709
# idx: 60, loss for current idx: 0.727275
# idx: 80, loss for current idx: 0.643544
# idx: 100, loss for current idx: 0.697963
# idx: 120, loss for current idx: 0.654546
# idx: 140, loss for current idx: 0.630466
# idx: 160, loss for current idx: 0.728061
# idx: 180, loss for current idx: 0.638406
# idx: 200, loss for current idx: 0.627097
# idx: 220, loss for current idx: 0.626672
# idx: 240, loss for current idx: 0.632198
# idx: 260, loss for current idx: 0.631941
# idx: 280, loss for current idx: 0.636062
# idx: 300, loss for current idx: 0.637218
# idx: 320, loss for current idx: 0.626726
# idx: 340, loss for current idx: 0.657643
# idx: 360, loss for current idx: 0.626869
# idx: 380, loss for current idx: 0.635583
# idx: 400, loss for current idx: 0.656886
# idx: 420, loss for current idx: 0.652030
# idx: 440, loss for current idx: 0.653063
# idx: 460, loss for current idx: 0.626951
# idx: 480, loss for current idx: 0.635854
# idx: 500, loss for current idx: 0.658130
# best model updated
# Epoch 1, Loss: 0.6708, Accuracy: 0.9922
# best model updated
# Epoch 2, Loss: 0.6393, Accuracy: 0.9939
# best model updated
# Epoch 3, Loss: 0.6328, Accuracy: 0.9966
# Epoch 4, Loss: 0.6341, Accuracy: 0.9961
# Epoch 5, Loss: 0.6352, Accuracy: 0.9899
# Epoch 6, Loss: 0.6311, Accuracy: 0.9944
# Epoch 7, Loss: 0.6349, Accuracy: 0.9966
# best model updated
# Epoch 8, Loss: 0.6329, Accuracy: 0.9983
# Epoch 9, Loss: 0.6301, Accuracy: 0.9961
# Epoch 10, Loss: 0.6314, Accuracy: 0.9927
# Epoch 11, Loss: 0.6325, Accuracy: 0.9961
# Epoch 12, Loss: 0.6355, Accuracy: 0.9983
# Epoch 13, Loss: 0.6318, Accuracy: 0.9978
# Epoch 14, Loss: 0.6319, Accuracy: 0.9944
# Epoch 15, Loss: 0.6289, Accuracy: 0.9961
# Epoch 16, Loss: 0.6314, Accuracy: 0.9715
# best model updated
# Epoch 17, Loss: 0.6352, Accuracy: 0.9989
# Epoch 18, Loss: 0.6347, Accuracy: 0.9966
# Epoch 19, Loss: 0.6297, Accuracy: 0.9966
# Epoch 20, Loss: 0.6320, Accuracy: 0.9983
# Epoch 21, Loss: 0.6307, Accuracy: 0.9983
# Epoch 22, Loss: 0.6360, Accuracy: 0.9972
# Epoch 23, Loss: 0.6297, Accuracy: 0.9916
# Epoch 24, Loss: 0.6321, Accuracy: 0.9978
# Epoch 25, Loss: 0.6306, Accuracy: 0.9972
# Epoch 26, Loss: 0.6307, Accuracy: 0.9966
# Best Epoch: 16, Best Valid Acc: 0.9988820570150923
# Valid Acc (with Epoch valid set) on Loaded Best Model: 0.9988820570150923
# Final Acc (with TEST set) on Loaded Best Model: 0.9979811574697174 (time: 0.002458626224148658)
#
# === case=3, backbone=resnet34 ===
# idx: 20, loss for current idx: 0.767741
# idx: 40, loss for current idx: 0.792830
# idx: 60, loss for current idx: 0.644874
# idx: 80, loss for current idx: 0.665465
# idx: 100, loss for current idx: 0.656090
# idx: 120, loss for current idx: 0.680007
# idx: 140, loss for current idx: 0.657901
# idx: 160, loss for current idx: 0.670717
# idx: 180, loss for current idx: 0.627471
# idx: 200, loss for current idx: 0.650428
# idx: 220, loss for current idx: 0.627274
# idx: 240, loss for current idx: 0.657954
# idx: 260, loss for current idx: 0.626609
# idx: 280, loss for current idx: 0.653382
# idx: 300, loss for current idx: 0.655100
# idx: 320, loss for current idx: 0.627332
# idx: 340, loss for current idx: 0.657893
# idx: 360, loss for current idx: 0.627632
# idx: 380, loss for current idx: 0.626903
# idx: 400, loss for current idx: 0.644629
# idx: 420, loss for current idx: 0.626620
# idx: 440, loss for current idx: 0.626602
# idx: 460, loss for current idx: 0.630092
# idx: 480, loss for current idx: 0.626952
# idx: 500, loss for current idx: 0.633469
# best model updated
# Epoch 1, Loss: 0.6700, Accuracy: 0.9899
# best model updated
# Epoch 2, Loss: 0.6377, Accuracy: 0.9939
# Epoch 3, Loss: 0.6379, Accuracy: 0.9916
# best model updated
# Epoch 4, Loss: 0.6327, Accuracy: 0.9972
# Epoch 5, Loss: 0.6329, Accuracy: 0.9955
# Epoch 6, Loss: 0.6336, Accuracy: 0.9944
# Epoch 7, Loss: 0.6303, Accuracy: 0.9966
# Epoch 8, Loss: 0.6337, Accuracy: 0.9855
# Epoch 9, Loss: 0.6326, Accuracy: 0.9927
# Epoch 10, Loss: 0.6301, Accuracy: 0.9888
# best model updated
# Epoch 11, Loss: 0.6312, Accuracy: 0.9983
# Epoch 12, Loss: 0.6293, Accuracy: 0.9961
# Epoch 13, Loss: 0.6354, Accuracy: 0.9916
# Epoch 14, Loss: 0.6338, Accuracy: 0.9955
# Epoch 15, Loss: 0.6293, Accuracy: 0.9961
# Epoch 16, Loss: 0.6304, Accuracy: 0.9972
# Epoch 17, Loss: 0.6309, Accuracy: 0.9916
# best model updated
# Epoch 18, Loss: 0.6323, Accuracy: 0.9989
# Epoch 19, Loss: 0.6326, Accuracy: 0.9978
# Epoch 20, Loss: 0.6289, Accuracy: 0.9989
# best model updated
# Epoch 21, Loss: 0.6281, Accuracy: 0.9994
# Epoch 22, Loss: 0.6315, Accuracy: 0.9950
# Epoch 23, Loss: 0.6306, Accuracy: 0.9933
# Epoch 24, Loss: 0.6314, Accuracy: 0.9972
# Epoch 25, Loss: 0.6291, Accuracy: 0.9978
# Epoch 26, Loss: 0.6309, Accuracy: 0.9972
# Epoch 27, Loss: 0.6300, Accuracy: 0.9972
# Epoch 28, Loss: 0.6285, Accuracy: 0.9978
# Epoch 29, Loss: 0.6297, Accuracy: 0.9983
# Epoch 30, Loss: 0.6279, Accuracy: 0.9983
# Best Epoch: 20, Best Valid Acc: 0.9994410285075461
# Valid Acc (with Epoch valid set) on Loaded Best Model: 0.9994410285075461
# Final Acc (with TEST set) on Loaded Best Model: 0.9993270524899058 (time: 0.005125827686761016)
#
# === case=3, backbone=resnet50 ===
# idx: 20, loss for current idx: 1.013522
# idx: 40, loss for current idx: 0.788605
# idx: 60, loss for current idx: 0.703869
# idx: 80, loss for current idx: 0.651694
# idx: 100, loss for current idx: 0.676849
# idx: 120, loss for current idx: 0.750598
# idx: 140, loss for current idx: 0.720016
# idx: 160, loss for current idx: 0.659460
# idx: 180, loss for current idx: 0.678033
# idx: 200, loss for current idx: 0.681432
# idx: 220, loss for current idx: 0.680477
# idx: 240, loss for current idx: 0.703716
# idx: 260, loss for current idx: 0.627904
# idx: 280, loss for current idx: 0.628398
# idx: 300, loss for current idx: 0.678460
# idx: 320, loss for current idx: 0.657845
# idx: 340, loss for current idx: 0.690537
# idx: 360, loss for current idx: 0.627238
# idx: 380, loss for current idx: 0.657795
# idx: 400, loss for current idx: 0.693485
# idx: 420, loss for current idx: 0.631241
# idx: 440, loss for current idx: 0.626621
# idx: 460, loss for current idx: 0.749540
# idx: 480, loss for current idx: 0.634678
# idx: 500, loss for current idx: 0.626547
# best model updated
# Epoch 1, Loss: 0.6966, Accuracy: 0.9888
# best model updated
# Epoch 2, Loss: 0.6432, Accuracy: 0.9950
# Epoch 3, Loss: 0.6353, Accuracy: 0.9922
# best model updated
# Epoch 4, Loss: 0.6358, Accuracy: 0.9972
# Epoch 5, Loss: 0.6343, Accuracy: 0.9961
# best model updated
# Epoch 6, Loss: 0.6302, Accuracy: 0.9978
# Epoch 7, Loss: 0.6333, Accuracy: 0.9961
# Epoch 8, Loss: 0.6360, Accuracy: 0.9955
# Epoch 9, Loss: 0.6351, Accuracy: 0.9972
# Epoch 10, Loss: 0.6372, Accuracy: 0.9961
# Epoch 11, Loss: 0.6415, Accuracy: 0.9978
# Epoch 12, Loss: 0.6347, Accuracy: 0.9933
# Epoch 13, Loss: 0.6349, Accuracy: 0.9961
# Epoch 14, Loss: 0.6355, Accuracy: 0.9922
# best model updated
# Epoch 15, Loss: 0.6398, Accuracy: 0.9983
# Epoch 16, Loss: 0.6359, Accuracy: 0.9911
# Epoch 17, Loss: 0.6438, Accuracy: 0.9955
# Epoch 18, Loss: 0.6344, Accuracy: 0.9883
# Epoch 19, Loss: 0.6358, Accuracy: 0.9972
# Epoch 20, Loss: 0.6396, Accuracy: 0.9978
# Epoch 21, Loss: 0.6327, Accuracy: 0.9922
# Epoch 22, Loss: 0.6344, Accuracy: 0.9922
# Epoch 23, Loss: 0.6332, Accuracy: 0.9966
# Epoch 24, Loss: 0.6305, Accuracy: 0.9916
# Best Epoch: 14, Best Valid Acc: 0.9983230855226384
# Valid Acc (with Epoch valid set) on Loaded Best Model: 0.9983230855226384
# Final Acc (with TEST set) on Loaded Best Model: 0.9976446837146703 (time: 0.00731216194809124)
#
# === case=4_1, backbone=resnet18 ===
# idx: 20, loss for current idx: 0.795624
# idx: 40, loss for current idx: 0.728998
# idx: 60, loss for current idx: 0.628158
# idx: 80, loss for current idx: 0.662614
# idx: 100, loss for current idx: 0.689357
# idx: 120, loss for current idx: 0.652740
# idx: 140, loss for current idx: 0.641873
# idx: 160, loss for current idx: 0.675534
# idx: 180, loss for current idx: 0.638657
# idx: 200, loss for current idx: 0.626763
# idx: 220, loss for current idx: 0.627307
# idx: 240, loss for current idx: 0.629387
# idx: 260, loss for current idx: 0.693106
# idx: 280, loss for current idx: 0.626589
# idx: 300, loss for current idx: 0.654497
# idx: 320, loss for current idx: 0.627945
# idx: 340, loss for current idx: 0.657441
# idx: 360, loss for current idx: 0.660411
# idx: 380, loss for current idx: 0.626915
# idx: 400, loss for current idx: 0.626613
# idx: 420, loss for current idx: 0.626604
# idx: 440, loss for current idx: 0.643843
# idx: 460, loss for current idx: 0.626633
# idx: 480, loss for current idx: 0.626527
# idx: 500, loss for current idx: 0.636256
# best model updated
# Epoch 1, Loss: 0.6615, Accuracy: 0.9939
# best model updated
# Epoch 2, Loss: 0.6347, Accuracy: 0.9961
# Epoch 3, Loss: 0.6329, Accuracy: 0.9961
# Epoch 4, Loss: 0.6323, Accuracy: 0.9911
# best model updated
# Epoch 5, Loss: 0.6336, Accuracy: 0.9972
# Epoch 6, Loss: 0.6341, Accuracy: 0.9905
# Epoch 7, Loss: 0.6307, Accuracy: 0.9966
# Epoch 8, Loss: 0.6308, Accuracy: 0.9894
# Epoch 9, Loss: 0.6340, Accuracy: 0.9966
# best model updated
# Epoch 10, Loss: 0.6301, Accuracy: 0.9978
# Epoch 11, Loss: 0.6318, Accuracy: 0.9978
# Epoch 12, Loss: 0.6317, Accuracy: 0.9905
# Epoch 13, Loss: 0.6384, Accuracy: 0.9944
# best model updated
# Epoch 14, Loss: 0.6342, Accuracy: 0.9983
# Epoch 15, Loss: 0.6301, Accuracy: 0.9966
# Epoch 16, Loss: 0.6312, Accuracy: 0.9983
# Epoch 17, Loss: 0.6317, Accuracy: 0.9978
# best model updated
# Epoch 18, Loss: 0.6319, Accuracy: 0.9994
# Epoch 19, Loss: 0.6302, Accuracy: 0.9927
# Epoch 20, Loss: 0.6356, Accuracy: 0.9950
# Epoch 21, Loss: 0.6314, Accuracy: 0.9978
# Epoch 22, Loss: 0.6299, Accuracy: 0.9978
# Epoch 23, Loss: 0.6292, Accuracy: 0.9983
# Epoch 24, Loss: 0.6325, Accuracy: 0.9939
# Epoch 25, Loss: 0.6313, Accuracy: 0.9961
# Epoch 26, Loss: 0.6296, Accuracy: 0.9978
# Epoch 27, Loss: 0.6307, Accuracy: 0.9955
# Best Epoch: 17, Best Valid Acc: 0.9994410285075461
# Valid Acc (with Epoch valid set) on Loaded Best Model: 0.9994410285075461
# Final Acc (with TEST set) on Loaded Best Model: 0.9979811574697174 (time: 0.004742840284942299)
#
# === case=4_1, backbone=resnet34 ===
# idx: 20, loss for current idx: 0.860804
# idx: 40, loss for current idx: 0.671947
# idx: 60, loss for current idx: 0.734260
# idx: 80, loss for current idx: 0.627028
# idx: 100, loss for current idx: 0.721494
# idx: 120, loss for current idx: 0.645099
# idx: 140, loss for current idx: 0.656113
# idx: 160, loss for current idx: 0.795958
# idx: 180, loss for current idx: 0.661148
# idx: 200, loss for current idx: 0.678364
# idx: 220, loss for current idx: 0.655618
# idx: 240, loss for current idx: 0.631318
# idx: 260, loss for current idx: 0.649597
# idx: 280, loss for current idx: 0.677757
# idx: 300, loss for current idx: 0.630990
# idx: 320, loss for current idx: 0.626761
# idx: 340, loss for current idx: 0.688691
# idx: 360, loss for current idx: 0.626593
# idx: 380, loss for current idx: 0.626532
# idx: 400, loss for current idx: 0.628622
# idx: 420, loss for current idx: 0.626536
# idx: 440, loss for current idx: 0.626579
# idx: 460, loss for current idx: 0.658275
# idx: 480, loss for current idx: 0.651515
# idx: 500, loss for current idx: 0.628201
# best model updated
# Epoch 1, Loss: 0.6669, Accuracy: 0.9905
# Epoch 2, Loss: 0.6406, Accuracy: 0.9877
# best model updated
# Epoch 3, Loss: 0.6353, Accuracy: 0.9961
# best model updated
# Epoch 4, Loss: 0.6335, Accuracy: 0.9966
# Epoch 5, Loss: 0.6314, Accuracy: 0.9927
# best model updated
# Epoch 6, Loss: 0.6302, Accuracy: 0.9978
# Epoch 7, Loss: 0.6331, Accuracy: 0.9978
# Epoch 8, Loss: 0.6373, Accuracy: 0.9939
# best model updated
# Epoch 9, Loss: 0.6315, Accuracy: 0.9989
# Epoch 10, Loss: 0.6298, Accuracy: 0.9972
# Epoch 11, Loss: 0.6368, Accuracy: 0.9972
# Epoch 12, Loss: 0.6322, Accuracy: 0.9972
# Epoch 13, Loss: 0.6297, Accuracy: 0.9983
# Epoch 14, Loss: 0.6295, Accuracy: 0.9983
# Epoch 15, Loss: 0.6295, Accuracy: 0.9989
# Epoch 16, Loss: 0.6284, Accuracy: 0.9989
# Epoch 17, Loss: 0.6324, Accuracy: 0.9944
# Epoch 18, Loss: 0.6441, Accuracy: 0.9966
# Best Epoch: 8, Best Valid Acc: 0.9988820570150923
# Valid Acc (with Epoch valid set) on Loaded Best Model: 0.9988820570150923
# Final Acc (with TEST set) on Loaded Best Model: 0.9986541049798116 (time: 0.008220062460950625)
#
# === case=4_1, backbone=resnet50 ===
# idx: 20, loss for current idx: 0.792463
# idx: 40, loss for current idx: 0.743462
# idx: 60, loss for current idx: 0.638263
# idx: 80, loss for current idx: 0.696667
# idx: 100, loss for current idx: 0.638246
# idx: 120, loss for current idx: 0.803764
# idx: 140, loss for current idx: 0.778291
# idx: 160, loss for current idx: 0.663317
# idx: 180, loss for current idx: 0.765982
# idx: 200, loss for current idx: 0.665503
# idx: 220, loss for current idx: 0.703497
# idx: 240, loss for current idx: 0.690102
# idx: 260, loss for current idx: 0.710545
# idx: 280, loss for current idx: 0.710634
# idx: 300, loss for current idx: 0.658895
# idx: 320, loss for current idx: 0.626560
# idx: 340, loss for current idx: 0.626582
# idx: 360, loss for current idx: 0.663646
# idx: 380, loss for current idx: 0.650093
# idx: 400, loss for current idx: 0.658001
# idx: 420, loss for current idx: 0.645611
# idx: 440, loss for current idx: 0.724454
# idx: 460, loss for current idx: 0.626524
# idx: 480, loss for current idx: 0.626550
# idx: 500, loss for current idx: 0.643754
# best model updated
# Epoch 1, Loss: 0.6875, Accuracy: 0.9905
# best model updated
# Epoch 2, Loss: 0.6454, Accuracy: 0.9972
# Epoch 3, Loss: 0.6385, Accuracy: 0.9950
# Epoch 4, Loss: 0.6332, Accuracy: 0.9916
# Epoch 5, Loss: 0.6379, Accuracy: 0.9944
# Epoch 6, Loss: 0.6315, Accuracy: 0.9955
# best model updated
# Epoch 7, Loss: 0.6323, Accuracy: 0.9978
# Epoch 8, Loss: 0.6322, Accuracy: 0.9950
# Epoch 9, Loss: 0.6378, Accuracy: 0.9916
# Epoch 10, Loss: 0.6362, Accuracy: 0.9933
# best model updated
# Epoch 11, Loss: 0.6314, Accuracy: 0.9983
# Epoch 12, Loss: 0.6326, Accuracy: 0.9944
# Epoch 13, Loss: 0.6343, Accuracy: 0.9972
# Epoch 14, Loss: 0.6390, Accuracy: 0.9966
# Epoch 15, Loss: 0.6311, Accuracy: 0.9972
# Epoch 16, Loss: 0.6339, Accuracy: 0.9961
# Epoch 17, Loss: 0.6326, Accuracy: 0.9950
# Epoch 18, Loss: 0.6304, Accuracy: 0.9944
# Epoch 19, Loss: 0.6319, Accuracy: 0.9978
# Epoch 20, Loss: 0.6368, Accuracy: 0.9966
# Best Epoch: 10, Best Valid Acc: 0.9983230855226384
# Valid Acc (with Epoch valid set) on Loaded Best Model: 0.9983230855226384
# Final Acc (with TEST set) on Loaded Best Model: 0.996971736204576 (time: 0.01113973125334709)
#
# === case=4_2, backbone=resnet18 ===
# idx: 20, loss for current idx: 0.871067
# idx: 40, loss for current idx: 0.726308
# idx: 60, loss for current idx: 0.818636
# idx: 80, loss for current idx: 0.712394
# idx: 100, loss for current idx: 0.675107
# idx: 120, loss for current idx: 0.649364
# idx: 140, loss for current idx: 0.702272
# idx: 160, loss for current idx: 0.688863
# idx: 180, loss for current idx: 0.741266
# idx: 200, loss for current idx: 0.679128
# idx: 220, loss for current idx: 0.684712
# idx: 240, loss for current idx: 0.631773
# idx: 260, loss for current idx: 0.658489
# idx: 280, loss for current idx: 0.679352
# idx: 300, loss for current idx: 0.633576
# idx: 320, loss for current idx: 0.628193
# idx: 340, loss for current idx: 0.627313
# idx: 360, loss for current idx: 0.628601
# idx: 380, loss for current idx: 0.626955
# idx: 400, loss for current idx: 0.654513
# idx: 420, loss for current idx: 0.626812
# idx: 440, loss for current idx: 0.715081
# idx: 460, loss for current idx: 0.627040
# idx: 480, loss for current idx: 0.627141
# idx: 500, loss for current idx: 0.627518
# best model updated
# Epoch 1, Loss: 0.6758, Accuracy: 0.9771
# best model updated
# Epoch 2, Loss: 0.6403, Accuracy: 0.9894
# best model updated
# Epoch 3, Loss: 0.6412, Accuracy: 0.9922
# best model updated
# Epoch 4, Loss: 0.6368, Accuracy: 0.9933
# best model updated
# Epoch 5, Loss: 0.6350, Accuracy: 0.9950
# best model updated
# Epoch 6, Loss: 0.6335, Accuracy: 0.9961
# Epoch 7, Loss: 0.6366, Accuracy: 0.9944
# Epoch 8, Loss: 0.6393, Accuracy: 0.9743
# Epoch 9, Loss: 0.6387, Accuracy: 0.9916
# Epoch 10, Loss: 0.6331, Accuracy: 0.9927
# Epoch 11, Loss: 0.6336, Accuracy: 0.9955
# best model updated
# Epoch 12, Loss: 0.6306, Accuracy: 0.9972
# Epoch 13, Loss: 0.6303, Accuracy: 0.9955
# Epoch 14, Loss: 0.6439, Accuracy: 0.9860
# Epoch 15, Loss: 0.6444, Accuracy: 0.9933
# Epoch 16, Loss: 0.6381, Accuracy: 0.9916
# Epoch 17, Loss: 0.6350, Accuracy: 0.9905
# Epoch 18, Loss: 0.6406, Accuracy: 0.9877
# Epoch 19, Loss: 0.6370, Accuracy: 0.9788
# Epoch 20, Loss: 0.6362, Accuracy: 0.9939
# Epoch 21, Loss: 0.6332, Accuracy: 0.9966
# Best Epoch: 11, Best Valid Acc: 0.9972051425377306
# Valid Acc (with Epoch valid set) on Loaded Best Model: 0.9972051425377306
# Final Acc (with TEST set) on Loaded Best Model: 0.9979811574697174 (time: 0.006373864348216724)
#
# === case=4_2, backbone=resnet34 ===
# idx: 20, loss for current idx: 0.759753
# idx: 40, loss for current idx: 0.714125
# idx: 60, loss for current idx: 0.646534
# idx: 80, loss for current idx: 0.659178
# idx: 100, loss for current idx: 0.656828
# idx: 120, loss for current idx: 0.644991
# idx: 140, loss for current idx: 0.627212
# idx: 160, loss for current idx: 0.658203
# idx: 180, loss for current idx: 0.760259
# idx: 200, loss for current idx: 0.750496
# idx: 220, loss for current idx: 0.680376
# idx: 240, loss for current idx: 0.687384
# idx: 260, loss for current idx: 0.631282
# idx: 280, loss for current idx: 0.652404
# idx: 300, loss for current idx: 0.627183
# idx: 320, loss for current idx: 0.657360
# idx: 340, loss for current idx: 0.629753
# idx: 360, loss for current idx: 0.626561
# idx: 380, loss for current idx: 0.689128
# idx: 400, loss for current idx: 0.635977
# idx: 420, loss for current idx: 0.660163
# idx: 440, loss for current idx: 0.722596
# idx: 460, loss for current idx: 0.626546
# idx: 480, loss for current idx: 0.657757
# idx: 500, loss for current idx: 0.626543
# best model updated
# Epoch 1, Loss: 0.6810, Accuracy: 0.9866
# Epoch 2, Loss: 0.6460, Accuracy: 0.9866
# best model updated
# Epoch 3, Loss: 0.6398, Accuracy: 0.9933
# Epoch 4, Loss: 0.6372, Accuracy: 0.9838
# Epoch 5, Loss: 0.6392, Accuracy: 0.9933
# Epoch 6, Loss: 0.6417, Accuracy: 0.9905
# best model updated
# Epoch 7, Loss: 0.6410, Accuracy: 0.9966
# Epoch 8, Loss: 0.6424, Accuracy: 0.9693
# Epoch 9, Loss: 0.6557, Accuracy: 0.9793
# Epoch 10, Loss: 0.6380, Accuracy: 0.9955
# Epoch 11, Loss: 0.6325, Accuracy: 0.9950
# Epoch 12, Loss: 0.6318, Accuracy: 0.9927
# Epoch 13, Loss: 0.6563, Accuracy: 0.9944
# Epoch 14, Loss: 0.6391, Accuracy: 0.9888
# Epoch 15, Loss: 0.6356, Accuracy: 0.9933
# Epoch 16, Loss: 0.6351, Accuracy: 0.9916
# Best Epoch: 6, Best Valid Acc: 0.9966461710452766
# Valid Acc (with Epoch valid set) on Loaded Best Model: 0.9966461710452766
# Final Acc (with TEST set) on Loaded Best Model: 0.9979811574697174 (time: 0.009675756577522523)
#
# === case=4_2, backbone=resnet50 ===
# idx: 20, loss for current idx: 0.889858
# idx: 40, loss for current idx: 0.661092
# idx: 60, loss for current idx: 0.962928
# idx: 80, loss for current idx: 0.644208
# idx: 100, loss for current idx: 0.711548
# idx: 120, loss for current idx: 0.664891
# idx: 140, loss for current idx: 0.734137
# idx: 160, loss for current idx: 0.692957
# idx: 180, loss for current idx: 0.637361
# idx: 200, loss for current idx: 0.645740
# idx: 220, loss for current idx: 0.682110
# idx: 240, loss for current idx: 0.703481
# idx: 260, loss for current idx: 0.657860
# idx: 280, loss for current idx: 0.627731
# idx: 300, loss for current idx: 0.645540
# idx: 320, loss for current idx: 0.626564
# idx: 340, loss for current idx: 0.627824
# idx: 360, loss for current idx: 0.626530
# idx: 380, loss for current idx: 0.665353
# idx: 400, loss for current idx: 0.626544
# idx: 420, loss for current idx: 0.658436
# idx: 440, loss for current idx: 0.629462
# idx: 460, loss for current idx: 0.626589
# idx: 480, loss for current idx: 0.657673
# idx: 500, loss for current idx: 0.727440
# best model updated
# Epoch 1, Loss: 0.6960, Accuracy: 0.9843
# best model updated
# Epoch 2, Loss: 0.6418, Accuracy: 0.9905
# Epoch 3, Loss: 0.6410, Accuracy: 0.9905
# best model updated
# Epoch 4, Loss: 0.6343, Accuracy: 0.9944
# Epoch 5, Loss: 0.6343, Accuracy: 0.9877
# Epoch 6, Loss: 0.6345, Accuracy: 0.9933
# Epoch 7, Loss: 0.6418, Accuracy: 0.9927
# Epoch 8, Loss: 0.6308, Accuracy: 0.9933
# Epoch 9, Loss: 0.6341, Accuracy: 0.9905
# best model updated
# Epoch 10, Loss: 0.6313, Accuracy: 0.9978
# Epoch 11, Loss: 0.6330, Accuracy: 0.9883
# Epoch 12, Loss: 0.6315, Accuracy: 0.9961
# Epoch 13, Loss: 0.6384, Accuracy: 0.9955
# Epoch 14, Loss: 0.6326, Accuracy: 0.9939
# Epoch 15, Loss: 0.6400, Accuracy: 0.9944
# Epoch 16, Loss: 0.6327, Accuracy: 0.9966
# Epoch 17, Loss: 0.6328, Accuracy: 0.9966
# Epoch 18, Loss: 0.6289, Accuracy: 0.9961
# Epoch 19, Loss: 0.6398, Accuracy: 0.9927
# Best Epoch: 9, Best Valid Acc: 0.9977641140301845
# Valid Acc (with Epoch valid set) on Loaded Best Model: 0.9977641140301845
# Final Acc (with TEST set) on Loaded Best Model: 0.9996635262449529 (time: 0.010901717729465936)

# %%
result_df = pd.DataFrame(result_dict)
result_df
# Out:
#     backbone case  accuracy  inference_time
# 0   resnet18    1  0.998318        0.004772
# 1   resnet34    1  0.998318        0.008407
# 2   resnet50    1  0.997645        0.011896
# 3   resnet18    2  0.995962        0.003151
# 4   resnet34    2  0.996972        0.004228
# 5   resnet50    2  0.997645        0.006893
# 6   resnet18    3  0.997981        0.002459
# 7   resnet34    3  0.999327        0.005126
# 8   resnet50    3  0.997645        0.007312
# 9   resnet18  4_1  0.997981        0.004743
# 10  resnet34  4_1  0.998654        0.008220
# 11  resnet50  4_1  0.996972        0.011140
# 12  resnet18  4_2  0.997981        0.006374
# 13  resnet34  4_2  0.997981        0.009676
# 14  resnet50  4_2  0.999664        0.010902

# %%
result_df.to_csv('result_experiment_2.csv')
