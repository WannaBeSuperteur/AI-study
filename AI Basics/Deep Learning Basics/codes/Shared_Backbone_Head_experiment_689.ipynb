# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms

import plotly.graph_objects as go

import random
import pandas as pd
import numpy as np

# !pip install torchinfo
from torchinfo import summary
# Out:
# Requirement already satisfied: torchinfo in /usr/local/lib/python3.12/dist-packages (1.8.0)

# %%
# 경고 미 표시

import warnings
warnings.filterwarnings('ignore')

# %%
# Random Seed 고정 (학습 반복 시행 시에도 동일한 결과가 나오도록)

seed = 20251003

random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)
torch.cuda.manual_seed_all(seed)

# %%
# 데이터셋 로딩

transform = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.5,), (0.5,))])

train_dataset = torchvision.datasets.MNIST(root='./data',
                                           train=True,
                                           transform=transform,
                                           download=True)

test_dataset = torchvision.datasets.MNIST(root='./data',
                                          train=False,
                                          transform=transform,
                                          download=True)

# %% [markdown]
# **1. 데이터셋 분석**

# %%
# 데이터셋 로딩

from torch.utils.data import DataLoader

BATCH_SIZE = 32

train_loader = DataLoader(train_dataset,
                          batch_size=BATCH_SIZE,
                          shuffle=True)

test_loader = DataLoader(test_dataset,
                         batch_size=BATCH_SIZE,
                         shuffle=False)

# %%
# 클래스 불균형 분석

# 학습 데이터
train_labels = torch.tensor(train_dataset.targets)
train_class_counts = torch.bincount(train_labels)
print(f'train data : {train_class_counts}')

# 테스트 데이터
test_labels = torch.tensor(test_dataset.targets)
test_class_counts = torch.bincount(test_labels)
print(f'test  data : {test_class_counts}')

NUM_CLASSES = len(train_class_counts)
# Out:
# train data : tensor([5923, 6742, 5958, 6131, 5842, 5421, 5918, 6265, 5851, 5949])
# test  data : tensor([ 980, 1135, 1032, 1010,  982,  892,  958, 1028,  974, 1009])

# %%
# 클래스 불균형 분석 (percentage)

train_class_percentage = np.array(train_class_counts) * 100.0 / sum(train_class_counts)

train_y_distrib = pd.DataFrame({'class': list(range(NUM_CLASSES)),
                                'count': train_class_counts,
                                'percentage (%)': train_class_percentage})

train_y_distrib
# Out:
#    class  count  percentage (%)
# 0      0   5923        9.871667
# 1      1   6742       11.236667
# 2      2   5958        9.930000
# 3      3   6131       10.218333
# 4      4   5842        9.736667
# 5      5   5421        9.035000
# 6      6   5918        9.863333
# 7      7   6265       10.441667
# 8      8   5851        9.751667
# 9      9   5949        9.915000

# %%
test_class_percentage = np.array(test_class_counts) * 100.0 / sum(test_class_counts)

test_y_distrib = pd.DataFrame({'class': list(range(NUM_CLASSES)),
                               'count': test_class_counts,
                               'percentage (%)': test_class_percentage})

test_y_distrib
# Out:
#    class  count  percentage (%)
# 0      0    980            9.80
# 1      1   1135           11.35
# 2      2   1032           10.32
# 3      3   1010           10.10
# 4      4    982            9.82
# 5      5    892            8.92
# 6      6    958            9.58
# 7      7   1028           10.28
# 8      8    974            9.74
# 9      9   1009           10.09

# %% [markdown]
# **2. 6, 8, 9 숫자 데이터만 추출**

# %%
from torch.utils.data import Subset

# train dataset
train_targets = torch.tensor(train_dataset.targets)
train_mask = (train_targets == 6) | (train_targets == 8) | (train_targets == 9)
train_indices = torch.where(train_mask)[0]

train_subset = Subset(train_dataset, train_indices)

# test dataset
test_targets = torch.tensor(test_dataset.targets)
test_mask = (test_targets == 6) | (test_targets == 8) | (test_targets == 9)
test_indices = torch.where(test_mask)[0]

test_subset = Subset(test_dataset, test_indices)

# %%
# train, test Data Loader 갱신

train_subset_loader = DataLoader(train_subset,
                                 batch_size=BATCH_SIZE,
                                 shuffle=True)

test_subset_loader = DataLoader(test_subset,
                                batch_size=BATCH_SIZE,
                                shuffle=False)

# %%
# train, test Data Loader 의 class 가 6, 8, 9 뿐인지 확인

train_subset_labels = train_subset.dataset.targets[train_subset.indices]
train_subset_class_counts = torch.bincount(train_subset_labels)
print(f'train data (subset) [6,8,9] : {train_subset_class_counts}')

test_subset_labels = test_subset.dataset.targets[test_subset.indices]
test_subset_class_counts = torch.bincount(test_subset_labels)
print(f'test  data (subset) [6,8,9] : {test_subset_class_counts}')
# Out:
# train data (subset) [6,8,9] : tensor([   0,    0,    0,    0,    0,    0, 5918,    0, 5851, 5949])
# test  data (subset) [6,8,9] : tensor([   0,    0,    0,    0,    0,    0,  958,    0,  974, 1009])

# %% [markdown]
# **3. CNN 모델 정의**

# %%
# 1. Non-Shared backbone & Shared head

class CNN_CASE_1(nn.Module):
    def __init__(self, backbone_1, backbone_2):
        super(CNN_CASE_1, self).__init__()

        self.backbone_1 = backbone_1
        self.backbone_2 = backbone_2
        self.final_linear = nn.Linear(2000, 3)
        self.final_softmax = nn.Softmax(dim=1)

    def forward(self, x):
        x1 = self.backbone_1(x)
        x2 = self.backbone_2(x)
        x = torch.concatenate([x1, x2], dim=1)

        x = self.final_linear(x)
        x = self.final_softmax(x)

        return x

# %%
# 2. Shared backbone & Shared head

class CNN_CASE_2(nn.Module):
    def __init__(self, backbone):
        super(CNN_CASE_2, self).__init__()

        self.backbone = backbone
        self.final_linear = nn.Linear(1000, 3)
        self.final_softmax = nn.Softmax(dim=1)

    def forward(self, x):
        x = self.backbone(x)
        x = self.final_linear(x)
        x = self.final_softmax(x)

        return x

# %%
# 3. Shared backbone & Non-Shared head

class CNN_CASE_3(nn.Module):
    def __init__(self, backbone):
        super(CNN_CASE_3, self).__init__()

        self.backbone = backbone
        self.final_linear_1 = nn.Linear(1000, 2)
        self.final_linear_2 = nn.Linear(1000, 2)
        self.final_softmax = nn.Softmax(dim=1)

    def forward(self, x):
        x = self.backbone(x)
        x1 = self.final_linear_1(x)
        x2 = self.final_linear_2(x)
        x1 = self.final_softmax(x1)
        x2 = self.final_softmax(x2)

        return x1, x2

# %%
# 4. Non-Shared backbone & Non-Shared head (4-1)

class CNN_CASE_4_1(nn.Module):
    def __init__(self, backbone_1, backbone_2):
        super(CNN_CASE_4_1, self).__init__()

        self.backbone_1 = backbone_1
        self.backbone_2 = backbone_2
        self.final_linear_1 = nn.Linear(2000, 2)
        self.final_linear_2 = nn.Linear(2000, 2)
        self.final_softmax = nn.Softmax(dim=1)

    def forward(self, x):
        x11 = self.backbone_1(x)
        x12 = self.backbone_2(x)
        x = torch.concatenate([x11, x12], dim=1)

        x21 = self.final_linear_1(x)
        x22 = self.final_linear_2(x)
        x21 = self.final_softmax(x21)
        x22 = self.final_softmax(x22)

        return x21, x22

# %%
# 5. Non-Shared backbone & Non-Shared head (4-2)

class CNN_CASE_4_2(nn.Module):
    def __init__(self, backbone_1, backbone_2):
        super(CNN_CASE_4_2, self).__init__()

        self.backbone_1 = backbone_1
        self.backbone_2 = backbone_2
        self.final_linear_1 = nn.Linear(1000, 2)
        self.final_linear_2 = nn.Linear(1000, 2)
        self.final_softmax = nn.Softmax(dim=1)

    def forward(self, x):
        x11 = self.backbone_1(x)
        x12 = self.backbone_2(x)
        x21 = self.final_linear_1(x11)
        x22 = self.final_linear_2(x12)
        x21 = self.final_softmax(x21)
        x22 = self.final_softmax(x22)

        return x21, x22

# %% [markdown]
# **4. backbone model 로딩**

# %%
import torchvision.models as models

def define_model(backbone_name, case_name, device):

    # model count
    if case_name in ['1', '4_1', '4_2']:
        model_count = 2
    else:
        model_count = 1

    # load pre-trained backbone model
    pretrained_models = []

    for _ in range(model_count):
        if backbone_name == 'resnet18':
            pretrained_model = models.resnet18(pretrained=True)

        elif backbone_name == 'resnet34':
            pretrained_model = models.resnet34(pretrained=True)

        else:  # resnet50
            pretrained_model = models.resnet50(pretrained=True)

        pretrained_model.conv1 = torch.nn.Conv2d(1, 64,
                                                 kernel_size=(7, 7),
                                                 stride=(2, 2),
                                                 padding=(3, 3),
                                                 bias=False)
        pretrained_models.append(pretrained_model)

    # define full model
    if case_name == '1':
        model = CNN_CASE_1(backbone_1=pretrained_models[0],
                           backbone_2=pretrained_models[1])

    elif case_name == '2':
        model = CNN_CASE_2(backbone=pretrained_models[0])

    elif case_name == '3':
        model = CNN_CASE_3(backbone=pretrained_models[0])

    elif case_name == '4_1':
        model = CNN_CASE_4_1(backbone_1=pretrained_models[0],
                             backbone_2=pretrained_models[1])

    elif case_name == '4_2':
        model = CNN_CASE_4_2(backbone_1=pretrained_models[0],
                             backbone_2=pretrained_models[1])

    # device & optimizer & scheduler setting
    model.to(device)
    model.optimizer = torch.optim.AdamW(model.parameters(), lr=0.0001)
    model.scheduler = torch.optim.lr_scheduler.ExponentialLR(optimizer=model.optimizer,
                                                             gamma=0.95)

    return model

# %% [markdown]
# **5. 모델 구조 출력**

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
input_size=(BATCH_SIZE, 1, 28, 28)

# %%
temp_backbone_name = 'resnet18'

# %%
# 1. Non-Shared backbone & Shared head

model_case_1 = define_model(temp_backbone_name, case_name='1', device=device)
print(summary(model=model_case_1, input_size=input_size))
# Out:
# ===============================================================================================
# Layer (type:depth-idx)                        Output Shape              Param #
# ===============================================================================================
# CNN_CASE_1                                    [32, 3]                   --
# ├─ResNet: 1-1                                 [32, 1000]                --
# │    └─Conv2d: 2-1                            [32, 64, 14, 14]          3,136
# │    └─BatchNorm2d: 2-2                       [32, 64, 14, 14]          128
# │    └─ReLU: 2-3                              [32, 64, 14, 14]          --
# │    └─MaxPool2d: 2-4                         [32, 64, 7, 7]            --
# │    └─Sequential: 2-5                        [32, 64, 7, 7]            --
# │    │    └─BasicBlock: 3-1                   [32, 64, 7, 7]            73,984
# │    │    └─BasicBlock: 3-2                   [32, 64, 7, 7]            73,984
# │    └─Sequential: 2-6                        [32, 128, 4, 4]           --
# │    │    └─BasicBlock: 3-3                   [32, 128, 4, 4]           230,144
# │    │    └─BasicBlock: 3-4                   [32, 128, 4, 4]           295,424
# │    └─Sequential: 2-7                        [32, 256, 2, 2]           --
# │    │    └─BasicBlock: 3-5                   [32, 256, 2, 2]           919,040
# │    │    └─BasicBlock: 3-6                   [32, 256, 2, 2]           1,180,672
# │    └─Sequential: 2-8                        [32, 512, 1, 1]           --
# │    │    └─BasicBlock: 3-7                   [32, 512, 1, 1]           3,673,088
# │    │    └─BasicBlock: 3-8                   [32, 512, 1, 1]           4,720,640
# │    └─AdaptiveAvgPool2d: 2-9                 [32, 512, 1, 1]           --
# │    └─Linear: 2-10                           [32, 1000]                513,000
# ├─ResNet: 1-2                                 [32, 1000]                --
# │    └─Conv2d: 2-11                           [32, 64, 14, 14]          3,136
# │    └─BatchNorm2d: 2-12                      [32, 64, 14, 14]          128
# │    └─ReLU: 2-13                             [32, 64, 14, 14]          --
# │    └─MaxPool2d: 2-14                        [32, 64, 7, 7]            --
# │    └─Sequential: 2-15                       [32, 64, 7, 7]            --
# │    │    └─BasicBlock: 3-9                   [32, 64, 7, 7]            73,984
# │    │    └─BasicBlock: 3-10                  [32, 64, 7, 7]            73,984
# │    └─Sequential: 2-16                       [32, 128, 4, 4]           --
# │    │    └─BasicBlock: 3-11                  [32, 128, 4, 4]           230,144
# │    │    └─BasicBlock: 3-12                  [32, 128, 4, 4]           295,424
# │    └─Sequential: 2-17                       [32, 256, 2, 2]           --
# │    │    └─BasicBlock: 3-13                  [32, 256, 2, 2]           919,040
# │    │    └─BasicBlock: 3-14                  [32, 256, 2, 2]           1,180,672
# │    └─Sequential: 2-18                       [32, 512, 1, 1]           --
# │    │    └─BasicBlock: 3-15                  [32, 512, 1, 1]           3,673,088
# │    │    └─BasicBlock: 3-16                  [32, 512, 1, 1]           4,720,640
# │    └─AdaptiveAvgPool2d: 2-19                [32, 512, 1, 1]           --
# │    └─Linear: 2-20                           [32, 1000]                513,000
# ├─Linear: 1-3                                 [32, 3]                   6,003
# ├─Softmax: 1-4                                [32, 3]                   --
# ===============================================================================================
# Total params: 23,372,483
# Trainable params: 23,372,483
# Non-trainable params: 0
# Total mult-adds (Units.GIGABYTES): 2.15
# ===============================================================================================
# Input size (MB): 0.10
# Forward/backward pass size (MB): 44.55
# Params size (MB): 93.49
# Estimated Total Size (MB): 138.14
# ===============================================================================================

# %%
# 2. Shared backbone & Shared head

model_case_2 = define_model(temp_backbone_name, case_name='2', device=device)
print(summary(model=model_case_2, input_size=input_size))
# Out:
# ===============================================================================================
# Layer (type:depth-idx)                        Output Shape              Param #
# ===============================================================================================
# CNN_CASE_2                                    [32, 3]                   --
# ├─ResNet: 1-1                                 [32, 1000]                --
# │    └─Conv2d: 2-1                            [32, 64, 14, 14]          3,136
# │    └─BatchNorm2d: 2-2                       [32, 64, 14, 14]          128
# │    └─ReLU: 2-3                              [32, 64, 14, 14]          --
# │    └─MaxPool2d: 2-4                         [32, 64, 7, 7]            --
# │    └─Sequential: 2-5                        [32, 64, 7, 7]            --
# │    │    └─BasicBlock: 3-1                   [32, 64, 7, 7]            73,984
# │    │    └─BasicBlock: 3-2                   [32, 64, 7, 7]            73,984
# │    └─Sequential: 2-6                        [32, 128, 4, 4]           --
# │    │    └─BasicBlock: 3-3                   [32, 128, 4, 4]           230,144
# │    │    └─BasicBlock: 3-4                   [32, 128, 4, 4]           295,424
# │    └─Sequential: 2-7                        [32, 256, 2, 2]           --
# │    │    └─BasicBlock: 3-5                   [32, 256, 2, 2]           919,040
# │    │    └─BasicBlock: 3-6                   [32, 256, 2, 2]           1,180,672
# │    └─Sequential: 2-8                        [32, 512, 1, 1]           --
# │    │    └─BasicBlock: 3-7                   [32, 512, 1, 1]           3,673,088
# │    │    └─BasicBlock: 3-8                   [32, 512, 1, 1]           4,720,640
# │    └─AdaptiveAvgPool2d: 2-9                 [32, 512, 1, 1]           --
# │    └─Linear: 2-10                           [32, 1000]                513,000
# ├─Linear: 1-2                                 [32, 3]                   3,003
# ├─Softmax: 1-3                                [32, 3]                   --
# ===============================================================================================
# Total params: 11,686,243
# Trainable params: 11,686,243
# Non-trainable params: 0
# Total mult-adds (Units.GIGABYTES): 1.07
# ===============================================================================================
# Input size (MB): 0.10
# Forward/backward pass size (MB): 22.28
# Params size (MB): 46.74
# Estimated Total Size (MB): 69.12
# ===============================================================================================

# %%
# 3. Shared backbone & Non-Shared head

model_case_3 = define_model(temp_backbone_name, case_name='3', device=device)
print(summary(model=model_case_3, input_size=input_size))
# Out:
# ===============================================================================================
# Layer (type:depth-idx)                        Output Shape              Param #
# ===============================================================================================
# CNN_CASE_3                                    [32, 2]                   --
# ├─ResNet: 1-1                                 [32, 1000]                --
# │    └─Conv2d: 2-1                            [32, 64, 14, 14]          3,136
# │    └─BatchNorm2d: 2-2                       [32, 64, 14, 14]          128
# │    └─ReLU: 2-3                              [32, 64, 14, 14]          --
# │    └─MaxPool2d: 2-4                         [32, 64, 7, 7]            --
# │    └─Sequential: 2-5                        [32, 64, 7, 7]            --
# │    │    └─BasicBlock: 3-1                   [32, 64, 7, 7]            73,984
# │    │    └─BasicBlock: 3-2                   [32, 64, 7, 7]            73,984
# │    └─Sequential: 2-6                        [32, 128, 4, 4]           --
# │    │    └─BasicBlock: 3-3                   [32, 128, 4, 4]           230,144
# │    │    └─BasicBlock: 3-4                   [32, 128, 4, 4]           295,424
# │    └─Sequential: 2-7                        [32, 256, 2, 2]           --
# │    │    └─BasicBlock: 3-5                   [32, 256, 2, 2]           919,040
# │    │    └─BasicBlock: 3-6                   [32, 256, 2, 2]           1,180,672
# │    └─Sequential: 2-8                        [32, 512, 1, 1]           --
# │    │    └─BasicBlock: 3-7                   [32, 512, 1, 1]           3,673,088
# │    │    └─BasicBlock: 3-8                   [32, 512, 1, 1]           4,720,640
# │    └─AdaptiveAvgPool2d: 2-9                 [32, 512, 1, 1]           --
# │    └─Linear: 2-10                           [32, 1000]                513,000
# ├─Linear: 1-2                                 [32, 2]                   2,002
# ├─Linear: 1-3                                 [32, 2]                   2,002
# ├─Softmax: 1-4                                [32, 2]                   --
# ├─Softmax: 1-5                                [32, 2]                   --
# ===============================================================================================
# Total params: 11,687,244
# Trainable params: 11,687,244
# Non-trainable params: 0
# Total mult-adds (Units.GIGABYTES): 1.07
# ===============================================================================================
# Input size (MB): 0.10
# Forward/backward pass size (MB): 22.28
# Params size (MB): 46.75
# Estimated Total Size (MB): 69.13
# ===============================================================================================

# %%
# 4. Non-Shared backbone & Non-Shared head (4-1)

model_case_4_1 = define_model(temp_backbone_name, case_name='4_1', device=device)
print(summary(model=model_case_4_1, input_size=input_size))
# Out:
# ===============================================================================================
# Layer (type:depth-idx)                        Output Shape              Param #
# ===============================================================================================
# CNN_CASE_4_1                                  [32, 2]                   --
# ├─ResNet: 1-1                                 [32, 1000]                --
# │    └─Conv2d: 2-1                            [32, 64, 14, 14]          3,136
# │    └─BatchNorm2d: 2-2                       [32, 64, 14, 14]          128
# │    └─ReLU: 2-3                              [32, 64, 14, 14]          --
# │    └─MaxPool2d: 2-4                         [32, 64, 7, 7]            --
# │    └─Sequential: 2-5                        [32, 64, 7, 7]            --
# │    │    └─BasicBlock: 3-1                   [32, 64, 7, 7]            73,984
# │    │    └─BasicBlock: 3-2                   [32, 64, 7, 7]            73,984
# │    └─Sequential: 2-6                        [32, 128, 4, 4]           --
# │    │    └─BasicBlock: 3-3                   [32, 128, 4, 4]           230,144
# │    │    └─BasicBlock: 3-4                   [32, 128, 4, 4]           295,424
# │    └─Sequential: 2-7                        [32, 256, 2, 2]           --
# │    │    └─BasicBlock: 3-5                   [32, 256, 2, 2]           919,040
# │    │    └─BasicBlock: 3-6                   [32, 256, 2, 2]           1,180,672
# │    └─Sequential: 2-8                        [32, 512, 1, 1]           --
# │    │    └─BasicBlock: 3-7                   [32, 512, 1, 1]           3,673,088
# │    │    └─BasicBlock: 3-8                   [32, 512, 1, 1]           4,720,640
# │    └─AdaptiveAvgPool2d: 2-9                 [32, 512, 1, 1]           --
# │    └─Linear: 2-10                           [32, 1000]                513,000
# ├─ResNet: 1-2                                 [32, 1000]                --
# │    └─Conv2d: 2-11                           [32, 64, 14, 14]          3,136
# │    └─BatchNorm2d: 2-12                      [32, 64, 14, 14]          128
# │    └─ReLU: 2-13                             [32, 64, 14, 14]          --
# │    └─MaxPool2d: 2-14                        [32, 64, 7, 7]            --
# │    └─Sequential: 2-15                       [32, 64, 7, 7]            --
# │    │    └─BasicBlock: 3-9                   [32, 64, 7, 7]            73,984
# │    │    └─BasicBlock: 3-10                  [32, 64, 7, 7]            73,984
# │    └─Sequential: 2-16                       [32, 128, 4, 4]           --
# │    │    └─BasicBlock: 3-11                  [32, 128, 4, 4]           230,144
# │    │    └─BasicBlock: 3-12                  [32, 128, 4, 4]           295,424
# │    └─Sequential: 2-17                       [32, 256, 2, 2]           --
# │    │    └─BasicBlock: 3-13                  [32, 256, 2, 2]           919,040
# │    │    └─BasicBlock: 3-14                  [32, 256, 2, 2]           1,180,672
# │    └─Sequential: 2-18                       [32, 512, 1, 1]           --
# │    │    └─BasicBlock: 3-15                  [32, 512, 1, 1]           3,673,088
# │    │    └─BasicBlock: 3-16                  [32, 512, 1, 1]           4,720,640
# │    └─AdaptiveAvgPool2d: 2-19                [32, 512, 1, 1]           --
# │    └─Linear: 2-20                           [32, 1000]                513,000
# ├─Linear: 1-3                                 [32, 2]                   4,002
# ├─Linear: 1-4                                 [32, 2]                   4,002
# ├─Softmax: 1-5                                [32, 2]                   --
# ├─Softmax: 1-6                                [32, 2]                   --
# ===============================================================================================
# Total params: 23,374,484
# Trainable params: 23,374,484
# Non-trainable params: 0
# Total mult-adds (Units.GIGABYTES): 2.15
# ===============================================================================================
# Input size (MB): 0.10
# Forward/backward pass size (MB): 44.55
# Params size (MB): 93.50
# Estimated Total Size (MB): 138.15
# ===============================================================================================

# %%
# 5. Non-Shared backbone & Non-Shared head (4-2)

model_case_4_2 = define_model(temp_backbone_name, case_name='4_2', device=device)
print(summary(model=model_case_4_2, input_size=input_size))
# Out:
# ===============================================================================================
# Layer (type:depth-idx)                        Output Shape              Param #
# ===============================================================================================
# CNN_CASE_4_2                                  [32, 2]                   --
# ├─ResNet: 1-1                                 [32, 1000]                --
# │    └─Conv2d: 2-1                            [32, 64, 14, 14]          3,136
# │    └─BatchNorm2d: 2-2                       [32, 64, 14, 14]          128
# │    └─ReLU: 2-3                              [32, 64, 14, 14]          --
# │    └─MaxPool2d: 2-4                         [32, 64, 7, 7]            --
# │    └─Sequential: 2-5                        [32, 64, 7, 7]            --
# │    │    └─BasicBlock: 3-1                   [32, 64, 7, 7]            73,984
# │    │    └─BasicBlock: 3-2                   [32, 64, 7, 7]            73,984
# │    └─Sequential: 2-6                        [32, 128, 4, 4]           --
# │    │    └─BasicBlock: 3-3                   [32, 128, 4, 4]           230,144
# │    │    └─BasicBlock: 3-4                   [32, 128, 4, 4]           295,424
# │    └─Sequential: 2-7                        [32, 256, 2, 2]           --
# │    │    └─BasicBlock: 3-5                   [32, 256, 2, 2]           919,040
# │    │    └─BasicBlock: 3-6                   [32, 256, 2, 2]           1,180,672
# │    └─Sequential: 2-8                        [32, 512, 1, 1]           --
# │    │    └─BasicBlock: 3-7                   [32, 512, 1, 1]           3,673,088
# │    │    └─BasicBlock: 3-8                   [32, 512, 1, 1]           4,720,640
# │    └─AdaptiveAvgPool2d: 2-9                 [32, 512, 1, 1]           --
# │    └─Linear: 2-10                           [32, 1000]                513,000
# ├─ResNet: 1-2                                 [32, 1000]                --
# │    └─Conv2d: 2-11                           [32, 64, 14, 14]          3,136
# │    └─BatchNorm2d: 2-12                      [32, 64, 14, 14]          128
# │    └─ReLU: 2-13                             [32, 64, 14, 14]          --
# │    └─MaxPool2d: 2-14                        [32, 64, 7, 7]            --
# │    └─Sequential: 2-15                       [32, 64, 7, 7]            --
# │    │    └─BasicBlock: 3-9                   [32, 64, 7, 7]            73,984
# │    │    └─BasicBlock: 3-10                  [32, 64, 7, 7]            73,984
# │    └─Sequential: 2-16                       [32, 128, 4, 4]           --
# │    │    └─BasicBlock: 3-11                  [32, 128, 4, 4]           230,144
# │    │    └─BasicBlock: 3-12                  [32, 128, 4, 4]           295,424
# │    └─Sequential: 2-17                       [32, 256, 2, 2]           --
# │    │    └─BasicBlock: 3-13                  [32, 256, 2, 2]           919,040
# │    │    └─BasicBlock: 3-14                  [32, 256, 2, 2]           1,180,672
# │    └─Sequential: 2-18                       [32, 512, 1, 1]           --
# │    │    └─BasicBlock: 3-15                  [32, 512, 1, 1]           3,673,088
# │    │    └─BasicBlock: 3-16                  [32, 512, 1, 1]           4,720,640
# │    └─AdaptiveAvgPool2d: 2-19                [32, 512, 1, 1]           --
# │    └─Linear: 2-20                           [32, 1000]                513,000
# ├─Linear: 1-3                                 [32, 2]                   2,002
# ├─Linear: 1-4                                 [32, 2]                   2,002
# ├─Softmax: 1-5                                [32, 2]                   --
# ├─Softmax: 1-6                                [32, 2]                   --
# ===============================================================================================
# Total params: 23,370,484
# Trainable params: 23,370,484
# Non-trainable params: 0
# Total mult-adds (Units.GIGABYTES): 2.15
# ===============================================================================================
# Input size (MB): 0.10
# Forward/backward pass size (MB): 44.55
# Params size (MB): 93.48
# Estimated Total Size (MB): 138.14
# ===============================================================================================

# %% [markdown]
# **6. 데이터셋 분리**
#
# * Train Data -> Train Data + Valid Data

# %%
# dataset size

num_tv = sum(train_subset_class_counts)
num_valid = int(0.1 * num_tv)
num_train = num_tv - num_valid

# %%
# 데이터셋 분리

from torch.utils.data import random_split

train_dataset, valid_dataset = random_split(train_subset, [num_train, num_valid])

# %%
# {0,1,2} -> {6,8,9} Mapping 된 DataLoader 생성

from torch.utils.data import Dataset

class MappedDataset(Dataset):
    def __init__(self, dataset):
        self.dataset = dataset

    def __len__(self):
        return len(self.dataset)

    def __getitem__(self, idx):
        img, target = self.dataset[idx]
        target_mapping = {6: 0, 8: 1, 9: 2}
        target = target_mapping[target]

        return img, target

# %%
# DataLoader 생성

train_dataset_loader = DataLoader(MappedDataset(train_dataset),
                                  batch_size=BATCH_SIZE,
                                  shuffle=True)

valid_dataset_loader = DataLoader(MappedDataset(valid_dataset),
                                  batch_size=BATCH_SIZE,
                                  shuffle=False)

test_dataset_loader = DataLoader(MappedDataset(test_subset),
                                 batch_size=BATCH_SIZE,
                                 shuffle=False)

# %%
# {6,8} vs. {9} / {6,9} vs. {8} Split 된 DataLoader 생성

class DualOutputDataset(Dataset):
    def __init__(self, dataset):
        self.dataset = dataset

    def __len__(self):
        return len(self.dataset)

    def __getitem__(self, idx):
        img, target = self.dataset[idx]
        target1_mapping = {6: 0, 8: 0, 9: 1}
        target2_mapping = {6: 0, 8: 1, 9: 0}

        target1 = target1_mapping[target]
        target2 = target2_mapping[target]

        return img, [target1, target2]

# %%
# Dual Output Dataset 생성

train_01_02_dataset_loader = DataLoader(DualOutputDataset(train_dataset),
                                        batch_size=BATCH_SIZE,
                                        shuffle=True)

valid_01_02_dataset_loader = DataLoader(DualOutputDataset(valid_dataset),
                                        batch_size=BATCH_SIZE,
                                        shuffle=False)

test_01_02_dataset_loader = DataLoader(DualOutputDataset(test_subset),
                                       batch_size=BATCH_SIZE,
                                       shuffle=False)

# %% [markdown]
# **7. 모델 학습 함수 정의**

# %%
MAX_EPOCHS = 9999
EARLY_STOPPING_ROUNDS = 10  # Early Stopping Patience (epochs)

# %%
# dual labels -> PyTorch tensor

def convert_to_tensor(labels):
    labels[0] = list(labels[0])
    labels[1] = list(labels[1])
    labels_tensor = torch.tensor(labels)
    labels_tensor = labels_tensor.transpose(0, 1)

    return labels_tensor

# %%
# 모델 학습 실시

# args :
# - model           : 학습할 모델
# - train_loader    : Training Data Loader
# - train_loss_list : 각 epoch 에서의 train loss 기록
# - is_dual_head    : 신경망 출력값, 즉 MLP Head 가 2개인지의 여부

# returns :
# - train_loss : 모델의 Train Loss

def run_train(model, train_loader, train_loss_list, is_dual_head, verbose):
    model.train()
    train_loss = 0.0
    train_idx = 0

    for images, labels in train_loader:
        if is_dual_head:
            labels = convert_to_tensor(labels)
        images, labels = images.to(device), labels.to(device)

        # train 실시
        model.optimizer.zero_grad()
        outputs = model(images)

        if is_dual_head:
            loss1 = nn.CrossEntropyLoss()(outputs[0], labels[:, 0])
            loss2 = nn.CrossEntropyLoss()(outputs[1], labels[:, 1])
            loss = loss1 + loss2
        else:
            loss = nn.CrossEntropyLoss()(outputs, labels)

        loss.backward()
        model.optimizer.step()

        train_loss += loss.item()
        train_idx += 1

        if verbose:
            if train_idx % 20 == 0:
                print(f'idx: {train_idx}, loss for current idx: {loss.item():.6f}')

    train_loss_list.append(train_loss / len(train_loader))
    return train_loss_list[-1]

# %%
import time

# 모델 validation / test 실시

# args :
# - model                : validation/test 할 모델
# - valid_or_test_loader : validation/test Data Loader
# - is_dual_head         : 신경망 출력값, 즉 MLP Head 가 2개인지의 여부

# returns :
# - accuracy       : 모델의 validation/test 정확도
# - inference_time : inference 시간 (seconds)

def run_valid_or_test(model, valid_or_test_loader, is_dual_head):
    model.eval()
    correct, total = 0, 0
    inference_time_sum = 0.0
    valid_test_idx = 0

    with torch.no_grad():
        for images, labels in valid_or_test_loader:
            if is_dual_head:
                labels = convert_to_tensor(labels)
            images, labels = images.to(device), labels.to(device)

            start_at = time.time()
            outputs = model(images)
            inference_time_sum += time.time() - start_at

            # validation/test 실시 및 정확도 측정
            if is_dual_head:
                _, predicted_1 = torch.max(outputs[0], 1)
                _, predicted_2 = torch.max(outputs[1], 1)
                correct += ((predicted_1 == labels[:, 0]) & (predicted_2 == labels[:, 1])).sum().item()

            else:
                _, predicted = torch.max(outputs, 1)
                correct += (predicted == labels).sum().item()

            total += labels.size(0)
            valid_test_idx += 1

    accuracy = correct / total
    inference_time = inference_time_sum / valid_test_idx

    return accuracy, inference_time

# %%
# 모델 학습 및 validation 전체 프로세스

# args :
# - model         : 학습할 모델
# - train_loader  : Training Data Loader
# - valid_loader  : Valid Data Loader
# - test_loader   : Test Data Loader
# - backbone_name : Backbone 모델 이름 ('resnet18', 'resnet34' or 'resnet50')
# - case_name     : 모델 구조 case 이름 ('1', '2', '3', '4_1' or '4_2')
# - verbose       : 학습 중 프로세스 출력 여부

# returns :
# - final_acc      : 해당 하이퍼파라미터 조합에 대한 최종 Accuracy (valid_acc 이 가장 높았던 epoch 의 모델로 측정)
# - inference_time : inference 시간 (seconds)

def run_model_common(model, train_loader, valid_loader, test_loader,
                     backbone_name, case_name, verbose=False):

    train_loss_list = []       # train loss
    valid_acc_list = []        # valid accuracy
    max_valid_acc = 0.0        # max validation accuracy
    best_valid_acc_epoch = -1  # valid_acc 이 가장 높았던 epoch (여기서는 Loss 가 아닌 Accuracy 기준 Early Stopping)
    best_epoch_model = None    # valid_acc 이 가장 높았던 epoch 의 모델

    is_dual_head = case_name in ['3', '4_1', '4_2']

    # 1. 학습 실시
    for epoch in range(MAX_EPOCHS):

        # 1-1. train model
        train_loss = run_train(model,
                               train_loader,
                               train_loss_list,
                               is_dual_head,
                               verbose=(verbose and epoch == 0))

        # 1-2. validate model (with VALID SET)
        epoch_acc, _ = run_valid_or_test(model, valid_loader, is_dual_head)
        valid_acc_list.append(epoch_acc)

        # 1-3. Early Stopping 처리 (overfitting 방지)
        if epoch_acc > max_valid_acc:
            max_valid_acc = epoch_acc
            best_valid_acc_epoch = epoch

            best_epoch_model = define_model(backbone_name, case_name, device)
            best_epoch_model.load_state_dict(model.state_dict())

            if verbose:
                print('best model updated')

        if epoch - best_valid_acc_epoch >= EARLY_STOPPING_ROUNDS:
            break

        # 1-4. 결과 출력
        if verbose:
            print(f"Epoch {epoch+1}, Loss: {train_loss:.4f}, Accuracy: {epoch_acc:.4f}")

    # check best-epoch model correctly loaded
    checked_acc, _ = run_valid_or_test(best_epoch_model, valid_loader, is_dual_head)

    if verbose:
        print(f"Best Epoch: {best_valid_acc_epoch}, Best Valid Acc: {max_valid_acc}")
        print(f"Valid Acc (with Epoch valid set) on Loaded Best Model: {checked_acc}")

    assert abs(max_valid_acc - checked_acc) < 1e-6

    # 2. test best-epoch model (with TEST SET)
    final_acc, inference_time = run_valid_or_test(best_epoch_model, test_loader, is_dual_head)

    if verbose:
        print(f"Final Acc (with TEST set) on Loaded Best Model: {final_acc} (time: {inference_time})")

    return final_acc, inference_time

# %% [markdown]
# **8. 학습 실시**

# %%
print(device)
# Out:
# cuda

# %%
result_dict = {
    'backbone': [],
    'case': [],
    'accuracy': [],
    'inference_time': []
}

dataloader_by_case_name = {
    'dual_head': {
        'train': train_01_02_dataset_loader,
        'valid': valid_01_02_dataset_loader,
        'test': test_01_02_dataset_loader
    },
    'single_head': {
        'train': train_dataset_loader,
        'valid': valid_dataset_loader,
        'test': test_dataset_loader
    }
}

for case_name in ['1', '2', '3', '4_1', '4_2']:
    if case_name in ['3', '4_1', '4_2']:
        head_type = 'dual_head'
    else:
        head_type = 'single_head'

    for backbone_name in ['resnet18', 'resnet34', 'resnet50']:
        print(f'\n=== case={case_name}, backbone={backbone_name} ===')
        model = define_model(backbone_name, case_name, device=device)

        train_loader = dataloader_by_case_name[head_type]['train']
        valid_loader = dataloader_by_case_name[head_type]['valid']
        test_loader = dataloader_by_case_name[head_type]['test']

        final_acc, inference_time = run_model_common(model,
                                                     train_loader=train_loader,
                                                     valid_loader=valid_loader,
                                                     test_loader=test_loader,
                                                     backbone_name=backbone_name,
                                                     case_name=case_name,
                                                     verbose=True)

        result_dict['backbone'].append(backbone_name)
        result_dict['case'].append(case_name)
        result_dict['accuracy'].append(final_acc)
        result_dict['inference_time'].append(inference_time)
# Out:
# === case=1, backbone=resnet18 ===
# idx: 20, loss for current idx: 0.691700
# idx: 40, loss for current idx: 0.644559
# idx: 60, loss for current idx: 0.688413
# idx: 80, loss for current idx: 0.615879
# idx: 100, loss for current idx: 0.620620
# idx: 120, loss for current idx: 0.594722
# idx: 140, loss for current idx: 0.640991
# idx: 160, loss for current idx: 0.582352
# idx: 180, loss for current idx: 0.621172
# idx: 200, loss for current idx: 0.612807
# idx: 220, loss for current idx: 0.564040
# idx: 240, loss for current idx: 0.592547
# idx: 260, loss for current idx: 0.565438
# idx: 280, loss for current idx: 0.582858
# idx: 300, loss for current idx: 0.579266
# idx: 320, loss for current idx: 0.634218
# idx: 340, loss for current idx: 0.551535
# idx: 360, loss for current idx: 0.613524
# idx: 380, loss for current idx: 0.581566
# idx: 400, loss for current idx: 0.593076
# idx: 420, loss for current idx: 0.613851
# idx: 440, loss for current idx: 0.635339
# idx: 460, loss for current idx: 0.663739
# idx: 480, loss for current idx: 0.676117
# best model updated
# Epoch 1, Loss: 0.6081, Accuracy: 0.9633
# best model updated
# Epoch 2, Loss: 0.5801, Accuracy: 0.9825
# best model updated
# Epoch 3, Loss: 0.5718, Accuracy: 0.9870
# best model updated
# Epoch 4, Loss: 0.5694, Accuracy: 0.9887
# Epoch 5, Loss: 0.5657, Accuracy: 0.9864
# Epoch 6, Loss: 0.5651, Accuracy: 0.9881
# Epoch 7, Loss: 0.5673, Accuracy: 0.9887
# best model updated
# Epoch 8, Loss: 0.5619, Accuracy: 0.9960
# Epoch 9, Loss: 0.5608, Accuracy: 0.9825
# Epoch 10, Loss: 0.5658, Accuracy: 0.9848
# Epoch 11, Loss: 0.5634, Accuracy: 0.9915
# Epoch 12, Loss: 0.5613, Accuracy: 0.9910
# Epoch 13, Loss: 0.5662, Accuracy: 0.9887
# Epoch 14, Loss: 0.5691, Accuracy: 0.9870
# Epoch 15, Loss: 0.5642, Accuracy: 0.9887
# Epoch 16, Loss: 0.5581, Accuracy: 0.9932
# Epoch 17, Loss: 0.5580, Accuracy: 0.9904
# Best Epoch: 7, Best Valid Acc: 0.9960474308300395
# Valid Acc (with Epoch valid set) on Loaded Best Model: 0.9960474308300395
# Final Acc (with TEST set) on Loaded Best Model: 0.99081944916695 (time: 0.0049595314523448114)
#
# === case=1, backbone=resnet34 ===
# idx: 20, loss for current idx: 0.678257
# idx: 40, loss for current idx: 0.608550
# idx: 60, loss for current idx: 0.632650
# idx: 80, loss for current idx: 0.658583
# idx: 100, loss for current idx: 0.578470
# idx: 120, loss for current idx: 0.603908
# idx: 140, loss for current idx: 0.586503
# idx: 160, loss for current idx: 0.565247
# idx: 180, loss for current idx: 0.562209
# idx: 200, loss for current idx: 0.601021
# idx: 220, loss for current idx: 0.575552
# idx: 240, loss for current idx: 0.606483
# idx: 260, loss for current idx: 0.601837
# idx: 280, loss for current idx: 0.643735
# idx: 300, loss for current idx: 0.628417
# idx: 320, loss for current idx: 0.584488
# idx: 340, loss for current idx: 0.638915
# idx: 360, loss for current idx: 0.603238
# idx: 380, loss for current idx: 0.615398
# idx: 400, loss for current idx: 0.612374
# idx: 420, loss for current idx: 0.613868
# idx: 440, loss for current idx: 0.568895
# idx: 460, loss for current idx: 0.705853
# idx: 480, loss for current idx: 0.565702
# best model updated
# Epoch 1, Loss: 0.6097, Accuracy: 0.9735
# best model updated
# Epoch 2, Loss: 0.5764, Accuracy: 0.9853
# best model updated
# Epoch 3, Loss: 0.5694, Accuracy: 0.9870
# Epoch 4, Loss: 0.5688, Accuracy: 0.9864
# Epoch 5, Loss: 0.5684, Accuracy: 0.9870
# Epoch 6, Loss: 0.5624, Accuracy: 0.9831
# Epoch 7, Loss: 0.5633, Accuracy: 0.9819
# Epoch 8, Loss: 0.5639, Accuracy: 0.9791
# best model updated
# Epoch 9, Loss: 0.5633, Accuracy: 0.9938
# Epoch 10, Loss: 0.5627, Accuracy: 0.9887
# Epoch 11, Loss: 0.5606, Accuracy: 0.9898
# Epoch 12, Loss: 0.5602, Accuracy: 0.9932
# Epoch 13, Loss: 0.5611, Accuracy: 0.9870
# Epoch 14, Loss: 0.5626, Accuracy: 0.9616
# Epoch 15, Loss: 0.5707, Accuracy: 0.9791
# best model updated
# Epoch 16, Loss: 0.5685, Accuracy: 0.9949
# Epoch 17, Loss: 0.5607, Accuracy: 0.9876
# Epoch 18, Loss: 0.5587, Accuracy: 0.9949
# Epoch 19, Loss: 0.5595, Accuracy: 0.9825
# Epoch 20, Loss: 0.5587, Accuracy: 0.9921
# Epoch 21, Loss: 0.5620, Accuracy: 0.9910
# best model updated
# Epoch 22, Loss: 0.5584, Accuracy: 0.9955
# Epoch 23, Loss: 0.5579, Accuracy: 0.9944
# Epoch 24, Loss: 0.5592, Accuracy: 0.9944
# best model updated
# Epoch 25, Loss: 0.5571, Accuracy: 0.9960
# Epoch 26, Loss: 0.5607, Accuracy: 0.9864
# Epoch 27, Loss: 0.5705, Accuracy: 0.9944
# Epoch 28, Loss: 0.5611, Accuracy: 0.9938
# Epoch 29, Loss: 0.5589, Accuracy: 0.9932
# Epoch 30, Loss: 0.5597, Accuracy: 0.9881
# Epoch 31, Loss: 0.5612, Accuracy: 0.9949
# best model updated
# Epoch 32, Loss: 0.5607, Accuracy: 0.9966
# Epoch 33, Loss: 0.5588, Accuracy: 0.9932
# Epoch 34, Loss: 0.5605, Accuracy: 0.9944
# Epoch 35, Loss: 0.5568, Accuracy: 0.9955
# Epoch 36, Loss: 0.5578, Accuracy: 0.9944
# Epoch 37, Loss: 0.5578, Accuracy: 0.9949
# Epoch 38, Loss: 0.5585, Accuracy: 0.9876
# Epoch 39, Loss: 0.5617, Accuracy: 0.9910
# Epoch 40, Loss: 0.5607, Accuracy: 0.9960
# Epoch 41, Loss: 0.5601, Accuracy: 0.9932
# Best Epoch: 31, Best Valid Acc: 0.9966120835686053
# Valid Acc (with Epoch valid set) on Loaded Best Model: 0.9966120835686053
# Final Acc (with TEST set) on Loaded Best Model: 0.9942196531791907 (time: 0.009821282780688742)
#
# === case=1, backbone=resnet50 ===
# idx: 20, loss for current idx: 0.838179
# idx: 40, loss for current idx: 0.666070
# idx: 60, loss for current idx: 0.652245
# idx: 80, loss for current idx: 0.613464
# idx: 100, loss for current idx: 0.581431
# idx: 120, loss for current idx: 0.603492
# idx: 140, loss for current idx: 0.671040
# idx: 160, loss for current idx: 0.581346
# idx: 180, loss for current idx: 0.586337
# idx: 200, loss for current idx: 0.590257
# idx: 220, loss for current idx: 0.654550
# idx: 240, loss for current idx: 0.627443
# idx: 260, loss for current idx: 0.632994
# idx: 280, loss for current idx: 0.592399
# idx: 300, loss for current idx: 0.551591
# idx: 320, loss for current idx: 0.616858
# idx: 340, loss for current idx: 0.554418
# idx: 360, loss for current idx: 0.558110
# idx: 380, loss for current idx: 0.573232
# idx: 400, loss for current idx: 0.614555
# idx: 420, loss for current idx: 0.551877
# idx: 440, loss for current idx: 0.592997
# idx: 460, loss for current idx: 0.607594
# idx: 480, loss for current idx: 0.551769
# best model updated
# Epoch 1, Loss: 0.6209, Accuracy: 0.9684
# best model updated
# Epoch 2, Loss: 0.5870, Accuracy: 0.9706
# Epoch 3, Loss: 0.5800, Accuracy: 0.9701
# best model updated
# Epoch 4, Loss: 0.5706, Accuracy: 0.9859
# Epoch 5, Loss: 0.5710, Accuracy: 0.9757
# Epoch 6, Loss: 0.5650, Accuracy: 0.9774
# best model updated
# Epoch 7, Loss: 0.5655, Accuracy: 0.9881
# best model updated
# Epoch 8, Loss: 0.5617, Accuracy: 0.9927
# Epoch 9, Loss: 0.5654, Accuracy: 0.9910
# Epoch 10, Loss: 0.5639, Accuracy: 0.9898
# Epoch 11, Loss: 0.5670, Accuracy: 0.9887
# Epoch 12, Loss: 0.5663, Accuracy: 0.9859
# Epoch 13, Loss: 0.5652, Accuracy: 0.9887
# Epoch 14, Loss: 0.5651, Accuracy: 0.9915
# Epoch 15, Loss: 0.5645, Accuracy: 0.9887
# Epoch 16, Loss: 0.5724, Accuracy: 0.9876
# Epoch 17, Loss: 0.5672, Accuracy: 0.9836
# Best Epoch: 7, Best Valid Acc: 0.9926595143986449
# Valid Acc (with Epoch valid set) on Loaded Best Model: 0.9926595143986449
# Final Acc (with TEST set) on Loaded Best Model: 0.9911594695681741 (time: 0.01127401123876157)
#
# === case=2, backbone=resnet18 ===
# idx: 20, loss for current idx: 0.677997
# idx: 40, loss for current idx: 0.659913
# idx: 60, loss for current idx: 0.669192
# idx: 80, loss for current idx: 0.594037
# idx: 100, loss for current idx: 0.642807
# idx: 120, loss for current idx: 0.644525
# idx: 140, loss for current idx: 0.658077
# idx: 160, loss for current idx: 0.582678
# idx: 180, loss for current idx: 0.633943
# idx: 200, loss for current idx: 0.663513
# idx: 220, loss for current idx: 0.618344
# idx: 240, loss for current idx: 0.614631
# idx: 260, loss for current idx: 0.583159
# idx: 280, loss for current idx: 0.652265
# idx: 300, loss for current idx: 0.654597
# idx: 320, loss for current idx: 0.581851
# idx: 340, loss for current idx: 0.628909
# idx: 360, loss for current idx: 0.551519
# idx: 380, loss for current idx: 0.634790
# idx: 400, loss for current idx: 0.615663
# idx: 420, loss for current idx: 0.551835
# idx: 440, loss for current idx: 0.585312
# idx: 460, loss for current idx: 0.551919
# idx: 480, loss for current idx: 0.557498
# best model updated
# Epoch 1, Loss: 0.6149, Accuracy: 0.9616
# best model updated
# Epoch 2, Loss: 0.5818, Accuracy: 0.9740
# best model updated
# Epoch 3, Loss: 0.5719, Accuracy: 0.9876
# Epoch 4, Loss: 0.5699, Accuracy: 0.9864
# Epoch 5, Loss: 0.5725, Accuracy: 0.9842
# Epoch 6, Loss: 0.5680, Accuracy: 0.9848
# Epoch 7, Loss: 0.5679, Accuracy: 0.9780
# Epoch 8, Loss: 0.5657, Accuracy: 0.9831
# Epoch 9, Loss: 0.5673, Accuracy: 0.9802
# best model updated
# Epoch 10, Loss: 0.5701, Accuracy: 0.9893
# best model updated
# Epoch 11, Loss: 0.5644, Accuracy: 0.9910
# Epoch 12, Loss: 0.5625, Accuracy: 0.9881
# Epoch 13, Loss: 0.5650, Accuracy: 0.9870
# Epoch 14, Loss: 0.5624, Accuracy: 0.9853
# Epoch 15, Loss: 0.5628, Accuracy: 0.9864
# Epoch 16, Loss: 0.5652, Accuracy: 0.9881
# Epoch 17, Loss: 0.5644, Accuracy: 0.9910
# Epoch 18, Loss: 0.5637, Accuracy: 0.9893
# Epoch 19, Loss: 0.5683, Accuracy: 0.9808
# Epoch 20, Loss: 0.5652, Accuracy: 0.9864
# best model updated
# Epoch 21, Loss: 0.5602, Accuracy: 0.9915
# Epoch 22, Loss: 0.5613, Accuracy: 0.9864
# Epoch 23, Loss: 0.5705, Accuracy: 0.9819
# Epoch 24, Loss: 0.5617, Accuracy: 0.9898
# Epoch 25, Loss: 0.5638, Accuracy: 0.9870
# Epoch 26, Loss: 0.5634, Accuracy: 0.9910
# Epoch 27, Loss: 0.5659, Accuracy: 0.9904
# Epoch 28, Loss: 0.5655, Accuracy: 0.9853
# Epoch 29, Loss: 0.5621, Accuracy: 0.9864
# Epoch 30, Loss: 0.5589, Accuracy: 0.9915
# best model updated
# Epoch 31, Loss: 0.5580, Accuracy: 0.9932
# Epoch 32, Loss: 0.5683, Accuracy: 0.9616
# Epoch 33, Loss: 0.5645, Accuracy: 0.9819
# Epoch 34, Loss: 0.5640, Accuracy: 0.9910
# best model updated
# Epoch 35, Loss: 0.5598, Accuracy: 0.9938
# Epoch 36, Loss: 0.5638, Accuracy: 0.9893
# Epoch 37, Loss: 0.5595, Accuracy: 0.9921
# Epoch 38, Loss: 0.5578, Accuracy: 0.9881
# Epoch 39, Loss: 0.5596, Accuracy: 0.9932
# Epoch 40, Loss: 0.5628, Accuracy: 0.9893
# Epoch 41, Loss: 0.5589, Accuracy: 0.9938
# Epoch 42, Loss: 0.5600, Accuracy: 0.9893
# Epoch 43, Loss: 0.5664, Accuracy: 0.9876
# Epoch 44, Loss: 0.5609, Accuracy: 0.9927
# Best Epoch: 34, Best Valid Acc: 0.9937888198757764
# Valid Acc (with Epoch valid set) on Loaded Best Model: 0.9937888198757764
# Final Acc (with TEST set) on Loaded Best Model: 0.9935396123767426 (time: 0.0026199299356211786)
#
# === case=2, backbone=resnet34 ===
# idx: 20, loss for current idx: 0.685839
# idx: 40, loss for current idx: 0.692780
# idx: 60, loss for current idx: 0.584663
# idx: 80, loss for current idx: 0.604827
# idx: 100, loss for current idx: 0.552731
# idx: 120, loss for current idx: 0.677891
# idx: 140, loss for current idx: 0.603412
# idx: 160, loss for current idx: 0.614116
# idx: 180, loss for current idx: 0.660768
# idx: 200, loss for current idx: 0.584380
# idx: 220, loss for current idx: 0.580805
# idx: 240, loss for current idx: 0.551525
# idx: 260, loss for current idx: 0.613955
# idx: 280, loss for current idx: 0.551622
# idx: 300, loss for current idx: 0.616880
# idx: 320, loss for current idx: 0.554843
# idx: 340, loss for current idx: 0.613953
# idx: 360, loss for current idx: 0.582948
# idx: 380, loss for current idx: 0.682001
# idx: 400, loss for current idx: 0.552505
# idx: 420, loss for current idx: 0.588274
# idx: 440, loss for current idx: 0.582270
# idx: 460, loss for current idx: 0.607853
# idx: 480, loss for current idx: 0.562564
# best model updated
# Epoch 1, Loss: 0.6161, Accuracy: 0.9825
# Epoch 2, Loss: 0.5795, Accuracy: 0.9797
# best model updated
# Epoch 3, Loss: 0.5706, Accuracy: 0.9904
# best model updated
# Epoch 4, Loss: 0.5661, Accuracy: 0.9944
# Epoch 5, Loss: 0.5680, Accuracy: 0.9469
# Epoch 6, Loss: 0.5725, Accuracy: 0.9915
# Epoch 7, Loss: 0.5636, Accuracy: 0.9808
# Epoch 8, Loss: 0.5673, Accuracy: 0.9932
# Epoch 9, Loss: 0.5646, Accuracy: 0.9825
# Epoch 10, Loss: 0.5685, Accuracy: 0.9808
# Epoch 11, Loss: 0.5735, Accuracy: 0.9904
# Epoch 12, Loss: 0.5638, Accuracy: 0.9887
# Epoch 13, Loss: 0.5646, Accuracy: 0.9915
# Best Epoch: 3, Best Valid Acc: 0.9943534726143421
# Valid Acc (with Epoch valid set) on Loaded Best Model: 0.9943534726143421
# Final Acc (with TEST set) on Loaded Best Model: 0.9880992859571575 (time: 0.004167688929516336)
#
# === case=2, backbone=resnet50 ===
# idx: 20, loss for current idx: 0.750179
# idx: 40, loss for current idx: 0.637842
# idx: 60, loss for current idx: 0.594189
# idx: 80, loss for current idx: 0.646704
# idx: 100, loss for current idx: 0.581564
# idx: 120, loss for current idx: 0.610353
# idx: 140, loss for current idx: 0.653173
# idx: 160, loss for current idx: 0.590517
# idx: 180, loss for current idx: 0.606208
# idx: 200, loss for current idx: 0.630063
# idx: 220, loss for current idx: 0.643503
# idx: 240, loss for current idx: 0.631845
# idx: 260, loss for current idx: 0.655986
# idx: 280, loss for current idx: 0.625857
# idx: 300, loss for current idx: 0.582757
# idx: 320, loss for current idx: 0.556378
# idx: 340, loss for current idx: 0.717613
# idx: 360, loss for current idx: 0.653257
# idx: 380, loss for current idx: 0.641820
# idx: 400, loss for current idx: 0.561484
# idx: 420, loss for current idx: 0.563348
# idx: 440, loss for current idx: 0.615465
# idx: 460, loss for current idx: 0.572207
# idx: 480, loss for current idx: 0.551875
# best model updated
# Epoch 1, Loss: 0.6254, Accuracy: 0.9650
# best model updated
# Epoch 2, Loss: 0.5781, Accuracy: 0.9797
# best model updated
# Epoch 3, Loss: 0.5700, Accuracy: 0.9876
# Epoch 4, Loss: 0.5701, Accuracy: 0.9819
# best model updated
# Epoch 5, Loss: 0.5647, Accuracy: 0.9938
# best model updated
# Epoch 6, Loss: 0.5610, Accuracy: 0.9944
# Epoch 7, Loss: 0.5640, Accuracy: 0.9927
# Epoch 8, Loss: 0.5651, Accuracy: 0.9808
# Epoch 9, Loss: 0.5679, Accuracy: 0.9853
# Epoch 10, Loss: 0.5666, Accuracy: 0.9910
# Epoch 11, Loss: 0.5662, Accuracy: 0.9893
# Epoch 12, Loss: 0.5639, Accuracy: 0.9938
# Epoch 13, Loss: 0.5635, Accuracy: 0.9893
# Epoch 14, Loss: 0.5629, Accuracy: 0.9915
# Epoch 15, Loss: 0.5632, Accuracy: 0.9876
# Best Epoch: 5, Best Valid Acc: 0.9943534726143421
# Valid Acc (with Epoch valid set) on Loaded Best Model: 0.9943534726143421
# Final Acc (with TEST set) on Loaded Best Model: 0.9901394083645019 (time: 0.005798972171285878)
#
# === case=3, backbone=resnet18 ===
# idx: 20, loss for current idx: 0.990876
# idx: 40, loss for current idx: 0.808733
# idx: 60, loss for current idx: 0.736133
# idx: 80, loss for current idx: 0.649338
# idx: 100, loss for current idx: 0.768368
# idx: 120, loss for current idx: 0.728972
# idx: 140, loss for current idx: 0.880722
# idx: 160, loss for current idx: 0.696762
# idx: 180, loss for current idx: 0.712792
# idx: 200, loss for current idx: 0.692894
# idx: 220, loss for current idx: 0.726877
# idx: 240, loss for current idx: 0.657235
# idx: 260, loss for current idx: 0.761308
# idx: 280, loss for current idx: 0.655988
# idx: 300, loss for current idx: 0.693440
# idx: 320, loss for current idx: 0.630175
# idx: 340, loss for current idx: 0.658588
# idx: 360, loss for current idx: 0.675755
# idx: 380, loss for current idx: 0.690621
# idx: 400, loss for current idx: 0.689627
# idx: 420, loss for current idx: 0.732969
# idx: 440, loss for current idx: 0.656721
# idx: 460, loss for current idx: 0.702409
# idx: 480, loss for current idx: 0.686747
# best model updated
# Epoch 1, Loss: 0.7157, Accuracy: 0.9819
# best model updated
# Epoch 2, Loss: 0.6561, Accuracy: 0.9910
# Epoch 3, Loss: 0.6497, Accuracy: 0.9599
# Epoch 4, Loss: 0.6531, Accuracy: 0.9819
# Epoch 5, Loss: 0.6439, Accuracy: 0.9898
# best model updated
# Epoch 6, Loss: 0.6431, Accuracy: 0.9932
# best model updated
# Epoch 7, Loss: 0.6406, Accuracy: 0.9949
# Epoch 8, Loss: 0.6417, Accuracy: 0.9938
# Epoch 9, Loss: 0.6463, Accuracy: 0.9712
# Epoch 10, Loss: 0.6459, Accuracy: 0.9944
# Epoch 11, Loss: 0.6429, Accuracy: 0.9915
# Epoch 12, Loss: 0.6431, Accuracy: 0.9848
# best model updated
# Epoch 13, Loss: 0.6407, Accuracy: 0.9983
# Epoch 14, Loss: 0.6407, Accuracy: 0.9904
# Epoch 15, Loss: 0.6544, Accuracy: 0.9898
# Epoch 16, Loss: 0.6415, Accuracy: 0.9921
# Epoch 17, Loss: 0.6413, Accuracy: 0.9927
# Epoch 18, Loss: 0.6399, Accuracy: 0.9944
# Epoch 19, Loss: 0.6399, Accuracy: 0.9797
# Epoch 20, Loss: 0.6495, Accuracy: 0.9740
# Epoch 21, Loss: 0.6436, Accuracy: 0.9955
# Epoch 22, Loss: 0.6427, Accuracy: 0.9853
# Best Epoch: 12, Best Valid Acc: 0.9983060417843026
# Valid Acc (with Epoch valid set) on Loaded Best Model: 0.9983060417843026
# Final Acc (with TEST set) on Loaded Best Model: 0.9938796327779666 (time: 0.0024339893589849057)
#
# === case=3, backbone=resnet34 ===
# idx: 20, loss for current idx: 0.838094
# idx: 40, loss for current idx: 0.950052
# idx: 60, loss for current idx: 0.783430
# idx: 80, loss for current idx: 0.683326
# idx: 100, loss for current idx: 0.842004
# idx: 120, loss for current idx: 0.677477
# idx: 140, loss for current idx: 0.912080
# idx: 160, loss for current idx: 0.723256
# idx: 180, loss for current idx: 0.771354
# idx: 200, loss for current idx: 0.627706
# idx: 220, loss for current idx: 0.719686
# idx: 240, loss for current idx: 0.718514
# idx: 260, loss for current idx: 0.629760
# idx: 280, loss for current idx: 0.761828
# idx: 300, loss for current idx: 0.674381
# idx: 320, loss for current idx: 0.627593
# idx: 340, loss for current idx: 0.687259
# idx: 360, loss for current idx: 0.626916
# idx: 380, loss for current idx: 0.659412
# idx: 400, loss for current idx: 0.669804
# idx: 420, loss for current idx: 0.628810
# idx: 440, loss for current idx: 0.739121
# idx: 460, loss for current idx: 0.661468
# idx: 480, loss for current idx: 0.697409
# best model updated
# Epoch 1, Loss: 0.7208, Accuracy: 0.9718
# Epoch 2, Loss: 0.6614, Accuracy: 0.9673
# best model updated
# Epoch 3, Loss: 0.6493, Accuracy: 0.9791
# best model updated
# Epoch 4, Loss: 0.6529, Accuracy: 0.9898
# Epoch 5, Loss: 0.6596, Accuracy: 0.9887
# Epoch 6, Loss: 0.6484, Accuracy: 0.9831
# Epoch 7, Loss: 0.6419, Accuracy: 0.9859
# Epoch 8, Loss: 0.6410, Accuracy: 0.9893
# best model updated
# Epoch 9, Loss: 0.6388, Accuracy: 0.9932
# Epoch 10, Loss: 0.6539, Accuracy: 0.9785
# Epoch 11, Loss: 0.6563, Accuracy: 0.9864
# best model updated
# Epoch 12, Loss: 0.6428, Accuracy: 0.9944
# Epoch 13, Loss: 0.6427, Accuracy: 0.9881
# Epoch 14, Loss: 0.6467, Accuracy: 0.9887
# Epoch 15, Loss: 0.6363, Accuracy: 0.9915
# Epoch 16, Loss: 0.6412, Accuracy: 0.9927
# Epoch 17, Loss: 0.6428, Accuracy: 0.9825
# Epoch 18, Loss: 0.6515, Accuracy: 0.9921
# Epoch 19, Loss: 0.6408, Accuracy: 0.9881
# Epoch 20, Loss: 0.6451, Accuracy: 0.9842
# Epoch 21, Loss: 0.6465, Accuracy: 0.9910
# best model updated
# Epoch 22, Loss: 0.6438, Accuracy: 0.9949
# Epoch 23, Loss: 0.6438, Accuracy: 0.9893
# Epoch 24, Loss: 0.6400, Accuracy: 0.9938
# Epoch 25, Loss: 0.6516, Accuracy: 0.9938
# Epoch 26, Loss: 0.6425, Accuracy: 0.9944
# Epoch 27, Loss: 0.6418, Accuracy: 0.9921
# Epoch 28, Loss: 0.6352, Accuracy: 0.9944
# best model updated
# Epoch 29, Loss: 0.6369, Accuracy: 0.9955
# best model updated
# Epoch 30, Loss: 0.6337, Accuracy: 0.9960
# Epoch 31, Loss: 0.6348, Accuracy: 0.9949
# Epoch 32, Loss: 0.6359, Accuracy: 0.9904
# Epoch 33, Loss: 0.6399, Accuracy: 0.9898
# Epoch 34, Loss: 0.6363, Accuracy: 0.9944
# Epoch 35, Loss: 0.6496, Accuracy: 0.9944
# best model updated
# Epoch 36, Loss: 0.6340, Accuracy: 0.9966
# Epoch 37, Loss: 0.6346, Accuracy: 0.9915
# best model updated
# Epoch 38, Loss: 0.6368, Accuracy: 0.9972
# Epoch 39, Loss: 0.6346, Accuracy: 0.9955
# Epoch 40, Loss: 0.6399, Accuracy: 0.9887
# Epoch 41, Loss: 0.6384, Accuracy: 0.9932
# Epoch 42, Loss: 0.6407, Accuracy: 0.9904
# Epoch 43, Loss: 0.6379, Accuracy: 0.9921
# Epoch 44, Loss: 0.6347, Accuracy: 0.9910
# Epoch 45, Loss: 0.6385, Accuracy: 0.9718
# Epoch 46, Loss: 0.6364, Accuracy: 0.9966
# Epoch 47, Loss: 0.6370, Accuracy: 0.9910
# Best Epoch: 37, Best Valid Acc: 0.9971767363071711
# Valid Acc (with Epoch valid set) on Loaded Best Model: 0.9971767363071711
# Final Acc (with TEST set) on Loaded Best Model: 0.9921795307718463 (time: 0.004623436409494151)
#
# === case=3, backbone=resnet50 ===
# idx: 20, loss for current idx: 1.084448
# idx: 40, loss for current idx: 0.815756
# idx: 60, loss for current idx: 0.658996
# idx: 80, loss for current idx: 0.737431
# idx: 100, loss for current idx: 0.793496
# idx: 120, loss for current idx: 0.774624
# idx: 140, loss for current idx: 0.822829
# idx: 160, loss for current idx: 0.656728
# idx: 180, loss for current idx: 0.657590
# idx: 200, loss for current idx: 0.780914
# idx: 220, loss for current idx: 0.923384
# idx: 240, loss for current idx: 0.753460
# idx: 260, loss for current idx: 0.627643
# idx: 280, loss for current idx: 0.626560
# idx: 300, loss for current idx: 0.720280
# idx: 320, loss for current idx: 0.723432
# idx: 340, loss for current idx: 0.722324
# idx: 360, loss for current idx: 0.658768
# idx: 380, loss for current idx: 0.689722
# idx: 400, loss for current idx: 0.771555
# idx: 420, loss for current idx: 0.695616
# idx: 440, loss for current idx: 0.684347
# idx: 460, loss for current idx: 0.662673
# idx: 480, loss for current idx: 0.717924
# best model updated
# Epoch 1, Loss: 0.7309, Accuracy: 0.9627
# Epoch 2, Loss: 0.6828, Accuracy: 0.9593
# best model updated
# Epoch 3, Loss: 0.6544, Accuracy: 0.9774
# best model updated
# Epoch 4, Loss: 0.6511, Accuracy: 0.9842
# best model updated
# Epoch 5, Loss: 0.6436, Accuracy: 0.9921
# Epoch 6, Loss: 0.6467, Accuracy: 0.9910
# Epoch 7, Loss: 0.6480, Accuracy: 0.9915
# Epoch 8, Loss: 0.6423, Accuracy: 0.9921
# Epoch 9, Loss: 0.6444, Accuracy: 0.9887
# Epoch 10, Loss: 0.6436, Accuracy: 0.9864
# best model updated
# Epoch 11, Loss: 0.6396, Accuracy: 0.9944
# Epoch 12, Loss: 0.6378, Accuracy: 0.9802
# Epoch 13, Loss: 0.6379, Accuracy: 0.9864
# Epoch 14, Loss: 0.6476, Accuracy: 0.9876
# Epoch 15, Loss: 0.6502, Accuracy: 0.9881
# Epoch 16, Loss: 0.6501, Accuracy: 0.9898
# Epoch 17, Loss: 0.6417, Accuracy: 0.9848
# Epoch 18, Loss: 0.6488, Accuracy: 0.9780
# Epoch 19, Loss: 0.6374, Accuracy: 0.9910
# Epoch 20, Loss: 0.6489, Accuracy: 0.9797
# Best Epoch: 10, Best Valid Acc: 0.9943534726143421
# Valid Acc (with Epoch valid set) on Loaded Best Model: 0.9943534726143421
# Final Acc (with TEST set) on Loaded Best Model: 0.9931995919755185 (time: 0.005696763163027556)
#
# === case=4_1, backbone=resnet18 ===
# idx: 20, loss for current idx: 0.963923
# idx: 40, loss for current idx: 0.797787
# idx: 60, loss for current idx: 0.787043
# idx: 80, loss for current idx: 0.741275
# idx: 100, loss for current idx: 0.797868
# idx: 120, loss for current idx: 0.627444
# idx: 140, loss for current idx: 0.783530
# idx: 160, loss for current idx: 0.671080
# idx: 180, loss for current idx: 0.634479
# idx: 200, loss for current idx: 0.732509
# idx: 220, loss for current idx: 0.680364
# idx: 240, loss for current idx: 0.632031
# idx: 260, loss for current idx: 0.672443
# idx: 280, loss for current idx: 0.668175
# idx: 300, loss for current idx: 0.685816
# idx: 320, loss for current idx: 0.626588
# idx: 340, loss for current idx: 0.712573
# idx: 360, loss for current idx: 0.633746
# idx: 380, loss for current idx: 0.626695
# idx: 400, loss for current idx: 0.626684
# idx: 420, loss for current idx: 0.750125
# idx: 440, loss for current idx: 0.626524
# idx: 460, loss for current idx: 0.626815
# idx: 480, loss for current idx: 0.661701
# best model updated
# Epoch 1, Loss: 0.7016, Accuracy: 0.9729
# best model updated
# Epoch 2, Loss: 0.6587, Accuracy: 0.9768
# best model updated
# Epoch 3, Loss: 0.6494, Accuracy: 0.9870
# Epoch 4, Loss: 0.6449, Accuracy: 0.9848
# best model updated
# Epoch 5, Loss: 0.6429, Accuracy: 0.9881
# Epoch 6, Loss: 0.6446, Accuracy: 0.9876
# Epoch 7, Loss: 0.6444, Accuracy: 0.9876
# best model updated
# Epoch 8, Loss: 0.6380, Accuracy: 0.9921
# Epoch 9, Loss: 0.6373, Accuracy: 0.9904
# best model updated
# Epoch 10, Loss: 0.6364, Accuracy: 0.9927
# Epoch 11, Loss: 0.6398, Accuracy: 0.9859
# Epoch 12, Loss: 0.6459, Accuracy: 0.9910
# best model updated
# Epoch 13, Loss: 0.6393, Accuracy: 0.9949
# Epoch 14, Loss: 0.6373, Accuracy: 0.9927
# Epoch 15, Loss: 0.6360, Accuracy: 0.9932
# Epoch 16, Loss: 0.6349, Accuracy: 0.9944
# Epoch 17, Loss: 0.6354, Accuracy: 0.9814
# Epoch 18, Loss: 0.6431, Accuracy: 0.9921
# Epoch 19, Loss: 0.6342, Accuracy: 0.9915
# Epoch 20, Loss: 0.6354, Accuracy: 0.9785
# Epoch 21, Loss: 0.6368, Accuracy: 0.9910
# Epoch 22, Loss: 0.6394, Accuracy: 0.9915
# Best Epoch: 12, Best Valid Acc: 0.9949181253529079
# Valid Acc (with Epoch valid set) on Loaded Best Model: 0.9949181253529079
# Final Acc (with TEST set) on Loaded Best Model: 0.9884393063583815 (time: 0.0047086347704348355)
#
# === case=4_1, backbone=resnet34 ===
# idx: 20, loss for current idx: 0.788609
# idx: 40, loss for current idx: 0.681003
# idx: 60, loss for current idx: 0.696416
# idx: 80, loss for current idx: 0.792507
# idx: 100, loss for current idx: 0.813877
# idx: 120, loss for current idx: 0.667922
# idx: 140, loss for current idx: 0.665785
# idx: 160, loss for current idx: 0.842552
# idx: 180, loss for current idx: 0.639210
# idx: 200, loss for current idx: 0.642283
# idx: 220, loss for current idx: 0.721521
# idx: 240, loss for current idx: 0.662016
# idx: 260, loss for current idx: 0.626554
# idx: 280, loss for current idx: 0.696924
# idx: 300, loss for current idx: 0.767080
# idx: 320, loss for current idx: 0.675209
# idx: 340, loss for current idx: 0.629592
# idx: 360, loss for current idx: 0.665597
# idx: 380, loss for current idx: 0.626954
# idx: 400, loss for current idx: 0.629473
# idx: 420, loss for current idx: 0.754211
# idx: 440, loss for current idx: 0.632062
# idx: 460, loss for current idx: 0.684351
# idx: 480, loss for current idx: 0.771973
# best model updated
# Epoch 1, Loss: 0.7103, Accuracy: 0.9819
# best model updated
# Epoch 2, Loss: 0.6611, Accuracy: 0.9836
# best model updated
# Epoch 3, Loss: 0.6511, Accuracy: 0.9921
# Epoch 4, Loss: 0.6462, Accuracy: 0.9910
# Epoch 5, Loss: 0.6449, Accuracy: 0.9859
# Epoch 6, Loss: 0.6445, Accuracy: 0.9915
# Epoch 7, Loss: 0.6426, Accuracy: 0.9881
# Epoch 8, Loss: 0.6404, Accuracy: 0.9915
# Epoch 9, Loss: 0.6429, Accuracy: 0.9876
# Epoch 10, Loss: 0.6412, Accuracy: 0.9842
# best model updated
# Epoch 11, Loss: 0.6381, Accuracy: 0.9949
# Epoch 12, Loss: 0.6398, Accuracy: 0.9774
# Epoch 13, Loss: 0.6544, Accuracy: 0.9881
# Epoch 14, Loss: 0.6396, Accuracy: 0.9842
# Epoch 15, Loss: 0.6368, Accuracy: 0.9949
# Epoch 16, Loss: 0.6390, Accuracy: 0.9944
# Epoch 17, Loss: 0.6367, Accuracy: 0.9938
# Epoch 18, Loss: 0.6347, Accuracy: 0.9910
# Epoch 19, Loss: 0.6382, Accuracy: 0.9944
# Epoch 20, Loss: 0.6367, Accuracy: 0.9712
# Best Epoch: 10, Best Valid Acc: 0.9949181253529079
# Valid Acc (with Epoch valid set) on Loaded Best Model: 0.9949181253529079
# Final Acc (with TEST set) on Loaded Best Model: 0.9918395103706222 (time: 0.008280899213707966)
#
# === case=4_1, backbone=resnet50 ===
# idx: 20, loss for current idx: 1.071296
# idx: 40, loss for current idx: 0.723954
# idx: 60, loss for current idx: 0.694656
# idx: 80, loss for current idx: 0.688628
# idx: 100, loss for current idx: 0.929546
# idx: 120, loss for current idx: 0.931366
# idx: 140, loss for current idx: 0.746956
# idx: 160, loss for current idx: 0.722601
# idx: 180, loss for current idx: 0.798819
# idx: 200, loss for current idx: 0.637214
# idx: 220, loss for current idx: 0.671432
# idx: 240, loss for current idx: 0.642822
# idx: 260, loss for current idx: 0.643020
# idx: 280, loss for current idx: 0.703754
# idx: 300, loss for current idx: 0.659438
# idx: 320, loss for current idx: 0.886256
# idx: 340, loss for current idx: 0.626716
# idx: 360, loss for current idx: 0.695476
# idx: 380, loss for current idx: 0.691127
# idx: 400, loss for current idx: 0.713227
# idx: 420, loss for current idx: 0.626862
# idx: 440, loss for current idx: 0.752150
# idx: 460, loss for current idx: 0.661392
# idx: 480, loss for current idx: 0.627637
# best model updated
# Epoch 1, Loss: 0.7283, Accuracy: 0.9695
# best model updated
# Epoch 2, Loss: 0.6662, Accuracy: 0.9706
# best model updated
# Epoch 3, Loss: 0.6506, Accuracy: 0.9910
# Epoch 4, Loss: 0.6426, Accuracy: 0.9893
# Epoch 5, Loss: 0.6435, Accuracy: 0.9859
# Epoch 6, Loss: 0.6534, Accuracy: 0.9898
# best model updated
# Epoch 7, Loss: 0.6424, Accuracy: 0.9915
# Epoch 8, Loss: 0.6402, Accuracy: 0.9893
# best model updated
# Epoch 9, Loss: 0.6463, Accuracy: 0.9938
# Epoch 10, Loss: 0.6467, Accuracy: 0.9898
# Epoch 11, Loss: 0.6375, Accuracy: 0.9910
# Epoch 12, Loss: 0.6432, Accuracy: 0.9876
# Epoch 13, Loss: 0.6518, Accuracy: 0.9848
# Epoch 14, Loss: 0.6460, Accuracy: 0.9898
# Epoch 15, Loss: 0.6438, Accuracy: 0.9898
# Epoch 16, Loss: 0.6426, Accuracy: 0.9904
# Epoch 17, Loss: 0.6511, Accuracy: 0.9780
# Epoch 18, Loss: 0.6424, Accuracy: 0.9898
# Best Epoch: 8, Best Valid Acc: 0.9937888198757764
# Valid Acc (with Epoch valid set) on Loaded Best Model: 0.9937888198757764
# Final Acc (with TEST set) on Loaded Best Model: 0.9918395103706222 (time: 0.013563845468604046)
#
# === case=4_2, backbone=resnet18 ===
# idx: 20, loss for current idx: 0.949601
# idx: 40, loss for current idx: 0.812811
# idx: 60, loss for current idx: 0.712090
# idx: 80, loss for current idx: 0.712745
# idx: 100, loss for current idx: 0.748552
# idx: 120, loss for current idx: 0.687902
# idx: 140, loss for current idx: 0.645296
# idx: 160, loss for current idx: 0.768250
# idx: 180, loss for current idx: 0.681669
# idx: 200, loss for current idx: 0.647748
# idx: 220, loss for current idx: 0.711776
# idx: 240, loss for current idx: 0.710094
# idx: 260, loss for current idx: 0.658341
# idx: 280, loss for current idx: 0.704575
# idx: 300, loss for current idx: 0.750928
# idx: 320, loss for current idx: 0.661127
# idx: 340, loss for current idx: 0.704123
# idx: 360, loss for current idx: 0.629481
# idx: 380, loss for current idx: 0.659058
# idx: 400, loss for current idx: 0.679554
# idx: 420, loss for current idx: 0.627103
# idx: 440, loss for current idx: 0.640927
# idx: 460, loss for current idx: 0.652031
# idx: 480, loss for current idx: 0.662402
# best model updated
# Epoch 1, Loss: 0.7245, Accuracy: 0.9571
# best model updated
# Epoch 2, Loss: 0.6704, Accuracy: 0.9757
# best model updated
# Epoch 3, Loss: 0.6577, Accuracy: 0.9802
# Epoch 4, Loss: 0.6472, Accuracy: 0.9752
# best model updated
# Epoch 5, Loss: 0.6455, Accuracy: 0.9853
# Epoch 6, Loss: 0.6480, Accuracy: 0.9735
# Epoch 7, Loss: 0.6498, Accuracy: 0.9780
# Epoch 8, Loss: 0.6434, Accuracy: 0.9763
# Epoch 9, Loss: 0.6435, Accuracy: 0.9831
# Epoch 10, Loss: 0.6495, Accuracy: 0.9503
# best model updated
# Epoch 11, Loss: 0.6445, Accuracy: 0.9915
# Epoch 12, Loss: 0.6405, Accuracy: 0.9729
# Epoch 13, Loss: 0.6453, Accuracy: 0.9904
# best model updated
# Epoch 14, Loss: 0.6361, Accuracy: 0.9938
# Epoch 15, Loss: 0.6370, Accuracy: 0.9898
# Epoch 16, Loss: 0.6432, Accuracy: 0.9853
# Epoch 17, Loss: 0.6397, Accuracy: 0.9904
# Epoch 18, Loss: 0.6421, Accuracy: 0.9802
# Epoch 19, Loss: 0.6453, Accuracy: 0.9921
# Epoch 20, Loss: 0.6415, Accuracy: 0.9740
# Epoch 21, Loss: 0.6459, Accuracy: 0.9893
# Epoch 22, Loss: 0.6393, Accuracy: 0.9921
# Epoch 23, Loss: 0.6426, Accuracy: 0.9644
# Best Epoch: 13, Best Valid Acc: 0.9937888198757764
# Valid Acc (with Epoch valid set) on Loaded Best Model: 0.9937888198757764
# Final Acc (with TEST set) on Loaded Best Model: 0.99081944916695 (time: 0.004738986492156982)
#
# === case=4_2, backbone=resnet34 ===
# idx: 20, loss for current idx: 0.809282
# idx: 40, loss for current idx: 0.876694
# idx: 60, loss for current idx: 0.671367
# idx: 80, loss for current idx: 0.727570
# idx: 100, loss for current idx: 0.627498
# idx: 120, loss for current idx: 0.695322
# idx: 140, loss for current idx: 0.771568
# idx: 160, loss for current idx: 0.697878
# idx: 180, loss for current idx: 0.759102
# idx: 200, loss for current idx: 0.688681
# idx: 220, loss for current idx: 0.703361
# idx: 240, loss for current idx: 0.720693
# idx: 260, loss for current idx: 0.755277
# idx: 280, loss for current idx: 0.791755
# idx: 300, loss for current idx: 0.749726
# idx: 320, loss for current idx: 0.660679
# idx: 340, loss for current idx: 0.672752
# idx: 360, loss for current idx: 0.689226
# idx: 380, loss for current idx: 0.656732
# idx: 400, loss for current idx: 0.626536
# idx: 420, loss for current idx: 0.650682
# idx: 440, loss for current idx: 0.663103
# idx: 460, loss for current idx: 0.627510
# idx: 480, loss for current idx: 0.672238
# best model updated
# Epoch 1, Loss: 0.7262, Accuracy: 0.9543
# best model updated
# Epoch 2, Loss: 0.6786, Accuracy: 0.9695
# best model updated
# Epoch 3, Loss: 0.6625, Accuracy: 0.9808
# best model updated
# Epoch 4, Loss: 0.6560, Accuracy: 0.9842
# Epoch 5, Loss: 0.6515, Accuracy: 0.9791
# Epoch 6, Loss: 0.6527, Accuracy: 0.9768
# Epoch 7, Loss: 0.6572, Accuracy: 0.9689
# Epoch 8, Loss: 0.6481, Accuracy: 0.9639
# best model updated
# Epoch 9, Loss: 0.6473, Accuracy: 0.9848
# best model updated
# Epoch 10, Loss: 0.6432, Accuracy: 0.9927
# Epoch 11, Loss: 0.6457, Accuracy: 0.9864
# Epoch 12, Loss: 0.6538, Accuracy: 0.9853
# Epoch 13, Loss: 0.6520, Accuracy: 0.8944
# Epoch 14, Loss: 0.6473, Accuracy: 0.9898
# Epoch 15, Loss: 0.6460, Accuracy: 0.9848
# Epoch 16, Loss: 0.6440, Accuracy: 0.9876
# Epoch 17, Loss: 0.6516, Accuracy: 0.9622
# Epoch 18, Loss: 0.6562, Accuracy: 0.9814
# Epoch 19, Loss: 0.6543, Accuracy: 0.9763
# Best Epoch: 9, Best Valid Acc: 0.9926595143986449
# Valid Acc (with Epoch valid set) on Loaded Best Model: 0.9926595143986449
# Final Acc (with TEST set) on Loaded Best Model: 0.9877592655559334 (time: 0.008484091447747272)
#
# === case=4_2, backbone=resnet50 ===
# idx: 20, loss for current idx: 1.096053
# idx: 40, loss for current idx: 0.752643
# idx: 60, loss for current idx: 0.730602
# idx: 80, loss for current idx: 0.754472
# idx: 100, loss for current idx: 0.777869
# idx: 120, loss for current idx: 0.661247
# idx: 140, loss for current idx: 0.737065
# idx: 160, loss for current idx: 0.666045
# idx: 180, loss for current idx: 0.761904
# idx: 200, loss for current idx: 0.778992
# idx: 220, loss for current idx: 0.812950
# idx: 240, loss for current idx: 0.689195
# idx: 260, loss for current idx: 0.736981
# idx: 280, loss for current idx: 0.741255
# idx: 300, loss for current idx: 0.663566
# idx: 320, loss for current idx: 0.691639
# idx: 340, loss for current idx: 0.701591
# idx: 360, loss for current idx: 0.678571
# idx: 380, loss for current idx: 0.657381
# idx: 400, loss for current idx: 0.686966
# idx: 420, loss for current idx: 0.626622
# idx: 440, loss for current idx: 0.627511
# idx: 460, loss for current idx: 0.628101
# idx: 480, loss for current idx: 0.665689
# best model updated
# Epoch 1, Loss: 0.7347, Accuracy: 0.9599
# best model updated
# Epoch 2, Loss: 0.6644, Accuracy: 0.9763
# Epoch 3, Loss: 0.6543, Accuracy: 0.9740
# best model updated
# Epoch 4, Loss: 0.6531, Accuracy: 0.9802
# best model updated
# Epoch 5, Loss: 0.6462, Accuracy: 0.9825
# Epoch 6, Loss: 0.6519, Accuracy: 0.9802
# Epoch 7, Loss: 0.6444, Accuracy: 0.9661
# Epoch 8, Loss: 0.6501, Accuracy: 0.9379
# Epoch 9, Loss: 0.6477, Accuracy: 0.9661
# best model updated
# Epoch 10, Loss: 0.6497, Accuracy: 0.9887
# Epoch 11, Loss: 0.6488, Accuracy: 0.9774
# Epoch 12, Loss: 0.6520, Accuracy: 0.9848
# Epoch 13, Loss: 0.6516, Accuracy: 0.9848
# best model updated
# Epoch 14, Loss: 0.6409, Accuracy: 0.9904
# Epoch 15, Loss: 0.6447, Accuracy: 0.9853
# Epoch 16, Loss: 0.6415, Accuracy: 0.9859
# Epoch 17, Loss: 0.6488, Accuracy: 0.9853
# Epoch 18, Loss: 0.6435, Accuracy: 0.9848
# Epoch 19, Loss: 0.6423, Accuracy: 0.9898
# Epoch 20, Loss: 0.6652, Accuracy: 0.7781
# Epoch 21, Loss: 0.6490, Accuracy: 0.9898
# Epoch 22, Loss: 0.6455, Accuracy: 0.9797
# Epoch 23, Loss: 0.6504, Accuracy: 0.9780
# Best Epoch: 13, Best Valid Acc: 0.9904009034443817
# Valid Acc (with Epoch valid set) on Loaded Best Model: 0.9904009034443817
# Final Acc (with TEST set) on Loaded Best Model: 0.9894593675620538 (time: 0.01166460825049359)

# %%
result_df = pd.DataFrame(result_dict)
result_df
# Out:
#     backbone case  accuracy  inference_time
# 0   resnet18    1  0.990819        0.004960
# 1   resnet34    1  0.994220        0.009821
# 2   resnet50    1  0.991159        0.011274
# 3   resnet18    2  0.993540        0.002620
# 4   resnet34    2  0.988099        0.004168
# 5   resnet50    2  0.990139        0.005799
# 6   resnet18    3  0.993880        0.002434
# 7   resnet34    3  0.992180        0.004623
# 8   resnet50    3  0.993200        0.005697
# 9   resnet18  4_1  0.988439        0.004709
# 10  resnet34  4_1  0.991840        0.008281
# 11  resnet50  4_1  0.991840        0.013564
# 12  resnet18  4_2  0.990819        0.004739
# 13  resnet34  4_2  0.987759        0.008484
# 14  resnet50  4_2  0.989459        0.011665

# %%
result_df.to_csv('result_experiment_2.csv')
