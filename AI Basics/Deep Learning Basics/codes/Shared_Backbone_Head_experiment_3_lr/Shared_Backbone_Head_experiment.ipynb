# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms

import plotly.graph_objects as go

import random
import pandas as pd
import numpy as np

# !pip install torchinfo
from torchinfo import summary
# Out:
# Requirement already satisfied: torchinfo in /usr/local/lib/python3.12/dist-packages (1.8.0)

# %%
# 경고 미 표시

import warnings
warnings.filterwarnings('ignore')

# %%
# Random Seed 고정 (학습 반복 시행 시에도 동일한 결과가 나오도록)

seed = 20251004

random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)
torch.cuda.manual_seed_all(seed)

# %%
# 데이터셋 로딩

transform = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.5,), (0.5,))])

train_dataset = torchvision.datasets.MNIST(root='./data',
                                           train=True,
                                           transform=transform,
                                           download=True)

test_dataset = torchvision.datasets.MNIST(root='./data',
                                          train=False,
                                          transform=transform,
                                          download=True)

# %% [markdown]
# **1. 데이터셋 분석**

# %%
# 데이터셋 로딩

from torch.utils.data import DataLoader

BATCH_SIZE = 32

train_loader = DataLoader(train_dataset,
                          batch_size=BATCH_SIZE,
                          shuffle=True)

test_loader = DataLoader(test_dataset,
                         batch_size=BATCH_SIZE,
                         shuffle=False)

# %%
# 클래스 불균형 분석

# 학습 데이터
train_labels = torch.tensor(train_dataset.targets)
train_class_counts = torch.bincount(train_labels)
print(f'train data : {train_class_counts}')

# 테스트 데이터
test_labels = torch.tensor(test_dataset.targets)
test_class_counts = torch.bincount(test_labels)
print(f'test  data : {test_class_counts}')

NUM_CLASSES = len(train_class_counts)
# Out:
# train data : tensor([5923, 6742, 5958, 6131, 5842, 5421, 5918, 6265, 5851, 5949])
# test  data : tensor([ 980, 1135, 1032, 1010,  982,  892,  958, 1028,  974, 1009])

# %%
# 클래스 불균형 분석 (percentage)

train_class_percentage = np.array(train_class_counts) * 100.0 / sum(train_class_counts)

train_y_distrib = pd.DataFrame({'class': list(range(NUM_CLASSES)),
                                'count': train_class_counts,
                                'percentage (%)': train_class_percentage})

train_y_distrib
# Out:
#    class  count  percentage (%)
# 0      0   5923        9.871667
# 1      1   6742       11.236667
# 2      2   5958        9.930000
# 3      3   6131       10.218333
# 4      4   5842        9.736667
# 5      5   5421        9.035000
# 6      6   5918        9.863333
# 7      7   6265       10.441667
# 8      8   5851        9.751667
# 9      9   5949        9.915000

# %%
test_class_percentage = np.array(test_class_counts) * 100.0 / sum(test_class_counts)

test_y_distrib = pd.DataFrame({'class': list(range(NUM_CLASSES)),
                               'count': test_class_counts,
                               'percentage (%)': test_class_percentage})

test_y_distrib
# Out:
#    class  count  percentage (%)
# 0      0    980            9.80
# 1      1   1135           11.35
# 2      2   1032           10.32
# 3      3   1010           10.10
# 4      4    982            9.82
# 5      5    892            8.92
# 6      6    958            9.58
# 7      7   1028           10.28
# 8      8    974            9.74
# 9      9   1009           10.09

# %% [markdown]
# **2. 6, 8, 9 숫자 데이터만 추출**

# %%
from torch.utils.data import Subset

TRAIN_N = 4000
LEARNING_RATE = 0.005

# train dataset
train_targets = torch.tensor(train_dataset.targets)[:TRAIN_N]
train_mask = (train_targets == 6) | (train_targets == 8) | (train_targets == 9)
train_indices = torch.where(train_mask)[0]

train_subset = Subset(train_dataset, train_indices)

# test dataset
test_targets = torch.tensor(test_dataset.targets)
test_mask = (test_targets == 6) | (test_targets == 8) | (test_targets == 9)
test_indices = torch.where(test_mask)[0]

test_subset = Subset(test_dataset, test_indices)

# %%
# train, test Data Loader 갱신

train_subset_loader = DataLoader(train_subset,
                                 batch_size=BATCH_SIZE,
                                 shuffle=True)

test_subset_loader = DataLoader(test_subset,
                                batch_size=BATCH_SIZE,
                                shuffle=False)

# %%
# train, test Data Loader 의 class 가 6, 8, 9 뿐인지 확인

train_subset_labels = train_subset.dataset.targets[train_subset.indices]
train_subset_class_counts = torch.bincount(train_subset_labels)
print(f'train data (subset) [6,8,9] : {train_subset_class_counts}')

test_subset_labels = test_subset.dataset.targets[test_subset.indices]
test_subset_class_counts = torch.bincount(test_subset_labels)
print(f'test  data (subset) [6,8,9] : {test_subset_class_counts}')
# Out:
# train data (subset) [6,8,9] : tensor([  0,   0,   0,   0,   0,   0, 405,   0, 373, 397])
# test  data (subset) [6,8,9] : tensor([   0,    0,    0,    0,    0,    0,  958,    0,  974, 1009])

# %% [markdown]
# **3. CNN 모델 정의**

# %%
# 1. Non-Shared backbone & Shared head

class CNN_CASE_1(nn.Module):
    def __init__(self, backbone_1, backbone_2):
        super(CNN_CASE_1, self).__init__()

        self.backbone_1 = backbone_1
        self.backbone_2 = backbone_2
        self.final_linear = nn.Linear(2000, 3)
        self.final_softmax = nn.Softmax(dim=1)

    def forward(self, x):
        x1 = self.backbone_1(x)
        x2 = self.backbone_2(x)
        x = torch.concatenate([x1, x2], dim=1)

        x = self.final_linear(x)
        x = self.final_softmax(x)

        return x

# %%
# 2. Shared backbone & Shared head

class CNN_CASE_2(nn.Module):
    def __init__(self, backbone):
        super(CNN_CASE_2, self).__init__()

        self.backbone = backbone
        self.final_linear = nn.Linear(1000, 3)
        self.final_softmax = nn.Softmax(dim=1)

    def forward(self, x):
        x = self.backbone(x)
        x = self.final_linear(x)
        x = self.final_softmax(x)

        return x

# %%
# 3. Shared backbone & Non-Shared head

class CNN_CASE_3(nn.Module):
    def __init__(self, backbone):
        super(CNN_CASE_3, self).__init__()

        self.backbone = backbone
        self.final_linear_1 = nn.Linear(1000, 2)
        self.final_linear_2 = nn.Linear(1000, 2)
        self.final_softmax = nn.Softmax(dim=1)

    def forward(self, x):
        x = self.backbone(x)
        x1 = self.final_linear_1(x)
        x2 = self.final_linear_2(x)
        x1 = self.final_softmax(x1)
        x2 = self.final_softmax(x2)

        return x1, x2

# %%
# 4. Non-Shared backbone & Non-Shared head (4-1)

class CNN_CASE_4_1(nn.Module):
    def __init__(self, backbone_1, backbone_2):
        super(CNN_CASE_4_1, self).__init__()

        self.backbone_1 = backbone_1
        self.backbone_2 = backbone_2
        self.final_linear_1 = nn.Linear(2000, 2)
        self.final_linear_2 = nn.Linear(2000, 2)
        self.final_softmax = nn.Softmax(dim=1)

    def forward(self, x):
        x11 = self.backbone_1(x)
        x12 = self.backbone_2(x)
        x = torch.concatenate([x11, x12], dim=1)

        x21 = self.final_linear_1(x)
        x22 = self.final_linear_2(x)
        x21 = self.final_softmax(x21)
        x22 = self.final_softmax(x22)

        return x21, x22

# %%
# 5. Non-Shared backbone & Non-Shared head (4-2)

class CNN_CASE_4_2(nn.Module):
    def __init__(self, backbone_1, backbone_2):
        super(CNN_CASE_4_2, self).__init__()

        self.backbone_1 = backbone_1
        self.backbone_2 = backbone_2
        self.final_linear_1 = nn.Linear(1000, 2)
        self.final_linear_2 = nn.Linear(1000, 2)
        self.final_softmax = nn.Softmax(dim=1)

    def forward(self, x):
        x11 = self.backbone_1(x)
        x12 = self.backbone_2(x)
        x21 = self.final_linear_1(x11)
        x22 = self.final_linear_2(x12)
        x21 = self.final_softmax(x21)
        x22 = self.final_softmax(x22)

        return x21, x22

# %% [markdown]
# **4. backbone model 로딩**

# %%
import torchvision.models as models

def define_model(backbone_name, case_name, device):

    # model count
    if case_name in ['1', '4_1', '4_2']:
        model_count = 2
    else:
        model_count = 1

    # load pre-trained backbone model
    pretrained_models = []

    for _ in range(model_count):
        if backbone_name == 'resnet18':
            pretrained_model = models.resnet18(pretrained=True)

        elif backbone_name == 'resnet34':
            pretrained_model = models.resnet34(pretrained=True)

        else:  # resnet50
            pretrained_model = models.resnet50(pretrained=True)

        pretrained_model.conv1 = torch.nn.Conv2d(1, 64,
                                                 kernel_size=(7, 7),
                                                 stride=(2, 2),
                                                 padding=(3, 3),
                                                 bias=False)
        pretrained_models.append(pretrained_model)

    # define full model
    if case_name == '1':
        model = CNN_CASE_1(backbone_1=pretrained_models[0],
                           backbone_2=pretrained_models[1])

    elif case_name == '2':
        model = CNN_CASE_2(backbone=pretrained_models[0])

    elif case_name == '3':
        model = CNN_CASE_3(backbone=pretrained_models[0])

    elif case_name == '4_1':
        model = CNN_CASE_4_1(backbone_1=pretrained_models[0],
                             backbone_2=pretrained_models[1])

    elif case_name == '4_2':
        model = CNN_CASE_4_2(backbone_1=pretrained_models[0],
                             backbone_2=pretrained_models[1])

    # device & optimizer & scheduler setting
    model.to(device)
    model.optimizer = torch.optim.AdamW(model.parameters(), lr=LEARNING_RATE)
    model.scheduler = torch.optim.lr_scheduler.ExponentialLR(optimizer=model.optimizer,
                                                             gamma=0.95)

    return model

# %% [markdown]
# **5. 모델 구조 출력**

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
input_size=(BATCH_SIZE, 1, 28, 28)

# %%
temp_backbone_name = 'resnet18'

# %%
# 1. Non-Shared backbone & Shared head

model_case_1 = define_model(temp_backbone_name, case_name='1', device=device)
print(summary(model=model_case_1, input_size=input_size))
# Out:
# ===============================================================================================
# Layer (type:depth-idx)                        Output Shape              Param #
# ===============================================================================================
# CNN_CASE_1                                    [32, 3]                   --
# ├─ResNet: 1-1                                 [32, 1000]                --
# │    └─Conv2d: 2-1                            [32, 64, 14, 14]          3,136
# │    └─BatchNorm2d: 2-2                       [32, 64, 14, 14]          128
# │    └─ReLU: 2-3                              [32, 64, 14, 14]          --
# │    └─MaxPool2d: 2-4                         [32, 64, 7, 7]            --
# │    └─Sequential: 2-5                        [32, 64, 7, 7]            --
# │    │    └─BasicBlock: 3-1                   [32, 64, 7, 7]            73,984
# │    │    └─BasicBlock: 3-2                   [32, 64, 7, 7]            73,984
# │    └─Sequential: 2-6                        [32, 128, 4, 4]           --
# │    │    └─BasicBlock: 3-3                   [32, 128, 4, 4]           230,144
# │    │    └─BasicBlock: 3-4                   [32, 128, 4, 4]           295,424
# │    └─Sequential: 2-7                        [32, 256, 2, 2]           --
# │    │    └─BasicBlock: 3-5                   [32, 256, 2, 2]           919,040
# │    │    └─BasicBlock: 3-6                   [32, 256, 2, 2]           1,180,672
# │    └─Sequential: 2-8                        [32, 512, 1, 1]           --
# │    │    └─BasicBlock: 3-7                   [32, 512, 1, 1]           3,673,088
# │    │    └─BasicBlock: 3-8                   [32, 512, 1, 1]           4,720,640
# │    └─AdaptiveAvgPool2d: 2-9                 [32, 512, 1, 1]           --
# │    └─Linear: 2-10                           [32, 1000]                513,000
# ├─ResNet: 1-2                                 [32, 1000]                --
# │    └─Conv2d: 2-11                           [32, 64, 14, 14]          3,136
# │    └─BatchNorm2d: 2-12                      [32, 64, 14, 14]          128
# │    └─ReLU: 2-13                             [32, 64, 14, 14]          --
# │    └─MaxPool2d: 2-14                        [32, 64, 7, 7]            --
# │    └─Sequential: 2-15                       [32, 64, 7, 7]            --
# │    │    └─BasicBlock: 3-9                   [32, 64, 7, 7]            73,984
# │    │    └─BasicBlock: 3-10                  [32, 64, 7, 7]            73,984
# │    └─Sequential: 2-16                       [32, 128, 4, 4]           --
# │    │    └─BasicBlock: 3-11                  [32, 128, 4, 4]           230,144
# │    │    └─BasicBlock: 3-12                  [32, 128, 4, 4]           295,424
# │    └─Sequential: 2-17                       [32, 256, 2, 2]           --
# │    │    └─BasicBlock: 3-13                  [32, 256, 2, 2]           919,040
# │    │    └─BasicBlock: 3-14                  [32, 256, 2, 2]           1,180,672
# │    └─Sequential: 2-18                       [32, 512, 1, 1]           --
# │    │    └─BasicBlock: 3-15                  [32, 512, 1, 1]           3,673,088
# │    │    └─BasicBlock: 3-16                  [32, 512, 1, 1]           4,720,640
# │    └─AdaptiveAvgPool2d: 2-19                [32, 512, 1, 1]           --
# │    └─Linear: 2-20                           [32, 1000]                513,000
# ├─Linear: 1-3                                 [32, 3]                   6,003
# ├─Softmax: 1-4                                [32, 3]                   --
# ===============================================================================================
# Total params: 23,372,483
# Trainable params: 23,372,483
# Non-trainable params: 0
# Total mult-adds (Units.GIGABYTES): 2.15
# ===============================================================================================
# Input size (MB): 0.10
# Forward/backward pass size (MB): 44.55
# Params size (MB): 93.49
# Estimated Total Size (MB): 138.14
# ===============================================================================================

# %%
# 2. Shared backbone & Shared head

model_case_2 = define_model(temp_backbone_name, case_name='2', device=device)
print(summary(model=model_case_2, input_size=input_size))
# Out:
# ===============================================================================================
# Layer (type:depth-idx)                        Output Shape              Param #
# ===============================================================================================
# CNN_CASE_2                                    [32, 3]                   --
# ├─ResNet: 1-1                                 [32, 1000]                --
# │    └─Conv2d: 2-1                            [32, 64, 14, 14]          3,136
# │    └─BatchNorm2d: 2-2                       [32, 64, 14, 14]          128
# │    └─ReLU: 2-3                              [32, 64, 14, 14]          --
# │    └─MaxPool2d: 2-4                         [32, 64, 7, 7]            --
# │    └─Sequential: 2-5                        [32, 64, 7, 7]            --
# │    │    └─BasicBlock: 3-1                   [32, 64, 7, 7]            73,984
# │    │    └─BasicBlock: 3-2                   [32, 64, 7, 7]            73,984
# │    └─Sequential: 2-6                        [32, 128, 4, 4]           --
# │    │    └─BasicBlock: 3-3                   [32, 128, 4, 4]           230,144
# │    │    └─BasicBlock: 3-4                   [32, 128, 4, 4]           295,424
# │    └─Sequential: 2-7                        [32, 256, 2, 2]           --
# │    │    └─BasicBlock: 3-5                   [32, 256, 2, 2]           919,040
# │    │    └─BasicBlock: 3-6                   [32, 256, 2, 2]           1,180,672
# │    └─Sequential: 2-8                        [32, 512, 1, 1]           --
# │    │    └─BasicBlock: 3-7                   [32, 512, 1, 1]           3,673,088
# │    │    └─BasicBlock: 3-8                   [32, 512, 1, 1]           4,720,640
# │    └─AdaptiveAvgPool2d: 2-9                 [32, 512, 1, 1]           --
# │    └─Linear: 2-10                           [32, 1000]                513,000
# ├─Linear: 1-2                                 [32, 3]                   3,003
# ├─Softmax: 1-3                                [32, 3]                   --
# ===============================================================================================
# Total params: 11,686,243
# Trainable params: 11,686,243
# Non-trainable params: 0
# Total mult-adds (Units.GIGABYTES): 1.07
# ===============================================================================================
# Input size (MB): 0.10
# Forward/backward pass size (MB): 22.28
# Params size (MB): 46.74
# Estimated Total Size (MB): 69.12
# ===============================================================================================

# %%
# 3. Shared backbone & Non-Shared head

model_case_3 = define_model(temp_backbone_name, case_name='3', device=device)
print(summary(model=model_case_3, input_size=input_size))
# Out:
# ===============================================================================================
# Layer (type:depth-idx)                        Output Shape              Param #
# ===============================================================================================
# CNN_CASE_3                                    [32, 2]                   --
# ├─ResNet: 1-1                                 [32, 1000]                --
# │    └─Conv2d: 2-1                            [32, 64, 14, 14]          3,136
# │    └─BatchNorm2d: 2-2                       [32, 64, 14, 14]          128
# │    └─ReLU: 2-3                              [32, 64, 14, 14]          --
# │    └─MaxPool2d: 2-4                         [32, 64, 7, 7]            --
# │    └─Sequential: 2-5                        [32, 64, 7, 7]            --
# │    │    └─BasicBlock: 3-1                   [32, 64, 7, 7]            73,984
# │    │    └─BasicBlock: 3-2                   [32, 64, 7, 7]            73,984
# │    └─Sequential: 2-6                        [32, 128, 4, 4]           --
# │    │    └─BasicBlock: 3-3                   [32, 128, 4, 4]           230,144
# │    │    └─BasicBlock: 3-4                   [32, 128, 4, 4]           295,424
# │    └─Sequential: 2-7                        [32, 256, 2, 2]           --
# │    │    └─BasicBlock: 3-5                   [32, 256, 2, 2]           919,040
# │    │    └─BasicBlock: 3-6                   [32, 256, 2, 2]           1,180,672
# │    └─Sequential: 2-8                        [32, 512, 1, 1]           --
# │    │    └─BasicBlock: 3-7                   [32, 512, 1, 1]           3,673,088
# │    │    └─BasicBlock: 3-8                   [32, 512, 1, 1]           4,720,640
# │    └─AdaptiveAvgPool2d: 2-9                 [32, 512, 1, 1]           --
# │    └─Linear: 2-10                           [32, 1000]                513,000
# ├─Linear: 1-2                                 [32, 2]                   2,002
# ├─Linear: 1-3                                 [32, 2]                   2,002
# ├─Softmax: 1-4                                [32, 2]                   --
# ├─Softmax: 1-5                                [32, 2]                   --
# ===============================================================================================
# Total params: 11,687,244
# Trainable params: 11,687,244
# Non-trainable params: 0
# Total mult-adds (Units.GIGABYTES): 1.07
# ===============================================================================================
# Input size (MB): 0.10
# Forward/backward pass size (MB): 22.28
# Params size (MB): 46.75
# Estimated Total Size (MB): 69.13
# ===============================================================================================

# %%
# 4. Non-Shared backbone & Non-Shared head (4-1)

model_case_4_1 = define_model(temp_backbone_name, case_name='4_1', device=device)
print(summary(model=model_case_4_1, input_size=input_size))
# Out:
# ===============================================================================================
# Layer (type:depth-idx)                        Output Shape              Param #
# ===============================================================================================
# CNN_CASE_4_1                                  [32, 2]                   --
# ├─ResNet: 1-1                                 [32, 1000]                --
# │    └─Conv2d: 2-1                            [32, 64, 14, 14]          3,136
# │    └─BatchNorm2d: 2-2                       [32, 64, 14, 14]          128
# │    └─ReLU: 2-3                              [32, 64, 14, 14]          --
# │    └─MaxPool2d: 2-4                         [32, 64, 7, 7]            --
# │    └─Sequential: 2-5                        [32, 64, 7, 7]            --
# │    │    └─BasicBlock: 3-1                   [32, 64, 7, 7]            73,984
# │    │    └─BasicBlock: 3-2                   [32, 64, 7, 7]            73,984
# │    └─Sequential: 2-6                        [32, 128, 4, 4]           --
# │    │    └─BasicBlock: 3-3                   [32, 128, 4, 4]           230,144
# │    │    └─BasicBlock: 3-4                   [32, 128, 4, 4]           295,424
# │    └─Sequential: 2-7                        [32, 256, 2, 2]           --
# │    │    └─BasicBlock: 3-5                   [32, 256, 2, 2]           919,040
# │    │    └─BasicBlock: 3-6                   [32, 256, 2, 2]           1,180,672
# │    └─Sequential: 2-8                        [32, 512, 1, 1]           --
# │    │    └─BasicBlock: 3-7                   [32, 512, 1, 1]           3,673,088
# │    │    └─BasicBlock: 3-8                   [32, 512, 1, 1]           4,720,640
# │    └─AdaptiveAvgPool2d: 2-9                 [32, 512, 1, 1]           --
# │    └─Linear: 2-10                           [32, 1000]                513,000
# ├─ResNet: 1-2                                 [32, 1000]                --
# │    └─Conv2d: 2-11                           [32, 64, 14, 14]          3,136
# │    └─BatchNorm2d: 2-12                      [32, 64, 14, 14]          128
# │    └─ReLU: 2-13                             [32, 64, 14, 14]          --
# │    └─MaxPool2d: 2-14                        [32, 64, 7, 7]            --
# │    └─Sequential: 2-15                       [32, 64, 7, 7]            --
# │    │    └─BasicBlock: 3-9                   [32, 64, 7, 7]            73,984
# │    │    └─BasicBlock: 3-10                  [32, 64, 7, 7]            73,984
# │    └─Sequential: 2-16                       [32, 128, 4, 4]           --
# │    │    └─BasicBlock: 3-11                  [32, 128, 4, 4]           230,144
# │    │    └─BasicBlock: 3-12                  [32, 128, 4, 4]           295,424
# │    └─Sequential: 2-17                       [32, 256, 2, 2]           --
# │    │    └─BasicBlock: 3-13                  [32, 256, 2, 2]           919,040
# │    │    └─BasicBlock: 3-14                  [32, 256, 2, 2]           1,180,672
# │    └─Sequential: 2-18                       [32, 512, 1, 1]           --
# │    │    └─BasicBlock: 3-15                  [32, 512, 1, 1]           3,673,088
# │    │    └─BasicBlock: 3-16                  [32, 512, 1, 1]           4,720,640
# │    └─AdaptiveAvgPool2d: 2-19                [32, 512, 1, 1]           --
# │    └─Linear: 2-20                           [32, 1000]                513,000
# ├─Linear: 1-3                                 [32, 2]                   4,002
# ├─Linear: 1-4                                 [32, 2]                   4,002
# ├─Softmax: 1-5                                [32, 2]                   --
# ├─Softmax: 1-6                                [32, 2]                   --
# ===============================================================================================
# Total params: 23,374,484
# Trainable params: 23,374,484
# Non-trainable params: 0
# Total mult-adds (Units.GIGABYTES): 2.15
# ===============================================================================================
# Input size (MB): 0.10
# Forward/backward pass size (MB): 44.55
# Params size (MB): 93.50
# Estimated Total Size (MB): 138.15
# ===============================================================================================

# %%
# 5. Non-Shared backbone & Non-Shared head (4-2)

model_case_4_2 = define_model(temp_backbone_name, case_name='4_2', device=device)
print(summary(model=model_case_4_2, input_size=input_size))
# Out:
# ===============================================================================================
# Layer (type:depth-idx)                        Output Shape              Param #
# ===============================================================================================
# CNN_CASE_4_2                                  [32, 2]                   --
# ├─ResNet: 1-1                                 [32, 1000]                --
# │    └─Conv2d: 2-1                            [32, 64, 14, 14]          3,136
# │    └─BatchNorm2d: 2-2                       [32, 64, 14, 14]          128
# │    └─ReLU: 2-3                              [32, 64, 14, 14]          --
# │    └─MaxPool2d: 2-4                         [32, 64, 7, 7]            --
# │    └─Sequential: 2-5                        [32, 64, 7, 7]            --
# │    │    └─BasicBlock: 3-1                   [32, 64, 7, 7]            73,984
# │    │    └─BasicBlock: 3-2                   [32, 64, 7, 7]            73,984
# │    └─Sequential: 2-6                        [32, 128, 4, 4]           --
# │    │    └─BasicBlock: 3-3                   [32, 128, 4, 4]           230,144
# │    │    └─BasicBlock: 3-4                   [32, 128, 4, 4]           295,424
# │    └─Sequential: 2-7                        [32, 256, 2, 2]           --
# │    │    └─BasicBlock: 3-5                   [32, 256, 2, 2]           919,040
# │    │    └─BasicBlock: 3-6                   [32, 256, 2, 2]           1,180,672
# │    └─Sequential: 2-8                        [32, 512, 1, 1]           --
# │    │    └─BasicBlock: 3-7                   [32, 512, 1, 1]           3,673,088
# │    │    └─BasicBlock: 3-8                   [32, 512, 1, 1]           4,720,640
# │    └─AdaptiveAvgPool2d: 2-9                 [32, 512, 1, 1]           --
# │    └─Linear: 2-10                           [32, 1000]                513,000
# ├─ResNet: 1-2                                 [32, 1000]                --
# │    └─Conv2d: 2-11                           [32, 64, 14, 14]          3,136
# │    └─BatchNorm2d: 2-12                      [32, 64, 14, 14]          128
# │    └─ReLU: 2-13                             [32, 64, 14, 14]          --
# │    └─MaxPool2d: 2-14                        [32, 64, 7, 7]            --
# │    └─Sequential: 2-15                       [32, 64, 7, 7]            --
# │    │    └─BasicBlock: 3-9                   [32, 64, 7, 7]            73,984
# │    │    └─BasicBlock: 3-10                  [32, 64, 7, 7]            73,984
# │    └─Sequential: 2-16                       [32, 128, 4, 4]           --
# │    │    └─BasicBlock: 3-11                  [32, 128, 4, 4]           230,144
# │    │    └─BasicBlock: 3-12                  [32, 128, 4, 4]           295,424
# │    └─Sequential: 2-17                       [32, 256, 2, 2]           --
# │    │    └─BasicBlock: 3-13                  [32, 256, 2, 2]           919,040
# │    │    └─BasicBlock: 3-14                  [32, 256, 2, 2]           1,180,672
# │    └─Sequential: 2-18                       [32, 512, 1, 1]           --
# │    │    └─BasicBlock: 3-15                  [32, 512, 1, 1]           3,673,088
# │    │    └─BasicBlock: 3-16                  [32, 512, 1, 1]           4,720,640
# │    └─AdaptiveAvgPool2d: 2-19                [32, 512, 1, 1]           --
# │    └─Linear: 2-20                           [32, 1000]                513,000
# ├─Linear: 1-3                                 [32, 2]                   2,002
# ├─Linear: 1-4                                 [32, 2]                   2,002
# ├─Softmax: 1-5                                [32, 2]                   --
# ├─Softmax: 1-6                                [32, 2]                   --
# ===============================================================================================
# Total params: 23,370,484
# Trainable params: 23,370,484
# Non-trainable params: 0
# Total mult-adds (Units.GIGABYTES): 2.15
# ===============================================================================================
# Input size (MB): 0.10
# Forward/backward pass size (MB): 44.55
# Params size (MB): 93.48
# Estimated Total Size (MB): 138.14
# ===============================================================================================

# %% [markdown]
# **6. 데이터셋 분리**
#
# * Train Data -> Train Data + Valid Data

# %%
# dataset size

num_tv = sum(train_subset_class_counts)
num_valid = int(0.1 * num_tv)
num_train = num_tv - num_valid

# %%
# 데이터셋 분리

from torch.utils.data import random_split

train_dataset, valid_dataset = random_split(train_subset, [num_train, num_valid])

# %%
# {0,1,2} -> {6,8,9} Mapping 된 DataLoader 생성

from torch.utils.data import Dataset

class MappedDataset(Dataset):
    def __init__(self, dataset):
        self.dataset = dataset

    def __len__(self):
        return len(self.dataset)

    def __getitem__(self, idx):
        img, target = self.dataset[idx]
        target_mapping = {6: 0, 8: 1, 9: 2}
        target = target_mapping[target]

        return img, target

# %%
# DataLoader 생성

train_dataset_loader = DataLoader(MappedDataset(train_dataset),
                                  batch_size=BATCH_SIZE,
                                  shuffle=True)

valid_dataset_loader = DataLoader(MappedDataset(valid_dataset),
                                  batch_size=BATCH_SIZE,
                                  shuffle=False)

test_dataset_loader = DataLoader(MappedDataset(test_subset),
                                 batch_size=BATCH_SIZE,
                                 shuffle=False)

# %%
# {6,8} vs. {9} / {6,9} vs. {8} Split 된 DataLoader 생성

class DualOutputDataset(Dataset):
    def __init__(self, dataset):
        self.dataset = dataset

    def __len__(self):
        return len(self.dataset)

    def __getitem__(self, idx):
        img, target = self.dataset[idx]
        target1_mapping = {6: 0, 8: 0, 9: 1}
        target2_mapping = {6: 0, 8: 1, 9: 0}

        target1 = target1_mapping[target]
        target2 = target2_mapping[target]

        return img, [target1, target2]

# %%
# Dual Output Dataset 생성

train_01_02_dataset_loader = DataLoader(DualOutputDataset(train_dataset),
                                        batch_size=BATCH_SIZE,
                                        shuffle=True)

valid_01_02_dataset_loader = DataLoader(DualOutputDataset(valid_dataset),
                                        batch_size=BATCH_SIZE,
                                        shuffle=False)

test_01_02_dataset_loader = DataLoader(DualOutputDataset(test_subset),
                                       batch_size=BATCH_SIZE,
                                       shuffle=False)

# %% [markdown]
# **7. 모델 학습 함수 정의**

# %%
MAX_EPOCHS = 9999
EARLY_STOPPING_ROUNDS = 20  # Early Stopping Patience (epochs)

# %%
# dual labels -> PyTorch tensor

def convert_to_tensor(labels):
    labels[0] = list(labels[0])
    labels[1] = list(labels[1])
    labels_tensor = torch.tensor(labels)
    labels_tensor = labels_tensor.transpose(0, 1)

    return labels_tensor

# %%
# 모델 학습 실시

# args :
# - model           : 학습할 모델
# - train_loader    : Training Data Loader
# - train_loss_list : 각 epoch 에서의 train loss 기록
# - is_dual_head    : 신경망 출력값, 즉 MLP Head 가 2개인지의 여부

# returns :
# - train_loss : 모델의 Train Loss

def run_train(model, train_loader, train_loss_list, is_dual_head, verbose):
    model.train()
    train_loss = 0.0
    total_data = 0
    train_idx = 0

    for images, labels in train_loader:
        if is_dual_head:
            labels = convert_to_tensor(labels)
        images, labels = images.to(device), labels.to(device)

        # train 실시
        model.optimizer.zero_grad()
        outputs = model(images)

        if is_dual_head:
            loss1 = nn.CrossEntropyLoss(reduction='sum')(outputs[0], labels[:, 0])
            loss2 = nn.CrossEntropyLoss(reduction='sum')(outputs[1], labels[:, 1])
            loss = loss1 + loss2
        else:
            loss = nn.CrossEntropyLoss(reduction='sum')(outputs, labels)

        loss.backward()
        model.optimizer.step()

        train_loss += loss.item()
        total_data += labels.size(0)
        train_idx += 1

        if verbose:
            if train_idx % 20 == 0:
                print(f'idx: {train_idx}, loss for current batch: {loss.item() / labels.size(0):.6f}')

    train_loss_list.append(train_loss / total_data)
    return train_loss_list[-1]

# %%
import time

# 모델 validation / test 실시

# args :
# - model                : validation/test 할 모델
# - valid_or_test_loader : validation/test Data Loader
# - is_dual_head         : 신경망 출력값, 즉 MLP Head 가 2개인지의 여부

# returns :
# - accuracy       : 모델의 validation/test 정확도
# - inference_time : inference 시간 (seconds)

def run_valid_or_test(model, valid_or_test_loader, is_dual_head):
    model.eval()
    correct, total_data, valid_loss = 0, 0, 0.0
    inference_time_sum = 0.0
    valid_test_idx = 0

    with torch.no_grad():
        for images, labels in valid_or_test_loader:
            if is_dual_head:
                labels = convert_to_tensor(labels)
            images, labels = images.to(device), labels.to(device)

            start_at = time.time()
            outputs = model(images)
            inference_time_sum += time.time() - start_at

            # validation/test 실시 및 Loss 계산 & 정확도 측정
            if is_dual_head:
                _, predicted_1 = torch.max(outputs[0], 1)
                _, predicted_2 = torch.max(outputs[1], 1)
                correct += ((predicted_1 == labels[:, 0]) & (predicted_2 == labels[:, 1])).sum().item()

                loss1 = nn.CrossEntropyLoss(reduction='sum')(outputs[0], labels[:, 0])
                loss2 = nn.CrossEntropyLoss(reduction='sum')(outputs[1], labels[:, 1])
                loss = loss1 + loss2

            else:
                _, predicted = torch.max(outputs, 1)
                correct += (predicted == labels).sum().item()
                loss = nn.CrossEntropyLoss(reduction='sum')(outputs, labels)

            valid_loss += loss.item()
            total_data += labels.size(0)
            valid_test_idx += 1

    accuracy = correct / total_data
    inference_time = inference_time_sum / valid_test_idx
    loss = valid_loss / total_data

    return accuracy, loss, inference_time

# %%
# 모델 학습 및 validation 전체 프로세스

# args :
# - model         : 학습할 모델
# - train_loader  : Training Data Loader
# - valid_loader  : Valid Data Loader
# - test_loader   : Test Data Loader
# - backbone_name : Backbone 모델 이름 ('resnet18', 'resnet34' or 'resnet50')
# - case_name     : 모델 구조 case 이름 ('1', '2', '3', '4_1' or '4_2')
# - verbose       : 학습 중 프로세스 출력 여부

# returns :
# - final_acc      : 최종 Accuracy
# - inference_time : inference 시간 (seconds)

def run_model_common(model, train_loader, valid_loader, test_loader,
                     backbone_name, case_name, verbose=False):

    train_loss_list = []        # train loss
    min_valid_loss = 999.9      # min validation loss
    best_valid_loss_epoch = -1  # valid_loss 가 가장 낮았던 epoch
    best_epoch_model = None     # valid_loss 가 가장 낮았던 epoch 의 모델

    is_dual_head = case_name in ['3', '4_1', '4_2']

    # 1. 학습 실시
    for epoch in range(MAX_EPOCHS):

        # 1-1. train model
        train_loss = run_train(model,
                               train_loader,
                               train_loss_list,
                               is_dual_head,
                               verbose=(verbose and epoch == 0))

        # 1-2. validate model (with VALID SET)
        valid_acc, valid_loss, _ = run_valid_or_test(model, valid_loader, is_dual_head)

        # 1-3. Early Stopping 처리 (overfitting 방지)
        if valid_loss < min_valid_loss - 1e-6:
            min_valid_loss = valid_loss
            best_valid_loss_epoch = epoch

            best_epoch_model = define_model(backbone_name, case_name, device)
            best_epoch_model.load_state_dict(model.state_dict())

            if verbose:
                print('best model updated')

        if epoch - best_valid_loss_epoch >= EARLY_STOPPING_ROUNDS:
            break

        # 1-4. 결과 출력
        if verbose:
            print(f"Epoch {epoch+1}, Loss: train={train_loss:.4f} valid={valid_loss:.4f}, Acc: valid={valid_acc:.4f}")

    # check best-epoch model correctly loaded
    _, checked_loss, _ = run_valid_or_test(best_epoch_model, valid_loader, is_dual_head)

    if verbose:
        print(f"Best Epoch: {best_valid_loss_epoch}, Best Valid Loss: {min_valid_loss}")
        print(f"Valid Loss (with Epoch valid set) on Loaded Best Model: {checked_loss}")

    assert abs(min_valid_loss - checked_loss) < 1e-6

    # 2. test best-epoch model (with TEST SET)
    final_acc, _, inference_time = run_valid_or_test(best_epoch_model, test_loader, is_dual_head)

    if verbose:
        print(f"Final Acc (with TEST set) on Loaded Best Model: {final_acc} (time: {inference_time})")

    return final_acc, inference_time

# %% [markdown]
# **8. 학습 실시**

# %%
print(device)
# Out:
# cuda

# %%
result_dict = {
    'backbone': [],
    'case': [],
    'accuracy': [],
    'inference_time': []
}

dataloader_by_case_name = {
    'dual_head': {
        'train': train_01_02_dataset_loader,
        'valid': valid_01_02_dataset_loader,
        'test': test_01_02_dataset_loader
    },
    'single_head': {
        'train': train_dataset_loader,
        'valid': valid_dataset_loader,
        'test': test_dataset_loader
    }
}

for case_name in ['1', '2', '3', '4_1', '4_2']:
    if case_name in ['3', '4_1', '4_2']:
        head_type = 'dual_head'
    else:
        head_type = 'single_head'

    for backbone_name in ['resnet18', 'resnet34', 'resnet50']:
        print(f'\n=== case={case_name}, backbone={backbone_name} ===')
        model = define_model(backbone_name, case_name, device=device)

        train_loader = dataloader_by_case_name[head_type]['train']
        valid_loader = dataloader_by_case_name[head_type]['valid']
        test_loader = dataloader_by_case_name[head_type]['test']

        final_acc, inference_time = run_model_common(model,
                                                     train_loader=train_loader,
                                                     valid_loader=valid_loader,
                                                     test_loader=test_loader,
                                                     backbone_name=backbone_name,
                                                     case_name=case_name,
                                                     verbose=True)

        result_dict['backbone'].append(backbone_name)
        result_dict['case'].append(case_name)
        result_dict['accuracy'].append(final_acc)
        result_dict['inference_time'].append(inference_time)
# Out:
# === case=1, backbone=resnet18 ===
# idx: 20, loss for current batch: 1.207695
# best model updated
# Epoch 1, Loss: train=1.2103 valid=1.2267, Acc: valid=0.3248
# Epoch 2, Loss: train=1.2121 valid=1.2267, Acc: valid=0.3248
# Epoch 3, Loss: train=1.2121 valid=1.2267, Acc: valid=0.3248
# Epoch 4, Loss: train=1.2121 valid=1.2267, Acc: valid=0.3248
# Epoch 5, Loss: train=1.2121 valid=1.2267, Acc: valid=0.3248
# Epoch 6, Loss: train=1.2121 valid=1.2267, Acc: valid=0.3248
# Epoch 7, Loss: train=1.2121 valid=1.2267, Acc: valid=0.3248
# Epoch 8, Loss: train=1.2121 valid=1.2267, Acc: valid=0.3248
# Epoch 9, Loss: train=1.2121 valid=1.2267, Acc: valid=0.3248
# Epoch 10, Loss: train=1.2121 valid=1.2267, Acc: valid=0.3248
# Epoch 11, Loss: train=1.2121 valid=1.2267, Acc: valid=0.3248
# Epoch 12, Loss: train=1.2121 valid=1.2267, Acc: valid=0.3248
# Epoch 13, Loss: train=1.2121 valid=1.2267, Acc: valid=0.3248
# Epoch 14, Loss: train=1.2121 valid=1.2267, Acc: valid=0.3248
# Epoch 15, Loss: train=1.2121 valid=1.2267, Acc: valid=0.3248
# Epoch 16, Loss: train=1.2121 valid=1.2267, Acc: valid=0.3248
# Epoch 17, Loss: train=1.2121 valid=1.2267, Acc: valid=0.3248
# Epoch 18, Loss: train=1.2121 valid=1.2267, Acc: valid=0.3248
# Epoch 19, Loss: train=1.2121 valid=1.2267, Acc: valid=0.3248
# Epoch 20, Loss: train=1.2121 valid=1.2267, Acc: valid=0.3248
# Best Epoch: 0, Best Valid Loss: 1.2266584543081431
# Valid Loss (with Epoch valid set) on Loaded Best Model: 1.2266584543081431
# Final Acc (with TEST set) on Loaded Best Model: 0.34308058483509013 (time: 0.0047751561455104665)
#
# === case=1, backbone=resnet34 ===
# idx: 20, loss for current batch: 1.238945
# best model updated
# Epoch 1, Loss: train=1.1612 valid=1.2267, Acc: valid=0.3248
# Epoch 2, Loss: train=1.1541 valid=1.2438, Acc: valid=0.3077
# Epoch 3, Loss: train=1.1953 valid=1.2267, Acc: valid=0.3248
# best model updated
# Epoch 4, Loss: train=1.0170 valid=1.0215, Acc: valid=0.5299
# Epoch 5, Loss: train=1.0628 valid=1.0557, Acc: valid=0.4957
# Epoch 6, Loss: train=1.0779 valid=1.0985, Acc: valid=0.4530
# Epoch 7, Loss: train=1.0807 valid=1.0899, Acc: valid=0.4615
# Epoch 8, Loss: train=1.0722 valid=1.0301, Acc: valid=0.5214
# best model updated
# Epoch 9, Loss: train=1.0524 valid=0.9959, Acc: valid=0.5556
# Epoch 10, Loss: train=1.0477 valid=1.0728, Acc: valid=0.4786
# Epoch 11, Loss: train=1.0392 valid=1.0301, Acc: valid=0.5214
# Epoch 12, Loss: train=1.0732 valid=1.1241, Acc: valid=0.4274
# Epoch 13, Loss: train=1.0882 valid=1.0985, Acc: valid=0.4530
# Epoch 14, Loss: train=1.0654 valid=1.0643, Acc: valid=0.4872
# Epoch 15, Loss: train=1.2001 valid=1.2181, Acc: valid=0.3333
# Epoch 16, Loss: train=1.2121 valid=1.2267, Acc: valid=0.3248
# Epoch 17, Loss: train=1.2121 valid=1.2181, Acc: valid=0.3333
# Epoch 18, Loss: train=1.2121 valid=1.2096, Acc: valid=0.3419
# Epoch 19, Loss: train=1.2121 valid=1.2096, Acc: valid=0.3419
# Epoch 20, Loss: train=1.2121 valid=1.2181, Acc: valid=0.3333
# Epoch 21, Loss: train=1.2121 valid=1.2267, Acc: valid=0.3248
# Epoch 22, Loss: train=1.2121 valid=1.2267, Acc: valid=0.3248
# Epoch 23, Loss: train=1.2121 valid=1.2267, Acc: valid=0.3248
# Epoch 24, Loss: train=1.2121 valid=1.2181, Acc: valid=0.3333
# Epoch 25, Loss: train=1.2121 valid=1.2181, Acc: valid=0.3333
# Epoch 26, Loss: train=1.2121 valid=1.2181, Acc: valid=0.3333
# Epoch 27, Loss: train=1.2121 valid=1.2181, Acc: valid=0.3333
# Epoch 28, Loss: train=1.2121 valid=1.2267, Acc: valid=0.3248
# Best Epoch: 8, Best Valid Loss: 0.9958892235389123
# Valid Loss (with Epoch valid set) on Loaded Best Model: 0.9958892235389123
# Final Acc (with TEST set) on Loaded Best Model: 0.5763345800748045 (time: 0.00828340779180112)
#
# === case=1, backbone=resnet50 ===
# idx: 20, loss for current batch: 1.270195
# best model updated
# Epoch 1, Loss: train=1.2130 valid=1.1839, Acc: valid=0.3675
# Epoch 2, Loss: train=1.2093 valid=1.1839, Acc: valid=0.3675
# Epoch 3, Loss: train=1.2093 valid=1.1839, Acc: valid=0.3675
# Epoch 4, Loss: train=1.2093 valid=1.1839, Acc: valid=0.3675
# Epoch 5, Loss: train=1.2093 valid=1.1839, Acc: valid=0.3675
# Epoch 6, Loss: train=1.2093 valid=1.1839, Acc: valid=0.3675
# Epoch 7, Loss: train=1.2093 valid=1.1839, Acc: valid=0.3675
# Epoch 8, Loss: train=1.2093 valid=1.1839, Acc: valid=0.3675
# Epoch 9, Loss: train=1.2093 valid=1.1839, Acc: valid=0.3675
# Epoch 10, Loss: train=1.2093 valid=1.1839, Acc: valid=0.3675
# Epoch 11, Loss: train=1.2093 valid=1.1839, Acc: valid=0.3675
# Epoch 12, Loss: train=1.2093 valid=1.1839, Acc: valid=0.3675
# Epoch 13, Loss: train=1.2093 valid=1.1839, Acc: valid=0.3675
# Epoch 14, Loss: train=1.2093 valid=1.1839, Acc: valid=0.3675
# Epoch 15, Loss: train=1.2093 valid=1.1839, Acc: valid=0.3675
# Epoch 16, Loss: train=1.2093 valid=1.1839, Acc: valid=0.3675
# Epoch 17, Loss: train=1.2093 valid=1.1839, Acc: valid=0.3675
# Epoch 18, Loss: train=1.2093 valid=1.1839, Acc: valid=0.3675
# Epoch 19, Loss: train=1.2093 valid=1.1839, Acc: valid=0.3675
# Epoch 20, Loss: train=1.2093 valid=1.1839, Acc: valid=0.3675
# Best Epoch: 0, Best Valid Loss: 1.1839234115731003
# Valid Loss (with Epoch valid set) on Loaded Best Model: 1.1839234115731003
# Final Acc (with TEST set) on Loaded Best Model: 0.32573954437266234 (time: 0.014294994914013407)
#
# === case=2, backbone=resnet18 ===
# idx: 20, loss for current batch: 1.395195
# best model updated
# Epoch 1, Loss: train=1.1857 valid=1.2438, Acc: valid=0.3077
# Epoch 2, Loss: train=1.2329 valid=1.2438, Acc: valid=0.3077
# Epoch 3, Loss: train=1.2329 valid=1.2438, Acc: valid=0.3077
# Epoch 4, Loss: train=1.2329 valid=1.2438, Acc: valid=0.3077
# Epoch 5, Loss: train=1.2329 valid=1.2438, Acc: valid=0.3077
# Epoch 6, Loss: train=1.2329 valid=1.2438, Acc: valid=0.3077
# Epoch 7, Loss: train=1.2329 valid=1.2438, Acc: valid=0.3077
# Epoch 8, Loss: train=1.2329 valid=1.2438, Acc: valid=0.3077
# Epoch 9, Loss: train=1.2329 valid=1.2438, Acc: valid=0.3077
# Epoch 10, Loss: train=1.2329 valid=1.2438, Acc: valid=0.3077
# Epoch 11, Loss: train=1.2329 valid=1.2438, Acc: valid=0.3077
# Epoch 12, Loss: train=1.2329 valid=1.2438, Acc: valid=0.3077
# Epoch 13, Loss: train=1.2329 valid=1.2438, Acc: valid=0.3077
# Epoch 14, Loss: train=1.2329 valid=1.2438, Acc: valid=0.3077
# Epoch 15, Loss: train=1.2329 valid=1.2438, Acc: valid=0.3077
# Epoch 16, Loss: train=1.2329 valid=1.2438, Acc: valid=0.3077
# Epoch 17, Loss: train=1.2329 valid=1.2438, Acc: valid=0.3077
# Epoch 18, Loss: train=1.2329 valid=1.2438, Acc: valid=0.3077
# Epoch 19, Loss: train=1.2329 valid=1.2438, Acc: valid=0.3077
# Epoch 20, Loss: train=1.2329 valid=1.2438, Acc: valid=0.3077
# Best Epoch: 0, Best Valid Loss: 1.2437524714021602
# Valid Loss (with Epoch valid set) on Loaded Best Model: 1.2437524714021602
# Final Acc (with TEST set) on Loaded Best Model: 0.33117987079224753 (time: 0.002384869948677395)
#
# === case=2, backbone=resnet34 ===
# idx: 20, loss for current batch: 1.238945
# best model updated
# Epoch 1, Loss: train=1.1715 valid=1.2267, Acc: valid=0.3248
# Epoch 2, Loss: train=1.2063 valid=1.2267, Acc: valid=0.3248
# Epoch 3, Loss: train=1.2121 valid=1.2267, Acc: valid=0.3248
# Epoch 4, Loss: train=1.2121 valid=1.2267, Acc: valid=0.3248
# Epoch 5, Loss: train=1.2121 valid=1.2267, Acc: valid=0.3248
# Epoch 6, Loss: train=1.2121 valid=1.2267, Acc: valid=0.3248
# Epoch 7, Loss: train=1.2121 valid=1.2267, Acc: valid=0.3248
# Epoch 8, Loss: train=1.2121 valid=1.2267, Acc: valid=0.3248
# Epoch 9, Loss: train=1.2121 valid=1.2267, Acc: valid=0.3248
# Epoch 10, Loss: train=1.2121 valid=1.2267, Acc: valid=0.3248
# Epoch 11, Loss: train=1.2121 valid=1.2267, Acc: valid=0.3248
# Epoch 12, Loss: train=1.2121 valid=1.2267, Acc: valid=0.3248
# Epoch 13, Loss: train=1.2121 valid=1.2267, Acc: valid=0.3248
# Epoch 14, Loss: train=1.2121 valid=1.2267, Acc: valid=0.3248
# Epoch 15, Loss: train=1.2121 valid=1.2267, Acc: valid=0.3248
# Epoch 16, Loss: train=1.2121 valid=1.2267, Acc: valid=0.3248
# Epoch 17, Loss: train=1.2121 valid=1.2267, Acc: valid=0.3248
# Epoch 18, Loss: train=1.2121 valid=1.2267, Acc: valid=0.3248
# Epoch 19, Loss: train=1.2121 valid=1.2267, Acc: valid=0.3248
# Epoch 20, Loss: train=1.2121 valid=1.2267, Acc: valid=0.3248
# Best Epoch: 0, Best Valid Loss: 1.2266584543081431
# Valid Loss (with Epoch valid set) on Loaded Best Model: 1.2266584543081431
# Final Acc (with TEST set) on Loaded Best Model: 0.34308058483509013 (time: 0.006673890611399775)
#
# === case=2, backbone=resnet50 ===
# idx: 20, loss for current batch: 1.238945
# best model updated
# Epoch 1, Loss: train=1.1303 valid=1.2010, Acc: valid=0.3504
# best model updated
# Epoch 2, Loss: train=1.0212 valid=1.0301, Acc: valid=0.5214
# Epoch 3, Loss: train=1.0457 valid=1.0899, Acc: valid=0.4615
# Epoch 4, Loss: train=1.1050 valid=1.2267, Acc: valid=0.3248
# Epoch 5, Loss: train=1.2098 valid=1.1839, Acc: valid=0.3675
# Epoch 6, Loss: train=1.2093 valid=1.1839, Acc: valid=0.3675
# Epoch 7, Loss: train=1.2093 valid=1.1839, Acc: valid=0.3675
# Epoch 8, Loss: train=1.2093 valid=1.1839, Acc: valid=0.3675
# Epoch 9, Loss: train=1.2093 valid=1.1839, Acc: valid=0.3675
# Epoch 10, Loss: train=1.2093 valid=1.1839, Acc: valid=0.3675
# Epoch 11, Loss: train=1.2093 valid=1.1839, Acc: valid=0.3675
# Epoch 12, Loss: train=1.2093 valid=1.1839, Acc: valid=0.3675
# Epoch 13, Loss: train=1.2093 valid=1.1839, Acc: valid=0.3675
# Epoch 14, Loss: train=1.2093 valid=1.1839, Acc: valid=0.3675
# Epoch 15, Loss: train=1.2093 valid=1.1839, Acc: valid=0.3675
# Epoch 16, Loss: train=1.2093 valid=1.1839, Acc: valid=0.3675
# Epoch 17, Loss: train=1.2093 valid=1.1839, Acc: valid=0.3675
# Epoch 18, Loss: train=1.2093 valid=1.1839, Acc: valid=0.3675
# Epoch 19, Loss: train=1.2093 valid=1.1839, Acc: valid=0.3675
# Epoch 20, Loss: train=1.2093 valid=1.1839, Acc: valid=0.3675
# Epoch 21, Loss: train=1.2093 valid=1.1839, Acc: valid=0.3675
# Best Epoch: 1, Best Valid Loss: 1.0300772577269464
# Valid Loss (with Epoch valid set) on Loaded Best Model: 1.0300772577269464
# Final Acc (with TEST set) on Loaded Best Model: 0.5351921115266915 (time: 0.007451930771703305)
#
# === case=3, backbone=resnet18 ===
# idx: 20, loss for current batch: 1.345273
# best model updated
# Epoch 1, Loss: train=1.2966 valid=1.2590, Acc: valid=0.3675
# Epoch 2, Loss: train=1.2844 valid=1.2590, Acc: valid=0.3675
# Epoch 3, Loss: train=1.2844 valid=1.2590, Acc: valid=0.3675
# Epoch 4, Loss: train=1.2844 valid=1.2590, Acc: valid=0.3675
# Epoch 5, Loss: train=1.2844 valid=1.2590, Acc: valid=0.3675
# Epoch 6, Loss: train=1.2844 valid=1.2590, Acc: valid=0.3675
# Epoch 7, Loss: train=1.2844 valid=1.2590, Acc: valid=0.3675
# Epoch 8, Loss: train=1.2844 valid=1.2590, Acc: valid=0.3675
# Epoch 9, Loss: train=1.2844 valid=1.2590, Acc: valid=0.3675
# Epoch 10, Loss: train=1.2844 valid=1.2590, Acc: valid=0.3675
# Epoch 11, Loss: train=1.2844 valid=1.2590, Acc: valid=0.3675
# Epoch 12, Loss: train=1.2844 valid=1.2590, Acc: valid=0.3675
# Epoch 13, Loss: train=1.2844 valid=1.2590, Acc: valid=0.3675
# Epoch 14, Loss: train=1.2844 valid=1.2590, Acc: valid=0.3675
# Epoch 15, Loss: train=1.2844 valid=1.2590, Acc: valid=0.3675
# Epoch 16, Loss: train=1.2844 valid=1.2590, Acc: valid=0.3675
# Epoch 17, Loss: train=1.2844 valid=1.2590, Acc: valid=0.3675
# Epoch 18, Loss: train=1.2844 valid=1.2590, Acc: valid=0.3675
# Epoch 19, Loss: train=1.2844 valid=1.2590, Acc: valid=0.3675
# Epoch 20, Loss: train=1.2844 valid=1.2590, Acc: valid=0.3675
# Best Epoch: 0, Best Valid Loss: 1.2590021312746227
# Valid Loss (with Epoch valid set) on Loaded Best Model: 1.2590021312746227
# Final Acc (with TEST set) on Loaded Best Model: 0.32573954437266234 (time: 0.0023772275966146717)
#
# === case=3, backbone=resnet34 ===
# idx: 20, loss for current batch: 1.220160
# best model updated
# Epoch 1, Loss: train=1.2798 valid=1.5838, Acc: valid=0.3248
# best model updated
# Epoch 2, Loss: train=1.2244 valid=1.2675, Acc: valid=0.3932
# Epoch 3, Loss: train=1.1908 valid=1.2932, Acc: valid=0.5641
# best model updated
# Epoch 4, Loss: train=1.2239 valid=1.1222, Acc: valid=0.5043
# Epoch 5, Loss: train=1.2050 valid=1.2163, Acc: valid=0.4103
# Epoch 6, Loss: train=1.3820 valid=1.6094, Acc: valid=0.3248
# Epoch 7, Loss: train=1.6057 valid=1.6094, Acc: valid=0.3248
# Epoch 8, Loss: train=1.6057 valid=1.6094, Acc: valid=0.3248
# Epoch 9, Loss: train=1.6057 valid=1.6094, Acc: valid=0.3248
# Epoch 10, Loss: train=1.6057 valid=1.6094, Acc: valid=0.3248
# Epoch 11, Loss: train=1.6057 valid=1.6094, Acc: valid=0.3248
# Epoch 12, Loss: train=1.6057 valid=1.6094, Acc: valid=0.3248
# Epoch 13, Loss: train=1.6057 valid=1.6094, Acc: valid=0.3248
# Epoch 14, Loss: train=1.6057 valid=1.6094, Acc: valid=0.3248
# Epoch 15, Loss: train=1.6057 valid=1.6094, Acc: valid=0.3248
# Epoch 16, Loss: train=1.6057 valid=1.6094, Acc: valid=0.3248
# Epoch 17, Loss: train=1.6057 valid=1.6094, Acc: valid=0.3248
# Epoch 18, Loss: train=1.6057 valid=1.6094, Acc: valid=0.3248
# Epoch 19, Loss: train=1.6057 valid=1.6094, Acc: valid=0.3248
# Epoch 20, Loss: train=1.6057 valid=1.6094, Acc: valid=0.3248
# Epoch 21, Loss: train=1.6057 valid=1.6094, Acc: valid=0.3248
# Epoch 22, Loss: train=1.6057 valid=1.6094, Acc: valid=0.3248
# Epoch 23, Loss: train=1.6057 valid=1.6094, Acc: valid=0.3248
# Best Epoch: 3, Best Valid Loss: 1.122249994522486
# Valid Loss (with Epoch valid set) on Loaded Best Model: 1.122249994522486
# Final Acc (with TEST set) on Loaded Best Model: 0.44610676640598435 (time: 0.004236242045526919)
#
# === case=3, backbone=resnet50 ===
# idx: 20, loss for current batch: 1.282773
# best model updated
# Epoch 1, Loss: train=1.2898 valid=1.2590, Acc: valid=0.3675
# Epoch 2, Loss: train=1.2844 valid=1.2590, Acc: valid=0.3675
# Epoch 3, Loss: train=1.2844 valid=1.2590, Acc: valid=0.3675
# Epoch 4, Loss: train=1.2844 valid=1.2590, Acc: valid=0.3675
# Epoch 5, Loss: train=1.2844 valid=1.2590, Acc: valid=0.3675
# Epoch 6, Loss: train=1.2844 valid=1.2590, Acc: valid=0.3675
# Epoch 7, Loss: train=1.2844 valid=1.2590, Acc: valid=0.3675
# Epoch 8, Loss: train=1.2844 valid=1.2590, Acc: valid=0.3675
# Epoch 9, Loss: train=1.2844 valid=1.2590, Acc: valid=0.3675
# Epoch 10, Loss: train=1.2844 valid=1.2590, Acc: valid=0.3675
# Epoch 11, Loss: train=1.2844 valid=1.2590, Acc: valid=0.3675
# Epoch 12, Loss: train=1.2844 valid=1.2590, Acc: valid=0.3675
# Epoch 13, Loss: train=1.2844 valid=1.2590, Acc: valid=0.3675
# Epoch 14, Loss: train=1.2844 valid=1.2590, Acc: valid=0.3675
# Epoch 15, Loss: train=1.2844 valid=1.2590, Acc: valid=0.3675
# Epoch 16, Loss: train=1.2844 valid=1.2590, Acc: valid=0.3675
# Epoch 17, Loss: train=1.2844 valid=1.2590, Acc: valid=0.3675
# Epoch 18, Loss: train=1.2844 valid=1.2590, Acc: valid=0.3675
# Epoch 19, Loss: train=1.2844 valid=1.2590, Acc: valid=0.3675
# Epoch 20, Loss: train=1.2844 valid=1.2590, Acc: valid=0.3675
# Best Epoch: 0, Best Valid Loss: 1.2590021312746227
# Valid Loss (with Epoch valid set) on Loaded Best Model: 1.2590021312746227
# Final Acc (with TEST set) on Loaded Best Model: 0.32573954437266234 (time: 0.005486340626426365)
#
# === case=4_1, backbone=resnet18 ===
# idx: 20, loss for current batch: 1.345273
# best model updated
# Epoch 1, Loss: train=1.2970 valid=1.2590, Acc: valid=0.3675
# Epoch 2, Loss: train=1.2844 valid=1.2590, Acc: valid=0.3675
# Epoch 3, Loss: train=1.2844 valid=1.2590, Acc: valid=0.3675
# Epoch 4, Loss: train=1.2844 valid=1.2590, Acc: valid=0.3675
# Epoch 5, Loss: train=1.2844 valid=1.2590, Acc: valid=0.3675
# Epoch 6, Loss: train=1.2844 valid=1.2590, Acc: valid=0.3675
# Epoch 7, Loss: train=1.2844 valid=1.2590, Acc: valid=0.3675
# Epoch 8, Loss: train=1.2844 valid=1.2590, Acc: valid=0.3675
# Epoch 9, Loss: train=1.2844 valid=1.2590, Acc: valid=0.3675
# Epoch 10, Loss: train=1.2844 valid=1.2590, Acc: valid=0.3675
# Epoch 11, Loss: train=1.2844 valid=1.2590, Acc: valid=0.3675
# Epoch 12, Loss: train=1.2844 valid=1.2590, Acc: valid=0.3675
# Epoch 13, Loss: train=1.2844 valid=1.2590, Acc: valid=0.3675
# Epoch 14, Loss: train=1.2844 valid=1.2590, Acc: valid=0.3675
# Epoch 15, Loss: train=1.2844 valid=1.2590, Acc: valid=0.3675
# Epoch 16, Loss: train=1.2844 valid=1.2590, Acc: valid=0.3675
# Epoch 17, Loss: train=1.2844 valid=1.2590, Acc: valid=0.3675
# Epoch 18, Loss: train=1.2844 valid=1.2590, Acc: valid=0.3675
# Epoch 19, Loss: train=1.2844 valid=1.2590, Acc: valid=0.3675
# Epoch 20, Loss: train=1.2844 valid=1.2590, Acc: valid=0.3675
# Best Epoch: 0, Best Valid Loss: 1.2590021312746227
# Valid Loss (with Epoch valid set) on Loaded Best Model: 1.2590021312746227
# Final Acc (with TEST set) on Loaded Best Model: 0.32573954437266234 (time: 0.00681459903717041)
#
# === case=4_1, backbone=resnet34 ===
# idx: 20, loss for current batch: 1.220273
# best model updated
# Epoch 1, Loss: train=1.2951 valid=1.2590, Acc: valid=0.3675
# Epoch 2, Loss: train=1.2844 valid=1.2590, Acc: valid=0.3675
# Epoch 3, Loss: train=1.2844 valid=1.2590, Acc: valid=0.3675
# Epoch 4, Loss: train=1.2844 valid=1.2590, Acc: valid=0.3675
# Epoch 5, Loss: train=1.2844 valid=1.2590, Acc: valid=0.3675
# Epoch 6, Loss: train=1.2844 valid=1.2590, Acc: valid=0.3675
# Epoch 7, Loss: train=1.2844 valid=1.2590, Acc: valid=0.3675
# Epoch 8, Loss: train=1.2844 valid=1.2590, Acc: valid=0.3675
# Epoch 9, Loss: train=1.2844 valid=1.2590, Acc: valid=0.3675
# Epoch 10, Loss: train=1.2844 valid=1.2590, Acc: valid=0.3675
# Epoch 11, Loss: train=1.2844 valid=1.2590, Acc: valid=0.3675
# Epoch 12, Loss: train=1.2844 valid=1.2590, Acc: valid=0.3675
# Epoch 13, Loss: train=1.2844 valid=1.2590, Acc: valid=0.3675
# Epoch 14, Loss: train=1.2844 valid=1.2590, Acc: valid=0.3675
# Epoch 15, Loss: train=1.2844 valid=1.2590, Acc: valid=0.3675
# Epoch 16, Loss: train=1.2844 valid=1.2590, Acc: valid=0.3675
# Epoch 17, Loss: train=1.2844 valid=1.2590, Acc: valid=0.3675
# Epoch 18, Loss: train=1.2844 valid=1.2590, Acc: valid=0.3675
# Epoch 19, Loss: train=1.2844 valid=1.2590, Acc: valid=0.3675
# Epoch 20, Loss: train=1.2844 valid=1.2590, Acc: valid=0.3675
# Best Epoch: 0, Best Valid Loss: 1.2590021312746227
# Valid Loss (with Epoch valid set) on Loaded Best Model: 1.2590021312746227
# Final Acc (with TEST set) on Loaded Best Model: 0.32573954437266234 (time: 0.008016581120698349)
#
# === case=4_1, backbone=resnet50 ===
# idx: 20, loss for current batch: 1.251523
# best model updated
# Epoch 1, Loss: train=1.2863 valid=1.2590, Acc: valid=0.3675
# Epoch 2, Loss: train=1.2844 valid=1.2590, Acc: valid=0.3675
# Epoch 3, Loss: train=1.2844 valid=1.2590, Acc: valid=0.3675
# Epoch 4, Loss: train=1.2844 valid=1.2590, Acc: valid=0.3675
# Epoch 5, Loss: train=1.2844 valid=1.2590, Acc: valid=0.3675
# Epoch 6, Loss: train=1.2844 valid=1.2590, Acc: valid=0.3675
# Epoch 7, Loss: train=1.2844 valid=1.2590, Acc: valid=0.3675
# Epoch 8, Loss: train=1.2844 valid=1.2590, Acc: valid=0.3675
# Epoch 9, Loss: train=1.2844 valid=1.2590, Acc: valid=0.3675
# Epoch 10, Loss: train=1.2844 valid=1.2590, Acc: valid=0.3675
# Epoch 11, Loss: train=1.2844 valid=1.2590, Acc: valid=0.3675
# Epoch 12, Loss: train=1.2844 valid=1.2590, Acc: valid=0.3675
# Epoch 13, Loss: train=1.2844 valid=1.2590, Acc: valid=0.3675
# Epoch 14, Loss: train=1.2844 valid=1.2590, Acc: valid=0.3675
# Epoch 15, Loss: train=1.2844 valid=1.2590, Acc: valid=0.3675
# Epoch 16, Loss: train=1.2844 valid=1.2590, Acc: valid=0.3675
# Epoch 17, Loss: train=1.2844 valid=1.2590, Acc: valid=0.3675
# Epoch 18, Loss: train=1.2844 valid=1.2590, Acc: valid=0.3675
# Epoch 19, Loss: train=1.2844 valid=1.2590, Acc: valid=0.3675
# Epoch 20, Loss: train=1.2844 valid=1.2590, Acc: valid=0.3675
# Best Epoch: 0, Best Valid Loss: 1.2590021312746227
# Valid Loss (with Epoch valid set) on Loaded Best Model: 1.2590021312746227
# Final Acc (with TEST set) on Loaded Best Model: 0.32573954437266234 (time: 0.01058823647706405)
#
# === case=4_2, backbone=resnet18 ===
# idx: 20, loss for current batch: 1.189023
# best model updated
# Epoch 1, Loss: train=1.2866 valid=1.2590, Acc: valid=0.3675
# Epoch 2, Loss: train=1.2834 valid=1.2590, Acc: valid=0.3675
# Epoch 3, Loss: train=1.2844 valid=1.2590, Acc: valid=0.3675
# Epoch 4, Loss: train=1.2844 valid=1.2590, Acc: valid=0.3675
# Epoch 5, Loss: train=1.2844 valid=1.2590, Acc: valid=0.3675
# Epoch 6, Loss: train=1.2844 valid=1.2590, Acc: valid=0.3675
# Epoch 7, Loss: train=1.2844 valid=1.2590, Acc: valid=0.3675
# Epoch 8, Loss: train=1.2844 valid=1.2590, Acc: valid=0.3675
# Epoch 9, Loss: train=1.2844 valid=1.2590, Acc: valid=0.3675
# Epoch 10, Loss: train=1.2844 valid=1.2590, Acc: valid=0.3675
# Epoch 11, Loss: train=1.2844 valid=1.2590, Acc: valid=0.3675
# Epoch 12, Loss: train=1.2844 valid=1.2590, Acc: valid=0.3675
# Epoch 13, Loss: train=1.2844 valid=1.2590, Acc: valid=0.3675
# Epoch 14, Loss: train=1.2844 valid=1.2590, Acc: valid=0.3675
# Epoch 15, Loss: train=1.2844 valid=1.2590, Acc: valid=0.3675
# Epoch 16, Loss: train=1.2844 valid=1.2590, Acc: valid=0.3675
# Epoch 17, Loss: train=1.2844 valid=1.2590, Acc: valid=0.3675
# Epoch 18, Loss: train=1.2844 valid=1.2590, Acc: valid=0.3675
# Epoch 19, Loss: train=1.2844 valid=1.2590, Acc: valid=0.3675
# Epoch 20, Loss: train=1.2844 valid=1.2590, Acc: valid=0.3675
# Best Epoch: 0, Best Valid Loss: 1.2590021312746227
# Valid Loss (with Epoch valid set) on Loaded Best Model: 1.2590021312746227
# Final Acc (with TEST set) on Loaded Best Model: 0.32607956477388644 (time: 0.004607029583143151)
#
# === case=4_2, backbone=resnet34 ===
# idx: 20, loss for current batch: 1.376523
# best model updated
# Epoch 1, Loss: train=1.2954 valid=1.2590, Acc: valid=0.3675
# Epoch 2, Loss: train=1.2844 valid=1.2590, Acc: valid=0.3675
# Epoch 3, Loss: train=1.2844 valid=1.2590, Acc: valid=0.3675
# Epoch 4, Loss: train=1.2844 valid=1.2590, Acc: valid=0.3675
# Epoch 5, Loss: train=1.2844 valid=1.2590, Acc: valid=0.3675
# Epoch 6, Loss: train=1.2844 valid=1.2590, Acc: valid=0.3675
# Epoch 7, Loss: train=1.2844 valid=1.2590, Acc: valid=0.3675
# Epoch 8, Loss: train=1.2844 valid=1.2590, Acc: valid=0.3675
# Epoch 9, Loss: train=1.2844 valid=1.2590, Acc: valid=0.3675
# Epoch 10, Loss: train=1.2844 valid=1.2590, Acc: valid=0.3675
# Epoch 11, Loss: train=1.2844 valid=1.2590, Acc: valid=0.3675
# Epoch 12, Loss: train=1.2844 valid=1.2590, Acc: valid=0.3675
# Epoch 13, Loss: train=1.2844 valid=1.2590, Acc: valid=0.3675
# Epoch 14, Loss: train=1.2844 valid=1.2590, Acc: valid=0.3675
# Epoch 15, Loss: train=1.2844 valid=1.2590, Acc: valid=0.3675
# Epoch 16, Loss: train=1.2844 valid=1.2590, Acc: valid=0.3675
# Epoch 17, Loss: train=1.2844 valid=1.2590, Acc: valid=0.3675
# Epoch 18, Loss: train=1.2844 valid=1.2590, Acc: valid=0.3675
# Epoch 19, Loss: train=1.2844 valid=1.2590, Acc: valid=0.3675
# Epoch 20, Loss: train=1.2844 valid=1.2590, Acc: valid=0.3675
# Best Epoch: 0, Best Valid Loss: 1.2590021312746227
# Valid Loss (with Epoch valid set) on Loaded Best Model: 1.2590021312746227
# Final Acc (with TEST set) on Loaded Best Model: 0.32573954437266234 (time: 0.00812747167504352)
#
# === case=4_2, backbone=resnet50 ===
# idx: 20, loss for current batch: 1.251523
# best model updated
# Epoch 1, Loss: train=1.2872 valid=1.2590, Acc: valid=0.3675
# Epoch 2, Loss: train=1.2844 valid=1.2590, Acc: valid=0.3675
# Epoch 3, Loss: train=1.2844 valid=1.2590, Acc: valid=0.3675
# Epoch 4, Loss: train=1.2844 valid=1.2590, Acc: valid=0.3675
# Epoch 5, Loss: train=1.2844 valid=1.2590, Acc: valid=0.3675
# Epoch 6, Loss: train=1.2844 valid=1.2590, Acc: valid=0.3675
# Epoch 7, Loss: train=1.2844 valid=1.2590, Acc: valid=0.3675
# Epoch 8, Loss: train=1.2844 valid=1.2590, Acc: valid=0.3675
# Epoch 9, Loss: train=1.2844 valid=1.2590, Acc: valid=0.3675
# Epoch 10, Loss: train=1.2844 valid=1.2590, Acc: valid=0.3675
# Epoch 11, Loss: train=1.2844 valid=1.2590, Acc: valid=0.3675
# Epoch 12, Loss: train=1.2844 valid=1.2590, Acc: valid=0.3675
# Epoch 13, Loss: train=1.2844 valid=1.2590, Acc: valid=0.3675
# Epoch 14, Loss: train=1.2844 valid=1.2590, Acc: valid=0.3675
# Epoch 15, Loss: train=1.2844 valid=1.2590, Acc: valid=0.3675
# Epoch 16, Loss: train=1.2844 valid=1.2590, Acc: valid=0.3675
# Epoch 17, Loss: train=1.2844 valid=1.2590, Acc: valid=0.3675
# Epoch 18, Loss: train=1.2844 valid=1.2590, Acc: valid=0.3675
# Epoch 19, Loss: train=1.2844 valid=1.2590, Acc: valid=0.3675
# Epoch 20, Loss: train=1.2844 valid=1.2590, Acc: valid=0.3675
# Best Epoch: 0, Best Valid Loss: 1.2590021312746227
# Valid Loss (with Epoch valid set) on Loaded Best Model: 1.2590021312746227
# Final Acc (with TEST set) on Loaded Best Model: 0.32573954437266234 (time: 0.014773265175197435)

# %%
result_df = pd.DataFrame(result_dict)
result_df
# Out:
#     backbone case  accuracy  inference_time
# 0   resnet18    1  0.343081        0.004775
# 1   resnet34    1  0.576335        0.008283
# 2   resnet50    1  0.325740        0.014295
# 3   resnet18    2  0.331180        0.002385
# 4   resnet34    2  0.343081        0.006674
# 5   resnet50    2  0.535192        0.007452
# 6   resnet18    3  0.325740        0.002377
# 7   resnet34    3  0.446107        0.004236
# 8   resnet50    3  0.325740        0.005486
# 9   resnet18  4_1  0.325740        0.006815
# 10  resnet34  4_1  0.325740        0.008017
# 11  resnet50  4_1  0.325740        0.010588
# 12  resnet18  4_2  0.326080        0.004607
# 13  resnet34  4_2  0.325740        0.008127
# 14  resnet50  4_2  0.325740        0.014773

# %%
result_df.to_csv(f'result_experiment_3_lr_{LEARNING_RATE}.csv')
