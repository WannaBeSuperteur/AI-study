# %%
import numpy as np
import pandas as pd
import plotly.express as px
import math

# %%
# Covariance Matrix 등 표시할 때 줄이 넘어가는 것 방지

np.set_printoptions(linewidth=65536)

# %%
# 여러 번 반복해도 똑같은 데이터 생성

np.random.seed(2025)

# %%
# 데이터 생성

n_data = 10000

# features
x1 = np.random.uniform(-1, 1, n_data)   # feature 1
x2 = np.random.uniform(10, 20, n_data)  # feature 2
x3 = np.random.uniform(0, 3, n_data)    # feature 3
x4 = 3.0 * x1 + 4.0 * x2 + np.random.normal(0, 1.5, n_data)     # feature 4
x5 = 3.0 * x1 - 2.5 * x3 + np.random.normal(0, 1.25, n_data)    # feature 5
x6 = 10.0 * x2 + 5.0 * x3 + np.random.normal(0, 1.75, n_data)   # feature 6
x7 = 2.0 * x4 + 1.5 * x5 + 10.0 * x6 + np.random.normal(0, 3, n_data)  # feature 7

# target features
Z = x1 + 3.5 * x2 - 1.5 * x3 + 0.25 * x4 + 2.25 * x5 - 5.0 * x6 + 0.05 * x7 + np.random.normal(0, 20.0, n_data)
Y = np.where(Z > -650, 1, 0)

# %%
# features 를 DataFrame 으로 묶기

X = pd.DataFrame(np.array([x1, x2, x3, x4, x5, x6, x7]).T,
                 columns = ['x1', 'x2', 'x3', 'x4', 'x5', 'x6', 'x7'])

# %%
X
# Out:
#             x1         x2        x3         x4        x5          x6  \
# 0    -0.729024  11.799575  2.210763  46.591230 -6.715616  129.019107
# 1     0.775703  18.325762  1.015722  75.860538  0.362405  188.361382
# 2     0.865211  13.171807  0.760341  54.255391 -0.075004  135.691516
# 3    -0.108864  14.929943  0.135729  59.800570  2.189315  149.282323
# 4    -0.223529  11.246902  2.806034  44.228312 -5.223614  125.049275
# ...        ...        ...       ...        ...       ...         ...
# 9995 -0.865921  13.634483  1.797690  53.288799 -7.188415  146.525520
# 9996  0.259917  19.905819  2.766057  80.774763 -4.985581  211.762857
# 9997 -0.476120  10.509216  1.620520  40.019763 -3.729654  113.509149
# 9998 -0.151336  17.137833  1.188643  65.893734 -3.705811  176.294488
# 9999  0.921749  10.578099  1.138772  44.274193  0.315815  113.237160
#
#                x7
# 0     1373.959493
# 1     2038.659560
# 2     1464.496608
# 3     1614.552124
# 4     1328.552497
# ...           ...
# 9995  1559.898396
# 9996  2271.385457
# 9997  1205.795188
# 9998  1887.561149
# 9999  1224.324816
#
# [10000 rows x 7 columns]

# %%
# X 에 대한 데이터 분포 출력

import plotly.figure_factory as ff

for col in X.columns:
    bin_size = (X[col].max() - X[col].min()) / 100

    fig = ff.create_distplot(hist_data=[X[col].values.tolist()],
                             group_labels=[col],
                             bin_size=bin_size)
    fig.update_layout(width=900, height=520)

    fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="14fbbc79-b7a8-47ff-9c8d-10fbc8c61e17" class="plotly-graph-div" style="height:520px; width:900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("14fbbc79-b7a8-47ff-9c8d-10fbc8c61e17")) {                    Plotly.newPlot(                        "14fbbc79-b7a8-47ff-9c8d-10fbc8c61e17",                        [{"autobinx":false,"histnorm":"probability density","legendgroup":"x1","marker":{"color":"rgb(31, 119, 180)"},"name":"x1","opacity":0.7,"x":[-0.7290236726440764,0.7757034054607559,0.8652112797730049,-0.10886367190480972,-0.22352890777203482,-0.4848071293976821,0.31473517094207537,-0.014766124987475093,0.9284768385001143,0.60196894973888,-0.08958942958085037,0.6021161731839897,-0.9165640543624978,0.5389157438756231,-0.9936577664894115,-0.41438121590104626,0.221828665333758,0.8260547828412923,-0.3997699905107268,-0.5028027266585802,0.33278420980665757,0.9750658217196329,-0.06345918785114346,-0.7534252409472912,0.832062773464878,0.8922870669668503,-0.44460525339158474,0.03930737751592095,-0.6905100025671167,-0.9707452943515591,-0.3515135871810178,0.9817968774915744,0.026282575611985326,0.7529912825043323,-0.8652085066815607,-0.4316925256874051,-0.06220146414700789,0.5235463809137351,0.8452235534576378,-0.2139524858757298,0.8581753543813058,-0.0007759791334565058,0.6040993806032251,0.7931602278073766,-0.03574184953093407,0.6958598046962556,-0.44664143277907686,-0.3195415731556077,-0.7898507974832718,0.04629543743056286,0.29701604270275506,0.799223167313972,-0.7922681158892069,-0.3765106480110487,-0.843793361762009,0.8757403771208427,0.9181739752252265,-0.6175156302596874,0.9080422888589188,-0.11190345203924079,-0.47315121903749713,0.3397954308143305,-0.2474633701351754,0.9709322597056889,0.33414660283855024,0.9829347998917723,0.9471289479562688,-0.6370873514946569,-0.11725600511177947,0.34558676695320756,0.30713516815215347,-0.2339215237887673,0.3384636047386169,0.4396712849100892,0.5667289147204668,-0.3580349199523043,-0.8058786630044816,0.6688352277814484,-0.9495549635969951,-0.5224635223069487,0.7142166738589908,-0.8990791912174505,-0.6117816319035738,-0.048188651420691286,-0.5296326904960202,-0.28179674837357593,-0.7096729657323231,-0.7287239573571942,-0.8044239778286684,-0.6966305915774378,-0.7109605437343174,-0.9410512531424209,0.4584296343464953,0.3523877715378769,-0.11292297471319834,-0.7502492783767374,-0.648452468934388,0.2193968515791882,-0.4562045881481256,0.42552799613488124,-0.2679708161392307,-0.44038607554571385,0.7630053260772285,-0.6665670158741268,-0.7983071080037181,0.9482437227640945,0.9129040731948115,-0.7493902617003569,-0.7369873823696107,-0.3190434371425017,0.001088904457321238,0.6951620217796701,0.13636374366074544,-0.5671302423059497,0.24288352176691186,-0.22757172300501538,-0.2304385084184406,-0.6217555669299004,0.9147857521456948,-0.7537537288648326,-0.826932725758615,0.20347320988474094,0.1918312478212152,-0.7478484529998861,0.23004970130657232,-0.34523786094115083,-0.3094138421739141,-0.3185822442226267,-0.7552264946841525,0.8984806399807657,-0.29221898968582827,-0.019133446646829144,-0.8750519180602319,-0.021454017028087247,-0.3001688681958392,0.9221444301378425,-0.4720240478411877,0.4715866085958602,-0.0025092721753616765,0.8535262099275134,0.35266780356774463,-0.8545335762348354,-0.47796118595731696,-0.6264305321627341,0.2887608604203644,-0.8761494621001349,-0.31942561287839877,-0.017571778916515735,0.5698120192457055,-0.9295553330698689,0.21798885954956249,0.18119612805310314,-0.9067019417382101,-0.6446643405471342,0.6012440481519217,-0.4620783747414978,-0.5393239104477416,0.7007567135521304,0.7300987483806001,-0.14063487677489528,0.2004760471772875,-0.3952793188800834,-0.2794827176598298,0.5444294212025369,0.23593153832585956,0.43764508135519 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="7983e0da-cbcc-4c57-a81e-cbc86f59eaf4" class="plotly-graph-div" style="height:520px; width:900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7983e0da-cbcc-4c57-a81e-cbc86f59eaf4")) {                    Plotly.newPlot(                        "7983e0da-cbcc-4c57-a81e-cbc86f59eaf4",                        [{"autobinx":false,"histnorm":"probability density","legendgroup":"x2","marker":{"color":"rgb(31, 119, 180)"},"name":"x2","opacity":0.7,"x":[11.79957480378504,18.325762262644123,13.171806809154285,14.929943252466547,11.24690212745815,15.731371035839128,15.491048499433631,15.639979212711296,14.431286653575697,13.52380600531292,11.81300942755802,13.404747051517356,10.872840758689291,17.76415693522782,16.266334481784423,15.653626270076725,16.295330696611373,13.469404635052225,18.474678864238157,12.310915948992013,18.09018153900994,19.948875716223892,15.869965551090756,17.476228699260766,12.986712178579136,19.341649733881873,13.7422534592041,18.31164980591076,17.782689867694558,17.46419810153712,10.709664984742341,10.497380326861443,17.485653311116003,14.1936529423011,16.045212784423065,19.44073142154442,19.75364455903282,13.945842461214944,11.850802552709132,14.053817893449803,19.999432092290846,16.43237597861375,15.566493836762852,14.915327434750616,11.411423011293719,15.872325168848645,10.191091167342428,18.210278277739114,18.875594884775943,19.471079232077006,19.93334160419318,16.935379162807205,14.473275624831333,10.167854751486233,14.429962705034583,18.91046536057239,11.874339401217483,13.629427726196816,10.906205391679002,16.527608392760158,12.335123679112154,19.49494184715162,19.465753715912243,11.441238041723373,15.962994395892547,11.899142351577373,11.225225150726576,11.380025617733528,11.240657393244453,19.97556597732507,18.937428789618906,12.868762754785028,12.09739489133634,18.651190253364682,17.13580702911456,15.434078470633033,10.40536554795367,17.437949392387704,13.144510188316762,12.310963938198391,19.528954626584767,16.675679946607257,12.027340802173505,17.284171377815127,16.06433456489645,18.738219918462228,12.2343214844117,14.860856019502622,12.96908428021882,17.50453077402703,16.98577019316956,11.84349357874309,18.635453207429677,18.17949364555752,14.673123388988607,16.031962676416743,15.963918552006731,18.218085587263843,15.185190211124569,16.015387351149435,18.633882391535437,10.74562282929131,10.646068524051362,12.605567118030136,11.08199927148046,13.90214191665896,18.29887959089735,11.098712725105338,14.124597819617767,17.667217666094952,18.398948496538413,11.393618793130846,18.506762273890054,17.226174294224624,10.471459134488613,11.16215416807059,14.411182657232487,17.49749259017716,12.460121492696995,15.641809106610381,19.473838649642623,19.718938452649542,19.147268573378987,18.99014531872993,15.226734697592198,10.497639933985036,18.475708826446606,14.334333735746835,17.273671606435773,18.845279255545886,14.19893627488368,10.32797414949579,16.476775684780517,15.292446020185881,11.664079583243412,18.050131660790143,15.739937144200498,18.751580337644928,14.46126085179479,13.485038144466877,10.202129257373683,15.687485283786213,17.95165446411971,19.144517519425467,19.22845960009737,19.24382859956247,18.954205069985072,17.489236050271682,18.332896500486733,12.986890931128965,15.848893458359509,16.09118407133223,18.38218403192444,16.803054395694215,12.249106373330461,17.19850729854599,10.837972465867502,13.202355273955444,18.401782844817966,15.444780216331964,12.161144477688175,13.939478492582023,17.8787054281923,14.821391522254357,15.727964790362527,11.017169698313312,13.844116488556399,12.49809792463902,17.881211077220392,13.784728169513674,17.29185835316934,13.820824501599718,10.233998351734595,13.289955046516795,11.36217646728663,19.13862780454516,13. ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="2f94da7f-9c51-4668-80cf-ba899048c0e5" class="plotly-graph-div" style="height:520px; width:900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2f94da7f-9c51-4668-80cf-ba899048c0e5")) {                    Plotly.newPlot(                        "2f94da7f-9c51-4668-80cf-ba899048c0e5",                        [{"autobinx":false,"histnorm":"probability density","legendgroup":"x3","marker":{"color":"rgb(31, 119, 180)"},"name":"x3","opacity":0.7,"x":[2.2107633872959753,1.0157222949796312,0.7603414276551815,0.13572922969754342,2.8060342858292397,1.304570882434446,1.7460935446822243,0.20701714187233977,0.1657983136371074,1.919254428316055,2.5476870269959377,0.24185879605248772,1.5188924268692823,2.5339668629747503,1.294139929048914,2.85159177561122,2.871447364984245,0.35615508124608797,2.2886120495572246,0.3018801075918057,2.371111022228666,2.0670043620189906,2.480106898868515,2.3506565694432684,0.9711080990640917,0.5737339286719194,0.7364211686850037,1.1383654800178462,2.8423106226710404,1.7259400229507404,2.3470003531365027,2.2718506257503486,2.785251289991201,0.7876815147466798,2.555926088424447,1.7544119591434302,1.8550928095825554,0.3312355697195226,1.3417168235094232,1.3628271689652833,1.1133429380553816,0.9150306356792502,1.113054229649177,0.0043312233878447515,0.8939147754198757,2.5251625650832548,0.6411695103517302,1.838184801282087,1.1833705918322472,1.1676762652211443,1.740556607190388,2.681378663532969,0.8013788445387455,1.2968749140401123,2.371277747323781,1.2110049147693336,2.8655348123201465,2.325904499390094,1.667403641407132,0.6802356203419031,1.9970466318176945,2.720590659500088,2.0320162023301025,1.3903259950718803,2.414362817157943,2.4638061004005865,2.515645558566521,1.4734066611915058,1.6593800385391906,2.39251522661787,2.645558584619044,2.9374666689588635,0.7517281689347399,0.15665191311070958,0.21792078643980906,0.4181142182912363,0.0065859976484923255,0.3199013376435583,1.5351223976568746,0.956118508404863,2.915537638698363,1.1449504209417456,2.6200976081875713,1.1517458871287118,2.4174119179507767,0.8124966005717366,1.5827200041849208,1.4671132772236901,1.5455419288110557,1.0419870645969693,1.240932106932557,2.0749090168194866,1.9846820234600377,0.39586027834140836,0.643302107265676,2.303324004861883,0.7730977072043338,1.3735602497492758,2.926588412231826,1.6695634680121523,0.11534552751847083,0.2013010267713684,0.32379466169618065,1.3081789193577407,2.621559066369819,1.5676258672511596,2.8365541174740585,2.0233333298378686,2.6194950755560464,2.972470813968621,2.8108014114479816,1.206001909673787,2.8708963956223252,1.803763324724084,0.13750711523467096,0.8694352922180542,2.6613556131508003,0.17275294185793488,0.3845791739823289,1.8483885249516967,1.517575193119212,0.16489389459557446,1.6287651488242112,1.5307041408590547,1.1271196199812001,0.015037470159806277,2.6891817113791436,1.508632724583134,0.69891031866971,0.4605299257518688,0.451602135547174,0.28547530928855946,2.1543338480478513,1.0697799217156332,0.4702327795942528,2.920083217682209,2.0140185131264414,0.8283026825863804,2.3066845904841924,2.335241854116765,2.169825310553677,0.5309081393458225,2.8195218351300064,2.1137864539980367,0.12588310926179103,2.618782840036278,0.14115615890703348,2.1651307007552476,2.5305644599611075,1.9512586611510383,0.053095292510827674,1.672114784179557,2.4413330848502026,1.308933403744235,2.1233296863017284,0.8883661813588849,2.2525569283752582,0.3767670689665883,0.45499986284603067,0.47653657445339637,0.2553599131533737,1.5194560549722942,2.8773147164802126,2.7493426481046845,2.246230443087968,0.34375109795716396,2.054804971347279,1.5858481771198447,2.1030754337198356,0.364687051704527,0.8066565118566253,2.1951550974485787,1.5062882976922924,1.1814735336529334,1.857036 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="82077fee-fcc7-4293-9231-1e9dcca21661" class="plotly-graph-div" style="height:520px; width:900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("82077fee-fcc7-4293-9231-1e9dcca21661")) {                    Plotly.newPlot(                        "82077fee-fcc7-4293-9231-1e9dcca21661",                        [{"autobinx":false,"histnorm":"probability density","legendgroup":"x4","marker":{"color":"rgb(31, 119, 180)"},"name":"x4","opacity":0.7,"x":[46.59122984323719,75.8605378096381,54.25539102340531,59.80057007646193,44.22831249795405,63.90027994779586,65.42731653645983,66.01949436734218,62.27691918553699,55.76984106910647,47.82316029688922,57.06756900905719,41.48284902197518,71.4591863753522,62.101703153165154,62.57602712213511,67.26465439547223,56.30417073004238,72.53602538170931,49.06041900231681,72.91744301239038,83.41709027204811,63.17986922446597,69.78441421162933,55.58575345102415,80.09496192228862,53.54118275571268,72.76946565280615,67.83279862506896,67.96411165911337,40.92199791264466,42.22776366680182,69.18677234847853,60.18823435892792,60.870961053242404,76.69420824095498,78.38051360891411,57.10336929597287,47.8080341341384,56.992537304448526,84.0966740570284,65.70869660365756,64.01162213730585,63.546009858151464,43.46142820069012,64.65267575038594,39.5120895415206,69.72745823232556,72.83786913375083,76.50025726151826,79.90954311663558,68.7427579025802,53.599703100604536,40.69153554167926,55.822484325933964,77.41812491074525,50.28552388976308,51.31397455712256,45.66906825731379,67.57970828032721,48.74581175894525,82.13525891588101,78.33371092276106,48.75509021125413,64.71517488994981,50.304482730255046,49.245219788418424,44.33589737172,44.23820193159016,79.54779708658052,76.13209657278253,52.2076581558752,47.76520212087975,76.53956065201979,70.82346913292007,60.65451084132124,39.04466261533186,72.05276131365825,49.09740692842351,47.728276496693475,82.39244596169445,61.56937371074545,46.478914179857036,70.28735084297385,61.298302927796854,73.85750750104322,47.702249888767604,55.67613712208701,50.09993540080954,66.11946983421213,67.40829821266746,43.65943837712037,75.39959184821252,75.54079242527855,59.74635429154182,59.72494886960515,61.179344709617475,72.18447827341835,59.068605785151824,66.35622023719638,73.22985769624788,39.5833779611686,45.60937719964551,49.32798220406365,42.02632997040989,58.588757565727335,76.32353625011916,43.49677989658065,53.563739409887,68.48960845991061,74.72623509813147,45.77229244005382,75.13049611793171,67.46063630640934,40.98499271099754,42.34774962698992,58.07515648343819,66.71692837123103,51.04247799440213,59.69350324376579,75.73206772226159,77.88192195264794,74.22082247624998,74.71403080691704,63.8207041989751,40.381217214342456,70.53263321760267,54.49247165776224,67.05015735096768,79.8591891012084,52.2282678134104,40.00680318104514,61.51695946456901,63.2951322138946,47.61775357507646,72.1948130127134,64.67638018287906,76.84344175430212,58.918099784526035,56.38596683020916,40.25183953440792,60.856311410145665,69.55229914835276,74.12160807321538,75.72389555877544,74.3533832661403,74.76577459981824,71.20474870719931,72.78801455752819,47.188403884979124,65.8345396939349,65.41790610514788,69.18841708019401,66.20304368025727,51.54774490878945,68.73104107531199,39.94501022129554,53.78859514809888,76.27268608237442,63.23246968774061,47.87854438565592,54.733719353995134,71.61805938054427,60.37960712553388,62.82693778009716,46.52555604656959,55.059016580798584,49.507657376142916,67.71346568328276,55.1092680493281,68.72092257156736,56.85398636050428,37.934644542046506,50.96532599557119,44.76964971026339,77.15999427250757,55.50200307850289,71.72593167180567,45.98725482202307,68.7908124740558,79.30348436690421,44.37068186971077,72.23875118179714, ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="14f7db44-2ea4-427c-8999-0cb1a1866d65" class="plotly-graph-div" style="height:520px; width:900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("14f7db44-2ea4-427c-8999-0cb1a1866d65")) {                    Plotly.newPlot(                        "14f7db44-2ea4-427c-8999-0cb1a1866d65",                        [{"autobinx":false,"histnorm":"probability density","legendgroup":"x5","marker":{"color":"rgb(31, 119, 180)"},"name":"x5","opacity":0.7,"x":[-6.715615751774923,0.36240452472645845,-0.07500405288913647,2.189315181783441,-5.223614388070255,-5.79057149394453,-2.4486631355508406,-2.6858963680271275,3.466781783179976,-1.4432614600405098,-5.626869960418453,-0.3882904620518701,-5.734937302917639,-4.4651369166776504,-8.545664151283608,-8.181743416323414,-6.349747748148081,0.9801288516704623,-6.963629767441476,-0.7969679394876237,-8.808605240738315,-2.3281389911262944,-5.146000110394112,-7.998657289510117,-0.7273100742808977,2.6542167868687576,-4.486808041377018,-3.0758893725593373,-8.364825920056989,-5.8752573402328006,-6.426681751890204,-2.017743576745626,-7.807183648022585,-0.740438149742888,-10.022940831553774,-3.3802773267822412,-3.712786041484578,1.5044795539584288,-1.2757678548417928,-3.8710683059435684,1.4628369303627975,-3.7476568891841255,-1.5707649666196248,3.491320278263303,-1.3849668776303963,-2.34627743626967,-4.567245027338208,-7.789822427963007,-5.361848608136955,-3.402054305059973,-1.7818969952111388,-3.6576432583260265,-5.299761179642781,-1.8819660330032981,-8.124824125516836,2.593788820908401,-3.0087067248937416,-7.737341823779446,-1.265185889757855,-2.2571897135038372,-8.059384675006541,-6.570365029210549,-6.558105403203592,-0.3117701256475114,-5.155102515841685,-1.7451585887021344,-4.170932965841924,-8.230689385441423,-4.073339708426764,-4.78717139108667,-4.839701891602645,-7.744748715449005,-2.113073169891577,0.46368879478696934,-0.14061318051766425,-2.7163150470553568,-0.3349434668719731,1.0247661599541182,-4.714435621450671,-3.360505376994133,-4.409312449612642,-5.06940350767725,-6.653357607514659,-1.5716885069489321,-6.066977624137737,-2.710189456768484,-4.116213420314613,-4.032955881254383,-6.2218086401815365,-5.65393158459844,-6.634716162845051,-5.135761820496902,-2.6974933313336518,-1.1148096629977204,-2.139909570276988,-8.815714843373557,-1.6652488402789825,-3.893295838791854,-7.506122803799778,-1.8604991341873416,-1.4965031019272659,-0.7302529345491966,0.3566137596278489,-4.339279065518565,-7.492241828539526,-1.2086870858633327,-2.603531769835406,-6.195860086435284,-8.289447210803965,-9.430253924734973,-8.026190854195715,-1.1544233133587913,-3.3680908079115977,-7.274576826792716,0.05659502139810779,-2.3595388276376874,-7.368614237548202,-2.215234812060989,1.4129011616855318,-5.831653634085982,-6.879504396824393,1.3226619304106393,-4.223370017820881,-6.544608234176279,-2.2110477697677786,1.755427420300535,-6.130827570434737,-5.364306704255121,-4.565583296020935,2.390167742247222,-1.2983374276058783,-1.1176969453517769,-9.692933943594333,-3.1023130858856085,-0.6857150068842686,-6.5817872433780416,-7.87496611012959,-1.8927217138525905,-1.648362971755983,-2.5605290897543203,-4.889695349956773,-4.842596690165699,-6.538557071602009,-8.362739803175735,1.3671404738839312,-7.7859281728699825,0.995719757288682,-4.961735362773698,-5.965518452806043,-10.328079371191336,1.6869212982965127,-3.5958524210233076,-8.304385004375177,-5.895389493523495,-3.5814998330652035,-5.921588882623232,-8.225644568617383,-0.46964358467992495,1.4795567503331077,-1.9081019614243981,2.5357392210002256,-4.5872062968669916,-8.489408249511655,-7.487524203077896,-6.392757243256266,0.05701929093731661,-4.65749767923968,-1.4035430827120252,-9.898609715403074,-0.7110712811541979,-2.227712592471 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="93c28a70-7ff6-429c-be2e-9210859c8a3d" class="plotly-graph-div" style="height:520px; width:900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("93c28a70-7ff6-429c-be2e-9210859c8a3d")) {                    Plotly.newPlot(                        "93c28a70-7ff6-429c-be2e-9210859c8a3d",                        [{"autobinx":false,"histnorm":"probability density","legendgroup":"x6","marker":{"color":"rgb(31, 119, 180)"},"name":"x6","opacity":0.7,"x":[129.0191068940806,188.36138185328122,135.69151618149087,149.28232277495906,125.04927528280483,162.0474116274407,165.5662592456312,158.04664456152452,140.16192855434045,145.94581195002937,129.97615205943953,132.08031735979915,119.11431536279093,191.19712815632934,169.5185440639273,170.91163180240332,179.5341859560405,136.55378758717052,192.98815567611297,126.76441479990676,195.6357122484777,212.00288801536635,169.5708287584894,187.96738812716626,135.57121981474222,198.04922450306626,142.63826654436173,190.29320841290797,193.06751936613253,180.72893583992195,118.56393798407085,118.65114236855024,185.8912960387246,145.04601478034294,174.1629488090046,207.75545462181475,208.0388496179448,137.06161132870952,125.49504029552341,146.62280180915286,206.68047174186384,168.17857088614795,160.96558640429956,150.5717183244036,120.4107649989793,171.52718126637117,106.35718153308378,190.94419166161592,195.81276736561367,200.72777172014403,209.10232909073974,182.73855502508303,148.82463815925954,111.59705549229741,156.0724817264361,196.97422832999584,133.39533402901168,150.17430693180125,115.64491679079256,166.79333811904942,134.87742491797192,210.06193384938598,205.0659150296176,123.10554198600128,174.26085524064996,129.3423454146442,122.74033881829496,120.94067342614775,117.58980329810167,210.64652187702782,202.29781064940605,143.84871312570982,125.39476314136976,188.83454733153846,174.7351087524983,157.72097500669125,103.28399647185901,173.64275578840795,139.29039568798302,128.40900948393926,211.443530285464,171.67712754545565,130.30505299207707,177.38984839480977,174.71895802509803,191.61499699790048,129.4516233525353,161.05332939922008,139.06516737823915,177.68970134936202,175.50513655487052,126.48964907495859,192.9238874253143,185.5677306547019,147.07077306078241,172.08430840330067,164.37129922725964,189.24840539691408,168.67318716533248,170.18178810514905,187.63895462705082,105.56438181436732,110.06701309247234,133.7946268440261,124.37199714651003,148.80228624345537,197.7148912856014,122.2465121592694,152.3415640820678,191.9587732320002,197.58387628133008,119.66559368440525,196.83583079962622,182.02042862005618,107.26581824403996,113.67972719321915,158.6549994740862,174.1920951623371,129.42713308226791,167.25251530948157,202.33592102603993,199.55811193684096,200.60262641855059,195.56032743355186,157.09234809923024,104.79965727392931,200.5828588859406,151.34060997371535,173.55992815084267,190.81717298377058,145.81461390186792,105.98460790461804,174.93668082764233,160.3434082791263,117.86960561949034,196.4833431358246,168.92124942576652,192.47433130898042,154.0895926333236,151.21529790591066,111.9549639326474,159.77682993195108,193.74180392143597,199.82649054893244,194.69016265780147,205.80237741035066,184.7438517197368,185.6022436108704,197.59508264034895,136.93403413760947,160.18659638514845,167.29508154677112,196.14687425056553,174.14085339269573,133.4979295345848,176.24974561859273,118.32655165817498,135.27027487363316,187.98926782517026,158.02468420402457,122.20400146656642,144.33011462430727,194.25409747520717,162.50138112988458,170.17550189984024,111.23672544621404,145.6410188650577,133.69708894229603,187.53530488056163,142.91111069113057,179.54182795423242,148.64275681061181,109.09885681121997,141.28762890503754,124.39931141739085,196.414 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="9c99d006-9949-4f50-930f-43aad0d859fc" class="plotly-graph-div" style="height:520px; width:900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9c99d006-9949-4f50-930f-43aad0d859fc")) {                    Plotly.newPlot(                        "9c99d006-9949-4f50-930f-43aad0d859fc",                        [{"autobinx":false,"histnorm":"probability density","legendgroup":"x7","marker":{"color":"rgb(31, 119, 180)"},"name":"x7","opacity":0.7,"x":[1373.9594931116833,2038.6595599238124,1464.4966079474304,1614.5521242787331,1328.5524968846387,1742.3771820024579,1787.1937014992468,1707.3384893946672,1537.3129089823606,1566.9530108635672,1390.536385064805,1430.8986371432657,1265.8670573568584,2046.9636803136975,1803.3260280614477,1818.2541942711186,1919.6476464197247,1476.5504512300363,2063.3066948731935,1357.2992636501895,2092.019787112594,2281.481761017858,1811.9279426341088,2011.1641641207457,1466.8904440125184,2145.2335032659844,1526.7171003183191,2038.2862979234153,2053.0023437423242,1931.8737617460765,1255.5426829435914,1268.951625779734,1981.0966573675455,1572.4267328789401,1849.2557440712183,2226.5362438046454,2231.8281124516016,1487.9791320367083,1349.9266052440403,1573.9403696766651,2236.5342947757304,1806.940129734719,1735.4859673505016,1635.4851479864453,1289.0646188279024,1833.745876940233,1133.8737295764781,2034.584614051906,2092.130500753205,2151.4645370687513,2250.766502962927,1959.841250713632,1586.4187556570992,1195.5181931738362,1664.0804978363124,2125.5731909801234,1428.2943514315534,1594.5276480846273,1246.6697841042405,1792.080598121101,1435.3716438620766,2250.5810564064413,2201.9156117566076,1324.0750666604638,1867.9734132613007,1390.7455065374847,1318.099057007422,1281.5659463402098,1260.395173635291,2256.741569231894,2165.206613564213,1536.229846624042,1349.0769473390515,2039.692550015979,1883.0068394003044,1698.3098325688677,1109.5375975378658,1882.2403085480357,1486.165975805049,1372.4865293081982,2278.814653199583,1834.5668964882732,1389.0388434114848,1917.8534888503887,1858.5134273515916,2053.9427019704735,1383.0996731180146,1716.2852733496775,1477.1169959725225,1901.2696820767605,1884.5173913295346,1347.7323746334052,2073.9476276856826,2009.6871561717307,1586.0492404999166,1826.9456697929575,1765.7231252079914,2031.7804625778147,1790.5469835827928,1831.4518685089095,2020.2985466714592,1137.392464015481,1191.5458887733464,1429.2892327600407,1311.6223900830598,1600.9077440553633,2126.8449070884417,1298.9136278573121,1613.6719844517286,2043.951091546095,2110.554831053913,1288.747057934554,2111.880036718456,1948.1455434318837,1157.2137227379876,1219.416027758357,1692.9804237995986,1874.820605146752,1398.558585140891,1782.057997196588,2161.0791259323064,2154.960785258381,2143.388471152298,2097.0892533867823,1696.4281049845174,1130.5801302613831,2133.202860917445,1613.3361805273948,1858.8774040605126,2064.0346473715367,1556.9349320377755,1134.313387825679,1860.3100338973986,1722.1073987491677,1272.79362394517,2099.3695382748588,1804.558626342762,2074.9039268860993,1654.1376157453242,1615.7162493578758,1187.488954584807,1709.658436133908,2070.644238647253,2133.7328840648456,2107.2599357445456,2200.1629194401553,1994.3568918707474,1987.0643102581055,2108.9414687250096,1450.2863668161983,1733.42171000148,1798.8987002415615,2085.0727489914666,1865.2967115500835,1427.9147211864936,1892.8601489987393,1250.5279993245747,1463.5732882965485,2032.0267626534464,1700.1879368645668,1317.948724718241,1543.2831826935196,2072.2308077059274,1729.3022874342464,1810.3410443039656,1206.1799576345231,1563.8117381740703,1434.1227575521611,1996.5424512999393,1541.3905049548387,1932.937990181771,1584.6745062543553,1159.8676626703907,1507.8912551117264,1332.1454488433071,2124.0727623 ...

# %%
print(Y)
# Out:
# [1 0 1 ... 1 0 1]

# %%
# 상관계수 출력

all_data = pd.DataFrame(np.array([x1, x2, x3, x4, x5, x6, x7, Y]).T,
                        columns = ['x1', 'x2', 'x3', 'x4', 'x5', 'x6', 'x7', 'y'])

corr = all_data.corr()

fig = ff.create_annotated_heatmap(
            z=corr.round(decimals=3).to_numpy(),
            x=corr.columns.tolist(),
            y=corr.index.tolist(),
            xgap=1,
            ygap=1,
            zmax=1,
            zmin=-1,
            showscale=True,
            colorscale=['#F53', '#BBC', '#57F'],
            hoverongaps=True)

fig.update_layout(title='correlation', width=700, height=450)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="805d65c1-ef1e-4ed8-9cac-9f399b931ae6" class="plotly-graph-div" style="height:450px; width:700px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("805d65c1-ef1e-4ed8-9cac-9f399b931ae6")) {                    Plotly.newPlot(                        "805d65c1-ef1e-4ed8-9cac-9f399b931ae6",                        [{"colorscale":[[0.0,"#F53"],[0.5,"#BBC"],[1.0,"#57F"]],"hoverongaps":true,"reversescale":false,"showscale":true,"x":["x1","x2","x3","x4","x5","x6","x7","y"],"xgap":1,"y":["x1","x2","x3","x4","x5","x6","x7","y"],"ygap":1,"z":[[1.0,-0.005,0.001,0.141,0.565,-0.005,0.015,0.027],[-0.005,1.0,0.005,0.981,-0.002,0.987,0.99,-0.84],[0.001,0.005,1.0,0.008,-0.715,0.155,0.134,-0.14],[0.141,0.981,0.008,1.0,0.079,0.968,0.975,-0.821],[0.565,-0.002,-0.715,0.079,1.0,-0.109,-0.081,0.115],[-0.005,0.987,0.155,0.968,-0.109,1.0,0.999,-0.852],[0.015,0.99,0.134,0.975,-0.081,0.999,1.0,-0.851],[0.027,-0.84,-0.14,-0.821,0.115,-0.852,-0.851,1.0]],"zmax":1,"zmin":-1,"type":"heatmap"}],                        {"annotations":[{"font":{"color":"#FFFFFF"},"showarrow":false,"text":"1.0","x":"x1","xref":"x","y":"x1","yref":"y"},{"font":{"color":"#FFFFFF"},"showarrow":false,"text":"-0.005","x":"x2","xref":"x","y":"x1","yref":"y"},{"font":{"color":"#FFFFFF"},"showarrow":false,"text":"0.001","x":"x3","xref":"x","y":"x1","yref":"y"},{"font":{"color":"#FFFFFF"},"showarrow":false,"text":"0.141","x":"x4","xref":"x","y":"x1","yref":"y"},{"font":{"color":"#FFFFFF"},"showarrow":false,"text":"0.565","x":"x5","xref":"x","y":"x1","yref":"y"},{"font":{"color":"#FFFFFF"},"showarrow":false,"text":"-0.005","x":"x6","xref":"x","y":"x1","yref":"y"},{"font":{"color":"#FFFFFF"},"showarrow":false,"text":"0.015","x":"x7","xref":"x","y":"x1","yref":"y"},{"font":{"color":"#FFFFFF"},"showarrow":false,"text":"0.027","x":"y","xref":"x","y":"x1","yref":"y"},{"font":{"color":"#FFFFFF"},"showarrow":false,"text":"-0.005","x":"x1","xref":"x","y":"x2","yref":"y"},{"font":{"color":"#FFFFFF"},"showarrow":false,"text":"1.0","x":"x2","xref":"x","y":"x2","yref":"y"},{"font":{"color":"#FFFFFF"},"showarrow":false,"text":"0.005","x":"x3","xref":"x","y":"x2","yref":"y"},{"font":{"color":"#FFFFFF"},"showarrow":false,"text":"0.981","x":"x4","xref":"x","y":"x2","yref":"y"},{"font":{"color":"#FFFFFF"},"showarrow":false,"text":"-0.002","x":"x5","xref":"x","y":"x2","yref":"y"},{"font":{"color":"#FFFFFF"},"showarrow":false,"text":"0.987","x":"x6","xref":"x","y":"x2","yref":"y"},{"font":{"color":"#FFFFFF"},"showarrow":false,"text":"0.99","x":"x7","xref":"x","y":"x2","yref":"y"},{"font":{"color":"#FFFFFF"},"showarrow":false,"text":"-0.84","x":"y","xref":"x","y":"x2","yref":"y"},{"font":{"color":"#FFFFFF"},"showarrow":false,"text":"0.001","x":"x1","xref":"x","y":"x3","yref":"y"},{"font":{"color":"#FFFFFF"},"showarrow":false,"text":"0.005","x":"x2","xref":"x","y":"x3","yref":"y"},{"font":{"color":"#FFFFFF"},"showarrow":false,"text":"1.0","x":"x3","xref":"x","y":"x3","yref":"y"},{"font":{"color":"#FFFFFF"},"showarrow":false,"text":"0.008","x":"x4","xref":"x","y":"x3","yref":"y"},{"font":{"color":"#FFFFFF"},"showarrow":false,"text":"-0.715","x":"x5","xref":"x","y":"x3","yref":"y"},{"font":{"color":"#FFFFFF"},"showarrow":false,"text":"0.155","x":"x6","xref":"x","y":"x3","yref":"y"},{"font":{"color":"#FFFFFF"},"showarrow":false,"text":"0.134","x":"x7","xref":"x","y":"x3","yref":"y"},{"font":{"color":"#FFFFFF"},"showarrow":false,"text":"-0.14","x":"y","xref":"x","y":"x3","yref":"y"},{"font":{"color":"#FFFFFF"},"showarrow":false,"text":"0.141","x":"x1","xref":"x","y":"x4","yref":"y"},{"font":{"color":"#FFFFFF"},"showarrow":false,"text":"0.981","x":"x2","xref":"x","y":"x4","yref":"y"},{"font":{"color":"#FFFFFF"},"showarrow":false,"text":"0.008","x":"x3","xref":"x","y" ...

# %%
# 1. 각 feature 가 평균 0, 표준편차 1 scaling 된 데이터로 변환

X_scaled = (X - np.mean(X, axis=0)) / np.std(X, axis=0)  # 또는 scikit-learn의 StandardScaler 사용 가능

# %%
X_scaled
# Out:
#             x1        x2        x3        x4        x5        x6        x7
# 0    -1.275738 -1.108602  0.805628 -1.141918 -0.967487 -0.971998 -0.999966
# 1     1.344625  1.163369 -0.563076  1.358784  1.347090  1.065152  1.119108
# 2     1.500496 -0.630885 -0.855568 -0.487110  1.204053 -0.742942 -0.711332
# 3    -0.195779 -0.018823 -1.570949 -0.013342  1.944506 -0.276386 -0.232953
# 4    -0.395459 -1.301005  1.487404 -1.343800 -0.479589 -1.108277 -1.144724
# ...        ...       ...       ...       ...       ...       ...       ...
# 9995 -1.514134 -0.469813  0.332527 -0.569693 -1.122097 -0.371024 -0.407190
# 9996  0.446423  1.713436  1.441617  1.778643 -0.401750  1.868497  1.861041
# 9997 -0.835327 -1.557816  0.129611 -1.703368  0.008949 -1.504436 -1.536076
# 9998 -0.269741  0.749813 -0.365027  0.507243  0.016746  0.650910  0.637404
# 9999  1.598952 -1.533836 -0.422144 -1.339880  1.331855 -1.513773 -1.477003
#
# [10000 rows x 7 columns]

# %%
# 2. Covariance Matrix 계산

cov_matrix = np.cov(X_scaled, rowvar=False)

# %%
print(cov_matrix)
# Out:
# [[ 1.00010001 -0.00490141  0.0011496   0.14103372  0.56468024 -0.00459686  0.01463943]
#  [-0.00490141  1.00010001  0.0051673   0.98090967 -0.00150635  0.98693946  0.98983796]
#  [ 0.0011496   0.0051673   1.00010001  0.00801632 -0.71504238  0.15501967  0.13418846]
#  [ 0.14103372  0.98090967  0.00801632  1.00010001  0.07866411  0.96844361  0.97527477]
#  [ 0.56468024 -0.00150635 -0.71504238  0.07866411  1.00010001 -0.10877214 -0.08054929]
#  [-0.00459686  0.98693946  0.15501967  0.96844361 -0.10877214  1.00010001  0.99957492]
#  [ 0.01463943  0.98983796  0.13418846  0.97527477 -0.08054929  0.99957492  1.00010001]]

# %%
# 3. Eigenvalue, Eigenvector 계산

eigenvalues, eigenvectors = np.linalg.eig(cov_matrix)

# %%
for i, evalue in enumerate(eigenvalues):
    print(f'Eigenvalue {i} : {evalue}')
# Out:
# Eigenvalue 0 : 3.962555246044329
# Eigenvalue 1 : 1.9313836333924168
# Eigenvalue 2 : 1.0016757004389292
# Eigenvalue 3 : 0.08987251698007105
# Eigenvalue 4 : 0.012977028283058342
# Eigenvalue 5 : 0.0021877923476341554
# Eigenvalue 6 : 4.8152520561966555e-05

# %%
for i, evector in enumerate(eigenvectors):
    print(f'Eigenvector {i} : {evector}')
# Out:
# Eigenvector 0 : [-1.87746638e-02  4.40511911e-01 -7.78663441e-01  4.26711629e-01 -1.29951283e-01  1.76016737e-02 -2.09904156e-04]
# Eigenvector 1 : [-0.49830273  0.0429712   0.10233028  0.02356247 -0.20509283  0.83466831  0.00932382]
# Eigenvector 2 : [-0.05831999 -0.54640456 -0.61876041 -0.5412365   0.1013905   0.10934857  0.00151438]
# Eigenvector 3 : [-0.49423351  0.10572344 -0.01507457  0.10416016  0.84973702 -0.09219631 -0.05409287]
# Eigenvector 4 : [ 0.02966641  0.70174398  0.00364165 -0.71149655  0.01716121  0.00555569 -0.01045489]
# Eigenvector 5 : [-0.50099987 -0.03966721  0.00814796 -0.06162678 -0.36335184 -0.37795186 -0.68460881]
# Eigenvector 6 : [-0.50178975 -0.01868791  0.00635735 -0.05958607 -0.27640096 -0.37374222  0.72676417]

# %%
# 4. Eigenvalue가 큰 순으로 정렬

eigen_collection = []

for evalue, evector in zip(eigenvalues, eigenvectors):
    eigen_collection.append({'eigenvalue': evalue, 'eigenvector': evector})

# np.linalg.eig 함수 자체에서 이미 정렬을 해 주는 것으로 추정하지만, 확실히 하기 위함
eigen_collection.sort(key=lambda x: x['eigenvalue'], reverse=True)

# %%
for i, info in enumerate(eigen_collection):
    print(f'Eigen value/vector {i} :\neigenvalue  = {info["eigenvalue"]}\neigenvector = {info["eigenvector"]}\n')
# Out:
# Eigen value/vector 0 :
# eigenvalue  = 3.962555246044329
# eigenvector = [-1.87746638e-02  4.40511911e-01 -7.78663441e-01  4.26711629e-01 -1.29951283e-01  1.76016737e-02 -2.09904156e-04]
#
# Eigen value/vector 1 :
# eigenvalue  = 1.9313836333924168
# eigenvector = [-0.49830273  0.0429712   0.10233028  0.02356247 -0.20509283  0.83466831  0.00932382]
#
# Eigen value/vector 2 :
# eigenvalue  = 1.0016757004389292
# eigenvector = [-0.05831999 -0.54640456 -0.61876041 -0.5412365   0.1013905   0.10934857  0.00151438]
#
# Eigen value/vector 3 :
# eigenvalue  = 0.08987251698007105
# eigenvector = [-0.49423351  0.10572344 -0.01507457  0.10416016  0.84973702 -0.09219631 -0.05409287]
#
# Eigen value/vector 4 :
# eigenvalue  = 0.012977028283058342
# eigenvector = [ 0.02966641  0.70174398  0.00364165 -0.71149655  0.01716121  0.00555569 -0.01045489]
#
# Eigen value/vector 5 :
# eigenvalue  = 0.0021877923476341554
# eigenvector = [-0.50099987 -0.03966721  0.00814796 -0.06162678 -0.36335184 -0.37795186 -0.68460881]
#
# Eigen value/vector 6 :
# eigenvalue  = 4.8152520561966555e-05
# eigenvector = [-0.50178975 -0.01868791  0.00635735 -0.05958607 -0.27640096 -0.37374222  0.72676417]

# %%
# 5. Eigenvalue가 가장 큰 K 개의 Eigenvector 선택

K = 3
PCA_eigenvectors = np.array([info['eigenvector'] for info in eigen_collection[:K]])

for i in range(K):
    print(f'Eigen value/vector {i} :\neigenvector = {PCA_eigenvectors[i]}\n')
# Out:
# Eigen value/vector 0 :
# eigenvector = [-1.87746638e-02  4.40511911e-01 -7.78663441e-01  4.26711629e-01 -1.29951283e-01  1.76016737e-02 -2.09904156e-04]
#
# Eigen value/vector 1 :
# eigenvector = [-0.49830273  0.0429712   0.10233028  0.02356247 -0.20509283  0.83466831  0.00932382]
#
# Eigen value/vector 2 :
# eigenvector = [-0.05831999 -0.54640456 -0.61876041 -0.5412365   0.1013905   0.10934857  0.00151438]

# %%
# NumPy.dot 을 이용하여 scaling 된 학습 데이터와 행렬곱 가능하게 변환
PCA_eigenvectors = PCA_eigenvectors.T

# %%
PCA_eigenvectors
# Out:
# array([[-1.87746638e-02, -4.98302731e-01, -5.83199892e-02],
#        [ 4.40511911e-01,  4.29711972e-02, -5.46404559e-01],
#        [-7.78663441e-01,  1.02330279e-01, -6.18760414e-01],
#        [ 4.26711629e-01,  2.35624684e-02, -5.41236501e-01],
#        [-1.29951283e-01, -2.05092825e-01,  1.01390502e-01],
#        [ 1.76016737e-02,  8.34668310e-01,  1.09348571e-01],
#        [-2.09904156e-04,  9.32382063e-03,  1.51438429e-03]])

# %%
# 특징 정보 보존 비율 계산

from itertools import accumulate

sum_eigenvalues = []  # a 번째 원소는 상위 a 위까지의 eigenvalue의 합
preserve_rates = []   # a 번째 원소는 정보 보존 비율 (상위 a 위까지의 eigenvalue가 전체 eigenvalue 중 차지하는 비율)

eigenvalues = [info['eigenvalue'] for info in eigen_collection]
sum_eigenvalues = list(accumulate(eigenvalues))
preserve_rates = [se / sum_eigenvalues[-1] for se in sum_eigenvalues]

# %%
for i, (ev, cum, rate) in enumerate(zip(eigenvalues, sum_eigenvalues, preserve_rates), 1):
    print(f'{i} 번째 Eigenvalue: {ev:7.4f}, 누적 합: {cum:7.4f}, 정보 보존 비율: {rate*100:6.2f}%')
# Out:
# 1 번째 Eigenvalue:  3.9626, 누적 합:  3.9626, 정보 보존 비율:  56.60%
# 2 번째 Eigenvalue:  1.9314, 누적 합:  5.8939, 정보 보존 비율:  84.19%
# 3 번째 Eigenvalue:  1.0017, 누적 합:  6.8956, 정보 보존 비율:  98.50%
# 4 번째 Eigenvalue:  0.0899, 누적 합:  6.9855, 정보 보존 비율:  99.78%
# 5 번째 Eigenvalue:  0.0130, 누적 합:  6.9985, 정보 보존 비율:  99.97%
# 6 번째 Eigenvalue:  0.0022, 누적 합:  7.0007, 정보 보존 비율: 100.00%
# 7 번째 Eigenvalue:  0.0000, 누적 합:  7.0007, 정보 보존 비율: 100.00%

# %%
print(f'{K} 차원으로 PCA 시 정보 보존 비율 : {preserve_rates[K-1] * 100.0}%')
# Out:
# 3 차원으로 PCA 시 정보 보존 비율 : 98.4989288345384%

# %%
# 6. K 개의 Eigenvector 축을 선택하여 데이터를 K 차원으로 축소

column_names = [f'new axis {i}' for i in range(1, K + 1)]
X_PCA_applied = np.dot(np.array(X_scaled), PCA_eigenvectors)
X_PCA_applied = pd.DataFrame(X_PCA_applied, columns=column_names)

# %%
X_PCA_applied
# Out:
#       new axis 1  new axis 2  new axis 3
# 0      -1.470156    0.021405    0.593808
# 1       1.348946   -0.022438   -0.846353
# 2      -0.017135   -1.747524    1.090006
# 3       0.955424   -0.695989    1.167544
# 4      -2.254229   -0.575661    0.369357
# ...          ...         ...         ...
# 9995   -0.541179    0.671569    0.292639
# 9996    0.467547    1.699928   -2.650545
# 9997   -1.525645   -0.949431    1.575714
# 9998    0.845192    0.687034   -0.368805
# 9999   -1.148138   -2.487866    1.698514
#
# [10000 rows x 3 columns]

# %%
# Logistie Regression 을 이용하여 학습

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

use_PCA = True  # 학습 대상을 PCA 적용된 것으로 할지 선택

logistic_regression = LogisticRegression()

if use_PCA:
    X_PCA_applied_train, X_PCA_applied_test, Y_train, Y_test = \
        train_test_split(X_PCA_applied, Y, test_size=0.2, random_state=2025)
    logistic_regression.fit(X_PCA_applied_train, Y_train)

    Y_pred = logistic_regression.predict(X_PCA_applied_test)

else:
    X_scaled_train, X_scaled_test, Y_train, Y_test = \
        train_test_split(X_scaled, Y, test_size=0.2, random_state=2025)
    logistic_regression.fit(X_scaled_train, Y_train)

    Y_pred = logistic_regression.predict(X_scaled_test)

# %%
# prediction result

print(f'prediction examples : {Y_pred[:20]}')
print(f'ground truth        : {Y_test[:20]}')
# Out:
# prediction examples : [0 0 0 0 0 1 0 1 1 0 1 1 0 0 1 1 1 1 0 1]
# ground truth        : [0 0 0 0 0 1 0 1 1 0 1 1 0 0 1 1 1 1 0 1]

# %%
# Accuracy, Recall, Precision, F1 Score 계산 함수

def compute_scores(TP, TN, FP, FN):
    accuracy = (TP + TN) / (TP + TN + FP + FN)
    recall = TP / (TP + FN)
    precision = TP / (TP + FP)
    f1_score = 2 * recall * precision / (recall + precision)

    print(f'Accuracy  : {accuracy}\nRecall    : {recall}\nPrecision : {precision}\nF1 Score  : {f1_score}')

# %%
# 성능지표 계산 (TP, TN, FP, FN, Accuracy, Recall, Precision, F1 Score)
# TP, TN, FP, FN 개수 계산

TP = sum(pred == 1 and Y_true == 1 for pred, Y_true in zip(Y_pred, Y_test))
TN = sum(pred == 0 and Y_true == 0 for pred, Y_true in zip(Y_pred, Y_test))
FP = sum(pred == 1 and Y_true == 0 for pred, Y_true in zip(Y_pred, Y_test))
FN = sum(pred == 0 and Y_true == 1 for pred, Y_true in zip(Y_pred, Y_test))

print(f'True  Positive : {TP}\nTrue  Negative : {TN}\nFalse Positive : {FP}\nFalse Negative : {FN}')
# Out:
# True  Positive : 1011
# True  Negative : 905
# False Positive : 45
# False Negative : 39

# %%
compute_scores(TP, TN, FP, FN)
# Out:
# Accuracy  : 0.958
# Recall    : 0.9628571428571429
# Precision : 0.9573863636363636
# F1 Score  : 0.9601139601139602
